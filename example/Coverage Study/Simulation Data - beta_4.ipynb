# %%
import os, importlib, sys, time

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import scipy.linalg as la
import scipy.stats as stats

# %%
import pyarrow

# %% [markdown]
# # 1. parameters

# %%
T = 60
T0 = 40

# %%
GPi = np.load('data/GPi.npz')

# %% [markdown]
# ## observation parameters

# %%
pi = np.zeros(T+T0)
pi[:min(GPi['pi'].shape[0], T+T0)] = GPi['pi'][:min(GPi['pi'].shape[0], T+T0)]
alpha = 0.01
r_Y = 10

# %% [markdown]
# $$Y_t = NegBinom( \frac{EY_t}{r_Y + EY_t}, r_Y )$$
#
# $$ EY_t = \alpha\sum_{s=1}^{t-1} I_s \pi_{t-s} $$

# %% [markdown]
# ## latent parameters

# %%
g = np.zeros(T+T0)
g[:min(GPi['g'].shape[0], T+T0)] = GPi['g'][:min(GPi['g'].shape[0], T+T0)]

# %%
d = 2
beta = np.array([1, -3.2])

# %%
r_I = 100
K = 6.5

# %% [markdown]
# $$I_t = NegBinom( \frac{EI_t}{r_I + EI_t}, r_I )$$
#
# $$ EI_t = R(\bar{A}_t, \beta) \sum_{s=1}^{t-1} I_s g_{t-s} $$
#
# $$R(\bar{A}_t, \beta) = \frac{K}{1+\exp(- \beta^\top A_t)}$$

# %% [markdown]
# ## seed values

# %%
mu = np.log(100)

# %% [markdown]
# $$I_{-T_0} = \mu_0$$

# %% [markdown]
# # 2. simulation

# %%
num_sim = 1000

# %% [markdown]
# ## random seed

# %%
np.random.seed(1234)

# %% [markdown]
# ## data generation

# %%
I0 = np.full(T0, np.exp(mu))

# %%
A = np.stack([np.full(T, 1), 1 * (np.arange(T) > 15)], -1)
R = K / (1 + np.exp(- A @ beta))

# %%
Pi = alpha * np.concatenate([[0],pi])[np.maximum(0, np.arange(T)[:,None] - np.arange(T))]
Pi0 = alpha * np.concatenate([[0],pi])[np.maximum(0, np.arange(T)[:,None] - np.arange(-T0,0))]

# %%
G = R[:,None] * np.concatenate([[0],g])[np.maximum(0, np.arange(T)[:,None] - np.arange(T))]
G0 = R[:,None] * np.concatenate([[0],g])[np.maximum(0, np.arange(T)[:,None] - np.arange(-T0,0))]

# %%
inv_ImG = la.inv(np.eye(T) - G)

# %%
EEI = inv_ImG @ (G0 @ I0)

# %%
EI = np.zeros((num_sim, T))
I = np.zeros((num_sim, T))

# %%
for t in np.arange(T):
    EI[:,t] = G0[t] @ I0 + G[t,:t] @ I[:,:t].T
    I[:,t] = np.random.negative_binomial(r_I, r_I/(r_I+EI[:,t]))

# %%
EEY = EEI @ Pi.T + Pi0 @ I0

# %%
EY = I @ Pi.T + Pi0 @ I0
Y = np.random.negative_binomial(r_Y, r_Y/(r_Y+EY))

# %% [markdown]
# ## result

# %%
plt.plot(A)
# Out:
# [<matplotlib.lines.Line2D at 0x13705fd30>,
#  <matplotlib.lines.Line2D at 0x13705dd50>]

# %%
plt.plot(R)

# %%
plt.plot(EI.T)
plt.show()

# %%
plt.plot(np.mean(I,0))
plt.plot(np.mean(EI,0))
plt.plot(EEI)
plt.show()

# %%
plt.plot(I.T)
plt.show()

# %%
plt.plot(np.mean(EEY, 0))
plt.plot(np.mean(EY, 0))
plt.plot(np.mean(Y, 0))
plt.show()

# %%
plt.plot(EY.T)
plt.show()

# %%
plt.plot(Y.T)
plt.show()

# %% [markdown]
# # 3. Save Data

# %%
data = {'sim': np.tile(np.arange(num_sim)[:,None], (1,T)).flatten(),
        'date': np.tile(np.arange(T), (num_sim,1)).flatten(),
        'R': np.tile(R, (num_sim,1)).flatten(),
        'EI': EI.flatten(),
        'infection': I.flatten(),
        'EY': EY.flatten(),
        'death': Y.flatten(),
        'intervention': np.tile(A[:,1], (num_sim,1)).flatten()}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#        sim  date         R           EI  infection         EY  death  \
# 0        0     0  4.751881   475.184804      516.0   0.956069      1
# 1        0     1  4.751881   511.412680      505.0   0.962545      1
# 2        0     2  4.751881   642.093954      669.0   0.968354      1
# 3        0     3  4.751881   854.356947      836.0   0.974111      3
# 4        0     4  4.751881  1148.169578      942.0   0.981589      1
# ...    ...   ...       ...          ...        ...        ...    ...
# 59995  999    55  0.648378   885.944342      908.0  39.632942     42
# 59996  999    56  0.648378   839.945956      853.0  37.595696     50
# 59997  999    57  0.648378   796.884901      795.0  35.639456     74
# 59998  999    58  0.648378   755.284834      661.0  33.743259     28
# 59999  999    59  0.648378   713.678448      696.0  31.929427     38
#
#        intervention
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 59995             1
# 59996             1
# 59997             1
# 59998             1
# 59999             1
#
# [60000 rows x 8 columns]

# %%
df.to_feather('data/simulation_randinf_4.feather')
