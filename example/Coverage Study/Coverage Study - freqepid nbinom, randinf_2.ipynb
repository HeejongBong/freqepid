# %%
import os, importlib, sys, time

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import scipy.linalg as la
import scipy.stats as stats
import scipy.optimize as opt

# %%
import freqepid

# %% [markdown]
# # 1. parameters

# %%
T = 60
T0 = 40

# %%
GPi = np.load('data/GPi.npz')

# %% [markdown]
# ## observation parameters

# %%
alpha = 0.01
r_Y = 10

# %% [markdown]
# $$Y_t = NegBinom( \frac{EY_t}{r_Y + EY_t}, r_Y )$$
#
# $$ EY_t = \alpha\sum_{s=1}^{t-1} I_s \pi_{t-s} $$

# %% [markdown]
# ## latent parameters

# %%
d = 2
beta = np.array([0.5, -2.7])

# %%
r_I = 100
K = 6.5

# %% [markdown]
# $$I_t = NegBinom( \frac{EI_t}{r_I + EI_t}, r_I )$$
#
# $$ EI_t = R(\bar{A}_t, \beta) \sum_{s=1}^{t-1} I_s g_{t-s} $$
#
# $$R(\bar{A}_t, \beta) = \frac{K}{1+\exp(- \beta^\top A_t)}$$

# %% [markdown]
# ## seed values

# %%
mu = np.log(100)

# %% [markdown]
# $$I_{[-T_0,0)} = \exp(\mu_0)$$

# %% [markdown]
# # 2. simulation

# %%
num_sim = 1000

# %% [markdown]
# ## load simulation

# %%
data = pd.read_feather('data/simulation_randinf_2.feather')

# %%
data
# Out:
#        sim  date         R          EI  infection         EY  death  \
# 0        0     0  4.045986  404.595779      441.0   0.956069      1
# 1        0     1  4.045986  429.880919      530.0   0.962544      2
# 2        0     2  4.045986  528.356785      533.0   0.968322      0
# 3        0     3  4.045986  693.167715      715.0   0.973949      3
# 4        0     4  4.045986  906.581202      952.0   0.981001      5
# ...    ...   ...       ...         ...        ...        ...    ...
# 59995  999    55  0.648378  402.686550      427.0  17.516285     11
# 59996  999    56  0.648378  379.787070      390.0  16.607593      8
# 59997  999    57  0.648378  358.160166      355.0  15.732875      8
# 59998  999    58  0.648378  338.050643      308.0  14.890695     10
# 59999  999    59  0.648378  318.713091      291.0  14.086622      6
#
#        intervention
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 59995             1
# 59996             1
# 59997             1
# 59998             1
# 59999             1
#
# [60000 rows x 8 columns]

# %% [markdown]
# # 3. Fit

# %%
model = freqepid.Model(GPi['g'], GPi['pi'], alpha, K, T0, "nbinom")

# %%
nsim = np.zeros(num_sim)
msim = np.zeros(num_sim)
bsim = np.zeros((num_sim,d))

# %%
for iter_sim in np.arange(num_sim):
    start_sim = time.time()
    
    data_i = data[data['sim']==iter_sim]
    A = np.stack([np.full(T, 1), data_i["intervention"].to_numpy()], -1)
    Y = data_i["death"].to_numpy()
    
    # fit
    nmle, mmle, bmle, ll =\
    model.fit(A, Y, n_iter=500, step_size=1,
              history=False, verbose=False)
    
    nsim[iter_sim] = nmle
    msim[iter_sim] = mmle
    bsim[iter_sim,:] = bmle
    
    sys.__stdout__.write("%d-th simulation finished, %f sec.\n"
                         %(iter_sim+1, time.time()-start_sim))
    sys.__stdout__.flush()
# Out:
# /Users/blueconet/mambaforge/envs/freqepid/lib/python3.10/site-packages/freqepid/model.py:140: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   bhaty = np.linalg.lstsq(Xy, Yy)[0]
# 1-th simulation finished, 2.995095 sec.
# 2-th simulation finished, 2.871347 sec.
# 3-th simulation finished, 2.767687 sec.
# 4-th simulation finished, 2.882564 sec.
# 5-th simulation finished, 2.746712 sec.
# 6-th simulation finished, 2.757442 sec.
# 7-th simulation finished, 3.367276 sec.
# 8-th simulation finished, 2.847843 sec.
# 9-th simulation finished, 2.946578 sec.
# 10-th simulation finished, 2.925280 sec.
# 11-th simulation finished, 2.871612 sec.
# 12-th simulation finished, 2.794829 sec.
# 13-th simulation finished, 2.651752 sec.
# 14-th simulation finished, 2.647539 sec.
# 15-th simulation finished, 2.836020 sec.
# 16-th simulation finished, 2.738990 sec.
# 17-th simulation finished, 2.793155 sec.
# 18-th simulation finished, 3.271459 sec.
# 19-th simulation finished, 3.093288 sec.
# 20-th simulation finished, 3.028573 sec.
# 21-th simulation finished, 2.972207 sec.
# 22-th simulation finished, 3.121573 sec.
# 23-th simulation finished, 2.973519 sec.
# 24-th simulation finished, 3.412670 sec.
# 25-th simulation finished, 2.772772 sec.
# 26-th simulation finished, 2.812577 sec.
# 27-th simulation finished, 2.853953 sec.
# 28-th simulation finished, 3.198717 sec.
# 29-th simulation finished, 2.910763 sec.
# 30-th simulation finished, 3.043779 sec.
# 31-th simulation finished, 3.003232 sec.
# 32-th simulation finished, 3.065850 sec.
# 33-th simulation finished, 2.826050 sec.
# 34-th simulation finished, 3.160301 sec.
# 35-th simulation finished, 3.018834 sec.
# 36-th simulation finished, 3.146287 sec.
# 37-th simulation finished, 2.879249 sec.
# 38-th simulation finished, 3.327330 sec.
# 39-th simulation finished, 2.653143 sec.
# 40-th simulation finished, 2.968603 sec.
# 41-th simulation finished, 2.858212 sec.
# 42-th simulation finished, 2.763046 sec.
# 43-th simulation finished, 2.597015 sec.
# 44-th simulation finished, 2.779039 sec.
# 45-th simulation finished, 2.951387 sec.
# 46-th simulation finished, 3.021821 sec.
# 47-th simulation finished, 3.002025 sec.
# 48-th simulation finished, 3.032478 sec.
# 49-th simulation finished, 2.846606 sec.
# 50-th simulation finished, 2.735449 sec.
# 51-th simulation finished, 2.885169 sec.
# 52-th simulation finished, 2.881811 sec.
# 53-th simulation finished, 2.872284 sec.
# 54-th simulation finished, 2.786032 sec.
# 55-th simulation finished, 2.697268 sec.
# 56-th simulation finished, 2.942907 sec.
# 57-th simulation finished, 3.255944 sec.
# 58-th simulation finished, 2.751329 sec.
# 59-th simulation finished, 2.964391 sec.
# 60-th simulation finished, 2.782923 sec.
# 61-th simulation finished, 2.706951 sec.
# 62-th simulation finished, 2.479105 sec.
# 63-th simulation finished, 2.878866 sec.
# 64-th simulation finished, 3.051462 sec.
# 65-th simulation finished, 2.811851 sec.
# 66-th simulation finished, 3.227280 sec.
# 67-th simulation finished, 2.901297 sec.
# 68-th simulation finished, 3.131163 sec.
# 69-th simulation finished, 3.087751 sec.
# 70-th simulation finished, 2.869660 sec.
# 71-th simulation finished, 2.788609 sec.
# 72-th simulation finished, 2.793439 sec.
# 73-th simulation finished, 3.526518 sec.
# 74-th simulation finished, 2.928596 sec.
# 75-th simulation finished, 2.877789 sec.
# 76-th simulation finished, 2.782594 sec.
# 77-th simulation finished, 2.611410 sec.
# 78-th simulation finished, 2.894148 sec.
# 79-th simulation finished, 2.799352 sec.
# 80-th simulation finished, 2.896239 sec.
# 81-th simulation finished, 3.331154 sec.
# 82-th simulation finished, 3.054957 sec.
# 83-th simulation finished, 2.811876 sec.
# 84-th simulation finished, 3.124402 sec.
# 85-th simulation finished, 2.765734 sec.
# 86-th simulation finished, 2.619517 sec.
# 87-th simulation finished, 2.879465 sec.
# 88-th simulation finished, 2.932596 sec.
# 89-th simulation finished, 2.947242 sec.
# 90-th simulation finished, 2.884461 sec.
# 91-th simulation finished, 2.979818 sec.
# 92-th simulation finished, 2.911308 sec.
# 93-th simulation finished, 2.849647 sec.
# 94-th simulation finished, 2.933534 sec.
# 95-th simulation finished, 2.696154 sec.
# 96-th simulation finished, 3.026343 sec.
# 97-th simulation finished, 2.863735 sec.
# 98-th simulation finished, 2.970843 sec.
# 99-th simulation finished, 2.717922 sec.
# 100-th simulation finished, 2.830724 sec.
# 101-th simulation finished, 2.701630 sec.
# 102-th simulation finished, 2.964096 sec.
# 103-th simulation finished, 2.917901 sec.
# 104-th simulation finished, 3.101145 sec.
# 105-th simulation finished, 3.365129 sec.
# 106-th simulation finished, 2.638989 sec.
# 107-th simulation finished, 2.899988 sec.
# 108-th simulation finished, 3.294169 sec.
# 109-th simulation finished, 3.040722 sec.
# 110-th simulation finished, 3.121657 sec.
# 111-th simulation finished, 2.714876 sec.
# 112-th simulation finished, 3.307279 sec.
# 113-th simulation finished, 2.866023 sec.
# 114-th simulation finished, 2.853688 sec.
# 115-th simulation finished, 2.708565 sec.
# 116-th simulation finished, 2.860957 sec.
# 117-th simulation finished, 2.816184 sec.
# 118-th simulation finished, 2.939906 sec.
# 119-th simulation finished, 3.106923 sec.
# 120-th simulation finished, 2.722154 sec.
# 121-th simulation finished, 3.319972 sec.
# 122-th simulation finished, 2.603849 sec.
# 123-th simulation finished, 2.854314 sec.
# 124-th simulation finished, 2.879032 sec.
# 125-th simulation finished, 2.800411 sec.
# 126-th simulation finished, 3.464754 sec.
# 127-th simulation finished, 3.226912 sec.
# 128-th simulation finished, 2.895901 sec.
# 129-th simulation finished, 2.924875 sec.
# 130-th simulation finished, 3.019733 sec.
# 131-th simulation finished, 3.181933 sec.
# 132-th simulation finished, 2.881184 sec.
# 133-th simulation finished, 2.986654 sec.
# 134-th simulation finished, 2.762950 sec.
# 135-th simulation finished, 2.630467 sec.
# 136-th simulation finished, 2.801500 sec.
# 137-th simulation finished, 2.963327 sec.
# 138-th simulation finished, 2.876707 sec.
# 139-th simulation finished, 2.860924 sec.
# 140-th simulation finished, 3.643602 sec.
# 141-th simulation finished, 3.305652 sec.
# 142-th simulation finished, 2.904285 sec.
# 143-th simulation finished, 3.003917 sec.
# 144-th simulation finished, 3.400818 sec.
# 145-th simulation finished, 3.031503 sec.
# 146-th simulation finished, 3.044542 sec.
# 147-th simulation finished, 3.111961 sec.
# 148-th simulation finished, 2.860113 sec.
# 149-th simulation finished, 2.484086 sec.
# 150-th simulation finished, 2.874472 sec.
# 151-th simulation finished, 3.247542 sec.
# 152-th simulation finished, 2.954353 sec.
# 153-th simulation finished, 2.786732 sec.
# 154-th simulation finished, 3.249056 sec.
# 155-th simulation finished, 2.924530 sec.
# 156-th simulation finished, 2.874776 sec.
# 157-th simulation finished, 3.284744 sec.
# 158-th simulation finished, 2.956203 sec.
# 159-th simulation finished, 3.506445 sec.
# 160-th simulation finished, 3.220696 sec.
# 161-th simulation finished, 3.222373 sec.
# 162-th simulation finished, 2.814111 sec.
# 163-th simulation finished, 3.184156 sec.
# 164-th simulation finished, 3.245227 sec.
# 165-th simulation finished, 2.910494 sec.
# 166-th simulation finished, 2.783857 sec.
# 167-th simulation finished, 2.926650 sec.
# 168-th simulation finished, 3.108495 sec.
# 169-th simulation finished, 3.071970 sec.
# 170-th simulation finished, 2.834659 sec.
# 171-th simulation finished, 2.744385 sec.
# 172-th simulation finished, 3.192774 sec.
# 173-th simulation finished, 2.721932 sec.
# 174-th simulation finished, 2.943040 sec.
# 175-th simulation finished, 2.782143 sec.
# 176-th simulation finished, 3.035349 sec.
# 177-th simulation finished, 2.829007 sec.
# 178-th simulation finished, 2.937550 sec.
# 179-th simulation finished, 2.913037 sec.
# 180-th simulation finished, 2.663125 sec.
# 181-th simulation finished, 2.898553 sec.
# 182-th simulation finished, 2.939343 sec.
# 183-th simulation finished, 2.936721 sec.
# 184-th simulation finished, 2.896493 sec.
# 185-th simulation finished, 2.985537 sec.
# 186-th simulation finished, 2.943716 sec.
# 187-th simulation finished, 2.959480 sec.
# 188-th simulation finished, 2.923166 sec.
# 189-th simulation finished, 2.636125 sec.
# 190-th simulation finished, 2.942491 sec.
# 191-th simulation finished, 3.003884 sec.
# 192-th simulation finished, 3.079516 sec.
# 193-th simulation finished, 3.357744 sec.
# 194-th simulation finished, 3.142573 sec.
# 195-th simulation finished, 3.045542 sec.
# 196-th simulation finished, 3.011369 sec.
# 197-th simulation finished, 2.931683 sec.
# 198-th simulation finished, 2.954954 sec.
# 199-th simulation finished, 2.987921 sec.
# 200-th simulation finished, 2.935912 sec.
# 201-th simulation finished, 3.024798 sec.
# 202-th simulation finished, 3.250324 sec.
# 203-th simulation finished, 2.877659 sec.
# 204-th simulation finished, 3.009273 sec.
# 205-th simulation finished, 3.505360 sec.
# 206-th simulation finished, 2.827518 sec.
# 207-th simulation finished, 3.192582 sec.
# 208-th simulation finished, 2.907376 sec.
# 209-th simulation finished, 3.105926 sec.
# 210-th simulation finished, 3.065708 sec.
# 211-th simulation finished, 3.013241 sec.
# 212-th simulation finished, 2.941910 sec.
# 213-th simulation finished, 3.145863 sec.
# 214-th simulation finished, 2.867645 sec.
# 215-th simulation finished, 3.046069 sec.
# 216-th simulation finished, 2.987011 sec.
# 217-th simulation finished, 3.481377 sec.
# 218-th simulation finished, 2.936998 sec.
# 219-th simulation finished, 2.874820 sec.
# 220-th simulation finished, 2.869923 sec.
# 221-th simulation finished, 2.874075 sec.
# 222-th simulation finished, 2.961673 sec.
# 223-th simulation finished, 3.305929 sec.
# 224-th simulation finished, 2.872049 sec.
# 225-th simulation finished, 3.077858 sec.
# 226-th simulation finished, 3.023575 sec.
# 227-th simulation finished, 2.973542 sec.
# 228-th simulation finished, 2.947652 sec.
# 229-th simulation finished, 2.893952 sec.
# 230-th simulation finished, 2.943954 sec.
# 231-th simulation finished, 3.123357 sec.
# 232-th simulation finished, 2.975456 sec.
# 233-th simulation finished, 3.175132 sec.
# 234-th simulation finished, 3.003617 sec.
# 235-th simulation finished, 3.053385 sec.
# 236-th simulation finished, 3.001363 sec.
# 237-th simulation finished, 3.174487 sec.
# 238-th simulation finished, 3.079857 sec.
# 239-th simulation finished, 3.606861 sec.
# 240-th simulation finished, 3.116421 sec.
# 241-th simulation finished, 3.189454 sec.
# 242-th simulation finished, 3.058605 sec.
# 243-th simulation finished, 3.429261 sec.
# 244-th simulation finished, 3.136019 sec.
# 245-th simulation finished, 3.065771 sec.
# 246-th simulation finished, 3.043212 sec.
# 247-th simulation finished, 3.180400 sec.
# 248-th simulation finished, 3.307876 sec.
# 249-th simulation finished, 3.305133 sec.
# 250-th simulation finished, 2.966478 sec.
# 251-th simulation finished, 3.533699 sec.
# 252-th simulation finished, 3.196953 sec.
# 253-th simulation finished, 3.067267 sec.
# 254-th simulation finished, 2.966155 sec.
# 255-th simulation finished, 3.259273 sec.
# 256-th simulation finished, 3.403576 sec.
# 257-th simulation finished, 2.916296 sec.
# 258-th simulation finished, 2.914939 sec.
# 259-th simulation finished, 2.930814 sec.
# 260-th simulation finished, 3.129743 sec.
# 261-th simulation finished, 3.215977 sec.
# 262-th simulation finished, 3.068622 sec.
# 263-th simulation finished, 2.993434 sec.
# 264-th simulation finished, 3.570295 sec.
# 265-th simulation finished, 2.936680 sec.
# 266-th simulation finished, 2.788944 sec.
# 267-th simulation finished, 2.892636 sec.
# 268-th simulation finished, 3.065583 sec.
# 269-th simulation finished, 3.005545 sec.
# 270-th simulation finished, 3.331488 sec.
# 271-th simulation finished, 3.087353 sec.
# 272-th simulation finished, 2.988023 sec.
# 273-th simulation finished, 3.105241 sec.
# 274-th simulation finished, 3.669421 sec.
# 275-th simulation finished, 3.376056 sec.
# 276-th simulation finished, 2.934926 sec.
# 277-th simulation finished, 2.892468 sec.
# 278-th simulation finished, 3.063187 sec.
# 279-th simulation finished, 2.915963 sec.
# 280-th simulation finished, 3.029605 sec.
# 281-th simulation finished, 3.212689 sec.
# 282-th simulation finished, 3.114825 sec.
# 283-th simulation finished, 2.761547 sec.
# 284-th simulation finished, 2.886186 sec.
# 285-th simulation finished, 3.394457 sec.
# 286-th simulation finished, 3.087445 sec.
# 287-th simulation finished, 3.014381 sec.
# 288-th simulation finished, 3.027610 sec.
# 289-th simulation finished, 2.886229 sec.
# 290-th simulation finished, 2.930719 sec.
# 291-th simulation finished, 2.991642 sec.
# 292-th simulation finished, 2.842131 sec.
# 293-th simulation finished, 2.979394 sec.
# 294-th simulation finished, 2.999221 sec.
# 295-th simulation finished, 3.084150 sec.
# 296-th simulation finished, 3.132719 sec.
# 297-th simulation finished, 2.992544 sec.
# 298-th simulation finished, 3.190889 sec.
# 299-th simulation finished, 2.754999 sec.
# 300-th simulation finished, 2.919945 sec.
# 301-th simulation finished, 3.545445 sec.
# 302-th simulation finished, 2.900627 sec.
# 303-th simulation finished, 3.061785 sec.
# 304-th simulation finished, 2.962335 sec.
# 305-th simulation finished, 3.063762 sec.
# 306-th simulation finished, 2.972024 sec.
# 307-th simulation finished, 3.027958 sec.
# 308-th simulation finished, 2.940520 sec.
# 309-th simulation finished, 2.882513 sec.
# 310-th simulation finished, 3.231253 sec.
# 311-th simulation finished, 3.183644 sec.
# 312-th simulation finished, 3.046449 sec.
# 313-th simulation finished, 3.319906 sec.
# 314-th simulation finished, 2.792659 sec.
# 315-th simulation finished, 2.882074 sec.
# 316-th simulation finished, 2.974769 sec.
# 317-th simulation finished, 3.225163 sec.
# 318-th simulation finished, 3.376796 sec.
# 319-th simulation finished, 3.032962 sec.
# 320-th simulation finished, 3.002696 sec.
# 321-th simulation finished, 3.140500 sec.
# 322-th simulation finished, 3.130315 sec.
# 323-th simulation finished, 2.865576 sec.
# 324-th simulation finished, 2.922125 sec.
# 325-th simulation finished, 2.749894 sec.
# 326-th simulation finished, 3.202182 sec.
# 327-th simulation finished, 3.177807 sec.
# 328-th simulation finished, 3.029176 sec.
# 329-th simulation finished, 2.662654 sec.
# 330-th simulation finished, 3.236268 sec.
# 331-th simulation finished, 2.868979 sec.
# 332-th simulation finished, 2.886796 sec.
# 333-th simulation finished, 3.114742 sec.
# 334-th simulation finished, 3.201407 sec.
# 335-th simulation finished, 3.034818 sec.
# 336-th simulation finished, 3.056529 sec.
# 337-th simulation finished, 2.981115 sec.
# 338-th simulation finished, 3.318952 sec.
# 339-th simulation finished, 3.473704 sec.
# 340-th simulation finished, 2.842398 sec.
# 341-th simulation finished, 3.242489 sec.
# 342-th simulation finished, 2.936734 sec.
# 343-th simulation finished, 2.903100 sec.
# 344-th simulation finished, 3.017246 sec.
# 345-th simulation finished, 3.005502 sec.
# 346-th simulation finished, 2.799557 sec.
# 347-th simulation finished, 3.066969 sec.
# 348-th simulation finished, 3.116885 sec.
# 349-th simulation finished, 2.887617 sec.
# 350-th simulation finished, 2.851870 sec.
# 351-th simulation finished, 3.211590 sec.
# 352-th simulation finished, 2.746106 sec.
# 353-th simulation finished, 2.793416 sec.
# 354-th simulation finished, 3.114575 sec.
# 355-th simulation finished, 2.977971 sec.
# 356-th simulation finished, 3.630626 sec.
# 357-th simulation finished, 3.079022 sec.
# 358-th simulation finished, 2.955911 sec.
# 359-th simulation finished, 2.983448 sec.
# 360-th simulation finished, 2.990293 sec.
# 361-th simulation finished, 3.133774 sec.
# 362-th simulation finished, 2.876839 sec.
# 363-th simulation finished, 2.978874 sec.
# 364-th simulation finished, 3.173870 sec.
# 365-th simulation finished, 2.954645 sec.
# 366-th simulation finished, 3.243093 sec.
# 367-th simulation finished, 2.712451 sec.
# 368-th simulation finished, 3.209393 sec.
# 369-th simulation finished, 2.889548 sec.
# 370-th simulation finished, 3.191033 sec.
# 371-th simulation finished, 2.979982 sec.
# 372-th simulation finished, 2.997252 sec.
# 373-th simulation finished, 2.968855 sec.
# 374-th simulation finished, 2.944132 sec.
# 375-th simulation finished, 3.039909 sec.
# 376-th simulation finished, 3.215242 sec.
# 377-th simulation finished, 2.961783 sec.
# 378-th simulation finished, 3.383024 sec.
# 379-th simulation finished, 2.947709 sec.
# 380-th simulation finished, 2.999608 sec.
# 381-th simulation finished, 3.356236 sec.
# 382-th simulation finished, 3.334503 sec.
# 383-th simulation finished, 2.959793 sec.
# 384-th simulation finished, 2.786673 sec.
# 385-th simulation finished, 2.935072 sec.
# 386-th simulation finished, 2.872855 sec.
# 387-th simulation finished, 2.942793 sec.
# 388-th simulation finished, 2.987001 sec.
# 389-th simulation finished, 2.972077 sec.
# 390-th simulation finished, 3.371503 sec.
# 391-th simulation finished, 2.906402 sec.
# 392-th simulation finished, 3.088296 sec.
# 393-th simulation finished, 2.866863 sec.
# 394-th simulation finished, 3.019609 sec.
# 395-th simulation finished, 3.303217 sec.
# 396-th simulation finished, 2.972505 sec.
# 397-th simulation finished, 3.288072 sec.
# 398-th simulation finished, 3.478889 sec.
# 399-th simulation finished, 2.973774 sec.
# 400-th simulation finished, 2.889683 sec.
# 401-th simulation finished, 2.892909 sec.
# 402-th simulation finished, 3.055364 sec.
# 403-th simulation finished, 3.113960 sec.
# 404-th simulation finished, 3.341144 sec.
# 405-th simulation finished, 2.944773 sec.
# 406-th simulation finished, 2.979842 sec.
# 407-th simulation finished, 3.149952 sec.
# 408-th simulation finished, 2.731983 sec.
# 409-th simulation finished, 3.139361 sec.
# 410-th simulation finished, 2.974292 sec.
# 411-th simulation finished, 3.676677 sec.
# 412-th simulation finished, 3.062418 sec.
# 413-th simulation finished, 3.132031 sec.
# 414-th simulation finished, 3.031736 sec.
# 415-th simulation finished, 2.832138 sec.
# 416-th simulation finished, 2.956395 sec.
# 417-th simulation finished, 3.088439 sec.
# 418-th simulation finished, 3.131772 sec.
# 419-th simulation finished, 2.880839 sec.
# 420-th simulation finished, 3.035897 sec.
# 421-th simulation finished, 3.232955 sec.
# 422-th simulation finished, 3.540964 sec.
# 423-th simulation finished, 3.179289 sec.
# 424-th simulation finished, 3.075397 sec.
# 425-th simulation finished, 2.917973 sec.
# 426-th simulation finished, 2.893575 sec.
# 427-th simulation finished, 2.939358 sec.
# 428-th simulation finished, 3.086960 sec.
# 429-th simulation finished, 2.852183 sec.
# 430-th simulation finished, 2.913936 sec.
# 431-th simulation finished, 3.058334 sec.
# 432-th simulation finished, 2.878718 sec.
# 433-th simulation finished, 3.396250 sec.
# 434-th simulation finished, 3.317184 sec.
# 435-th simulation finished, 2.952371 sec.
# 436-th simulation finished, 2.757890 sec.
# 437-th simulation finished, 2.651008 sec.
# 438-th simulation finished, 2.977185 sec.
# 439-th simulation finished, 3.019740 sec.
# 440-th simulation finished, 2.946904 sec.
# 441-th simulation finished, 2.861185 sec.
# 442-th simulation finished, 2.816229 sec.
# 443-th simulation finished, 3.132244 sec.
# 444-th simulation finished, 2.923275 sec.
# 445-th simulation finished, 3.123281 sec.
# 446-th simulation finished, 3.450847 sec.
# 447-th simulation finished, 3.042092 sec.
# 448-th simulation finished, 3.108024 sec.
# 449-th simulation finished, 3.170874 sec.
# 450-th simulation finished, 3.192769 sec.
# 451-th simulation finished, 3.101451 sec.
# 452-th simulation finished, 3.014919 sec.
# 453-th simulation finished, 3.441504 sec.
# 454-th simulation finished, 3.058333 sec.
# 455-th simulation finished, 2.936532 sec.
# 456-th simulation finished, 3.171014 sec.
# 457-th simulation finished, 3.022925 sec.
# 458-th simulation finished, 2.920044 sec.
# 459-th simulation finished, 2.678561 sec.
# 460-th simulation finished, 2.838927 sec.
# 461-th simulation finished, 2.976301 sec.
# 462-th simulation finished, 3.011506 sec.
# 463-th simulation finished, 3.028092 sec.
# 464-th simulation finished, 3.446552 sec.
# 465-th simulation finished, 2.875116 sec.
# 466-th simulation finished, 3.130771 sec.
# 467-th simulation finished, 3.369300 sec.
# 468-th simulation finished, 3.014660 sec.
# 469-th simulation finished, 3.026050 sec.
# 470-th simulation finished, 2.917811 sec.
# 471-th simulation finished, 3.131485 sec.
# 472-th simulation finished, 3.196435 sec.
# 473-th simulation finished, 2.810606 sec.
# 474-th simulation finished, 3.038165 sec.
# 475-th simulation finished, 3.035044 sec.
# 476-th simulation finished, 2.981954 sec.
# 477-th simulation finished, 2.972482 sec.
# 478-th simulation finished, 3.097007 sec.
# 479-th simulation finished, 2.905881 sec.
# 480-th simulation finished, 3.095025 sec.
# 481-th simulation finished, 2.870689 sec.
# 482-th simulation finished, 2.728315 sec.
# 483-th simulation finished, 2.896753 sec.
# 484-th simulation finished, 2.975375 sec.
# 485-th simulation finished, 3.203706 sec.
# 486-th simulation finished, 3.214246 sec.
# 487-th simulation finished, 3.325012 sec.
# 488-th simulation finished, 2.986452 sec.
# 489-th simulation finished, 3.176436 sec.
# 490-th simulation finished, 3.285392 sec.
# 491-th simulation finished, 3.062059 sec.
# 492-th simulation finished, 3.039251 sec.
# 493-th simulation finished, 3.591594 sec.
# 494-th simulation finished, 3.154191 sec.
# 495-th simulation finished, 4.132056 sec.
# 496-th simulation finished, 3.774118 sec.
# 497-th simulation finished, 3.362595 sec.
# 498-th simulation finished, 3.042127 sec.
# 499-th simulation finished, 3.012616 sec.
# 500-th simulation finished, 3.117982 sec.
# 501-th simulation finished, 3.769259 sec.
# 502-th simulation finished, 3.302965 sec.
# 503-th simulation finished, 2.935027 sec.
# 504-th simulation finished, 3.203298 sec.
# 505-th simulation finished, 3.099895 sec.
# 506-th simulation finished, 3.801832 sec.
# 507-th simulation finished, 3.616935 sec.
# 508-th simulation finished, 3.253086 sec.
# 509-th simulation finished, 3.267281 sec.
# 510-th simulation finished, 3.612379 sec.
# 511-th simulation finished, 3.411941 sec.
# 512-th simulation finished, 3.049008 sec.
# 513-th simulation finished, 4.615847 sec.
# 514-th simulation finished, 3.511056 sec.
# 515-th simulation finished, 3.286339 sec.
# 516-th simulation finished, 3.057529 sec.
# 517-th simulation finished, 3.114100 sec.
# 518-th simulation finished, 3.362253 sec.
# 519-th simulation finished, 3.260237 sec.
# 520-th simulation finished, 3.239851 sec.
# 521-th simulation finished, 3.153423 sec.
# 522-th simulation finished, 3.114279 sec.
# 523-th simulation finished, 3.488872 sec.
# 524-th simulation finished, 3.314314 sec.
# 525-th simulation finished, 3.787969 sec.
# 526-th simulation finished, 3.205429 sec.
# 527-th simulation finished, 3.930139 sec.
# 528-th simulation finished, 3.618465 sec.
# 529-th simulation finished, 3.813134 sec.
# 530-th simulation finished, 3.651143 sec.
# 531-th simulation finished, 3.195726 sec.
# 532-th simulation finished, 3.578907 sec.
# 533-th simulation finished, 3.302079 sec.
# 534-th simulation finished, 3.594424 sec.
# 535-th simulation finished, 3.330386 sec.
# 536-th simulation finished, 3.028462 sec.
# 537-th simulation finished, 3.536180 sec.
# 538-th simulation finished, 3.212675 sec.
# 539-th simulation finished, 3.480952 sec.
# 540-th simulation finished, 3.473494 sec.
# 541-th simulation finished, 3.281766 sec.
# 542-th simulation finished, 3.607626 sec.
# 543-th simulation finished, 3.671796 sec.
# 544-th simulation finished, 3.823767 sec.
# 545-th simulation finished, 4.580207 sec.
# 546-th simulation finished, 3.578256 sec.
# 547-th simulation finished, 3.179327 sec.
# 548-th simulation finished, 3.468675 sec.
# 549-th simulation finished, 3.813670 sec.
# 550-th simulation finished, 3.574653 sec.
# 551-th simulation finished, 3.779254 sec.
# 552-th simulation finished, 3.306039 sec.
# 553-th simulation finished, 3.355153 sec.
# 554-th simulation finished, 3.494709 sec.
# 555-th simulation finished, 3.613902 sec.
# 556-th simulation finished, 3.419346 sec.
# 557-th simulation finished, 3.320934 sec.
# 558-th simulation finished, 3.555681 sec.
# 559-th simulation finished, 3.410027 sec.
# 560-th simulation finished, 3.914734 sec.
# 561-th simulation finished, 3.159180 sec.
# 562-th simulation finished, 3.233259 sec.
# 563-th simulation finished, 3.335203 sec.
# 564-th simulation finished, 3.382434 sec.
# 565-th simulation finished, 3.496531 sec.
# 566-th simulation finished, 3.584337 sec.
# 567-th simulation finished, 3.562278 sec.
# 568-th simulation finished, 3.193333 sec.
# 569-th simulation finished, 3.188845 sec.
# 570-th simulation finished, 3.228793 sec.
# 571-th simulation finished, 3.319317 sec.
# 572-th simulation finished, 3.207463 sec.
# 573-th simulation finished, 3.191142 sec.
# 574-th simulation finished, 3.625102 sec.
# 575-th simulation finished, 3.217457 sec.
# 576-th simulation finished, 3.407560 sec.
# 577-th simulation finished, 3.276148 sec.
# 578-th simulation finished, 3.232284 sec.
# 579-th simulation finished, 3.268054 sec.
# 580-th simulation finished, 3.397250 sec.
# 581-th simulation finished, 3.248224 sec.
# 582-th simulation finished, 3.283870 sec.
# 583-th simulation finished, 3.061179 sec.
# 584-th simulation finished, 3.108463 sec.
# 585-th simulation finished, 3.247305 sec.
# 586-th simulation finished, 3.123831 sec.
# 587-th simulation finished, 3.259510 sec.
# 588-th simulation finished, 3.546813 sec.
# 589-th simulation finished, 3.850803 sec.
# 590-th simulation finished, 3.487791 sec.
# 591-th simulation finished, 3.369453 sec.
# 592-th simulation finished, 3.175472 sec.
# 593-th simulation finished, 3.563528 sec.
# 594-th simulation finished, 3.207292 sec.
# 595-th simulation finished, 3.528690 sec.
# 596-th simulation finished, 3.637048 sec.
# 597-th simulation finished, 3.133298 sec.
# 598-th simulation finished, 3.040947 sec.
# 599-th simulation finished, 3.769283 sec.
# 600-th simulation finished, 3.468598 sec.
# 601-th simulation finished, 3.510311 sec.
# 602-th simulation finished, 2.930169 sec.
# 603-th simulation finished, 2.896913 sec.
# 604-th simulation finished, 3.466551 sec.
# 605-th simulation finished, 3.617317 sec.
# 606-th simulation finished, 3.515377 sec.
# 607-th simulation finished, 3.151084 sec.
# 608-th simulation finished, 3.272413 sec.
# 609-th simulation finished, 3.605180 sec.
# 610-th simulation finished, 2.880883 sec.
# 611-th simulation finished, 3.208891 sec.
# 612-th simulation finished, 3.214295 sec.
# 613-th simulation finished, 3.637500 sec.
# 614-th simulation finished, 3.462153 sec.
# 615-th simulation finished, 3.465916 sec.
# 616-th simulation finished, 3.170522 sec.
# 617-th simulation finished, 3.175531 sec.
# 618-th simulation finished, 3.619908 sec.
# 619-th simulation finished, 3.211769 sec.
# 620-th simulation finished, 3.355578 sec.
# 621-th simulation finished, 3.337248 sec.
# 622-th simulation finished, 3.374581 sec.
# 623-th simulation finished, 3.080847 sec.
# 624-th simulation finished, 3.128802 sec.
# 625-th simulation finished, 3.247591 sec.
# 626-th simulation finished, 3.145385 sec.
# 627-th simulation finished, 3.426033 sec.
# 628-th simulation finished, 3.864151 sec.
# 629-th simulation finished, 3.439567 sec.
# 630-th simulation finished, 3.929192 sec.
# 631-th simulation finished, 4.148484 sec.
# 632-th simulation finished, 3.552885 sec.
# 633-th simulation finished, 3.685028 sec.
# 634-th simulation finished, 3.938877 sec.
# 635-th simulation finished, 3.620635 sec.
# 636-th simulation finished, 3.683705 sec.
# 637-th simulation finished, 4.088287 sec.
# 638-th simulation finished, 4.457012 sec.
# 639-th simulation finished, 4.190133 sec.
# 640-th simulation finished, 3.745291 sec.
# 641-th simulation finished, 3.851047 sec.
# 642-th simulation finished, 4.150620 sec.
# 643-th simulation finished, 4.082477 sec.
# 644-th simulation finished, 4.267016 sec.
# 645-th simulation finished, 4.219207 sec.
# 646-th simulation finished, 4.255049 sec.
# 647-th simulation finished, 4.241298 sec.
# 648-th simulation finished, 4.203948 sec.
# 649-th simulation finished, 4.166444 sec.
# 650-th simulation finished, 4.348474 sec.
# 651-th simulation finished, 4.303028 sec.
# 652-th simulation finished, 4.732943 sec.
# 653-th simulation finished, 4.118864 sec.
# 654-th simulation finished, 4.232053 sec.
# 655-th simulation finished, 4.135483 sec.
# 656-th simulation finished, 4.238591 sec.
# 657-th simulation finished, 4.582939 sec.
# 658-th simulation finished, 4.794269 sec.
# 659-th simulation finished, 4.167206 sec.
# 660-th simulation finished, 4.538359 sec.
# 661-th simulation finished, 4.298859 sec.
# 662-th simulation finished, 3.834496 sec.
# 663-th simulation finished, 4.014200 sec.
# 664-th simulation finished, 3.945569 sec.
# 665-th simulation finished, 4.224146 sec.
# 666-th simulation finished, 4.133012 sec.
# 667-th simulation finished, 4.076325 sec.
# 668-th simulation finished, 4.089986 sec.
# 669-th simulation finished, 4.577328 sec.
# 670-th simulation finished, 4.539927 sec.
# 671-th simulation finished, 4.253543 sec.
# 672-th simulation finished, 4.223757 sec.
# 673-th simulation finished, 4.129329 sec.
# 674-th simulation finished, 4.648615 sec.
# 675-th simulation finished, 4.194063 sec.
# 676-th simulation finished, 4.612326 sec.
# 677-th simulation finished, 4.270805 sec.
# 678-th simulation finished, 4.325211 sec.
# 679-th simulation finished, 4.262550 sec.
# 680-th simulation finished, 4.140533 sec.
# 681-th simulation finished, 4.024226 sec.
# 682-th simulation finished, 4.237499 sec.
# 683-th simulation finished, 4.008643 sec.
# 684-th simulation finished, 3.969314 sec.
# 685-th simulation finished, 4.285776 sec.
# 686-th simulation finished, 4.203148 sec.
# 687-th simulation finished, 3.945186 sec.
# 688-th simulation finished, 3.980433 sec.
# 689-th simulation finished, 4.069991 sec.
# 690-th simulation finished, 5.226354 sec.
# 691-th simulation finished, 5.317147 sec.
# 692-th simulation finished, 4.742322 sec.
# 693-th simulation finished, 4.234023 sec.
# 694-th simulation finished, 4.455181 sec.
# 695-th simulation finished, 4.691666 sec.
# 696-th simulation finished, 5.135097 sec.
# 697-th simulation finished, 4.852340 sec.
# 698-th simulation finished, 5.843988 sec.
# 699-th simulation finished, 4.862121 sec.
# 700-th simulation finished, 4.928026 sec.
# 701-th simulation finished, 4.079879 sec.
# 702-th simulation finished, 4.316037 sec.
# 703-th simulation finished, 4.572713 sec.
# 704-th simulation finished, 4.353761 sec.
# 705-th simulation finished, 4.234327 sec.
# 706-th simulation finished, 4.595497 sec.
# 707-th simulation finished, 3.784769 sec.
# 708-th simulation finished, 4.482683 sec.
# 709-th simulation finished, 4.141812 sec.
# 710-th simulation finished, 4.243757 sec.
# 711-th simulation finished, 4.579579 sec.
# 712-th simulation finished, 4.426446 sec.
# 713-th simulation finished, 4.273877 sec.
# 714-th simulation finished, 4.128118 sec.
# 715-th simulation finished, 4.579139 sec.
# 716-th simulation finished, 4.112599 sec.
# 717-th simulation finished, 4.239984 sec.
# 718-th simulation finished, 4.513767 sec.
# 719-th simulation finished, 4.741436 sec.
# 720-th simulation finished, 4.247448 sec.
# 721-th simulation finished, 4.167038 sec.
# 722-th simulation finished, 4.418556 sec.
# 723-th simulation finished, 4.409511 sec.
# 724-th simulation finished, 4.043390 sec.
# 725-th simulation finished, 4.249197 sec.
# 726-th simulation finished, 4.250915 sec.
# 727-th simulation finished, 4.614260 sec.
# 728-th simulation finished, 4.007301 sec.
# 729-th simulation finished, 4.476139 sec.
# 730-th simulation finished, 3.974515 sec.
# 731-th simulation finished, 4.313193 sec.
# 732-th simulation finished, 4.138512 sec.
# 733-th simulation finished, 4.176178 sec.
# 734-th simulation finished, 4.844187 sec.
# 735-th simulation finished, 4.676310 sec.
# 736-th simulation finished, 4.591038 sec.
# 737-th simulation finished, 4.246544 sec.
# 738-th simulation finished, 4.032580 sec.
# 739-th simulation finished, 4.846996 sec.
# 740-th simulation finished, 4.042892 sec.
# 741-th simulation finished, 4.300064 sec.
# 742-th simulation finished, 4.374804 sec.
# 743-th simulation finished, 4.408218 sec.
# 744-th simulation finished, 4.270119 sec.
# 745-th simulation finished, 4.208420 sec.
# 746-th simulation finished, 4.654444 sec.
# 747-th simulation finished, 5.264278 sec.
# 748-th simulation finished, 3.987925 sec.
# 749-th simulation finished, 4.255449 sec.
# 750-th simulation finished, 4.168546 sec.
# 751-th simulation finished, 4.246592 sec.
# 752-th simulation finished, 4.253529 sec.
# 753-th simulation finished, 4.313077 sec.
# 754-th simulation finished, 4.181358 sec.
# 755-th simulation finished, 4.868322 sec.
# 756-th simulation finished, 4.276562 sec.
# 757-th simulation finished, 4.948255 sec.
# 758-th simulation finished, 4.140516 sec.
# 759-th simulation finished, 4.125545 sec.
# 760-th simulation finished, 4.180971 sec.
# 761-th simulation finished, 4.144873 sec.
# 762-th simulation finished, 4.363575 sec.
# 763-th simulation finished, 3.923565 sec.
# 764-th simulation finished, 3.787917 sec.
# 765-th simulation finished, 4.406546 sec.
# 766-th simulation finished, 4.238973 sec.
# 767-th simulation finished, 4.298544 sec.
# 768-th simulation finished, 3.973527 sec.
# 769-th simulation finished, 4.530520 sec.
# 770-th simulation finished, 4.475219 sec.
# 771-th simulation finished, 4.077181 sec.
# 772-th simulation finished, 4.182760 sec.
# 773-th simulation finished, 4.425925 sec.
# 774-th simulation finished, 4.255558 sec.
# 775-th simulation finished, 4.302965 sec.
# 776-th simulation finished, 4.637355 sec.
# 777-th simulation finished, 4.137121 sec.
# 778-th simulation finished, 4.257480 sec.
# 779-th simulation finished, 4.420290 sec.
# 780-th simulation finished, 4.251988 sec.
# 781-th simulation finished, 4.372336 sec.
# 782-th simulation finished, 4.408981 sec.
# 783-th simulation finished, 4.261728 sec.
# 784-th simulation finished, 3.555928 sec.
# 785-th simulation finished, 4.867722 sec.
# 786-th simulation finished, 4.555193 sec.
# 787-th simulation finished, 4.130803 sec.
# 788-th simulation finished, 4.379550 sec.
# 789-th simulation finished, 4.224492 sec.
# 790-th simulation finished, 4.081295 sec.
# 791-th simulation finished, 4.590386 sec.
# 792-th simulation finished, 4.086669 sec.
# 793-th simulation finished, 4.490017 sec.
# 794-th simulation finished, 3.930248 sec.
# 795-th simulation finished, 4.701014 sec.
# 796-th simulation finished, 4.178729 sec.
# 797-th simulation finished, 4.024445 sec.
# 798-th simulation finished, 4.315189 sec.
# 799-th simulation finished, 3.924821 sec.
# 800-th simulation finished, 4.686584 sec.
# 801-th simulation finished, 4.139710 sec.
# 802-th simulation finished, 4.354275 sec.
# 803-th simulation finished, 4.051431 sec.
# 804-th simulation finished, 4.100304 sec.
# 805-th simulation finished, 4.239376 sec.
# 806-th simulation finished, 4.477124 sec.
# 807-th simulation finished, 4.148058 sec.
# 808-th simulation finished, 4.505907 sec.
# 809-th simulation finished, 4.426037 sec.
# 810-th simulation finished, 4.193443 sec.
# 811-th simulation finished, 4.329335 sec.
# 812-th simulation finished, 3.964785 sec.
# 813-th simulation finished, 4.331478 sec.
# 814-th simulation finished, 4.934315 sec.
# 815-th simulation finished, 4.117570 sec.
# 816-th simulation finished, 4.916461 sec.
# 817-th simulation finished, 4.112249 sec.
# 818-th simulation finished, 4.245066 sec.
# 819-th simulation finished, 4.139415 sec.
# 820-th simulation finished, 3.832589 sec.
# 821-th simulation finished, 4.857524 sec.
# 822-th simulation finished, 4.262029 sec.
# 823-th simulation finished, 4.332418 sec.
# 824-th simulation finished, 4.293152 sec.
# 825-th simulation finished, 3.873483 sec.
# 826-th simulation finished, 4.343019 sec.
# 827-th simulation finished, 4.138816 sec.
# 828-th simulation finished, 4.399060 sec.
# 829-th simulation finished, 4.158850 sec.
# 830-th simulation finished, 4.406902 sec.
# 831-th simulation finished, 3.988528 sec.
# 832-th simulation finished, 4.121741 sec.
# 833-th simulation finished, 4.160467 sec.
# 834-th simulation finished, 4.278084 sec.
# 835-th simulation finished, 4.445008 sec.
# 836-th simulation finished, 4.008148 sec.
# 837-th simulation finished, 4.663194 sec.
# 838-th simulation finished, 4.736584 sec.
# 839-th simulation finished, 4.191097 sec.
# 840-th simulation finished, 3.933467 sec.
# 841-th simulation finished, 4.480275 sec.
# 842-th simulation finished, 4.420148 sec.
# 843-th simulation finished, 4.715320 sec.
# 844-th simulation finished, 5.049609 sec.
# 845-th simulation finished, 4.158224 sec.
# 846-th simulation finished, 4.625540 sec.
# 847-th simulation finished, 4.304026 sec.
# 848-th simulation finished, 4.005444 sec.
# 849-th simulation finished, 4.213757 sec.
# 850-th simulation finished, 4.383586 sec.
# 851-th simulation finished, 4.502189 sec.
# 852-th simulation finished, 3.916479 sec.
# 853-th simulation finished, 4.355255 sec.
# 854-th simulation finished, 4.361946 sec.
# 855-th simulation finished, 4.204362 sec.
# 856-th simulation finished, 4.354937 sec.
# 857-th simulation finished, 4.063399 sec.
# 858-th simulation finished, 4.300037 sec.
# 859-th simulation finished, 4.184745 sec.
# 860-th simulation finished, 3.969542 sec.
# 861-th simulation finished, 4.227148 sec.
# 862-th simulation finished, 4.728795 sec.
# 863-th simulation finished, 4.510577 sec.
# 864-th simulation finished, 3.828158 sec.
# 865-th simulation finished, 4.573908 sec.
# 866-th simulation finished, 4.202692 sec.
# 867-th simulation finished, 4.300564 sec.
# 868-th simulation finished, 4.016977 sec.
# 869-th simulation finished, 4.216104 sec.
# 870-th simulation finished, 4.274756 sec.
# 871-th simulation finished, 4.000795 sec.
# 872-th simulation finished, 4.695337 sec.
# 873-th simulation finished, 4.545117 sec.
# 874-th simulation finished, 4.287044 sec.
# 875-th simulation finished, 4.311381 sec.
# 876-th simulation finished, 4.173947 sec.
# 877-th simulation finished, 4.107816 sec.
# 878-th simulation finished, 3.987748 sec.
# 879-th simulation finished, 4.508584 sec.
# 880-th simulation finished, 4.141860 sec.
# 881-th simulation finished, 4.258266 sec.
# 882-th simulation finished, 4.814475 sec.
# 883-th simulation finished, 3.814316 sec.
# 884-th simulation finished, 3.952594 sec.
# 885-th simulation finished, 3.859391 sec.
# 886-th simulation finished, 3.727526 sec.
# 887-th simulation finished, 3.605831 sec.
# 888-th simulation finished, 3.808089 sec.
# 889-th simulation finished, 3.763338 sec.
# 890-th simulation finished, 4.194231 sec.
# 891-th simulation finished, 4.184415 sec.
# 892-th simulation finished, 3.869290 sec.
# 893-th simulation finished, 3.756683 sec.
# 894-th simulation finished, 3.455954 sec.
# 895-th simulation finished, 3.460412 sec.
# 896-th simulation finished, 3.737566 sec.
# 897-th simulation finished, 3.372509 sec.
# 898-th simulation finished, 3.464968 sec.
# 899-th simulation finished, 3.422028 sec.
# 900-th simulation finished, 3.557113 sec.
# 901-th simulation finished, 3.644731 sec.
# 902-th simulation finished, 3.717600 sec.
# 903-th simulation finished, 4.192024 sec.
# 904-th simulation finished, 4.528037 sec.
# 905-th simulation finished, 3.533842 sec.
# 906-th simulation finished, 3.509264 sec.
# 907-th simulation finished, 3.252342 sec.
# 908-th simulation finished, 3.348393 sec.
# 909-th simulation finished, 3.462870 sec.
# 910-th simulation finished, 3.607057 sec.
# 911-th simulation finished, 3.858075 sec.
# 912-th simulation finished, 3.560855 sec.
# 913-th simulation finished, 4.522740 sec.
# 914-th simulation finished, 4.316471 sec.
# 915-th simulation finished, 4.110956 sec.
# 916-th simulation finished, 6.209707 sec.
# 917-th simulation finished, 5.948199 sec.
# 918-th simulation finished, 4.243339 sec.
# 919-th simulation finished, 3.749900 sec.
# 920-th simulation finished, 3.637384 sec.
# 921-th simulation finished, 3.710841 sec.
# 922-th simulation finished, 3.831336 sec.
# 923-th simulation finished, 3.650762 sec.
# 924-th simulation finished, 3.486192 sec.
# 925-th simulation finished, 3.424476 sec.
# 926-th simulation finished, 3.717862 sec.
# 927-th simulation finished, 4.153455 sec.
# 928-th simulation finished, 3.769852 sec.
# 929-th simulation finished, 4.230838 sec.
# 930-th simulation finished, 3.584111 sec.
# 931-th simulation finished, 3.721043 sec.
# 932-th simulation finished, 3.856653 sec.
# 933-th simulation finished, 3.791108 sec.
# 934-th simulation finished, 4.093193 sec.
# 935-th simulation finished, 3.395700 sec.
# 936-th simulation finished, 4.042421 sec.
# 937-th simulation finished, 3.528913 sec.
# 938-th simulation finished, 3.683253 sec.
# 939-th simulation finished, 4.016657 sec.
# 940-th simulation finished, 3.764266 sec.
# 941-th simulation finished, 3.502720 sec.
# 942-th simulation finished, 3.417472 sec.
# 943-th simulation finished, 3.449073 sec.
# 944-th simulation finished, 3.429798 sec.
# 945-th simulation finished, 3.933775 sec.
# 946-th simulation finished, 3.543905 sec.
# 947-th simulation finished, 3.663846 sec.
# 948-th simulation finished, 4.198637 sec.
# 949-th simulation finished, 3.742802 sec.
# 950-th simulation finished, 3.691984 sec.
# 951-th simulation finished, 4.066613 sec.
# 952-th simulation finished, 3.918468 sec.
# 953-th simulation finished, 3.546075 sec.
# 954-th simulation finished, 3.700648 sec.
# 955-th simulation finished, 3.322715 sec.
# 956-th simulation finished, 3.363254 sec.
# 957-th simulation finished, 4.400815 sec.
# 958-th simulation finished, 4.135892 sec.
# 959-th simulation finished, 4.264528 sec.
# 960-th simulation finished, 3.647036 sec.
# 961-th simulation finished, 3.546226 sec.
# 962-th simulation finished, 4.012475 sec.
# 963-th simulation finished, 4.224690 sec.
# 964-th simulation finished, 3.997348 sec.
# 965-th simulation finished, 3.528479 sec.
# 966-th simulation finished, 3.672603 sec.
# 967-th simulation finished, 3.638908 sec.
# 968-th simulation finished, 3.741464 sec.
# 969-th simulation finished, 3.552960 sec.
# 970-th simulation finished, 3.707208 sec.
# 971-th simulation finished, 3.655119 sec.
# 972-th simulation finished, 3.841566 sec.
# 973-th simulation finished, 3.645229 sec.
# 974-th simulation finished, 3.678349 sec.
# 975-th simulation finished, 3.599281 sec.
# 976-th simulation finished, 3.287634 sec.
# 977-th simulation finished, 3.643446 sec.
# 978-th simulation finished, 3.464570 sec.
# 979-th simulation finished, 3.872442 sec.
# 980-th simulation finished, 3.542791 sec.
# 981-th simulation finished, 3.425632 sec.
# 982-th simulation finished, 3.355253 sec.
# 983-th simulation finished, 3.771183 sec.
# 984-th simulation finished, 3.729500 sec.
# 985-th simulation finished, 3.446627 sec.
# 986-th simulation finished, 3.512087 sec.
# 987-th simulation finished, 4.065545 sec.
# 988-th simulation finished, 3.524010 sec.
# 989-th simulation finished, 3.508573 sec.
# 990-th simulation finished, 3.929646 sec.
# 991-th simulation finished, 3.585961 sec.
# 992-th simulation finished, 3.489581 sec.
# 993-th simulation finished, 3.276664 sec.
# 994-th simulation finished, 4.180275 sec.
# 995-th simulation finished, 3.682970 sec.
# 996-th simulation finished, 3.735424 sec.
# 997-th simulation finished, 3.417218 sec.
# 998-th simulation finished, 3.628772 sec.
# 999-th simulation finished, 4.122730 sec.
# 1000-th simulation finished, 3.807850 sec.

# %%
np.savez('coverage_freqepid_nbinom_randinf_2.npz',
         nsim = nsim, msim = msim, bsim = bsim)

# %% [markdown]
# # 4. Wald's Confidence Region Coverage Test

# %%
# locals.update(np.load('coverage_freqepid_nbinom_randinf_2.npz'))

# %%
Ihs_dth = np.zeros([num_sim, 2+d, 2+d])
Ts_dth = np.zeros(num_sim)
ps_dth = np.zeros(num_sim)

# %%
Ihs_hac = np.zeros([num_sim, 2+d, 2+d])
Ts_hac = np.zeros(num_sim)
ps_hac = np.zeros(num_sim)

# %%
Ihs_sdw = np.zeros([num_sim, 2+d, 2+d])
Ts_sdw = np.zeros(num_sim)
ps_sdw = np.zeros(num_sim)

# %%
for iter_sim in np.arange(num_sim):
    start_sim = time.time()
    
    nmle = nsim[iter_sim]
    mmle = msim[iter_sim]
    bmle = bsim[iter_sim,:]
    
    data_i = data[data['sim']==iter_sim]
    A = np.stack([np.full(T, 1), data_i["intervention"].to_numpy()], -1)
    Y = data_i["death"].to_numpy()
    
    Ihat_dth, Ihat_hac, Ihat_sdw =\
    model.inference(A, Y, nmle, mmle, bmle)
    
    # Fisher information matrix
    Ihs_dth[iter_sim] = Ihat_dth
    Ts_dth[iter_sim] = (bmle[1]-beta[1])/np.sqrt(la.pinv(Ihs_dth[iter_sim])[-1,-1])
    ps_dth[iter_sim] = 2*(1-stats.norm.cdf(np.abs(Ts_dth[iter_sim])))
    
    # HAC estimator
    Ihs_hac[iter_sim] = Ihat_hac
    Ts_hac[iter_sim] = (bmle[1]-beta[1])/np.sqrt(la.pinv(Ihs_hac[iter_sim])[-1,-1])
    ps_hac[iter_sim] = 2*(1-stats.norm.cdf(np.abs(Ts_hac[iter_sim])))
    
    # Sandwich estimator
    Ihs_sdw[iter_sim] = Ihat_sdw
    Ts_sdw[iter_sim] = (bmle[1]-beta[1])/np.sqrt(la.pinv(Ihs_sdw[iter_sim])[-1,-1])
    ps_sdw[iter_sim] = 2*(1-stats.norm.cdf(np.abs(Ts_sdw[iter_sim])))
    
    sys.__stdout__.write("%d-th simulation finished, %f sec.\n"
                         %(iter_sim+1, time.time()-start_sim))
    sys.__stdout__.flush()
# Out:
# 1-th simulation finished, 0.005546 sec.
# 2-th simulation finished, 0.003206 sec.
# 3-th simulation finished, 0.001812 sec.
# 4-th simulation finished, 0.001725 sec.
# 5-th simulation finished, 0.001474 sec.
# 6-th simulation finished, 0.001428 sec.
# 7-th simulation finished, 0.001319 sec.
# 8-th simulation finished, 0.001263 sec.
# 9-th simulation finished, 0.003437 sec.
# 10-th simulation finished, 0.002379 sec.
# 11-th simulation finished, 0.001493 sec.
# 12-th simulation finished, 0.003471 sec.
# 13-th simulation finished, 0.002948 sec.
# 14-th simulation finished, 0.002860 sec.
# 15-th simulation finished, 0.001712 sec.
# 16-th simulation finished, 0.001369 sec.
# 17-th simulation finished, 0.003627 sec.
# 18-th simulation finished, 0.001662 sec.
# 19-th simulation finished, 0.001632 sec.
# 20-th simulation finished, 0.001368 sec.
# 21-th simulation finished, 0.001299 sec.
# 22-th simulation finished, 0.001783 sec.
# 23-th simulation finished, 0.001337 sec.
# 24-th simulation finished, 0.001220 sec.
# 25-th simulation finished, 0.001202 sec.
# 26-th simulation finished, 0.001194 sec.
# 27-th simulation finished, 0.001174 sec.
# 28-th simulation finished, 0.003810 sec.
# 29-th simulation finished, 0.003544 sec.
# 30-th simulation finished, 0.002855 sec.
# 31-th simulation finished, 0.002853 sec.
# 32-th simulation finished, 0.004976 sec.
# 33-th simulation finished, 0.002002 sec.
# 34-th simulation finished, 0.001697 sec.
# 35-th simulation finished, 0.003008 sec.
# 36-th simulation finished, 0.002764 sec.
# 37-th simulation finished, 0.002474 sec.
# 38-th simulation finished, 0.001311 sec.
# 39-th simulation finished, 0.001217 sec.
# 40-th simulation finished, 0.001229 sec.
# 41-th simulation finished, 0.001191 sec.
# 42-th simulation finished, 0.001625 sec.
# 43-th simulation finished, 0.001210 sec.
# 44-th simulation finished, 0.001185 sec.
# 45-th simulation finished, 0.008745 sec.
# 46-th simulation finished, 0.004308 sec.
# 47-th simulation finished, 0.002165 sec.
# 48-th simulation finished, 0.004025 sec.
# 49-th simulation finished, 0.001252 sec.
# 50-th simulation finished, 0.001197 sec.
# 51-th simulation finished, 0.003155 sec.
# 52-th simulation finished, 0.003034 sec.
# 53-th simulation finished, 0.002498 sec.
# 54-th simulation finished, 0.001238 sec.
# 55-th simulation finished, 0.001185 sec.
# 56-th simulation finished, 0.004955 sec.
# 57-th simulation finished, 0.003088 sec.
# 58-th simulation finished, 0.003356 sec.
# 59-th simulation finished, 0.009204 sec.
# 60-th simulation finished, 0.001984 sec.
# 61-th simulation finished, 0.002555 sec.
# 62-th simulation finished, 0.001314 sec.
# 63-th simulation finished, 0.001356 sec.
# 64-th simulation finished, 0.004139 sec.
# 65-th simulation finished, 0.002448 sec.
# 66-th simulation finished, 0.003023 sec.
# 67-th simulation finished, 0.008080 sec.
# 68-th simulation finished, 0.001825 sec.
# 69-th simulation finished, 0.001979 sec.
# 70-th simulation finished, 0.002610 sec.
# 71-th simulation finished, 0.003110 sec.
# 72-th simulation finished, 0.002683 sec.
# 73-th simulation finished, 0.001731 sec.
# 74-th simulation finished, 0.001374 sec.
# 75-th simulation finished, 0.001292 sec.
# 76-th simulation finished, 0.001312 sec.
# 77-th simulation finished, 0.001204 sec.
# 78-th simulation finished, 0.002311 sec.
# 79-th simulation finished, 0.001350 sec.
# 80-th simulation finished, 0.001200 sec.
# 81-th simulation finished, 0.001217 sec.
# 82-th simulation finished, 0.002577 sec.
# 83-th simulation finished, 0.001387 sec.
# 84-th simulation finished, 0.001253 sec.
# 85-th simulation finished, 0.001192 sec.
# 86-th simulation finished, 0.001194 sec.
# 87-th simulation finished, 0.001192 sec.
# 88-th simulation finished, 0.008260 sec.
# 89-th simulation finished, 0.001595 sec.
# 90-th simulation finished, 0.001396 sec.
# 91-th simulation finished, 0.003137 sec.
# 92-th simulation finished, 0.005070 sec.
# 93-th simulation finished, 0.001897 sec.
# 94-th simulation finished, 0.004724 sec.
# 95-th simulation finished, 0.002601 sec.
# 96-th simulation finished, 0.001260 sec.
# 97-th simulation finished, 0.001182 sec.
# 98-th simulation finished, 0.001202 sec.
# 99-th simulation finished, 0.003235 sec.
# 100-th simulation finished, 0.003938 sec.
# 101-th simulation finished, 0.002732 sec.
# 102-th simulation finished, 0.001349 sec.
# 103-th simulation finished, 0.001250 sec.
# 104-th simulation finished, 0.001182 sec.
# 105-th simulation finished, 0.001204 sec.
# 106-th simulation finished, 0.001167 sec.
# 107-th simulation finished, 0.001208 sec.
# 108-th simulation finished, 0.004106 sec.
# 109-th simulation finished, 0.001350 sec.
# 110-th simulation finished, 0.001377 sec.
# 111-th simulation finished, 0.001214 sec.
# 112-th simulation finished, 0.001199 sec.
# 113-th simulation finished, 0.001187 sec.
# 114-th simulation finished, 0.001180 sec.
# 115-th simulation finished, 0.001180 sec.
# 116-th simulation finished, 0.001220 sec.
# 117-th simulation finished, 0.001335 sec.
# 118-th simulation finished, 0.002213 sec.
# 119-th simulation finished, 0.001434 sec.
# 120-th simulation finished, 0.001575 sec.
# 121-th simulation finished, 0.001303 sec.
# 122-th simulation finished, 0.001202 sec.
# 123-th simulation finished, 0.001206 sec.
# 124-th simulation finished, 0.001175 sec.
# 125-th simulation finished, 0.001196 sec.
# 126-th simulation finished, 0.001168 sec.
# 127-th simulation finished, 0.001204 sec.
# 128-th simulation finished, 0.001172 sec.
# 129-th simulation finished, 0.002346 sec.
# 130-th simulation finished, 0.001328 sec.
# 131-th simulation finished, 0.001441 sec.
# 132-th simulation finished, 0.001904 sec.
# 133-th simulation finished, 0.003161 sec.
# 134-th simulation finished, 0.002737 sec.
# 135-th simulation finished, 0.001332 sec.
# 136-th simulation finished, 0.003089 sec.
# 137-th simulation finished, 0.003745 sec.
# 138-th simulation finished, 0.001672 sec.
# 139-th simulation finished, 0.001755 sec.
# 140-th simulation finished, 0.001375 sec.
# 141-th simulation finished, 0.003112 sec.
# 142-th simulation finished, 0.002960 sec.
# 143-th simulation finished, 0.002941 sec.
# 144-th simulation finished, 0.001415 sec.
# 145-th simulation finished, 0.001442 sec.
# 146-th simulation finished, 0.001450 sec.
# 147-th simulation finished, 0.001998 sec.
# 148-th simulation finished, 0.001258 sec.
# 149-th simulation finished, 0.001367 sec.
# 150-th simulation finished, 0.003099 sec.
# 151-th simulation finished, 0.003121 sec.
# 152-th simulation finished, 0.001997 sec.
# 153-th simulation finished, 0.001301 sec.
# 154-th simulation finished, 0.001285 sec.
# 155-th simulation finished, 0.003203 sec.
# 156-th simulation finished, 0.002959 sec.
# 157-th simulation finished, 0.002803 sec.
# 158-th simulation finished, 0.001985 sec.
# 159-th simulation finished, 0.001386 sec.
# 160-th simulation finished, 0.003824 sec.
# 161-th simulation finished, 0.002776 sec.
# 162-th simulation finished, 0.002937 sec.
# 163-th simulation finished, 0.001416 sec.
# 164-th simulation finished, 0.001337 sec.
# 165-th simulation finished, 0.001302 sec.
# 166-th simulation finished, 0.003105 sec.
# 167-th simulation finished, 0.003225 sec.
# 168-th simulation finished, 0.001262 sec.
# 169-th simulation finished, 0.002963 sec.
# 170-th simulation finished, 0.001296 sec.
# 171-th simulation finished, 0.003114 sec.
# 172-th simulation finished, 0.002931 sec.
# 173-th simulation finished, 0.002823 sec.
# 174-th simulation finished, 0.002646 sec.
# 175-th simulation finished, 0.012348 sec.
# 176-th simulation finished, 0.001279 sec.
# 177-th simulation finished, 0.001408 sec.
# 178-th simulation finished, 0.003704 sec.
# 179-th simulation finished, 0.001416 sec.
# 180-th simulation finished, 0.002943 sec.
# 181-th simulation finished, 0.001355 sec.
# 182-th simulation finished, 0.001804 sec.
# 183-th simulation finished, 0.001767 sec.
# 184-th simulation finished, 0.001440 sec.
# 185-th simulation finished, 0.003977 sec.
# 186-th simulation finished, 0.002204 sec.
# 187-th simulation finished, 0.001500 sec.
# 188-th simulation finished, 0.004409 sec.
# 189-th simulation finished, 0.002874 sec.
# 190-th simulation finished, 0.002998 sec.
# 191-th simulation finished, 0.001409 sec.
# 192-th simulation finished, 0.001220 sec.
# 193-th simulation finished, 0.003500 sec.
# 194-th simulation finished, 0.002866 sec.
# 195-th simulation finished, 0.002826 sec.
# 196-th simulation finished, 0.001328 sec.
# 197-th simulation finished, 0.004692 sec.
# 198-th simulation finished, 0.003290 sec.
# 199-th simulation finished, 0.002349 sec.
# 200-th simulation finished, 0.001342 sec.
# 201-th simulation finished, 0.001368 sec.
# 202-th simulation finished, 0.001268 sec.
# 203-th simulation finished, 0.003293 sec.
# 204-th simulation finished, 0.003564 sec.
# 205-th simulation finished, 0.003431 sec.
# 206-th simulation finished, 0.001356 sec.
# 207-th simulation finished, 0.001361 sec.
# 208-th simulation finished, 0.003007 sec.
# 209-th simulation finished, 0.002962 sec.
# 210-th simulation finished, 0.003504 sec.
# 211-th simulation finished, 0.001458 sec.
# 212-th simulation finished, 0.001246 sec.
# 213-th simulation finished, 0.002179 sec.
# 214-th simulation finished, 0.001467 sec.
# 215-th simulation finished, 0.001208 sec.
# 216-th simulation finished, 0.003218 sec.
# 217-th simulation finished, 0.002993 sec.
# 218-th simulation finished, 0.003350 sec.
# 219-th simulation finished, 0.002468 sec.
# 220-th simulation finished, 0.001346 sec.
# 221-th simulation finished, 0.001410 sec.
# 222-th simulation finished, 0.007679 sec.
# 223-th simulation finished, 0.001913 sec.
# 224-th simulation finished, 0.006052 sec.
# 225-th simulation finished, 0.011304 sec.
# 226-th simulation finished, 0.001740 sec.
# 227-th simulation finished, 0.001536 sec.
# 228-th simulation finished, 0.001310 sec.
# 229-th simulation finished, 0.001374 sec.
# 230-th simulation finished, 0.005250 sec.
# 231-th simulation finished, 0.001398 sec.
# 232-th simulation finished, 0.013680 sec.
# 233-th simulation finished, 0.001442 sec.
# 234-th simulation finished, 0.015041 sec.
# 235-th simulation finished, 0.001339 sec.
# 236-th simulation finished, 0.003417 sec.
# 237-th simulation finished, 0.002562 sec.
# 238-th simulation finished, 0.001548 sec.
# 239-th simulation finished, 0.001460 sec.
# 240-th simulation finished, 0.003120 sec.
# 241-th simulation finished, 0.002853 sec.
# 242-th simulation finished, 0.002816 sec.
# 243-th simulation finished, 0.001808 sec.
# 244-th simulation finished, 0.001380 sec.
# 245-th simulation finished, 0.005934 sec.
# 246-th simulation finished, 0.001366 sec.
# 247-th simulation finished, 0.001376 sec.
# 248-th simulation finished, 0.001283 sec.
# 249-th simulation finished, 0.003249 sec.
# 250-th simulation finished, 0.001986 sec.
# 251-th simulation finished, 0.001316 sec.
# 252-th simulation finished, 0.006823 sec.
# 253-th simulation finished, 0.001281 sec.
# 254-th simulation finished, 0.001359 sec.
# 255-th simulation finished, 0.005000 sec.
# 256-th simulation finished, 0.001315 sec.
# 257-th simulation finished, 0.001334 sec.
# 258-th simulation finished, 0.001386 sec.
# 259-th simulation finished, 0.001519 sec.
# 260-th simulation finished, 0.001350 sec.
# 261-th simulation finished, 0.001380 sec.
# 262-th simulation finished, 0.001385 sec.
# 263-th simulation finished, 0.001416 sec.
# 264-th simulation finished, 0.001340 sec.
# 265-th simulation finished, 0.001218 sec.
# 266-th simulation finished, 0.001237 sec.
# 267-th simulation finished, 0.001200 sec.
# 268-th simulation finished, 0.001314 sec.
# 269-th simulation finished, 0.001310 sec.
# 270-th simulation finished, 0.004748 sec.
# 271-th simulation finished, 0.001326 sec.
# 272-th simulation finished, 0.001222 sec.
# 273-th simulation finished, 0.001328 sec.
# 274-th simulation finished, 0.001229 sec.
# 275-th simulation finished, 0.001285 sec.
# 276-th simulation finished, 0.001222 sec.
# 277-th simulation finished, 0.001234 sec.
# 278-th simulation finished, 0.002605 sec.
# 279-th simulation finished, 0.001338 sec.
# 280-th simulation finished, 0.002548 sec.
# 281-th simulation finished, 0.001244 sec.
# 282-th simulation finished, 0.001257 sec.
# 283-th simulation finished, 0.001445 sec.
# 284-th simulation finished, 0.001387 sec.
# 285-th simulation finished, 0.003291 sec.
# 286-th simulation finished, 0.001433 sec.
# 287-th simulation finished, 0.001343 sec.
# 288-th simulation finished, 0.001261 sec.
# 289-th simulation finished, 0.007230 sec.
# 290-th simulation finished, 0.001287 sec.
# 291-th simulation finished, 0.001333 sec.
# 292-th simulation finished, 0.001292 sec.
# 293-th simulation finished, 0.001295 sec.
# 294-th simulation finished, 0.007141 sec.
# 295-th simulation finished, 0.001644 sec.
# 296-th simulation finished, 0.001310 sec.
# 297-th simulation finished, 0.001395 sec.
# 298-th simulation finished, 0.001333 sec.
# 299-th simulation finished, 0.001312 sec.
# 300-th simulation finished, 0.001309 sec.
# 301-th simulation finished, 0.001283 sec.
# 302-th simulation finished, 0.001299 sec.
# 303-th simulation finished, 0.001262 sec.
# 304-th simulation finished, 0.001283 sec.
# 305-th simulation finished, 0.001306 sec.
# 306-th simulation finished, 0.001339 sec.
# 307-th simulation finished, 0.002461 sec.
# 308-th simulation finished, 0.001355 sec.
# 309-th simulation finished, 0.001232 sec.
# 310-th simulation finished, 0.001214 sec.
# 311-th simulation finished, 0.001211 sec.
# 312-th simulation finished, 0.001271 sec.
# 313-th simulation finished, 0.001315 sec.
# 314-th simulation finished, 0.001329 sec.
# 315-th simulation finished, 0.001251 sec.
# 316-th simulation finished, 0.001320 sec.
# 317-th simulation finished, 0.001277 sec.
# 318-th simulation finished, 0.006342 sec.
# 319-th simulation finished, 0.001237 sec.
# 320-th simulation finished, 0.001430 sec.
# 321-th simulation finished, 0.001325 sec.
# 322-th simulation finished, 0.001331 sec.
# 323-th simulation finished, 0.001398 sec.
# 324-th simulation finished, 0.001271 sec.
# 325-th simulation finished, 0.001291 sec.
# 326-th simulation finished, 0.001260 sec.
# 327-th simulation finished, 0.002281 sec.
# 328-th simulation finished, 0.001242 sec.
# 329-th simulation finished, 0.001279 sec.
# 330-th simulation finished, 0.001256 sec.
# 331-th simulation finished, 0.001212 sec.
# 332-th simulation finished, 0.001867 sec.
# 333-th simulation finished, 0.001303 sec.
# 334-th simulation finished, 0.001481 sec.
# 335-th simulation finished, 0.001597 sec.
# 336-th simulation finished, 0.001281 sec.
# 337-th simulation finished, 0.001250 sec.
# 338-th simulation finished, 0.004124 sec.
# 339-th simulation finished, 0.003134 sec.
# 340-th simulation finished, 0.001403 sec.
# 341-th simulation finished, 0.001335 sec.
# 342-th simulation finished, 0.001308 sec.
# 343-th simulation finished, 0.001295 sec.
# 344-th simulation finished, 0.001343 sec.
# 345-th simulation finished, 0.001587 sec.
# 346-th simulation finished, 0.002429 sec.
# 347-th simulation finished, 0.001281 sec.
# 348-th simulation finished, 0.001200 sec.
# 349-th simulation finished, 0.003950 sec.
# 350-th simulation finished, 0.001358 sec.
# 351-th simulation finished, 0.001229 sec.
# 352-th simulation finished, 0.001289 sec.
# 353-th simulation finished, 0.001258 sec.
# 354-th simulation finished, 0.001247 sec.
# 355-th simulation finished, 0.001268 sec.
# 356-th simulation finished, 0.001289 sec.
# 357-th simulation finished, 0.004870 sec.
# 358-th simulation finished, 0.002743 sec.
# 359-th simulation finished, 0.002785 sec.
# 360-th simulation finished, 0.001345 sec.
# 361-th simulation finished, 0.001406 sec.
# 362-th simulation finished, 0.001310 sec.
# 363-th simulation finished, 0.006114 sec.
# 364-th simulation finished, 0.011604 sec.
# 365-th simulation finished, 0.002345 sec.
# 366-th simulation finished, 0.001413 sec.
# 367-th simulation finished, 0.001423 sec.
# 368-th simulation finished, 0.001346 sec.
# 369-th simulation finished, 0.001305 sec.
# 370-th simulation finished, 0.001264 sec.
# 371-th simulation finished, 0.001270 sec.
# 372-th simulation finished, 0.001298 sec.
# 373-th simulation finished, 0.001298 sec.
# 374-th simulation finished, 0.001302 sec.
# 375-th simulation finished, 0.001321 sec.
# 376-th simulation finished, 0.001436 sec.
# 377-th simulation finished, 0.001233 sec.
# 378-th simulation finished, 0.001445 sec.
# 379-th simulation finished, 0.001485 sec.
# 380-th simulation finished, 0.001330 sec.
# 381-th simulation finished, 0.001263 sec.
# 382-th simulation finished, 0.001214 sec.
# 383-th simulation finished, 0.001233 sec.
# 384-th simulation finished, 0.001202 sec.
# 385-th simulation finished, 0.001211 sec.
# 386-th simulation finished, 0.001315 sec.
# 387-th simulation finished, 0.001360 sec.
# 388-th simulation finished, 0.001294 sec.
# 389-th simulation finished, 0.001421 sec.
# 390-th simulation finished, 0.001258 sec.
# 391-th simulation finished, 0.001202 sec.
# 392-th simulation finished, 0.001194 sec.
# 393-th simulation finished, 0.001577 sec.
# 394-th simulation finished, 0.001337 sec.
# 395-th simulation finished, 0.001292 sec.
# 396-th simulation finished, 0.001223 sec.
# 397-th simulation finished, 0.001258 sec.
# 398-th simulation finished, 0.001357 sec.
# 399-th simulation finished, 0.001317 sec.
# 400-th simulation finished, 0.001361 sec.
# 401-th simulation finished, 0.001798 sec.
# 402-th simulation finished, 0.001239 sec.
# 403-th simulation finished, 0.002406 sec.
# 404-th simulation finished, 0.003411 sec.
# 405-th simulation finished, 0.001440 sec.
# 406-th simulation finished, 0.001275 sec.
# 407-th simulation finished, 0.001219 sec.
# 408-th simulation finished, 0.001283 sec.
# 409-th simulation finished, 0.001295 sec.
# 410-th simulation finished, 0.001313 sec.
# 411-th simulation finished, 0.001501 sec.
# 412-th simulation finished, 0.001276 sec.
# 413-th simulation finished, 0.001319 sec.
# 414-th simulation finished, 0.001309 sec.
# 415-th simulation finished, 0.001447 sec.
# 416-th simulation finished, 0.001287 sec.
# 417-th simulation finished, 0.001280 sec.
# 418-th simulation finished, 0.001281 sec.
# 419-th simulation finished, 0.001309 sec.
# 420-th simulation finished, 0.001262 sec.
# 421-th simulation finished, 0.001244 sec.
# 422-th simulation finished, 0.001307 sec.
# 423-th simulation finished, 0.001294 sec.
# 424-th simulation finished, 0.001205 sec.
# 425-th simulation finished, 0.001235 sec.
# 426-th simulation finished, 0.001609 sec.
# 427-th simulation finished, 0.001473 sec.
# 428-th simulation finished, 0.001456 sec.
# 429-th simulation finished, 0.001255 sec.
# 430-th simulation finished, 0.001177 sec.
# 431-th simulation finished, 0.001198 sec.
# 432-th simulation finished, 0.001163 sec.
# 433-th simulation finished, 0.001180 sec.
# 434-th simulation finished, 0.001161 sec.
# 435-th simulation finished, 0.002486 sec.
# 436-th simulation finished, 0.001296 sec.
# 437-th simulation finished, 0.001200 sec.
# 438-th simulation finished, 0.001173 sec.
# 439-th simulation finished, 0.001169 sec.
# 440-th simulation finished, 0.001157 sec.
# 441-th simulation finished, 0.001186 sec.
# 442-th simulation finished, 0.001193 sec.
# 443-th simulation finished, 0.001178 sec.
# 444-th simulation finished, 0.001183 sec.
# 445-th simulation finished, 0.001170 sec.
# 446-th simulation finished, 0.001288 sec.
# 447-th simulation finished, 0.001258 sec.
# 448-th simulation finished, 0.001185 sec.
# 449-th simulation finished, 0.001167 sec.
# 450-th simulation finished, 0.001169 sec.
# 451-th simulation finished, 0.001167 sec.
# 452-th simulation finished, 0.001516 sec.
# 453-th simulation finished, 0.001518 sec.
# 454-th simulation finished, 0.001923 sec.
# 455-th simulation finished, 0.002920 sec.
# 456-th simulation finished, 0.003536 sec.
# 457-th simulation finished, 0.002912 sec.
# 458-th simulation finished, 0.002378 sec.
# 459-th simulation finished, 0.001205 sec.
# 460-th simulation finished, 0.001196 sec.
# 461-th simulation finished, 0.002955 sec.
# 462-th simulation finished, 0.002950 sec.
# 463-th simulation finished, 0.002911 sec.
# 464-th simulation finished, 0.001211 sec.
# 465-th simulation finished, 0.001169 sec.
# 466-th simulation finished, 0.001164 sec.
# 467-th simulation finished, 0.001163 sec.
# 468-th simulation finished, 0.001200 sec.
# 469-th simulation finished, 0.001752 sec.
# 470-th simulation finished, 0.002236 sec.
# 471-th simulation finished, 0.001271 sec.
# 472-th simulation finished, 0.001358 sec.
# 473-th simulation finished, 0.001214 sec.
# 474-th simulation finished, 0.001222 sec.
# 475-th simulation finished, 0.001165 sec.
# 476-th simulation finished, 0.001190 sec.
# 477-th simulation finished, 0.001160 sec.
# 478-th simulation finished, 0.001201 sec.
# 479-th simulation finished, 0.001165 sec.
# 480-th simulation finished, 0.001191 sec.
# 481-th simulation finished, 0.005587 sec.
# 482-th simulation finished, 0.003036 sec.
# 483-th simulation finished, 0.002937 sec.
# 484-th simulation finished, 0.002659 sec.
# 485-th simulation finished, 0.001277 sec.
# 486-th simulation finished, 0.003967 sec.
# 487-th simulation finished, 0.003148 sec.
# 488-th simulation finished, 0.002039 sec.
# 489-th simulation finished, 0.013030 sec.
# 490-th simulation finished, 0.001336 sec.
# 491-th simulation finished, 0.001196 sec.
# 492-th simulation finished, 0.001211 sec.
# 493-th simulation finished, 0.001177 sec.
# 494-th simulation finished, 0.004944 sec.
# 495-th simulation finished, 0.002751 sec.
# 496-th simulation finished, 0.002142 sec.
# 497-th simulation finished, 0.001341 sec.
# 498-th simulation finished, 0.001308 sec.
# 499-th simulation finished, 0.001287 sec.
# 500-th simulation finished, 0.001334 sec.
# 501-th simulation finished, 0.001293 sec.
# 502-th simulation finished, 0.010041 sec.
# 503-th simulation finished, 0.001299 sec.
# 504-th simulation finished, 0.001248 sec.
# 505-th simulation finished, 0.001280 sec.
# 506-th simulation finished, 0.001360 sec.
# 507-th simulation finished, 0.001287 sec.
# 508-th simulation finished, 0.001239 sec.
# 509-th simulation finished, 0.001313 sec.
# 510-th simulation finished, 0.001443 sec.
# 511-th simulation finished, 0.001308 sec.
# 512-th simulation finished, 0.001357 sec.
# 513-th simulation finished, 0.004555 sec.
# 514-th simulation finished, 0.001303 sec.
# 515-th simulation finished, 0.001758 sec.
# 516-th simulation finished, 0.001304 sec.
# 517-th simulation finished, 0.001266 sec.
# 518-th simulation finished, 0.001340 sec.
# 519-th simulation finished, 0.001328 sec.
# 520-th simulation finished, 0.003672 sec.
# 521-th simulation finished, 0.001386 sec.
# 522-th simulation finished, 0.001631 sec.
# 523-th simulation finished, 0.001366 sec.
# 524-th simulation finished, 0.001328 sec.
# 525-th simulation finished, 0.001344 sec.
# 526-th simulation finished, 0.002223 sec.
# 527-th simulation finished, 0.001323 sec.
# 528-th simulation finished, 0.001254 sec.
# 529-th simulation finished, 0.001205 sec.
# 530-th simulation finished, 0.008242 sec.
# 531-th simulation finished, 0.001332 sec.
# 532-th simulation finished, 0.001310 sec.
# 533-th simulation finished, 0.001339 sec.
# 534-th simulation finished, 0.001233 sec.
# 535-th simulation finished, 0.001326 sec.
# 536-th simulation finished, 0.001395 sec.
# 537-th simulation finished, 0.005158 sec.
# 538-th simulation finished, 0.002209 sec.
# 539-th simulation finished, 0.001498 sec.
# 540-th simulation finished, 0.001260 sec.
# 541-th simulation finished, 0.001654 sec.
# 542-th simulation finished, 0.001302 sec.
# 543-th simulation finished, 0.001294 sec.
# 544-th simulation finished, 0.002535 sec.
# 545-th simulation finished, 0.004722 sec.
# 546-th simulation finished, 0.001605 sec.
# 547-th simulation finished, 0.001533 sec.
# 548-th simulation finished, 0.001485 sec.
# 549-th simulation finished, 0.002262 sec.
# 550-th simulation finished, 0.001396 sec.
# 551-th simulation finished, 0.001317 sec.
# 552-th simulation finished, 0.001297 sec.
# 553-th simulation finished, 0.001268 sec.
# 554-th simulation finished, 0.001280 sec.
# 555-th simulation finished, 0.002380 sec.
# 556-th simulation finished, 0.001804 sec.
# 557-th simulation finished, 0.001329 sec.
# 558-th simulation finished, 0.001237 sec.
# 559-th simulation finished, 0.001218 sec.
# 560-th simulation finished, 0.001169 sec.
# 561-th simulation finished, 0.001205 sec.
# 562-th simulation finished, 0.001166 sec.
# 563-th simulation finished, 0.001180 sec.
# 564-th simulation finished, 0.001409 sec.
# 565-th simulation finished, 0.001263 sec.
# 566-th simulation finished, 0.001268 sec.
# 567-th simulation finished, 0.001172 sec.
# 568-th simulation finished, 0.001186 sec.
# 569-th simulation finished, 0.001191 sec.
# 570-th simulation finished, 0.005957 sec.
# 571-th simulation finished, 0.002507 sec.
# 572-th simulation finished, 0.001286 sec.
# 573-th simulation finished, 0.001225 sec.
# 574-th simulation finished, 0.001535 sec.
# 575-th simulation finished, 0.001303 sec.
# 576-th simulation finished, 0.001265 sec.
# 577-th simulation finished, 0.001477 sec.
# 578-th simulation finished, 0.001287 sec.
# 579-th simulation finished, 0.001269 sec.
# 580-th simulation finished, 0.001172 sec.
# 581-th simulation finished, 0.001179 sec.
# 582-th simulation finished, 0.001161 sec.
# 583-th simulation finished, 0.001784 sec.
# 584-th simulation finished, 0.003100 sec.
# 585-th simulation finished, 0.003052 sec.
# 586-th simulation finished, 0.003048 sec.
# 587-th simulation finished, 0.001264 sec.
# 588-th simulation finished, 0.007213 sec.
# 589-th simulation finished, 0.011250 sec.
# 590-th simulation finished, 0.002008 sec.
# 591-th simulation finished, 0.002972 sec.
# 592-th simulation finished, 0.002883 sec.
# 593-th simulation finished, 0.003392 sec.
# 594-th simulation finished, 0.004531 sec.
# 595-th simulation finished, 0.001254 sec.
# 596-th simulation finished, 0.001178 sec.
# 597-th simulation finished, 0.001170 sec.
# 598-th simulation finished, 0.001423 sec.
# 599-th simulation finished, 0.001248 sec.
# 600-th simulation finished, 0.001188 sec.
# 601-th simulation finished, 0.001191 sec.
# 602-th simulation finished, 0.001164 sec.
# 603-th simulation finished, 0.001160 sec.
# 604-th simulation finished, 0.002058 sec.
# 605-th simulation finished, 0.001429 sec.
# 606-th simulation finished, 0.006098 sec.
# 607-th simulation finished, 0.008173 sec.
# 608-th simulation finished, 0.001519 sec.
# 609-th simulation finished, 0.002379 sec.
# 610-th simulation finished, 0.001251 sec.
# 611-th simulation finished, 0.001203 sec.
# 612-th simulation finished, 0.007158 sec.
# 613-th simulation finished, 0.001363 sec.
# 614-th simulation finished, 0.001344 sec.
# 615-th simulation finished, 0.006591 sec.
# 616-th simulation finished, 0.001336 sec.
# 617-th simulation finished, 0.001336 sec.
# 618-th simulation finished, 0.003135 sec.
# 619-th simulation finished, 0.001315 sec.
# 620-th simulation finished, 0.001301 sec.
# 621-th simulation finished, 0.001304 sec.
# 622-th simulation finished, 0.005516 sec.
# 623-th simulation finished, 0.001419 sec.
# 624-th simulation finished, 0.001395 sec.
# 625-th simulation finished, 0.003650 sec.
# 626-th simulation finished, 0.001288 sec.
# 627-th simulation finished, 0.001326 sec.
# 628-th simulation finished, 0.001269 sec.
# 629-th simulation finished, 0.001225 sec.
# 630-th simulation finished, 0.010916 sec.
# 631-th simulation finished, 0.001429 sec.
# 632-th simulation finished, 0.001429 sec.
# 633-th simulation finished, 0.007418 sec.
# 634-th simulation finished, 0.001323 sec.
# 635-th simulation finished, 0.001254 sec.
# 636-th simulation finished, 0.001420 sec.
# 637-th simulation finished, 0.001308 sec.
# 638-th simulation finished, 0.010335 sec.
# 639-th simulation finished, 0.010913 sec.
# 640-th simulation finished, 0.001298 sec.
# 641-th simulation finished, 0.001265 sec.
# 642-th simulation finished, 0.002886 sec.
# 643-th simulation finished, 0.003474 sec.
# 644-th simulation finished, 0.002866 sec.
# 645-th simulation finished, 0.002125 sec.
# 646-th simulation finished, 0.001379 sec.
# 647-th simulation finished, 0.012394 sec.
# 648-th simulation finished, 0.004604 sec.
# 649-th simulation finished, 0.001352 sec.
# 650-th simulation finished, 0.016249 sec.
# 651-th simulation finished, 0.001594 sec.
# 652-th simulation finished, 0.012404 sec.
# 653-th simulation finished, 0.001317 sec.
# 654-th simulation finished, 0.001326 sec.
# 655-th simulation finished, 0.001415 sec.
# 656-th simulation finished, 0.003389 sec.
# 657-th simulation finished, 0.001394 sec.
# 658-th simulation finished, 0.003296 sec.
# 659-th simulation finished, 0.001685 sec.
# 660-th simulation finished, 0.001264 sec.
# 661-th simulation finished, 0.002981 sec.
# 662-th simulation finished, 0.002874 sec.
# 663-th simulation finished, 0.002520 sec.
# 664-th simulation finished, 0.002097 sec.
# 665-th simulation finished, 0.002781 sec.
# 666-th simulation finished, 0.003309 sec.
# 667-th simulation finished, 0.003025 sec.
# 668-th simulation finished, 0.001352 sec.
# 669-th simulation finished, 0.003416 sec.
# 670-th simulation finished, 0.003290 sec.
# 671-th simulation finished, 0.002872 sec.
# 672-th simulation finished, 0.001767 sec.
# 673-th simulation finished, 0.001346 sec.
# 674-th simulation finished, 0.002935 sec.
# 675-th simulation finished, 0.002868 sec.
# 676-th simulation finished, 0.004019 sec.
# 677-th simulation finished, 0.001847 sec.
# 678-th simulation finished, 0.001329 sec.
# 679-th simulation finished, 0.001325 sec.
# 680-th simulation finished, 0.001326 sec.
# 681-th simulation finished, 0.001355 sec.
# 682-th simulation finished, 0.003082 sec.
# 683-th simulation finished, 0.003194 sec.
# 684-th simulation finished, 0.003171 sec.
# 685-th simulation finished, 0.001515 sec.
# 686-th simulation finished, 0.001471 sec.
# 687-th simulation finished, 0.003117 sec.
# 688-th simulation finished, 0.014813 sec.
# 689-th simulation finished, 0.001277 sec.
# 690-th simulation finished, 0.001359 sec.
# 691-th simulation finished, 0.002312 sec.
# 692-th simulation finished, 0.001369 sec.
# 693-th simulation finished, 0.001229 sec.
# 694-th simulation finished, 0.001326 sec.
# 695-th simulation finished, 0.013519 sec.
# 696-th simulation finished, 0.003640 sec.
# 697-th simulation finished, 0.004257 sec.
# 698-th simulation finished, 0.001555 sec.
# 699-th simulation finished, 0.001219 sec.
# 700-th simulation finished, 0.001753 sec.
# 701-th simulation finished, 0.003949 sec.
# 702-th simulation finished, 0.004086 sec.
# 703-th simulation finished, 0.001520 sec.
# 704-th simulation finished, 0.002150 sec.
# 705-th simulation finished, 0.001332 sec.
# 706-th simulation finished, 0.003318 sec.
# 707-th simulation finished, 0.001384 sec.
# 708-th simulation finished, 0.003154 sec.
# 709-th simulation finished, 0.001582 sec.
# 710-th simulation finished, 0.001304 sec.
# 711-th simulation finished, 0.003186 sec.
# 712-th simulation finished, 0.001819 sec.
# 713-th simulation finished, 0.003163 sec.
# 714-th simulation finished, 0.002473 sec.
# 715-th simulation finished, 0.001443 sec.
# 716-th simulation finished, 0.001285 sec.
# 717-th simulation finished, 0.001375 sec.
# 718-th simulation finished, 0.003492 sec.
# 719-th simulation finished, 0.001382 sec.
# 720-th simulation finished, 0.003149 sec.
# 721-th simulation finished, 0.001453 sec.
# 722-th simulation finished, 0.001275 sec.
# 723-th simulation finished, 0.001295 sec.
# 724-th simulation finished, 0.003041 sec.
# 725-th simulation finished, 0.004356 sec.
# 726-th simulation finished, 0.001949 sec.
# 727-th simulation finished, 0.003367 sec.
# 728-th simulation finished, 0.002891 sec.
# 729-th simulation finished, 0.001395 sec.
# 730-th simulation finished, 0.001267 sec.
# 731-th simulation finished, 0.001398 sec.
# 732-th simulation finished, 0.001377 sec.
# 733-th simulation finished, 0.001308 sec.
# 734-th simulation finished, 0.002431 sec.
# 735-th simulation finished, 0.001456 sec.
# 736-th simulation finished, 0.003215 sec.
# 737-th simulation finished, 0.002869 sec.
# 738-th simulation finished, 0.002842 sec.
# 739-th simulation finished, 0.001650 sec.
# 740-th simulation finished, 0.001293 sec.
# 741-th simulation finished, 0.007950 sec.
# 742-th simulation finished, 0.001319 sec.
# 743-th simulation finished, 0.001337 sec.
# 744-th simulation finished, 0.001319 sec.
# 745-th simulation finished, 0.001221 sec.
# 746-th simulation finished, 0.001282 sec.
# 747-th simulation finished, 0.010282 sec.
# 748-th simulation finished, 0.001336 sec.
# 749-th simulation finished, 0.008557 sec.
# 750-th simulation finished, 0.004413 sec.
# 751-th simulation finished, 0.001262 sec.
# 752-th simulation finished, 0.001369 sec.
# 753-th simulation finished, 0.001226 sec.
# 754-th simulation finished, 0.001295 sec.
# 755-th simulation finished, 0.001237 sec.
# 756-th simulation finished, 0.001359 sec.
# 757-th simulation finished, 0.001277 sec.
# 758-th simulation finished, 0.005958 sec.
# 759-th simulation finished, 0.001365 sec.
# 760-th simulation finished, 0.001423 sec.
# 761-th simulation finished, 0.001221 sec.
# 762-th simulation finished, 0.002872 sec.
# 763-th simulation finished, 0.001288 sec.
# 764-th simulation finished, 0.001470 sec.
# 765-th simulation finished, 0.001357 sec.
# 766-th simulation finished, 0.003638 sec.
# 767-th simulation finished, 0.001258 sec.
# 768-th simulation finished, 0.005217 sec.
# 769-th simulation finished, 0.001239 sec.
# 770-th simulation finished, 0.005091 sec.
# 771-th simulation finished, 0.001271 sec.
# 772-th simulation finished, 0.001283 sec.
# 773-th simulation finished, 0.001265 sec.
# 774-th simulation finished, 0.001259 sec.
# 775-th simulation finished, 0.001302 sec.
# 776-th simulation finished, 0.002772 sec.
# 777-th simulation finished, 0.001290 sec.
# 778-th simulation finished, 0.001305 sec.
# 779-th simulation finished, 0.001292 sec.
# 780-th simulation finished, 0.001438 sec.
# 781-th simulation finished, 0.001348 sec.
# 782-th simulation finished, 0.001447 sec.
# 783-th simulation finished, 0.001309 sec.
# 784-th simulation finished, 0.005998 sec.
# 785-th simulation finished, 0.001255 sec.
# 786-th simulation finished, 0.001319 sec.
# 787-th simulation finished, 0.001433 sec.
# 788-th simulation finished, 0.001378 sec.
# 789-th simulation finished, 0.001352 sec.
# 790-th simulation finished, 0.001299 sec.
# 791-th simulation finished, 0.001237 sec.
# 792-th simulation finished, 0.001447 sec.
# 793-th simulation finished, 0.001280 sec.
# 794-th simulation finished, 0.007314 sec.
# 795-th simulation finished, 0.001284 sec.
# 796-th simulation finished, 0.001374 sec.
# 797-th simulation finished, 0.001197 sec.
# 798-th simulation finished, 0.001314 sec.
# 799-th simulation finished, 0.001358 sec.
# 800-th simulation finished, 0.001827 sec.
# 801-th simulation finished, 0.005602 sec.
# 802-th simulation finished, 0.001320 sec.
# 803-th simulation finished, 0.003768 sec.
# 804-th simulation finished, 0.012970 sec.
# 805-th simulation finished, 0.001360 sec.
# 806-th simulation finished, 0.001248 sec.
# 807-th simulation finished, 0.001321 sec.
# 808-th simulation finished, 0.001282 sec.
# 809-th simulation finished, 0.001260 sec.
# 810-th simulation finished, 0.001306 sec.
# 811-th simulation finished, 0.001244 sec.
# 812-th simulation finished, 0.001595 sec.
# 813-th simulation finished, 0.001593 sec.
# 814-th simulation finished, 0.002200 sec.
# 815-th simulation finished, 0.003461 sec.
# 816-th simulation finished, 0.001978 sec.
# 817-th simulation finished, 0.001337 sec.
# 818-th simulation finished, 0.001254 sec.
# 819-th simulation finished, 0.001261 sec.
# 820-th simulation finished, 0.009993 sec.
# 821-th simulation finished, 0.001452 sec.
# 822-th simulation finished, 0.001336 sec.
# 823-th simulation finished, 0.003128 sec.
# 824-th simulation finished, 0.001276 sec.
# 825-th simulation finished, 0.002602 sec.
# 826-th simulation finished, 0.002860 sec.
# 827-th simulation finished, 0.002996 sec.
# 828-th simulation finished, 0.002569 sec.
# 829-th simulation finished, 0.001321 sec.
# 830-th simulation finished, 0.001281 sec.
# 831-th simulation finished, 0.003038 sec.
# 832-th simulation finished, 0.003548 sec.
# 833-th simulation finished, 0.002825 sec.
# 834-th simulation finished, 0.003303 sec.
# 835-th simulation finished, 0.002855 sec.
# 836-th simulation finished, 0.001909 sec.
# 837-th simulation finished, 0.001352 sec.
# 838-th simulation finished, 0.001316 sec.
# 839-th simulation finished, 0.001294 sec.
# 840-th simulation finished, 0.001263 sec.
# 841-th simulation finished, 0.001875 sec.
# 842-th simulation finished, 0.001317 sec.
# 843-th simulation finished, 0.001265 sec.
# 844-th simulation finished, 0.001278 sec.
# 845-th simulation finished, 0.003182 sec.
# 846-th simulation finished, 0.002849 sec.
# 847-th simulation finished, 0.002865 sec.
# 848-th simulation finished, 0.001759 sec.
# 849-th simulation finished, 0.001470 sec.
# 850-th simulation finished, 0.001841 sec.
# 851-th simulation finished, 0.001378 sec.
# 852-th simulation finished, 0.003300 sec.
# 853-th simulation finished, 0.002873 sec.
# 854-th simulation finished, 0.003488 sec.
# 855-th simulation finished, 0.001303 sec.
# 856-th simulation finished, 0.001336 sec.
# 857-th simulation finished, 0.001194 sec.
# 858-th simulation finished, 0.001234 sec.
# 859-th simulation finished, 0.003259 sec.
# 860-th simulation finished, 0.003175 sec.
# 861-th simulation finished, 0.002528 sec.
# 862-th simulation finished, 0.001380 sec.
# 863-th simulation finished, 0.001292 sec.
# 864-th simulation finished, 0.001225 sec.
# 865-th simulation finished, 0.001237 sec.
# 866-th simulation finished, 0.001217 sec.
# 867-th simulation finished, 0.001562 sec.
# 868-th simulation finished, 0.001453 sec.
# 869-th simulation finished, 0.001365 sec.
# 870-th simulation finished, 0.003251 sec.
# 871-th simulation finished, 0.002767 sec.
# 872-th simulation finished, 0.001327 sec.
# 873-th simulation finished, 0.001228 sec.
# 874-th simulation finished, 0.001214 sec.
# 875-th simulation finished, 0.001204 sec.
# 876-th simulation finished, 0.001206 sec.
# 877-th simulation finished, 0.001205 sec.
# 878-th simulation finished, 0.001812 sec.
# 879-th simulation finished, 0.003109 sec.
# 880-th simulation finished, 0.001798 sec.
# 881-th simulation finished, 0.001479 sec.
# 882-th simulation finished, 0.001312 sec.
# 883-th simulation finished, 0.001239 sec.
# 884-th simulation finished, 0.001212 sec.
# 885-th simulation finished, 0.001422 sec.
# 886-th simulation finished, 0.002633 sec.
# 887-th simulation finished, 0.003062 sec.
# 888-th simulation finished, 0.002934 sec.
# 889-th simulation finished, 0.002863 sec.
# 890-th simulation finished, 0.002032 sec.
# 891-th simulation finished, 0.001276 sec.
# 892-th simulation finished, 0.006040 sec.
# 893-th simulation finished, 0.003305 sec.
# 894-th simulation finished, 0.002440 sec.
# 895-th simulation finished, 0.001375 sec.
# 896-th simulation finished, 0.001602 sec.
# 897-th simulation finished, 0.001405 sec.
# 898-th simulation finished, 0.001324 sec.
# 899-th simulation finished, 0.001576 sec.
# 900-th simulation finished, 0.001405 sec.
# 901-th simulation finished, 0.002076 sec.
# 902-th simulation finished, 0.003066 sec.
# 903-th simulation finished, 0.002904 sec.
# 904-th simulation finished, 0.002960 sec.
# 905-th simulation finished, 0.002540 sec.
# 906-th simulation finished, 0.001313 sec.
# 907-th simulation finished, 0.001182 sec.
# 908-th simulation finished, 0.001174 sec.
# 909-th simulation finished, 0.001182 sec.
# 910-th simulation finished, 0.003699 sec.
# 911-th simulation finished, 0.003624 sec.
# 912-th simulation finished, 0.002730 sec.
# 913-th simulation finished, 0.004040 sec.
# 914-th simulation finished, 0.002554 sec.
# 915-th simulation finished, 0.001436 sec.
# 916-th simulation finished, 0.003128 sec.
# 917-th simulation finished, 0.002962 sec.
# 918-th simulation finished, 0.003574 sec.
# 919-th simulation finished, 0.001756 sec.
# 920-th simulation finished, 0.001501 sec.
# 921-th simulation finished, 0.001669 sec.
# 922-th simulation finished, 0.003282 sec.
# 923-th simulation finished, 0.001265 sec.
# 924-th simulation finished, 0.003469 sec.
# 925-th simulation finished, 0.002392 sec.
# 926-th simulation finished, 0.001370 sec.
# 927-th simulation finished, 0.001416 sec.
# 928-th simulation finished, 0.001923 sec.
# 929-th simulation finished, 0.003788 sec.
# 930-th simulation finished, 0.002876 sec.
# 931-th simulation finished, 0.002867 sec.
# 932-th simulation finished, 0.001890 sec.
# 933-th simulation finished, 0.001388 sec.
# 934-th simulation finished, 0.010844 sec.
# 935-th simulation finished, 0.001618 sec.
# 936-th simulation finished, 0.001393 sec.
# 937-th simulation finished, 0.011108 sec.
# 938-th simulation finished, 0.001514 sec.
# 939-th simulation finished, 0.015389 sec.
# 940-th simulation finished, 0.001278 sec.
# 941-th simulation finished, 0.003113 sec.
# 942-th simulation finished, 0.001249 sec.
# 943-th simulation finished, 0.002813 sec.
# 944-th simulation finished, 0.001717 sec.
# 945-th simulation finished, 0.001374 sec.
# 946-th simulation finished, 0.003098 sec.
# 947-th simulation finished, 0.001484 sec.
# 948-th simulation finished, 0.001267 sec.
# 949-th simulation finished, 0.002251 sec.
# 950-th simulation finished, 0.003032 sec.
# 951-th simulation finished, 0.004431 sec.
# 952-th simulation finished, 0.003973 sec.
# 953-th simulation finished, 0.006530 sec.
# 954-th simulation finished, 0.001499 sec.
# 955-th simulation finished, 0.001274 sec.
# 956-th simulation finished, 0.001294 sec.
# 957-th simulation finished, 0.001347 sec.
# 958-th simulation finished, 0.001346 sec.
# 959-th simulation finished, 0.001351 sec.
# 960-th simulation finished, 0.001369 sec.
# 961-th simulation finished, 0.001273 sec.
# 962-th simulation finished, 0.001382 sec.
# 963-th simulation finished, 0.001300 sec.
# 964-th simulation finished, 0.001377 sec.
# 965-th simulation finished, 0.002608 sec.
# 966-th simulation finished, 0.004132 sec.
# 967-th simulation finished, 0.001348 sec.
# 968-th simulation finished, 0.001360 sec.
# 969-th simulation finished, 0.001910 sec.
# 970-th simulation finished, 0.001359 sec.
# 971-th simulation finished, 0.011366 sec.
# 972-th simulation finished, 0.001320 sec.
# 973-th simulation finished, 0.003303 sec.
# 974-th simulation finished, 0.003057 sec.
# 975-th simulation finished, 0.002850 sec.
# 976-th simulation finished, 0.001494 sec.
# 977-th simulation finished, 0.010107 sec.
# 978-th simulation finished, 0.001345 sec.
# 979-th simulation finished, 0.001366 sec.
# 980-th simulation finished, 0.001988 sec.
# 981-th simulation finished, 0.013898 sec.
# 982-th simulation finished, 0.001607 sec.
# 983-th simulation finished, 0.001312 sec.
# 984-th simulation finished, 0.001362 sec.
# 985-th simulation finished, 0.003641 sec.
# 986-th simulation finished, 0.002493 sec.
# 987-th simulation finished, 0.002873 sec.
# 988-th simulation finished, 0.001572 sec.
# 989-th simulation finished, 0.001321 sec.
# 990-th simulation finished, 0.001856 sec.
# 991-th simulation finished, 0.001329 sec.
# 992-th simulation finished, 0.001327 sec.
# 993-th simulation finished, 0.003025 sec.
# 994-th simulation finished, 0.001427 sec.
# 995-th simulation finished, 0.001271 sec.
# 996-th simulation finished, 0.003249 sec.
# 997-th simulation finished, 0.002932 sec.
# 998-th simulation finished, 0.002822 sec.
# 999-th simulation finished, 0.001561 sec.
# 1000-th simulation finished, 0.001338 sec.

# %%
plt.hist(bsim[:,1])
plt.axvline(beta[1], color='red')

# %%
stats.probplot(bsim[:,1], dist = 'norm', plot=plt, fit=True)
# plt.plot([0, 1], [0, 1], color='black')
plt.show()

# %%
plt.hist(Ts_dth)
# Out:
# (array([ 40., 154., 271., 241., 188.,  66.,  27.,  11.,   1.,   1.]),
#  array([-2.33053498, -1.59680967, -0.86308436, -0.12935905,  0.60436626,
#          1.33809157,  2.07181689,  2.8055422 ,  3.53926751,  4.27299282,
#          5.00671813]),
#  <BarContainer object of 10 artists>)

# %%
stats.probplot(ps_dth, dist = 'uniform', plot=plt, fit=False)
plt.plot([0, 1], [0, 1], color='black')
plt.show()

# %%
np.mean(np.abs(ps_dth) > 0.05)
# Out:
# 0.937

# %%
stats.probplot(ps_sdw, dist = 'uniform', plot=plt, fit=False)
plt.plot([0, 1], [0, 1], color='black')
plt.show()

# %%
np.mean(np.abs(ps_sdw) > 0.05)
# Out:
# 0.914
