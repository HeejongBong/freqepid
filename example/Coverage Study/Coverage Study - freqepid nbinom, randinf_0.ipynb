# %%
import os, importlib, sys, time

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import scipy.linalg as la
import scipy.stats as stats
import scipy.optimize as opt

# %%
import freqepid

# %% [markdown]
# # 1. parameters

# %%
T = 60
T0 = 40

# %%
GPi = np.load('data/GPi.npz')

# %% [markdown]
# ## observation parameters

# %%
alpha = 0.01
r_Y = 10

# %% [markdown]
# $$Y_t = NegBinom( \frac{EY_t}{r_Y + EY_t}, r_Y )$$
#
# $$ EY_t = \alpha\sum_{s=1}^{t-1} I_s \pi_{t-s} $$

# %% [markdown]
# ## latent parameters

# %%
d = 2
beta = np.array([0, -2.2])

# %%
r_I = 100
K = 6.5

# %% [markdown]
# $$I_t = NegBinom( \frac{EI_t}{r_I + EI_t}, r_I )$$
#
# $$ EI_t = R(\bar{A}_t, \beta) \sum_{s=1}^{t-1} I_s g_{t-s} $$
#
# $$R(\bar{A}_t, \beta) = \frac{K}{1+\exp(- \beta^\top A_t)}$$

# %% [markdown]
# ## seed values

# %%
mu = np.log(100)

# %% [markdown]
# $$I_{[-T_0,0)} = \exp(\mu_0)$$

# %% [markdown]
# # 2. simulation

# %%
num_sim = 1000

# %% [markdown]
# ## load simulation

# %%
data = pd.read_feather('data/simulation_randinf_0.feather')

# %%
data
# Out:
#        sim  date         R          EI  infection        EY  death  \
# 0        0     0  3.250000  324.997762      356.0  0.956069      0
# 1        0     1  3.250000  340.245831      298.0  0.962543      0
# 2        0     2  3.250000  392.196621      409.0  0.968283      0
# 3        0     3  3.250000  471.047829      545.0  0.973654      1
# 4        0     4  3.250000  581.900998      584.0  0.979752      4
# ...    ...   ...       ...         ...        ...       ...    ...
# 59995  999    55  0.648378  209.251090      218.0  9.330738     18
# 59996  999    56  0.648378  199.304639      232.0  8.838784      8
# 59997  999    57  0.648378  190.393661      212.0  8.368827      7
# 59998  999    58  0.648378  182.315811      204.0  7.916002      3
# 59999  999    59  0.648378  174.657976      191.0  7.484827      2
#
#        intervention
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 59995             1
# 59996             1
# 59997             1
# 59998             1
# 59999             1
#
# [60000 rows x 8 columns]

# %% [markdown]
# # 3. Fit

# %%
model = freqepid.Model(GPi['g'], GPi['pi'], alpha, K, T0, "nbinom")

# %%
nsim = np.zeros(num_sim)
msim = np.zeros(num_sim)
bsim = np.zeros((num_sim,d))

# %%
for iter_sim in np.arange(num_sim):
    start_sim = time.time()
    
    data_i = data[data['sim']==iter_sim]
    A = np.stack([np.full(T, 1), data_i["intervention"].to_numpy()], -1)
    Y = data_i["death"].to_numpy()
    
    # fit
    nmle, mmle, bmle, ll =\
    model.fit(A, Y, n_iter=500, step_size=1,
              history=False, verbose=False)
    
    nsim[iter_sim] = nmle
    msim[iter_sim] = mmle
    bsim[iter_sim,:] = bmle
    
    sys.__stdout__.write("%d-th simulation finished, %f sec.\n"
                         %(iter_sim+1, time.time()-start_sim))
    sys.__stdout__.flush()
# Out:
# /Users/blueconet/mambaforge/envs/freqepid/lib/python3.10/site-packages/freqepid/model.py:139: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   bhaty = np.linalg.lstsq(Xy, Yy)[0]
# 1-th simulation finished, 3.207591 sec.
# 2-th simulation finished, 2.886826 sec.
# 3-th simulation finished, 3.229105 sec.
# 4-th simulation finished, 2.536213 sec.
# 5-th simulation finished, 3.278325 sec.
# 6-th simulation finished, 3.420997 sec.
# 7-th simulation finished, 3.190036 sec.
# 8-th simulation finished, 2.993734 sec.
# 9-th simulation finished, 3.060336 sec.
# 10-th simulation finished, 3.561825 sec.
# 11-th simulation finished, 3.412987 sec.
# 12-th simulation finished, 2.698131 sec.
# 13-th simulation finished, 3.487646 sec.
# 14-th simulation finished, 3.295021 sec.
# 15-th simulation finished, 3.242963 sec.
# 16-th simulation finished, 3.288736 sec.
# 17-th simulation finished, 2.674552 sec.
# 18-th simulation finished, 3.051369 sec.
# 19-th simulation finished, 3.074528 sec.
# 20-th simulation finished, 3.089756 sec.
# 21-th simulation finished, 3.285767 sec.
# 22-th simulation finished, 3.307662 sec.
# 23-th simulation finished, 2.689852 sec.
# 24-th simulation finished, 3.235677 sec.
# 25-th simulation finished, 2.940841 sec.
# 26-th simulation finished, 3.174083 sec.
# 27-th simulation finished, 3.080221 sec.
# 28-th simulation finished, 3.060436 sec.
# 29-th simulation finished, 3.313430 sec.
# 30-th simulation finished, 3.045510 sec.
# 31-th simulation finished, 2.771619 sec.
# 32-th simulation finished, 3.046721 sec.
# 33-th simulation finished, 3.353383 sec.
# 34-th simulation finished, 3.041172 sec.
# 35-th simulation finished, 3.397566 sec.
# 36-th simulation finished, 2.863144 sec.
# 37-th simulation finished, 3.093508 sec.
# 38-th simulation finished, 2.846421 sec.
# 39-th simulation finished, 3.355183 sec.
# 40-th simulation finished, 3.395205 sec.
# 41-th simulation finished, 3.523758 sec.
# 42-th simulation finished, 3.535156 sec.
# 43-th simulation finished, 2.783585 sec.
# 44-th simulation finished, 3.506944 sec.
# 45-th simulation finished, 3.684944 sec.
# 46-th simulation finished, 3.022889 sec.
# 47-th simulation finished, 2.708129 sec.
# 48-th simulation finished, 2.615329 sec.
# 49-th simulation finished, 3.423061 sec.
# 50-th simulation finished, 2.943920 sec.
# 51-th simulation finished, 2.777062 sec.
# 52-th simulation finished, 3.337771 sec.
# 53-th simulation finished, 3.167890 sec.
# 54-th simulation finished, 3.144465 sec.
# 55-th simulation finished, 2.803821 sec.
# 56-th simulation finished, 3.161887 sec.
# 57-th simulation finished, 2.765965 sec.
# 58-th simulation finished, 3.185122 sec.
# 59-th simulation finished, 3.269571 sec.
# 60-th simulation finished, 3.044822 sec.
# 61-th simulation finished, 3.454445 sec.
# 62-th simulation finished, 3.476308 sec.
# 63-th simulation finished, 3.030459 sec.
# 64-th simulation finished, 3.363949 sec.
# 65-th simulation finished, 2.974708 sec.
# 66-th simulation finished, 3.182306 sec.
# 67-th simulation finished, 2.913349 sec.
# 68-th simulation finished, 2.618965 sec.
# 69-th simulation finished, 3.399763 sec.
# 70-th simulation finished, 3.294507 sec.
# 71-th simulation finished, 3.304349 sec.
# 72-th simulation finished, 3.327989 sec.
# 73-th simulation finished, 2.710802 sec.
# 74-th simulation finished, 2.848525 sec.
# 75-th simulation finished, 3.106659 sec.
# 76-th simulation finished, 2.750806 sec.
# 77-th simulation finished, 2.676687 sec.
# 78-th simulation finished, 3.202577 sec.
# 79-th simulation finished, 2.662193 sec.
# 80-th simulation finished, 3.233081 sec.
# 81-th simulation finished, 3.090654 sec.
# 82-th simulation finished, 2.571979 sec.
# 83-th simulation finished, 2.670921 sec.
# 84-th simulation finished, 3.462897 sec.
# 85-th simulation finished, 3.364338 sec.
# 86-th simulation finished, 3.344392 sec.
# 87-th simulation finished, 3.432339 sec.
# 88-th simulation finished, 3.337161 sec.
# 89-th simulation finished, 2.565696 sec.
# 90-th simulation finished, 3.259943 sec.
# 91-th simulation finished, 3.065813 sec.
# 92-th simulation finished, 3.108117 sec.
# 93-th simulation finished, 3.100508 sec.
# 94-th simulation finished, 3.273893 sec.
# 95-th simulation finished, 3.112842 sec.
# 96-th simulation finished, 3.167486 sec.
# 97-th simulation finished, 3.377629 sec.
# 98-th simulation finished, 3.227000 sec.
# 99-th simulation finished, 3.306428 sec.
# 100-th simulation finished, 3.217200 sec.
# 101-th simulation finished, 3.263410 sec.
# 102-th simulation finished, 2.755529 sec.
# 103-th simulation finished, 3.932797 sec.
# 104-th simulation finished, 3.312284 sec.
# 105-th simulation finished, 3.499015 sec.
# 106-th simulation finished, 2.754797 sec.
# 107-th simulation finished, 2.949661 sec.
# 108-th simulation finished, 2.733795 sec.
# 109-th simulation finished, 3.305439 sec.
# 110-th simulation finished, 3.125541 sec.
# 111-th simulation finished, 2.858972 sec.
# 112-th simulation finished, 3.581985 sec.
# 113-th simulation finished, 3.591070 sec.
# 114-th simulation finished, 3.147336 sec.
# 115-th simulation finished, 2.759074 sec.
# 116-th simulation finished, 3.215823 sec.
# 117-th simulation finished, 3.183845 sec.
# 118-th simulation finished, 3.037911 sec.
# 119-th simulation finished, 3.743044 sec.
# 120-th simulation finished, 3.566651 sec.
# 121-th simulation finished, 3.326197 sec.
# 122-th simulation finished, 3.196380 sec.
# 123-th simulation finished, 2.818709 sec.
# 124-th simulation finished, 2.634350 sec.
# 125-th simulation finished, 3.654611 sec.
# 126-th simulation finished, 3.338202 sec.
# 127-th simulation finished, 2.590426 sec.
# 128-th simulation finished, 2.950369 sec.
# 129-th simulation finished, 3.223876 sec.
# 130-th simulation finished, 3.194043 sec.
# 131-th simulation finished, 2.703397 sec.
# 132-th simulation finished, 2.748247 sec.
# 133-th simulation finished, 3.208187 sec.
# 134-th simulation finished, 3.165734 sec.
# 135-th simulation finished, 3.575015 sec.
# 136-th simulation finished, 2.799948 sec.
# 137-th simulation finished, 3.330261 sec.
# 138-th simulation finished, 3.672726 sec.
# 139-th simulation finished, 2.878579 sec.
# 140-th simulation finished, 2.744802 sec.
# 141-th simulation finished, 2.755179 sec.
# 142-th simulation finished, 2.693514 sec.
# 143-th simulation finished, 3.317627 sec.
# 144-th simulation finished, 3.239755 sec.
# 145-th simulation finished, 3.056632 sec.
# 146-th simulation finished, 3.081079 sec.
# 147-th simulation finished, 2.804540 sec.
# 148-th simulation finished, 3.477313 sec.
# 149-th simulation finished, 3.364203 sec.
# 150-th simulation finished, 2.798314 sec.
# 151-th simulation finished, 3.160951 sec.
# 152-th simulation finished, 3.207932 sec.
# 153-th simulation finished, 2.922842 sec.
# 154-th simulation finished, 2.820766 sec.
# 155-th simulation finished, 3.766990 sec.
# 156-th simulation finished, 3.369390 sec.
# 157-th simulation finished, 3.562282 sec.
# 158-th simulation finished, 3.253816 sec.
# 159-th simulation finished, 3.001396 sec.
# 160-th simulation finished, 3.424323 sec.
# 161-th simulation finished, 2.832747 sec.
# 162-th simulation finished, 2.831030 sec.
# 163-th simulation finished, 3.011873 sec.
# 164-th simulation finished, 2.891929 sec.
# 165-th simulation finished, 3.041604 sec.
# 166-th simulation finished, 3.006688 sec.
# 167-th simulation finished, 3.136706 sec.
# 168-th simulation finished, 3.295040 sec.
# 169-th simulation finished, 3.584810 sec.
# 170-th simulation finished, 3.533952 sec.
# 171-th simulation finished, 3.893789 sec.
# 172-th simulation finished, 3.349020 sec.
# 173-th simulation finished, 3.517523 sec.
# 174-th simulation finished, 3.714470 sec.
# 175-th simulation finished, 2.788234 sec.
# 176-th simulation finished, 3.533071 sec.
# 177-th simulation finished, 3.313692 sec.
# 178-th simulation finished, 3.253026 sec.
# 179-th simulation finished, 3.810627 sec.
# 180-th simulation finished, 3.247320 sec.
# 181-th simulation finished, 4.610647 sec.
# 182-th simulation finished, 3.578245 sec.
# 183-th simulation finished, 2.993159 sec.
# 184-th simulation finished, 3.297359 sec.
# 185-th simulation finished, 3.583856 sec.
# 186-th simulation finished, 2.775078 sec.
# 187-th simulation finished, 3.318755 sec.
# 188-th simulation finished, 2.938954 sec.
# 189-th simulation finished, 2.815252 sec.
# 190-th simulation finished, 2.915077 sec.
# 191-th simulation finished, 3.453113 sec.
# 192-th simulation finished, 3.273477 sec.
# 193-th simulation finished, 3.717300 sec.
# 194-th simulation finished, 3.355389 sec.
# 195-th simulation finished, 3.529751 sec.
# 196-th simulation finished, 2.967546 sec.
# 197-th simulation finished, 3.515872 sec.
# 198-th simulation finished, 3.680038 sec.
# 199-th simulation finished, 3.611660 sec.
# 200-th simulation finished, 3.387181 sec.
# 201-th simulation finished, 2.950369 sec.
# 202-th simulation finished, 2.977588 sec.
# 203-th simulation finished, 2.800814 sec.
# 204-th simulation finished, 3.128738 sec.
# 205-th simulation finished, 3.764420 sec.
# 206-th simulation finished, 3.389427 sec.
# 207-th simulation finished, 2.922995 sec.
# 208-th simulation finished, 3.017658 sec.
# 209-th simulation finished, 3.606963 sec.
# 210-th simulation finished, 3.347304 sec.
# 211-th simulation finished, 3.654157 sec.
# 212-th simulation finished, 3.267871 sec.
# 213-th simulation finished, 3.712173 sec.
# 214-th simulation finished, 3.024565 sec.
# 215-th simulation finished, 3.623927 sec.
# 216-th simulation finished, 3.108996 sec.
# 217-th simulation finished, 3.077946 sec.
# 218-th simulation finished, 2.959638 sec.
# 219-th simulation finished, 3.569108 sec.
# 220-th simulation finished, 2.958114 sec.
# 221-th simulation finished, 3.675394 sec.
# 222-th simulation finished, 3.180274 sec.
# 223-th simulation finished, 3.616671 sec.
# 224-th simulation finished, 3.615092 sec.
# 225-th simulation finished, 3.439609 sec.
# 226-th simulation finished, 3.338966 sec.
# 227-th simulation finished, 3.452334 sec.
# 228-th simulation finished, 4.141445 sec.
# 229-th simulation finished, 3.066315 sec.
# 230-th simulation finished, 2.957295 sec.
# 231-th simulation finished, 3.203491 sec.
# 232-th simulation finished, 2.867974 sec.
# 233-th simulation finished, 3.692351 sec.
# 234-th simulation finished, 2.901660 sec.
# 235-th simulation finished, 3.669932 sec.
# 236-th simulation finished, 3.367996 sec.
# 237-th simulation finished, 3.094499 sec.
# 238-th simulation finished, 3.482634 sec.
# 239-th simulation finished, 3.774798 sec.
# 240-th simulation finished, 3.672988 sec.
# 241-th simulation finished, 3.514954 sec.
# 242-th simulation finished, 2.883654 sec.
# 243-th simulation finished, 2.872005 sec.
# 244-th simulation finished, 3.500832 sec.
# 245-th simulation finished, 3.549118 sec.
# 246-th simulation finished, 4.851126 sec.
# 247-th simulation finished, 2.873446 sec.
# 248-th simulation finished, 2.891346 sec.
# 249-th simulation finished, 2.967571 sec.
# 250-th simulation finished, 3.347265 sec.
# 251-th simulation finished, 3.220776 sec.
# 252-th simulation finished, 3.404396 sec.
# 253-th simulation finished, 3.472482 sec.
# 254-th simulation finished, 3.421518 sec.
# 255-th simulation finished, 3.309375 sec.
# 256-th simulation finished, 3.614357 sec.
# 257-th simulation finished, 3.363956 sec.
# 258-th simulation finished, 3.412658 sec.
# 259-th simulation finished, 3.397000 sec.
# 260-th simulation finished, 3.325414 sec.
# 261-th simulation finished, 3.203713 sec.
# 262-th simulation finished, 3.549640 sec.
# 263-th simulation finished, 3.688072 sec.
# 264-th simulation finished, 3.364613 sec.
# 265-th simulation finished, 2.815499 sec.
# 266-th simulation finished, 3.029381 sec.
# 267-th simulation finished, 2.833472 sec.
# 268-th simulation finished, 3.436737 sec.
# 269-th simulation finished, 2.711421 sec.
# 270-th simulation finished, 3.991068 sec.
# 271-th simulation finished, 3.456615 sec.
# 272-th simulation finished, 3.284792 sec.
# 273-th simulation finished, 3.336824 sec.
# 274-th simulation finished, 2.909317 sec.
# 275-th simulation finished, 3.379898 sec.
# 276-th simulation finished, 2.870265 sec.
# 277-th simulation finished, 3.607013 sec.
# 278-th simulation finished, 3.314974 sec.
# 279-th simulation finished, 3.975607 sec.
# 280-th simulation finished, 2.918689 sec.
# 281-th simulation finished, 3.528514 sec.
# 282-th simulation finished, 3.325496 sec.
# 283-th simulation finished, 2.759039 sec.
# 284-th simulation finished, 3.411363 sec.
# 285-th simulation finished, 3.420374 sec.
# 286-th simulation finished, 3.488540 sec.
# 287-th simulation finished, 3.635778 sec.
# 288-th simulation finished, 3.464988 sec.
# 289-th simulation finished, 3.213487 sec.
# 290-th simulation finished, 3.388142 sec.
# 291-th simulation finished, 3.658978 sec.
# 292-th simulation finished, 3.134947 sec.
# 293-th simulation finished, 2.886216 sec.
# 294-th simulation finished, 3.203920 sec.
# 295-th simulation finished, 3.570091 sec.
# 296-th simulation finished, 3.254029 sec.
# 297-th simulation finished, 2.955683 sec.
# 298-th simulation finished, 3.368416 sec.
# 299-th simulation finished, 2.779234 sec.
# 300-th simulation finished, 2.910288 sec.
# 301-th simulation finished, 3.356644 sec.
# 302-th simulation finished, 2.900643 sec.
# 303-th simulation finished, 3.658176 sec.
# 304-th simulation finished, 2.987986 sec.
# 305-th simulation finished, 3.362156 sec.
# 306-th simulation finished, 3.481432 sec.
# 307-th simulation finished, 3.518348 sec.
# 308-th simulation finished, 3.209215 sec.
# 309-th simulation finished, 3.541329 sec.
# 310-th simulation finished, 3.141358 sec.
# 311-th simulation finished, 2.844282 sec.
# 312-th simulation finished, 3.665680 sec.
# 313-th simulation finished, 3.501542 sec.
# 314-th simulation finished, 3.461272 sec.
# 315-th simulation finished, 3.149352 sec.
# 316-th simulation finished, 3.339784 sec.
# 317-th simulation finished, 3.014768 sec.
# 318-th simulation finished, 3.268500 sec.
# 319-th simulation finished, 2.934484 sec.
# 320-th simulation finished, 3.354040 sec.
# 321-th simulation finished, 3.501369 sec.
# 322-th simulation finished, 3.272292 sec.
# 323-th simulation finished, 2.739268 sec.
# 324-th simulation finished, 3.281836 sec.
# 325-th simulation finished, 3.260798 sec.
# 326-th simulation finished, 2.724991 sec.
# 327-th simulation finished, 3.432261 sec.
# 328-th simulation finished, 3.376287 sec.
# 329-th simulation finished, 2.938853 sec.
# 330-th simulation finished, 2.765443 sec.
# 331-th simulation finished, 2.848940 sec.
# 332-th simulation finished, 3.152492 sec.
# 333-th simulation finished, 3.380485 sec.
# 334-th simulation finished, 3.268089 sec.
# 335-th simulation finished, 3.081713 sec.
# 336-th simulation finished, 2.833211 sec.
# 337-th simulation finished, 3.318083 sec.
# 338-th simulation finished, 2.841326 sec.
# 339-th simulation finished, 3.537793 sec.
# 340-th simulation finished, 3.053710 sec.
# 341-th simulation finished, 3.790315 sec.
# 342-th simulation finished, 3.193270 sec.
# 343-th simulation finished, 3.267826 sec.
# 344-th simulation finished, 3.299360 sec.
# 345-th simulation finished, 3.289773 sec.
# 346-th simulation finished, 2.848061 sec.
# 347-th simulation finished, 4.077539 sec.
# 348-th simulation finished, 3.030393 sec.
# 349-th simulation finished, 3.119369 sec.
# 350-th simulation finished, 2.930104 sec.
# 351-th simulation finished, 2.862740 sec.
# 352-th simulation finished, 3.235660 sec.
# 353-th simulation finished, 3.581624 sec.
# 354-th simulation finished, 3.364077 sec.
# 355-th simulation finished, 3.145030 sec.
# 356-th simulation finished, 3.209017 sec.
# 357-th simulation finished, 3.243505 sec.
# 358-th simulation finished, 3.388272 sec.
# 359-th simulation finished, 4.424847 sec.
# 360-th simulation finished, 3.250721 sec.
# 361-th simulation finished, 3.362665 sec.
# 362-th simulation finished, 3.448004 sec.
# 363-th simulation finished, 3.393926 sec.
# 364-th simulation finished, 3.258734 sec.
# 365-th simulation finished, 3.458780 sec.
# 366-th simulation finished, 3.164442 sec.
# 367-th simulation finished, 2.764225 sec.
# 368-th simulation finished, 3.380292 sec.
# 369-th simulation finished, 3.427820 sec.
# 370-th simulation finished, 3.218764 sec.
# 371-th simulation finished, 3.290301 sec.
# 372-th simulation finished, 3.281849 sec.
# 373-th simulation finished, 3.147032 sec.
# 374-th simulation finished, 3.659629 sec.
# 375-th simulation finished, 3.053598 sec.
# 376-th simulation finished, 3.469902 sec.
# 377-th simulation finished, 3.495202 sec.
# 378-th simulation finished, 3.197761 sec.
# 379-th simulation finished, 3.033140 sec.
# 380-th simulation finished, 3.396788 sec.
# 381-th simulation finished, 3.448031 sec.
# 382-th simulation finished, 3.100805 sec.
# 383-th simulation finished, 3.276295 sec.
# 384-th simulation finished, 2.865722 sec.
# 385-th simulation finished, 3.162316 sec.
# 386-th simulation finished, 3.409164 sec.
# 387-th simulation finished, 3.400178 sec.
# 388-th simulation finished, 3.229531 sec.
# 389-th simulation finished, 3.622371 sec.
# 390-th simulation finished, 3.269825 sec.
# 391-th simulation finished, 3.530510 sec.
# 392-th simulation finished, 3.129136 sec.
# 393-th simulation finished, 3.441687 sec.
# 394-th simulation finished, 3.444970 sec.
# 395-th simulation finished, 2.848146 sec.
# 396-th simulation finished, 2.875887 sec.
# 397-th simulation finished, 3.436606 sec.
# 398-th simulation finished, 2.894337 sec.
# 399-th simulation finished, 2.885524 sec.
# 400-th simulation finished, 3.174053 sec.
# 401-th simulation finished, 2.715612 sec.
# 402-th simulation finished, 2.817306 sec.
# 403-th simulation finished, 3.751151 sec.
# 404-th simulation finished, 2.877082 sec.
# 405-th simulation finished, 3.453816 sec.
# 406-th simulation finished, 3.482948 sec.
# 407-th simulation finished, 3.278701 sec.
# 408-th simulation finished, 3.067937 sec.
# 409-th simulation finished, 2.919342 sec.
# 410-th simulation finished, 2.827535 sec.
# 411-th simulation finished, 3.244229 sec.
# 412-th simulation finished, 2.928441 sec.
# 413-th simulation finished, 3.429803 sec.
# 414-th simulation finished, 3.504979 sec.
# 415-th simulation finished, 2.886474 sec.
# 416-th simulation finished, 3.280426 sec.
# 417-th simulation finished, 3.119630 sec.
# 418-th simulation finished, 3.501034 sec.
# 419-th simulation finished, 3.155276 sec.
# 420-th simulation finished, 2.912356 sec.
# 421-th simulation finished, 3.144989 sec.
# 422-th simulation finished, 3.398317 sec.
# 423-th simulation finished, 3.096432 sec.
# 424-th simulation finished, 3.709799 sec.
# 425-th simulation finished, 3.482804 sec.
# 426-th simulation finished, 2.911342 sec.
# 427-th simulation finished, 2.767803 sec.
# 428-th simulation finished, 2.731363 sec.
# 429-th simulation finished, 2.991587 sec.
# 430-th simulation finished, 3.242839 sec.
# 431-th simulation finished, 4.438960 sec.
# 432-th simulation finished, 3.026808 sec.
# 433-th simulation finished, 3.371599 sec.
# 434-th simulation finished, 3.433245 sec.
# 435-th simulation finished, 3.203064 sec.
# 436-th simulation finished, 2.929872 sec.
# 437-th simulation finished, 2.689864 sec.
# 438-th simulation finished, 3.507037 sec.
# 439-th simulation finished, 3.338416 sec.
# 440-th simulation finished, 2.959853 sec.
# 441-th simulation finished, 3.454925 sec.
# 442-th simulation finished, 3.580282 sec.
# 443-th simulation finished, 3.396415 sec.
# 444-th simulation finished, 3.323267 sec.
# 445-th simulation finished, 2.722584 sec.
# 446-th simulation finished, 3.426384 sec.
# 447-th simulation finished, 2.910683 sec.
# 448-th simulation finished, 3.682600 sec.
# 449-th simulation finished, 2.890116 sec.
# 450-th simulation finished, 2.962069 sec.
# 451-th simulation finished, 3.823927 sec.
# 452-th simulation finished, 3.488704 sec.
# 453-th simulation finished, 3.976353 sec.
# 454-th simulation finished, 2.935994 sec.
# 455-th simulation finished, 3.733987 sec.
# 456-th simulation finished, 3.485076 sec.
# 457-th simulation finished, 3.483806 sec.
# 458-th simulation finished, 2.916478 sec.
# 459-th simulation finished, 2.923941 sec.
# 460-th simulation finished, 3.417747 sec.
# 461-th simulation finished, 3.649717 sec.
# 462-th simulation finished, 3.025430 sec.
# 463-th simulation finished, 3.247101 sec.
# 464-th simulation finished, 3.685848 sec.
# 465-th simulation finished, 3.347916 sec.
# 466-th simulation finished, 2.932586 sec.
# 467-th simulation finished, 3.274409 sec.
# 468-th simulation finished, 3.328070 sec.
# 469-th simulation finished, 2.770695 sec.
# 470-th simulation finished, 3.914220 sec.
# 471-th simulation finished, 3.232080 sec.
# 472-th simulation finished, 3.377939 sec.
# 473-th simulation finished, 3.676363 sec.
# 474-th simulation finished, 3.030578 sec.
# 475-th simulation finished, 3.372539 sec.
# 476-th simulation finished, 3.410593 sec.
# 477-th simulation finished, 2.906242 sec.
# 478-th simulation finished, 3.206635 sec.
# 479-th simulation finished, 3.422074 sec.
# 480-th simulation finished, 2.944629 sec.
# 481-th simulation finished, 3.510044 sec.
# 482-th simulation finished, 3.278234 sec.
# 483-th simulation finished, 2.888226 sec.
# 484-th simulation finished, 3.302860 sec.
# 485-th simulation finished, 2.914509 sec.
# 486-th simulation finished, 3.570948 sec.
# 487-th simulation finished, 3.040556 sec.
# 488-th simulation finished, 3.620967 sec.
# 489-th simulation finished, 3.479665 sec.
# 490-th simulation finished, 2.889448 sec.
# 491-th simulation finished, 3.056880 sec.
# 492-th simulation finished, 3.145294 sec.
# 493-th simulation finished, 2.910363 sec.
# 494-th simulation finished, 2.868119 sec.
# 495-th simulation finished, 3.527954 sec.
# 496-th simulation finished, 3.490924 sec.
# 497-th simulation finished, 3.873452 sec.
# 498-th simulation finished, 3.249555 sec.
# 499-th simulation finished, 3.408243 sec.
# 500-th simulation finished, 3.098861 sec.
# 501-th simulation finished, 3.162145 sec.
# 502-th simulation finished, 2.929348 sec.
# 503-th simulation finished, 3.785508 sec.
# 504-th simulation finished, 2.713664 sec.
# 505-th simulation finished, 2.913393 sec.
# 506-th simulation finished, 3.437434 sec.
# 507-th simulation finished, 3.438774 sec.
# 508-th simulation finished, 3.325647 sec.
# 509-th simulation finished, 3.353081 sec.
# 510-th simulation finished, 3.554811 sec.
# 511-th simulation finished, 3.663749 sec.
# 512-th simulation finished, 3.244075 sec.
# 513-th simulation finished, 3.194954 sec.
# 514-th simulation finished, 2.913432 sec.
# 515-th simulation finished, 3.325952 sec.
# 516-th simulation finished, 2.962253 sec.
# 517-th simulation finished, 3.498213 sec.
# 518-th simulation finished, 3.420003 sec.
# 519-th simulation finished, 3.892352 sec.
# 520-th simulation finished, 3.088622 sec.
# 521-th simulation finished, 2.937191 sec.
# 522-th simulation finished, 3.449535 sec.
# 523-th simulation finished, 3.437390 sec.
# 524-th simulation finished, 3.640778 sec.
# 525-th simulation finished, 3.241346 sec.
# 526-th simulation finished, 11.073629 sec.
# 527-th simulation finished, 2.778856 sec.
# 528-th simulation finished, 3.347987 sec.
# 529-th simulation finished, 2.972195 sec.
# 530-th simulation finished, 3.455937 sec.
# 531-th simulation finished, 3.718562 sec.
# 532-th simulation finished, 3.328877 sec.
# 533-th simulation finished, 2.935285 sec.
# 534-th simulation finished, 3.411916 sec.
# 535-th simulation finished, 3.293188 sec.
# 536-th simulation finished, 3.507361 sec.
# 537-th simulation finished, 3.517628 sec.
# 538-th simulation finished, 3.690135 sec.
# 539-th simulation finished, 2.865220 sec.
# 540-th simulation finished, 3.550055 sec.
# 541-th simulation finished, 2.878543 sec.
# 542-th simulation finished, 3.547420 sec.
# 543-th simulation finished, 2.981844 sec.
# 544-th simulation finished, 3.359284 sec.
# 545-th simulation finished, 3.985883 sec.
# 546-th simulation finished, 2.931259 sec.
# 547-th simulation finished, 3.416027 sec.
# 548-th simulation finished, 3.297591 sec.
# 549-th simulation finished, 3.755502 sec.
# 550-th simulation finished, 2.922789 sec.
# 551-th simulation finished, 3.558686 sec.
# 552-th simulation finished, 2.960887 sec.
# 553-th simulation finished, 2.794064 sec.
# 554-th simulation finished, 3.339659 sec.
# 555-th simulation finished, 3.356609 sec.
# 556-th simulation finished, 2.943356 sec.
# 557-th simulation finished, 3.229712 sec.
# 558-th simulation finished, 2.935325 sec.
# 559-th simulation finished, 3.298340 sec.
# 560-th simulation finished, 3.299790 sec.
# 561-th simulation finished, 3.249933 sec.
# 562-th simulation finished, 3.606908 sec.
# 563-th simulation finished, 3.352612 sec.
# 564-th simulation finished, 3.493066 sec.
# 565-th simulation finished, 3.162891 sec.
# 566-th simulation finished, 2.882628 sec.
# 567-th simulation finished, 3.030275 sec.
# 568-th simulation finished, 3.248207 sec.
# 569-th simulation finished, 3.537957 sec.
# 570-th simulation finished, 3.558522 sec.
# 571-th simulation finished, 3.310087 sec.
# 572-th simulation finished, 3.610874 sec.
# 573-th simulation finished, 3.454581 sec.
# 574-th simulation finished, 3.292974 sec.
# 575-th simulation finished, 2.981438 sec.
# 576-th simulation finished, 3.512844 sec.
# 577-th simulation finished, 3.531941 sec.
# 578-th simulation finished, 3.515869 sec.
# 579-th simulation finished, 3.497458 sec.
# 580-th simulation finished, 3.328364 sec.
# 581-th simulation finished, 3.192388 sec.
# 582-th simulation finished, 3.503308 sec.
# 583-th simulation finished, 2.906396 sec.
# 584-th simulation finished, 4.376744 sec.
# 585-th simulation finished, 3.365199 sec.
# 586-th simulation finished, 2.772452 sec.
# 587-th simulation finished, 3.318110 sec.
# 588-th simulation finished, 2.880145 sec.
# 589-th simulation finished, 3.328407 sec.
# 590-th simulation finished, 3.228838 sec.
# 591-th simulation finished, 3.444244 sec.
# 592-th simulation finished, 2.954242 sec.
# 593-th simulation finished, 3.676497 sec.
# 594-th simulation finished, 2.906461 sec.
# 595-th simulation finished, 2.877835 sec.
# 596-th simulation finished, 3.404806 sec.
# 597-th simulation finished, 3.448670 sec.
# 598-th simulation finished, 3.619403 sec.
# 599-th simulation finished, 2.886819 sec.
# 600-th simulation finished, 3.334427 sec.
# 601-th simulation finished, 2.861333 sec.
# 602-th simulation finished, 3.411360 sec.
# 603-th simulation finished, 3.286740 sec.
# 604-th simulation finished, 3.082814 sec.
# 605-th simulation finished, 4.119035 sec.
# 606-th simulation finished, 3.300380 sec.
# 607-th simulation finished, 3.534528 sec.
# 608-th simulation finished, 3.196434 sec.
# 609-th simulation finished, 3.442315 sec.
# 610-th simulation finished, 3.163917 sec.
# 611-th simulation finished, 2.729961 sec.
# 612-th simulation finished, 3.219135 sec.
# 613-th simulation finished, 3.000541 sec.
# 614-th simulation finished, 2.742869 sec.
# 615-th simulation finished, 3.467940 sec.
# 616-th simulation finished, 3.325905 sec.
# 617-th simulation finished, 3.532784 sec.
# 618-th simulation finished, 2.910846 sec.
# 619-th simulation finished, 2.729031 sec.
# 620-th simulation finished, 3.488539 sec.
# 621-th simulation finished, 3.069773 sec.
# 622-th simulation finished, 3.570026 sec.
# 623-th simulation finished, 3.300019 sec.
# 624-th simulation finished, 3.853881 sec.
# 625-th simulation finished, 3.162874 sec.
# 626-th simulation finished, 3.542790 sec.
# 627-th simulation finished, 3.455432 sec.
# 628-th simulation finished, 3.271765 sec.
# 629-th simulation finished, 2.913209 sec.
# 630-th simulation finished, 3.272292 sec.
# 631-th simulation finished, 3.232904 sec.
# 632-th simulation finished, 3.607066 sec.
# 633-th simulation finished, 3.624749 sec.
# 634-th simulation finished, 3.085647 sec.
# 635-th simulation finished, 3.533436 sec.
# 636-th simulation finished, 2.704658 sec.
# 637-th simulation finished, 3.516629 sec.
# 638-th simulation finished, 2.943150 sec.
# 639-th simulation finished, 3.221438 sec.
# 640-th simulation finished, 3.637278 sec.
# 641-th simulation finished, 3.223011 sec.
# 642-th simulation finished, 2.921478 sec.
# 643-th simulation finished, 2.850836 sec.
# 644-th simulation finished, 3.656101 sec.
# 645-th simulation finished, 3.034999 sec.
# 646-th simulation finished, 3.103166 sec.
# 647-th simulation finished, 3.269989 sec.
# 648-th simulation finished, 3.305543 sec.
# 649-th simulation finished, 3.438711 sec.
# 650-th simulation finished, 4.056696 sec.
# 651-th simulation finished, 3.136745 sec.
# 652-th simulation finished, 3.389403 sec.
# 653-th simulation finished, 2.952222 sec.
# 654-th simulation finished, 3.252130 sec.
# 655-th simulation finished, 3.908424 sec.
# 656-th simulation finished, 4.101313 sec.
# 657-th simulation finished, 2.857175 sec.
# 658-th simulation finished, 3.798051 sec.
# 659-th simulation finished, 2.826689 sec.
# 660-th simulation finished, 3.310990 sec.
# 661-th simulation finished, 3.003359 sec.
# 662-th simulation finished, 3.269703 sec.
# 663-th simulation finished, 3.226533 sec.
# 664-th simulation finished, 3.578493 sec.
# 665-th simulation finished, 3.451224 sec.
# 666-th simulation finished, 3.148429 sec.
# 667-th simulation finished, 3.527725 sec.
# 668-th simulation finished, 3.587041 sec.
# 669-th simulation finished, 3.311623 sec.
# 670-th simulation finished, 2.894388 sec.
# 671-th simulation finished, 3.876374 sec.
# 672-th simulation finished, 3.244996 sec.
# 673-th simulation finished, 3.208737 sec.
# 674-th simulation finished, 3.543123 sec.
# 675-th simulation finished, 2.863615 sec.
# 676-th simulation finished, 3.507930 sec.
# 677-th simulation finished, 3.364197 sec.
# 678-th simulation finished, 3.370221 sec.
# 679-th simulation finished, 3.437309 sec.
# 680-th simulation finished, 3.281081 sec.
# 681-th simulation finished, 2.930891 sec.
# 682-th simulation finished, 3.425343 sec.
# 683-th simulation finished, 3.080874 sec.
# 684-th simulation finished, 3.375549 sec.
# 685-th simulation finished, 3.521479 sec.
# 686-th simulation finished, 3.804594 sec.
# 687-th simulation finished, 3.215465 sec.
# 688-th simulation finished, 2.880681 sec.
# 689-th simulation finished, 3.580935 sec.
# 690-th simulation finished, 3.714489 sec.
# 691-th simulation finished, 3.587647 sec.
# 692-th simulation finished, 3.063388 sec.
# 693-th simulation finished, 2.877078 sec.
# 694-th simulation finished, 3.543283 sec.
# 695-th simulation finished, 2.970294 sec.
# 696-th simulation finished, 3.246839 sec.
# 697-th simulation finished, 2.802163 sec.
# 698-th simulation finished, 3.406818 sec.
# 699-th simulation finished, 2.937236 sec.
# 700-th simulation finished, 3.365785 sec.
# 701-th simulation finished, 2.994598 sec.
# 702-th simulation finished, 2.875882 sec.
# 703-th simulation finished, 3.439739 sec.
# 704-th simulation finished, 3.639577 sec.
# 705-th simulation finished, 2.920555 sec.
# 706-th simulation finished, 3.493733 sec.
# 707-th simulation finished, 3.274757 sec.
# 708-th simulation finished, 3.380910 sec.
# 709-th simulation finished, 2.963623 sec.
# 710-th simulation finished, 3.355670 sec.
# 711-th simulation finished, 3.451260 sec.
# 712-th simulation finished, 2.920556 sec.
# 713-th simulation finished, 2.845854 sec.
# 714-th simulation finished, 2.870384 sec.
# 715-th simulation finished, 2.707454 sec.
# 716-th simulation finished, 2.887597 sec.
# 717-th simulation finished, 3.205369 sec.
# 718-th simulation finished, 3.511579 sec.
# 719-th simulation finished, 3.692232 sec.
# 720-th simulation finished, 2.806989 sec.
# 721-th simulation finished, 2.876134 sec.
# 722-th simulation finished, 3.531539 sec.
# 723-th simulation finished, 2.739408 sec.
# 724-th simulation finished, 3.267266 sec.
# 725-th simulation finished, 3.375116 sec.
# 726-th simulation finished, 3.462956 sec.
# 727-th simulation finished, 3.323368 sec.
# 728-th simulation finished, 3.320825 sec.
# 729-th simulation finished, 3.115976 sec.
# 730-th simulation finished, 2.873873 sec.
# 731-th simulation finished, 10.075998 sec.
# 732-th simulation finished, 3.582908 sec.
# 733-th simulation finished, 3.833007 sec.
# 734-th simulation finished, 3.407880 sec.
# 735-th simulation finished, 3.303666 sec.
# 736-th simulation finished, 2.915231 sec.
# 737-th simulation finished, 3.554176 sec.
# 738-th simulation finished, 3.165009 sec.
# 739-th simulation finished, 3.109763 sec.
# 740-th simulation finished, 3.210565 sec.
# 741-th simulation finished, 3.200438 sec.
# 742-th simulation finished, 2.795091 sec.
# 743-th simulation finished, 2.967282 sec.
# 744-th simulation finished, 3.440624 sec.
# 745-th simulation finished, 3.584879 sec.
# 746-th simulation finished, 2.852878 sec.
# 747-th simulation finished, 3.298015 sec.
# 748-th simulation finished, 3.512112 sec.
# 749-th simulation finished, 3.203258 sec.
# 750-th simulation finished, 2.887987 sec.
# 751-th simulation finished, 3.376155 sec.
# 752-th simulation finished, 3.189644 sec.
# 753-th simulation finished, 3.313503 sec.
# 754-th simulation finished, 3.466890 sec.
# 755-th simulation finished, 3.484615 sec.
# 756-th simulation finished, 2.925334 sec.
# 757-th simulation finished, 2.949122 sec.
# 758-th simulation finished, 3.325216 sec.
# 759-th simulation finished, 3.528060 sec.
# 760-th simulation finished, 3.166958 sec.
# 761-th simulation finished, 2.879830 sec.
# 762-th simulation finished, 3.664944 sec.
# 763-th simulation finished, 2.901467 sec.
# 764-th simulation finished, 2.924749 sec.
# 765-th simulation finished, 3.303151 sec.
# 766-th simulation finished, 3.639143 sec.
# 767-th simulation finished, 3.251092 sec.
# 768-th simulation finished, 2.716932 sec.
# 769-th simulation finished, 3.436227 sec.
# 770-th simulation finished, 2.983840 sec.
# 771-th simulation finished, 2.918669 sec.
# 772-th simulation finished, 3.595158 sec.
# 773-th simulation finished, 2.866843 sec.
# 774-th simulation finished, 3.515843 sec.
# 775-th simulation finished, 2.859683 sec.
# 776-th simulation finished, 3.206700 sec.
# 777-th simulation finished, 2.900103 sec.
# 778-th simulation finished, 3.294342 sec.
# 779-th simulation finished, 3.235764 sec.
# 780-th simulation finished, 2.976215 sec.
# 781-th simulation finished, 3.503237 sec.
# 782-th simulation finished, 3.196320 sec.
# 783-th simulation finished, 3.397198 sec.
# 784-th simulation finished, 2.884616 sec.
# 785-th simulation finished, 2.968694 sec.
# 786-th simulation finished, 3.454000 sec.
# 787-th simulation finished, 3.366220 sec.
# 788-th simulation finished, 3.293890 sec.
# 789-th simulation finished, 3.576150 sec.
# 790-th simulation finished, 2.810743 sec.
# 791-th simulation finished, 3.286238 sec.
# 792-th simulation finished, 3.424606 sec.
# 793-th simulation finished, 3.206124 sec.
# 794-th simulation finished, 3.453819 sec.
# 795-th simulation finished, 3.280991 sec.
# 796-th simulation finished, 2.845769 sec.
# 797-th simulation finished, 3.318700 sec.
# 798-th simulation finished, 3.473662 sec.
# 799-th simulation finished, 3.509158 sec.
# 800-th simulation finished, 2.836489 sec.
# 801-th simulation finished, 3.346122 sec.
# 802-th simulation finished, 3.404031 sec.
# 803-th simulation finished, 3.524740 sec.
# 804-th simulation finished, 3.299612 sec.
# 805-th simulation finished, 3.260937 sec.
# 806-th simulation finished, 3.027536 sec.
# 807-th simulation finished, 3.491748 sec.
# 808-th simulation finished, 3.239363 sec.
# 809-th simulation finished, 3.649014 sec.
# 810-th simulation finished, 3.853344 sec.
# 811-th simulation finished, 3.352257 sec.
# 812-th simulation finished, 3.766230 sec.
# 813-th simulation finished, 2.727164 sec.
# 814-th simulation finished, 3.827720 sec.
# 815-th simulation finished, 3.592731 sec.
# 816-th simulation finished, 3.453342 sec.
# 817-th simulation finished, 3.029501 sec.
# 818-th simulation finished, 3.448613 sec.
# 819-th simulation finished, 3.582080 sec.
# 820-th simulation finished, 3.255795 sec.
# 821-th simulation finished, 3.075495 sec.
# 822-th simulation finished, 3.618426 sec.
# 823-th simulation finished, 2.912386 sec.
# 824-th simulation finished, 2.896995 sec.
# 825-th simulation finished, 3.290601 sec.
# 826-th simulation finished, 3.816474 sec.
# 827-th simulation finished, 2.836652 sec.
# 828-th simulation finished, 2.833286 sec.
# 829-th simulation finished, 3.871950 sec.
# 830-th simulation finished, 2.903737 sec.
# 831-th simulation finished, 3.431030 sec.
# 832-th simulation finished, 2.905968 sec.
# 833-th simulation finished, 3.362878 sec.
# 834-th simulation finished, 3.486632 sec.
# 835-th simulation finished, 3.575779 sec.
# 836-th simulation finished, 2.829698 sec.
# 837-th simulation finished, 3.234572 sec.
# 838-th simulation finished, 3.470505 sec.
# 839-th simulation finished, 3.579150 sec.
# 840-th simulation finished, 2.812211 sec.
# 841-th simulation finished, 3.442047 sec.
# 842-th simulation finished, 3.344528 sec.
# 843-th simulation finished, 2.929338 sec.
# 844-th simulation finished, 3.341008 sec.
# 845-th simulation finished, 3.320882 sec.
# 846-th simulation finished, 3.643774 sec.
# 847-th simulation finished, 3.459970 sec.
# 848-th simulation finished, 2.831495 sec.
# 849-th simulation finished, 3.187786 sec.
# 850-th simulation finished, 3.314918 sec.
# 851-th simulation finished, 2.780155 sec.
# 852-th simulation finished, 3.280887 sec.
# 853-th simulation finished, 3.498211 sec.
# 854-th simulation finished, 3.459017 sec.
# 855-th simulation finished, 3.113661 sec.
# 856-th simulation finished, 3.568485 sec.
# 857-th simulation finished, 3.362377 sec.
# 858-th simulation finished, 3.250925 sec.
# 859-th simulation finished, 3.250560 sec.
# 860-th simulation finished, 3.021653 sec.
# 861-th simulation finished, 3.507291 sec.
# 862-th simulation finished, 2.924128 sec.
# 863-th simulation finished, 3.296177 sec.
# 864-th simulation finished, 3.291267 sec.
# 865-th simulation finished, 3.019021 sec.
# 866-th simulation finished, 3.667244 sec.
# 867-th simulation finished, 3.186666 sec.
# 868-th simulation finished, 2.667806 sec.
# 869-th simulation finished, 2.903401 sec.
# 870-th simulation finished, 2.952393 sec.
# 871-th simulation finished, 3.350075 sec.
# 872-th simulation finished, 3.757024 sec.
# 873-th simulation finished, 3.340192 sec.
# 874-th simulation finished, 3.176064 sec.
# 875-th simulation finished, 2.882325 sec.
# 876-th simulation finished, 3.470659 sec.
# 877-th simulation finished, 3.526540 sec.
# 878-th simulation finished, 3.297838 sec.
# 879-th simulation finished, 2.797130 sec.
# 880-th simulation finished, 2.848615 sec.
# 881-th simulation finished, 2.955040 sec.
# 882-th simulation finished, 3.912852 sec.
# 883-th simulation finished, 2.870108 sec.
# 884-th simulation finished, 3.495992 sec.
# 885-th simulation finished, 3.269421 sec.
# 886-th simulation finished, 3.510888 sec.
# 887-th simulation finished, 4.032387 sec.
# 888-th simulation finished, 3.339638 sec.
# 889-th simulation finished, 3.532534 sec.
# 890-th simulation finished, 2.900151 sec.
# 891-th simulation finished, 3.087802 sec.
# 892-th simulation finished, 3.554846 sec.
# 893-th simulation finished, 2.858254 sec.
# 894-th simulation finished, 3.264365 sec.
# 895-th simulation finished, 3.210155 sec.
# 896-th simulation finished, 3.190692 sec.
# 897-th simulation finished, 3.394093 sec.
# 898-th simulation finished, 3.337051 sec.
# 899-th simulation finished, 3.363559 sec.
# 900-th simulation finished, 4.345123 sec.
# 901-th simulation finished, 2.856637 sec.
# 902-th simulation finished, 3.715765 sec.
# 903-th simulation finished, 3.252674 sec.
# 904-th simulation finished, 3.499880 sec.
# 905-th simulation finished, 3.445277 sec.
# 906-th simulation finished, 3.906896 sec.
# 907-th simulation finished, 3.379466 sec.
# 908-th simulation finished, 2.990177 sec.
# 909-th simulation finished, 2.875026 sec.
# 910-th simulation finished, 3.580427 sec.
# 911-th simulation finished, 3.538666 sec.
# 912-th simulation finished, 3.199655 sec.
# 913-th simulation finished, 4.262162 sec.
# 914-th simulation finished, 2.899320 sec.
# 915-th simulation finished, 3.883032 sec.
# 916-th simulation finished, 2.841573 sec.
# 917-th simulation finished, 3.670165 sec.
# 918-th simulation finished, 3.620068 sec.
# 919-th simulation finished, 3.121163 sec.
# 920-th simulation finished, 3.643955 sec.
# 921-th simulation finished, 2.717444 sec.
# 922-th simulation finished, 3.276168 sec.
# 923-th simulation finished, 3.301486 sec.
# 924-th simulation finished, 3.377746 sec.
# 925-th simulation finished, 3.152360 sec.
# 926-th simulation finished, 3.528500 sec.
# 927-th simulation finished, 3.375155 sec.
# 928-th simulation finished, 3.267338 sec.
# 929-th simulation finished, 3.835191 sec.
# 930-th simulation finished, 2.830150 sec.
# 931-th simulation finished, 3.359048 sec.
# 932-th simulation finished, 3.226628 sec.
# 933-th simulation finished, 3.060532 sec.
# 934-th simulation finished, 2.919444 sec.
# 935-th simulation finished, 3.360799 sec.
# 936-th simulation finished, 3.865054 sec.
# 937-th simulation finished, 3.286772 sec.
# 938-th simulation finished, 3.302690 sec.
# 939-th simulation finished, 3.451089 sec.
# 940-th simulation finished, 3.371485 sec.
# 941-th simulation finished, 3.448813 sec.
# 942-th simulation finished, 3.567808 sec.
# 943-th simulation finished, 3.579081 sec.
# 944-th simulation finished, 3.518994 sec.
# 945-th simulation finished, 2.732338 sec.
# 946-th simulation finished, 3.625628 sec.
# 947-th simulation finished, 2.993278 sec.
# 948-th simulation finished, 10.866799 sec.
# 949-th simulation finished, 2.932344 sec.
# 950-th simulation finished, 3.116811 sec.
# 951-th simulation finished, 3.512094 sec.
# 952-th simulation finished, 2.983845 sec.
# 953-th simulation finished, 2.786473 sec.
# 954-th simulation finished, 3.337748 sec.
# 955-th simulation finished, 2.874728 sec.
# 956-th simulation finished, 3.551191 sec.
# 957-th simulation finished, 2.858488 sec.
# 958-th simulation finished, 2.866803 sec.
# 959-th simulation finished, 3.496414 sec.
# 960-th simulation finished, 2.761505 sec.
# 961-th simulation finished, 3.843274 sec.
# 962-th simulation finished, 3.194269 sec.
# 963-th simulation finished, 3.821419 sec.
# 964-th simulation finished, 3.179605 sec.
# 965-th simulation finished, 3.483964 sec.
# 966-th simulation finished, 2.927597 sec.
# 967-th simulation finished, 3.492502 sec.
# 968-th simulation finished, 3.604906 sec.
# 969-th simulation finished, 3.575708 sec.
# 970-th simulation finished, 3.307168 sec.
# 971-th simulation finished, 2.955905 sec.
# 972-th simulation finished, 2.881345 sec.
# 973-th simulation finished, 2.812363 sec.
# 974-th simulation finished, 3.247096 sec.
# 975-th simulation finished, 2.874483 sec.
# 976-th simulation finished, 3.035894 sec.
# 977-th simulation finished, 3.496656 sec.
# 978-th simulation finished, 3.341222 sec.
# 979-th simulation finished, 3.088805 sec.
# 980-th simulation finished, 3.040037 sec.
# 981-th simulation finished, 3.281155 sec.
# 982-th simulation finished, 2.877989 sec.
# 983-th simulation finished, 3.335141 sec.
# 984-th simulation finished, 2.894568 sec.
# 985-th simulation finished, 3.489846 sec.
# 986-th simulation finished, 3.320444 sec.
# 987-th simulation finished, 3.436072 sec.
# 988-th simulation finished, 3.536063 sec.
# 989-th simulation finished, 3.330470 sec.
# 990-th simulation finished, 3.320222 sec.
# 991-th simulation finished, 3.319110 sec.
# 992-th simulation finished, 3.343635 sec.
# 993-th simulation finished, 2.997745 sec.
# 994-th simulation finished, 3.338163 sec.
# 995-th simulation finished, 3.198262 sec.
# 996-th simulation finished, 3.874710 sec.
# 997-th simulation finished, 3.196933 sec.
# 998-th simulation finished, 3.247574 sec.
# 999-th simulation finished, 3.525508 sec.
# 1000-th simulation finished, 2.782616 sec.

# %%
# np.savez('coverage_freqepid_nbinom_randinf_0.npz',
#          nsim = nsim, msim = msim, bsim = bsim)

# %% [markdown]
# # 4. Wald's Confidence Region Coverage Test

# %%
# locals.update(np.load('coverage_freqepid_nbinom_randinf_0.npz'))

# %%
Ihs_dth = np.zeros([num_sim, 2+d, 2+d])
Ts_dth = np.zeros(num_sim)
ps_dth = np.zeros(num_sim)

# %%
Ihs_hac = np.zeros([num_sim, 2+d, 2+d])
Ts_hac = np.zeros(num_sim)
ps_hac = np.zeros(num_sim)

# %%
Ihs_sdw = np.zeros([num_sim, 2+d, 2+d])
Ts_sdw = np.zeros(num_sim)
ps_sdw = np.zeros(num_sim)

# %%
for iter_sim in np.arange(num_sim):
    start_sim = time.time()
    
    nmle = nsim[iter_sim]
    mmle = msim[iter_sim]
    bmle = bsim[iter_sim,:]
    
    data_i = data[data['sim']==iter_sim]
    A = np.stack([np.full(T, 1), data_i["intervention"].to_numpy()], -1)
    Y = data_i["death"].to_numpy()
    
    Ihat_dth, Ihat_hac, Ihat_sdw =\
    model.inference(A, Y, nmle, mmle, bmle)
    
    # Fisher information matrix
    Ihs_dth[iter_sim] = Ihat_dth
    Ts_dth[iter_sim] = (bmle[1]-beta[1])/np.sqrt(la.pinv(Ihs_dth[iter_sim])[-1,-1])
    ps_dth[iter_sim] = 2*(1-stats.norm.cdf(np.abs(Ts_dth[iter_sim])))
    
    # HAC estimator
    Ihs_hac[iter_sim] = Ihat_hac
    Ts_hac[iter_sim] = (bmle[1]-beta[1])/np.sqrt(la.pinv(Ihs_hac[iter_sim])[-1,-1])
    ps_hac[iter_sim] = 2*(1-stats.norm.cdf(np.abs(Ts_hac[iter_sim])))
    
    # Sandwich estimator
    Ihs_sdw[iter_sim] = Ihat_sdw
    Ts_sdw[iter_sim] = (bmle[1]-beta[1])/np.sqrt(la.pinv(Ihs_sdw[iter_sim])[-1,-1])
    ps_sdw[iter_sim] = 2*(1-stats.norm.cdf(np.abs(Ts_sdw[iter_sim])))
    
    sys.__stdout__.write("%d-th simulation finished, %f sec.\n"
                         %(iter_sim+1, time.time()-start_sim))
    sys.__stdout__.flush()
# Out:
# 1-th simulation finished, 0.009404 sec.
# 2-th simulation finished, 0.003598 sec.
# 3-th simulation finished, 0.003348 sec.
# 4-th simulation finished, 0.003501 sec.
# 5-th simulation finished, 0.002458 sec.
# 6-th simulation finished, 0.002553 sec.
# 7-th simulation finished, 0.002378 sec.
# 8-th simulation finished, 0.002477 sec.
# 9-th simulation finished, 0.002188 sec.
# 10-th simulation finished, 0.002136 sec.
# 11-th simulation finished, 0.001921 sec.
# 12-th simulation finished, 0.001838 sec.
# 13-th simulation finished, 0.001804 sec.
# 14-th simulation finished, 0.001812 sec.
# 15-th simulation finished, 0.001710 sec.
# 16-th simulation finished, 0.001749 sec.
# 17-th simulation finished, 0.001697 sec.
# 18-th simulation finished, 0.001728 sec.
# 19-th simulation finished, 0.001646 sec.
# 20-th simulation finished, 0.001553 sec.
# 21-th simulation finished, 0.001467 sec.
# 22-th simulation finished, 0.001737 sec.
# 23-th simulation finished, 0.001459 sec.
# 24-th simulation finished, 0.001376 sec.
# 25-th simulation finished, 0.001391 sec.
# 26-th simulation finished, 0.001292 sec.
# 27-th simulation finished, 0.001314 sec.
# 28-th simulation finished, 0.001288 sec.
# 29-th simulation finished, 0.001430 sec.
# 30-th simulation finished, 0.001274 sec.
# 31-th simulation finished, 0.001241 sec.
# 32-th simulation finished, 0.001207 sec.
# 33-th simulation finished, 0.001228 sec.
# 34-th simulation finished, 0.001156 sec.
# 35-th simulation finished, 0.001155 sec.
# 36-th simulation finished, 0.001121 sec.
# 37-th simulation finished, 0.001130 sec.
# 38-th simulation finished, 0.001086 sec.
# 39-th simulation finished, 0.001101 sec.
# 40-th simulation finished, 0.001081 sec.
# 41-th simulation finished, 0.001070 sec.
# 42-th simulation finished, 0.001043 sec.
# 43-th simulation finished, 0.001076 sec.
# 44-th simulation finished, 0.001047 sec.
# 45-th simulation finished, 0.001073 sec.
# 46-th simulation finished, 0.001209 sec.
# 47-th simulation finished, 0.001156 sec.
# 48-th simulation finished, 0.001170 sec.
# 49-th simulation finished, 0.001169 sec.
# 50-th simulation finished, 0.001118 sec.
# 51-th simulation finished, 0.001160 sec.
# 52-th simulation finished, 0.001098 sec.
# 53-th simulation finished, 0.001172 sec.
# 54-th simulation finished, 0.001097 sec.
# 55-th simulation finished, 0.001128 sec.
# 56-th simulation finished, 0.001093 sec.
# 57-th simulation finished, 0.001127 sec.
# 58-th simulation finished, 0.001086 sec.
# 59-th simulation finished, 0.001137 sec.
# 60-th simulation finished, 0.001093 sec.
# 61-th simulation finished, 0.001121 sec.
# 62-th simulation finished, 0.001086 sec.
# 63-th simulation finished, 0.001073 sec.
# 64-th simulation finished, 0.001117 sec.
# 65-th simulation finished, 0.001124 sec.
# 66-th simulation finished, 0.001033 sec.
# 67-th simulation finished, 0.001040 sec.
# 68-th simulation finished, 0.001021 sec.
# 69-th simulation finished, 0.001044 sec.
# 70-th simulation finished, 0.001030 sec.
# 71-th simulation finished, 0.001042 sec.
# 72-th simulation finished, 0.000995 sec.
# 73-th simulation finished, 0.001040 sec.
# 74-th simulation finished, 0.001004 sec.
# 75-th simulation finished, 0.001032 sec.
# 76-th simulation finished, 0.001015 sec.
# 77-th simulation finished, 0.001023 sec.
# 78-th simulation finished, 0.001006 sec.
# 79-th simulation finished, 0.001099 sec.
# 80-th simulation finished, 0.001096 sec.
# 81-th simulation finished, 0.001073 sec.
# 82-th simulation finished, 0.001092 sec.
# 83-th simulation finished, 0.001019 sec.
# 84-th simulation finished, 0.001022 sec.
# 85-th simulation finished, 0.001031 sec.
# 86-th simulation finished, 0.001044 sec.
# 87-th simulation finished, 0.001009 sec.
# 88-th simulation finished, 0.001022 sec.
# 89-th simulation finished, 0.001011 sec.
# 90-th simulation finished, 0.001026 sec.
# 91-th simulation finished, 0.001009 sec.
# 92-th simulation finished, 0.001033 sec.
# 93-th simulation finished, 0.001028 sec.
# 94-th simulation finished, 0.001038 sec.
# 95-th simulation finished, 0.001006 sec.
# 96-th simulation finished, 0.001027 sec.
# 97-th simulation finished, 0.001021 sec.
# 98-th simulation finished, 0.001028 sec.
# 99-th simulation finished, 0.001011 sec.
# 100-th simulation finished, 0.001028 sec.
# 101-th simulation finished, 0.001017 sec.
# 102-th simulation finished, 0.001034 sec.
# 103-th simulation finished, 0.001014 sec.
# 104-th simulation finished, 0.001022 sec.
# 105-th simulation finished, 0.001018 sec.
# 106-th simulation finished, 0.001028 sec.
# 107-th simulation finished, 0.001002 sec.
# 108-th simulation finished, 0.001172 sec.
# 109-th simulation finished, 0.001032 sec.
# 110-th simulation finished, 0.001070 sec.
# 111-th simulation finished, 0.001066 sec.
# 112-th simulation finished, 0.001017 sec.
# 113-th simulation finished, 0.001087 sec.
# 114-th simulation finished, 0.001084 sec.
# 115-th simulation finished, 0.001094 sec.
# 116-th simulation finished, 0.001046 sec.
# 117-th simulation finished, 0.001095 sec.
# 118-th simulation finished, 0.001026 sec.
# 119-th simulation finished, 0.001056 sec.
# 120-th simulation finished, 0.001020 sec.
# 121-th simulation finished, 0.001035 sec.
# 122-th simulation finished, 0.001017 sec.
# 123-th simulation finished, 0.001039 sec.
# 124-th simulation finished, 0.001002 sec.
# 125-th simulation finished, 0.001022 sec.
# 126-th simulation finished, 0.001015 sec.
# 127-th simulation finished, 0.001037 sec.
# 128-th simulation finished, 0.001002 sec.
# 129-th simulation finished, 0.001022 sec.
# 130-th simulation finished, 0.001014 sec.
# 131-th simulation finished, 0.001025 sec.
# 132-th simulation finished, 0.001013 sec.
# 133-th simulation finished, 0.001028 sec.
# 134-th simulation finished, 0.001006 sec.
# 135-th simulation finished, 0.001017 sec.
# 136-th simulation finished, 0.001013 sec.
# 137-th simulation finished, 0.001043 sec.
# 138-th simulation finished, 0.001019 sec.
# 139-th simulation finished, 0.001027 sec.
# 140-th simulation finished, 0.001011 sec.
# 141-th simulation finished, 0.001035 sec.
# 142-th simulation finished, 0.001013 sec.
# 143-th simulation finished, 0.001019 sec.
# 144-th simulation finished, 0.001019 sec.
# 145-th simulation finished, 0.001040 sec.
# 146-th simulation finished, 0.001012 sec.
# 147-th simulation finished, 0.001023 sec.
# 148-th simulation finished, 0.001057 sec.
# 149-th simulation finished, 0.001113 sec.
# 150-th simulation finished, 0.001008 sec.
# 151-th simulation finished, 0.001041 sec.
# 152-th simulation finished, 0.001012 sec.
# 153-th simulation finished, 0.001021 sec.
# 154-th simulation finished, 0.001017 sec.
# 155-th simulation finished, 0.001029 sec.
# 156-th simulation finished, 0.001018 sec.
# 157-th simulation finished, 0.001020 sec.
# 158-th simulation finished, 0.001015 sec.
# 159-th simulation finished, 0.001027 sec.
# 160-th simulation finished, 0.001025 sec.
# 161-th simulation finished, 0.001034 sec.
# 162-th simulation finished, 0.000997 sec.
# 163-th simulation finished, 0.001027 sec.
# 164-th simulation finished, 0.001010 sec.
# 165-th simulation finished, 0.001027 sec.
# 166-th simulation finished, 0.001000 sec.
# 167-th simulation finished, 0.001079 sec.
# 168-th simulation finished, 0.001597 sec.
# 169-th simulation finished, 0.001475 sec.
# 170-th simulation finished, 0.001137 sec.
# 171-th simulation finished, 0.001066 sec.
# 172-th simulation finished, 0.001033 sec.
# 173-th simulation finished, 0.001027 sec.
# 174-th simulation finished, 0.001011 sec.
# 175-th simulation finished, 0.001045 sec.
# 176-th simulation finished, 0.001015 sec.
# 177-th simulation finished, 0.001027 sec.
# 178-th simulation finished, 0.001010 sec.
# 179-th simulation finished, 0.001031 sec.
# 180-th simulation finished, 0.001009 sec.
# 181-th simulation finished, 0.001040 sec.
# 182-th simulation finished, 0.001072 sec.
# 183-th simulation finished, 0.001214 sec.
# 184-th simulation finished, 0.001274 sec.
# 185-th simulation finished, 0.001402 sec.
# 186-th simulation finished, 0.001166 sec.
# 187-th simulation finished, 0.001108 sec.
# 188-th simulation finished, 0.001035 sec.
# 189-th simulation finished, 0.001047 sec.
# 190-th simulation finished, 0.001024 sec.
# 191-th simulation finished, 0.001140 sec.
# 192-th simulation finished, 0.001069 sec.
# 193-th simulation finished, 0.001043 sec.
# 194-th simulation finished, 0.001036 sec.
# 195-th simulation finished, 0.001049 sec.
# 196-th simulation finished, 0.001024 sec.
# 197-th simulation finished, 0.001017 sec.
# 198-th simulation finished, 0.001012 sec.
# 199-th simulation finished, 0.001021 sec.
# 200-th simulation finished, 0.001005 sec.
# 201-th simulation finished, 0.001028 sec.
# 202-th simulation finished, 0.001118 sec.
# 203-th simulation finished, 0.001115 sec.
# 204-th simulation finished, 0.001069 sec.
# 205-th simulation finished, 0.001031 sec.
# 206-th simulation finished, 0.001044 sec.
# 207-th simulation finished, 0.001023 sec.
# 208-th simulation finished, 0.001063 sec.
# 209-th simulation finished, 0.001016 sec.
# 210-th simulation finished, 0.001019 sec.
# 211-th simulation finished, 0.001022 sec.
# 212-th simulation finished, 0.001020 sec.
# 213-th simulation finished, 0.001012 sec.
# 214-th simulation finished, 0.001022 sec.
# 215-th simulation finished, 0.001120 sec.
# 216-th simulation finished, 0.001161 sec.
# 217-th simulation finished, 0.001081 sec.
# 218-th simulation finished, 0.001064 sec.
# 219-th simulation finished, 0.001078 sec.
# 220-th simulation finished, 0.001035 sec.
# 221-th simulation finished, 0.001032 sec.
# 222-th simulation finished, 0.001009 sec.
# 223-th simulation finished, 0.001028 sec.
# 224-th simulation finished, 0.001006 sec.
# 225-th simulation finished, 0.001034 sec.
# 226-th simulation finished, 0.001009 sec.
# 227-th simulation finished, 0.001040 sec.
# 228-th simulation finished, 0.001005 sec.
# 229-th simulation finished, 0.001038 sec.
# 230-th simulation finished, 0.001006 sec.
# 231-th simulation finished, 0.001026 sec.
# 232-th simulation finished, 0.001011 sec.
# 233-th simulation finished, 0.001043 sec.
# 234-th simulation finished, 0.001027 sec.
# 235-th simulation finished, 0.001025 sec.
# 236-th simulation finished, 0.001019 sec.
# 237-th simulation finished, 0.001047 sec.
# 238-th simulation finished, 0.001025 sec.
# 239-th simulation finished, 0.001034 sec.
# 240-th simulation finished, 0.000998 sec.
# 241-th simulation finished, 0.001018 sec.
# 242-th simulation finished, 0.001010 sec.
# 243-th simulation finished, 0.001023 sec.
# 244-th simulation finished, 0.001088 sec.
# 245-th simulation finished, 0.001021 sec.
# 246-th simulation finished, 0.001024 sec.
# 247-th simulation finished, 0.001014 sec.
# 248-th simulation finished, 0.001015 sec.
# 249-th simulation finished, 0.001114 sec.
# 250-th simulation finished, 0.001118 sec.
# 251-th simulation finished, 0.001073 sec.
# 252-th simulation finished, 0.001040 sec.
# 253-th simulation finished, 0.001041 sec.
# 254-th simulation finished, 0.001031 sec.
# 255-th simulation finished, 0.001004 sec.
# 256-th simulation finished, 0.001023 sec.
# 257-th simulation finished, 0.000991 sec.
# 258-th simulation finished, 0.001033 sec.
# 259-th simulation finished, 0.001019 sec.
# 260-th simulation finished, 0.001035 sec.
# 261-th simulation finished, 0.001015 sec.
# 262-th simulation finished, 0.001029 sec.
# 263-th simulation finished, 0.001027 sec.
# 264-th simulation finished, 0.001027 sec.
# 265-th simulation finished, 0.001013 sec.
# 266-th simulation finished, 0.001035 sec.
# 267-th simulation finished, 0.001003 sec.
# 268-th simulation finished, 0.001030 sec.
# 269-th simulation finished, 0.001017 sec.
# 270-th simulation finished, 0.001088 sec.
# 271-th simulation finished, 0.001038 sec.
# 272-th simulation finished, 0.001048 sec.
# 273-th simulation finished, 0.001009 sec.
# 274-th simulation finished, 0.001019 sec.
# 275-th simulation finished, 0.001031 sec.
# 276-th simulation finished, 0.001044 sec.
# 277-th simulation finished, 0.001038 sec.
# 278-th simulation finished, 0.001025 sec.
# 279-th simulation finished, 0.001008 sec.
# 280-th simulation finished, 0.001015 sec.
# 281-th simulation finished, 0.001011 sec.
# 282-th simulation finished, 0.001024 sec.
# 283-th simulation finished, 0.001033 sec.
# 284-th simulation finished, 0.001147 sec.
# 285-th simulation finished, 0.001073 sec.
# 286-th simulation finished, 0.001084 sec.
# 287-th simulation finished, 0.001035 sec.
# 288-th simulation finished, 0.001069 sec.
# 289-th simulation finished, 0.001102 sec.
# 290-th simulation finished, 0.001061 sec.
# 291-th simulation finished, 0.001047 sec.
# 292-th simulation finished, 0.001035 sec.
# 293-th simulation finished, 0.001036 sec.
# 294-th simulation finished, 0.001024 sec.
# 295-th simulation finished, 0.001004 sec.
# 296-th simulation finished, 0.001026 sec.
# 297-th simulation finished, 0.001016 sec.
# 298-th simulation finished, 0.001030 sec.
# 299-th simulation finished, 0.001016 sec.
# 300-th simulation finished, 0.001015 sec.
# 301-th simulation finished, 0.001019 sec.
# 302-th simulation finished, 0.001015 sec.
# 303-th simulation finished, 0.001009 sec.
# 304-th simulation finished, 0.001013 sec.
# 305-th simulation finished, 0.001024 sec.
# 306-th simulation finished, 0.001009 sec.
# 307-th simulation finished, 0.001015 sec.
# 308-th simulation finished, 0.001018 sec.
# 309-th simulation finished, 0.001007 sec.
# 310-th simulation finished, 0.001006 sec.
# 311-th simulation finished, 0.001020 sec.
# 312-th simulation finished, 0.001006 sec.
# 313-th simulation finished, 0.001011 sec.
# 314-th simulation finished, 0.001011 sec.
# 315-th simulation finished, 0.001011 sec.
# 316-th simulation finished, 0.001017 sec.
# 317-th simulation finished, 0.001004 sec.
# 318-th simulation finished, 0.001044 sec.
# 319-th simulation finished, 0.001084 sec.
# 320-th simulation finished, 0.001011 sec.
# 321-th simulation finished, 0.001007 sec.
# 322-th simulation finished, 0.001029 sec.
# 323-th simulation finished, 0.001001 sec.
# 324-th simulation finished, 0.001014 sec.
# 325-th simulation finished, 0.001006 sec.
# 326-th simulation finished, 0.001012 sec.
# 327-th simulation finished, 0.001013 sec.
# 328-th simulation finished, 0.001016 sec.
# 329-th simulation finished, 0.001005 sec.
# 330-th simulation finished, 0.001014 sec.
# 331-th simulation finished, 0.001008 sec.
# 332-th simulation finished, 0.001032 sec.
# 333-th simulation finished, 0.001012 sec.
# 334-th simulation finished, 0.001007 sec.
# 335-th simulation finished, 0.001006 sec.
# 336-th simulation finished, 0.001001 sec.
# 337-th simulation finished, 0.001012 sec.
# 338-th simulation finished, 0.000999 sec.
# 339-th simulation finished, 0.001123 sec.
# 340-th simulation finished, 0.001047 sec.
# 341-th simulation finished, 0.001092 sec.
# 342-th simulation finished, 0.001033 sec.
# 343-th simulation finished, 0.001059 sec.
# 344-th simulation finished, 0.001027 sec.
# 345-th simulation finished, 0.001039 sec.
# 346-th simulation finished, 0.001030 sec.
# 347-th simulation finished, 0.001064 sec.
# 348-th simulation finished, 0.001062 sec.
# 349-th simulation finished, 0.001003 sec.
# 350-th simulation finished, 0.001005 sec.
# 351-th simulation finished, 0.001009 sec.
# 352-th simulation finished, 0.001009 sec.
# 353-th simulation finished, 0.001050 sec.
# 354-th simulation finished, 0.001096 sec.
# 355-th simulation finished, 0.001047 sec.
# 356-th simulation finished, 0.001103 sec.
# 357-th simulation finished, 0.001056 sec.
# 358-th simulation finished, 0.001075 sec.
# 359-th simulation finished, 0.001034 sec.
# 360-th simulation finished, 0.001042 sec.
# 361-th simulation finished, 0.001271 sec.
# 362-th simulation finished, 0.001433 sec.
# 363-th simulation finished, 0.001084 sec.
# 364-th simulation finished, 0.001046 sec.
# 365-th simulation finished, 0.001044 sec.
# 366-th simulation finished, 0.001068 sec.
# 367-th simulation finished, 0.001036 sec.
# 368-th simulation finished, 0.001039 sec.
# 369-th simulation finished, 0.001020 sec.
# 370-th simulation finished, 0.001021 sec.
# 371-th simulation finished, 0.001013 sec.
# 372-th simulation finished, 0.001027 sec.
# 373-th simulation finished, 0.001108 sec.
# 374-th simulation finished, 0.001123 sec.
# 375-th simulation finished, 0.001010 sec.
# 376-th simulation finished, 0.001034 sec.
# 377-th simulation finished, 0.001003 sec.
# 378-th simulation finished, 0.001037 sec.
# 379-th simulation finished, 0.001017 sec.
# 380-th simulation finished, 0.001031 sec.
# 381-th simulation finished, 0.001004 sec.
# 382-th simulation finished, 0.001046 sec.
# 383-th simulation finished, 0.001011 sec.
# 384-th simulation finished, 0.001037 sec.
# 385-th simulation finished, 0.001008 sec.
# 386-th simulation finished, 0.001053 sec.
# 387-th simulation finished, 0.001086 sec.
# 388-th simulation finished, 0.001030 sec.
# 389-th simulation finished, 0.001003 sec.
# 390-th simulation finished, 0.001032 sec.
# 391-th simulation finished, 0.001006 sec.
# 392-th simulation finished, 0.001031 sec.
# 393-th simulation finished, 0.001003 sec.
# 394-th simulation finished, 0.001028 sec.
# 395-th simulation finished, 0.001011 sec.
# 396-th simulation finished, 0.001028 sec.
# 397-th simulation finished, 0.001009 sec.
# 398-th simulation finished, 0.001033 sec.
# 399-th simulation finished, 0.001011 sec.
# 400-th simulation finished, 0.001038 sec.
# 401-th simulation finished, 0.000996 sec.
# 402-th simulation finished, 0.001018 sec.
# 403-th simulation finished, 0.001003 sec.
# 404-th simulation finished, 0.001030 sec.
# 405-th simulation finished, 0.001072 sec.
# 406-th simulation finished, 0.001038 sec.
# 407-th simulation finished, 0.001001 sec.
# 408-th simulation finished, 0.001021 sec.
# 409-th simulation finished, 0.000998 sec.
# 410-th simulation finished, 0.001040 sec.
# 411-th simulation finished, 0.001004 sec.
# 412-th simulation finished, 0.001033 sec.
# 413-th simulation finished, 0.001027 sec.
# 414-th simulation finished, 0.001040 sec.
# 415-th simulation finished, 0.001016 sec.
# 416-th simulation finished, 0.001025 sec.
# 417-th simulation finished, 0.001003 sec.
# 418-th simulation finished, 0.001024 sec.
# 419-th simulation finished, 0.001000 sec.
# 420-th simulation finished, 0.001072 sec.
# 421-th simulation finished, 0.001144 sec.
# 422-th simulation finished, 0.001057 sec.
# 423-th simulation finished, 0.001035 sec.
# 424-th simulation finished, 0.001025 sec.
# 425-th simulation finished, 0.001024 sec.
# 426-th simulation finished, 0.001051 sec.
# 427-th simulation finished, 0.001018 sec.
# 428-th simulation finished, 0.001064 sec.
# 429-th simulation finished, 0.001032 sec.
# 430-th simulation finished, 0.001033 sec.
# 431-th simulation finished, 0.001010 sec.
# 432-th simulation finished, 0.001056 sec.
# 433-th simulation finished, 0.001013 sec.
# 434-th simulation finished, 0.001080 sec.
# 435-th simulation finished, 0.001106 sec.
# 436-th simulation finished, 0.001052 sec.
# 437-th simulation finished, 0.001029 sec.
# 438-th simulation finished, 0.001015 sec.
# 439-th simulation finished, 0.001007 sec.
# 440-th simulation finished, 0.001027 sec.
# 441-th simulation finished, 0.001032 sec.
# 442-th simulation finished, 0.001015 sec.
# 443-th simulation finished, 0.001006 sec.
# 444-th simulation finished, 0.001027 sec.
# 445-th simulation finished, 0.001024 sec.
# 446-th simulation finished, 0.001047 sec.
# 447-th simulation finished, 0.001018 sec.
# 448-th simulation finished, 0.001037 sec.
# 449-th simulation finished, 0.001015 sec.
# 450-th simulation finished, 0.001018 sec.
# 451-th simulation finished, 0.001016 sec.
# 452-th simulation finished, 0.001029 sec.
# 453-th simulation finished, 0.000999 sec.
# 454-th simulation finished, 0.001027 sec.
# 455-th simulation finished, 0.001072 sec.
# 456-th simulation finished, 0.001071 sec.
# 457-th simulation finished, 0.001025 sec.
# 458-th simulation finished, 0.001044 sec.
# 459-th simulation finished, 0.001017 sec.
# 460-th simulation finished, 0.001076 sec.
# 461-th simulation finished, 0.001013 sec.
# 462-th simulation finished, 0.001029 sec.
# 463-th simulation finished, 0.001007 sec.
# 464-th simulation finished, 0.001071 sec.
# 465-th simulation finished, 0.001092 sec.
# 466-th simulation finished, 0.001033 sec.
# 467-th simulation finished, 0.001016 sec.
# 468-th simulation finished, 0.001034 sec.
# 469-th simulation finished, 0.001022 sec.
# 470-th simulation finished, 0.001030 sec.
# 471-th simulation finished, 0.001028 sec.
# 472-th simulation finished, 0.001037 sec.
# 473-th simulation finished, 0.001003 sec.
# 474-th simulation finished, 0.001025 sec.
# 475-th simulation finished, 0.001013 sec.
# 476-th simulation finished, 0.001036 sec.
# 477-th simulation finished, 0.001015 sec.
# 478-th simulation finished, 0.001034 sec.
# 479-th simulation finished, 0.001007 sec.
# 480-th simulation finished, 0.001022 sec.
# 481-th simulation finished, 0.001002 sec.
# 482-th simulation finished, 0.001029 sec.
# 483-th simulation finished, 0.001008 sec.
# 484-th simulation finished, 0.001013 sec.
# 485-th simulation finished, 0.001006 sec.
# 486-th simulation finished, 0.001025 sec.
# 487-th simulation finished, 0.001018 sec.
# 488-th simulation finished, 0.001029 sec.
# 489-th simulation finished, 0.001063 sec.
# 490-th simulation finished, 0.001084 sec.
# 491-th simulation finished, 0.001008 sec.
# 492-th simulation finished, 0.001046 sec.
# 493-th simulation finished, 0.001006 sec.
# 494-th simulation finished, 0.001026 sec.
# 495-th simulation finished, 0.001032 sec.
# 496-th simulation finished, 0.001040 sec.
# 497-th simulation finished, 0.000996 sec.
# 498-th simulation finished, 0.001023 sec.
# 499-th simulation finished, 0.001009 sec.
# 500-th simulation finished, 0.001037 sec.
# 501-th simulation finished, 0.001004 sec.
# 502-th simulation finished, 0.001041 sec.
# 503-th simulation finished, 0.001017 sec.
# 504-th simulation finished, 0.001030 sec.
# 505-th simulation finished, 0.000994 sec.
# 506-th simulation finished, 0.001025 sec.
# 507-th simulation finished, 0.000996 sec.
# 508-th simulation finished, 0.001020 sec.
# 509-th simulation finished, 0.000998 sec.
# 510-th simulation finished, 0.001032 sec.
# 511-th simulation finished, 0.000993 sec.
# 512-th simulation finished, 0.001029 sec.
# 513-th simulation finished, 0.001027 sec.
# 514-th simulation finished, 0.001026 sec.
# 515-th simulation finished, 0.001005 sec.
# 516-th simulation finished, 0.001043 sec.
# 517-th simulation finished, 0.001015 sec.
# 518-th simulation finished, 0.001031 sec.
# 519-th simulation finished, 0.001009 sec.
# 520-th simulation finished, 0.001029 sec.
# 521-th simulation finished, 0.001006 sec.
# 522-th simulation finished, 0.001035 sec.
# 523-th simulation finished, 0.001020 sec.
# 524-th simulation finished, 0.001167 sec.
# 525-th simulation finished, 0.001030 sec.
# 526-th simulation finished, 0.001085 sec.
# 527-th simulation finished, 0.001103 sec.
# 528-th simulation finished, 0.001037 sec.
# 529-th simulation finished, 0.001047 sec.
# 530-th simulation finished, 0.001027 sec.
# 531-th simulation finished, 0.001043 sec.
# 532-th simulation finished, 0.001011 sec.
# 533-th simulation finished, 0.001040 sec.
# 534-th simulation finished, 0.001014 sec.
# 535-th simulation finished, 0.001029 sec.
# 536-th simulation finished, 0.001010 sec.
# 537-th simulation finished, 0.001039 sec.
# 538-th simulation finished, 0.001009 sec.
# 539-th simulation finished, 0.001017 sec.
# 540-th simulation finished, 0.001021 sec.
# 541-th simulation finished, 0.001041 sec.
# 542-th simulation finished, 0.001031 sec.
# 543-th simulation finished, 0.001030 sec.
# 544-th simulation finished, 0.001006 sec.
# 545-th simulation finished, 0.001024 sec.
# 546-th simulation finished, 0.001016 sec.
# 547-th simulation finished, 0.001040 sec.
# 548-th simulation finished, 0.001003 sec.
# 549-th simulation finished, 0.001022 sec.
# 550-th simulation finished, 0.001010 sec.
# 551-th simulation finished, 0.001021 sec.
# 552-th simulation finished, 0.000993 sec.
# 553-th simulation finished, 0.001051 sec.
# 554-th simulation finished, 0.001006 sec.
# 555-th simulation finished, 0.001023 sec.
# 556-th simulation finished, 0.001240 sec.
# 557-th simulation finished, 0.001421 sec.
# 558-th simulation finished, 0.001134 sec.
# 559-th simulation finished, 0.001081 sec.
# 560-th simulation finished, 0.001034 sec.
# 561-th simulation finished, 0.001052 sec.
# 562-th simulation finished, 0.001023 sec.
# 563-th simulation finished, 0.001038 sec.
# 564-th simulation finished, 0.001012 sec.
# 565-th simulation finished, 0.001028 sec.
# 566-th simulation finished, 0.001011 sec.
# 567-th simulation finished, 0.001044 sec.
# 568-th simulation finished, 0.001010 sec.
# 569-th simulation finished, 0.001022 sec.
# 570-th simulation finished, 0.001011 sec.
# 571-th simulation finished, 0.001030 sec.
# 572-th simulation finished, 0.001015 sec.
# 573-th simulation finished, 0.001023 sec.
# 574-th simulation finished, 0.001014 sec.
# 575-th simulation finished, 0.001010 sec.
# 576-th simulation finished, 0.001007 sec.
# 577-th simulation finished, 0.001037 sec.
# 578-th simulation finished, 0.001015 sec.
# 579-th simulation finished, 0.001128 sec.
# 580-th simulation finished, 0.001155 sec.
# 581-th simulation finished, 0.001082 sec.
# 582-th simulation finished, 0.001189 sec.
# 583-th simulation finished, 0.001095 sec.
# 584-th simulation finished, 0.001224 sec.
# 585-th simulation finished, 0.001196 sec.
# 586-th simulation finished, 0.001099 sec.
# 587-th simulation finished, 0.001018 sec.
# 588-th simulation finished, 0.001044 sec.
# 589-th simulation finished, 0.001011 sec.
# 590-th simulation finished, 0.001035 sec.
# 591-th simulation finished, 0.001216 sec.
# 592-th simulation finished, 0.001279 sec.
# 593-th simulation finished, 0.001098 sec.
# 594-th simulation finished, 0.001065 sec.
# 595-th simulation finished, 0.001093 sec.
# 596-th simulation finished, 0.001244 sec.
# 597-th simulation finished, 0.001035 sec.
# 598-th simulation finished, 0.001088 sec.
# 599-th simulation finished, 0.001055 sec.
# 600-th simulation finished, 0.001041 sec.
# 601-th simulation finished, 0.001012 sec.
# 602-th simulation finished, 0.001038 sec.
# 603-th simulation finished, 0.001017 sec.
# 604-th simulation finished, 0.001060 sec.
# 605-th simulation finished, 0.001019 sec.
# 606-th simulation finished, 0.001029 sec.
# 607-th simulation finished, 0.001091 sec.
# 608-th simulation finished, 0.001205 sec.
# 609-th simulation finished, 0.001031 sec.
# 610-th simulation finished, 0.001018 sec.
# 611-th simulation finished, 0.001046 sec.
# 612-th simulation finished, 0.001011 sec.
# 613-th simulation finished, 0.001061 sec.
# 614-th simulation finished, 0.001001 sec.
# 615-th simulation finished, 0.001041 sec.
# 616-th simulation finished, 0.001003 sec.
# 617-th simulation finished, 0.001022 sec.
# 618-th simulation finished, 0.001012 sec.
# 619-th simulation finished, 0.001028 sec.
# 620-th simulation finished, 0.001026 sec.
# 621-th simulation finished, 0.001022 sec.
# 622-th simulation finished, 0.001017 sec.
# 623-th simulation finished, 0.001026 sec.
# 624-th simulation finished, 0.001050 sec.
# 625-th simulation finished, 0.001102 sec.
# 626-th simulation finished, 0.001069 sec.
# 627-th simulation finished, 0.001075 sec.
# 628-th simulation finished, 0.001027 sec.
# 629-th simulation finished, 0.001004 sec.
# 630-th simulation finished, 0.001033 sec.
# 631-th simulation finished, 0.001022 sec.
# 632-th simulation finished, 0.001032 sec.
# 633-th simulation finished, 0.000995 sec.
# 634-th simulation finished, 0.001029 sec.
# 635-th simulation finished, 0.000997 sec.
# 636-th simulation finished, 0.001031 sec.
# 637-th simulation finished, 0.001016 sec.
# 638-th simulation finished, 0.001022 sec.
# 639-th simulation finished, 0.001026 sec.
# 640-th simulation finished, 0.001014 sec.
# 641-th simulation finished, 0.000998 sec.
# 642-th simulation finished, 0.001046 sec.
# 643-th simulation finished, 0.001000 sec.
# 644-th simulation finished, 0.001033 sec.
# 645-th simulation finished, 0.001014 sec.
# 646-th simulation finished, 0.001030 sec.
# 647-th simulation finished, 0.001008 sec.
# 648-th simulation finished, 0.001017 sec.
# 649-th simulation finished, 0.001018 sec.
# 650-th simulation finished, 0.001022 sec.
# 651-th simulation finished, 0.001001 sec.
# 652-th simulation finished, 0.001032 sec.
# 653-th simulation finished, 0.001008 sec.
# 654-th simulation finished, 0.001027 sec.
# 655-th simulation finished, 0.001017 sec.
# 656-th simulation finished, 0.001032 sec.
# 657-th simulation finished, 0.001005 sec.
# 658-th simulation finished, 0.001044 sec.
# 659-th simulation finished, 0.001067 sec.
# 660-th simulation finished, 0.001042 sec.
# 661-th simulation finished, 0.001024 sec.
# 662-th simulation finished, 0.001040 sec.
# 663-th simulation finished, 0.001014 sec.
# 664-th simulation finished, 0.001037 sec.
# 665-th simulation finished, 0.001008 sec.
# 666-th simulation finished, 0.001015 sec.
# 667-th simulation finished, 0.001015 sec.
# 668-th simulation finished, 0.001017 sec.
# 669-th simulation finished, 0.000998 sec.
# 670-th simulation finished, 0.001030 sec.
# 671-th simulation finished, 0.001010 sec.
# 672-th simulation finished, 0.001025 sec.
# 673-th simulation finished, 0.001017 sec.
# 674-th simulation finished, 0.001025 sec.
# 675-th simulation finished, 0.001011 sec.
# 676-th simulation finished, 0.001036 sec.
# 677-th simulation finished, 0.001018 sec.
# 678-th simulation finished, 0.001016 sec.
# 679-th simulation finished, 0.001011 sec.
# 680-th simulation finished, 0.001017 sec.
# 681-th simulation finished, 0.001020 sec.
# 682-th simulation finished, 0.001030 sec.
# 683-th simulation finished, 0.001023 sec.
# 684-th simulation finished, 0.001038 sec.
# 685-th simulation finished, 0.001024 sec.
# 686-th simulation finished, 0.001034 sec.
# 687-th simulation finished, 0.001043 sec.
# 688-th simulation finished, 0.001049 sec.
# 689-th simulation finished, 0.001020 sec.
# 690-th simulation finished, 0.001045 sec.
# 691-th simulation finished, 0.001031 sec.
# 692-th simulation finished, 0.001048 sec.
# 693-th simulation finished, 0.001056 sec.
# 694-th simulation finished, 0.001091 sec.
# 695-th simulation finished, 0.001081 sec.
# 696-th simulation finished, 0.001043 sec.
# 697-th simulation finished, 0.001044 sec.
# 698-th simulation finished, 0.001041 sec.
# 699-th simulation finished, 0.001035 sec.
# 700-th simulation finished, 0.001050 sec.
# 701-th simulation finished, 0.001041 sec.
# 702-th simulation finished, 0.001040 sec.
# 703-th simulation finished, 0.001031 sec.
# 704-th simulation finished, 0.001043 sec.
# 705-th simulation finished, 0.001037 sec.
# 706-th simulation finished, 0.001065 sec.
# 707-th simulation finished, 0.001047 sec.
# 708-th simulation finished, 0.001061 sec.
# 709-th simulation finished, 0.001031 sec.
# 710-th simulation finished, 0.001040 sec.
# 711-th simulation finished, 0.001050 sec.
# 712-th simulation finished, 0.001065 sec.
# 713-th simulation finished, 0.001053 sec.
# 714-th simulation finished, 0.001048 sec.
# 715-th simulation finished, 0.001036 sec.
# 716-th simulation finished, 0.001148 sec.
# 717-th simulation finished, 0.001048 sec.
# 718-th simulation finished, 0.001085 sec.
# 719-th simulation finished, 0.001028 sec.
# 720-th simulation finished, 0.001075 sec.
# 721-th simulation finished, 0.001034 sec.
# 722-th simulation finished, 0.001035 sec.
# 723-th simulation finished, 0.001011 sec.
# 724-th simulation finished, 0.001044 sec.
# 725-th simulation finished, 0.001027 sec.
# 726-th simulation finished, 0.001051 sec.
# 727-th simulation finished, 0.001062 sec.
# 728-th simulation finished, 0.001099 sec.
# 729-th simulation finished, 0.001070 sec.
# 730-th simulation finished, 0.001042 sec.
# 731-th simulation finished, 0.001029 sec.
# 732-th simulation finished, 0.001026 sec.
# 733-th simulation finished, 0.001010 sec.
# 734-th simulation finished, 0.001027 sec.
# 735-th simulation finished, 0.000998 sec.
# 736-th simulation finished, 0.001014 sec.
# 737-th simulation finished, 0.001015 sec.
# 738-th simulation finished, 0.001037 sec.
# 739-th simulation finished, 0.001009 sec.
# 740-th simulation finished, 0.001029 sec.
# 741-th simulation finished, 0.001017 sec.
# 742-th simulation finished, 0.001016 sec.
# 743-th simulation finished, 0.001011 sec.
# 744-th simulation finished, 0.001028 sec.
# 745-th simulation finished, 0.001034 sec.
# 746-th simulation finished, 0.001092 sec.
# 747-th simulation finished, 0.001092 sec.
# 748-th simulation finished, 0.001034 sec.
# 749-th simulation finished, 0.001474 sec.
# 750-th simulation finished, 0.001207 sec.
# 751-th simulation finished, 0.001081 sec.
# 752-th simulation finished, 0.001056 sec.
# 753-th simulation finished, 0.001033 sec.
# 754-th simulation finished, 0.001030 sec.
# 755-th simulation finished, 0.001038 sec.
# 756-th simulation finished, 0.001017 sec.
# 757-th simulation finished, 0.001021 sec.
# 758-th simulation finished, 0.001016 sec.
# 759-th simulation finished, 0.001006 sec.
# 760-th simulation finished, 0.001036 sec.
# 761-th simulation finished, 0.001085 sec.
# 762-th simulation finished, 0.001095 sec.
# 763-th simulation finished, 0.001012 sec.
# 764-th simulation finished, 0.001065 sec.
# 765-th simulation finished, 0.001025 sec.
# 766-th simulation finished, 0.001043 sec.
# 767-th simulation finished, 0.001042 sec.
# 768-th simulation finished, 0.001054 sec.
# 769-th simulation finished, 0.001013 sec.
# 770-th simulation finished, 0.001044 sec.
# 771-th simulation finished, 0.001019 sec.
# 772-th simulation finished, 0.001031 sec.
# 773-th simulation finished, 0.001014 sec.
# 774-th simulation finished, 0.001055 sec.
# 775-th simulation finished, 0.001027 sec.
# 776-th simulation finished, 0.001044 sec.
# 777-th simulation finished, 0.001007 sec.
# 778-th simulation finished, 0.001036 sec.
# 779-th simulation finished, 0.001009 sec.
# 780-th simulation finished, 0.001040 sec.
# 781-th simulation finished, 0.001012 sec.
# 782-th simulation finished, 0.001032 sec.
# 783-th simulation finished, 0.001005 sec.
# 784-th simulation finished, 0.001035 sec.
# 785-th simulation finished, 0.001011 sec.
# 786-th simulation finished, 0.001052 sec.
# 787-th simulation finished, 0.001019 sec.
# 788-th simulation finished, 0.001042 sec.
# 789-th simulation finished, 0.001081 sec.
# 790-th simulation finished, 0.001065 sec.
# 791-th simulation finished, 0.001031 sec.
# 792-th simulation finished, 0.001059 sec.
# 793-th simulation finished, 0.001028 sec.
# 794-th simulation finished, 0.001017 sec.
# 795-th simulation finished, 0.001079 sec.
# 796-th simulation finished, 0.001078 sec.
# 797-th simulation finished, 0.001012 sec.
# 798-th simulation finished, 0.001041 sec.
# 799-th simulation finished, 0.001121 sec.
# 800-th simulation finished, 0.001047 sec.
# 801-th simulation finished, 0.001040 sec.
# 802-th simulation finished, 0.001054 sec.
# 803-th simulation finished, 0.001029 sec.
# 804-th simulation finished, 0.001039 sec.
# 805-th simulation finished, 0.001022 sec.
# 806-th simulation finished, 0.001040 sec.
# 807-th simulation finished, 0.001026 sec.
# 808-th simulation finished, 0.001033 sec.
# 809-th simulation finished, 0.001006 sec.
# 810-th simulation finished, 0.001038 sec.
# 811-th simulation finished, 0.001012 sec.
# 812-th simulation finished, 0.001040 sec.
# 813-th simulation finished, 0.001008 sec.
# 814-th simulation finished, 0.001032 sec.
# 815-th simulation finished, 0.001008 sec.
# 816-th simulation finished, 0.001033 sec.
# 817-th simulation finished, 0.001013 sec.
# 818-th simulation finished, 0.001032 sec.
# 819-th simulation finished, 0.001052 sec.
# 820-th simulation finished, 0.001026 sec.
# 821-th simulation finished, 0.001001 sec.
# 822-th simulation finished, 0.001023 sec.
# 823-th simulation finished, 0.001004 sec.
# 824-th simulation finished, 0.001036 sec.
# 825-th simulation finished, 0.001002 sec.
# 826-th simulation finished, 0.001024 sec.
# 827-th simulation finished, 0.001016 sec.
# 828-th simulation finished, 0.001028 sec.
# 829-th simulation finished, 0.001047 sec.
# 830-th simulation finished, 0.001102 sec.
# 831-th simulation finished, 0.000997 sec.
# 832-th simulation finished, 0.001033 sec.
# 833-th simulation finished, 0.001011 sec.
# 834-th simulation finished, 0.001040 sec.
# 835-th simulation finished, 0.001003 sec.
# 836-th simulation finished, 0.001014 sec.
# 837-th simulation finished, 0.001002 sec.
# 838-th simulation finished, 0.001028 sec.
# 839-th simulation finished, 0.000998 sec.
# 840-th simulation finished, 0.001034 sec.
# 841-th simulation finished, 0.001013 sec.
# 842-th simulation finished, 0.001013 sec.
# 843-th simulation finished, 0.001009 sec.
# 844-th simulation finished, 0.001077 sec.
# 845-th simulation finished, 0.001067 sec.
# 846-th simulation finished, 0.001020 sec.
# 847-th simulation finished, 0.001058 sec.
# 848-th simulation finished, 0.000999 sec.
# 849-th simulation finished, 0.001024 sec.
# 850-th simulation finished, 0.001016 sec.
# 851-th simulation finished, 0.001027 sec.
# 852-th simulation finished, 0.001009 sec.
# 853-th simulation finished, 0.001020 sec.
# 854-th simulation finished, 0.001032 sec.
# 855-th simulation finished, 0.001040 sec.
# 856-th simulation finished, 0.001015 sec.
# 857-th simulation finished, 0.001027 sec.
# 858-th simulation finished, 0.001009 sec.
# 859-th simulation finished, 0.001016 sec.
# 860-th simulation finished, 0.001054 sec.
# 861-th simulation finished, 0.001034 sec.
# 862-th simulation finished, 0.001050 sec.
# 863-th simulation finished, 0.001044 sec.
# 864-th simulation finished, 0.001119 sec.
# 865-th simulation finished, 0.001086 sec.
# 866-th simulation finished, 0.001018 sec.
# 867-th simulation finished, 0.001044 sec.
# 868-th simulation finished, 0.001041 sec.
# 869-th simulation finished, 0.001074 sec.
# 870-th simulation finished, 0.001021 sec.
# 871-th simulation finished, 0.001048 sec.
# 872-th simulation finished, 0.001024 sec.
# 873-th simulation finished, 0.001041 sec.
# 874-th simulation finished, 0.001008 sec.
# 875-th simulation finished, 0.001044 sec.
# 876-th simulation finished, 0.001003 sec.
# 877-th simulation finished, 0.001044 sec.
# 878-th simulation finished, 0.001014 sec.
# 879-th simulation finished, 0.001034 sec.
# 880-th simulation finished, 0.001053 sec.
# 881-th simulation finished, 0.001068 sec.
# 882-th simulation finished, 0.001029 sec.
# 883-th simulation finished, 0.001055 sec.
# 884-th simulation finished, 0.001036 sec.
# 885-th simulation finished, 0.001019 sec.
# 886-th simulation finished, 0.001042 sec.
# 887-th simulation finished, 0.001015 sec.
# 888-th simulation finished, 0.001036 sec.
# 889-th simulation finished, 0.001016 sec.
# 890-th simulation finished, 0.001029 sec.
# 891-th simulation finished, 0.001022 sec.
# 892-th simulation finished, 0.001045 sec.
# 893-th simulation finished, 0.001018 sec.
# 894-th simulation finished, 0.001033 sec.
# 895-th simulation finished, 0.000998 sec.
# 896-th simulation finished, 0.001030 sec.
# 897-th simulation finished, 0.001009 sec.
# 898-th simulation finished, 0.001094 sec.
# 899-th simulation finished, 0.001079 sec.
# 900-th simulation finished, 0.001016 sec.
# 901-th simulation finished, 0.001034 sec.
# 902-th simulation finished, 0.001018 sec.
# 903-th simulation finished, 0.001022 sec.
# 904-th simulation finished, 0.001029 sec.
# 905-th simulation finished, 0.001042 sec.
# 906-th simulation finished, 0.001009 sec.
# 907-th simulation finished, 0.001027 sec.
# 908-th simulation finished, 0.001005 sec.
# 909-th simulation finished, 0.001022 sec.
# 910-th simulation finished, 0.001011 sec.
# 911-th simulation finished, 0.001019 sec.
# 912-th simulation finished, 0.001023 sec.
# 913-th simulation finished, 0.001028 sec.
# 914-th simulation finished, 0.001007 sec.
# 915-th simulation finished, 0.001032 sec.
# 916-th simulation finished, 0.001011 sec.
# 917-th simulation finished, 0.001025 sec.
# 918-th simulation finished, 0.001003 sec.
# 919-th simulation finished, 0.001031 sec.
# 920-th simulation finished, 0.001013 sec.
# 921-th simulation finished, 0.001033 sec.
# 922-th simulation finished, 0.001017 sec.
# 923-th simulation finished, 0.001026 sec.
# 924-th simulation finished, 0.001005 sec.
# 925-th simulation finished, 0.001027 sec.
# 926-th simulation finished, 0.001026 sec.
# 927-th simulation finished, 0.001028 sec.
# 928-th simulation finished, 0.000999 sec.
# 929-th simulation finished, 0.001019 sec.
# 930-th simulation finished, 0.001007 sec.
# 931-th simulation finished, 0.001025 sec.
# 932-th simulation finished, 0.001039 sec.
# 933-th simulation finished, 0.001093 sec.
# 934-th simulation finished, 0.001019 sec.
# 935-th simulation finished, 0.001021 sec.
# 936-th simulation finished, 0.001013 sec.
# 937-th simulation finished, 0.001039 sec.
# 938-th simulation finished, 0.001043 sec.
# 939-th simulation finished, 0.001055 sec.
# 940-th simulation finished, 0.001021 sec.
# 941-th simulation finished, 0.001038 sec.
# 942-th simulation finished, 0.001041 sec.
# 943-th simulation finished, 0.001050 sec.
# 944-th simulation finished, 0.001782 sec.
# 945-th simulation finished, 0.001409 sec.
# 946-th simulation finished, 0.001046 sec.
# 947-th simulation finished, 0.001025 sec.
# 948-th simulation finished, 0.001023 sec.
# 949-th simulation finished, 0.001017 sec.
# 950-th simulation finished, 0.001040 sec.
# 951-th simulation finished, 0.001030 sec.
# 952-th simulation finished, 0.001052 sec.
# 953-th simulation finished, 0.001019 sec.
# 954-th simulation finished, 0.001012 sec.
# 955-th simulation finished, 0.001032 sec.
# 956-th simulation finished, 0.001020 sec.
# 957-th simulation finished, 0.001020 sec.
# 958-th simulation finished, 0.001014 sec.
# 959-th simulation finished, 0.001017 sec.
# 960-th simulation finished, 0.001016 sec.
# 961-th simulation finished, 0.001018 sec.
# 962-th simulation finished, 0.001010 sec.
# 963-th simulation finished, 0.001034 sec.
# 964-th simulation finished, 0.001017 sec.
# 965-th simulation finished, 0.001026 sec.
# 966-th simulation finished, 0.001060 sec.
# 967-th simulation finished, 0.001053 sec.
# 968-th simulation finished, 0.001014 sec.
# 969-th simulation finished, 0.001028 sec.
# 970-th simulation finished, 0.001008 sec.
# 971-th simulation finished, 0.001027 sec.
# 972-th simulation finished, 0.001018 sec.
# 973-th simulation finished, 0.001029 sec.
# 974-th simulation finished, 0.001025 sec.
# 975-th simulation finished, 0.001082 sec.
# 976-th simulation finished, 0.001036 sec.
# 977-th simulation finished, 0.001051 sec.
# 978-th simulation finished, 0.001028 sec.
# 979-th simulation finished, 0.001047 sec.
# 980-th simulation finished, 0.001035 sec.
# 981-th simulation finished, 0.001065 sec.
# 982-th simulation finished, 0.001032 sec.
# 983-th simulation finished, 0.001054 sec.
# 984-th simulation finished, 0.001028 sec.
# 985-th simulation finished, 0.001049 sec.
# 986-th simulation finished, 0.001041 sec.
# 987-th simulation finished, 0.001054 sec.
# 988-th simulation finished, 0.001040 sec.
# 989-th simulation finished, 0.001066 sec.
# 990-th simulation finished, 0.001037 sec.
# 991-th simulation finished, 0.001058 sec.
# 992-th simulation finished, 0.001059 sec.
# 993-th simulation finished, 0.001059 sec.
# 994-th simulation finished, 0.001032 sec.
# 995-th simulation finished, 0.001039 sec.
# 996-th simulation finished, 0.001028 sec.
# 997-th simulation finished, 0.001058 sec.
# 998-th simulation finished, 0.001030 sec.
# 999-th simulation finished, 0.001080 sec.
# 1000-th simulation finished, 0.001079 sec.

# %%
plt.hist(bsim[:,1])
plt.axvline(beta[1], color='red')

# %%
stats.probplot(bsim[:,1], dist = 'norm', plot=plt, fit=True)
# plt.plot([0, 1], [0, 1], color='black')
plt.show()

# %%
plt.hist(Ts_dth)
# Out:
# (array([ 41., 137., 277., 256., 179.,  74.,  29.,   6.,   0.,   1.]),
#  array([-2.48981358, -1.72776564, -0.96571769, -0.20366975,  0.55837819,
#          1.32042613,  2.08247407,  2.84452201,  3.60656995,  4.36861789,
#          5.13066583]),
#  <BarContainer object of 10 artists>)

# %%
stats.probplot(ps_dth, dist = 'uniform', plot=plt, fit=False)
plt.plot([0, 1], [0, 1], color='black')
plt.show()

# %%
np.mean(np.abs(ps_dth) > 0.05)
# Out:
# 0.932

# %%
stats.probplot(ps_sdw, dist = 'uniform', plot=plt, fit=False)
plt.plot([0, 1], [0, 1], color='black')
plt.show()

# %%
np.mean(np.abs(ps_sdw) > 0.05)
# Out:
# 0.899
