# %%
import os, importlib, sys, time

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import scipy.linalg as la
import scipy.stats as stats
import scipy.optimize as opt

# %%
import freqepid

# %% [markdown]
# # 1. parameters

# %%
T = 60
T0 = 40

# %%
GPi = np.load('data/GPi.npz')

# %% [markdown]
# ## observation parameters

# %%
alpha = 0.01
r_Y = 10

# %% [markdown]
# $$Y_t = NegBinom( \frac{EY_t}{r_Y + EY_t}, r_Y )$$
#
# $$ EY_t = \alpha\sum_{s=1}^{t-1} I_s \pi_{t-s} $$

# %% [markdown]
# ## latent parameters

# %%
d = 2
beta = np.array([0.25, -2.45])

# %%
r_I = 100
K = 6.5

# %% [markdown]
# $$I_t = NegBinom( \frac{EI_t}{r_I + EI_t}, r_I )$$
#
# $$ EI_t = R(\bar{A}_t, \beta) \sum_{s=1}^{t-1} I_s g_{t-s} $$
#
# $$R(\bar{A}_t, \beta) = \frac{K}{1+\exp(- \beta^\top A_t)}$$

# %% [markdown]
# ## seed values

# %%
mu = np.log(100)

# %% [markdown]
# $$I_{[-T_0,0)} = \exp(\mu_0)$$

# %% [markdown]
# # 2. simulation

# %%
num_sim = 1000

# %% [markdown]
# ## load simulation

# %%
data = pd.read_feather('data/simulation_randinf_1.feather')

# %%
data
# Out:
#        sim  date         R          EI  infection         EY  death  \
# 0        0     0  3.654147  365.412210      399.0   0.956069      0
# 1        0     1  3.654147  385.435983      503.0   0.962544      0
# 2        0     2  3.654147  465.159133      437.0   0.968304      0
# 3        0     3  3.654147  597.396974      649.0   0.973840      1
# 4        0     4  3.654147  762.880480      808.0   0.980570      1
# ...    ...   ...       ...         ...        ...        ...    ...
# 59995  999    55  0.648378  375.180437      339.0  16.169417     18
# 59996  999    56  0.648378  354.125362      386.0  15.366388     14
# 59997  999    57  0.648378  334.331543      341.0  14.592187     13
# 59998  999    58  0.648378  316.412701      325.0  13.841366      6
# 59999  999    59  0.648378  299.660381      265.0  13.123721     23
#
#        intervention
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 59995             1
# 59996             1
# 59997             1
# 59998             1
# 59999             1
#
# [60000 rows x 8 columns]

# %% [markdown]
# # 3. Fit

# %%
model = freqepid.Model(GPi['g'], GPi['pi'], alpha, K, T0, "nbinom")

# %%
nsim = np.zeros(num_sim)
msim = np.zeros(num_sim)
bsim = np.zeros((num_sim,d))

# %%
for iter_sim in np.arange(num_sim):
    start_sim = time.time()
    
    data_i = data[data['sim']==iter_sim]
    A = np.stack([np.full(T, 1), data_i["intervention"].to_numpy()], -1)
    Y = data_i["death"].to_numpy()
    
    # fit
    nmle, mmle, bmle, ll =\
    model.fit(A, Y, n_iter=500, step_size=1,
              history=False, verbose=False)
    
    nsim[iter_sim] = nmle
    msim[iter_sim] = mmle
    bsim[iter_sim,:] = bmle
    
    sys.__stdout__.write("%d-th simulation finished, %f sec.\n"
                         %(iter_sim+1, time.time()-start_sim))
    sys.__stdout__.flush()
# Out:
# /Users/blueconet/mambaforge/envs/freqepid/lib/python3.10/site-packages/freqepid/model.py:140: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   bhaty = np.linalg.lstsq(Xy, Yy)[0]
# 1-th simulation finished, 3.006137 sec.
# 2-th simulation finished, 2.897541 sec.
# 3-th simulation finished, 3.007220 sec.
# 4-th simulation finished, 2.847811 sec.
# 5-th simulation finished, 3.220155 sec.
# 6-th simulation finished, 3.218339 sec.
# 7-th simulation finished, 2.718486 sec.
# 8-th simulation finished, 2.913473 sec.
# 9-th simulation finished, 2.687032 sec.
# 10-th simulation finished, 3.385433 sec.
# 11-th simulation finished, 3.065475 sec.
# 12-th simulation finished, 3.131058 sec.
# 13-th simulation finished, 3.008048 sec.
# 14-th simulation finished, 3.073901 sec.
# 15-th simulation finished, 2.726753 sec.
# 16-th simulation finished, 3.144393 sec.
# 17-th simulation finished, 2.782844 sec.
# 18-th simulation finished, 3.116831 sec.
# 19-th simulation finished, 3.324594 sec.
# 20-th simulation finished, 2.827610 sec.
# 21-th simulation finished, 2.772769 sec.
# 22-th simulation finished, 3.640340 sec.
# 23-th simulation finished, 3.224004 sec.
# 24-th simulation finished, 2.780574 sec.
# 25-th simulation finished, 3.261191 sec.
# 26-th simulation finished, 2.761718 sec.
# 27-th simulation finished, 3.216486 sec.
# 28-th simulation finished, 3.109655 sec.
# 29-th simulation finished, 2.900723 sec.
# 30-th simulation finished, 2.979653 sec.
# 31-th simulation finished, 3.291060 sec.
# 32-th simulation finished, 3.251012 sec.
# 33-th simulation finished, 2.883159 sec.
# 34-th simulation finished, 2.956266 sec.
# 35-th simulation finished, 3.154754 sec.
# 36-th simulation finished, 2.754059 sec.
# 37-th simulation finished, 2.878458 sec.
# 38-th simulation finished, 2.938295 sec.
# 39-th simulation finished, 3.089730 sec.
# 40-th simulation finished, 3.334405 sec.
# 41-th simulation finished, 3.054038 sec.
# 42-th simulation finished, 3.171963 sec.
# 43-th simulation finished, 2.924916 sec.
# 44-th simulation finished, 2.954016 sec.
# 45-th simulation finished, 2.876009 sec.
# 46-th simulation finished, 3.525334 sec.
# 47-th simulation finished, 2.834048 sec.
# 48-th simulation finished, 3.318230 sec.
# 49-th simulation finished, 3.312997 sec.
# 50-th simulation finished, 2.798120 sec.
# 51-th simulation finished, 2.989749 sec.
# 52-th simulation finished, 2.789204 sec.
# 53-th simulation finished, 3.000658 sec.
# 54-th simulation finished, 2.765341 sec.
# 55-th simulation finished, 2.752206 sec.
# 56-th simulation finished, 2.806164 sec.
# 57-th simulation finished, 3.108423 sec.
# 58-th simulation finished, 2.945745 sec.
# 59-th simulation finished, 2.898516 sec.
# 60-th simulation finished, 2.989799 sec.
# 61-th simulation finished, 3.261301 sec.
# 62-th simulation finished, 2.882321 sec.
# 63-th simulation finished, 2.839623 sec.
# 64-th simulation finished, 2.956817 sec.
# 65-th simulation finished, 2.882689 sec.
# 66-th simulation finished, 2.890485 sec.
# 67-th simulation finished, 2.810878 sec.
# 68-th simulation finished, 2.929871 sec.
# 69-th simulation finished, 3.044866 sec.
# 70-th simulation finished, 3.018312 sec.
# 71-th simulation finished, 2.784657 sec.
# 72-th simulation finished, 3.464585 sec.
# 73-th simulation finished, 3.085113 sec.
# 74-th simulation finished, 3.449747 sec.
# 75-th simulation finished, 3.279195 sec.
# 76-th simulation finished, 3.685772 sec.
# 77-th simulation finished, 3.751167 sec.
# 78-th simulation finished, 3.011085 sec.
# 79-th simulation finished, 3.644242 sec.
# 80-th simulation finished, 2.868356 sec.
# 81-th simulation finished, 2.925618 sec.
# 82-th simulation finished, 3.177759 sec.
# 83-th simulation finished, 3.213534 sec.
# 84-th simulation finished, 2.778101 sec.
# 85-th simulation finished, 3.582214 sec.
# 86-th simulation finished, 3.444381 sec.
# 87-th simulation finished, 2.777993 sec.
# 88-th simulation finished, 3.210838 sec.
# 89-th simulation finished, 3.525196 sec.
# 90-th simulation finished, 2.875241 sec.
# 91-th simulation finished, 3.256359 sec.
# 92-th simulation finished, 2.909220 sec.
# 93-th simulation finished, 2.755922 sec.
# 94-th simulation finished, 2.842504 sec.
# 95-th simulation finished, 2.746697 sec.
# 96-th simulation finished, 2.960720 sec.
# 97-th simulation finished, 2.762797 sec.
# 98-th simulation finished, 3.200278 sec.
# 99-th simulation finished, 3.246879 sec.
# 100-th simulation finished, 3.264569 sec.
# 101-th simulation finished, 2.956903 sec.
# 102-th simulation finished, 3.247445 sec.
# 103-th simulation finished, 2.910498 sec.
# 104-th simulation finished, 3.394307 sec.
# 105-th simulation finished, 3.658915 sec.
# 106-th simulation finished, 3.401761 sec.
# 107-th simulation finished, 2.798607 sec.
# 108-th simulation finished, 2.841098 sec.
# 109-th simulation finished, 2.820054 sec.
# 110-th simulation finished, 3.126257 sec.
# 111-th simulation finished, 3.404666 sec.
# 112-th simulation finished, 3.175066 sec.
# 113-th simulation finished, 3.188571 sec.
# 114-th simulation finished, 3.133283 sec.
# 115-th simulation finished, 2.955707 sec.
# 116-th simulation finished, 2.917479 sec.
# 117-th simulation finished, 3.275176 sec.
# 118-th simulation finished, 3.081825 sec.
# 119-th simulation finished, 2.672998 sec.
# 120-th simulation finished, 2.982200 sec.
# 121-th simulation finished, 3.120534 sec.
# 122-th simulation finished, 3.193672 sec.
# 123-th simulation finished, 2.704481 sec.
# 124-th simulation finished, 3.235263 sec.
# 125-th simulation finished, 3.166887 sec.
# 126-th simulation finished, 2.726892 sec.
# 127-th simulation finished, 3.048526 sec.
# 128-th simulation finished, 3.316800 sec.
# 129-th simulation finished, 3.151714 sec.
# 130-th simulation finished, 2.725071 sec.
# 131-th simulation finished, 2.727912 sec.
# 132-th simulation finished, 2.846323 sec.
# 133-th simulation finished, 3.431046 sec.
# 134-th simulation finished, 3.330519 sec.
# 135-th simulation finished, 2.832859 sec.
# 136-th simulation finished, 3.480594 sec.
# 137-th simulation finished, 2.868630 sec.
# 138-th simulation finished, 2.976612 sec.
# 139-th simulation finished, 3.252547 sec.
# 140-th simulation finished, 2.843225 sec.
# 141-th simulation finished, 2.991358 sec.
# 142-th simulation finished, 3.314860 sec.
# 143-th simulation finished, 3.021444 sec.
# 144-th simulation finished, 3.418189 sec.
# 145-th simulation finished, 3.029260 sec.
# 146-th simulation finished, 3.142323 sec.
# 147-th simulation finished, 3.261644 sec.
# 148-th simulation finished, 3.336373 sec.
# 149-th simulation finished, 3.075460 sec.
# 150-th simulation finished, 3.454642 sec.
# 151-th simulation finished, 2.912057 sec.
# 152-th simulation finished, 2.864958 sec.
# 153-th simulation finished, 3.338783 sec.
# 154-th simulation finished, 3.023837 sec.
# 155-th simulation finished, 3.487726 sec.
# 156-th simulation finished, 3.351720 sec.
# 157-th simulation finished, 2.654304 sec.
# 158-th simulation finished, 3.192083 sec.
# 159-th simulation finished, 2.788698 sec.
# 160-th simulation finished, 2.922344 sec.
# 161-th simulation finished, 2.761081 sec.
# 162-th simulation finished, 2.925633 sec.
# 163-th simulation finished, 3.173781 sec.
# 164-th simulation finished, 2.764024 sec.
# 165-th simulation finished, 3.170546 sec.
# 166-th simulation finished, 3.009537 sec.
# 167-th simulation finished, 3.339335 sec.
# 168-th simulation finished, 2.904723 sec.
# 169-th simulation finished, 3.138661 sec.
# 170-th simulation finished, 3.154099 sec.
# 171-th simulation finished, 2.897502 sec.
# 172-th simulation finished, 3.185425 sec.
# 173-th simulation finished, 2.983259 sec.
# 174-th simulation finished, 3.355771 sec.
# 175-th simulation finished, 3.342758 sec.
# 176-th simulation finished, 2.774051 sec.
# 177-th simulation finished, 2.889746 sec.
# 178-th simulation finished, 3.050191 sec.
# 179-th simulation finished, 2.975124 sec.
# 180-th simulation finished, 2.813919 sec.
# 181-th simulation finished, 2.819812 sec.
# 182-th simulation finished, 3.504116 sec.
# 183-th simulation finished, 2.888858 sec.
# 184-th simulation finished, 2.831688 sec.
# 185-th simulation finished, 2.775414 sec.
# 186-th simulation finished, 2.956268 sec.
# 187-th simulation finished, 2.785864 sec.
# 188-th simulation finished, 2.850426 sec.
# 189-th simulation finished, 2.575004 sec.
# 190-th simulation finished, 2.960959 sec.
# 191-th simulation finished, 2.939236 sec.
# 192-th simulation finished, 3.116421 sec.
# 193-th simulation finished, 2.953827 sec.
# 194-th simulation finished, 3.156696 sec.
# 195-th simulation finished, 2.816445 sec.
# 196-th simulation finished, 3.248452 sec.
# 197-th simulation finished, 3.195769 sec.
# 198-th simulation finished, 3.147241 sec.
# 199-th simulation finished, 3.393639 sec.
# 200-th simulation finished, 2.934880 sec.
# 201-th simulation finished, 2.826718 sec.
# 202-th simulation finished, 2.874815 sec.
# 203-th simulation finished, 3.623270 sec.
# 204-th simulation finished, 3.283664 sec.
# 205-th simulation finished, 2.792899 sec.
# 206-th simulation finished, 3.198070 sec.
# 207-th simulation finished, 3.112351 sec.
# 208-th simulation finished, 3.310759 sec.
# 209-th simulation finished, 2.986630 sec.
# 210-th simulation finished, 2.919546 sec.
# 211-th simulation finished, 3.181961 sec.
# 212-th simulation finished, 3.428667 sec.
# 213-th simulation finished, 3.159681 sec.
# 214-th simulation finished, 3.301511 sec.
# 215-th simulation finished, 3.220861 sec.
# 216-th simulation finished, 3.468809 sec.
# 217-th simulation finished, 2.925148 sec.
# 218-th simulation finished, 2.814267 sec.
# 219-th simulation finished, 3.299604 sec.
# 220-th simulation finished, 3.321483 sec.
# 221-th simulation finished, 3.517291 sec.
# 222-th simulation finished, 3.068477 sec.
# 223-th simulation finished, 3.275616 sec.
# 224-th simulation finished, 2.872171 sec.
# 225-th simulation finished, 3.565755 sec.
# 226-th simulation finished, 3.415441 sec.
# 227-th simulation finished, 3.155407 sec.
# 228-th simulation finished, 3.065078 sec.
# 229-th simulation finished, 2.805824 sec.
# 230-th simulation finished, 2.746648 sec.
# 231-th simulation finished, 2.882804 sec.
# 232-th simulation finished, 2.650286 sec.
# 233-th simulation finished, 3.113727 sec.
# 234-th simulation finished, 3.189823 sec.
# 235-th simulation finished, 2.850321 sec.
# 236-th simulation finished, 3.030414 sec.
# 237-th simulation finished, 3.162707 sec.
# 238-th simulation finished, 2.818468 sec.
# 239-th simulation finished, 3.605692 sec.
# 240-th simulation finished, 3.319147 sec.
# 241-th simulation finished, 2.982401 sec.
# 242-th simulation finished, 3.101182 sec.
# 243-th simulation finished, 2.902209 sec.
# 244-th simulation finished, 2.779938 sec.
# 245-th simulation finished, 3.160971 sec.
# 246-th simulation finished, 3.052100 sec.
# 247-th simulation finished, 2.812041 sec.
# 248-th simulation finished, 3.048355 sec.
# 249-th simulation finished, 2.804243 sec.
# 250-th simulation finished, 2.692066 sec.
# 251-th simulation finished, 3.031132 sec.
# 252-th simulation finished, 2.977477 sec.
# 253-th simulation finished, 3.330197 sec.
# 254-th simulation finished, 3.073796 sec.
# 255-th simulation finished, 2.798827 sec.
# 256-th simulation finished, 3.154404 sec.
# 257-th simulation finished, 2.852492 sec.
# 258-th simulation finished, 2.795897 sec.
# 259-th simulation finished, 3.210826 sec.
# 260-th simulation finished, 3.138800 sec.
# 261-th simulation finished, 2.944372 sec.
# 262-th simulation finished, 2.587094 sec.
# 263-th simulation finished, 3.107153 sec.
# 264-th simulation finished, 2.936869 sec.
# 265-th simulation finished, 2.903642 sec.
# 266-th simulation finished, 3.142749 sec.
# 267-th simulation finished, 3.012777 sec.
# 268-th simulation finished, 3.355687 sec.
# 269-th simulation finished, 3.163068 sec.
# 270-th simulation finished, 3.027785 sec.
# 271-th simulation finished, 3.911794 sec.
# 272-th simulation finished, 3.749869 sec.
# 273-th simulation finished, 3.368225 sec.
# 274-th simulation finished, 3.059984 sec.
# 275-th simulation finished, 3.411637 sec.
# 276-th simulation finished, 3.121219 sec.
# 277-th simulation finished, 3.099344 sec.
# 278-th simulation finished, 3.271865 sec.
# 279-th simulation finished, 2.973298 sec.
# 280-th simulation finished, 2.810280 sec.
# 281-th simulation finished, 3.497280 sec.
# 282-th simulation finished, 2.988944 sec.
# 283-th simulation finished, 2.947476 sec.
# 284-th simulation finished, 3.133103 sec.
# 285-th simulation finished, 3.061977 sec.
# 286-th simulation finished, 3.374066 sec.
# 287-th simulation finished, 3.437484 sec.
# 288-th simulation finished, 3.276847 sec.
# 289-th simulation finished, 3.705528 sec.
# 290-th simulation finished, 3.283544 sec.
# 291-th simulation finished, 2.910063 sec.
# 292-th simulation finished, 3.028510 sec.
# 293-th simulation finished, 3.159958 sec.
# 294-th simulation finished, 3.019477 sec.
# 295-th simulation finished, 3.404319 sec.
# 296-th simulation finished, 3.205462 sec.
# 297-th simulation finished, 2.886205 sec.
# 298-th simulation finished, 2.778036 sec.
# 299-th simulation finished, 3.190017 sec.
# 300-th simulation finished, 2.924096 sec.
# 301-th simulation finished, 3.288592 sec.
# 302-th simulation finished, 3.472649 sec.
# 303-th simulation finished, 3.425546 sec.
# 304-th simulation finished, 3.246316 sec.
# 305-th simulation finished, 3.040902 sec.
# 306-th simulation finished, 2.675495 sec.
# 307-th simulation finished, 3.061816 sec.
# 308-th simulation finished, 2.930398 sec.
# 309-th simulation finished, 3.354618 sec.
# 310-th simulation finished, 3.227675 sec.
# 311-th simulation finished, 2.848450 sec.
# 312-th simulation finished, 3.353040 sec.
# 313-th simulation finished, 2.915334 sec.
# 314-th simulation finished, 2.990063 sec.
# 315-th simulation finished, 2.916588 sec.
# 316-th simulation finished, 2.996736 sec.
# 317-th simulation finished, 2.810220 sec.
# 318-th simulation finished, 2.686448 sec.
# 319-th simulation finished, 3.042807 sec.
# 320-th simulation finished, 3.179239 sec.
# 321-th simulation finished, 3.217398 sec.
# 322-th simulation finished, 3.039626 sec.
# 323-th simulation finished, 2.814115 sec.
# 324-th simulation finished, 2.883501 sec.
# 325-th simulation finished, 2.799761 sec.
# 326-th simulation finished, 3.022812 sec.
# 327-th simulation finished, 3.436111 sec.
# 328-th simulation finished, 2.851888 sec.
# 329-th simulation finished, 2.981770 sec.
# 330-th simulation finished, 2.967912 sec.
# 331-th simulation finished, 3.046062 sec.
# 332-th simulation finished, 3.378198 sec.
# 333-th simulation finished, 3.558886 sec.
# 334-th simulation finished, 2.762047 sec.
# 335-th simulation finished, 2.790241 sec.
# 336-th simulation finished, 2.898114 sec.
# 337-th simulation finished, 2.865401 sec.
# 338-th simulation finished, 3.144075 sec.
# 339-th simulation finished, 3.189074 sec.
# 340-th simulation finished, 2.862196 sec.
# 341-th simulation finished, 2.786957 sec.
# 342-th simulation finished, 3.193362 sec.
# 343-th simulation finished, 2.950070 sec.
# 344-th simulation finished, 2.926064 sec.
# 345-th simulation finished, 3.256033 sec.
# 346-th simulation finished, 3.078805 sec.
# 347-th simulation finished, 3.117149 sec.
# 348-th simulation finished, 2.943482 sec.
# 349-th simulation finished, 3.672839 sec.
# 350-th simulation finished, 3.567468 sec.
# 351-th simulation finished, 3.473374 sec.
# 352-th simulation finished, 2.754817 sec.
# 353-th simulation finished, 2.797983 sec.
# 354-th simulation finished, 3.378899 sec.
# 355-th simulation finished, 2.779122 sec.
# 356-th simulation finished, 2.797707 sec.
# 357-th simulation finished, 3.237676 sec.
# 358-th simulation finished, 2.859794 sec.
# 359-th simulation finished, 2.800555 sec.
# 360-th simulation finished, 3.282508 sec.
# 361-th simulation finished, 3.055433 sec.
# 362-th simulation finished, 2.800439 sec.
# 363-th simulation finished, 3.547193 sec.
# 364-th simulation finished, 2.837913 sec.
# 365-th simulation finished, 2.930346 sec.
# 366-th simulation finished, 2.977917 sec.
# 367-th simulation finished, 3.169904 sec.
# 368-th simulation finished, 2.990445 sec.
# 369-th simulation finished, 3.372041 sec.
# 370-th simulation finished, 3.208312 sec.
# 371-th simulation finished, 3.243165 sec.
# 372-th simulation finished, 3.131566 sec.
# 373-th simulation finished, 3.272546 sec.
# 374-th simulation finished, 3.596411 sec.
# 375-th simulation finished, 3.397584 sec.
# 376-th simulation finished, 2.998996 sec.
# 377-th simulation finished, 2.609352 sec.
# 378-th simulation finished, 3.565512 sec.
# 379-th simulation finished, 2.847084 sec.
# 380-th simulation finished, 3.054819 sec.
# 381-th simulation finished, 2.985217 sec.
# 382-th simulation finished, 3.614258 sec.
# 383-th simulation finished, 3.253023 sec.
# 384-th simulation finished, 3.393906 sec.
# 385-th simulation finished, 2.791927 sec.
# 386-th simulation finished, 3.300562 sec.
# 387-th simulation finished, 2.885189 sec.
# 388-th simulation finished, 3.288876 sec.
# 389-th simulation finished, 2.949020 sec.
# 390-th simulation finished, 3.435211 sec.
# 391-th simulation finished, 2.744627 sec.
# 392-th simulation finished, 2.829903 sec.
# 393-th simulation finished, 2.924785 sec.
# 394-th simulation finished, 3.040275 sec.
# 395-th simulation finished, 3.300162 sec.
# 396-th simulation finished, 3.319166 sec.
# 397-th simulation finished, 3.175043 sec.
# 398-th simulation finished, 3.341831 sec.
# 399-th simulation finished, 3.216887 sec.
# 400-th simulation finished, 3.265724 sec.
# 401-th simulation finished, 3.773672 sec.
# 402-th simulation finished, 3.039999 sec.
# 403-th simulation finished, 3.576839 sec.
# 404-th simulation finished, 2.959546 sec.
# 405-th simulation finished, 3.271189 sec.
# 406-th simulation finished, 2.748746 sec.
# 407-th simulation finished, 2.865853 sec.
# 408-th simulation finished, 2.885175 sec.
# 409-th simulation finished, 2.964261 sec.
# 410-th simulation finished, 2.807354 sec.
# 411-th simulation finished, 3.359197 sec.
# 412-th simulation finished, 2.772260 sec.
# 413-th simulation finished, 3.010668 sec.
# 414-th simulation finished, 2.970452 sec.
# 415-th simulation finished, 2.784958 sec.
# 416-th simulation finished, 2.742972 sec.
# 417-th simulation finished, 2.713153 sec.
# 418-th simulation finished, 3.324992 sec.
# 419-th simulation finished, 2.623512 sec.
# 420-th simulation finished, 2.640991 sec.
# 421-th simulation finished, 3.179510 sec.
# 422-th simulation finished, 3.059245 sec.
# 423-th simulation finished, 3.297693 sec.
# 424-th simulation finished, 3.217895 sec.
# 425-th simulation finished, 3.238685 sec.
# 426-th simulation finished, 3.336656 sec.
# 427-th simulation finished, 3.022863 sec.
# 428-th simulation finished, 3.192966 sec.
# 429-th simulation finished, 3.232227 sec.
# 430-th simulation finished, 4.071974 sec.
# 431-th simulation finished, 3.194910 sec.
# 432-th simulation finished, 2.835931 sec.
# 433-th simulation finished, 3.245673 sec.
# 434-th simulation finished, 3.100124 sec.
# 435-th simulation finished, 2.959638 sec.
# 436-th simulation finished, 3.339092 sec.
# 437-th simulation finished, 3.608438 sec.
# 438-th simulation finished, 2.847762 sec.
# 439-th simulation finished, 3.266315 sec.
# 440-th simulation finished, 3.015024 sec.
# 441-th simulation finished, 3.458201 sec.
# 442-th simulation finished, 3.249486 sec.
# 443-th simulation finished, 3.340797 sec.
# 444-th simulation finished, 3.166327 sec.
# 445-th simulation finished, 3.917551 sec.
# 446-th simulation finished, 2.843972 sec.
# 447-th simulation finished, 2.942071 sec.
# 448-th simulation finished, 3.045430 sec.
# 449-th simulation finished, 3.008023 sec.
# 450-th simulation finished, 2.936308 sec.
# 451-th simulation finished, 3.006070 sec.
# 452-th simulation finished, 2.801068 sec.
# 453-th simulation finished, 2.949471 sec.
# 454-th simulation finished, 3.021402 sec.
# 455-th simulation finished, 3.133183 sec.
# 456-th simulation finished, 91.905416 sec.
# 457-th simulation finished, 2.868878 sec.
# 458-th simulation finished, 3.014230 sec.
# 459-th simulation finished, 2.922471 sec.
# 460-th simulation finished, 2.731248 sec.
# 461-th simulation finished, 2.744993 sec.
# 462-th simulation finished, 2.730770 sec.
# 463-th simulation finished, 3.224042 sec.
# 464-th simulation finished, 3.829698 sec.
# 465-th simulation finished, 5.045688 sec.
# 466-th simulation finished, 5.415729 sec.
# 467-th simulation finished, 3.986896 sec.
# 468-th simulation finished, 3.871467 sec.
# 469-th simulation finished, 3.461872 sec.
# 470-th simulation finished, 113.525033 sec.
# 471-th simulation finished, 3.326943 sec.
# 472-th simulation finished, 2.892598 sec.
# 473-th simulation finished, 2.883421 sec.
# 474-th simulation finished, 3.342169 sec.
# 475-th simulation finished, 2.837957 sec.
# 476-th simulation finished, 2.934781 sec.
# 477-th simulation finished, 3.546912 sec.
# 478-th simulation finished, 3.700832 sec.
# 479-th simulation finished, 3.759970 sec.
# 480-th simulation finished, 3.643871 sec.
# 481-th simulation finished, 3.378232 sec.
# 482-th simulation finished, 4.232986 sec.
# 483-th simulation finished, 126.228099 sec.
# 484-th simulation finished, 3.275148 sec.
# 485-th simulation finished, 3.238295 sec.
# 486-th simulation finished, 3.361168 sec.
# 487-th simulation finished, 2.811634 sec.
# 488-th simulation finished, 2.952684 sec.
# 489-th simulation finished, 2.706108 sec.
# 490-th simulation finished, 3.105420 sec.
# 491-th simulation finished, 3.257086 sec.
# 492-th simulation finished, 3.356726 sec.
# 493-th simulation finished, 3.447262 sec.
# 494-th simulation finished, 3.291115 sec.
# 495-th simulation finished, 3.525299 sec.
# 496-th simulation finished, 3.527688 sec.
# 497-th simulation finished, 4.262069 sec.
# 498-th simulation finished, 26.903804 sec.
# 499-th simulation finished, 3.232581 sec.
# 500-th simulation finished, 3.310637 sec.
# 501-th simulation finished, 3.140351 sec.
# 502-th simulation finished, 2.809186 sec.
# 503-th simulation finished, 3.386266 sec.
# 504-th simulation finished, 3.446644 sec.
# 505-th simulation finished, 3.075716 sec.
# 506-th simulation finished, 3.492943 sec.
# 507-th simulation finished, 4.117512 sec.
# 508-th simulation finished, 3.652200 sec.
# 509-th simulation finished, 3.432229 sec.
# 510-th simulation finished, 3.385484 sec.
# 511-th simulation finished, 27.747933 sec.
# 512-th simulation finished, 3.433302 sec.
# 513-th simulation finished, 3.173580 sec.
# 514-th simulation finished, 3.313589 sec.
# 515-th simulation finished, 3.071990 sec.
# 516-th simulation finished, 2.888607 sec.
# 517-th simulation finished, 2.979019 sec.
# 518-th simulation finished, 2.993004 sec.
# 519-th simulation finished, 3.216394 sec.
# 520-th simulation finished, 3.948728 sec.
# 521-th simulation finished, 3.804799 sec.
# 522-th simulation finished, 3.614484 sec.
# 523-th simulation finished, 3.652826 sec.
# 524-th simulation finished, 3.341639 sec.
# 525-th simulation finished, 440.436343 sec.
# 526-th simulation finished, 3.869043 sec.
# 527-th simulation finished, 2.927629 sec.
# 528-th simulation finished, 3.304603 sec.
# 529-th simulation finished, 3.260583 sec.
# 530-th simulation finished, 2.889747 sec.
# 531-th simulation finished, 3.190059 sec.
# 532-th simulation finished, 2.784756 sec.
# 533-th simulation finished, 3.174347 sec.
# 534-th simulation finished, 2.976412 sec.
# 535-th simulation finished, 3.023129 sec.
# 536-th simulation finished, 2.869865 sec.
# 537-th simulation finished, 3.318300 sec.
# 538-th simulation finished, 3.348491 sec.
# 539-th simulation finished, 3.195126 sec.
# 540-th simulation finished, 2.993147 sec.
# 541-th simulation finished, 3.213696 sec.
# 542-th simulation finished, 2.911762 sec.
# 543-th simulation finished, 3.384852 sec.
# 544-th simulation finished, 3.000132 sec.
# 545-th simulation finished, 2.735052 sec.
# 546-th simulation finished, 2.803000 sec.
# 547-th simulation finished, 3.510937 sec.
# 548-th simulation finished, 3.398474 sec.
# 549-th simulation finished, 3.138504 sec.
# 550-th simulation finished, 3.006981 sec.
# 551-th simulation finished, 3.955007 sec.
# 552-th simulation finished, 3.154745 sec.
# 553-th simulation finished, 2.725652 sec.
# 554-th simulation finished, 2.951219 sec.
# 555-th simulation finished, 3.106290 sec.
# 556-th simulation finished, 2.787918 sec.
# 557-th simulation finished, 2.672336 sec.
# 558-th simulation finished, 2.875344 sec.
# 559-th simulation finished, 3.286303 sec.
# 560-th simulation finished, 2.820180 sec.
# 561-th simulation finished, 3.229843 sec.
# 562-th simulation finished, 3.462025 sec.
# 563-th simulation finished, 2.678794 sec.
# 564-th simulation finished, 3.559525 sec.
# 565-th simulation finished, 2.941554 sec.
# 566-th simulation finished, 2.950212 sec.
# 567-th simulation finished, 3.318444 sec.
# 568-th simulation finished, 2.814791 sec.
# 569-th simulation finished, 2.685658 sec.
# 570-th simulation finished, 3.272605 sec.
# 571-th simulation finished, 2.977261 sec.
# 572-th simulation finished, 2.918414 sec.
# 573-th simulation finished, 2.713166 sec.
# 574-th simulation finished, 3.213295 sec.
# 575-th simulation finished, 2.934983 sec.
# 576-th simulation finished, 2.881712 sec.
# 577-th simulation finished, 2.915761 sec.
# 578-th simulation finished, 2.727030 sec.
# 579-th simulation finished, 3.188552 sec.
# 580-th simulation finished, 3.330457 sec.
# 581-th simulation finished, 3.146325 sec.
# 582-th simulation finished, 4.065741 sec.
# 583-th simulation finished, 2.894427 sec.
# 584-th simulation finished, 3.568971 sec.
# 585-th simulation finished, 2.972043 sec.
# 586-th simulation finished, 2.974721 sec.
# 587-th simulation finished, 2.732567 sec.
# 588-th simulation finished, 3.594770 sec.
# 589-th simulation finished, 3.190611 sec.
# 590-th simulation finished, 2.917789 sec.
# 591-th simulation finished, 3.006179 sec.
# 592-th simulation finished, 2.785633 sec.
# 593-th simulation finished, 3.042683 sec.
# 594-th simulation finished, 3.297351 sec.
# 595-th simulation finished, 2.691041 sec.
# 596-th simulation finished, 3.038133 sec.
# 597-th simulation finished, 3.194516 sec.
# 598-th simulation finished, 2.857633 sec.
# 599-th simulation finished, 3.373157 sec.
# 600-th simulation finished, 2.878813 sec.
# 601-th simulation finished, 2.940017 sec.
# 602-th simulation finished, 2.768091 sec.
# 603-th simulation finished, 3.114914 sec.
# 604-th simulation finished, 3.237720 sec.
# 605-th simulation finished, 3.637412 sec.
# 606-th simulation finished, 3.203266 sec.
# 607-th simulation finished, 2.919677 sec.
# 608-th simulation finished, 2.718283 sec.
# 609-th simulation finished, 2.781344 sec.
# 610-th simulation finished, 3.353826 sec.
# 611-th simulation finished, 3.072803 sec.
# 612-th simulation finished, 2.807057 sec.
# 613-th simulation finished, 2.859866 sec.
# 614-th simulation finished, 3.127862 sec.
# 615-th simulation finished, 2.868531 sec.
# 616-th simulation finished, 2.860153 sec.
# 617-th simulation finished, 3.310010 sec.
# 618-th simulation finished, 2.864349 sec.
# 619-th simulation finished, 3.228128 sec.
# 620-th simulation finished, 3.048445 sec.
# 621-th simulation finished, 3.284931 sec.
# 622-th simulation finished, 3.342790 sec.
# 623-th simulation finished, 3.298622 sec.
# 624-th simulation finished, 2.765488 sec.
# 625-th simulation finished, 3.104614 sec.
# 626-th simulation finished, 3.692534 sec.
# 627-th simulation finished, 3.256089 sec.
# 628-th simulation finished, 3.126868 sec.
# 629-th simulation finished, 2.914877 sec.
# 630-th simulation finished, 3.408771 sec.
# 631-th simulation finished, 3.221423 sec.
# 632-th simulation finished, 2.824187 sec.
# 633-th simulation finished, 2.817347 sec.
# 634-th simulation finished, 3.095979 sec.
# 635-th simulation finished, 3.021891 sec.
# 636-th simulation finished, 3.448512 sec.
# 637-th simulation finished, 3.522185 sec.
# 638-th simulation finished, 2.858877 sec.
# 639-th simulation finished, 2.731608 sec.
# 640-th simulation finished, 2.938835 sec.
# 641-th simulation finished, 2.704469 sec.
# 642-th simulation finished, 2.882022 sec.
# 643-th simulation finished, 3.219089 sec.
# 644-th simulation finished, 2.857591 sec.
# 645-th simulation finished, 2.974336 sec.
# 646-th simulation finished, 8.251075 sec.
# 647-th simulation finished, 3.239349 sec.
# 648-th simulation finished, 2.803678 sec.
# 649-th simulation finished, 2.805155 sec.
# 650-th simulation finished, 3.019511 sec.
# 651-th simulation finished, 2.766869 sec.
# 652-th simulation finished, 3.126212 sec.
# 653-th simulation finished, 2.758044 sec.
# 654-th simulation finished, 3.514909 sec.
# 655-th simulation finished, 2.876894 sec.
# 656-th simulation finished, 2.859963 sec.
# 657-th simulation finished, 2.926932 sec.
# 658-th simulation finished, 2.898221 sec.
# 659-th simulation finished, 2.910094 sec.
# 660-th simulation finished, 2.911617 sec.
# 661-th simulation finished, 3.338645 sec.
# 662-th simulation finished, 2.977042 sec.
# 663-th simulation finished, 2.880498 sec.
# 664-th simulation finished, 3.274272 sec.
# 665-th simulation finished, 2.744719 sec.
# 666-th simulation finished, 3.280734 sec.
# 667-th simulation finished, 2.976400 sec.
# 668-th simulation finished, 3.444227 sec.
# 669-th simulation finished, 3.332509 sec.
# 670-th simulation finished, 3.374747 sec.
# 671-th simulation finished, 3.288531 sec.
# 672-th simulation finished, 3.541646 sec.
# 673-th simulation finished, 2.914384 sec.
# 674-th simulation finished, 2.924235 sec.
# 675-th simulation finished, 3.269709 sec.
# 676-th simulation finished, 2.899936 sec.
# 677-th simulation finished, 2.915074 sec.
# 678-th simulation finished, 3.596303 sec.
# 679-th simulation finished, 2.650138 sec.
# 680-th simulation finished, 3.104912 sec.
# 681-th simulation finished, 3.291121 sec.
# 682-th simulation finished, 2.893960 sec.
# 683-th simulation finished, 3.003332 sec.
# 684-th simulation finished, 3.143256 sec.
# 685-th simulation finished, 3.274662 sec.
# 686-th simulation finished, 2.956629 sec.
# 687-th simulation finished, 2.881494 sec.
# 688-th simulation finished, 2.757849 sec.
# 689-th simulation finished, 3.201959 sec.
# 690-th simulation finished, 2.814809 sec.
# 691-th simulation finished, 3.500499 sec.
# 692-th simulation finished, 2.752834 sec.
# 693-th simulation finished, 2.723839 sec.
# 694-th simulation finished, 2.919504 sec.
# 695-th simulation finished, 3.378149 sec.
# 696-th simulation finished, 3.175521 sec.
# 697-th simulation finished, 2.739354 sec.
# 698-th simulation finished, 3.389765 sec.
# 699-th simulation finished, 3.321061 sec.
# 700-th simulation finished, 3.008938 sec.
# 701-th simulation finished, 2.883605 sec.
# 702-th simulation finished, 2.946018 sec.
# 703-th simulation finished, 2.775152 sec.
# 704-th simulation finished, 2.929091 sec.
# 705-th simulation finished, 2.926030 sec.
# 706-th simulation finished, 3.249679 sec.
# 707-th simulation finished, 2.986212 sec.
# 708-th simulation finished, 3.435702 sec.
# 709-th simulation finished, 2.615631 sec.
# 710-th simulation finished, 3.137053 sec.
# 711-th simulation finished, 3.829979 sec.
# 712-th simulation finished, 3.056568 sec.
# 713-th simulation finished, 3.161350 sec.
# 714-th simulation finished, 2.830765 sec.
# 715-th simulation finished, 3.010028 sec.
# 716-th simulation finished, 2.770929 sec.
# 717-th simulation finished, 2.544024 sec.
# 718-th simulation finished, 2.849495 sec.
# 719-th simulation finished, 3.035344 sec.
# 720-th simulation finished, 2.786326 sec.
# 721-th simulation finished, 3.519519 sec.
# 722-th simulation finished, 2.774838 sec.
# 723-th simulation finished, 3.136935 sec.
# 724-th simulation finished, 2.907354 sec.
# 725-th simulation finished, 3.278999 sec.
# 726-th simulation finished, 2.805147 sec.
# 727-th simulation finished, 2.857133 sec.
# 728-th simulation finished, 3.242679 sec.
# 729-th simulation finished, 3.286134 sec.
# 730-th simulation finished, 2.943927 sec.
# 731-th simulation finished, 2.665891 sec.
# 732-th simulation finished, 3.019318 sec.
# 733-th simulation finished, 2.937047 sec.
# 734-th simulation finished, 3.044227 sec.
# 735-th simulation finished, 3.025102 sec.
# 736-th simulation finished, 3.098545 sec.
# 737-th simulation finished, 3.787935 sec.
# 738-th simulation finished, 3.325412 sec.
# 739-th simulation finished, 3.074294 sec.
# 740-th simulation finished, 3.430735 sec.
# 741-th simulation finished, 2.775051 sec.
# 742-th simulation finished, 3.075487 sec.
# 743-th simulation finished, 3.008237 sec.
# 744-th simulation finished, 3.064214 sec.
# 745-th simulation finished, 2.861763 sec.
# 746-th simulation finished, 2.793536 sec.
# 747-th simulation finished, 2.907782 sec.
# 748-th simulation finished, 2.895002 sec.
# 749-th simulation finished, 3.148567 sec.
# 750-th simulation finished, 2.908758 sec.
# 751-th simulation finished, 2.917774 sec.
# 752-th simulation finished, 2.783843 sec.
# 753-th simulation finished, 2.786288 sec.
# 754-th simulation finished, 3.063435 sec.
# 755-th simulation finished, 2.952803 sec.
# 756-th simulation finished, 2.897154 sec.
# 757-th simulation finished, 3.474954 sec.
# 758-th simulation finished, 3.428416 sec.
# 759-th simulation finished, 3.051272 sec.
# 760-th simulation finished, 3.302619 sec.
# 761-th simulation finished, 2.943973 sec.
# 762-th simulation finished, 2.937829 sec.
# 763-th simulation finished, 2.798568 sec.
# 764-th simulation finished, 3.016142 sec.
# 765-th simulation finished, 2.809842 sec.
# 766-th simulation finished, 2.802986 sec.
# 767-th simulation finished, 2.694557 sec.
# 768-th simulation finished, 3.180257 sec.
# 769-th simulation finished, 2.835091 sec.
# 770-th simulation finished, 3.378707 sec.
# 771-th simulation finished, 3.244764 sec.
# 772-th simulation finished, 3.378961 sec.
# 773-th simulation finished, 2.967466 sec.
# 774-th simulation finished, 2.941093 sec.
# 775-th simulation finished, 2.961292 sec.
# 776-th simulation finished, 2.965383 sec.
# 777-th simulation finished, 2.920993 sec.
# 778-th simulation finished, 3.169903 sec.
# 779-th simulation finished, 2.782379 sec.
# 780-th simulation finished, 2.743190 sec.
# 781-th simulation finished, 3.322142 sec.
# 782-th simulation finished, 3.235392 sec.
# 783-th simulation finished, 2.932070 sec.
# 784-th simulation finished, 2.937188 sec.
# 785-th simulation finished, 2.819849 sec.
# 786-th simulation finished, 3.236652 sec.
# 787-th simulation finished, 2.873188 sec.
# 788-th simulation finished, 2.899023 sec.
# 789-th simulation finished, 3.100655 sec.
# 790-th simulation finished, 3.156952 sec.
# 791-th simulation finished, 3.547234 sec.
# 792-th simulation finished, 3.563356 sec.
# 793-th simulation finished, 3.245281 sec.
# 794-th simulation finished, 2.717902 sec.
# 795-th simulation finished, 2.871148 sec.
# 796-th simulation finished, 3.116978 sec.
# 797-th simulation finished, 3.445059 sec.
# 798-th simulation finished, 3.286787 sec.
# 799-th simulation finished, 2.905795 sec.
# 800-th simulation finished, 2.966254 sec.
# 801-th simulation finished, 3.184134 sec.
# 802-th simulation finished, 3.138240 sec.
# 803-th simulation finished, 3.273835 sec.
# 804-th simulation finished, 3.019390 sec.
# 805-th simulation finished, 2.758318 sec.
# 806-th simulation finished, 2.907282 sec.
# 807-th simulation finished, 3.023244 sec.
# 808-th simulation finished, 3.017649 sec.
# 809-th simulation finished, 3.276498 sec.
# 810-th simulation finished, 2.882452 sec.
# 811-th simulation finished, 2.771430 sec.
# 812-th simulation finished, 2.956629 sec.
# 813-th simulation finished, 2.930122 sec.
# 814-th simulation finished, 2.839071 sec.
# 815-th simulation finished, 2.708606 sec.
# 816-th simulation finished, 2.861120 sec.
# 817-th simulation finished, 3.234751 sec.
# 818-th simulation finished, 2.734344 sec.
# 819-th simulation finished, 3.037588 sec.
# 820-th simulation finished, 2.768080 sec.
# 821-th simulation finished, 3.163036 sec.
# 822-th simulation finished, 3.481944 sec.
# 823-th simulation finished, 3.064645 sec.
# 824-th simulation finished, 2.729572 sec.
# 825-th simulation finished, 2.926981 sec.
# 826-th simulation finished, 3.337809 sec.
# 827-th simulation finished, 3.104668 sec.
# 828-th simulation finished, 3.177975 sec.
# 829-th simulation finished, 2.946142 sec.
# 830-th simulation finished, 2.858416 sec.
# 831-th simulation finished, 2.910096 sec.
# 832-th simulation finished, 3.120614 sec.
# 833-th simulation finished, 2.770423 sec.
# 834-th simulation finished, 3.215928 sec.
# 835-th simulation finished, 2.835780 sec.
# 836-th simulation finished, 2.960149 sec.
# 837-th simulation finished, 3.127377 sec.
# 838-th simulation finished, 3.260392 sec.
# 839-th simulation finished, 2.917296 sec.
# 840-th simulation finished, 3.055868 sec.
# 841-th simulation finished, 2.869181 sec.
# 842-th simulation finished, 2.896748 sec.
# 843-th simulation finished, 3.585733 sec.
# 844-th simulation finished, 2.967104 sec.
# 845-th simulation finished, 2.939549 sec.
# 846-th simulation finished, 2.771836 sec.
# 847-th simulation finished, 2.958522 sec.
# 848-th simulation finished, 2.823075 sec.
# 849-th simulation finished, 2.979817 sec.
# 850-th simulation finished, 2.797352 sec.
# 851-th simulation finished, 3.202775 sec.
# 852-th simulation finished, 3.050680 sec.
# 853-th simulation finished, 3.229978 sec.
# 854-th simulation finished, 3.137296 sec.
# 855-th simulation finished, 3.089283 sec.
# 856-th simulation finished, 2.931897 sec.
# 857-th simulation finished, 2.765472 sec.
# 858-th simulation finished, 2.780589 sec.
# 859-th simulation finished, 3.002991 sec.
# 860-th simulation finished, 2.859966 sec.
# 861-th simulation finished, 3.008115 sec.
# 862-th simulation finished, 2.941908 sec.
# 863-th simulation finished, 3.949809 sec.
# 864-th simulation finished, 2.824214 sec.
# 865-th simulation finished, 3.058005 sec.
# 866-th simulation finished, 2.816563 sec.
# 867-th simulation finished, 3.468335 sec.
# 868-th simulation finished, 3.314953 sec.
# 869-th simulation finished, 2.767997 sec.
# 870-th simulation finished, 3.080581 sec.
# 871-th simulation finished, 2.742472 sec.
# 872-th simulation finished, 2.837504 sec.
# 873-th simulation finished, 3.328383 sec.
# 874-th simulation finished, 2.971630 sec.
# 875-th simulation finished, 2.888475 sec.
# 876-th simulation finished, 2.850527 sec.
# 877-th simulation finished, 3.374785 sec.
# 878-th simulation finished, 3.439757 sec.
# 879-th simulation finished, 2.939787 sec.
# 880-th simulation finished, 2.891845 sec.
# 881-th simulation finished, 2.854120 sec.
# 882-th simulation finished, 3.415872 sec.
# 883-th simulation finished, 3.625660 sec.
# 884-th simulation finished, 2.784073 sec.
# 885-th simulation finished, 2.937088 sec.
# 886-th simulation finished, 3.008668 sec.
# 887-th simulation finished, 3.257765 sec.
# 888-th simulation finished, 2.861538 sec.
# 889-th simulation finished, 3.045476 sec.
# 890-th simulation finished, 3.380613 sec.
# 891-th simulation finished, 2.444693 sec.
# 892-th simulation finished, 2.688044 sec.
# 893-th simulation finished, 2.773261 sec.
# 894-th simulation finished, 3.146483 sec.
# 895-th simulation finished, 3.294281 sec.
# 896-th simulation finished, 3.663917 sec.
# 897-th simulation finished, 3.134151 sec.
# 898-th simulation finished, 2.750143 sec.
# 899-th simulation finished, 2.994657 sec.
# 900-th simulation finished, 3.118453 sec.
# 901-th simulation finished, 2.810742 sec.
# 902-th simulation finished, 2.771750 sec.
# 903-th simulation finished, 3.261088 sec.
# 904-th simulation finished, 2.981226 sec.
# 905-th simulation finished, 3.525150 sec.
# 906-th simulation finished, 3.351566 sec.
# 907-th simulation finished, 3.411377 sec.
# 908-th simulation finished, 2.945239 sec.
# 909-th simulation finished, 3.248964 sec.
# 910-th simulation finished, 2.800882 sec.
# 911-th simulation finished, 3.200101 sec.
# 912-th simulation finished, 3.193752 sec.
# 913-th simulation finished, 2.777806 sec.
# 914-th simulation finished, 2.901894 sec.
# 915-th simulation finished, 2.863182 sec.
# 916-th simulation finished, 3.006123 sec.
# 917-th simulation finished, 2.982021 sec.
# 918-th simulation finished, 3.627415 sec.
# 919-th simulation finished, 3.211056 sec.
# 920-th simulation finished, 3.542164 sec.
# 921-th simulation finished, 3.141571 sec.
# 922-th simulation finished, 2.830346 sec.
# 923-th simulation finished, 3.126720 sec.
# 924-th simulation finished, 3.877567 sec.
# 925-th simulation finished, 3.308872 sec.
# 926-th simulation finished, 2.894576 sec.
# 927-th simulation finished, 3.007877 sec.
# 928-th simulation finished, 3.540922 sec.
# 929-th simulation finished, 3.481559 sec.
# 930-th simulation finished, 3.056646 sec.
# 931-th simulation finished, 3.194034 sec.
# 932-th simulation finished, 3.358156 sec.
# 933-th simulation finished, 3.207723 sec.
# 934-th simulation finished, 3.498220 sec.
# 935-th simulation finished, 3.075977 sec.
# 936-th simulation finished, 3.388059 sec.
# 937-th simulation finished, 2.842203 sec.
# 938-th simulation finished, 3.847639 sec.
# 939-th simulation finished, 3.435096 sec.
# 940-th simulation finished, 2.622021 sec.
# 941-th simulation finished, 3.271099 sec.
# 942-th simulation finished, 3.741689 sec.
# 943-th simulation finished, 3.036260 sec.
# 944-th simulation finished, 3.077279 sec.
# 945-th simulation finished, 3.360631 sec.
# 946-th simulation finished, 3.266614 sec.
# 947-th simulation finished, 4.292802 sec.
# 948-th simulation finished, 3.229116 sec.
# 949-th simulation finished, 2.861925 sec.
# 950-th simulation finished, 2.959082 sec.
# 951-th simulation finished, 3.262678 sec.
# 952-th simulation finished, 3.380891 sec.
# 953-th simulation finished, 3.423471 sec.
# 954-th simulation finished, 3.425359 sec.
# 955-th simulation finished, 3.306508 sec.
# 956-th simulation finished, 3.248255 sec.
# 957-th simulation finished, 3.017896 sec.
# 958-th simulation finished, 2.870891 sec.
# 959-th simulation finished, 3.720887 sec.
# 960-th simulation finished, 3.259364 sec.
# 961-th simulation finished, 3.391741 sec.
# 962-th simulation finished, 3.010321 sec.
# 963-th simulation finished, 2.961239 sec.
# 964-th simulation finished, 2.979973 sec.
# 965-th simulation finished, 2.914332 sec.
# 966-th simulation finished, 2.834617 sec.
# 967-th simulation finished, 2.874705 sec.
# 968-th simulation finished, 3.374365 sec.
# 969-th simulation finished, 3.226226 sec.
# 970-th simulation finished, 3.199368 sec.
# 971-th simulation finished, 2.999844 sec.
# 972-th simulation finished, 2.957848 sec.
# 973-th simulation finished, 3.152354 sec.
# 974-th simulation finished, 3.383330 sec.
# 975-th simulation finished, 3.374764 sec.
# 976-th simulation finished, 3.082823 sec.
# 977-th simulation finished, 3.465803 sec.
# 978-th simulation finished, 2.650482 sec.
# 979-th simulation finished, 2.977232 sec.
# 980-th simulation finished, 2.985893 sec.
# 981-th simulation finished, 3.253056 sec.
# 982-th simulation finished, 2.800854 sec.
# 983-th simulation finished, 2.694469 sec.
# 984-th simulation finished, 2.903201 sec.
# 985-th simulation finished, 3.129886 sec.
# 986-th simulation finished, 2.881156 sec.
# 987-th simulation finished, 2.841845 sec.
# 988-th simulation finished, 2.977233 sec.
# 989-th simulation finished, 3.339450 sec.
# 990-th simulation finished, 3.039227 sec.
# 991-th simulation finished, 3.188680 sec.
# 992-th simulation finished, 3.133088 sec.
# 993-th simulation finished, 2.949153 sec.
# 994-th simulation finished, 3.049842 sec.
# 995-th simulation finished, 3.183873 sec.
# 996-th simulation finished, 3.315039 sec.
# 997-th simulation finished, 3.399274 sec.
# 998-th simulation finished, 3.270893 sec.
# 999-th simulation finished, 2.978161 sec.
# 1000-th simulation finished, 2.884094 sec.

# %%
np.savez('coverage_freqepid_nbinom_randinf_1.npz',
         nsim = nsim, msim = msim, bsim = bsim)

# %% [markdown]
# # 4. Confidence Region Coverage Test

# %%
# locals.update(np.load('coverage_freqepid_nbinom_randinf_1.npz'))

# %%
Ihs_dth = np.zeros([num_sim, 2+d, 2+d])
Ts_dth = np.zeros(num_sim)
ps_dth = np.zeros(num_sim)

# %%
Ihs_hac = np.zeros([num_sim, 2+d, 2+d])
Ts_hac = np.zeros(num_sim)
ps_hac = np.zeros(num_sim)

# %%
Ihs_sdw = np.zeros([num_sim, 2+d, 2+d])
Ts_sdw = np.zeros(num_sim)
ps_sdw = np.zeros(num_sim)

# %%
for iter_sim in np.arange(num_sim):
    start_sim = time.time()
    
    nmle = nsim[iter_sim]
    mmle = msim[iter_sim]
    bmle = bsim[iter_sim,:]
    
    data_i = data[data['sim']==iter_sim]
    A = np.stack([np.full(T, 1), data_i["intervention"].to_numpy()], -1)
    Y = data_i["death"].to_numpy()
    
    Ihat_dth, Ihat_hac, Ihat_sdw =\
    model.inference(A, Y, nmle, mmle, bmle)
    
    # Fisher information matrix
    Ihs_dth[iter_sim] = Ihat_dth
    Ts_dth[iter_sim] = (bmle[1]-beta[1])/np.sqrt(la.pinv(Ihs_dth[iter_sim])[-1,-1])
    ps_dth[iter_sim] = 2*(1-stats.norm.cdf(np.abs(Ts_dth[iter_sim])))
    
    # HAC estimator
    Ihs_hac[iter_sim] = Ihat_hac
    Ts_hac[iter_sim] = (bmle[1]-beta[1])/np.sqrt(la.pinv(Ihs_hac[iter_sim])[-1,-1])
    ps_hac[iter_sim] = 2*(1-stats.norm.cdf(np.abs(Ts_hac[iter_sim])))
    
    # Sandwich estimator
    Ihs_sdw[iter_sim] = Ihat_sdw
    Ts_sdw[iter_sim] = (bmle[1]-beta[1])/np.sqrt(la.pinv(Ihs_sdw[iter_sim])[-1,-1])
    ps_sdw[iter_sim] = 2*(1-stats.norm.cdf(np.abs(Ts_sdw[iter_sim])))
    
    sys.__stdout__.write("%d-th simulation finished, %f sec.\n"
                         %(iter_sim+1, time.time()-start_sim))
    sys.__stdout__.flush()
# Out:
# 1-th simulation finished, 0.003883 sec.
# 2-th simulation finished, 0.001591 sec.
# 3-th simulation finished, 0.001257 sec.
# 4-th simulation finished, 0.001298 sec.
# 5-th simulation finished, 0.001231 sec.
# 6-th simulation finished, 0.001237 sec.
# 7-th simulation finished, 0.001209 sec.
# 8-th simulation finished, 0.001233 sec.
# 9-th simulation finished, 0.001230 sec.
# 10-th simulation finished, 0.001379 sec.
# 11-th simulation finished, 0.001303 sec.
# 12-th simulation finished, 0.001236 sec.
# 13-th simulation finished, 0.001221 sec.
# 14-th simulation finished, 0.001222 sec.
# 15-th simulation finished, 0.001210 sec.
# 16-th simulation finished, 0.001201 sec.
# 17-th simulation finished, 0.001214 sec.
# 18-th simulation finished, 0.001192 sec.
# 19-th simulation finished, 0.001299 sec.
# 20-th simulation finished, 0.001212 sec.
# 21-th simulation finished, 0.001269 sec.
# 22-th simulation finished, 0.001225 sec.
# 23-th simulation finished, 0.001208 sec.
# 24-th simulation finished, 0.001287 sec.
# 25-th simulation finished, 0.001186 sec.
# 26-th simulation finished, 0.001373 sec.
# 27-th simulation finished, 0.001314 sec.
# 28-th simulation finished, 0.001270 sec.
# 29-th simulation finished, 0.001196 sec.
# 30-th simulation finished, 0.001260 sec.
# 31-th simulation finished, 0.001189 sec.
# 32-th simulation finished, 0.001198 sec.
# 33-th simulation finished, 0.001163 sec.
# 34-th simulation finished, 0.001283 sec.
# 35-th simulation finished, 0.001221 sec.
# 36-th simulation finished, 0.001196 sec.
# 37-th simulation finished, 0.001187 sec.
# 38-th simulation finished, 0.001194 sec.
# 39-th simulation finished, 0.001207 sec.
# 40-th simulation finished, 0.001194 sec.
# 41-th simulation finished, 0.001266 sec.
# 42-th simulation finished, 0.001249 sec.
# 43-th simulation finished, 0.001194 sec.
# 44-th simulation finished, 0.001207 sec.
# 45-th simulation finished, 0.001180 sec.
# 46-th simulation finished, 0.001224 sec.
# 47-th simulation finished, 0.001207 sec.
# 48-th simulation finished, 0.001170 sec.
# 49-th simulation finished, 0.001211 sec.
# 50-th simulation finished, 0.001200 sec.
# 51-th simulation finished, 0.001170 sec.
# 52-th simulation finished, 0.001185 sec.
# 53-th simulation finished, 0.001165 sec.
# 54-th simulation finished, 0.001188 sec.
# 55-th simulation finished, 0.001164 sec.
# 56-th simulation finished, 0.001188 sec.
# 57-th simulation finished, 0.001160 sec.
# 58-th simulation finished, 0.001191 sec.
# 59-th simulation finished, 0.001134 sec.
# 60-th simulation finished, 0.001145 sec.
# 61-th simulation finished, 0.001165 sec.
# 62-th simulation finished, 0.001135 sec.
# 63-th simulation finished, 0.001146 sec.
# 64-th simulation finished, 0.001120 sec.
# 65-th simulation finished, 0.001145 sec.
# 66-th simulation finished, 0.001130 sec.
# 67-th simulation finished, 0.001151 sec.
# 68-th simulation finished, 0.001122 sec.
# 69-th simulation finished, 0.001163 sec.
# 70-th simulation finished, 0.001138 sec.
# 71-th simulation finished, 0.001235 sec.
# 72-th simulation finished, 0.001158 sec.
# 73-th simulation finished, 0.001166 sec.
# 74-th simulation finished, 0.001142 sec.
# 75-th simulation finished, 0.001153 sec.
# 76-th simulation finished, 0.001139 sec.
# 77-th simulation finished, 0.001145 sec.
# 78-th simulation finished, 0.001137 sec.
# 79-th simulation finished, 0.001134 sec.
# 80-th simulation finished, 0.001140 sec.
# 81-th simulation finished, 0.001139 sec.
# 82-th simulation finished, 0.001141 sec.
# 83-th simulation finished, 0.001144 sec.
# 84-th simulation finished, 0.001138 sec.
# 85-th simulation finished, 0.001137 sec.
# 86-th simulation finished, 0.001135 sec.
# 87-th simulation finished, 0.001141 sec.
# 88-th simulation finished, 0.001133 sec.
# 89-th simulation finished, 0.001133 sec.
# 90-th simulation finished, 0.001136 sec.
# 91-th simulation finished, 0.001139 sec.
# 92-th simulation finished, 0.001133 sec.
# 93-th simulation finished, 0.001174 sec.
# 94-th simulation finished, 0.001172 sec.
# 95-th simulation finished, 0.001171 sec.
# 96-th simulation finished, 0.001174 sec.
# 97-th simulation finished, 0.001177 sec.
# 98-th simulation finished, 0.001174 sec.
# 99-th simulation finished, 0.001160 sec.
# 100-th simulation finished, 0.001172 sec.
# 101-th simulation finished, 0.001168 sec.
# 102-th simulation finished, 0.001205 sec.
# 103-th simulation finished, 0.001246 sec.
# 104-th simulation finished, 0.001235 sec.
# 105-th simulation finished, 0.001198 sec.
# 106-th simulation finished, 0.001141 sec.
# 107-th simulation finished, 0.001170 sec.
# 108-th simulation finished, 0.001135 sec.
# 109-th simulation finished, 0.001157 sec.
# 110-th simulation finished, 0.001158 sec.
# 111-th simulation finished, 0.001131 sec.
# 112-th simulation finished, 0.001154 sec.
# 113-th simulation finished, 0.001124 sec.
# 114-th simulation finished, 0.001140 sec.
# 115-th simulation finished, 0.001130 sec.
# 116-th simulation finished, 0.001138 sec.
# 117-th simulation finished, 0.001132 sec.
# 118-th simulation finished, 0.001155 sec.
# 119-th simulation finished, 0.001123 sec.
# 120-th simulation finished, 0.001143 sec.
# 121-th simulation finished, 0.001140 sec.
# 122-th simulation finished, 0.001144 sec.
# 123-th simulation finished, 0.001124 sec.
# 124-th simulation finished, 0.001133 sec.
# 125-th simulation finished, 0.001126 sec.
# 126-th simulation finished, 0.001138 sec.
# 127-th simulation finished, 0.001161 sec.
# 128-th simulation finished, 0.001151 sec.
# 129-th simulation finished, 0.001136 sec.
# 130-th simulation finished, 0.001149 sec.
# 131-th simulation finished, 0.001125 sec.
# 132-th simulation finished, 0.001159 sec.
# 133-th simulation finished, 0.001138 sec.
# 134-th simulation finished, 0.001176 sec.
# 135-th simulation finished, 0.001141 sec.
# 136-th simulation finished, 0.001154 sec.
# 137-th simulation finished, 0.001180 sec.
# 138-th simulation finished, 0.001180 sec.
# 139-th simulation finished, 0.001154 sec.
# 140-th simulation finished, 0.001182 sec.
# 141-th simulation finished, 0.001160 sec.
# 142-th simulation finished, 0.001180 sec.
# 143-th simulation finished, 0.001170 sec.
# 144-th simulation finished, 0.001182 sec.
# 145-th simulation finished, 0.001165 sec.
# 146-th simulation finished, 0.001182 sec.
# 147-th simulation finished, 0.001152 sec.
# 148-th simulation finished, 0.001140 sec.
# 149-th simulation finished, 0.001116 sec.
# 150-th simulation finished, 0.001143 sec.
# 151-th simulation finished, 0.001344 sec.
# 152-th simulation finished, 0.001449 sec.
# 153-th simulation finished, 0.001195 sec.
# 154-th simulation finished, 0.001140 sec.
# 155-th simulation finished, 0.001152 sec.
# 156-th simulation finished, 0.001130 sec.
# 157-th simulation finished, 0.001171 sec.
# 158-th simulation finished, 0.001124 sec.
# 159-th simulation finished, 0.001186 sec.
# 160-th simulation finished, 0.001128 sec.
# 161-th simulation finished, 0.001208 sec.
# 162-th simulation finished, 0.001118 sec.
# 163-th simulation finished, 0.001138 sec.
# 164-th simulation finished, 0.001121 sec.
# 165-th simulation finished, 0.001164 sec.
# 166-th simulation finished, 0.001234 sec.
# 167-th simulation finished, 0.001131 sec.
# 168-th simulation finished, 0.001154 sec.
# 169-th simulation finished, 0.001121 sec.
# 170-th simulation finished, 0.001179 sec.
# 171-th simulation finished, 0.001480 sec.
# 172-th simulation finished, 0.001481 sec.
# 173-th simulation finished, 0.001205 sec.
# 174-th simulation finished, 0.001324 sec.
# 175-th simulation finished, 0.001290 sec.
# 176-th simulation finished, 0.001199 sec.
# 177-th simulation finished, 0.001218 sec.
# 178-th simulation finished, 0.001178 sec.
# 179-th simulation finished, 0.001196 sec.
# 180-th simulation finished, 0.001161 sec.
# 181-th simulation finished, 0.001158 sec.
# 182-th simulation finished, 0.001175 sec.
# 183-th simulation finished, 0.001143 sec.
# 184-th simulation finished, 0.001153 sec.
# 185-th simulation finished, 0.001152 sec.
# 186-th simulation finished, 0.001209 sec.
# 187-th simulation finished, 0.001148 sec.
# 188-th simulation finished, 0.001164 sec.
# 189-th simulation finished, 0.001159 sec.
# 190-th simulation finished, 0.001149 sec.
# 191-th simulation finished, 0.001126 sec.
# 192-th simulation finished, 0.001155 sec.
# 193-th simulation finished, 0.001132 sec.
# 194-th simulation finished, 0.001143 sec.
# 195-th simulation finished, 0.001140 sec.
# 196-th simulation finished, 0.001164 sec.
# 197-th simulation finished, 0.001132 sec.
# 198-th simulation finished, 0.001183 sec.
# 199-th simulation finished, 0.001114 sec.
# 200-th simulation finished, 0.001150 sec.
# 201-th simulation finished, 0.001129 sec.
# 202-th simulation finished, 0.001141 sec.
# 203-th simulation finished, 0.001264 sec.
# 204-th simulation finished, 0.001189 sec.
# 205-th simulation finished, 0.001214 sec.
# 206-th simulation finished, 0.001163 sec.
# 207-th simulation finished, 0.001188 sec.
# 208-th simulation finished, 0.001161 sec.
# 209-th simulation finished, 0.001193 sec.
# 210-th simulation finished, 0.001165 sec.
# 211-th simulation finished, 0.001181 sec.
# 212-th simulation finished, 0.001157 sec.
# 213-th simulation finished, 0.001189 sec.
# 214-th simulation finished, 0.001125 sec.
# 215-th simulation finished, 0.001146 sec.
# 216-th simulation finished, 0.001118 sec.
# 217-th simulation finished, 0.001339 sec.
# 218-th simulation finished, 0.001181 sec.
# 219-th simulation finished, 0.001206 sec.
# 220-th simulation finished, 0.001141 sec.
# 221-th simulation finished, 0.001141 sec.
# 222-th simulation finished, 0.001133 sec.
# 223-th simulation finished, 0.001140 sec.
# 224-th simulation finished, 0.001126 sec.
# 225-th simulation finished, 0.001143 sec.
# 226-th simulation finished, 0.001149 sec.
# 227-th simulation finished, 0.001146 sec.
# 228-th simulation finished, 0.001137 sec.
# 229-th simulation finished, 0.001153 sec.
# 230-th simulation finished, 0.001131 sec.
# 231-th simulation finished, 0.001126 sec.
# 232-th simulation finished, 0.001135 sec.
# 233-th simulation finished, 0.001140 sec.
# 234-th simulation finished, 0.001131 sec.
# 235-th simulation finished, 0.001136 sec.
# 236-th simulation finished, 0.001143 sec.
# 237-th simulation finished, 0.001172 sec.
# 238-th simulation finished, 0.001171 sec.
# 239-th simulation finished, 0.001174 sec.
# 240-th simulation finished, 0.001175 sec.
# 241-th simulation finished, 0.001250 sec.
# 242-th simulation finished, 0.001224 sec.
# 243-th simulation finished, 0.001205 sec.
# 244-th simulation finished, 0.001205 sec.
# 245-th simulation finished, 0.001174 sec.
# 246-th simulation finished, 0.001187 sec.
# 247-th simulation finished, 0.001163 sec.
# 248-th simulation finished, 0.001149 sec.
# 249-th simulation finished, 0.001124 sec.
# 250-th simulation finished, 0.001175 sec.
# 251-th simulation finished, 0.001133 sec.
# 252-th simulation finished, 0.001167 sec.
# 253-th simulation finished, 0.001142 sec.
# 254-th simulation finished, 0.001150 sec.
# 255-th simulation finished, 0.001155 sec.
# 256-th simulation finished, 0.001148 sec.
# 257-th simulation finished, 0.001220 sec.
# 258-th simulation finished, 0.001160 sec.
# 259-th simulation finished, 0.001190 sec.
# 260-th simulation finished, 0.001144 sec.
# 261-th simulation finished, 0.001145 sec.
# 262-th simulation finished, 0.001136 sec.
# 263-th simulation finished, 0.001171 sec.
# 264-th simulation finished, 0.001179 sec.
# 265-th simulation finished, 0.001185 sec.
# 266-th simulation finished, 0.001148 sec.
# 267-th simulation finished, 0.001127 sec.
# 268-th simulation finished, 0.001141 sec.
# 269-th simulation finished, 0.001130 sec.
# 270-th simulation finished, 0.001131 sec.
# 271-th simulation finished, 0.001132 sec.
# 272-th simulation finished, 0.001140 sec.
# 273-th simulation finished, 0.001137 sec.
# 274-th simulation finished, 0.001146 sec.
# 275-th simulation finished, 0.001133 sec.
# 276-th simulation finished, 0.001131 sec.
# 277-th simulation finished, 0.001141 sec.
# 278-th simulation finished, 0.001130 sec.
# 279-th simulation finished, 0.001126 sec.
# 280-th simulation finished, 0.001139 sec.
# 281-th simulation finished, 0.001131 sec.
# 282-th simulation finished, 0.001120 sec.
# 283-th simulation finished, 0.001174 sec.
# 284-th simulation finished, 0.001154 sec.
# 285-th simulation finished, 0.001153 sec.
# 286-th simulation finished, 0.001145 sec.
# 287-th simulation finished, 0.001164 sec.
# 288-th simulation finished, 0.001139 sec.
# 289-th simulation finished, 0.001204 sec.
# 290-th simulation finished, 0.001192 sec.
# 291-th simulation finished, 0.001135 sec.
# 292-th simulation finished, 0.001211 sec.
# 293-th simulation finished, 0.001198 sec.
# 294-th simulation finished, 0.001163 sec.
# 295-th simulation finished, 0.001229 sec.
# 296-th simulation finished, 0.001167 sec.
# 297-th simulation finished, 0.001192 sec.
# 298-th simulation finished, 0.001187 sec.
# 299-th simulation finished, 0.001178 sec.
# 300-th simulation finished, 0.001226 sec.
# 301-th simulation finished, 0.001184 sec.
# 302-th simulation finished, 0.001201 sec.
# 303-th simulation finished, 0.001169 sec.
# 304-th simulation finished, 0.001178 sec.
# 305-th simulation finished, 0.001122 sec.
# 306-th simulation finished, 0.001144 sec.
# 307-th simulation finished, 0.001121 sec.
# 308-th simulation finished, 0.001283 sec.
# 309-th simulation finished, 0.001194 sec.
# 310-th simulation finished, 0.001129 sec.
# 311-th simulation finished, 0.001282 sec.
# 312-th simulation finished, 0.001129 sec.
# 313-th simulation finished, 0.001182 sec.
# 314-th simulation finished, 0.001128 sec.
# 315-th simulation finished, 0.001180 sec.
# 316-th simulation finished, 0.001124 sec.
# 317-th simulation finished, 0.001180 sec.
# 318-th simulation finished, 0.001240 sec.
# 319-th simulation finished, 0.001200 sec.
# 320-th simulation finished, 0.001139 sec.
# 321-th simulation finished, 0.001165 sec.
# 322-th simulation finished, 0.001206 sec.
# 323-th simulation finished, 0.001129 sec.
# 324-th simulation finished, 0.001695 sec.
# 325-th simulation finished, 0.001385 sec.
# 326-th simulation finished, 0.001336 sec.
# 327-th simulation finished, 0.001397 sec.
# 328-th simulation finished, 0.001318 sec.
# 329-th simulation finished, 0.001243 sec.
# 330-th simulation finished, 0.001274 sec.
# 331-th simulation finished, 0.001178 sec.
# 332-th simulation finished, 0.001202 sec.
# 333-th simulation finished, 0.001159 sec.
# 334-th simulation finished, 0.001185 sec.
# 335-th simulation finished, 0.001178 sec.
# 336-th simulation finished, 0.001239 sec.
# 337-th simulation finished, 0.001203 sec.
# 338-th simulation finished, 0.001227 sec.
# 339-th simulation finished, 0.001158 sec.
# 340-th simulation finished, 0.001196 sec.
# 341-th simulation finished, 0.001177 sec.
# 342-th simulation finished, 0.001208 sec.
# 343-th simulation finished, 0.001663 sec.
# 344-th simulation finished, 0.001498 sec.
# 345-th simulation finished, 0.001197 sec.
# 346-th simulation finished, 0.001250 sec.
# 347-th simulation finished, 0.001193 sec.
# 348-th simulation finished, 0.001311 sec.
# 349-th simulation finished, 0.001210 sec.
# 350-th simulation finished, 0.001244 sec.
# 351-th simulation finished, 0.001297 sec.
# 352-th simulation finished, 0.001215 sec.
# 353-th simulation finished, 0.001193 sec.
# 354-th simulation finished, 0.001184 sec.
# 355-th simulation finished, 0.001179 sec.
# 356-th simulation finished, 0.001187 sec.
# 357-th simulation finished, 0.001141 sec.
# 358-th simulation finished, 0.001139 sec.
# 359-th simulation finished, 0.001130 sec.
# 360-th simulation finished, 0.001139 sec.
# 361-th simulation finished, 0.001136 sec.
# 362-th simulation finished, 0.001131 sec.
# 363-th simulation finished, 0.001132 sec.
# 364-th simulation finished, 0.001130 sec.
# 365-th simulation finished, 0.001130 sec.
# 366-th simulation finished, 0.001135 sec.
# 367-th simulation finished, 0.001129 sec.
# 368-th simulation finished, 0.001150 sec.
# 369-th simulation finished, 0.001168 sec.
# 370-th simulation finished, 0.001162 sec.
# 371-th simulation finished, 0.001163 sec.
# 372-th simulation finished, 0.001165 sec.
# 373-th simulation finished, 0.001193 sec.
# 374-th simulation finished, 0.001240 sec.
# 375-th simulation finished, 0.001175 sec.
# 376-th simulation finished, 0.001271 sec.
# 377-th simulation finished, 0.001203 sec.
# 378-th simulation finished, 0.001192 sec.
# 379-th simulation finished, 0.001177 sec.
# 380-th simulation finished, 0.001318 sec.
# 381-th simulation finished, 0.001207 sec.
# 382-th simulation finished, 0.001206 sec.
# 383-th simulation finished, 0.001171 sec.
# 384-th simulation finished, 0.001210 sec.
# 385-th simulation finished, 0.001176 sec.
# 386-th simulation finished, 0.001186 sec.
# 387-th simulation finished, 0.001163 sec.
# 388-th simulation finished, 0.001191 sec.
# 389-th simulation finished, 0.001168 sec.
# 390-th simulation finished, 0.001175 sec.
# 391-th simulation finished, 0.001120 sec.
# 392-th simulation finished, 0.001151 sec.
# 393-th simulation finished, 0.001123 sec.
# 394-th simulation finished, 0.001146 sec.
# 395-th simulation finished, 0.001129 sec.
# 396-th simulation finished, 0.001146 sec.
# 397-th simulation finished, 0.001122 sec.
# 398-th simulation finished, 0.001188 sec.
# 399-th simulation finished, 0.001178 sec.
# 400-th simulation finished, 0.001170 sec.
# 401-th simulation finished, 0.001151 sec.
# 402-th simulation finished, 0.001260 sec.
# 403-th simulation finished, 0.001190 sec.
# 404-th simulation finished, 0.001211 sec.
# 405-th simulation finished, 0.001214 sec.
# 406-th simulation finished, 0.001180 sec.
# 407-th simulation finished, 0.001201 sec.
# 408-th simulation finished, 0.001158 sec.
# 409-th simulation finished, 0.001183 sec.
# 410-th simulation finished, 0.001169 sec.
# 411-th simulation finished, 0.001174 sec.
# 412-th simulation finished, 0.001227 sec.
# 413-th simulation finished, 0.001161 sec.
# 414-th simulation finished, 0.001172 sec.
# 415-th simulation finished, 0.001117 sec.
# 416-th simulation finished, 0.001148 sec.
# 417-th simulation finished, 0.001132 sec.
# 418-th simulation finished, 0.001132 sec.
# 419-th simulation finished, 0.001115 sec.
# 420-th simulation finished, 0.001149 sec.
# 421-th simulation finished, 0.001158 sec.
# 422-th simulation finished, 0.001112 sec.
# 423-th simulation finished, 0.001143 sec.
# 424-th simulation finished, 0.001124 sec.
# 425-th simulation finished, 0.001143 sec.
# 426-th simulation finished, 0.001118 sec.
# 427-th simulation finished, 0.001131 sec.
# 428-th simulation finished, 0.001113 sec.
# 429-th simulation finished, 0.001138 sec.
# 430-th simulation finished, 0.001115 sec.
# 431-th simulation finished, 0.001139 sec.
# 432-th simulation finished, 0.001110 sec.
# 433-th simulation finished, 0.001136 sec.
# 434-th simulation finished, 0.001113 sec.
# 435-th simulation finished, 0.001136 sec.
# 436-th simulation finished, 0.001161 sec.
# 437-th simulation finished, 0.001171 sec.
# 438-th simulation finished, 0.001157 sec.
# 439-th simulation finished, 0.001220 sec.
# 440-th simulation finished, 0.001174 sec.
# 441-th simulation finished, 0.001200 sec.
# 442-th simulation finished, 0.001161 sec.
# 443-th simulation finished, 0.001189 sec.
# 444-th simulation finished, 0.001191 sec.
# 445-th simulation finished, 0.001158 sec.
# 446-th simulation finished, 0.001177 sec.
# 447-th simulation finished, 0.001111 sec.
# 448-th simulation finished, 0.001144 sec.
# 449-th simulation finished, 0.001110 sec.
# 450-th simulation finished, 0.001131 sec.
# 451-th simulation finished, 0.001106 sec.
# 452-th simulation finished, 0.001137 sec.
# 453-th simulation finished, 0.001109 sec.
# 454-th simulation finished, 0.001141 sec.
# 455-th simulation finished, 0.001103 sec.
# 456-th simulation finished, 0.001137 sec.
# 457-th simulation finished, 0.001113 sec.
# 458-th simulation finished, 0.001140 sec.
# 459-th simulation finished, 0.001115 sec.
# 460-th simulation finished, 0.001140 sec.
# 461-th simulation finished, 0.001117 sec.
# 462-th simulation finished, 0.001133 sec.
# 463-th simulation finished, 0.001106 sec.
# 464-th simulation finished, 0.001132 sec.
# 465-th simulation finished, 0.001109 sec.
# 466-th simulation finished, 0.001133 sec.
# 467-th simulation finished, 0.001107 sec.
# 468-th simulation finished, 0.001163 sec.
# 469-th simulation finished, 0.001224 sec.
# 470-th simulation finished, 0.001233 sec.
# 471-th simulation finished, 0.001194 sec.
# 472-th simulation finished, 0.001307 sec.
# 473-th simulation finished, 0.001214 sec.
# 474-th simulation finished, 0.001196 sec.
# 475-th simulation finished, 0.001184 sec.
# 476-th simulation finished, 0.001181 sec.
# 477-th simulation finished, 0.001177 sec.
# 478-th simulation finished, 0.001178 sec.
# 479-th simulation finished, 0.001177 sec.
# 480-th simulation finished, 0.001171 sec.
# 481-th simulation finished, 0.001144 sec.
# 482-th simulation finished, 0.001137 sec.
# 483-th simulation finished, 0.001128 sec.
# 484-th simulation finished, 0.001134 sec.
# 485-th simulation finished, 0.001137 sec.
# 486-th simulation finished, 0.001135 sec.
# 487-th simulation finished, 0.001132 sec.
# 488-th simulation finished, 0.001131 sec.
# 489-th simulation finished, 0.001134 sec.
# 490-th simulation finished, 0.001131 sec.
# 491-th simulation finished, 0.001130 sec.
# 492-th simulation finished, 0.001155 sec.
# 493-th simulation finished, 0.001166 sec.
# 494-th simulation finished, 0.001165 sec.
# 495-th simulation finished, 0.001164 sec.
# 496-th simulation finished, 0.001388 sec.
# 497-th simulation finished, 0.001438 sec.
# 498-th simulation finished, 0.001281 sec.
# 499-th simulation finished, 0.001198 sec.
# 500-th simulation finished, 0.001190 sec.
# 501-th simulation finished, 0.001178 sec.
# 502-th simulation finished, 0.001193 sec.
# 503-th simulation finished, 0.001146 sec.
# 504-th simulation finished, 0.001133 sec.
# 505-th simulation finished, 0.001132 sec.
# 506-th simulation finished, 0.001133 sec.
# 507-th simulation finished, 0.001125 sec.
# 508-th simulation finished, 0.001171 sec.
# 509-th simulation finished, 0.001215 sec.
# 510-th simulation finished, 0.001176 sec.
# 511-th simulation finished, 0.001131 sec.
# 512-th simulation finished, 0.001139 sec.
# 513-th simulation finished, 0.001146 sec.
# 514-th simulation finished, 0.001124 sec.
# 515-th simulation finished, 0.001142 sec.
# 516-th simulation finished, 0.001352 sec.
# 517-th simulation finished, 0.001388 sec.
# 518-th simulation finished, 0.001159 sec.
# 519-th simulation finished, 0.001165 sec.
# 520-th simulation finished, 0.001142 sec.
# 521-th simulation finished, 0.001136 sec.
# 522-th simulation finished, 0.001131 sec.
# 523-th simulation finished, 0.001131 sec.
# 524-th simulation finished, 0.001151 sec.
# 525-th simulation finished, 0.001117 sec.
# 526-th simulation finished, 0.001189 sec.
# 527-th simulation finished, 0.001155 sec.
# 528-th simulation finished, 0.001180 sec.
# 529-th simulation finished, 0.001194 sec.
# 530-th simulation finished, 0.001180 sec.
# 531-th simulation finished, 0.001169 sec.
# 532-th simulation finished, 0.001184 sec.
# 533-th simulation finished, 0.001154 sec.
# 534-th simulation finished, 0.001170 sec.
# 535-th simulation finished, 0.001155 sec.
# 536-th simulation finished, 0.001177 sec.
# 537-th simulation finished, 0.001130 sec.
# 538-th simulation finished, 0.001159 sec.
# 539-th simulation finished, 0.001153 sec.
# 540-th simulation finished, 0.001140 sec.
# 541-th simulation finished, 0.001114 sec.
# 542-th simulation finished, 0.001150 sec.
# 543-th simulation finished, 0.001125 sec.
# 544-th simulation finished, 0.001136 sec.
# 545-th simulation finished, 0.001116 sec.
# 546-th simulation finished, 0.001133 sec.
# 547-th simulation finished, 0.001145 sec.
# 548-th simulation finished, 0.001270 sec.
# 549-th simulation finished, 0.001198 sec.
# 550-th simulation finished, 0.001249 sec.
# 551-th simulation finished, 0.001178 sec.
# 552-th simulation finished, 0.001209 sec.
# 553-th simulation finished, 0.001170 sec.
# 554-th simulation finished, 0.001193 sec.
# 555-th simulation finished, 0.001159 sec.
# 556-th simulation finished, 0.001190 sec.
# 557-th simulation finished, 0.001161 sec.
# 558-th simulation finished, 0.001184 sec.
# 559-th simulation finished, 0.001173 sec.
# 560-th simulation finished, 0.001143 sec.
# 561-th simulation finished, 0.001237 sec.
# 562-th simulation finished, 0.001150 sec.
# 563-th simulation finished, 0.001176 sec.
# 564-th simulation finished, 0.001129 sec.
# 565-th simulation finished, 0.001146 sec.
# 566-th simulation finished, 0.001121 sec.
# 567-th simulation finished, 0.001137 sec.
# 568-th simulation finished, 0.001121 sec.
# 569-th simulation finished, 0.001151 sec.
# 570-th simulation finished, 0.001121 sec.
# 571-th simulation finished, 0.001137 sec.
# 572-th simulation finished, 0.001122 sec.
# 573-th simulation finished, 0.001143 sec.
# 574-th simulation finished, 0.001120 sec.
# 575-th simulation finished, 0.001143 sec.
# 576-th simulation finished, 0.001121 sec.
# 577-th simulation finished, 0.001142 sec.
# 578-th simulation finished, 0.001114 sec.
# 579-th simulation finished, 0.001134 sec.
# 580-th simulation finished, 0.001113 sec.
# 581-th simulation finished, 0.001156 sec.
# 582-th simulation finished, 0.001141 sec.
# 583-th simulation finished, 0.001176 sec.
# 584-th simulation finished, 0.001151 sec.
# 585-th simulation finished, 0.001180 sec.
# 586-th simulation finished, 0.001143 sec.
# 587-th simulation finished, 0.001169 sec.
# 588-th simulation finished, 0.001160 sec.
# 589-th simulation finished, 0.001188 sec.
# 590-th simulation finished, 0.001147 sec.
# 591-th simulation finished, 0.001183 sec.
# 592-th simulation finished, 0.001158 sec.
# 593-th simulation finished, 0.001209 sec.
# 594-th simulation finished, 0.001149 sec.
# 595-th simulation finished, 0.001158 sec.
# 596-th simulation finished, 0.001146 sec.
# 597-th simulation finished, 0.001138 sec.
# 598-th simulation finished, 0.001224 sec.
# 599-th simulation finished, 0.001159 sec.
# 600-th simulation finished, 0.001184 sec.
# 601-th simulation finished, 0.001140 sec.
# 602-th simulation finished, 0.001146 sec.
# 603-th simulation finished, 0.001130 sec.
# 604-th simulation finished, 0.001148 sec.
# 605-th simulation finished, 0.001139 sec.
# 606-th simulation finished, 0.001152 sec.
# 607-th simulation finished, 0.001140 sec.
# 608-th simulation finished, 0.001165 sec.
# 609-th simulation finished, 0.001129 sec.
# 610-th simulation finished, 0.001145 sec.
# 611-th simulation finished, 0.001115 sec.
# 612-th simulation finished, 0.001152 sec.
# 613-th simulation finished, 0.001118 sec.
# 614-th simulation finished, 0.001139 sec.
# 615-th simulation finished, 0.001143 sec.
# 616-th simulation finished, 0.001162 sec.
# 617-th simulation finished, 0.001158 sec.
# 618-th simulation finished, 0.001173 sec.
# 619-th simulation finished, 0.001161 sec.
# 620-th simulation finished, 0.001176 sec.
# 621-th simulation finished, 0.001154 sec.
# 622-th simulation finished, 0.001176 sec.
# 623-th simulation finished, 0.001157 sec.
# 624-th simulation finished, 0.001199 sec.
# 625-th simulation finished, 0.001167 sec.
# 626-th simulation finished, 0.001184 sec.
# 627-th simulation finished, 0.001144 sec.
# 628-th simulation finished, 0.001147 sec.
# 629-th simulation finished, 0.001132 sec.
# 630-th simulation finished, 0.001146 sec.
# 631-th simulation finished, 0.001122 sec.
# 632-th simulation finished, 0.001148 sec.
# 633-th simulation finished, 0.001130 sec.
# 634-th simulation finished, 0.001151 sec.
# 635-th simulation finished, 0.001115 sec.
# 636-th simulation finished, 0.001186 sec.
# 637-th simulation finished, 0.001142 sec.
# 638-th simulation finished, 0.001125 sec.
# 639-th simulation finished, 0.001154 sec.
# 640-th simulation finished, 0.001181 sec.
# 641-th simulation finished, 0.001162 sec.
# 642-th simulation finished, 0.001119 sec.
# 643-th simulation finished, 0.001129 sec.
# 644-th simulation finished, 0.001135 sec.
# 645-th simulation finished, 0.001136 sec.
# 646-th simulation finished, 0.001116 sec.
# 647-th simulation finished, 0.001131 sec.
# 648-th simulation finished, 0.001130 sec.
# 649-th simulation finished, 0.001169 sec.
# 650-th simulation finished, 0.001107 sec.
# 651-th simulation finished, 0.001129 sec.
# 652-th simulation finished, 0.001118 sec.
# 653-th simulation finished, 0.001158 sec.
# 654-th simulation finished, 0.001112 sec.
# 655-th simulation finished, 0.001135 sec.
# 656-th simulation finished, 0.001161 sec.
# 657-th simulation finished, 0.001147 sec.
# 658-th simulation finished, 0.001141 sec.
# 659-th simulation finished, 0.001127 sec.
# 660-th simulation finished, 0.001138 sec.
# 661-th simulation finished, 0.001152 sec.
# 662-th simulation finished, 0.001148 sec.
# 663-th simulation finished, 0.001196 sec.
# 664-th simulation finished, 0.001154 sec.
# 665-th simulation finished, 0.001190 sec.
# 666-th simulation finished, 0.001157 sec.
# 667-th simulation finished, 0.001295 sec.
# 668-th simulation finished, 0.001187 sec.
# 669-th simulation finished, 0.001167 sec.
# 670-th simulation finished, 0.001170 sec.
# 671-th simulation finished, 0.001439 sec.
# 672-th simulation finished, 0.001299 sec.
# 673-th simulation finished, 0.001227 sec.
# 674-th simulation finished, 0.001158 sec.
# 675-th simulation finished, 0.001146 sec.
# 676-th simulation finished, 0.001136 sec.
# 677-th simulation finished, 0.001184 sec.
# 678-th simulation finished, 0.001123 sec.
# 679-th simulation finished, 0.001140 sec.
# 680-th simulation finished, 0.001116 sec.
# 681-th simulation finished, 0.001140 sec.
# 682-th simulation finished, 0.001123 sec.
# 683-th simulation finished, 0.001149 sec.
# 684-th simulation finished, 0.001132 sec.
# 685-th simulation finished, 0.001144 sec.
# 686-th simulation finished, 0.001116 sec.
# 687-th simulation finished, 0.001164 sec.
# 688-th simulation finished, 0.001181 sec.
# 689-th simulation finished, 0.001155 sec.
# 690-th simulation finished, 0.001488 sec.
# 691-th simulation finished, 0.001462 sec.
# 692-th simulation finished, 0.001234 sec.
# 693-th simulation finished, 0.001143 sec.
# 694-th simulation finished, 0.001166 sec.
# 695-th simulation finished, 0.001161 sec.
# 696-th simulation finished, 0.001187 sec.
# 697-th simulation finished, 0.001271 sec.
# 698-th simulation finished, 0.001177 sec.
# 699-th simulation finished, 0.001192 sec.
# 700-th simulation finished, 0.001160 sec.
# 701-th simulation finished, 0.001186 sec.
# 702-th simulation finished, 0.001170 sec.
# 703-th simulation finished, 0.001195 sec.
# 704-th simulation finished, 0.001160 sec.
# 705-th simulation finished, 0.001173 sec.
# 706-th simulation finished, 0.001129 sec.
# 707-th simulation finished, 0.001140 sec.
# 708-th simulation finished, 0.001121 sec.
# 709-th simulation finished, 0.001163 sec.
# 710-th simulation finished, 0.001135 sec.
# 711-th simulation finished, 0.001144 sec.
# 712-th simulation finished, 0.001111 sec.
# 713-th simulation finished, 0.001134 sec.
# 714-th simulation finished, 0.001128 sec.
# 715-th simulation finished, 0.001138 sec.
# 716-th simulation finished, 0.001113 sec.
# 717-th simulation finished, 0.001156 sec.
# 718-th simulation finished, 0.001155 sec.
# 719-th simulation finished, 0.001164 sec.
# 720-th simulation finished, 0.001183 sec.
# 721-th simulation finished, 0.001150 sec.
# 722-th simulation finished, 0.001133 sec.
# 723-th simulation finished, 0.001146 sec.
# 724-th simulation finished, 0.001126 sec.
# 725-th simulation finished, 0.001140 sec.
# 726-th simulation finished, 0.001102 sec.
# 727-th simulation finished, 0.001130 sec.
# 728-th simulation finished, 0.001115 sec.
# 729-th simulation finished, 0.001162 sec.
# 730-th simulation finished, 0.001170 sec.
# 731-th simulation finished, 0.001181 sec.
# 732-th simulation finished, 0.001153 sec.
# 733-th simulation finished, 0.001174 sec.
# 734-th simulation finished, 0.001150 sec.
# 735-th simulation finished, 0.001171 sec.
# 736-th simulation finished, 0.001154 sec.
# 737-th simulation finished, 0.001175 sec.
# 738-th simulation finished, 0.001163 sec.
# 739-th simulation finished, 0.001178 sec.
# 740-th simulation finished, 0.001138 sec.
# 741-th simulation finished, 0.001140 sec.
# 742-th simulation finished, 0.001120 sec.
# 743-th simulation finished, 0.001136 sec.
# 744-th simulation finished, 0.001110 sec.
# 745-th simulation finished, 0.001132 sec.
# 746-th simulation finished, 0.001108 sec.
# 747-th simulation finished, 0.001125 sec.
# 748-th simulation finished, 0.001111 sec.
# 749-th simulation finished, 0.001131 sec.
# 750-th simulation finished, 0.001141 sec.
# 751-th simulation finished, 0.001147 sec.
# 752-th simulation finished, 0.001180 sec.
# 753-th simulation finished, 0.001216 sec.
# 754-th simulation finished, 0.001168 sec.
# 755-th simulation finished, 0.001201 sec.
# 756-th simulation finished, 0.001270 sec.
# 757-th simulation finished, 0.001198 sec.
# 758-th simulation finished, 0.001183 sec.
# 759-th simulation finished, 0.001174 sec.
# 760-th simulation finished, 0.001184 sec.
# 761-th simulation finished, 0.001178 sec.
# 762-th simulation finished, 0.001185 sec.
# 763-th simulation finished, 0.001182 sec.
# 764-th simulation finished, 0.001169 sec.
# 765-th simulation finished, 0.001174 sec.
# 766-th simulation finished, 0.001168 sec.
# 767-th simulation finished, 0.001160 sec.
# 768-th simulation finished, 0.001321 sec.
# 769-th simulation finished, 0.001216 sec.
# 770-th simulation finished, 0.001250 sec.
# 771-th simulation finished, 0.001230 sec.
# 772-th simulation finished, 0.001234 sec.
# 773-th simulation finished, 0.001307 sec.
# 774-th simulation finished, 0.001292 sec.
# 775-th simulation finished, 0.001233 sec.
# 776-th simulation finished, 0.001202 sec.
# 777-th simulation finished, 0.001195 sec.
# 778-th simulation finished, 0.001295 sec.
# 779-th simulation finished, 0.001266 sec.
# 780-th simulation finished, 0.001232 sec.
# 781-th simulation finished, 0.001248 sec.
# 782-th simulation finished, 0.001237 sec.
# 783-th simulation finished, 0.001182 sec.
# 784-th simulation finished, 0.001206 sec.
# 785-th simulation finished, 0.001175 sec.
# 786-th simulation finished, 0.001201 sec.
# 787-th simulation finished, 0.001174 sec.
# 788-th simulation finished, 0.001182 sec.
# 789-th simulation finished, 0.001175 sec.
# 790-th simulation finished, 0.001183 sec.
# 791-th simulation finished, 0.001163 sec.
# 792-th simulation finished, 0.001191 sec.
# 793-th simulation finished, 0.001159 sec.
# 794-th simulation finished, 0.001212 sec.
# 795-th simulation finished, 0.001149 sec.
# 796-th simulation finished, 0.001171 sec.
# 797-th simulation finished, 0.001164 sec.
# 798-th simulation finished, 0.001180 sec.
# 799-th simulation finished, 0.001163 sec.
# 800-th simulation finished, 0.001178 sec.
# 801-th simulation finished, 0.001153 sec.
# 802-th simulation finished, 0.001173 sec.
# 803-th simulation finished, 0.001244 sec.
# 804-th simulation finished, 0.001246 sec.
# 805-th simulation finished, 0.001195 sec.
# 806-th simulation finished, 0.001186 sec.
# 807-th simulation finished, 0.001174 sec.
# 808-th simulation finished, 0.001186 sec.
# 809-th simulation finished, 0.001183 sec.
# 810-th simulation finished, 0.001198 sec.
# 811-th simulation finished, 0.001225 sec.
# 812-th simulation finished, 0.001210 sec.
# 813-th simulation finished, 0.001232 sec.
# 814-th simulation finished, 0.001179 sec.
# 815-th simulation finished, 0.001210 sec.
# 816-th simulation finished, 0.001173 sec.
# 817-th simulation finished, 0.001186 sec.
# 818-th simulation finished, 0.001135 sec.
# 819-th simulation finished, 0.001157 sec.
# 820-th simulation finished, 0.001148 sec.
# 821-th simulation finished, 0.001158 sec.
# 822-th simulation finished, 0.001123 sec.
# 823-th simulation finished, 0.001158 sec.
# 824-th simulation finished, 0.001128 sec.
# 825-th simulation finished, 0.001153 sec.
# 826-th simulation finished, 0.001122 sec.
# 827-th simulation finished, 0.001139 sec.
# 828-th simulation finished, 0.001120 sec.
# 829-th simulation finished, 0.001164 sec.
# 830-th simulation finished, 0.001116 sec.
# 831-th simulation finished, 0.001138 sec.
# 832-th simulation finished, 0.001131 sec.
# 833-th simulation finished, 0.001149 sec.
# 834-th simulation finished, 0.001202 sec.
# 835-th simulation finished, 0.001181 sec.
# 836-th simulation finished, 0.001140 sec.
# 837-th simulation finished, 0.001154 sec.
# 838-th simulation finished, 0.001126 sec.
# 839-th simulation finished, 0.001140 sec.
# 840-th simulation finished, 0.001142 sec.
# 841-th simulation finished, 0.001189 sec.
# 842-th simulation finished, 0.001214 sec.
# 843-th simulation finished, 0.001502 sec.
# 844-th simulation finished, 0.001501 sec.
# 845-th simulation finished, 0.001245 sec.
# 846-th simulation finished, 0.001190 sec.
# 847-th simulation finished, 0.001177 sec.
# 848-th simulation finished, 0.001176 sec.
# 849-th simulation finished, 0.001239 sec.
# 850-th simulation finished, 0.001213 sec.
# 851-th simulation finished, 0.001136 sec.
# 852-th simulation finished, 0.001156 sec.
# 853-th simulation finished, 0.001124 sec.
# 854-th simulation finished, 0.001148 sec.
# 855-th simulation finished, 0.001113 sec.
# 856-th simulation finished, 0.001145 sec.
# 857-th simulation finished, 0.001123 sec.
# 858-th simulation finished, 0.001159 sec.
# 859-th simulation finished, 0.001111 sec.
# 860-th simulation finished, 0.001156 sec.
# 861-th simulation finished, 0.001123 sec.
# 862-th simulation finished, 0.001609 sec.
# 863-th simulation finished, 0.001358 sec.
# 864-th simulation finished, 0.001266 sec.
# 865-th simulation finished, 0.001216 sec.
# 866-th simulation finished, 0.001169 sec.
# 867-th simulation finished, 0.001186 sec.
# 868-th simulation finished, 0.001176 sec.
# 869-th simulation finished, 0.001200 sec.
# 870-th simulation finished, 0.001157 sec.
# 871-th simulation finished, 0.001187 sec.
# 872-th simulation finished, 0.001162 sec.
# 873-th simulation finished, 0.001158 sec.
# 874-th simulation finished, 0.001123 sec.
# 875-th simulation finished, 0.001147 sec.
# 876-th simulation finished, 0.001120 sec.
# 877-th simulation finished, 0.001142 sec.
# 878-th simulation finished, 0.001127 sec.
# 879-th simulation finished, 0.001170 sec.
# 880-th simulation finished, 0.001117 sec.
# 881-th simulation finished, 0.001137 sec.
# 882-th simulation finished, 0.001114 sec.
# 883-th simulation finished, 0.001134 sec.
# 884-th simulation finished, 0.001105 sec.
# 885-th simulation finished, 0.001139 sec.
# 886-th simulation finished, 0.001116 sec.
# 887-th simulation finished, 0.001134 sec.
# 888-th simulation finished, 0.001245 sec.
# 889-th simulation finished, 0.001231 sec.
# 890-th simulation finished, 0.001137 sec.
# 891-th simulation finished, 0.001165 sec.
# 892-th simulation finished, 0.001136 sec.
# 893-th simulation finished, 0.001152 sec.
# 894-th simulation finished, 0.001194 sec.
# 895-th simulation finished, 0.001203 sec.
# 896-th simulation finished, 0.001138 sec.
# 897-th simulation finished, 0.001152 sec.
# 898-th simulation finished, 0.001143 sec.
# 899-th simulation finished, 0.001141 sec.
# 900-th simulation finished, 0.001118 sec.
# 901-th simulation finished, 0.001138 sec.
# 902-th simulation finished, 0.001130 sec.
# 903-th simulation finished, 0.001157 sec.
# 904-th simulation finished, 0.001154 sec.
# 905-th simulation finished, 0.001147 sec.
# 906-th simulation finished, 0.001110 sec.
# 907-th simulation finished, 0.001153 sec.
# 908-th simulation finished, 0.001158 sec.
# 909-th simulation finished, 0.001180 sec.
# 910-th simulation finished, 0.001149 sec.
# 911-th simulation finished, 0.001167 sec.
# 912-th simulation finished, 0.001179 sec.
# 913-th simulation finished, 0.001170 sec.
# 914-th simulation finished, 0.001150 sec.
# 915-th simulation finished, 0.001172 sec.
# 916-th simulation finished, 0.001199 sec.
# 917-th simulation finished, 0.001213 sec.
# 918-th simulation finished, 0.001142 sec.
# 919-th simulation finished, 0.001132 sec.
# 920-th simulation finished, 0.001141 sec.
# 921-th simulation finished, 0.001133 sec.
# 922-th simulation finished, 0.001129 sec.
# 923-th simulation finished, 0.001153 sec.
# 924-th simulation finished, 0.001112 sec.
# 925-th simulation finished, 0.001137 sec.
# 926-th simulation finished, 0.001121 sec.
# 927-th simulation finished, 0.001162 sec.
# 928-th simulation finished, 0.001113 sec.
# 929-th simulation finished, 0.001138 sec.
# 930-th simulation finished, 0.001127 sec.
# 931-th simulation finished, 0.001128 sec.
# 932-th simulation finished, 0.001119 sec.
# 933-th simulation finished, 0.001133 sec.
# 934-th simulation finished, 0.001111 sec.
# 935-th simulation finished, 0.001154 sec.
# 936-th simulation finished, 0.001222 sec.
# 937-th simulation finished, 0.001193 sec.
# 938-th simulation finished, 0.001128 sec.
# 939-th simulation finished, 0.001158 sec.
# 940-th simulation finished, 0.001125 sec.
# 941-th simulation finished, 0.001164 sec.
# 942-th simulation finished, 0.001157 sec.
# 943-th simulation finished, 0.001217 sec.
# 944-th simulation finished, 0.001224 sec.
# 945-th simulation finished, 0.001194 sec.
# 946-th simulation finished, 0.001161 sec.
# 947-th simulation finished, 0.001179 sec.
# 948-th simulation finished, 0.001164 sec.
# 949-th simulation finished, 0.001176 sec.
# 950-th simulation finished, 0.001164 sec.
# 951-th simulation finished, 0.001181 sec.
# 952-th simulation finished, 0.001157 sec.
# 953-th simulation finished, 0.001134 sec.
# 954-th simulation finished, 0.001117 sec.
# 955-th simulation finished, 0.001142 sec.
# 956-th simulation finished, 0.001131 sec.
# 957-th simulation finished, 0.001128 sec.
# 958-th simulation finished, 0.001112 sec.
# 959-th simulation finished, 0.001144 sec.
# 960-th simulation finished, 0.001117 sec.
# 961-th simulation finished, 0.001159 sec.
# 962-th simulation finished, 0.001115 sec.
# 963-th simulation finished, 0.001236 sec.
# 964-th simulation finished, 0.001157 sec.
# 965-th simulation finished, 0.001148 sec.
# 966-th simulation finished, 0.001153 sec.
# 967-th simulation finished, 0.001152 sec.
# 968-th simulation finished, 0.001183 sec.
# 969-th simulation finished, 0.001184 sec.
# 970-th simulation finished, 0.001124 sec.
# 971-th simulation finished, 0.001161 sec.
# 972-th simulation finished, 0.001119 sec.
# 973-th simulation finished, 0.001147 sec.
# 974-th simulation finished, 0.001119 sec.
# 975-th simulation finished, 0.001167 sec.
# 976-th simulation finished, 0.001152 sec.
# 977-th simulation finished, 0.001185 sec.
# 978-th simulation finished, 0.001180 sec.
# 979-th simulation finished, 0.001224 sec.
# 980-th simulation finished, 0.001183 sec.
# 981-th simulation finished, 0.001163 sec.
# 982-th simulation finished, 0.001188 sec.
# 983-th simulation finished, 0.001173 sec.
# 984-th simulation finished, 0.001196 sec.
# 985-th simulation finished, 0.001163 sec.
# 986-th simulation finished, 0.001162 sec.
# 987-th simulation finished, 0.001112 sec.
# 988-th simulation finished, 0.001139 sec.
# 989-th simulation finished, 0.001113 sec.
# 990-th simulation finished, 0.001134 sec.
# 991-th simulation finished, 0.001112 sec.
# 992-th simulation finished, 0.001137 sec.
# 993-th simulation finished, 0.001125 sec.
# 994-th simulation finished, 0.001136 sec.
# 995-th simulation finished, 0.001118 sec.
# 996-th simulation finished, 0.001131 sec.
# 997-th simulation finished, 0.001113 sec.
# 998-th simulation finished, 0.001147 sec.
# 999-th simulation finished, 0.001169 sec.
# 1000-th simulation finished, 0.001136 sec.

# %%
plt.hist(bsim[:,1])
plt.axvline(beta[1], color='red')

# %%
stats.probplot(bsim[:,1], dist = 'norm', plot=plt, fit=True)
# plt.plot([0, 1], [0, 1], color='black')
plt.show()

# %%
plt.hist(Ts_dth)
# Out:
# (array([ 24., 105., 223., 264., 216., 106.,  51.,   7.,   1.,   3.]),
#  array([-2.47287646, -1.78155851, -1.09024056, -0.39892261,  0.29239534,
#          0.98371329,  1.67503124,  2.36634919,  3.05766715,  3.7489851 ,
#          4.44030305]),
#  <BarContainer object of 10 artists>)

# %%
stats.probplot(ps_dth, dist = 'uniform', plot=plt, fit=False)
plt.plot([0, 1], [0, 1], color='black')
plt.show()

# %%
np.mean(np.abs(ps_dth) > 0.05)
# Out:
# 0.955

# %%
stats.probplot(ps_sdw, dist = 'uniform', plot=plt, fit=False)
plt.plot([0, 1], [0, 1], color='black')
plt.show()

# %%
np.mean(np.abs(ps_sdw) > 0.05)
# Out:
# 0.921
