# %%
import os, importlib, sys, time

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import scipy.linalg as la
import scipy.stats as stats
import scipy.optimize as opt

# %%
import freqepid

# %% [markdown]
# # 1. parameters

# %%
T = 60
T0 = 40

# %%
GPi = np.load('data/GPi.npz')

# %% [markdown]
# ## observation parameters

# %%
alpha = 0.01
r_Y = 10

# %% [markdown]
# $$Y_t = NegBinom( \frac{EY_t}{r_Y + EY_t}, r_Y )$$
#
# $$ EY_t = \alpha\sum_{s=1}^{t-1} I_s \pi_{t-s} $$

# %% [markdown]
# ## latent parameters

# %%
d = 2
beta = np.array([1, -3.2])

# %%
r_I = 100
K = 6.5

# %% [markdown]
# $$I_t = NegBinom( \frac{EI_t}{r_I + EI_t}, r_I )$$
#
# $$ EI_t = R(\bar{A}_t, \beta) \sum_{s=1}^{t-1} I_s g_{t-s} $$
#
# $$R(\bar{A}_t, \beta) = \frac{K}{1+\exp(- \beta^\top A_t)}$$

# %% [markdown]
# ## seed values

# %%
mu = np.log(100)

# %% [markdown]
# $$I_{[-T_0,0)} = \exp(\mu_0)$$

# %% [markdown]
# # 2. simulation

# %%
num_sim = 1000

# %% [markdown]
# ## load simulation

# %%
data = pd.read_feather('data/simulation_randinf_4.feather')

# %%
data
# Out:
#        sim  date         R           EI  infection         EY  death  \
# 0        0     0  4.751881   475.184804      516.0   0.956069      1
# 1        0     1  4.751881   511.412680      505.0   0.962545      1
# 2        0     2  4.751881   642.093954      669.0   0.968354      1
# 3        0     3  4.751881   854.356947      836.0   0.974111      3
# 4        0     4  4.751881  1148.169578      942.0   0.981589      1
# ...    ...   ...       ...          ...        ...        ...    ...
# 59995  999    55  0.648378   885.944342      908.0  39.632942     42
# 59996  999    56  0.648378   839.945956      853.0  37.595696     50
# 59997  999    57  0.648378   796.884901      795.0  35.639456     74
# 59998  999    58  0.648378   755.284834      661.0  33.743259     28
# 59999  999    59  0.648378   713.678448      696.0  31.929427     38
#
#        intervention
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 59995             1
# 59996             1
# 59997             1
# 59998             1
# 59999             1
#
# [60000 rows x 8 columns]

# %% [markdown]
# # 3. Fit

# %%
model = freqepid.Model(GPi['g'], GPi['pi'], alpha, K, T0, "nbinom")

# %%
nsim = np.zeros(num_sim)
msim = np.zeros(num_sim)
bsim = np.zeros((num_sim,d))

# %%
for iter_sim in np.arange(num_sim):
    start_sim = time.time()
    
    data_i = data[data['sim']==iter_sim]
    A = np.stack([np.full(T, 1), data_i["intervention"].to_numpy()], -1)
    Y = data_i["death"].to_numpy()
    
    # fit
    nmle, mmle, bmle, ll =\
    model.fit(A, Y, n_iter=500, step_size=1,
              history=False, verbose=False)
    
    nsim[iter_sim] = nmle
    msim[iter_sim] = mmle
    bsim[iter_sim,:] = bmle
    
    sys.__stdout__.write("%d-th simulation finished, %f sec.\n"
                         %(iter_sim+1, time.time()-start_sim))
    sys.__stdout__.flush()
# Out:
# /Users/blueconet/mambaforge/envs/freqepid/lib/python3.10/site-packages/freqepid/model.py:140: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   bhaty = np.linalg.lstsq(Xy, Yy)[0]
# 1-th simulation finished, 2.635063 sec.
# 2-th simulation finished, 2.544532 sec.
# 3-th simulation finished, 2.488963 sec.
# 4-th simulation finished, 2.511071 sec.
# 5-th simulation finished, 2.719303 sec.
# 6-th simulation finished, 2.621358 sec.
# 7-th simulation finished, 2.795858 sec.
# 8-th simulation finished, 2.596144 sec.
# 9-th simulation finished, 2.722276 sec.
# 10-th simulation finished, 2.726746 sec.
# 11-th simulation finished, 2.781624 sec.
# 12-th simulation finished, 2.629631 sec.
# 13-th simulation finished, 2.552818 sec.
# 14-th simulation finished, 2.504875 sec.
# 15-th simulation finished, 2.598064 sec.
# 16-th simulation finished, 2.394729 sec.
# 17-th simulation finished, 2.675034 sec.
# 18-th simulation finished, 2.635192 sec.
# 19-th simulation finished, 2.713565 sec.
# 20-th simulation finished, 2.627215 sec.
# 21-th simulation finished, 2.687697 sec.
# 22-th simulation finished, 2.614920 sec.
# 23-th simulation finished, 2.652219 sec.
# 24-th simulation finished, 2.575254 sec.
# 25-th simulation finished, 2.685332 sec.
# 26-th simulation finished, 2.555719 sec.
# 27-th simulation finished, 2.568686 sec.
# 28-th simulation finished, 2.670629 sec.
# 29-th simulation finished, 2.607946 sec.
# 30-th simulation finished, 2.546256 sec.
# 31-th simulation finished, 2.594666 sec.
# 32-th simulation finished, 2.555645 sec.
# 33-th simulation finished, 2.669423 sec.
# 34-th simulation finished, 2.632984 sec.
# 35-th simulation finished, 2.618327 sec.
# 36-th simulation finished, 2.872200 sec.
# 37-th simulation finished, 2.742523 sec.
# 38-th simulation finished, 2.676820 sec.
# 39-th simulation finished, 2.590443 sec.
# 40-th simulation finished, 2.618891 sec.
# 41-th simulation finished, 2.662292 sec.
# 42-th simulation finished, 2.705144 sec.
# 43-th simulation finished, 2.632008 sec.
# 44-th simulation finished, 2.421329 sec.
# 45-th simulation finished, 2.682189 sec.
# 46-th simulation finished, 2.606595 sec.
# 47-th simulation finished, 2.973671 sec.
# 48-th simulation finished, 2.626328 sec.
# 49-th simulation finished, 2.693215 sec.
# 50-th simulation finished, 2.569098 sec.
# 51-th simulation finished, 2.546230 sec.
# 52-th simulation finished, 2.617962 sec.
# 53-th simulation finished, 2.672094 sec.
# 54-th simulation finished, 2.773881 sec.
# 55-th simulation finished, 2.688243 sec.
# 56-th simulation finished, 2.858331 sec.
# 57-th simulation finished, 2.611146 sec.
# 58-th simulation finished, 2.872439 sec.
# 59-th simulation finished, 2.581994 sec.
# 60-th simulation finished, 2.677938 sec.
# 61-th simulation finished, 2.623890 sec.
# 62-th simulation finished, 2.960400 sec.
# 63-th simulation finished, 2.637799 sec.
# 64-th simulation finished, 2.609600 sec.
# 65-th simulation finished, 2.658256 sec.
# 66-th simulation finished, 2.621306 sec.
# 67-th simulation finished, 2.687824 sec.
# 68-th simulation finished, 2.894567 sec.
# 69-th simulation finished, 2.702705 sec.
# 70-th simulation finished, 2.546938 sec.
# 71-th simulation finished, 2.596022 sec.
# 72-th simulation finished, 2.821624 sec.
# 73-th simulation finished, 2.641943 sec.
# 74-th simulation finished, 2.635887 sec.
# 75-th simulation finished, 2.702340 sec.
# 76-th simulation finished, 2.936190 sec.
# 77-th simulation finished, 2.701084 sec.
# 78-th simulation finished, 2.542493 sec.
# 79-th simulation finished, 2.654965 sec.
# 80-th simulation finished, 2.691423 sec.
# 81-th simulation finished, 2.647295 sec.
# 82-th simulation finished, 2.639599 sec.
# 83-th simulation finished, 2.676105 sec.
# 84-th simulation finished, 2.685679 sec.
# 85-th simulation finished, 2.679690 sec.
# 86-th simulation finished, 2.677284 sec.
# 87-th simulation finished, 2.767785 sec.
# 88-th simulation finished, 2.630953 sec.
# 89-th simulation finished, 2.637760 sec.
# 90-th simulation finished, 2.662673 sec.
# 91-th simulation finished, 2.920448 sec.
# 92-th simulation finished, 2.697903 sec.
# 93-th simulation finished, 2.884554 sec.
# 94-th simulation finished, 2.565046 sec.
# 95-th simulation finished, 2.587734 sec.
# 96-th simulation finished, 2.519270 sec.
# 97-th simulation finished, 2.905536 sec.
# 98-th simulation finished, 2.612236 sec.
# 99-th simulation finished, 2.617089 sec.
# 100-th simulation finished, 2.851524 sec.
# 101-th simulation finished, 2.829818 sec.
# 102-th simulation finished, 2.639576 sec.
# 103-th simulation finished, 2.596281 sec.
# 104-th simulation finished, 2.677604 sec.
# 105-th simulation finished, 2.732720 sec.
# 106-th simulation finished, 2.512695 sec.
# 107-th simulation finished, 2.736407 sec.
# 108-th simulation finished, 2.653615 sec.
# 109-th simulation finished, 2.620031 sec.
# 110-th simulation finished, 2.667927 sec.
# 111-th simulation finished, 2.540528 sec.
# 112-th simulation finished, 2.643377 sec.
# 113-th simulation finished, 2.711388 sec.
# 114-th simulation finished, 2.616155 sec.
# 115-th simulation finished, 2.422591 sec.
# 116-th simulation finished, 2.721801 sec.
# 117-th simulation finished, 2.648220 sec.
# 118-th simulation finished, 2.614471 sec.
# 119-th simulation finished, 2.693908 sec.
# 120-th simulation finished, 2.461824 sec.
# 121-th simulation finished, 2.669276 sec.
# 122-th simulation finished, 2.890614 sec.
# 123-th simulation finished, 2.679599 sec.
# 124-th simulation finished, 2.613378 sec.
# 125-th simulation finished, 2.609178 sec.
# 126-th simulation finished, 2.608660 sec.
# 127-th simulation finished, 2.631482 sec.
# 128-th simulation finished, 2.756847 sec.
# 129-th simulation finished, 2.700375 sec.
# 130-th simulation finished, 2.733459 sec.
# 131-th simulation finished, 2.658577 sec.
# 132-th simulation finished, 2.611320 sec.
# 133-th simulation finished, 2.646412 sec.
# 134-th simulation finished, 2.710565 sec.
# 135-th simulation finished, 2.921813 sec.
# 136-th simulation finished, 2.907939 sec.
# 137-th simulation finished, 2.555770 sec.
# 138-th simulation finished, 2.816760 sec.
# 139-th simulation finished, 2.711205 sec.
# 140-th simulation finished, 2.619678 sec.
# 141-th simulation finished, 3.137200 sec.
# 142-th simulation finished, 2.596643 sec.
# 143-th simulation finished, 2.598063 sec.
# 144-th simulation finished, 2.637540 sec.
# 145-th simulation finished, 2.783016 sec.
# 146-th simulation finished, 2.641952 sec.
# 147-th simulation finished, 2.656246 sec.
# 148-th simulation finished, 2.855986 sec.
# 149-th simulation finished, 2.707691 sec.
# 150-th simulation finished, 2.679993 sec.
# 151-th simulation finished, 2.624853 sec.
# 152-th simulation finished, 2.907881 sec.
# 153-th simulation finished, 2.704971 sec.
# 154-th simulation finished, 3.033681 sec.
# 155-th simulation finished, 2.706623 sec.
# 156-th simulation finished, 2.475607 sec.
# 157-th simulation finished, 2.585820 sec.
# 158-th simulation finished, 2.851709 sec.
# 159-th simulation finished, 2.551760 sec.
# 160-th simulation finished, 2.692886 sec.
# 161-th simulation finished, 2.607316 sec.
# 162-th simulation finished, 2.691702 sec.
# 163-th simulation finished, 2.697708 sec.
# 164-th simulation finished, 2.595067 sec.
# 165-th simulation finished, 2.727971 sec.
# 166-th simulation finished, 2.779236 sec.
# 167-th simulation finished, 2.581157 sec.
# 168-th simulation finished, 2.554618 sec.
# 169-th simulation finished, 2.592532 sec.
# 170-th simulation finished, 2.620314 sec.
# 171-th simulation finished, 2.692787 sec.
# 172-th simulation finished, 2.705444 sec.
# 173-th simulation finished, 2.832401 sec.
# 174-th simulation finished, 2.934933 sec.
# 175-th simulation finished, 2.615987 sec.
# 176-th simulation finished, 2.615725 sec.
# 177-th simulation finished, 2.878167 sec.
# 178-th simulation finished, 2.608771 sec.
# 179-th simulation finished, 2.620710 sec.
# 180-th simulation finished, 2.617103 sec.
# 181-th simulation finished, 2.793050 sec.
# 182-th simulation finished, 2.592841 sec.
# 183-th simulation finished, 2.697805 sec.
# 184-th simulation finished, 2.617961 sec.
# 185-th simulation finished, 2.695938 sec.
# 186-th simulation finished, 2.771745 sec.
# 187-th simulation finished, 2.658072 sec.
# 188-th simulation finished, 2.606152 sec.
# 189-th simulation finished, 2.686555 sec.
# 190-th simulation finished, 2.671856 sec.
# 191-th simulation finished, 2.638619 sec.
# 192-th simulation finished, 2.640350 sec.
# 193-th simulation finished, 2.685111 sec.
# 194-th simulation finished, 2.714471 sec.
# 195-th simulation finished, 2.573958 sec.
# 196-th simulation finished, 2.642190 sec.
# 197-th simulation finished, 2.732071 sec.
# 198-th simulation finished, 2.699518 sec.
# 199-th simulation finished, 2.673085 sec.
# 200-th simulation finished, 2.828364 sec.
# 201-th simulation finished, 2.861772 sec.
# 202-th simulation finished, 2.569903 sec.
# 203-th simulation finished, 2.677229 sec.
# 204-th simulation finished, 2.873563 sec.
# 205-th simulation finished, 2.706693 sec.
# 206-th simulation finished, 2.621682 sec.
# 207-th simulation finished, 2.711928 sec.
# 208-th simulation finished, 2.889379 sec.
# 209-th simulation finished, 2.490657 sec.
# 210-th simulation finished, 2.654900 sec.
# 211-th simulation finished, 2.621214 sec.
# 212-th simulation finished, 2.774348 sec.
# 213-th simulation finished, 3.061330 sec.
# 214-th simulation finished, 2.630199 sec.
# 215-th simulation finished, 2.649902 sec.
# 216-th simulation finished, 2.644940 sec.
# 217-th simulation finished, 2.639433 sec.
# 218-th simulation finished, 2.612094 sec.
# 219-th simulation finished, 2.640344 sec.
# 220-th simulation finished, 2.700417 sec.
# 221-th simulation finished, 2.714036 sec.
# 222-th simulation finished, 2.685973 sec.
# 223-th simulation finished, 2.670391 sec.
# 224-th simulation finished, 2.737072 sec.
# 225-th simulation finished, 2.609443 sec.
# 226-th simulation finished, 2.546694 sec.
# 227-th simulation finished, 2.620463 sec.
# 228-th simulation finished, 2.774021 sec.
# 229-th simulation finished, 2.583153 sec.
# 230-th simulation finished, 2.506241 sec.
# 231-th simulation finished, 2.615542 sec.
# 232-th simulation finished, 2.702376 sec.
# 233-th simulation finished, 2.511276 sec.
# 234-th simulation finished, 2.687354 sec.
# 235-th simulation finished, 2.601912 sec.
# 236-th simulation finished, 2.681793 sec.
# 237-th simulation finished, 2.707715 sec.
# 238-th simulation finished, 2.548413 sec.
# 239-th simulation finished, 2.950394 sec.
# 240-th simulation finished, 2.753384 sec.
# 241-th simulation finished, 2.640349 sec.
# 242-th simulation finished, 2.757348 sec.
# 243-th simulation finished, 2.681650 sec.
# 244-th simulation finished, 2.986976 sec.
# 245-th simulation finished, 2.628556 sec.
# 246-th simulation finished, 2.841641 sec.
# 247-th simulation finished, 2.623508 sec.
# 248-th simulation finished, 2.578946 sec.
# 249-th simulation finished, 2.708057 sec.
# 250-th simulation finished, 2.447577 sec.
# 251-th simulation finished, 2.644312 sec.
# 252-th simulation finished, 2.922492 sec.
# 253-th simulation finished, 2.514682 sec.
# 254-th simulation finished, 2.486721 sec.
# 255-th simulation finished, 2.587979 sec.
# 256-th simulation finished, 2.649280 sec.
# 257-th simulation finished, 2.888702 sec.
# 258-th simulation finished, 2.669253 sec.
# 259-th simulation finished, 2.652363 sec.
# 260-th simulation finished, 2.584898 sec.
# 261-th simulation finished, 2.695404 sec.
# 262-th simulation finished, 2.650285 sec.
# 263-th simulation finished, 2.991912 sec.
# 264-th simulation finished, 3.001386 sec.
# 265-th simulation finished, 2.665952 sec.
# 266-th simulation finished, 2.663196 sec.
# 267-th simulation finished, 2.426994 sec.
# 268-th simulation finished, 2.671620 sec.
# 269-th simulation finished, 2.564141 sec.
# 270-th simulation finished, 3.041260 sec.
# 271-th simulation finished, 2.901189 sec.
# 272-th simulation finished, 2.794601 sec.
# 273-th simulation finished, 2.749360 sec.
# 274-th simulation finished, 2.705112 sec.
# 275-th simulation finished, 2.678524 sec.
# 276-th simulation finished, 2.670801 sec.
# 277-th simulation finished, 2.695848 sec.
# 278-th simulation finished, 2.711890 sec.
# 279-th simulation finished, 2.697184 sec.
# 280-th simulation finished, 2.556307 sec.
# 281-th simulation finished, 2.763771 sec.
# 282-th simulation finished, 2.949268 sec.
# 283-th simulation finished, 2.884511 sec.
# 284-th simulation finished, 3.058796 sec.
# 285-th simulation finished, 2.744502 sec.
# 286-th simulation finished, 2.545061 sec.
# 287-th simulation finished, 2.623726 sec.
# 288-th simulation finished, 2.653745 sec.
# 289-th simulation finished, 2.690032 sec.
# 290-th simulation finished, 2.951408 sec.
# 291-th simulation finished, 2.576952 sec.
# 292-th simulation finished, 2.600538 sec.
# 293-th simulation finished, 3.318760 sec.
# 294-th simulation finished, 2.991740 sec.
# 295-th simulation finished, 2.767026 sec.
# 296-th simulation finished, 3.173092 sec.
# 297-th simulation finished, 2.760031 sec.
# 298-th simulation finished, 2.761357 sec.
# 299-th simulation finished, 2.955074 sec.
# 300-th simulation finished, 2.512564 sec.
# 301-th simulation finished, 2.733517 sec.
# 302-th simulation finished, 2.872955 sec.
# 303-th simulation finished, 2.964608 sec.
# 304-th simulation finished, 2.828334 sec.
# 305-th simulation finished, 2.660328 sec.
# 306-th simulation finished, 2.666994 sec.
# 307-th simulation finished, 2.603862 sec.
# 308-th simulation finished, 2.678146 sec.
# 309-th simulation finished, 2.715071 sec.
# 310-th simulation finished, 2.776764 sec.
# 311-th simulation finished, 2.755021 sec.
# 312-th simulation finished, 2.642088 sec.
# 313-th simulation finished, 2.693113 sec.
# 314-th simulation finished, 2.982433 sec.
# 315-th simulation finished, 2.846048 sec.
# 316-th simulation finished, 2.509105 sec.
# 317-th simulation finished, 2.703471 sec.
# 318-th simulation finished, 2.703734 sec.
# 319-th simulation finished, 2.886004 sec.
# 320-th simulation finished, 2.660914 sec.
# 321-th simulation finished, 2.671233 sec.
# 322-th simulation finished, 2.612179 sec.
# 323-th simulation finished, 3.091641 sec.
# 324-th simulation finished, 2.927321 sec.
# 325-th simulation finished, 2.734025 sec.
# 326-th simulation finished, 2.698649 sec.
# 327-th simulation finished, 2.651066 sec.
# 328-th simulation finished, 2.436178 sec.
# 329-th simulation finished, 2.699536 sec.
# 330-th simulation finished, 2.573161 sec.
# 331-th simulation finished, 2.968534 sec.
# 332-th simulation finished, 2.689402 sec.
# 333-th simulation finished, 2.661522 sec.
# 334-th simulation finished, 2.311665 sec.
# 335-th simulation finished, 2.716444 sec.
# 336-th simulation finished, 2.615915 sec.
# 337-th simulation finished, 2.612813 sec.
# 338-th simulation finished, 2.595062 sec.
# 339-th simulation finished, 2.735373 sec.
# 340-th simulation finished, 2.831534 sec.
# 341-th simulation finished, 2.827354 sec.
# 342-th simulation finished, 2.550478 sec.
# 343-th simulation finished, 2.738118 sec.
# 344-th simulation finished, 2.758244 sec.
# 345-th simulation finished, 2.678588 sec.
# 346-th simulation finished, 2.662930 sec.
# 347-th simulation finished, 2.750228 sec.
# 348-th simulation finished, 2.601828 sec.
# 349-th simulation finished, 2.867944 sec.
# 350-th simulation finished, 2.594960 sec.
# 351-th simulation finished, 2.704869 sec.
# 352-th simulation finished, 2.752659 sec.
# 353-th simulation finished, 2.812268 sec.
# 354-th simulation finished, 2.577257 sec.
# 355-th simulation finished, 2.699120 sec.
# 356-th simulation finished, 2.606627 sec.
# 357-th simulation finished, 2.649574 sec.
# 358-th simulation finished, 2.811975 sec.
# 359-th simulation finished, 2.618468 sec.
# 360-th simulation finished, 2.731945 sec.
# 361-th simulation finished, 2.697272 sec.
# 362-th simulation finished, 2.744657 sec.
# 363-th simulation finished, 2.716872 sec.
# 364-th simulation finished, 2.688983 sec.
# 365-th simulation finished, 2.856684 sec.
# 366-th simulation finished, 2.735764 sec.
# 367-th simulation finished, 2.731246 sec.
# 368-th simulation finished, 3.005632 sec.
# 369-th simulation finished, 2.587326 sec.
# 370-th simulation finished, 2.671488 sec.
# 371-th simulation finished, 2.661400 sec.
# 372-th simulation finished, 2.568763 sec.
# 373-th simulation finished, 2.652399 sec.
# 374-th simulation finished, 2.634670 sec.
# 375-th simulation finished, 2.587057 sec.
# 376-th simulation finished, 2.703444 sec.
# 377-th simulation finished, 2.509245 sec.
# 378-th simulation finished, 2.666715 sec.
# 379-th simulation finished, 2.662359 sec.
# 380-th simulation finished, 2.652228 sec.
# 381-th simulation finished, 2.693416 sec.
# 382-th simulation finished, 2.934661 sec.
# 383-th simulation finished, 2.986649 sec.
# 384-th simulation finished, 2.947018 sec.
# 385-th simulation finished, 3.089445 sec.
# 386-th simulation finished, 2.989120 sec.
# 387-th simulation finished, 2.924579 sec.
# 388-th simulation finished, 2.815352 sec.
# 389-th simulation finished, 2.936848 sec.
# 390-th simulation finished, 2.794825 sec.
# 391-th simulation finished, 2.723756 sec.
# 392-th simulation finished, 3.041334 sec.
# 393-th simulation finished, 2.815855 sec.
# 394-th simulation finished, 2.857190 sec.
# 395-th simulation finished, 2.673663 sec.
# 396-th simulation finished, 2.707792 sec.
# 397-th simulation finished, 3.320108 sec.
# 398-th simulation finished, 2.870026 sec.
# 399-th simulation finished, 2.719855 sec.
# 400-th simulation finished, 2.915350 sec.
# 401-th simulation finished, 2.751055 sec.
# 402-th simulation finished, 2.834036 sec.
# 403-th simulation finished, 2.912996 sec.
# 404-th simulation finished, 2.776763 sec.
# 405-th simulation finished, 3.620729 sec.
# 406-th simulation finished, 2.890951 sec.
# 407-th simulation finished, 3.055569 sec.
# 408-th simulation finished, 3.216222 sec.
# 409-th simulation finished, 2.830849 sec.
# 410-th simulation finished, 2.841306 sec.
# 411-th simulation finished, 2.835017 sec.
# 412-th simulation finished, 2.819706 sec.
# 413-th simulation finished, 2.779743 sec.
# 414-th simulation finished, 2.575919 sec.
# 415-th simulation finished, 2.769358 sec.
# 416-th simulation finished, 2.806291 sec.
# 417-th simulation finished, 3.014523 sec.
# 418-th simulation finished, 2.765286 sec.
# 419-th simulation finished, 2.814322 sec.
# 420-th simulation finished, 3.094315 sec.
# 421-th simulation finished, 2.824522 sec.
# 422-th simulation finished, 2.713274 sec.
# 423-th simulation finished, 2.795748 sec.
# 424-th simulation finished, 3.266693 sec.
# 425-th simulation finished, 2.917877 sec.
# 426-th simulation finished, 2.572063 sec.
# 427-th simulation finished, 2.833466 sec.
# 428-th simulation finished, 3.245067 sec.
# 429-th simulation finished, 2.887330 sec.
# 430-th simulation finished, 2.807512 sec.
# 431-th simulation finished, 2.913341 sec.
# 432-th simulation finished, 2.912767 sec.
# 433-th simulation finished, 2.910198 sec.
# 434-th simulation finished, 3.139174 sec.
# 435-th simulation finished, 2.922499 sec.
# 436-th simulation finished, 2.804729 sec.
# 437-th simulation finished, 2.914351 sec.
# 438-th simulation finished, 3.093374 sec.
# 439-th simulation finished, 2.923023 sec.
# 440-th simulation finished, 3.135701 sec.
# 441-th simulation finished, 3.048128 sec.
# 442-th simulation finished, 3.000626 sec.
# 443-th simulation finished, 3.011450 sec.
# 444-th simulation finished, 2.852252 sec.
# 445-th simulation finished, 2.925394 sec.
# 446-th simulation finished, 2.965202 sec.
# 447-th simulation finished, 3.005500 sec.
# 448-th simulation finished, 2.971943 sec.
# 449-th simulation finished, 2.811207 sec.
# 450-th simulation finished, 3.011407 sec.
# 451-th simulation finished, 3.002988 sec.
# 452-th simulation finished, 2.932061 sec.
# 453-th simulation finished, 2.993526 sec.
# 454-th simulation finished, 2.955876 sec.
# 455-th simulation finished, 2.950029 sec.
# 456-th simulation finished, 2.964957 sec.
# 457-th simulation finished, 3.145775 sec.
# 458-th simulation finished, 3.031516 sec.
# 459-th simulation finished, 2.868010 sec.
# 460-th simulation finished, 2.829949 sec.
# 461-th simulation finished, 3.155960 sec.
# 462-th simulation finished, 3.427505 sec.
# 463-th simulation finished, 2.903147 sec.
# 464-th simulation finished, 2.863371 sec.
# 465-th simulation finished, 2.899528 sec.
# 466-th simulation finished, 2.769281 sec.
# 467-th simulation finished, 2.872507 sec.
# 468-th simulation finished, 2.851381 sec.
# 469-th simulation finished, 3.023899 sec.
# 470-th simulation finished, 2.894967 sec.
# 471-th simulation finished, 2.845367 sec.
# 472-th simulation finished, 2.915429 sec.
# 473-th simulation finished, 3.000942 sec.
# 474-th simulation finished, 2.763115 sec.
# 475-th simulation finished, 2.908086 sec.
# 476-th simulation finished, 2.831669 sec.
# 477-th simulation finished, 2.779203 sec.
# 478-th simulation finished, 2.924577 sec.
# 479-th simulation finished, 3.002783 sec.
# 480-th simulation finished, 2.848972 sec.
# 481-th simulation finished, 2.855952 sec.
# 482-th simulation finished, 2.917151 sec.
# 483-th simulation finished, 3.063617 sec.
# 484-th simulation finished, 2.813563 sec.
# 485-th simulation finished, 2.825147 sec.
# 486-th simulation finished, 2.729765 sec.
# 487-th simulation finished, 3.115520 sec.
# 488-th simulation finished, 2.893850 sec.
# 489-th simulation finished, 2.888573 sec.
# 490-th simulation finished, 2.875995 sec.
# 491-th simulation finished, 2.943514 sec.
# 492-th simulation finished, 3.175316 sec.
# 493-th simulation finished, 2.809054 sec.
# 494-th simulation finished, 3.016846 sec.
# 495-th simulation finished, 2.877633 sec.
# 496-th simulation finished, 3.032693 sec.
# 497-th simulation finished, 2.883513 sec.
# 498-th simulation finished, 2.874551 sec.
# 499-th simulation finished, 2.893819 sec.
# 500-th simulation finished, 2.898346 sec.
# 501-th simulation finished, 3.069076 sec.
# 502-th simulation finished, 2.867274 sec.
# 503-th simulation finished, 2.830966 sec.
# 504-th simulation finished, 2.806978 sec.
# 505-th simulation finished, 2.808402 sec.
# 506-th simulation finished, 2.804705 sec.
# 507-th simulation finished, 2.904309 sec.
# 508-th simulation finished, 2.933895 sec.
# 509-th simulation finished, 3.157691 sec.
# 510-th simulation finished, 2.612432 sec.
# 511-th simulation finished, 2.835764 sec.
# 512-th simulation finished, 2.764078 sec.
# 513-th simulation finished, 2.889558 sec.
# 514-th simulation finished, 2.843031 sec.
# 515-th simulation finished, 2.769167 sec.
# 516-th simulation finished, 2.788275 sec.
# 517-th simulation finished, 2.937611 sec.
# 518-th simulation finished, 2.968494 sec.
# 519-th simulation finished, 2.784352 sec.
# 520-th simulation finished, 2.844774 sec.
# 521-th simulation finished, 2.866431 sec.
# 522-th simulation finished, 2.888816 sec.
# 523-th simulation finished, 3.113745 sec.
# 524-th simulation finished, 2.711863 sec.
# 525-th simulation finished, 2.870378 sec.
# 526-th simulation finished, 2.797884 sec.
# 527-th simulation finished, 2.904956 sec.
# 528-th simulation finished, 2.764110 sec.
# 529-th simulation finished, 3.106075 sec.
# 530-th simulation finished, 2.731537 sec.
# 531-th simulation finished, 3.058137 sec.
# 532-th simulation finished, 2.809702 sec.
# 533-th simulation finished, 3.008659 sec.
# 534-th simulation finished, 3.161251 sec.
# 535-th simulation finished, 3.024860 sec.
# 536-th simulation finished, 2.910135 sec.
# 537-th simulation finished, 2.971955 sec.
# 538-th simulation finished, 3.077507 sec.
# 539-th simulation finished, 2.947725 sec.
# 540-th simulation finished, 2.892329 sec.
# 541-th simulation finished, 2.943030 sec.
# 542-th simulation finished, 2.844722 sec.
# 543-th simulation finished, 2.906815 sec.
# 544-th simulation finished, 2.642469 sec.
# 545-th simulation finished, 2.974582 sec.
# 546-th simulation finished, 2.959480 sec.
# 547-th simulation finished, 3.119547 sec.
# 548-th simulation finished, 2.714038 sec.
# 549-th simulation finished, 3.003584 sec.
# 550-th simulation finished, 2.705961 sec.
# 551-th simulation finished, 3.294680 sec.
# 552-th simulation finished, 2.896139 sec.
# 553-th simulation finished, 2.914251 sec.
# 554-th simulation finished, 3.004649 sec.
# 555-th simulation finished, 3.023769 sec.
# 556-th simulation finished, 3.010821 sec.
# 557-th simulation finished, 3.101527 sec.
# 558-th simulation finished, 2.959614 sec.
# 559-th simulation finished, 3.095032 sec.
# 560-th simulation finished, 2.889882 sec.
# 561-th simulation finished, 3.253905 sec.
# 562-th simulation finished, 2.921018 sec.
# 563-th simulation finished, 3.152283 sec.
# 564-th simulation finished, 2.884304 sec.
# 565-th simulation finished, 3.212229 sec.
# 566-th simulation finished, 2.978198 sec.
# 567-th simulation finished, 2.819831 sec.
# 568-th simulation finished, 2.730180 sec.
# 569-th simulation finished, 3.080855 sec.
# 570-th simulation finished, 3.183748 sec.
# 571-th simulation finished, 2.799991 sec.
# 572-th simulation finished, 3.193848 sec.
# 573-th simulation finished, 2.941492 sec.
# 574-th simulation finished, 2.854873 sec.
# 575-th simulation finished, 3.024961 sec.
# 576-th simulation finished, 3.189836 sec.
# 577-th simulation finished, 3.209195 sec.
# 578-th simulation finished, 2.988431 sec.
# 579-th simulation finished, 2.871857 sec.
# 580-th simulation finished, 2.909884 sec.
# 581-th simulation finished, 2.925679 sec.
# 582-th simulation finished, 3.061314 sec.
# 583-th simulation finished, 3.079497 sec.
# 584-th simulation finished, 3.042445 sec.
# 585-th simulation finished, 2.833249 sec.
# 586-th simulation finished, 3.310419 sec.
# 587-th simulation finished, 2.940751 sec.
# 588-th simulation finished, 2.866114 sec.
# 589-th simulation finished, 2.875997 sec.
# 590-th simulation finished, 3.272095 sec.
# 591-th simulation finished, 2.710801 sec.
# 592-th simulation finished, 3.083180 sec.
# 593-th simulation finished, 2.855967 sec.
# 594-th simulation finished, 2.822954 sec.
# 595-th simulation finished, 2.858805 sec.
# 596-th simulation finished, 2.821933 sec.
# 597-th simulation finished, 2.843186 sec.
# 598-th simulation finished, 2.843595 sec.
# 599-th simulation finished, 2.686968 sec.
# 600-th simulation finished, 2.792967 sec.
# 601-th simulation finished, 2.793642 sec.
# 602-th simulation finished, 3.183530 sec.
# 603-th simulation finished, 3.159724 sec.
# 604-th simulation finished, 2.868038 sec.
# 605-th simulation finished, 2.839134 sec.
# 606-th simulation finished, 2.846972 sec.
# 607-th simulation finished, 2.889082 sec.
# 608-th simulation finished, 2.824480 sec.
# 609-th simulation finished, 3.049194 sec.
# 610-th simulation finished, 2.947150 sec.
# 611-th simulation finished, 2.808269 sec.
# 612-th simulation finished, 2.817915 sec.
# 613-th simulation finished, 2.759515 sec.
# 614-th simulation finished, 2.815433 sec.
# 615-th simulation finished, 2.886025 sec.
# 616-th simulation finished, 2.831732 sec.
# 617-th simulation finished, 2.929143 sec.
# 618-th simulation finished, 2.867880 sec.
# 619-th simulation finished, 2.988089 sec.
# 620-th simulation finished, 2.854542 sec.
# 621-th simulation finished, 2.817968 sec.
# 622-th simulation finished, 2.910509 sec.
# 623-th simulation finished, 2.911545 sec.
# 624-th simulation finished, 2.927912 sec.
# 625-th simulation finished, 2.893168 sec.
# 626-th simulation finished, 3.033943 sec.
# 627-th simulation finished, 2.892018 sec.
# 628-th simulation finished, 2.927475 sec.
# 629-th simulation finished, 2.922615 sec.
# 630-th simulation finished, 2.826518 sec.
# 631-th simulation finished, 2.840270 sec.
# 632-th simulation finished, 3.080894 sec.
# 633-th simulation finished, 3.417930 sec.
# 634-th simulation finished, 3.264666 sec.
# 635-th simulation finished, 2.840246 sec.
# 636-th simulation finished, 2.821769 sec.
# 637-th simulation finished, 2.894380 sec.
# 638-th simulation finished, 2.959430 sec.
# 639-th simulation finished, 2.901717 sec.
# 640-th simulation finished, 2.587701 sec.
# 641-th simulation finished, 3.254117 sec.
# 642-th simulation finished, 2.967702 sec.
# 643-th simulation finished, 2.854054 sec.
# 644-th simulation finished, 2.862981 sec.
# 645-th simulation finished, 2.855745 sec.
# 646-th simulation finished, 2.847649 sec.
# 647-th simulation finished, 2.974766 sec.
# 648-th simulation finished, 2.881180 sec.
# 649-th simulation finished, 2.882024 sec.
# 650-th simulation finished, 2.904133 sec.
# 651-th simulation finished, 2.821406 sec.
# 652-th simulation finished, 2.922259 sec.
# 653-th simulation finished, 2.967116 sec.
# 654-th simulation finished, 2.860534 sec.
# 655-th simulation finished, 2.789360 sec.
# 656-th simulation finished, 2.860750 sec.
# 657-th simulation finished, 2.903034 sec.
# 658-th simulation finished, 2.936764 sec.
# 659-th simulation finished, 2.954442 sec.
# 660-th simulation finished, 2.882894 sec.
# 661-th simulation finished, 2.871796 sec.
# 662-th simulation finished, 2.860462 sec.
# 663-th simulation finished, 2.921492 sec.
# 664-th simulation finished, 2.871105 sec.
# 665-th simulation finished, 2.929142 sec.
# 666-th simulation finished, 2.960018 sec.
# 667-th simulation finished, 2.960966 sec.
# 668-th simulation finished, 3.242991 sec.
# 669-th simulation finished, 2.866372 sec.
# 670-th simulation finished, 3.009024 sec.
# 671-th simulation finished, 2.849503 sec.
# 672-th simulation finished, 3.037658 sec.
# 673-th simulation finished, 3.193315 sec.
# 674-th simulation finished, 2.874006 sec.
# 675-th simulation finished, 2.888087 sec.
# 676-th simulation finished, 3.001392 sec.
# 677-th simulation finished, 2.801645 sec.
# 678-th simulation finished, 2.986706 sec.
# 679-th simulation finished, 2.940985 sec.
# 680-th simulation finished, 2.954817 sec.
# 681-th simulation finished, 2.870273 sec.
# 682-th simulation finished, 3.111142 sec.
# 683-th simulation finished, 2.837156 sec.
# 684-th simulation finished, 3.081867 sec.
# 685-th simulation finished, 3.043091 sec.
# 686-th simulation finished, 2.905272 sec.
# 687-th simulation finished, 3.040324 sec.
# 688-th simulation finished, 3.001024 sec.
# 689-th simulation finished, 3.226772 sec.
# 690-th simulation finished, 2.885323 sec.
# 691-th simulation finished, 2.830556 sec.
# 692-th simulation finished, 2.980065 sec.
# 693-th simulation finished, 2.861968 sec.
# 694-th simulation finished, 2.832057 sec.
# 695-th simulation finished, 2.889247 sec.
# 696-th simulation finished, 2.854437 sec.
# 697-th simulation finished, 3.058743 sec.
# 698-th simulation finished, 2.882627 sec.
# 699-th simulation finished, 2.848018 sec.
# 700-th simulation finished, 2.862200 sec.
# 701-th simulation finished, 2.842572 sec.
# 702-th simulation finished, 2.866060 sec.
# 703-th simulation finished, 2.931613 sec.
# 704-th simulation finished, 2.863290 sec.
# 705-th simulation finished, 3.129505 sec.
# 706-th simulation finished, 2.904115 sec.
# 707-th simulation finished, 2.832799 sec.
# 708-th simulation finished, 2.999355 sec.
# 709-th simulation finished, 2.823965 sec.
# 710-th simulation finished, 2.893440 sec.
# 711-th simulation finished, 2.857912 sec.
# 712-th simulation finished, 2.937110 sec.
# 713-th simulation finished, 2.867957 sec.
# 714-th simulation finished, 2.780619 sec.
# 715-th simulation finished, 3.257556 sec.
# 716-th simulation finished, 2.824986 sec.
# 717-th simulation finished, 2.966187 sec.
# 718-th simulation finished, 2.787640 sec.
# 719-th simulation finished, 3.029503 sec.
# 720-th simulation finished, 2.821252 sec.
# 721-th simulation finished, 2.826133 sec.
# 722-th simulation finished, 3.051998 sec.
# 723-th simulation finished, 2.797388 sec.
# 724-th simulation finished, 2.906905 sec.
# 725-th simulation finished, 2.874965 sec.
# 726-th simulation finished, 2.873389 sec.
# 727-th simulation finished, 2.840022 sec.
# 728-th simulation finished, 2.873798 sec.
# 729-th simulation finished, 2.946158 sec.
# 730-th simulation finished, 2.934341 sec.
# 731-th simulation finished, 2.832891 sec.
# 732-th simulation finished, 2.921081 sec.
# 733-th simulation finished, 2.775109 sec.
# 734-th simulation finished, 3.088406 sec.
# 735-th simulation finished, 2.973106 sec.
# 736-th simulation finished, 2.856784 sec.
# 737-th simulation finished, 2.797782 sec.
# 738-th simulation finished, 2.853749 sec.
# 739-th simulation finished, 2.922685 sec.
# 740-th simulation finished, 2.793881 sec.
# 741-th simulation finished, 2.699534 sec.
# 742-th simulation finished, 2.911671 sec.
# 743-th simulation finished, 2.861594 sec.
# 744-th simulation finished, 2.915635 sec.
# 745-th simulation finished, 3.003478 sec.
# 746-th simulation finished, 2.892960 sec.
# 747-th simulation finished, 2.885651 sec.
# 748-th simulation finished, 2.860450 sec.
# 749-th simulation finished, 3.172029 sec.
# 750-th simulation finished, 2.805789 sec.
# 751-th simulation finished, 2.931967 sec.
# 752-th simulation finished, 3.021958 sec.
# 753-th simulation finished, 2.943563 sec.
# 754-th simulation finished, 2.708579 sec.
# 755-th simulation finished, 2.907921 sec.
# 756-th simulation finished, 3.101504 sec.
# 757-th simulation finished, 2.923610 sec.
# 758-th simulation finished, 2.988289 sec.
# 759-th simulation finished, 3.004888 sec.
# 760-th simulation finished, 2.975114 sec.
# 761-th simulation finished, 2.985290 sec.
# 762-th simulation finished, 3.103661 sec.
# 763-th simulation finished, 2.942713 sec.
# 764-th simulation finished, 2.954512 sec.
# 765-th simulation finished, 2.835669 sec.
# 766-th simulation finished, 3.235713 sec.
# 767-th simulation finished, 3.255693 sec.
# 768-th simulation finished, 2.919723 sec.
# 769-th simulation finished, 3.070615 sec.
# 770-th simulation finished, 2.954145 sec.
# 771-th simulation finished, 3.018934 sec.
# 772-th simulation finished, 2.926428 sec.
# 773-th simulation finished, 3.130147 sec.
# 774-th simulation finished, 2.923254 sec.
# 775-th simulation finished, 2.916204 sec.
# 776-th simulation finished, 2.815234 sec.
# 777-th simulation finished, 2.969004 sec.
# 778-th simulation finished, 3.099942 sec.
# 779-th simulation finished, 3.093877 sec.
# 780-th simulation finished, 2.962638 sec.
# 781-th simulation finished, 2.920871 sec.
# 782-th simulation finished, 2.917471 sec.
# 783-th simulation finished, 2.925652 sec.
# 784-th simulation finished, 3.264683 sec.
# 785-th simulation finished, 2.921694 sec.
# 786-th simulation finished, 2.702249 sec.
# 787-th simulation finished, 2.817237 sec.
# 788-th simulation finished, 2.874824 sec.
# 789-th simulation finished, 2.878592 sec.
# 790-th simulation finished, 2.877018 sec.
# 791-th simulation finished, 2.913705 sec.
# 792-th simulation finished, 3.153260 sec.
# 793-th simulation finished, 3.236040 sec.
# 794-th simulation finished, 2.855110 sec.
# 795-th simulation finished, 2.881441 sec.
# 796-th simulation finished, 2.923213 sec.
# 797-th simulation finished, 2.775054 sec.
# 798-th simulation finished, 2.890112 sec.
# 799-th simulation finished, 3.026379 sec.
# 800-th simulation finished, 2.849170 sec.
# 801-th simulation finished, 2.825110 sec.
# 802-th simulation finished, 3.134195 sec.
# 803-th simulation finished, 2.807428 sec.
# 804-th simulation finished, 2.856062 sec.
# 805-th simulation finished, 2.837643 sec.
# 806-th simulation finished, 2.898462 sec.
# 807-th simulation finished, 2.846686 sec.
# 808-th simulation finished, 2.812694 sec.
# 809-th simulation finished, 2.852867 sec.
# 810-th simulation finished, 3.023716 sec.
# 811-th simulation finished, 2.804647 sec.
# 812-th simulation finished, 3.182024 sec.
# 813-th simulation finished, 2.955086 sec.
# 814-th simulation finished, 2.973790 sec.
# 815-th simulation finished, 3.160755 sec.
# 816-th simulation finished, 2.753364 sec.
# 817-th simulation finished, 3.081175 sec.
# 818-th simulation finished, 2.909774 sec.
# 819-th simulation finished, 2.865209 sec.
# 820-th simulation finished, 2.999528 sec.
# 821-th simulation finished, 2.804159 sec.
# 822-th simulation finished, 2.938105 sec.
# 823-th simulation finished, 2.961509 sec.
# 824-th simulation finished, 2.827907 sec.
# 825-th simulation finished, 2.855475 sec.
# 826-th simulation finished, 2.832634 sec.
# 827-th simulation finished, 2.821781 sec.
# 828-th simulation finished, 2.856006 sec.
# 829-th simulation finished, 2.850613 sec.
# 830-th simulation finished, 2.782515 sec.
# 831-th simulation finished, 2.688234 sec.
# 832-th simulation finished, 2.803395 sec.
# 833-th simulation finished, 3.187655 sec.
# 834-th simulation finished, 2.779401 sec.
# 835-th simulation finished, 2.727515 sec.
# 836-th simulation finished, 2.820907 sec.
# 837-th simulation finished, 3.182413 sec.
# 838-th simulation finished, 2.866209 sec.
# 839-th simulation finished, 2.870727 sec.
# 840-th simulation finished, 2.888412 sec.
# 841-th simulation finished, 2.872895 sec.
# 842-th simulation finished, 2.721909 sec.
# 843-th simulation finished, 2.881163 sec.
# 844-th simulation finished, 3.169186 sec.
# 845-th simulation finished, 2.839762 sec.
# 846-th simulation finished, 2.854373 sec.
# 847-th simulation finished, 2.971050 sec.
# 848-th simulation finished, 2.945182 sec.
# 849-th simulation finished, 2.789857 sec.
# 850-th simulation finished, 2.813533 sec.
# 851-th simulation finished, 2.809797 sec.
# 852-th simulation finished, 2.936737 sec.
# 853-th simulation finished, 2.979690 sec.
# 854-th simulation finished, 2.883094 sec.
# 855-th simulation finished, 2.851484 sec.
# 856-th simulation finished, 2.887301 sec.
# 857-th simulation finished, 3.004073 sec.
# 858-th simulation finished, 2.855345 sec.
# 859-th simulation finished, 2.884459 sec.
# 860-th simulation finished, 2.913638 sec.
# 861-th simulation finished, 2.885796 sec.
# 862-th simulation finished, 2.770223 sec.
# 863-th simulation finished, 2.861677 sec.
# 864-th simulation finished, 2.841850 sec.
# 865-th simulation finished, 2.783441 sec.
# 866-th simulation finished, 2.889022 sec.
# 867-th simulation finished, 2.964012 sec.
# 868-th simulation finished, 2.843187 sec.
# 869-th simulation finished, 2.805293 sec.
# 870-th simulation finished, 2.952614 sec.
# 871-th simulation finished, 2.831723 sec.
# 872-th simulation finished, 2.782550 sec.
# 873-th simulation finished, 3.052782 sec.
# 874-th simulation finished, 2.758437 sec.
# 875-th simulation finished, 2.929660 sec.
# 876-th simulation finished, 2.965470 sec.
# 877-th simulation finished, 2.901852 sec.
# 878-th simulation finished, 2.877916 sec.
# 879-th simulation finished, 2.853897 sec.
# 880-th simulation finished, 3.101121 sec.
# 881-th simulation finished, 2.818402 sec.
# 882-th simulation finished, 2.995166 sec.
# 883-th simulation finished, 2.843451 sec.
# 884-th simulation finished, 2.970199 sec.
# 885-th simulation finished, 2.858517 sec.
# 886-th simulation finished, 2.809555 sec.
# 887-th simulation finished, 2.958561 sec.
# 888-th simulation finished, 2.804774 sec.
# 889-th simulation finished, 2.820463 sec.
# 890-th simulation finished, 3.145927 sec.
# 891-th simulation finished, 2.824407 sec.
# 892-th simulation finished, 2.817257 sec.
# 893-th simulation finished, 2.810042 sec.
# 894-th simulation finished, 3.193008 sec.
# 895-th simulation finished, 2.938826 sec.
# 896-th simulation finished, 2.945379 sec.
# 897-th simulation finished, 2.775100 sec.
# 898-th simulation finished, 2.872464 sec.
# 899-th simulation finished, 3.250773 sec.
# 900-th simulation finished, 2.971898 sec.
# 901-th simulation finished, 2.797865 sec.
# 902-th simulation finished, 2.962633 sec.
# 903-th simulation finished, 2.932938 sec.
# 904-th simulation finished, 2.851551 sec.
# 905-th simulation finished, 2.786268 sec.
# 906-th simulation finished, 3.184559 sec.
# 907-th simulation finished, 3.256633 sec.
# 908-th simulation finished, 2.828120 sec.
# 909-th simulation finished, 2.925951 sec.
# 910-th simulation finished, 2.899920 sec.
# 911-th simulation finished, 2.843538 sec.
# 912-th simulation finished, 2.966212 sec.
# 913-th simulation finished, 2.912903 sec.
# 914-th simulation finished, 2.802698 sec.
# 915-th simulation finished, 2.980659 sec.
# 916-th simulation finished, 2.862101 sec.
# 917-th simulation finished, 3.076032 sec.
# 918-th simulation finished, 3.158509 sec.
# 919-th simulation finished, 2.821074 sec.
# 920-th simulation finished, 3.117744 sec.
# 921-th simulation finished, 3.152401 sec.
# 922-th simulation finished, 3.039611 sec.
# 923-th simulation finished, 2.754364 sec.
# 924-th simulation finished, 2.838796 sec.
# 925-th simulation finished, 2.947342 sec.
# 926-th simulation finished, 2.795674 sec.
# 927-th simulation finished, 2.797907 sec.
# 928-th simulation finished, 3.059692 sec.
# 929-th simulation finished, 2.850096 sec.
# 930-th simulation finished, 2.808354 sec.
# 931-th simulation finished, 2.904142 sec.
# 932-th simulation finished, 2.934319 sec.
# 933-th simulation finished, 3.063692 sec.
# 934-th simulation finished, 2.905135 sec.
# 935-th simulation finished, 2.900941 sec.
# 936-th simulation finished, 2.904828 sec.
# 937-th simulation finished, 2.895362 sec.
# 938-th simulation finished, 2.693084 sec.
# 939-th simulation finished, 2.850554 sec.
# 940-th simulation finished, 3.015219 sec.
# 941-th simulation finished, 3.097368 sec.
# 942-th simulation finished, 3.203796 sec.
# 943-th simulation finished, 2.967735 sec.
# 944-th simulation finished, 2.912180 sec.
# 945-th simulation finished, 3.064241 sec.
# 946-th simulation finished, 3.419464 sec.
# 947-th simulation finished, 2.924979 sec.
# 948-th simulation finished, 3.032112 sec.
# 949-th simulation finished, 2.923528 sec.
# 950-th simulation finished, 2.903045 sec.
# 951-th simulation finished, 2.823232 sec.
# 952-th simulation finished, 2.973326 sec.
# 953-th simulation finished, 2.909949 sec.
# 954-th simulation finished, 2.894470 sec.
# 955-th simulation finished, 2.985432 sec.
# 956-th simulation finished, 2.825367 sec.
# 957-th simulation finished, 2.926170 sec.
# 958-th simulation finished, 2.898439 sec.
# 959-th simulation finished, 2.881328 sec.
# 960-th simulation finished, 2.833702 sec.
# 961-th simulation finished, 2.901367 sec.
# 962-th simulation finished, 2.949586 sec.
# 963-th simulation finished, 2.816678 sec.
# 964-th simulation finished, 3.017703 sec.
# 965-th simulation finished, 2.709758 sec.
# 966-th simulation finished, 2.842838 sec.
# 967-th simulation finished, 2.994235 sec.
# 968-th simulation finished, 2.825513 sec.
# 969-th simulation finished, 2.763752 sec.
# 970-th simulation finished, 2.841384 sec.
# 971-th simulation finished, 3.135006 sec.
# 972-th simulation finished, 2.858896 sec.
# 973-th simulation finished, 2.852499 sec.
# 974-th simulation finished, 2.784632 sec.
# 975-th simulation finished, 2.885745 sec.
# 976-th simulation finished, 3.234010 sec.
# 977-th simulation finished, 2.854056 sec.
# 978-th simulation finished, 2.877824 sec.
# 979-th simulation finished, 2.945398 sec.
# 980-th simulation finished, 2.784428 sec.
# 981-th simulation finished, 2.806417 sec.
# 982-th simulation finished, 2.988203 sec.
# 983-th simulation finished, 2.925489 sec.
# 984-th simulation finished, 2.916147 sec.
# 985-th simulation finished, 2.930723 sec.
# 986-th simulation finished, 2.723893 sec.
# 987-th simulation finished, 2.897486 sec.
# 988-th simulation finished, 2.893320 sec.
# 989-th simulation finished, 3.064416 sec.
# 990-th simulation finished, 2.840154 sec.
# 991-th simulation finished, 2.859116 sec.
# 992-th simulation finished, 3.097173 sec.
# 993-th simulation finished, 2.952032 sec.
# 994-th simulation finished, 3.170086 sec.
# 995-th simulation finished, 3.151542 sec.
# 996-th simulation finished, 2.940692 sec.
# 997-th simulation finished, 2.839023 sec.
# 998-th simulation finished, 2.867546 sec.
# 999-th simulation finished, 3.256189 sec.
# 1000-th simulation finished, 2.854866 sec.

# %%
np.savez('coverage_freqepid_nbinom_randinf_4.npz',
         nsim = nsim, msim = msim, bsim = bsim)

# %% [markdown]
# # 4. Wald's Confidence Region Coverage Test

# %%
# locals.update(np.load('coverage_freqepid_nbinom_randinf_1.npz'))

# %%
Ihs_dth = np.zeros([num_sim, 2+d, 2+d])
Ts_dth = np.zeros(num_sim)
ps_dth = np.zeros(num_sim)

# %%
Ihs_hac = np.zeros([num_sim, 2+d, 2+d])
Ts_hac = np.zeros(num_sim)
ps_hac = np.zeros(num_sim)

# %%
Ihs_sdw = np.zeros([num_sim, 2+d, 2+d])
Ts_sdw = np.zeros(num_sim)
ps_sdw = np.zeros(num_sim)

# %%
for iter_sim in np.arange(num_sim):
    start_sim = time.time()
    
    nmle = nsim[iter_sim]
    mmle = msim[iter_sim]
    bmle = bsim[iter_sim,:]
    
    data_i = data[data['sim']==iter_sim]
    A = np.stack([np.full(T, 1), data_i["intervention"].to_numpy()], -1)
    Y = data_i["death"].to_numpy()
    
    Ihat_dth, Ihat_hac, Ihat_sdw =\
    model.inference(A, Y, nmle, mmle, bmle)
    
    # Fisher information matrix
    Ihs_dth[iter_sim] = Ihat_dth
    Ts_dth[iter_sim] = (bmle[1]-beta[1])/np.sqrt(la.pinv(Ihs_dth[iter_sim])[-1,-1])
    ps_dth[iter_sim] = 2*(1-stats.norm.cdf(np.abs(Ts_dth[iter_sim])))
    
    # HAC estimator
    Ihs_hac[iter_sim] = Ihat_hac
    Ts_hac[iter_sim] = (bmle[1]-beta[1])/np.sqrt(la.pinv(Ihs_hac[iter_sim])[-1,-1])
    ps_hac[iter_sim] = 2*(1-stats.norm.cdf(np.abs(Ts_hac[iter_sim])))
    
    # Sandwich estimator
    Ihs_sdw[iter_sim] = Ihat_sdw
    Ts_sdw[iter_sim] = (bmle[1]-beta[1])/np.sqrt(la.pinv(Ihs_sdw[iter_sim])[-1,-1])
    ps_sdw[iter_sim] = 2*(1-stats.norm.cdf(np.abs(Ts_sdw[iter_sim])))
    
    sys.__stdout__.write("%d-th simulation finished, %f sec.\n"
                         %(iter_sim+1, time.time()-start_sim))
    sys.__stdout__.flush()
# Out:
# 1-th simulation finished, 0.002522 sec.
# 2-th simulation finished, 0.001588 sec.
# 3-th simulation finished, 0.001330 sec.
# 4-th simulation finished, 0.001245 sec.
# 5-th simulation finished, 0.001210 sec.
# 6-th simulation finished, 0.001196 sec.
# 7-th simulation finished, 0.001197 sec.
# 8-th simulation finished, 0.001219 sec.
# 9-th simulation finished, 0.001196 sec.
# 10-th simulation finished, 0.001188 sec.
# 11-th simulation finished, 0.001186 sec.
# 12-th simulation finished, 0.001189 sec.
# 13-th simulation finished, 0.001183 sec.
# 14-th simulation finished, 0.001189 sec.
# 15-th simulation finished, 0.001184 sec.
# 16-th simulation finished, 0.001189 sec.
# 17-th simulation finished, 0.001327 sec.
# 18-th simulation finished, 0.001430 sec.
# 19-th simulation finished, 0.001232 sec.
# 20-th simulation finished, 0.001194 sec.
# 21-th simulation finished, 0.001190 sec.
# 22-th simulation finished, 0.001232 sec.
# 23-th simulation finished, 0.001263 sec.
# 24-th simulation finished, 0.001200 sec.
# 25-th simulation finished, 0.001192 sec.
# 26-th simulation finished, 0.001169 sec.
# 27-th simulation finished, 0.001168 sec.
# 28-th simulation finished, 0.001169 sec.
# 29-th simulation finished, 0.001207 sec.
# 30-th simulation finished, 0.001199 sec.
# 31-th simulation finished, 0.001169 sec.
# 32-th simulation finished, 0.001173 sec.
# 33-th simulation finished, 0.001172 sec.
# 34-th simulation finished, 0.001203 sec.
# 35-th simulation finished, 0.001252 sec.
# 36-th simulation finished, 0.001193 sec.
# 37-th simulation finished, 0.001208 sec.
# 38-th simulation finished, 0.001187 sec.
# 39-th simulation finished, 0.001205 sec.
# 40-th simulation finished, 0.001182 sec.
# 41-th simulation finished, 0.001169 sec.
# 42-th simulation finished, 0.001167 sec.
# 43-th simulation finished, 0.001199 sec.
# 44-th simulation finished, 0.001192 sec.
# 45-th simulation finished, 0.001201 sec.
# 46-th simulation finished, 0.001175 sec.
# 47-th simulation finished, 0.001198 sec.
# 48-th simulation finished, 0.001178 sec.
# 49-th simulation finished, 0.001212 sec.
# 50-th simulation finished, 0.001161 sec.
# 51-th simulation finished, 0.001194 sec.
# 52-th simulation finished, 0.001166 sec.
# 53-th simulation finished, 0.001179 sec.
# 54-th simulation finished, 0.001171 sec.
# 55-th simulation finished, 0.001235 sec.
# 56-th simulation finished, 0.001167 sec.
# 57-th simulation finished, 0.001187 sec.
# 58-th simulation finished, 0.001162 sec.
# 59-th simulation finished, 0.001198 sec.
# 60-th simulation finished, 0.001170 sec.
# 61-th simulation finished, 0.001184 sec.
# 62-th simulation finished, 0.001160 sec.
# 63-th simulation finished, 0.001194 sec.
# 64-th simulation finished, 0.001159 sec.
# 65-th simulation finished, 0.001190 sec.
# 66-th simulation finished, 0.001163 sec.
# 67-th simulation finished, 0.001249 sec.
# 68-th simulation finished, 0.001164 sec.
# 69-th simulation finished, 0.001190 sec.
# 70-th simulation finished, 0.001167 sec.
# 71-th simulation finished, 0.001175 sec.
# 72-th simulation finished, 0.001158 sec.
# 73-th simulation finished, 0.001205 sec.
# 74-th simulation finished, 0.001162 sec.
# 75-th simulation finished, 0.001189 sec.
# 76-th simulation finished, 0.001164 sec.
# 77-th simulation finished, 0.001182 sec.
# 78-th simulation finished, 0.001167 sec.
# 79-th simulation finished, 0.001194 sec.
# 80-th simulation finished, 0.001181 sec.
# 81-th simulation finished, 0.001177 sec.
# 82-th simulation finished, 0.001156 sec.
# 83-th simulation finished, 0.001189 sec.
# 84-th simulation finished, 0.001173 sec.
# 85-th simulation finished, 0.001182 sec.
# 86-th simulation finished, 0.001161 sec.
# 87-th simulation finished, 0.001181 sec.
# 88-th simulation finished, 0.001166 sec.
# 89-th simulation finished, 0.001186 sec.
# 90-th simulation finished, 0.001178 sec.
# 91-th simulation finished, 0.001180 sec.
# 92-th simulation finished, 0.001178 sec.
# 93-th simulation finished, 0.001185 sec.
# 94-th simulation finished, 0.001162 sec.
# 95-th simulation finished, 0.001177 sec.
# 96-th simulation finished, 0.001169 sec.
# 97-th simulation finished, 0.001199 sec.
# 98-th simulation finished, 0.001167 sec.
# 99-th simulation finished, 0.001174 sec.
# 100-th simulation finished, 0.001166 sec.
# 101-th simulation finished, 0.001180 sec.
# 102-th simulation finished, 0.001163 sec.
# 103-th simulation finished, 0.001190 sec.
# 104-th simulation finished, 0.001182 sec.
# 105-th simulation finished, 0.001357 sec.
# 106-th simulation finished, 0.001204 sec.
# 107-th simulation finished, 0.001251 sec.
# 108-th simulation finished, 0.001200 sec.
# 109-th simulation finished, 0.001214 sec.
# 110-th simulation finished, 0.001170 sec.
# 111-th simulation finished, 0.001177 sec.
# 112-th simulation finished, 0.001158 sec.
# 113-th simulation finished, 0.001181 sec.
# 114-th simulation finished, 0.001173 sec.
# 115-th simulation finished, 0.001186 sec.
# 116-th simulation finished, 0.001156 sec.
# 117-th simulation finished, 0.001191 sec.
# 118-th simulation finished, 0.001163 sec.
# 119-th simulation finished, 0.001187 sec.
# 120-th simulation finished, 0.001156 sec.
# 121-th simulation finished, 0.001181 sec.
# 122-th simulation finished, 0.001156 sec.
# 123-th simulation finished, 0.001174 sec.
# 124-th simulation finished, 0.001154 sec.
# 125-th simulation finished, 0.001174 sec.
# 126-th simulation finished, 0.001161 sec.
# 127-th simulation finished, 0.001188 sec.
# 128-th simulation finished, 0.001153 sec.
# 129-th simulation finished, 0.001176 sec.
# 130-th simulation finished, 0.001171 sec.
# 131-th simulation finished, 0.001213 sec.
# 132-th simulation finished, 0.001164 sec.
# 133-th simulation finished, 0.001204 sec.
# 134-th simulation finished, 0.001173 sec.
# 135-th simulation finished, 0.001202 sec.
# 136-th simulation finished, 0.001163 sec.
# 137-th simulation finished, 0.001209 sec.
# 138-th simulation finished, 0.001181 sec.
# 139-th simulation finished, 0.001202 sec.
# 140-th simulation finished, 0.001179 sec.
# 141-th simulation finished, 0.001214 sec.
# 142-th simulation finished, 0.001170 sec.
# 143-th simulation finished, 0.001190 sec.
# 144-th simulation finished, 0.001167 sec.
# 145-th simulation finished, 0.001215 sec.
# 146-th simulation finished, 0.001183 sec.
# 147-th simulation finished, 0.001209 sec.
# 148-th simulation finished, 0.001319 sec.
# 149-th simulation finished, 0.001302 sec.
# 150-th simulation finished, 0.001516 sec.
# 151-th simulation finished, 0.001364 sec.
# 152-th simulation finished, 0.001254 sec.
# 153-th simulation finished, 0.001191 sec.
# 154-th simulation finished, 0.001211 sec.
# 155-th simulation finished, 0.001173 sec.
# 156-th simulation finished, 0.001191 sec.
# 157-th simulation finished, 0.001166 sec.
# 158-th simulation finished, 0.001203 sec.
# 159-th simulation finished, 0.001166 sec.
# 160-th simulation finished, 0.001204 sec.
# 161-th simulation finished, 0.001211 sec.
# 162-th simulation finished, 0.001217 sec.
# 163-th simulation finished, 0.001172 sec.
# 164-th simulation finished, 0.001203 sec.
# 165-th simulation finished, 0.001163 sec.
# 166-th simulation finished, 0.001190 sec.
# 167-th simulation finished, 0.001158 sec.
# 168-th simulation finished, 0.001350 sec.
# 169-th simulation finished, 0.001388 sec.
# 170-th simulation finished, 0.001549 sec.
# 171-th simulation finished, 0.001351 sec.
# 172-th simulation finished, 0.001304 sec.
# 173-th simulation finished, 0.001229 sec.
# 174-th simulation finished, 0.001183 sec.
# 175-th simulation finished, 0.001186 sec.
# 176-th simulation finished, 0.001166 sec.
# 177-th simulation finished, 0.001172 sec.
# 178-th simulation finished, 0.001180 sec.
# 179-th simulation finished, 0.001174 sec.
# 180-th simulation finished, 0.001174 sec.
# 181-th simulation finished, 0.001169 sec.
# 182-th simulation finished, 0.001164 sec.
# 183-th simulation finished, 0.001295 sec.
# 184-th simulation finished, 0.001269 sec.
# 185-th simulation finished, 0.001225 sec.
# 186-th simulation finished, 0.001241 sec.
# 187-th simulation finished, 0.001177 sec.
# 188-th simulation finished, 0.001201 sec.
# 189-th simulation finished, 0.001233 sec.
# 190-th simulation finished, 0.001186 sec.
# 191-th simulation finished, 0.001177 sec.
# 192-th simulation finished, 0.001167 sec.
# 193-th simulation finished, 0.001169 sec.
# 194-th simulation finished, 0.001161 sec.
# 195-th simulation finished, 0.001170 sec.
# 196-th simulation finished, 0.001165 sec.
# 197-th simulation finished, 0.001178 sec.
# 198-th simulation finished, 0.001172 sec.
# 199-th simulation finished, 0.001172 sec.
# 200-th simulation finished, 0.001170 sec.
# 201-th simulation finished, 0.001157 sec.
# 202-th simulation finished, 0.001310 sec.
# 203-th simulation finished, 0.001268 sec.
# 204-th simulation finished, 0.001200 sec.
# 205-th simulation finished, 0.001200 sec.
# 206-th simulation finished, 0.001181 sec.
# 207-th simulation finished, 0.001164 sec.
# 208-th simulation finished, 0.001285 sec.
# 209-th simulation finished, 0.001214 sec.
# 210-th simulation finished, 0.001213 sec.
# 211-th simulation finished, 0.001178 sec.
# 212-th simulation finished, 0.001227 sec.
# 213-th simulation finished, 0.001179 sec.
# 214-th simulation finished, 0.001206 sec.
# 215-th simulation finished, 0.001193 sec.
# 216-th simulation finished, 0.001172 sec.
# 217-th simulation finished, 0.001195 sec.
# 218-th simulation finished, 0.001170 sec.
# 219-th simulation finished, 0.001208 sec.
# 220-th simulation finished, 0.001196 sec.
# 221-th simulation finished, 0.001185 sec.
# 222-th simulation finished, 0.001172 sec.
# 223-th simulation finished, 0.001196 sec.
# 224-th simulation finished, 0.001167 sec.
# 225-th simulation finished, 0.001198 sec.
# 226-th simulation finished, 0.001167 sec.
# 227-th simulation finished, 0.001202 sec.
# 228-th simulation finished, 0.001174 sec.
# 229-th simulation finished, 0.001191 sec.
# 230-th simulation finished, 0.001165 sec.
# 231-th simulation finished, 0.001186 sec.
# 232-th simulation finished, 0.001191 sec.
# 233-th simulation finished, 0.001193 sec.
# 234-th simulation finished, 0.001160 sec.
# 235-th simulation finished, 0.001191 sec.
# 236-th simulation finished, 0.001171 sec.
# 237-th simulation finished, 0.001160 sec.
# 238-th simulation finished, 0.001175 sec.
# 239-th simulation finished, 0.001195 sec.
# 240-th simulation finished, 0.001176 sec.
# 241-th simulation finished, 0.001196 sec.
# 242-th simulation finished, 0.001171 sec.
# 243-th simulation finished, 0.001195 sec.
# 244-th simulation finished, 0.001191 sec.
# 245-th simulation finished, 0.001197 sec.
# 246-th simulation finished, 0.001166 sec.
# 247-th simulation finished, 0.001188 sec.
# 248-th simulation finished, 0.001166 sec.
# 249-th simulation finished, 0.001182 sec.
# 250-th simulation finished, 0.001156 sec.
# 251-th simulation finished, 0.001184 sec.
# 252-th simulation finished, 0.001167 sec.
# 253-th simulation finished, 0.001204 sec.
# 254-th simulation finished, 0.001164 sec.
# 255-th simulation finished, 0.001188 sec.
# 256-th simulation finished, 0.001174 sec.
# 257-th simulation finished, 0.001186 sec.
# 258-th simulation finished, 0.001161 sec.
# 259-th simulation finished, 0.001184 sec.
# 260-th simulation finished, 0.001161 sec.
# 261-th simulation finished, 0.001179 sec.
# 262-th simulation finished, 0.001154 sec.
# 263-th simulation finished, 0.001191 sec.
# 264-th simulation finished, 0.001161 sec.
# 265-th simulation finished, 0.001159 sec.
# 266-th simulation finished, 0.001163 sec.
# 267-th simulation finished, 0.001159 sec.
# 268-th simulation finished, 0.001164 sec.
# 269-th simulation finished, 0.001160 sec.
# 270-th simulation finished, 0.001160 sec.
# 271-th simulation finished, 0.001164 sec.
# 272-th simulation finished, 0.001160 sec.
# 273-th simulation finished, 0.001153 sec.
# 274-th simulation finished, 0.001167 sec.
# 275-th simulation finished, 0.001160 sec.
# 276-th simulation finished, 0.001156 sec.
# 277-th simulation finished, 0.001174 sec.
# 278-th simulation finished, 0.001160 sec.
# 279-th simulation finished, 0.001175 sec.
# 280-th simulation finished, 0.001152 sec.
# 281-th simulation finished, 0.001155 sec.
# 282-th simulation finished, 0.001171 sec.
# 283-th simulation finished, 0.001164 sec.
# 284-th simulation finished, 0.001158 sec.
# 285-th simulation finished, 0.001153 sec.
# 286-th simulation finished, 0.001161 sec.
# 287-th simulation finished, 0.001161 sec.
# 288-th simulation finished, 0.001152 sec.
# 289-th simulation finished, 0.001154 sec.
# 290-th simulation finished, 0.001152 sec.
# 291-th simulation finished, 0.001150 sec.
# 292-th simulation finished, 0.001184 sec.
# 293-th simulation finished, 0.001158 sec.
# 294-th simulation finished, 0.001163 sec.
# 295-th simulation finished, 0.001159 sec.
# 296-th simulation finished, 0.001157 sec.
# 297-th simulation finished, 0.001150 sec.
# 298-th simulation finished, 0.001207 sec.
# 299-th simulation finished, 0.001211 sec.
# 300-th simulation finished, 0.001159 sec.
# 301-th simulation finished, 0.001163 sec.
# 302-th simulation finished, 0.001158 sec.
# 303-th simulation finished, 0.001153 sec.
# 304-th simulation finished, 0.001156 sec.
# 305-th simulation finished, 0.001152 sec.
# 306-th simulation finished, 0.001158 sec.
# 307-th simulation finished, 0.001153 sec.
# 308-th simulation finished, 0.001170 sec.
# 309-th simulation finished, 0.001149 sec.
# 310-th simulation finished, 0.001151 sec.
# 311-th simulation finished, 0.001169 sec.
# 312-th simulation finished, 0.001147 sec.
# 313-th simulation finished, 0.001159 sec.
# 314-th simulation finished, 0.001153 sec.
# 315-th simulation finished, 0.001161 sec.
# 316-th simulation finished, 0.001157 sec.
# 317-th simulation finished, 0.001152 sec.
# 318-th simulation finished, 0.001157 sec.
# 319-th simulation finished, 0.001157 sec.
# 320-th simulation finished, 0.001158 sec.
# 321-th simulation finished, 0.001577 sec.
# 322-th simulation finished, 0.001219 sec.
# 323-th simulation finished, 0.001173 sec.
# 324-th simulation finished, 0.001189 sec.
# 325-th simulation finished, 0.001175 sec.
# 326-th simulation finished, 0.001190 sec.
# 327-th simulation finished, 0.001160 sec.
# 328-th simulation finished, 0.001181 sec.
# 329-th simulation finished, 0.001172 sec.
# 330-th simulation finished, 0.001186 sec.
# 331-th simulation finished, 0.001162 sec.
# 332-th simulation finished, 0.001233 sec.
# 333-th simulation finished, 0.001118 sec.
# 334-th simulation finished, 0.001201 sec.
# 335-th simulation finished, 0.001150 sec.
# 336-th simulation finished, 0.001133 sec.
# 337-th simulation finished, 0.001155 sec.
# 338-th simulation finished, 0.001126 sec.
# 339-th simulation finished, 0.001146 sec.
# 340-th simulation finished, 0.001152 sec.
# 341-th simulation finished, 0.001422 sec.
# 342-th simulation finished, 0.001408 sec.
# 343-th simulation finished, 0.001173 sec.
# 344-th simulation finished, 0.001212 sec.
# 345-th simulation finished, 0.001165 sec.
# 346-th simulation finished, 0.001225 sec.
# 347-th simulation finished, 0.001215 sec.
# 348-th simulation finished, 0.001173 sec.
# 349-th simulation finished, 0.001170 sec.
# 350-th simulation finished, 0.001162 sec.
# 351-th simulation finished, 0.001159 sec.
# 352-th simulation finished, 0.001159 sec.
# 353-th simulation finished, 0.001154 sec.
# 354-th simulation finished, 0.001151 sec.
# 355-th simulation finished, 0.001153 sec.
# 356-th simulation finished, 0.001166 sec.
# 357-th simulation finished, 0.001152 sec.
# 358-th simulation finished, 0.001199 sec.
# 359-th simulation finished, 0.001161 sec.
# 360-th simulation finished, 0.001154 sec.
# 361-th simulation finished, 0.001175 sec.
# 362-th simulation finished, 0.001147 sec.
# 363-th simulation finished, 0.001159 sec.
# 364-th simulation finished, 0.001158 sec.
# 365-th simulation finished, 0.001174 sec.
# 366-th simulation finished, 0.001125 sec.
# 367-th simulation finished, 0.001110 sec.
# 368-th simulation finished, 0.001123 sec.
# 369-th simulation finished, 0.001108 sec.
# 370-th simulation finished, 0.001111 sec.
# 371-th simulation finished, 0.001110 sec.
# 372-th simulation finished, 0.001112 sec.
# 373-th simulation finished, 0.001112 sec.
# 374-th simulation finished, 0.001112 sec.
# 375-th simulation finished, 0.001113 sec.
# 376-th simulation finished, 0.001118 sec.
# 377-th simulation finished, 0.001130 sec.
# 378-th simulation finished, 0.001152 sec.
# 379-th simulation finished, 0.001153 sec.
# 380-th simulation finished, 0.001159 sec.
# 381-th simulation finished, 0.001164 sec.
# 382-th simulation finished, 0.001150 sec.
# 383-th simulation finished, 0.001158 sec.
# 384-th simulation finished, 0.001157 sec.
# 385-th simulation finished, 0.001154 sec.
# 386-th simulation finished, 0.001147 sec.
# 387-th simulation finished, 0.001142 sec.
# 388-th simulation finished, 0.001147 sec.
# 389-th simulation finished, 0.001109 sec.
# 390-th simulation finished, 0.001141 sec.
# 391-th simulation finished, 0.001144 sec.
# 392-th simulation finished, 0.001127 sec.
# 393-th simulation finished, 0.001141 sec.
# 394-th simulation finished, 0.001126 sec.
# 395-th simulation finished, 0.001142 sec.
# 396-th simulation finished, 0.001116 sec.
# 397-th simulation finished, 0.001140 sec.
# 398-th simulation finished, 0.001123 sec.
# 399-th simulation finished, 0.001139 sec.
# 400-th simulation finished, 0.001141 sec.
# 401-th simulation finished, 0.001163 sec.
# 402-th simulation finished, 0.001151 sec.
# 403-th simulation finished, 0.001169 sec.
# 404-th simulation finished, 0.001153 sec.
# 405-th simulation finished, 0.001151 sec.
# 406-th simulation finished, 0.001182 sec.
# 407-th simulation finished, 0.001157 sec.
# 408-th simulation finished, 0.001182 sec.
# 409-th simulation finished, 0.001158 sec.
# 410-th simulation finished, 0.001185 sec.
# 411-th simulation finished, 0.001153 sec.
# 412-th simulation finished, 0.001129 sec.
# 413-th simulation finished, 0.001126 sec.
# 414-th simulation finished, 0.001125 sec.
# 415-th simulation finished, 0.001134 sec.
# 416-th simulation finished, 0.001114 sec.
# 417-th simulation finished, 0.001113 sec.
# 418-th simulation finished, 0.001114 sec.
# 419-th simulation finished, 0.001118 sec.
# 420-th simulation finished, 0.001133 sec.
# 421-th simulation finished, 0.001146 sec.
# 422-th simulation finished, 0.001112 sec.
# 423-th simulation finished, 0.001152 sec.
# 424-th simulation finished, 0.001161 sec.
# 425-th simulation finished, 0.001178 sec.
# 426-th simulation finished, 0.001157 sec.
# 427-th simulation finished, 0.001180 sec.
# 428-th simulation finished, 0.001158 sec.
# 429-th simulation finished, 0.001176 sec.
# 430-th simulation finished, 0.001154 sec.
# 431-th simulation finished, 0.001186 sec.
# 432-th simulation finished, 0.001175 sec.
# 433-th simulation finished, 0.001159 sec.
# 434-th simulation finished, 0.001182 sec.
# 435-th simulation finished, 0.001121 sec.
# 436-th simulation finished, 0.001141 sec.
# 437-th simulation finished, 0.001114 sec.
# 438-th simulation finished, 0.001134 sec.
# 439-th simulation finished, 0.001114 sec.
# 440-th simulation finished, 0.001140 sec.
# 441-th simulation finished, 0.001127 sec.
# 442-th simulation finished, 0.001116 sec.
# 443-th simulation finished, 0.001112 sec.
# 444-th simulation finished, 0.001117 sec.
# 445-th simulation finished, 0.001112 sec.
# 446-th simulation finished, 0.001128 sec.
# 447-th simulation finished, 0.001147 sec.
# 448-th simulation finished, 0.001157 sec.
# 449-th simulation finished, 0.001143 sec.
# 450-th simulation finished, 0.001153 sec.
# 451-th simulation finished, 0.001145 sec.
# 452-th simulation finished, 0.001149 sec.
# 453-th simulation finished, 0.001151 sec.
# 454-th simulation finished, 0.001153 sec.
# 455-th simulation finished, 0.001180 sec.
# 456-th simulation finished, 0.001195 sec.
# 457-th simulation finished, 0.001159 sec.
# 458-th simulation finished, 0.001136 sec.
# 459-th simulation finished, 0.001109 sec.
# 460-th simulation finished, 0.001110 sec.
# 461-th simulation finished, 0.001114 sec.
# 462-th simulation finished, 0.001110 sec.
# 463-th simulation finished, 0.001113 sec.
# 464-th simulation finished, 0.001147 sec.
# 465-th simulation finished, 0.001128 sec.
# 466-th simulation finished, 0.001142 sec.
# 467-th simulation finished, 0.001121 sec.
# 468-th simulation finished, 0.001112 sec.
# 469-th simulation finished, 0.001144 sec.
# 470-th simulation finished, 0.001155 sec.
# 471-th simulation finished, 0.001153 sec.
# 472-th simulation finished, 0.001163 sec.
# 473-th simulation finished, 0.001153 sec.
# 474-th simulation finished, 0.001157 sec.
# 475-th simulation finished, 0.001147 sec.
# 476-th simulation finished, 0.001150 sec.
# 477-th simulation finished, 0.001159 sec.
# 478-th simulation finished, 0.001157 sec.
# 479-th simulation finished, 0.001148 sec.
# 480-th simulation finished, 0.001152 sec.
# 481-th simulation finished, 0.001144 sec.
# 482-th simulation finished, 0.001151 sec.
# 483-th simulation finished, 0.001152 sec.
# 484-th simulation finished, 0.001156 sec.
# 485-th simulation finished, 0.001149 sec.
# 486-th simulation finished, 0.001143 sec.
# 487-th simulation finished, 0.001143 sec.
# 488-th simulation finished, 0.001156 sec.
# 489-th simulation finished, 0.001144 sec.
# 490-th simulation finished, 0.001196 sec.
# 491-th simulation finished, 0.001161 sec.
# 492-th simulation finished, 0.001122 sec.
# 493-th simulation finished, 0.001104 sec.
# 494-th simulation finished, 0.001110 sec.
# 495-th simulation finished, 0.001111 sec.
# 496-th simulation finished, 0.001530 sec.
# 497-th simulation finished, 0.001202 sec.
# 498-th simulation finished, 0.001142 sec.
# 499-th simulation finished, 0.001150 sec.
# 500-th simulation finished, 0.001131 sec.
# 501-th simulation finished, 0.001178 sec.
# 502-th simulation finished, 0.001136 sec.
# 503-th simulation finished, 0.001185 sec.
# 504-th simulation finished, 0.001159 sec.
# 505-th simulation finished, 0.001181 sec.
# 506-th simulation finished, 0.001155 sec.
# 507-th simulation finished, 0.001177 sec.
# 508-th simulation finished, 0.001158 sec.
# 509-th simulation finished, 0.001183 sec.
# 510-th simulation finished, 0.001155 sec.
# 511-th simulation finished, 0.001194 sec.
# 512-th simulation finished, 0.001154 sec.
# 513-th simulation finished, 0.001182 sec.
# 514-th simulation finished, 0.001114 sec.
# 515-th simulation finished, 0.001137 sec.
# 516-th simulation finished, 0.001131 sec.
# 517-th simulation finished, 0.001600 sec.
# 518-th simulation finished, 0.001343 sec.
# 519-th simulation finished, 0.001169 sec.
# 520-th simulation finished, 0.001134 sec.
# 521-th simulation finished, 0.001152 sec.
# 522-th simulation finished, 0.001150 sec.
# 523-th simulation finished, 0.001124 sec.
# 524-th simulation finished, 0.001153 sec.
# 525-th simulation finished, 0.001174 sec.
# 526-th simulation finished, 0.001171 sec.
# 527-th simulation finished, 0.001159 sec.
# 528-th simulation finished, 0.001169 sec.
# 529-th simulation finished, 0.001172 sec.
# 530-th simulation finished, 0.001177 sec.
# 531-th simulation finished, 0.001159 sec.
# 532-th simulation finished, 0.001180 sec.
# 533-th simulation finished, 0.001154 sec.
# 534-th simulation finished, 0.001183 sec.
# 535-th simulation finished, 0.001151 sec.
# 536-th simulation finished, 0.001176 sec.
# 537-th simulation finished, 0.001177 sec.
# 538-th simulation finished, 0.001193 sec.
# 539-th simulation finished, 0.001181 sec.
# 540-th simulation finished, 0.001171 sec.
# 541-th simulation finished, 0.001166 sec.
# 542-th simulation finished, 0.001166 sec.
# 543-th simulation finished, 0.001157 sec.
# 544-th simulation finished, 0.001160 sec.
# 545-th simulation finished, 0.001193 sec.
# 546-th simulation finished, 0.001196 sec.
# 547-th simulation finished, 0.001143 sec.
# 548-th simulation finished, 0.001143 sec.
# 549-th simulation finished, 0.001117 sec.
# 550-th simulation finished, 0.001144 sec.
# 551-th simulation finished, 0.001110 sec.
# 552-th simulation finished, 0.001132 sec.
# 553-th simulation finished, 0.001132 sec.
# 554-th simulation finished, 0.001125 sec.
# 555-th simulation finished, 0.001115 sec.
# 556-th simulation finished, 0.001112 sec.
# 557-th simulation finished, 0.001121 sec.
# 558-th simulation finished, 0.001157 sec.
# 559-th simulation finished, 0.001159 sec.
# 560-th simulation finished, 0.001173 sec.
# 561-th simulation finished, 0.001166 sec.
# 562-th simulation finished, 0.001188 sec.
# 563-th simulation finished, 0.001153 sec.
# 564-th simulation finished, 0.001187 sec.
# 565-th simulation finished, 0.001154 sec.
# 566-th simulation finished, 0.001171 sec.
# 567-th simulation finished, 0.001161 sec.
# 568-th simulation finished, 0.001182 sec.
# 569-th simulation finished, 0.001161 sec.
# 570-th simulation finished, 0.001142 sec.
# 571-th simulation finished, 0.001127 sec.
# 572-th simulation finished, 0.001133 sec.
# 573-th simulation finished, 0.001114 sec.
# 574-th simulation finished, 0.001138 sec.
# 575-th simulation finished, 0.001157 sec.
# 576-th simulation finished, 0.001127 sec.
# 577-th simulation finished, 0.001126 sec.
# 578-th simulation finished, 0.001130 sec.
# 579-th simulation finished, 0.001115 sec.
# 580-th simulation finished, 0.001128 sec.
# 581-th simulation finished, 0.001138 sec.
# 582-th simulation finished, 0.001280 sec.
# 583-th simulation finished, 0.001246 sec.
# 584-th simulation finished, 0.001187 sec.
# 585-th simulation finished, 0.001199 sec.
# 586-th simulation finished, 0.001172 sec.
# 587-th simulation finished, 0.001180 sec.
# 588-th simulation finished, 0.001160 sec.
# 589-th simulation finished, 0.001169 sec.
# 590-th simulation finished, 0.001165 sec.
# 591-th simulation finished, 0.001173 sec.
# 592-th simulation finished, 0.001139 sec.
# 593-th simulation finished, 0.001146 sec.
# 594-th simulation finished, 0.001122 sec.
# 595-th simulation finished, 0.001143 sec.
# 596-th simulation finished, 0.001114 sec.
# 597-th simulation finished, 0.001133 sec.
# 598-th simulation finished, 0.001114 sec.
# 599-th simulation finished, 0.001135 sec.
# 600-th simulation finished, 0.001113 sec.
# 601-th simulation finished, 0.001134 sec.
# 602-th simulation finished, 0.001114 sec.
# 603-th simulation finished, 0.001135 sec.
# 604-th simulation finished, 0.001144 sec.
# 605-th simulation finished, 0.001183 sec.
# 606-th simulation finished, 0.001155 sec.
# 607-th simulation finished, 0.001176 sec.
# 608-th simulation finished, 0.001160 sec.
# 609-th simulation finished, 0.001182 sec.
# 610-th simulation finished, 0.001151 sec.
# 611-th simulation finished, 0.001174 sec.
# 612-th simulation finished, 0.001149 sec.
# 613-th simulation finished, 0.001171 sec.
# 614-th simulation finished, 0.001156 sec.
# 615-th simulation finished, 0.001183 sec.
# 616-th simulation finished, 0.001202 sec.
# 617-th simulation finished, 0.001193 sec.
# 618-th simulation finished, 0.001156 sec.
# 619-th simulation finished, 0.001182 sec.
# 620-th simulation finished, 0.001151 sec.
# 621-th simulation finished, 0.001192 sec.
# 622-th simulation finished, 0.001210 sec.
# 623-th simulation finished, 0.001178 sec.
# 624-th simulation finished, 0.001192 sec.
# 625-th simulation finished, 0.001173 sec.
# 626-th simulation finished, 0.001177 sec.
# 627-th simulation finished, 0.001121 sec.
# 628-th simulation finished, 0.001152 sec.
# 629-th simulation finished, 0.001130 sec.
# 630-th simulation finished, 0.001146 sec.
# 631-th simulation finished, 0.001114 sec.
# 632-th simulation finished, 0.001153 sec.
# 633-th simulation finished, 0.001120 sec.
# 634-th simulation finished, 0.001152 sec.
# 635-th simulation finished, 0.001119 sec.
# 636-th simulation finished, 0.001141 sec.
# 637-th simulation finished, 0.001117 sec.
# 638-th simulation finished, 0.001176 sec.
# 639-th simulation finished, 0.001166 sec.
# 640-th simulation finished, 0.001182 sec.
# 641-th simulation finished, 0.001170 sec.
# 642-th simulation finished, 0.001185 sec.
# 643-th simulation finished, 0.001158 sec.
# 644-th simulation finished, 0.001181 sec.
# 645-th simulation finished, 0.001158 sec.
# 646-th simulation finished, 0.001239 sec.
# 647-th simulation finished, 0.001198 sec.
# 648-th simulation finished, 0.001170 sec.
# 649-th simulation finished, 0.001191 sec.
# 650-th simulation finished, 0.001161 sec.
# 651-th simulation finished, 0.001184 sec.
# 652-th simulation finished, 0.001161 sec.
# 653-th simulation finished, 0.001179 sec.
# 654-th simulation finished, 0.001181 sec.
# 655-th simulation finished, 0.001161 sec.
# 656-th simulation finished, 0.001167 sec.
# 657-th simulation finished, 0.001169 sec.
# 658-th simulation finished, 0.001178 sec.
# 659-th simulation finished, 0.001162 sec.
# 660-th simulation finished, 0.001152 sec.
# 661-th simulation finished, 0.001118 sec.
# 662-th simulation finished, 0.001143 sec.
# 663-th simulation finished, 0.001118 sec.
# 664-th simulation finished, 0.001137 sec.
# 665-th simulation finished, 0.001113 sec.
# 666-th simulation finished, 0.001148 sec.
# 667-th simulation finished, 0.001139 sec.
# 668-th simulation finished, 0.001114 sec.
# 669-th simulation finished, 0.001622 sec.
# 670-th simulation finished, 0.001309 sec.
# 671-th simulation finished, 0.001179 sec.
# 672-th simulation finished, 0.001162 sec.
# 673-th simulation finished, 0.001176 sec.
# 674-th simulation finished, 0.001158 sec.
# 675-th simulation finished, 0.001180 sec.
# 676-th simulation finished, 0.001171 sec.
# 677-th simulation finished, 0.001168 sec.
# 678-th simulation finished, 0.001155 sec.
# 679-th simulation finished, 0.001179 sec.
# 680-th simulation finished, 0.001155 sec.
# 681-th simulation finished, 0.001175 sec.
# 682-th simulation finished, 0.001154 sec.
# 683-th simulation finished, 0.001180 sec.
# 684-th simulation finished, 0.001152 sec.
# 685-th simulation finished, 0.001170 sec.
# 686-th simulation finished, 0.001150 sec.
# 687-th simulation finished, 0.001192 sec.
# 688-th simulation finished, 0.001152 sec.
# 689-th simulation finished, 0.001201 sec.
# 690-th simulation finished, 0.001151 sec.
# 691-th simulation finished, 0.001615 sec.
# 692-th simulation finished, 0.001414 sec.
# 693-th simulation finished, 0.001154 sec.
# 694-th simulation finished, 0.001131 sec.
# 695-th simulation finished, 0.001130 sec.
# 696-th simulation finished, 0.001160 sec.
# 697-th simulation finished, 0.001166 sec.
# 698-th simulation finished, 0.001144 sec.
# 699-th simulation finished, 0.001147 sec.
# 700-th simulation finished, 0.001120 sec.
# 701-th simulation finished, 0.001137 sec.
# 702-th simulation finished, 0.001116 sec.
# 703-th simulation finished, 0.001132 sec.
# 704-th simulation finished, 0.001132 sec.
# 705-th simulation finished, 0.001172 sec.
# 706-th simulation finished, 0.001157 sec.
# 707-th simulation finished, 0.001194 sec.
# 708-th simulation finished, 0.001153 sec.
# 709-th simulation finished, 0.001176 sec.
# 710-th simulation finished, 0.001149 sec.
# 711-th simulation finished, 0.001193 sec.
# 712-th simulation finished, 0.001183 sec.
# 713-th simulation finished, 0.001170 sec.
# 714-th simulation finished, 0.001169 sec.
# 715-th simulation finished, 0.001189 sec.
# 716-th simulation finished, 0.001162 sec.
# 717-th simulation finished, 0.001188 sec.
# 718-th simulation finished, 0.001168 sec.
# 719-th simulation finished, 0.001183 sec.
# 720-th simulation finished, 0.001153 sec.
# 721-th simulation finished, 0.001175 sec.
# 722-th simulation finished, 0.001156 sec.
# 723-th simulation finished, 0.001184 sec.
# 724-th simulation finished, 0.001151 sec.
# 725-th simulation finished, 0.001173 sec.
# 726-th simulation finished, 0.001148 sec.
# 727-th simulation finished, 0.001211 sec.
# 728-th simulation finished, 0.001169 sec.
# 729-th simulation finished, 0.001137 sec.
# 730-th simulation finished, 0.001120 sec.
# 731-th simulation finished, 0.001130 sec.
# 732-th simulation finished, 0.001118 sec.
# 733-th simulation finished, 0.001122 sec.
# 734-th simulation finished, 0.001114 sec.
# 735-th simulation finished, 0.001120 sec.
# 736-th simulation finished, 0.001118 sec.
# 737-th simulation finished, 0.001115 sec.
# 738-th simulation finished, 0.001128 sec.
# 739-th simulation finished, 0.001157 sec.
# 740-th simulation finished, 0.001170 sec.
# 741-th simulation finished, 0.001199 sec.
# 742-th simulation finished, 0.001165 sec.
# 743-th simulation finished, 0.001177 sec.
# 744-th simulation finished, 0.001163 sec.
# 745-th simulation finished, 0.001225 sec.
# 746-th simulation finished, 0.001155 sec.
# 747-th simulation finished, 0.001181 sec.
# 748-th simulation finished, 0.001153 sec.
# 749-th simulation finished, 0.001166 sec.
# 750-th simulation finished, 0.001108 sec.
# 751-th simulation finished, 0.001134 sec.
# 752-th simulation finished, 0.001111 sec.
# 753-th simulation finished, 0.001129 sec.
# 754-th simulation finished, 0.001111 sec.
# 755-th simulation finished, 0.001138 sec.
# 756-th simulation finished, 0.001123 sec.
# 757-th simulation finished, 0.001116 sec.
# 758-th simulation finished, 0.001113 sec.
# 759-th simulation finished, 0.001142 sec.
# 760-th simulation finished, 0.001117 sec.
# 761-th simulation finished, 0.001161 sec.
# 762-th simulation finished, 0.001151 sec.
# 763-th simulation finished, 0.001187 sec.
# 764-th simulation finished, 0.001160 sec.
# 765-th simulation finished, 0.001175 sec.
# 766-th simulation finished, 0.001157 sec.
# 767-th simulation finished, 0.001220 sec.
# 768-th simulation finished, 0.001154 sec.
# 769-th simulation finished, 0.001196 sec.
# 770-th simulation finished, 0.001163 sec.
# 771-th simulation finished, 0.001159 sec.
# 772-th simulation finished, 0.001157 sec.
# 773-th simulation finished, 0.001154 sec.
# 774-th simulation finished, 0.001155 sec.
# 775-th simulation finished, 0.001170 sec.
# 776-th simulation finished, 0.001150 sec.
# 777-th simulation finished, 0.001166 sec.
# 778-th simulation finished, 0.001151 sec.
# 779-th simulation finished, 0.001154 sec.
# 780-th simulation finished, 0.001176 sec.
# 781-th simulation finished, 0.001173 sec.
# 782-th simulation finished, 0.001155 sec.
# 783-th simulation finished, 0.001171 sec.
# 784-th simulation finished, 0.001113 sec.
# 785-th simulation finished, 0.001117 sec.
# 786-th simulation finished, 0.001111 sec.
# 787-th simulation finished, 0.001115 sec.
# 788-th simulation finished, 0.001102 sec.
# 789-th simulation finished, 0.001116 sec.
# 790-th simulation finished, 0.001105 sec.
# 791-th simulation finished, 0.001108 sec.
# 792-th simulation finished, 0.001170 sec.
# 793-th simulation finished, 0.001131 sec.
# 794-th simulation finished, 0.001136 sec.
# 795-th simulation finished, 0.001145 sec.
# 796-th simulation finished, 0.001181 sec.
# 797-th simulation finished, 0.001165 sec.
# 798-th simulation finished, 0.001175 sec.
# 799-th simulation finished, 0.001182 sec.
# 800-th simulation finished, 0.001177 sec.
# 801-th simulation finished, 0.001170 sec.
# 802-th simulation finished, 0.001209 sec.
# 803-th simulation finished, 0.001160 sec.
# 804-th simulation finished, 0.001176 sec.
# 805-th simulation finished, 0.001151 sec.
# 806-th simulation finished, 0.001178 sec.
# 807-th simulation finished, 0.001150 sec.
# 808-th simulation finished, 0.001170 sec.
# 809-th simulation finished, 0.001144 sec.
# 810-th simulation finished, 0.001183 sec.
# 811-th simulation finished, 0.001160 sec.
# 812-th simulation finished, 0.001172 sec.
# 813-th simulation finished, 0.001155 sec.
# 814-th simulation finished, 0.001259 sec.
# 815-th simulation finished, 0.001153 sec.
# 816-th simulation finished, 0.001173 sec.
# 817-th simulation finished, 0.001141 sec.
# 818-th simulation finished, 0.001135 sec.
# 819-th simulation finished, 0.001114 sec.
# 820-th simulation finished, 0.001135 sec.
# 821-th simulation finished, 0.001112 sec.
# 822-th simulation finished, 0.001139 sec.
# 823-th simulation finished, 0.001121 sec.
# 824-th simulation finished, 0.001148 sec.
# 825-th simulation finished, 0.001104 sec.
# 826-th simulation finished, 0.001169 sec.
# 827-th simulation finished, 0.001127 sec.
# 828-th simulation finished, 0.001123 sec.
# 829-th simulation finished, 0.001146 sec.
# 830-th simulation finished, 0.001156 sec.
# 831-th simulation finished, 0.001160 sec.
# 832-th simulation finished, 0.001152 sec.
# 833-th simulation finished, 0.001191 sec.
# 834-th simulation finished, 0.001168 sec.
# 835-th simulation finished, 0.001154 sec.
# 836-th simulation finished, 0.001153 sec.
# 837-th simulation finished, 0.001150 sec.
# 838-th simulation finished, 0.001153 sec.
# 839-th simulation finished, 0.001167 sec.
# 840-th simulation finished, 0.001176 sec.
# 841-th simulation finished, 0.001158 sec.
# 842-th simulation finished, 0.001172 sec.
# 843-th simulation finished, 0.001282 sec.
# 844-th simulation finished, 0.001426 sec.
# 845-th simulation finished, 0.001167 sec.
# 846-th simulation finished, 0.001184 sec.
# 847-th simulation finished, 0.001158 sec.
# 848-th simulation finished, 0.001182 sec.
# 849-th simulation finished, 0.001146 sec.
# 850-th simulation finished, 0.001170 sec.
# 851-th simulation finished, 0.001132 sec.
# 852-th simulation finished, 0.001140 sec.
# 853-th simulation finished, 0.001120 sec.
# 854-th simulation finished, 0.001150 sec.
# 855-th simulation finished, 0.001118 sec.
# 856-th simulation finished, 0.001139 sec.
# 857-th simulation finished, 0.001111 sec.
# 858-th simulation finished, 0.001155 sec.
# 859-th simulation finished, 0.001113 sec.
# 860-th simulation finished, 0.001137 sec.
# 861-th simulation finished, 0.001113 sec.
# 862-th simulation finished, 0.001134 sec.
# 863-th simulation finished, 0.001152 sec.
# 864-th simulation finished, 0.001163 sec.
# 865-th simulation finished, 0.001149 sec.
# 866-th simulation finished, 0.001540 sec.
# 867-th simulation finished, 0.001410 sec.
# 868-th simulation finished, 0.001209 sec.
# 869-th simulation finished, 0.001167 sec.
# 870-th simulation finished, 0.001189 sec.
# 871-th simulation finished, 0.001159 sec.
# 872-th simulation finished, 0.001182 sec.
# 873-th simulation finished, 0.001156 sec.
# 874-th simulation finished, 0.001177 sec.
# 875-th simulation finished, 0.001151 sec.
# 876-th simulation finished, 0.001175 sec.
# 877-th simulation finished, 0.001157 sec.
# 878-th simulation finished, 0.001172 sec.
# 879-th simulation finished, 0.001160 sec.
# 880-th simulation finished, 0.001170 sec.
# 881-th simulation finished, 0.001152 sec.
# 882-th simulation finished, 0.001241 sec.
# 883-th simulation finished, 0.001191 sec.
# 884-th simulation finished, 0.001168 sec.
# 885-th simulation finished, 0.001165 sec.
# 886-th simulation finished, 0.001177 sec.
# 887-th simulation finished, 0.001164 sec.
# 888-th simulation finished, 0.001167 sec.
# 889-th simulation finished, 0.001154 sec.
# 890-th simulation finished, 0.001161 sec.
# 891-th simulation finished, 0.001192 sec.
# 892-th simulation finished, 0.001161 sec.
# 893-th simulation finished, 0.001177 sec.
# 894-th simulation finished, 0.001152 sec.
# 895-th simulation finished, 0.001210 sec.
# 896-th simulation finished, 0.001133 sec.
# 897-th simulation finished, 0.001118 sec.
# 898-th simulation finished, 0.001146 sec.
# 899-th simulation finished, 0.001127 sec.
# 900-th simulation finished, 0.001153 sec.
# 901-th simulation finished, 0.001111 sec.
# 902-th simulation finished, 0.001143 sec.
# 903-th simulation finished, 0.001118 sec.
# 904-th simulation finished, 0.001143 sec.
# 905-th simulation finished, 0.001133 sec.
# 906-th simulation finished, 0.001120 sec.
# 907-th simulation finished, 0.001121 sec.
# 908-th simulation finished, 0.001121 sec.
# 909-th simulation finished, 0.001118 sec.
# 910-th simulation finished, 0.001125 sec.
# 911-th simulation finished, 0.001116 sec.
# 912-th simulation finished, 0.001120 sec.
# 913-th simulation finished, 0.001115 sec.
# 914-th simulation finished, 0.001134 sec.
# 915-th simulation finished, 0.001152 sec.
# 916-th simulation finished, 0.001141 sec.
# 917-th simulation finished, 0.001138 sec.
# 918-th simulation finished, 0.001117 sec.
# 919-th simulation finished, 0.001180 sec.
# 920-th simulation finished, 0.001151 sec.
# 921-th simulation finished, 0.001172 sec.
# 922-th simulation finished, 0.001166 sec.
# 923-th simulation finished, 0.001155 sec.
# 924-th simulation finished, 0.001153 sec.
# 925-th simulation finished, 0.001160 sec.
# 926-th simulation finished, 0.001155 sec.
# 927-th simulation finished, 0.001150 sec.
# 928-th simulation finished, 0.001164 sec.
# 929-th simulation finished, 0.001157 sec.
# 930-th simulation finished, 0.001151 sec.
# 931-th simulation finished, 0.001159 sec.
# 932-th simulation finished, 0.001155 sec.
# 933-th simulation finished, 0.001147 sec.
# 934-th simulation finished, 0.001151 sec.
# 935-th simulation finished, 0.001149 sec.
# 936-th simulation finished, 0.001152 sec.
# 937-th simulation finished, 0.001157 sec.
# 938-th simulation finished, 0.001148 sec.
# 939-th simulation finished, 0.001149 sec.
# 940-th simulation finished, 0.001145 sec.
# 941-th simulation finished, 0.001151 sec.
# 942-th simulation finished, 0.001119 sec.
# 943-th simulation finished, 0.001118 sec.
# 944-th simulation finished, 0.001108 sec.
# 945-th simulation finished, 0.001107 sec.
# 946-th simulation finished, 0.001113 sec.
# 947-th simulation finished, 0.001106 sec.
# 948-th simulation finished, 0.001149 sec.
# 949-th simulation finished, 0.001146 sec.
# 950-th simulation finished, 0.001113 sec.
# 951-th simulation finished, 0.001135 sec.
# 952-th simulation finished, 0.001122 sec.
# 953-th simulation finished, 0.001139 sec.
# 954-th simulation finished, 0.001149 sec.
# 955-th simulation finished, 0.001166 sec.
# 956-th simulation finished, 0.001154 sec.
# 957-th simulation finished, 0.001156 sec.
# 958-th simulation finished, 0.001150 sec.
# 959-th simulation finished, 0.001153 sec.
# 960-th simulation finished, 0.001150 sec.
# 961-th simulation finished, 0.001153 sec.
# 962-th simulation finished, 0.001149 sec.
# 963-th simulation finished, 0.001159 sec.
# 964-th simulation finished, 0.001152 sec.
# 965-th simulation finished, 0.001145 sec.
# 966-th simulation finished, 0.001147 sec.
# 967-th simulation finished, 0.001157 sec.
# 968-th simulation finished, 0.001167 sec.
# 969-th simulation finished, 0.001160 sec.
# 970-th simulation finished, 0.001149 sec.
# 971-th simulation finished, 0.001154 sec.
# 972-th simulation finished, 0.001179 sec.
# 973-th simulation finished, 0.001149 sec.
# 974-th simulation finished, 0.001157 sec.
# 975-th simulation finished, 0.001158 sec.
# 976-th simulation finished, 0.001154 sec.
# 977-th simulation finished, 0.001147 sec.
# 978-th simulation finished, 0.001146 sec.
# 979-th simulation finished, 0.001165 sec.
# 980-th simulation finished, 0.001148 sec.
# 981-th simulation finished, 0.001147 sec.
# 982-th simulation finished, 0.001146 sec.
# 983-th simulation finished, 0.001149 sec.
# 984-th simulation finished, 0.001146 sec.
# 985-th simulation finished, 0.001156 sec.
# 986-th simulation finished, 0.001143 sec.
# 987-th simulation finished, 0.001155 sec.
# 988-th simulation finished, 0.001103 sec.
# 989-th simulation finished, 0.001117 sec.
# 990-th simulation finished, 0.001107 sec.
# 991-th simulation finished, 0.001113 sec.
# 992-th simulation finished, 0.001159 sec.
# 993-th simulation finished, 0.001121 sec.
# 994-th simulation finished, 0.001132 sec.
# 995-th simulation finished, 0.001122 sec.
# 996-th simulation finished, 0.001135 sec.
# 997-th simulation finished, 0.001107 sec.
# 998-th simulation finished, 0.001136 sec.
# 999-th simulation finished, 0.001156 sec.
# 1000-th simulation finished, 0.001176 sec.

# %%
plt.hist(bsim[:,1])
plt.axvline(beta[1], color='red')

# %%
stats.probplot(bsim[:,1], dist = 'norm', plot=plt, fit=True)
# plt.plot([0, 1], [0, 1], color='black')
plt.show()

# %%
plt.hist(Ts_dth)
# Out:
# (array([ 78., 192., 221., 196., 124., 105.,  54.,  23.,   3.,   4.]),
#  array([-1.82453662, -1.25023481, -0.67593299, -0.10163118,  0.47267063,
#          1.04697244,  1.62127425,  2.19557606,  2.76987787,  3.34417969,
#          3.9184815 ]),
#  <BarContainer object of 10 artists>)

# %%
stats.probplot(ps_dth, dist = 'uniform', plot=plt, fit=False)
plt.plot([0, 1], [0, 1], color='black')
plt.show()

# %%
np.mean(np.abs(ps_dth) > 0.05)
# Out:
# 0.95

# %%
stats.probplot(ps_sdw, dist = 'uniform', plot=plt, fit=False)
plt.plot([0, 1], [0, 1], color='black')
plt.show()

# %%
np.mean(np.abs(ps_sdw) > 0.05)
# Out:
# 0.926
