# %%
import os, importlib, sys, time

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import scipy.linalg as la
import scipy.stats as stats

# %%
import freqepid

# %%
# %load_ext jupyternotify

# %% [markdown]
# # 1. parameters

# %%
T = 120
T0 = 40

# %%
GPi = np.load('data/GPi.npz')

# %% [markdown]
# ## observation parameters

# %%
alpha = 0.01
r_Y = 10

# %% [markdown]
# $$Y_t = NegBinom( \frac{EY_t}{r_Y + EY_t}, r_Y )$$
#
# $$ EY_t = \alpha\sum_{s=1}^{t-1} I_s \pi_{t-s} $$

# %% [markdown]
# ## latent parameters

# %%
d = 2
beta = np.array([0, -2.2])

# %%
r_I = 10
K = 6.5

# %% [markdown]
# $$I_t = NegBinom( \frac{EI_t}{r_I + EI_t}, r_I )$$
#
# $$ EI_t = R(\bar{A}_t, \beta) \sum_{s=1}^{t-1} I_s g_{t-s} $$
#
# $$R(\bar{A}_t, \beta) = \frac{K}{1+\exp(- \beta^\top A_t)}$$

# %% [markdown]
# ## seed values

# %%
mu = np.log(100)

# %% [markdown]
# $$I_{[-T_0,0)} = \exp(\mu_0)$$

# %% [markdown]
# # 2. simulation

# %% [markdown]
# ## load simulation

# %%
data = pd.read_feather('data/simulation_randinf.feather')

# %%
data_i = data[data['sim']==0]
A = np.stack([np.full(T, 1), data_i["intervention"].to_numpy()], -1)
R = data_i["R"].to_numpy()
EI = data_i["EI"].to_numpy()
I = data_i["infection"].to_numpy()
EY = data_i["EY"].to_numpy()
Y = data_i["death"].to_numpy()

# %%
data_i
# Out:
#      sim  date         R          EI  infection         EY  death  \
# 0      0     0  3.250000  324.997762      356.0   0.956069      0
# 1      0     1  3.250000  340.245831      298.0   0.962543      2
# 2      0     2  3.250000  392.196621      409.0   0.968283      0
# 3      0     3  3.250000  471.047829      545.0   0.973654      1
# 4      0     4  3.250000  581.900998      584.0   0.979752      1
# ..   ...   ...       ...         ...        ...        ...    ...
# 115    0   115  0.648378  371.111321      316.0  15.952502     18
# 116    0   116  0.648378  353.729962      301.0  15.065929      6
# 117    0   117  0.648378  334.027910      314.0  14.232065     22
# 118    0   118  0.648378  313.305734      285.0  13.440178     20
# 119    0   119  0.648378  293.160919      302.0  12.694121     17
#
#      intervention
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0
# ..            ...
# 115             1
# 116             1
# 117             1
# 118             1
# 119             1
#
# [120 rows x 8 columns]

# %% [markdown]
# # 3. fit by coordinate descent method

# %%
model = freqepid.Model(GPi['g'], GPi['pi'], alpha, K, T0, 'nbinom')

# %%
nhs, mhs, bhs, lls = \
model.fit(A, Y, n_iter=500, history=True, verbose=True)
# Out:
# /Users/blueconet/mambaforge/envs/freqepid/lib/python3.10/site-packages/freqepid/model.py:141: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   bhaty = np.linalg.lstsq(Xy, Yy)[0]
# /Users/blueconet/mambaforge/envs/freqepid/lib/python3.10/site-packages/freqepid/model.py:146: RuntimeWarning: divide by zero encountered in log
#   log_err_ratio = np.log(Y / self.predict_EY(A, 0, binit))
# Before EM, ll: -696.612784
# 1-th iteration finished, ll: -657.599872, lapse: 0.028sec.
# 2-th iteration finished, ll: -564.680739, lapse: 0.016sec.
# 3-th iteration finished, ll: -513.646712, lapse: 0.019sec.
# 4-th iteration finished, ll: -506.406466, lapse: 0.013sec.
# 5-th iteration finished, ll: -506.207388, lapse: 0.016sec.
# 6-th iteration finished, ll: -506.205622, lapse: 0.012sec.
# 7-th iteration finished, ll: -506.205598, lapse: 0.013sec.
# 8-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 9-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 10-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 11-th iteration finished, ll: -506.205597, lapse: 0.016sec.
# 12-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 13-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 14-th iteration finished, ll: -506.205597, lapse: 0.018sec.
# 15-th iteration finished, ll: -506.205597, lapse: 0.017sec.
# 16-th iteration finished, ll: -506.205597, lapse: 0.018sec.
# 17-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 18-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 19-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 20-th iteration finished, ll: -506.205597, lapse: 0.016sec.
# 21-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 22-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 23-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 24-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 25-th iteration finished, ll: -506.205597, lapse: 0.011sec.
# 26-th iteration finished, ll: -506.205597, lapse: 0.027sec.
# 27-th iteration finished, ll: -506.205597, lapse: 0.016sec.
# 28-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 29-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 30-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 31-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 32-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 33-th iteration finished, ll: -506.205597, lapse: 0.023sec.
# 34-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 35-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 36-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 37-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 38-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 39-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 40-th iteration finished, ll: -506.205597, lapse: 0.016sec.
# 41-th iteration finished, ll: -506.205597, lapse: 0.026sec.
# 42-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 43-th iteration finished, ll: -506.205597, lapse: 0.019sec.
# 44-th iteration finished, ll: -506.205597, lapse: 0.025sec.
# 45-th iteration finished, ll: -506.205597, lapse: 0.043sec.
# 46-th iteration finished, ll: -506.205597, lapse: 0.027sec.
# 47-th iteration finished, ll: -506.205597, lapse: 0.024sec.
# 48-th iteration finished, ll: -506.205597, lapse: 0.024sec.
# 49-th iteration finished, ll: -506.205597, lapse: 0.018sec.
# 50-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 51-th iteration finished, ll: -506.205597, lapse: 0.027sec.
# 52-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 53-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 54-th iteration finished, ll: -506.205597, lapse: 0.016sec.
# 55-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 56-th iteration finished, ll: -506.205597, lapse: 0.016sec.
# 57-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 58-th iteration finished, ll: -506.205597, lapse: 0.025sec.
# 59-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 60-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 61-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 62-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 63-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 64-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 65-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 66-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 67-th iteration finished, ll: -506.205597, lapse: 0.016sec.
# 68-th iteration finished, ll: -506.205597, lapse: 0.016sec.
# 69-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 70-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 71-th iteration finished, ll: -506.205597, lapse: 0.019sec.
# 72-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 73-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 74-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 75-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 76-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 77-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 78-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 79-th iteration finished, ll: -506.205597, lapse: 0.036sec.
# 80-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 81-th iteration finished, ll: -506.205597, lapse: 0.011sec.
# 82-th iteration finished, ll: -506.205597, lapse: 0.023sec.
# 83-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 84-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 85-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 86-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 87-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 88-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 89-th iteration finished, ll: -506.205597, lapse: 0.018sec.
# 90-th iteration finished, ll: -506.205597, lapse: 0.027sec.
# 91-th iteration finished, ll: -506.205597, lapse: 0.038sec.
# 92-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 93-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 94-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 95-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 96-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 97-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 98-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 99-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 100-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 101-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 102-th iteration finished, ll: -506.205597, lapse: 0.022sec.
# 103-th iteration finished, ll: -506.205597, lapse: 0.016sec.
# 104-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 105-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 106-th iteration finished, ll: -506.205597, lapse: 0.019sec.
# 107-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 108-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 109-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 110-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 111-th iteration finished, ll: -506.205597, lapse: 0.017sec.
# 112-th iteration finished, ll: -506.205597, lapse: 0.011sec.
# 113-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 114-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 115-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 116-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 117-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 118-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 119-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 120-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 121-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 122-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 123-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 124-th iteration finished, ll: -506.205597, lapse: 0.019sec.
# 125-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 126-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 127-th iteration finished, ll: -506.205597, lapse: 0.016sec.
# 128-th iteration finished, ll: -506.205597, lapse: 0.016sec.
# 129-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 130-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 131-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 132-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 133-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 134-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 135-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 136-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 137-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 138-th iteration finished, ll: -506.205597, lapse: 0.018sec.
# 139-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 140-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 141-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 142-th iteration finished, ll: -506.205597, lapse: 0.016sec.
# 143-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 144-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 145-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 146-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 147-th iteration finished, ll: -506.205597, lapse: 0.016sec.
# 148-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 149-th iteration finished, ll: -506.205597, lapse: 0.020sec.
# 150-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 151-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 152-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 153-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 154-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 155-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 156-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 157-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 158-th iteration finished, ll: -506.205597, lapse: 0.017sec.
# 159-th iteration finished, ll: -506.205597, lapse: 0.021sec.
# 160-th iteration finished, ll: -506.205597, lapse: 0.019sec.
# 161-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 162-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 163-th iteration finished, ll: -506.205597, lapse: 0.017sec.
# 164-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 165-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 166-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 167-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 168-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 169-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 170-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 171-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 172-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 173-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 174-th iteration finished, ll: -506.205597, lapse: 0.021sec.
# 175-th iteration finished, ll: -506.205597, lapse: 0.021sec.
# 176-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 177-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 178-th iteration finished, ll: -506.205597, lapse: 0.016sec.
# 179-th iteration finished, ll: -506.205597, lapse: 0.017sec.
# 180-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 181-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 182-th iteration finished, ll: -506.205597, lapse: 0.016sec.
# 183-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 184-th iteration finished, ll: -506.205597, lapse: 0.016sec.
# 185-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 186-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 187-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 188-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 189-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 190-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 191-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 192-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 193-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 194-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 195-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 196-th iteration finished, ll: -506.205597, lapse: 0.016sec.
# 197-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 198-th iteration finished, ll: -506.205597, lapse: 0.016sec.
# 199-th iteration finished, ll: -506.205597, lapse: 0.011sec.
# 200-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 201-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 202-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 203-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 204-th iteration finished, ll: -506.205597, lapse: 0.016sec.
# 205-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 206-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 207-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 208-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 209-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 210-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 211-th iteration finished, ll: -506.205597, lapse: 0.011sec.
# 212-th iteration finished, ll: -506.205597, lapse: 0.017sec.
# 213-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 214-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 215-th iteration finished, ll: -506.205597, lapse: 0.016sec.
# 216-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 217-th iteration finished, ll: -506.205597, lapse: 0.032sec.
# 218-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 219-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 220-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 221-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 222-th iteration finished, ll: -506.205597, lapse: 0.016sec.
# 223-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 224-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 225-th iteration finished, ll: -506.205597, lapse: 0.019sec.
# 226-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 227-th iteration finished, ll: -506.205597, lapse: 0.021sec.
# 228-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 229-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 230-th iteration finished, ll: -506.205597, lapse: 0.016sec.
# 231-th iteration finished, ll: -506.205597, lapse: 0.019sec.
# 232-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 233-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 234-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 235-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 236-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 237-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 238-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 239-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 240-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 241-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 242-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 243-th iteration finished, ll: -506.205597, lapse: 0.016sec.
# 244-th iteration finished, ll: -506.205597, lapse: 0.021sec.
# 245-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 246-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 247-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 248-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 249-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 250-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 251-th iteration finished, ll: -506.205597, lapse: 0.019sec.
# 252-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 253-th iteration finished, ll: -506.205597, lapse: 0.017sec.
# 254-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 255-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 256-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 257-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 258-th iteration finished, ll: -506.205597, lapse: 0.019sec.
# 259-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 260-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 261-th iteration finished, ll: -506.205597, lapse: 0.016sec.
# 262-th iteration finished, ll: -506.205597, lapse: 0.022sec.
# 263-th iteration finished, ll: -506.205597, lapse: 0.016sec.
# 264-th iteration finished, ll: -506.205597, lapse: 0.016sec.
# 265-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 266-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 267-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 268-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 269-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 270-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 271-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 272-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 273-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 274-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 275-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 276-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 277-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 278-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 279-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 280-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 281-th iteration finished, ll: -506.205597, lapse: 0.016sec.
# 282-th iteration finished, ll: -506.205597, lapse: 0.024sec.
# 283-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 284-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 285-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 286-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 287-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 288-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 289-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 290-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 291-th iteration finished, ll: -506.205597, lapse: 0.019sec.
# 292-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 293-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 294-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 295-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 296-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 297-th iteration finished, ll: -506.205597, lapse: 0.011sec.
# 298-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 299-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 300-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 301-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 302-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 303-th iteration finished, ll: -506.205597, lapse: 0.039sec.
# 304-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 305-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 306-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 307-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 308-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 309-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 310-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 311-th iteration finished, ll: -506.205597, lapse: 0.024sec.
# 312-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 313-th iteration finished, ll: -506.205597, lapse: 0.019sec.
# 314-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 315-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 316-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 317-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 318-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 319-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 320-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 321-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 322-th iteration finished, ll: -506.205597, lapse: 0.023sec.
# 323-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 324-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 325-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 326-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 327-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 328-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 329-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 330-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 331-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 332-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 333-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 334-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 335-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 336-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 337-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 338-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 339-th iteration finished, ll: -506.205597, lapse: 0.016sec.
# 340-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 341-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 342-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 343-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 344-th iteration finished, ll: -506.205597, lapse: 0.020sec.
# 345-th iteration finished, ll: -506.205597, lapse: 0.016sec.
# 346-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 347-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 348-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 349-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 350-th iteration finished, ll: -506.205597, lapse: 0.011sec.
# 351-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 352-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 353-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 354-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 355-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 356-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 357-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 358-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 359-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 360-th iteration finished, ll: -506.205597, lapse: 0.017sec.
# 361-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 362-th iteration finished, ll: -506.205597, lapse: 0.016sec.
# 363-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 364-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 365-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 366-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 367-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 368-th iteration finished, ll: -506.205597, lapse: 0.023sec.
# 369-th iteration finished, ll: -506.205597, lapse: 0.018sec.
# 370-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 371-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 372-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 373-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 374-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 375-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 376-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 377-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 378-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 379-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 380-th iteration finished, ll: -506.205597, lapse: 0.016sec.
# 381-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 382-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 383-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 384-th iteration finished, ll: -506.205597, lapse: 0.016sec.
# 385-th iteration finished, ll: -506.205597, lapse: 0.016sec.
# 386-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 387-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 388-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 389-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 390-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 391-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 392-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 393-th iteration finished, ll: -506.205597, lapse: 0.022sec.
# 394-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 395-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 396-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 397-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 398-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 399-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 400-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 401-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 402-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 403-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 404-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 405-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 406-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 407-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 408-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 409-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 410-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 411-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 412-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 413-th iteration finished, ll: -506.205597, lapse: 0.018sec.
# 414-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 415-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 416-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 417-th iteration finished, ll: -506.205597, lapse: 0.020sec.
# 418-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 419-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 420-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 421-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 422-th iteration finished, ll: -506.205597, lapse: 0.019sec.
# 423-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 424-th iteration finished, ll: -506.205597, lapse: 0.019sec.
# 425-th iteration finished, ll: -506.205597, lapse: 0.019sec.
# 426-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 427-th iteration finished, ll: -506.205597, lapse: 0.016sec.
# 428-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 429-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 430-th iteration finished, ll: -506.205597, lapse: 0.024sec.
# 431-th iteration finished, ll: -506.205597, lapse: 0.019sec.
# 432-th iteration finished, ll: -506.205597, lapse: 0.020sec.
# 433-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 434-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 435-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 436-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 437-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 438-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 439-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 440-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 441-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 442-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 443-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 444-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 445-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 446-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 447-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 448-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 449-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 450-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 451-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 452-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 453-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 454-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 455-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 456-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 457-th iteration finished, ll: -506.205597, lapse: 0.020sec.
# 458-th iteration finished, ll: -506.205597, lapse: 0.026sec.
# 459-th iteration finished, ll: -506.205597, lapse: 0.026sec.
# 460-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 461-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 462-th iteration finished, ll: -506.205597, lapse: 0.018sec.
# 463-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 464-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 465-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 466-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 467-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 468-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 469-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 470-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 471-th iteration finished, ll: -506.205597, lapse: 0.011sec.
# 472-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 473-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 474-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 475-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 476-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 477-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 478-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 479-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 480-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 481-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 482-th iteration finished, ll: -506.205597, lapse: 0.016sec.
# 483-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 484-th iteration finished, ll: -506.205597, lapse: 0.019sec.
# 485-th iteration finished, ll: -506.205597, lapse: 0.016sec.
# 486-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 487-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 488-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 489-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 490-th iteration finished, ll: -506.205597, lapse: 0.019sec.
# 491-th iteration finished, ll: -506.205597, lapse: 0.014sec.
# 492-th iteration finished, ll: -506.205597, lapse: 0.017sec.
# 493-th iteration finished, ll: -506.205597, lapse: 0.015sec.
# 494-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 495-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 496-th iteration finished, ll: -506.205597, lapse: 0.011sec.
# 497-th iteration finished, ll: -506.205597, lapse: 0.012sec.
# 498-th iteration finished, ll: -506.205597, lapse: 0.013sec.
# 499-th iteration finished, ll: -506.205597, lapse: 0.018sec.
# 500-th iteration finished, ll: -506.205597, lapse: 0.012sec.

# %%
nmle = nhs[-1]
mmle = mhs[-1]
bmle = bhs[-1]

# %%
nmle, mmle, bmle
# Out:
# (8.430108910959422, 4.81912627274026, array([-0.10148412, -2.08905259]))

# %%
Rmle = model.predict_R(A, bmle)
Imle = model.predict_I(A, mmle, bmle)
EYmle = model.predict_EY(A, mmle, bmle)

# %% [markdown]
# ## plots

# %%
plt.plot(nhs, label=r"$\hat{r}^{(i)}$")
plt.xlabel("iteration (i)"); plt.legend()

# %%
plt.plot(mhs, label=r"$\hat{\mu}^{(i)}$")
plt.xlabel("iteration (i)"); plt.legend()

# %%
plt.plot(bhs, label=r"$\hat{\beta}^{(i)}$")
plt.xlabel("iteration (i)"); plt.legend()

# %%
plt.plot(Rmle)
plt.plot(R, color='grey')

# %%
plt.plot(Imle)
plt.bar(np.arange(T), I, color='grey', alpha=0.5)
# Out:
# <BarContainer object of 120 artists>

# %%
conf_Y = model.confidence_Y(A, nmle, mmle, bmle, alpha=0.05)

# %%
plt.plot(EYmle)
plt.fill_between(np.arange(T), conf_Y[:,0], conf_Y[:,1], alpha=0.3)
plt.bar(np.arange(T), Y, color='grey', alpha=0.5)
# Out:
# <BarContainer object of 120 artists>

# %% [markdown]
# # 4. Confidence Region

# %%
Ihat_dth, Ihat_hac, Ihat_sdw = model.inference(A, Y, nmle, mmle, bmle)

# %%
chi_pa = freqepid.CV(d+1).chi_pa(0.05)

# %%
la.inv(Ihat_sdw)[-2:,-2:]
# Out:
# array([[ 0.0024869 , -0.00300037],
#        [-0.00300037,  0.00383767]])

# %%
la.inv(Ihat_dth)[-2:,-2:]
# Out:
# array([[ 0.00320598, -0.00368744],
#        [-0.00368744,  0.00451192]])

# %% [markdown]
# ## hessian

# %%
plt.figure(figsize=(5,5))
p = plt.scatter(*bmle)
plt.scatter(*beta)
freqepid.confidence_ellipse(
    bmle, np.linalg.pinv(Ihat_dth)[-2:,-2:], 
    n_std=chi_pa, facecolor=p.get_facecolor(), alpha=0.3)
plt.xlim(-1, 1); plt.ylim(-3,-1)
# Out:
# (-3.0, -1.0)

# %%
theta = np.array([mu, *beta])
tmle = np.array([mmle, *bmle])
tname = [r"$\mu$", r"$\beta_0$", r"$\beta_1$"]
tlimit = [[3, 8], [-1, 0.5], [-3, -1]]

# %%
plt.figure(figsize=(9,3))
for i in np.arange(d+1):
    for j in np.arange(i+1,d+1):
        plt.subplot(1,3,i+j)
        p = plt.scatter(tmle[j], tmle[i])
        plt.scatter(theta[j], theta[i], color='grey')
        freqepid.confidence_ellipse(
            [tmle[j],tmle[i]], np.linalg.pinv(Ihat_dth)[np.ix_([j+1,i+1],[j+1,i+1])], 
            n_std=chi_pa, facecolor=p.get_facecolor(), alpha=0.3)
        plt.xlabel(tname[j]); plt.ylabel(tname[i])
        plt.xlim(tlimit[j]); plt.ylim(tlimit[i])
plt.tight_layout()

# %% [markdown]
# ## sandwich estimator

# %%
plt.figure(figsize=(5,5))
p = plt.scatter(*bmle)
plt.scatter(*beta)
freqepid.confidence_ellipse(
    bmle, np.linalg.pinv(Ihat_sdw)[-2:,-2:], 
    n_std=chi_pa, facecolor=p.get_facecolor(), alpha=0.3)
plt.xlim(-1, 1); plt.ylim(-3,-1)
# Out:
# (-3.0, -1.0)

# %%
plt.figure(figsize=(10,10))
for i in np.arange(d+1):
    for j in np.arange(i+1,d+1):
        plt.subplot(d+1,d+1,i*(d+1)+j+1)
        p = plt.scatter(tmle[j], tmle[i])
        plt.scatter(theta[j], theta[i])
        freqepid.confidence_ellipse(
            [tmle[j],tmle[i]], np.linalg.pinv(Ihat_sdw)[np.ix_([j+1,i+1],[j+1,i+1])], 
            n_std=chi_pa, facecolor=p.get_facecolor(), alpha=0.3)

# %% [markdown]
# # 5. confidence bands

# %%
conf_R, beta_min, beta_max = \
model.confidence_R(A, bmle, np.linalg.inv(Ihat_dth)[-2:,-2:], chi_pa,
                   verbose=True)
# Out:
# optimization at t = 1 finished, lapse: 0.306sec.
# optimization at t = 2 finished, lapse: 0.158sec.
# optimization at t = 3 finished, lapse: 0.208sec.
# optimization at t = 4 finished, lapse: 0.159sec.
# optimization at t = 5 finished, lapse: 0.170sec.
# optimization at t = 6 finished, lapse: 0.162sec.
# optimization at t = 7 finished, lapse: 0.125sec.
# optimization at t = 8 finished, lapse: 0.190sec.
# optimization at t = 9 finished, lapse: 0.139sec.
# optimization at t = 10 finished, lapse: 0.209sec.
# optimization at t = 11 finished, lapse: 0.187sec.
# optimization at t = 12 finished, lapse: 0.176sec.
# optimization at t = 13 finished, lapse: 0.179sec.
# optimization at t = 14 finished, lapse: 0.158sec.
# optimization at t = 15 finished, lapse: 0.192sec.
# optimization at t = 16 finished, lapse: 0.140sec.
# optimization at t = 17 finished, lapse: 0.205sec.
# optimization at t = 18 finished, lapse: 0.164sec.
# optimization at t = 19 finished, lapse: 0.113sec.
# optimization at t = 20 finished, lapse: 0.184sec.
# optimization at t = 21 finished, lapse: 0.123sec.
# optimization at t = 22 finished, lapse: 0.208sec.
# optimization at t = 23 finished, lapse: 0.153sec.
# optimization at t = 24 finished, lapse: 0.170sec.
# optimization at t = 25 finished, lapse: 0.166sec.
# optimization at t = 26 finished, lapse: 0.141sec.
# optimization at t = 27 finished, lapse: 0.190sec.
# optimization at t = 28 finished, lapse: 0.166sec.
# optimization at t = 29 finished, lapse: 0.215sec.
# optimization at t = 30 finished, lapse: 0.173sec.
# optimization at t = 31 finished, lapse: 0.204sec.
# optimization at t = 32 finished, lapse: 0.058sec.
# optimization at t = 33 finished, lapse: 0.034sec.
# optimization at t = 34 finished, lapse: 0.035sec.
# optimization at t = 35 finished, lapse: 0.035sec.
# optimization at t = 36 finished, lapse: 0.034sec.
# optimization at t = 37 finished, lapse: 0.036sec.
# optimization at t = 38 finished, lapse: 0.036sec.
# optimization at t = 39 finished, lapse: 0.035sec.
# optimization at t = 40 finished, lapse: 0.036sec.
# optimization at t = 41 finished, lapse: 0.040sec.
# optimization at t = 42 finished, lapse: 0.041sec.
# optimization at t = 43 finished, lapse: 0.042sec.
# optimization at t = 44 finished, lapse: 0.041sec.
# optimization at t = 45 finished, lapse: 0.041sec.
# optimization at t = 46 finished, lapse: 0.041sec.
# optimization at t = 47 finished, lapse: 0.041sec.
# optimization at t = 48 finished, lapse: 0.042sec.
# optimization at t = 49 finished, lapse: 0.042sec.
# optimization at t = 50 finished, lapse: 0.042sec.
# optimization at t = 51 finished, lapse: 0.041sec.
# optimization at t = 52 finished, lapse: 0.041sec.
# optimization at t = 53 finished, lapse: 0.042sec.
# optimization at t = 54 finished, lapse: 0.041sec.
# optimization at t = 55 finished, lapse: 0.041sec.
# optimization at t = 56 finished, lapse: 0.041sec.
# optimization at t = 57 finished, lapse: 0.040sec.
# optimization at t = 58 finished, lapse: 0.041sec.
# optimization at t = 59 finished, lapse: 0.043sec.
# optimization at t = 60 finished, lapse: 0.041sec.
# optimization at t = 61 finished, lapse: 0.041sec.
# optimization at t = 62 finished, lapse: 0.041sec.
# optimization at t = 63 finished, lapse: 0.040sec.
# optimization at t = 64 finished, lapse: 0.042sec.
# optimization at t = 65 finished, lapse: 0.042sec.
# optimization at t = 66 finished, lapse: 0.041sec.
# optimization at t = 67 finished, lapse: 0.041sec.
# optimization at t = 68 finished, lapse: 0.041sec.
# optimization at t = 69 finished, lapse: 0.042sec.
# optimization at t = 70 finished, lapse: 0.042sec.
# optimization at t = 71 finished, lapse: 0.041sec.
# optimization at t = 72 finished, lapse: 0.041sec.
# optimization at t = 73 finished, lapse: 0.041sec.
# optimization at t = 74 finished, lapse: 0.043sec.
# optimization at t = 75 finished, lapse: 0.041sec.
# optimization at t = 76 finished, lapse: 0.042sec.
# optimization at t = 77 finished, lapse: 0.041sec.
# optimization at t = 78 finished, lapse: 0.041sec.
# optimization at t = 79 finished, lapse: 0.042sec.
# optimization at t = 80 finished, lapse: 0.041sec.
# optimization at t = 81 finished, lapse: 0.041sec.
# optimization at t = 82 finished, lapse: 0.040sec.
# optimization at t = 83 finished, lapse: 0.040sec.
# optimization at t = 84 finished, lapse: 0.043sec.
# optimization at t = 85 finished, lapse: 0.042sec.
# optimization at t = 86 finished, lapse: 0.041sec.
# optimization at t = 87 finished, lapse: 0.041sec.
# optimization at t = 88 finished, lapse: 0.041sec.
# optimization at t = 89 finished, lapse: 0.042sec.
# optimization at t = 90 finished, lapse: 0.041sec.
# optimization at t = 91 finished, lapse: 0.041sec.
# optimization at t = 92 finished, lapse: 0.041sec.
# optimization at t = 93 finished, lapse: 0.041sec.
# optimization at t = 94 finished, lapse: 0.043sec.
# optimization at t = 95 finished, lapse: 0.042sec.
# optimization at t = 96 finished, lapse: 0.041sec.
# optimization at t = 97 finished, lapse: 0.041sec.
# optimization at t = 98 finished, lapse: 0.041sec.
# optimization at t = 99 finished, lapse: 0.043sec.
# optimization at t = 100 finished, lapse: 0.041sec.
# optimization at t = 101 finished, lapse: 0.041sec.
# optimization at t = 102 finished, lapse: 0.041sec.
# optimization at t = 103 finished, lapse: 0.040sec.
# optimization at t = 104 finished, lapse: 0.042sec.
# optimization at t = 105 finished, lapse: 0.041sec.
# optimization at t = 106 finished, lapse: 0.041sec.
# optimization at t = 107 finished, lapse: 0.041sec.
# optimization at t = 108 finished, lapse: 0.040sec.
# optimization at t = 109 finished, lapse: 0.042sec.
# optimization at t = 110 finished, lapse: 0.041sec.
# optimization at t = 111 finished, lapse: 0.040sec.
# optimization at t = 112 finished, lapse: 0.041sec.
# optimization at t = 113 finished, lapse: 0.041sec.
# optimization at t = 114 finished, lapse: 0.042sec.
# optimization at t = 115 finished, lapse: 0.041sec.
# optimization at t = 116 finished, lapse: 0.041sec.
# optimization at t = 117 finished, lapse: 0.041sec.
# optimization at t = 118 finished, lapse: 0.041sec.
# optimization at t = 119 finished, lapse: 0.042sec.
# optimization at t = 120 finished, lapse: 0.042sec.

# %%
plt.plot(R, color='grey')
plt.plot(Rmle)
plt.fill_between(np.arange(T), conf_R[:,0], conf_R[:,1], alpha=0.3)

# %%
p = plt.scatter(*bmle)
freqepid.confidence_ellipse(
    bmle, np.linalg.inv(Ihat_dth)[-2:,-2:], n_std = chi_pa,
    facecolor=p.get_facecolor(), alpha=0.5)
plt.plot(beta_min[:,0], beta_min[:,1])
plt.plot(beta_max[:,0], beta_max[:,1])
#     confidence_ellipse(th_eb[i], Sigmas[i], ax, n_std = chi_pa,
#                        facecolor=p.get_facecolor(), alpha=0.25)
plt.xlabel(r"$\beta_0$"); plt.ylabel(r"$\beta_1$")
# Out:
# Text(0, 0.5, '$\\beta_1$')

# %%
conf_I, _, _ = \
model.confidence_I(A, mmle, bmle, np.linalg.inv(Ihat_dth)[1:,1:], chi_pa,
                    verbose=True)
# Out:
# optimization at t = 1 finished, lapse: 0.422sec.
# optimization at t = 2 finished, lapse: 0.096sec.
# optimization at t = 3 finished, lapse: 0.121sec.
# optimization at t = 4 finished, lapse: 0.162sec.
# optimization at t = 5 finished, lapse: 0.176sec.
# optimization at t = 6 finished, lapse: 0.143sec.
# optimization at t = 7 finished, lapse: 0.087sec.
# optimization at t = 8 finished, lapse: 0.097sec.
# /Users/blueconet/mambaforge/envs/freqepid/lib/python3.10/site-packages/scipy/optimize/_hessian_update_strategy.py:182: UserWarning: delta_grad == 0.0. Check if the approximated function is linear. If the function is linear better results can be obtained by defining the Hessian as zero instead of using quasi-Newton approximations.
#   warn('delta_grad == 0.0. Check if the approximated '
# optimization at t = 9 finished, lapse: 0.109sec.
# optimization at t = 10 finished, lapse: 0.275sec.
# optimization at t = 11 finished, lapse: 0.121sec.
# optimization at t = 12 finished, lapse: 0.142sec.
# optimization at t = 13 finished, lapse: 0.149sec.
# optimization at t = 14 finished, lapse: 0.160sec.
# optimization at t = 15 finished, lapse: 0.192sec.
# optimization at t = 16 finished, lapse: 0.278sec.
# optimization at t = 17 finished, lapse: 0.257sec.
# optimization at t = 18 finished, lapse: 0.189sec.
# optimization at t = 19 finished, lapse: 0.255sec.
# optimization at t = 20 finished, lapse: 0.304sec.
# optimization at t = 21 finished, lapse: 0.292sec.
# optimization at t = 22 finished, lapse: 0.285sec.
# optimization at t = 23 finished, lapse: 0.221sec.
# optimization at t = 24 finished, lapse: 0.232sec.
# optimization at t = 25 finished, lapse: 0.256sec.
# optimization at t = 26 finished, lapse: 0.266sec.
# optimization at t = 27 finished, lapse: 0.282sec.
# optimization at t = 28 finished, lapse: 0.324sec.
# optimization at t = 29 finished, lapse: 0.252sec.
# optimization at t = 30 finished, lapse: 0.221sec.
# optimization at t = 31 finished, lapse: 0.201sec.
# optimization at t = 32 finished, lapse: 0.438sec.
# optimization at t = 33 finished, lapse: 0.207sec.
# optimization at t = 34 finished, lapse: 0.303sec.
# optimization at t = 35 finished, lapse: 0.367sec.
# optimization at t = 36 finished, lapse: 0.362sec.
# optimization at t = 37 finished, lapse: 0.484sec.
# optimization at t = 38 finished, lapse: 1.641sec.
# optimization at t = 39 finished, lapse: 0.320sec.
# optimization at t = 40 finished, lapse: 0.430sec.
# optimization at t = 41 finished, lapse: 0.473sec.
# optimization at t = 42 finished, lapse: 0.446sec.
# optimization at t = 43 finished, lapse: 0.444sec.
# optimization at t = 44 finished, lapse: 0.379sec.
# optimization at t = 45 finished, lapse: 0.362sec.
# optimization at t = 46 finished, lapse: 0.366sec.
# optimization at t = 47 finished, lapse: 0.276sec.
# optimization at t = 48 finished, lapse: 0.336sec.
# optimization at t = 49 finished, lapse: 0.368sec.
# optimization at t = 50 finished, lapse: 0.371sec.
# optimization at t = 51 finished, lapse: 0.448sec.
# optimization at t = 52 finished, lapse: 0.410sec.
# optimization at t = 53 finished, lapse: 0.347sec.
# optimization at t = 54 finished, lapse: 0.428sec.
# optimization at t = 55 finished, lapse: 0.386sec.
# optimization at t = 56 finished, lapse: 0.671sec.
# optimization at t = 57 finished, lapse: 0.586sec.
# optimization at t = 58 finished, lapse: 0.889sec.
# optimization at t = 59 finished, lapse: 0.335sec.
# optimization at t = 60 finished, lapse: 1.594sec.
# optimization at t = 61 finished, lapse: 0.619sec.
# optimization at t = 62 finished, lapse: 0.353sec.
# optimization at t = 63 finished, lapse: 1.633sec.
# optimization at t = 64 finished, lapse: 0.492sec.
# optimization at t = 65 finished, lapse: 1.970sec.
# optimization at t = 66 finished, lapse: 2.041sec.
# optimization at t = 67 finished, lapse: 2.361sec.
# optimization at t = 68 finished, lapse: 1.933sec.
# optimization at t = 69 finished, lapse: 1.881sec.
# optimization at t = 70 finished, lapse: 0.675sec.
# optimization at t = 71 finished, lapse: 0.993sec.
# optimization at t = 72 finished, lapse: 0.949sec.
# optimization at t = 73 finished, lapse: 1.160sec.
# optimization at t = 74 finished, lapse: 0.883sec.
# optimization at t = 75 finished, lapse: 0.791sec.
# optimization at t = 76 finished, lapse: 0.670sec.
# optimization at t = 77 finished, lapse: 0.597sec.
# optimization at t = 78 finished, lapse: 0.733sec.
# optimization at t = 79 finished, lapse: 0.896sec.
# optimization at t = 80 finished, lapse: 0.779sec.
# optimization at t = 81 finished, lapse: 0.777sec.
# optimization at t = 82 finished, lapse: 0.900sec.
# optimization at t = 83 finished, lapse: 0.502sec.
# optimization at t = 84 finished, lapse: 0.732sec.
# optimization at t = 85 finished, lapse: 1.043sec.
# optimization at t = 86 finished, lapse: 1.007sec.
# optimization at t = 87 finished, lapse: 1.228sec.
# optimization at t = 88 finished, lapse: 1.411sec.
# optimization at t = 89 finished, lapse: 0.634sec.
# optimization at t = 90 finished, lapse: 0.826sec.
# optimization at t = 91 finished, lapse: 1.070sec.
# optimization at t = 92 finished, lapse: 0.892sec.
# optimization at t = 93 finished, lapse: 0.731sec.
# optimization at t = 94 finished, lapse: 0.890sec.
# optimization at t = 95 finished, lapse: 0.925sec.
# optimization at t = 96 finished, lapse: 0.730sec.
# optimization at t = 97 finished, lapse: 1.082sec.
# optimization at t = 98 finished, lapse: 0.953sec.
# optimization at t = 99 finished, lapse: 0.971sec.
# optimization at t = 100 finished, lapse: 1.447sec.
# optimization at t = 101 finished, lapse: 1.572sec.
# optimization at t = 102 finished, lapse: 1.308sec.
# optimization at t = 103 finished, lapse: 1.345sec.
# optimization at t = 104 finished, lapse: 4.108sec.
# optimization at t = 105 finished, lapse: 4.826sec.
# optimization at t = 106 finished, lapse: 2.905sec.
# optimization at t = 107 finished, lapse: 3.681sec.
# optimization at t = 108 finished, lapse: 3.001sec.
# optimization at t = 109 finished, lapse: 3.004sec.
# optimization at t = 110 finished, lapse: 2.226sec.
# optimization at t = 111 finished, lapse: 4.329sec.
# optimization at t = 112 finished, lapse: 2.628sec.
# optimization at t = 113 finished, lapse: 3.014sec.
# optimization at t = 114 finished, lapse: 3.837sec.
# optimization at t = 115 finished, lapse: 2.349sec.
# optimization at t = 116 finished, lapse: 3.826sec.
# optimization at t = 117 finished, lapse: 4.059sec.
# optimization at t = 118 finished, lapse: 3.139sec.
# optimization at t = 119 finished, lapse: 3.169sec.
# optimization at t = 120 finished, lapse: 3.615sec.

# %%
plt.figure(figsize = (4,3))
plt.xlabel("time $t$"); plt.ylabel("infection")
plt.bar(np.arange(T), I, color='C1')
plt.plot(Imle)
plt.fill_between(np.arange(T), conf_I[:,0], conf_I[:,1], alpha=0.3)

# %%
conf_EY, theta_min, theta_max = \
model.confidence_EY(A, mmle, bmle, np.linalg.inv(Ihat_dth)[1:,1:], chi_pa,
                    verbose=True)
# Out:
# optimization at t = 1 finished, lapse: 2.193sec.
# optimization at t = 2 finished, lapse: 2.156sec.
# optimization at t = 3 finished, lapse: 1.692sec.
# optimization at t = 4 finished, lapse: 2.098sec.
# optimization at t = 5 finished, lapse: 1.766sec.
# optimization at t = 6 finished, lapse: 1.026sec.
# optimization at t = 7 finished, lapse: 2.141sec.
# optimization at t = 8 finished, lapse: 1.333sec.
# optimization at t = 9 finished, lapse: 1.348sec.
# optimization at t = 10 finished, lapse: 0.506sec.
# optimization at t = 11 finished, lapse: 0.375sec.
# optimization at t = 12 finished, lapse: 0.846sec.
# optimization at t = 13 finished, lapse: 0.499sec.
# optimization at t = 14 finished, lapse: 0.247sec.
# optimization at t = 15 finished, lapse: 0.455sec.
# optimization at t = 16 finished, lapse: 0.459sec.
# optimization at t = 17 finished, lapse: 0.205sec.
# optimization at t = 18 finished, lapse: 0.182sec.
# optimization at t = 19 finished, lapse: 0.174sec.
# optimization at t = 20 finished, lapse: 0.133sec.
# optimization at t = 21 finished, lapse: 0.187sec.
# optimization at t = 22 finished, lapse: 0.175sec.
# optimization at t = 23 finished, lapse: 0.117sec.
# optimization at t = 24 finished, lapse: 0.122sec.
# optimization at t = 25 finished, lapse: 0.140sec.
# optimization at t = 26 finished, lapse: 0.113sec.
# optimization at t = 27 finished, lapse: 0.109sec.
# optimization at t = 28 finished, lapse: 0.103sec.
# optimization at t = 29 finished, lapse: 0.088sec.
# optimization at t = 30 finished, lapse: 0.101sec.
# optimization at t = 31 finished, lapse: 0.085sec.
# optimization at t = 32 finished, lapse: 0.074sec.
# optimization at t = 33 finished, lapse: 0.083sec.
# optimization at t = 34 finished, lapse: 0.823sec.
# optimization at t = 35 finished, lapse: 0.085sec.
# optimization at t = 36 finished, lapse: 0.082sec.
# optimization at t = 37 finished, lapse: 0.197sec.
# optimization at t = 38 finished, lapse: 0.156sec.
# optimization at t = 39 finished, lapse: 0.189sec.
# optimization at t = 40 finished, lapse: 0.172sec.
# optimization at t = 41 finished, lapse: 0.216sec.
# optimization at t = 42 finished, lapse: 0.148sec.
# optimization at t = 43 finished, lapse: 0.247sec.
# optimization at t = 44 finished, lapse: 0.244sec.
# optimization at t = 45 finished, lapse: 0.258sec.
# optimization at t = 46 finished, lapse: 0.235sec.
# optimization at t = 47 finished, lapse: 0.220sec.
# optimization at t = 48 finished, lapse: 0.199sec.
# optimization at t = 49 finished, lapse: 0.326sec.
# optimization at t = 50 finished, lapse: 0.185sec.
# optimization at t = 51 finished, lapse: 0.294sec.
# optimization at t = 52 finished, lapse: 0.248sec.
# optimization at t = 53 finished, lapse: 0.260sec.
# optimization at t = 54 finished, lapse: 0.232sec.
# optimization at t = 55 finished, lapse: 0.293sec.
# optimization at t = 56 finished, lapse: 0.252sec.
# optimization at t = 57 finished, lapse: 0.239sec.
# optimization at t = 58 finished, lapse: 0.271sec.
# optimization at t = 59 finished, lapse: 0.282sec.
# optimization at t = 60 finished, lapse: 0.224sec.
# optimization at t = 61 finished, lapse: 0.282sec.
# optimization at t = 62 finished, lapse: 0.201sec.
# optimization at t = 63 finished, lapse: 0.210sec.
# optimization at t = 64 finished, lapse: 0.220sec.
# optimization at t = 65 finished, lapse: 0.431sec.
# optimization at t = 66 finished, lapse: 0.487sec.
# optimization at t = 67 finished, lapse: 0.493sec.
# optimization at t = 68 finished, lapse: 0.550sec.
# optimization at t = 69 finished, lapse: 0.440sec.
# optimization at t = 70 finished, lapse: 0.282sec.
# optimization at t = 71 finished, lapse: 0.314sec.
# optimization at t = 72 finished, lapse: 0.338sec.
# optimization at t = 73 finished, lapse: 0.626sec.
# optimization at t = 74 finished, lapse: 0.372sec.
# optimization at t = 75 finished, lapse: 0.533sec.
# optimization at t = 76 finished, lapse: 0.441sec.
# optimization at t = 77 finished, lapse: 0.414sec.
# optimization at t = 78 finished, lapse: 0.559sec.
# optimization at t = 79 finished, lapse: 0.503sec.
# optimization at t = 80 finished, lapse: 0.372sec.
# optimization at t = 81 finished, lapse: 0.465sec.
# optimization at t = 82 finished, lapse: 0.529sec.
# optimization at t = 83 finished, lapse: 0.490sec.
# optimization at t = 84 finished, lapse: 0.386sec.
# optimization at t = 85 finished, lapse: 0.601sec.
# optimization at t = 86 finished, lapse: 0.641sec.
# optimization at t = 87 finished, lapse: 0.539sec.
# optimization at t = 88 finished, lapse: 0.379sec.
# optimization at t = 89 finished, lapse: 0.207sec.
# optimization at t = 90 finished, lapse: 0.502sec.
# optimization at t = 91 finished, lapse: 0.457sec.
# optimization at t = 92 finished, lapse: 0.573sec.
# optimization at t = 93 finished, lapse: 0.590sec.
# optimization at t = 94 finished, lapse: 0.495sec.
# optimization at t = 95 finished, lapse: 0.560sec.
# optimization at t = 96 finished, lapse: 0.666sec.
# optimization at t = 97 finished, lapse: 0.501sec.
# optimization at t = 98 finished, lapse: 0.624sec.
# optimization at t = 99 finished, lapse: 0.493sec.
# optimization at t = 100 finished, lapse: 0.499sec.
# optimization at t = 101 finished, lapse: 0.747sec.
# optimization at t = 102 finished, lapse: 0.561sec.
# optimization at t = 103 finished, lapse: 0.583sec.
# optimization at t = 104 finished, lapse: 1.048sec.
# optimization at t = 105 finished, lapse: 1.139sec.
# optimization at t = 106 finished, lapse: 1.298sec.
# optimization at t = 107 finished, lapse: 0.622sec.
# optimization at t = 108 finished, lapse: 0.607sec.
# optimization at t = 109 finished, lapse: 1.174sec.
# optimization at t = 110 finished, lapse: 2.381sec.
# optimization at t = 111 finished, lapse: 0.494sec.
# optimization at t = 112 finished, lapse: 1.083sec.
# optimization at t = 113 finished, lapse: 0.807sec.
# optimization at t = 114 finished, lapse: 0.832sec.
# optimization at t = 115 finished, lapse: 0.754sec.
# optimization at t = 116 finished, lapse: 0.688sec.
# optimization at t = 117 finished, lapse: 0.620sec.
# optimization at t = 118 finished, lapse: 1.071sec.
# optimization at t = 119 finished, lapse: 1.157sec.
# optimization at t = 120 finished, lapse: 0.688sec.

# %%
plt.figure(figsize = (4,3))
plt.xlabel("time $t$"); plt.ylabel("deaths")
plt.bar(np.arange(T), Y, color='C1')
plt.plot(EYmle)
plt.fill_between(np.arange(T), conf_EY[:,0], conf_EY[:,1], alpha=0.3)

# %%
conf_Y = \
model.confidence_Y(A, nmle, mmle, bmle, alpha=0.05, conf_EY=conf_EY)

# %%
plt.bar(np.arange(T), Y, color='C1', alpha=0.5)
plt.plot(EYmle)
plt.fill_between(np.arange(T), conf_Y[:,0], conf_Y[:,1], alpha=0.3)

# %% [markdown]
# # 6. Confidence Interval & Causal forecasting

# %% [markdown]
# ## A = 1

# %%
Tf = 60
Af = np.zeros([Tf, d])

# %%
Af[:,0] = np.full(Tf, 1)
Af[:,1] = np.full(Tf, 1)

# %%
Ae = np.concatenate([A, Af], 0)

# %%
conf_band, beta_min, beta_max = \
model.confidence_R(Ae, bmle, np.linalg.inv(Ihat_dth)[-2:,-2:], chi_pa,
                   verbose=True)
# Out:
# optimization at t = 1 finished, lapse: 0.283sec.
# optimization at t = 2 finished, lapse: 0.163sec.
# optimization at t = 3 finished, lapse: 0.217sec.
# optimization at t = 4 finished, lapse: 0.174sec.
# optimization at t = 5 finished, lapse: 0.199sec.
# optimization at t = 6 finished, lapse: 0.171sec.
# optimization at t = 7 finished, lapse: 0.133sec.
# optimization at t = 8 finished, lapse: 0.198sec.
# optimization at t = 9 finished, lapse: 0.150sec.
# optimization at t = 10 finished, lapse: 0.223sec.
# optimization at t = 11 finished, lapse: 0.197sec.
# optimization at t = 12 finished, lapse: 0.181sec.
# optimization at t = 13 finished, lapse: 0.189sec.
# optimization at t = 14 finished, lapse: 0.164sec.
# optimization at t = 15 finished, lapse: 0.202sec.
# optimization at t = 16 finished, lapse: 0.145sec.
# optimization at t = 17 finished, lapse: 0.215sec.
# optimization at t = 18 finished, lapse: 0.174sec.
# optimization at t = 19 finished, lapse: 0.122sec.
# optimization at t = 20 finished, lapse: 0.197sec.
# optimization at t = 21 finished, lapse: 0.132sec.
# optimization at t = 22 finished, lapse: 0.220sec.
# optimization at t = 23 finished, lapse: 0.164sec.
# optimization at t = 24 finished, lapse: 0.179sec.
# optimization at t = 25 finished, lapse: 0.173sec.
# optimization at t = 26 finished, lapse: 0.148sec.
# optimization at t = 27 finished, lapse: 0.197sec.
# optimization at t = 28 finished, lapse: 0.167sec.
# optimization at t = 29 finished, lapse: 0.225sec.
# optimization at t = 30 finished, lapse: 0.217sec.
# optimization at t = 31 finished, lapse: 0.215sec.
# optimization at t = 32 finished, lapse: 0.062sec.
# optimization at t = 33 finished, lapse: 0.037sec.
# optimization at t = 34 finished, lapse: 0.036sec.
# optimization at t = 35 finished, lapse: 0.037sec.
# optimization at t = 36 finished, lapse: 0.038sec.
# optimization at t = 37 finished, lapse: 0.036sec.
# optimization at t = 38 finished, lapse: 0.037sec.
# optimization at t = 39 finished, lapse: 0.037sec.
# optimization at t = 40 finished, lapse: 0.037sec.
# optimization at t = 41 finished, lapse: 0.037sec.
# optimization at t = 42 finished, lapse: 0.041sec.
# optimization at t = 43 finished, lapse: 0.037sec.
# optimization at t = 44 finished, lapse: 0.036sec.
# optimization at t = 45 finished, lapse: 0.036sec.
# optimization at t = 46 finished, lapse: 0.037sec.
# optimization at t = 47 finished, lapse: 0.037sec.
# optimization at t = 48 finished, lapse: 0.038sec.
# optimization at t = 49 finished, lapse: 0.037sec.
# optimization at t = 50 finished, lapse: 0.037sec.
# optimization at t = 51 finished, lapse: 0.036sec.
# optimization at t = 52 finished, lapse: 0.036sec.
# optimization at t = 53 finished, lapse: 0.036sec.
# optimization at t = 54 finished, lapse: 0.037sec.
# optimization at t = 55 finished, lapse: 0.037sec.
# optimization at t = 56 finished, lapse: 0.036sec.
# optimization at t = 57 finished, lapse: 0.036sec.
# optimization at t = 58 finished, lapse: 0.036sec.
# optimization at t = 59 finished, lapse: 0.037sec.
# optimization at t = 60 finished, lapse: 0.038sec.
# optimization at t = 61 finished, lapse: 0.038sec.
# optimization at t = 62 finished, lapse: 0.037sec.
# optimization at t = 63 finished, lapse: 0.039sec.
# optimization at t = 64 finished, lapse: 0.036sec.
# optimization at t = 65 finished, lapse: 0.038sec.
# optimization at t = 66 finished, lapse: 0.041sec.
# optimization at t = 67 finished, lapse: 0.038sec.
# optimization at t = 68 finished, lapse: 0.036sec.
# optimization at t = 69 finished, lapse: 0.036sec.
# optimization at t = 70 finished, lapse: 0.037sec.
# optimization at t = 71 finished, lapse: 0.036sec.
# optimization at t = 72 finished, lapse: 0.039sec.
# optimization at t = 73 finished, lapse: 0.037sec.
# optimization at t = 74 finished, lapse: 0.036sec.
# optimization at t = 75 finished, lapse: 0.036sec.
# optimization at t = 76 finished, lapse: 0.037sec.
# optimization at t = 77 finished, lapse: 0.036sec.
# optimization at t = 78 finished, lapse: 0.039sec.
# optimization at t = 79 finished, lapse: 0.036sec.
# optimization at t = 80 finished, lapse: 0.036sec.
# optimization at t = 81 finished, lapse: 0.036sec.
# optimization at t = 82 finished, lapse: 0.036sec.
# optimization at t = 83 finished, lapse: 0.036sec.
# optimization at t = 84 finished, lapse: 0.038sec.
# optimization at t = 85 finished, lapse: 0.037sec.
# optimization at t = 86 finished, lapse: 0.037sec.
# optimization at t = 87 finished, lapse: 0.036sec.
# optimization at t = 88 finished, lapse: 0.036sec.
# optimization at t = 89 finished, lapse: 0.036sec.
# optimization at t = 90 finished, lapse: 0.038sec.
# optimization at t = 91 finished, lapse: 0.037sec.
# optimization at t = 92 finished, lapse: 0.037sec.
# optimization at t = 93 finished, lapse: 0.037sec.
# optimization at t = 94 finished, lapse: 0.037sec.
# optimization at t = 95 finished, lapse: 0.038sec.
# optimization at t = 96 finished, lapse: 0.040sec.
# optimization at t = 97 finished, lapse: 0.038sec.
# optimization at t = 98 finished, lapse: 0.037sec.
# optimization at t = 99 finished, lapse: 0.038sec.
# optimization at t = 100 finished, lapse: 0.037sec.
# optimization at t = 101 finished, lapse: 0.037sec.
# optimization at t = 102 finished, lapse: 0.038sec.
# optimization at t = 103 finished, lapse: 0.037sec.
# optimization at t = 104 finished, lapse: 0.036sec.
# optimization at t = 105 finished, lapse: 0.036sec.
# optimization at t = 106 finished, lapse: 0.037sec.
# optimization at t = 107 finished, lapse: 0.037sec.
# optimization at t = 108 finished, lapse: 0.037sec.
# optimization at t = 109 finished, lapse: 0.037sec.
# optimization at t = 110 finished, lapse: 0.036sec.
# optimization at t = 111 finished, lapse: 0.036sec.
# optimization at t = 112 finished, lapse: 0.037sec.
# optimization at t = 113 finished, lapse: 0.036sec.
# optimization at t = 114 finished, lapse: 0.039sec.
# optimization at t = 115 finished, lapse: 0.037sec.
# optimization at t = 116 finished, lapse: 0.036sec.
# optimization at t = 117 finished, lapse: 0.036sec.
# optimization at t = 118 finished, lapse: 0.036sec.
# optimization at t = 119 finished, lapse: 0.038sec.
# optimization at t = 120 finished, lapse: 0.038sec.
# optimization at t = 121 finished, lapse: 0.039sec.
# optimization at t = 122 finished, lapse: 0.038sec.
# optimization at t = 123 finished, lapse: 0.037sec.
# optimization at t = 124 finished, lapse: 0.037sec.
# optimization at t = 125 finished, lapse: 0.038sec.
# optimization at t = 126 finished, lapse: 0.039sec.
# optimization at t = 127 finished, lapse: 0.037sec.
# optimization at t = 128 finished, lapse: 0.036sec.
# optimization at t = 129 finished, lapse: 0.036sec.
# optimization at t = 130 finished, lapse: 0.036sec.
# optimization at t = 131 finished, lapse: 0.036sec.
# optimization at t = 132 finished, lapse: 0.036sec.
# optimization at t = 133 finished, lapse: 0.037sec.
# optimization at t = 134 finished, lapse: 0.036sec.
# optimization at t = 135 finished, lapse: 0.036sec.
# optimization at t = 136 finished, lapse: 0.037sec.
# optimization at t = 137 finished, lapse: 0.036sec.
# optimization at t = 138 finished, lapse: 0.038sec.
# optimization at t = 139 finished, lapse: 0.037sec.
# optimization at t = 140 finished, lapse: 0.036sec.
# optimization at t = 141 finished, lapse: 0.037sec.
# optimization at t = 142 finished, lapse: 0.037sec.
# optimization at t = 143 finished, lapse: 0.037sec.
# optimization at t = 144 finished, lapse: 0.037sec.
# optimization at t = 145 finished, lapse: 0.036sec.
# optimization at t = 146 finished, lapse: 0.037sec.
# optimization at t = 147 finished, lapse: 0.037sec.
# optimization at t = 148 finished, lapse: 0.036sec.
# optimization at t = 149 finished, lapse: 0.036sec.
# optimization at t = 150 finished, lapse: 0.040sec.
# optimization at t = 151 finished, lapse: 0.039sec.
# optimization at t = 152 finished, lapse: 0.036sec.
# optimization at t = 153 finished, lapse: 0.036sec.
# optimization at t = 154 finished, lapse: 0.037sec.
# optimization at t = 155 finished, lapse: 0.037sec.
# optimization at t = 156 finished, lapse: 0.037sec.
# optimization at t = 157 finished, lapse: 0.036sec.
# optimization at t = 158 finished, lapse: 0.037sec.
# optimization at t = 159 finished, lapse: 0.038sec.
# optimization at t = 160 finished, lapse: 0.037sec.
# optimization at t = 161 finished, lapse: 0.037sec.
# optimization at t = 162 finished, lapse: 0.038sec.
# optimization at t = 163 finished, lapse: 0.038sec.
# optimization at t = 164 finished, lapse: 0.037sec.
# optimization at t = 165 finished, lapse: 0.037sec.
# optimization at t = 166 finished, lapse: 0.037sec.
# optimization at t = 167 finished, lapse: 0.035sec.
# optimization at t = 168 finished, lapse: 0.036sec.
# optimization at t = 169 finished, lapse: 0.036sec.
# optimization at t = 170 finished, lapse: 0.035sec.
# optimization at t = 171 finished, lapse: 0.037sec.
# optimization at t = 172 finished, lapse: 0.036sec.
# optimization at t = 173 finished, lapse: 0.038sec.
# optimization at t = 174 finished, lapse: 0.039sec.
# optimization at t = 175 finished, lapse: 0.037sec.
# optimization at t = 176 finished, lapse: 0.036sec.
# optimization at t = 177 finished, lapse: 0.037sec.
# optimization at t = 178 finished, lapse: 0.037sec.
# optimization at t = 179 finished, lapse: 0.037sec.
# optimization at t = 180 finished, lapse: 0.039sec.

# %%
plt.plot(R, color='grey')
plt.plot(model.predict_R(Ae, bmle))
plt.fill_between(np.arange(np.shape(conf_band)[0]),
                 conf_band[:,0], conf_band[:,1], alpha=0.3)

# %%
conf_band, theta_min, theta_max = \
model.confidence_I(Ae, mmle, bmle, np.linalg.inv(Ihat_dth)[1:,1:], chi_pa,
                    verbose=True)
# Out:
# optimization at t = 1 finished, lapse: 0.389sec.
# optimization at t = 2 finished, lapse: 0.095sec.
# optimization at t = 3 finished, lapse: 0.109sec.
# optimization at t = 4 finished, lapse: 0.143sec.
# optimization at t = 5 finished, lapse: 0.156sec.
# optimization at t = 6 finished, lapse: 0.126sec.
# optimization at t = 7 finished, lapse: 0.077sec.
# optimization at t = 8 finished, lapse: 0.086sec.
# optimization at t = 9 finished, lapse: 0.094sec.
# optimization at t = 10 finished, lapse: 0.245sec.
# optimization at t = 11 finished, lapse: 0.107sec.
# optimization at t = 12 finished, lapse: 0.127sec.
# optimization at t = 13 finished, lapse: 0.131sec.
# optimization at t = 14 finished, lapse: 0.142sec.
# optimization at t = 15 finished, lapse: 0.175sec.
# optimization at t = 16 finished, lapse: 0.247sec.
# optimization at t = 17 finished, lapse: 0.227sec.
# optimization at t = 18 finished, lapse: 0.167sec.
# optimization at t = 19 finished, lapse: 0.230sec.
# optimization at t = 20 finished, lapse: 0.270sec.
# optimization at t = 21 finished, lapse: 0.249sec.
# optimization at t = 22 finished, lapse: 0.251sec.
# optimization at t = 23 finished, lapse: 0.191sec.
# optimization at t = 24 finished, lapse: 0.198sec.
# optimization at t = 25 finished, lapse: 0.235sec.
# optimization at t = 26 finished, lapse: 0.232sec.
# optimization at t = 27 finished, lapse: 0.252sec.
# optimization at t = 28 finished, lapse: 0.285sec.
# optimization at t = 29 finished, lapse: 0.214sec.
# optimization at t = 30 finished, lapse: 0.197sec.
# optimization at t = 31 finished, lapse: 0.200sec.
# optimization at t = 32 finished, lapse: 0.413sec.
# optimization at t = 33 finished, lapse: 0.205sec.
# optimization at t = 34 finished, lapse: 0.276sec.
# optimization at t = 35 finished, lapse: 0.314sec.
# optimization at t = 36 finished, lapse: 0.311sec.
# optimization at t = 37 finished, lapse: 0.419sec.
# optimization at t = 38 finished, lapse: 1.440sec.
# optimization at t = 39 finished, lapse: 0.298sec.
# optimization at t = 40 finished, lapse: 0.376sec.
# optimization at t = 41 finished, lapse: 0.417sec.
# optimization at t = 42 finished, lapse: 0.389sec.
# optimization at t = 43 finished, lapse: 0.398sec.
# optimization at t = 44 finished, lapse: 0.332sec.
# optimization at t = 45 finished, lapse: 0.323sec.
# optimization at t = 46 finished, lapse: 0.332sec.
# optimization at t = 47 finished, lapse: 0.256sec.
# optimization at t = 48 finished, lapse: 0.302sec.
# optimization at t = 49 finished, lapse: 0.323sec.
# optimization at t = 50 finished, lapse: 0.325sec.
# optimization at t = 51 finished, lapse: 0.391sec.
# optimization at t = 52 finished, lapse: 0.363sec.
# optimization at t = 53 finished, lapse: 0.304sec.
# optimization at t = 54 finished, lapse: 0.376sec.
# optimization at t = 55 finished, lapse: 0.340sec.
# optimization at t = 56 finished, lapse: 0.590sec.
# optimization at t = 57 finished, lapse: 0.520sec.
# optimization at t = 58 finished, lapse: 0.778sec.
# optimization at t = 59 finished, lapse: 0.295sec.
# optimization at t = 60 finished, lapse: 1.411sec.
# optimization at t = 61 finished, lapse: 0.543sec.
# optimization at t = 62 finished, lapse: 0.318sec.
# optimization at t = 63 finished, lapse: 1.432sec.
# optimization at t = 64 finished, lapse: 0.426sec.
# optimization at t = 65 finished, lapse: 1.681sec.
# optimization at t = 66 finished, lapse: 1.667sec.
# optimization at t = 67 finished, lapse: 1.909sec.
# optimization at t = 68 finished, lapse: 1.512sec.
# optimization at t = 69 finished, lapse: 1.513sec.
# optimization at t = 70 finished, lapse: 0.506sec.
# optimization at t = 71 finished, lapse: 0.791sec.
# optimization at t = 72 finished, lapse: 0.752sec.
# optimization at t = 73 finished, lapse: 0.920sec.
# optimization at t = 74 finished, lapse: 0.706sec.
# optimization at t = 75 finished, lapse: 0.643sec.
# optimization at t = 76 finished, lapse: 0.548sec.
# optimization at t = 77 finished, lapse: 0.463sec.
# optimization at t = 78 finished, lapse: 0.540sec.
# optimization at t = 79 finished, lapse: 0.697sec.
# optimization at t = 80 finished, lapse: 0.631sec.
# optimization at t = 81 finished, lapse: 0.617sec.
# optimization at t = 82 finished, lapse: 0.707sec.
# optimization at t = 83 finished, lapse: 0.412sec.
# optimization at t = 84 finished, lapse: 0.575sec.
# optimization at t = 85 finished, lapse: 0.812sec.
# optimization at t = 86 finished, lapse: 0.832sec.
# optimization at t = 87 finished, lapse: 0.942sec.
# optimization at t = 88 finished, lapse: 1.138sec.
# optimization at t = 89 finished, lapse: 0.510sec.
# optimization at t = 90 finished, lapse: 0.662sec.
# optimization at t = 91 finished, lapse: 0.858sec.
# optimization at t = 92 finished, lapse: 0.706sec.
# optimization at t = 93 finished, lapse: 0.599sec.
# optimization at t = 94 finished, lapse: 0.702sec.
# optimization at t = 95 finished, lapse: 0.720sec.
# optimization at t = 96 finished, lapse: 0.576sec.
# optimization at t = 97 finished, lapse: 0.857sec.
# optimization at t = 98 finished, lapse: 0.755sec.
# optimization at t = 99 finished, lapse: 0.740sec.
# optimization at t = 100 finished, lapse: 0.822sec.
# optimization at t = 101 finished, lapse: 0.975sec.
# optimization at t = 102 finished, lapse: 0.793sec.
# optimization at t = 103 finished, lapse: 0.709sec.
# optimization at t = 104 finished, lapse: 7.052sec.
# optimization at t = 105 finished, lapse: 7.989sec.
# optimization at t = 106 finished, lapse: 6.232sec.
# optimization at t = 107 finished, lapse: 4.743sec.
# optimization at t = 108 finished, lapse: 4.901sec.
# optimization at t = 109 finished, lapse: 5.053sec.
# optimization at t = 110 finished, lapse: 4.467sec.
# optimization at t = 111 finished, lapse: 8.320sec.
# optimization at t = 112 finished, lapse: 4.752sec.
# optimization at t = 113 finished, lapse: 3.226sec.
# optimization at t = 114 finished, lapse: 6.475sec.
# optimization at t = 115 finished, lapse: 4.251sec.
# optimization at t = 116 finished, lapse: 7.419sec.
# optimization at t = 117 finished, lapse: 7.357sec.
# optimization at t = 118 finished, lapse: 3.895sec.
# optimization at t = 119 finished, lapse: 6.219sec.
# optimization at t = 120 finished, lapse: 6.936sec.
# optimization at t = 121 finished, lapse: 5.838sec.
# optimization at t = 122 finished, lapse: 6.160sec.
# optimization at t = 123 finished, lapse: 6.559sec.
# optimization at t = 124 finished, lapse: 4.258sec.
# optimization at t = 125 finished, lapse: 4.631sec.
# optimization at t = 126 finished, lapse: 7.321sec.
# optimization at t = 127 finished, lapse: 4.054sec.
# optimization at t = 128 finished, lapse: 4.885sec.
# optimization at t = 129 finished, lapse: 2.623sec.
# optimization at t = 130 finished, lapse: 3.540sec.
# optimization at t = 131 finished, lapse: 8.547sec.
# optimization at t = 132 finished, lapse: 5.937sec.
# optimization at t = 133 finished, lapse: 4.245sec.
# optimization at t = 134 finished, lapse: 4.723sec.
# optimization at t = 135 finished, lapse: 3.519sec.
# optimization at t = 136 finished, lapse: 6.832sec.
# optimization at t = 137 finished, lapse: 2.152sec.
# optimization at t = 138 finished, lapse: 4.571sec.
# optimization at t = 139 finished, lapse: 1.774sec.
# optimization at t = 140 finished, lapse: 3.869sec.
# optimization at t = 141 finished, lapse: 5.192sec.
# optimization at t = 142 finished, lapse: 6.441sec.
# optimization at t = 143 finished, lapse: 1.572sec.
# optimization at t = 144 finished, lapse: 2.442sec.
# optimization at t = 145 finished, lapse: 2.893sec.
# optimization at t = 146 finished, lapse: 4.718sec.
# optimization at t = 147 finished, lapse: 2.845sec.
# optimization at t = 148 finished, lapse: 1.995sec.
# optimization at t = 149 finished, lapse: 4.972sec.
# optimization at t = 150 finished, lapse: 5.431sec.
# optimization at t = 151 finished, lapse: 3.327sec.
# optimization at t = 152 finished, lapse: 2.210sec.
# optimization at t = 153 finished, lapse: 1.765sec.
# optimization at t = 154 finished, lapse: 3.774sec.
# optimization at t = 155 finished, lapse: 6.729sec.
# optimization at t = 156 finished, lapse: 2.689sec.
# optimization at t = 157 finished, lapse: 6.026sec.
# optimization at t = 158 finished, lapse: 7.138sec.
# optimization at t = 159 finished, lapse: 6.514sec.
# optimization at t = 160 finished, lapse: 6.762sec.
# optimization at t = 161 finished, lapse: 6.389sec.
# optimization at t = 162 finished, lapse: 6.824sec.
# optimization at t = 163 finished, lapse: 5.023sec.
# optimization at t = 164 finished, lapse: 7.082sec.
# optimization at t = 165 finished, lapse: 6.454sec.
# optimization at t = 166 finished, lapse: 8.660sec.
# optimization at t = 167 finished, lapse: 3.631sec.
# optimization at t = 168 finished, lapse: 7.262sec.
# optimization at t = 169 finished, lapse: 1.827sec.
# optimization at t = 170 finished, lapse: 6.943sec.
# optimization at t = 171 finished, lapse: 6.145sec.
# optimization at t = 172 finished, lapse: 3.461sec.
# optimization at t = 173 finished, lapse: 2.903sec.
# optimization at t = 174 finished, lapse: 6.025sec.
# optimization at t = 175 finished, lapse: 6.381sec.
# optimization at t = 176 finished, lapse: 2.532sec.
# optimization at t = 177 finished, lapse: 2.916sec.
# optimization at t = 178 finished, lapse: 12.361sec.
# optimization at t = 179 finished, lapse: 21.287sec.
# optimization at t = 180 finished, lapse: 10.495sec.

# %%
plt.bar(np.arange(T), I, color='grey', alpha=0.5)
plt.plot(model.predict_I(Ae, mmle, bmle))
plt.fill_between(np.arange(np.shape(conf_band)[0]),
                 conf_band[:,0], conf_band[:,1], alpha=0.3)

# %%
conf_band, theta_min, theta_max = \
model.confidence_EY(Ae, mmle, bmle, np.linalg.inv(Ihat_dth)[1:,1:], chi_pa,
                    verbose=True)
# Out:
# optimization at t = 1 finished, lapse: 1.295sec.
# optimization at t = 2 finished, lapse: 1.688sec.
# optimization at t = 3 finished, lapse: 1.492sec.
# optimization at t = 4 finished, lapse: 1.834sec.
# optimization at t = 5 finished, lapse: 1.688sec.
# optimization at t = 6 finished, lapse: 0.892sec.
# optimization at t = 7 finished, lapse: 1.865sec.
# optimization at t = 8 finished, lapse: 1.176sec.
# optimization at t = 9 finished, lapse: 1.464sec.
# optimization at t = 10 finished, lapse: 0.446sec.
# optimization at t = 11 finished, lapse: 0.334sec.
# optimization at t = 12 finished, lapse: 0.750sec.
# optimization at t = 13 finished, lapse: 0.439sec.
# optimization at t = 14 finished, lapse: 0.215sec.
# optimization at t = 15 finished, lapse: 0.450sec.
# optimization at t = 16 finished, lapse: 0.398sec.
# optimization at t = 17 finished, lapse: 0.180sec.
# optimization at t = 18 finished, lapse: 0.166sec.
# optimization at t = 19 finished, lapse: 0.153sec.
# optimization at t = 20 finished, lapse: 0.116sec.
# optimization at t = 21 finished, lapse: 0.161sec.
# optimization at t = 22 finished, lapse: 0.152sec.
# optimization at t = 23 finished, lapse: 0.103sec.
# optimization at t = 24 finished, lapse: 0.106sec.
# optimization at t = 25 finished, lapse: 0.123sec.
# optimization at t = 26 finished, lapse: 0.100sec.
# optimization at t = 27 finished, lapse: 0.095sec.
# optimization at t = 28 finished, lapse: 0.090sec.
# optimization at t = 29 finished, lapse: 0.078sec.
# optimization at t = 30 finished, lapse: 0.088sec.
# optimization at t = 31 finished, lapse: 0.076sec.
# optimization at t = 32 finished, lapse: 0.064sec.
# optimization at t = 33 finished, lapse: 0.071sec.
# optimization at t = 34 finished, lapse: 0.723sec.
# optimization at t = 35 finished, lapse: 0.073sec.
# optimization at t = 36 finished, lapse: 0.072sec.
# optimization at t = 37 finished, lapse: 0.173sec.
# optimization at t = 38 finished, lapse: 0.137sec.
# optimization at t = 39 finished, lapse: 0.166sec.
# optimization at t = 40 finished, lapse: 0.150sec.
# optimization at t = 41 finished, lapse: 0.187sec.
# optimization at t = 42 finished, lapse: 0.132sec.
# optimization at t = 43 finished, lapse: 0.216sec.
# optimization at t = 44 finished, lapse: 0.214sec.
# optimization at t = 45 finished, lapse: 0.225sec.
# optimization at t = 46 finished, lapse: 0.205sec.
# optimization at t = 47 finished, lapse: 0.193sec.
# optimization at t = 48 finished, lapse: 0.175sec.
# optimization at t = 49 finished, lapse: 0.286sec.
# optimization at t = 50 finished, lapse: 0.250sec.
# optimization at t = 51 finished, lapse: 0.278sec.
# optimization at t = 52 finished, lapse: 0.239sec.
# optimization at t = 53 finished, lapse: 0.245sec.
# optimization at t = 54 finished, lapse: 0.210sec.
# optimization at t = 55 finished, lapse: 0.259sec.
# optimization at t = 56 finished, lapse: 0.309sec.
# optimization at t = 57 finished, lapse: 0.220sec.
# optimization at t = 58 finished, lapse: 0.239sec.
# optimization at t = 59 finished, lapse: 0.245sec.
# optimization at t = 60 finished, lapse: 0.197sec.
# optimization at t = 61 finished, lapse: 0.325sec.
# optimization at t = 62 finished, lapse: 0.232sec.
# optimization at t = 63 finished, lapse: 0.245sec.
# optimization at t = 64 finished, lapse: 0.257sec.
# optimization at t = 65 finished, lapse: 0.394sec.
# optimization at t = 66 finished, lapse: 0.423sec.
# optimization at t = 67 finished, lapse: 0.419sec.
# optimization at t = 68 finished, lapse: 0.466sec.
# optimization at t = 69 finished, lapse: 0.384sec.
# optimization at t = 70 finished, lapse: 0.237sec.
# optimization at t = 71 finished, lapse: 0.271sec.
# optimization at t = 72 finished, lapse: 0.297sec.
# optimization at t = 73 finished, lapse: 0.534sec.
# optimization at t = 74 finished, lapse: 0.322sec.
# optimization at t = 75 finished, lapse: 0.469sec.
# optimization at t = 76 finished, lapse: 0.381sec.
# optimization at t = 77 finished, lapse: 0.363sec.
# optimization at t = 78 finished, lapse: 0.489sec.
# optimization at t = 79 finished, lapse: 0.430sec.
# optimization at t = 80 finished, lapse: 0.325sec.
# optimization at t = 81 finished, lapse: 0.404sec.
# optimization at t = 82 finished, lapse: 0.469sec.
# optimization at t = 83 finished, lapse: 0.434sec.
# optimization at t = 84 finished, lapse: 0.336sec.
# optimization at t = 85 finished, lapse: 0.566sec.
# optimization at t = 86 finished, lapse: 0.649sec.
# optimization at t = 87 finished, lapse: 0.510sec.
# optimization at t = 88 finished, lapse: 0.304sec.
# optimization at t = 89 finished, lapse: 0.158sec.
# optimization at t = 90 finished, lapse: 0.385sec.
# optimization at t = 91 finished, lapse: 0.356sec.
# optimization at t = 92 finished, lapse: 0.432sec.
# optimization at t = 93 finished, lapse: 0.465sec.
# optimization at t = 94 finished, lapse: 0.381sec.
# optimization at t = 95 finished, lapse: 0.443sec.
# optimization at t = 96 finished, lapse: 0.535sec.
# optimization at t = 97 finished, lapse: 0.377sec.
# optimization at t = 98 finished, lapse: 0.515sec.
# optimization at t = 99 finished, lapse: 0.406sec.
# optimization at t = 100 finished, lapse: 0.389sec.
# optimization at t = 101 finished, lapse: 0.689sec.
# optimization at t = 102 finished, lapse: 0.476sec.
# optimization at t = 103 finished, lapse: 0.477sec.
# optimization at t = 104 finished, lapse: 3.271sec.
# optimization at t = 105 finished, lapse: 3.652sec.
# optimization at t = 106 finished, lapse: 3.502sec.
# optimization at t = 107 finished, lapse: 1.612sec.
# optimization at t = 108 finished, lapse: 2.107sec.
# optimization at t = 109 finished, lapse: 3.220sec.
# optimization at t = 110 finished, lapse: 6.785sec.
# optimization at t = 111 finished, lapse: 1.695sec.
# optimization at t = 112 finished, lapse: 1.925sec.
# optimization at t = 113 finished, lapse: 2.412sec.
# optimization at t = 114 finished, lapse: 3.161sec.
# optimization at t = 115 finished, lapse: 1.927sec.
# optimization at t = 116 finished, lapse: 2.257sec.
# optimization at t = 117 finished, lapse: 1.919sec.
# optimization at t = 118 finished, lapse: 4.122sec.
# optimization at t = 119 finished, lapse: 2.221sec.
# optimization at t = 120 finished, lapse: 1.543sec.
# optimization at t = 121 finished, lapse: 1.657sec.
# optimization at t = 122 finished, lapse: 1.980sec.
# optimization at t = 123 finished, lapse: 1.615sec.
# optimization at t = 124 finished, lapse: 1.553sec.
# optimization at t = 125 finished, lapse: 5.857sec.
# optimization at t = 126 finished, lapse: 1.805sec.
# optimization at t = 127 finished, lapse: 3.047sec.
# optimization at t = 128 finished, lapse: 1.975sec.
# optimization at t = 129 finished, lapse: 6.338sec.
# optimization at t = 130 finished, lapse: 2.735sec.
# optimization at t = 131 finished, lapse: 6.700sec.
# optimization at t = 132 finished, lapse: 1.184sec.
# optimization at t = 133 finished, lapse: 1.038sec.
# optimization at t = 134 finished, lapse: 1.641sec.
# optimization at t = 135 finished, lapse: 1.339sec.
# optimization at t = 136 finished, lapse: 1.155sec.
# optimization at t = 137 finished, lapse: 3.809sec.
# optimization at t = 138 finished, lapse: 3.411sec.
# optimization at t = 139 finished, lapse: 1.260sec.
# optimization at t = 140 finished, lapse: 1.247sec.
# optimization at t = 141 finished, lapse: 1.524sec.
# optimization at t = 142 finished, lapse: 1.564sec.
# optimization at t = 143 finished, lapse: 1.490sec.
# optimization at t = 144 finished, lapse: 1.545sec.
# optimization at t = 145 finished, lapse: 1.520sec.
# optimization at t = 146 finished, lapse: 1.575sec.
# optimization at t = 147 finished, lapse: 1.671sec.
# optimization at t = 148 finished, lapse: 1.521sec.
# optimization at t = 149 finished, lapse: 1.332sec.
# optimization at t = 150 finished, lapse: 1.298sec.
# optimization at t = 151 finished, lapse: 1.383sec.
# optimization at t = 152 finished, lapse: 1.273sec.
# optimization at t = 153 finished, lapse: 1.059sec.
# optimization at t = 154 finished, lapse: 1.630sec.
# optimization at t = 155 finished, lapse: 2.635sec.
# optimization at t = 156 finished, lapse: 2.916sec.
# optimization at t = 157 finished, lapse: 2.461sec.
# optimization at t = 158 finished, lapse: 2.557sec.
# optimization at t = 159 finished, lapse: 2.866sec.
# optimization at t = 160 finished, lapse: 32.891sec.
# optimization at t = 161 finished, lapse: 3.318sec.
# optimization at t = 162 finished, lapse: 10.245sec.
# optimization at t = 163 finished, lapse: 11.931sec.
# optimization at t = 164 finished, lapse: 3.315sec.
# optimization at t = 165 finished, lapse: 2.648sec.
# optimization at t = 166 finished, lapse: 3.381sec.
# optimization at t = 167 finished, lapse: 3.308sec.
# optimization at t = 168 finished, lapse: 3.852sec.
# optimization at t = 169 finished, lapse: 4.256sec.
# optimization at t = 170 finished, lapse: 3.424sec.
# optimization at t = 171 finished, lapse: 3.335sec.
# optimization at t = 172 finished, lapse: 11.177sec.
# optimization at t = 173 finished, lapse: 14.391sec.
# optimization at t = 174 finished, lapse: 1.436sec.
# optimization at t = 175 finished, lapse: 2.647sec.
# optimization at t = 176 finished, lapse: 3.174sec.
# optimization at t = 177 finished, lapse: 8.861sec.
# optimization at t = 178 finished, lapse: 5.599sec.
# optimization at t = 179 finished, lapse: 7.264sec.
# optimization at t = 180 finished, lapse: 6.650sec.

# %%
plt.bar(np.arange(T), Y, color='grey', alpha=0.5)
plt.plot(model.predict_EY(Ae, mmle, bmle))
plt.fill_between(np.arange(np.shape(conf_band)[0]),
                 conf_band[:,0], conf_band[:,1], alpha=0.3)

# %% [markdown]
# ## A = 0.5

# %%
Tf = 60
Af = np.zeros([Tf, d])

# %%
Af[:,0] = np.full(Tf, 1)
Af[:,1] = np.full(Tf, 0.5)

# %%
Ae = np.concatenate([A, Af], 0)

# %%
conf_band, beta_min, beta_max = \
model.confidence_R(Ae, bmle, np.linalg.inv(Ihat_dth)[-2:,-2:], chi_pa,
                   verbose=True)
# Out:
# optimization at t = 1 finished, lapse: 0.290sec.
# optimization at t = 2 finished, lapse: 0.163sec.
# optimization at t = 3 finished, lapse: 0.219sec.
# optimization at t = 4 finished, lapse: 0.163sec.
# optimization at t = 5 finished, lapse: 0.180sec.
# optimization at t = 6 finished, lapse: 0.172sec.
# optimization at t = 7 finished, lapse: 0.130sec.
# optimization at t = 8 finished, lapse: 0.197sec.
# optimization at t = 9 finished, lapse: 0.147sec.
# optimization at t = 10 finished, lapse: 0.218sec.
# optimization at t = 11 finished, lapse: 0.199sec.
# optimization at t = 12 finished, lapse: 0.185sec.
# optimization at t = 13 finished, lapse: 0.190sec.
# optimization at t = 14 finished, lapse: 0.164sec.
# optimization at t = 15 finished, lapse: 0.211sec.
# optimization at t = 16 finished, lapse: 0.194sec.
# optimization at t = 17 finished, lapse: 0.288sec.
# optimization at t = 18 finished, lapse: 0.320sec.
# optimization at t = 19 finished, lapse: 0.184sec.
# optimization at t = 20 finished, lapse: 0.239sec.
# optimization at t = 21 finished, lapse: 0.124sec.
# optimization at t = 22 finished, lapse: 0.214sec.
# optimization at t = 23 finished, lapse: 0.162sec.
# optimization at t = 24 finished, lapse: 0.179sec.
# optimization at t = 25 finished, lapse: 0.175sec.
# optimization at t = 26 finished, lapse: 0.147sec.
# optimization at t = 27 finished, lapse: 0.194sec.
# optimization at t = 28 finished, lapse: 0.164sec.
# optimization at t = 29 finished, lapse: 0.224sec.
# optimization at t = 30 finished, lapse: 0.181sec.
# optimization at t = 31 finished, lapse: 0.214sec.
# optimization at t = 32 finished, lapse: 0.062sec.
# optimization at t = 33 finished, lapse: 0.036sec.
# optimization at t = 34 finished, lapse: 0.037sec.
# optimization at t = 35 finished, lapse: 0.037sec.
# optimization at t = 36 finished, lapse: 0.037sec.
# optimization at t = 37 finished, lapse: 0.037sec.
# optimization at t = 38 finished, lapse: 0.037sec.
# optimization at t = 39 finished, lapse: 0.036sec.
# optimization at t = 40 finished, lapse: 0.036sec.
# optimization at t = 41 finished, lapse: 0.036sec.
# optimization at t = 42 finished, lapse: 0.037sec.
# optimization at t = 43 finished, lapse: 0.037sec.
# optimization at t = 44 finished, lapse: 0.037sec.
# optimization at t = 45 finished, lapse: 0.036sec.
# optimization at t = 46 finished, lapse: 0.037sec.
# optimization at t = 47 finished, lapse: 0.037sec.
# optimization at t = 48 finished, lapse: 0.039sec.
# optimization at t = 49 finished, lapse: 0.037sec.
# optimization at t = 50 finished, lapse: 0.036sec.
# optimization at t = 51 finished, lapse: 0.037sec.
# optimization at t = 52 finished, lapse: 0.036sec.
# optimization at t = 53 finished, lapse: 0.037sec.
# optimization at t = 54 finished, lapse: 0.038sec.
# optimization at t = 55 finished, lapse: 0.037sec.
# optimization at t = 56 finished, lapse: 0.037sec.
# optimization at t = 57 finished, lapse: 0.037sec.
# optimization at t = 58 finished, lapse: 0.036sec.
# optimization at t = 59 finished, lapse: 0.036sec.
# optimization at t = 60 finished, lapse: 0.037sec.
# optimization at t = 61 finished, lapse: 0.038sec.
# optimization at t = 62 finished, lapse: 0.037sec.
# optimization at t = 63 finished, lapse: 0.036sec.
# optimization at t = 64 finished, lapse: 0.037sec.
# optimization at t = 65 finished, lapse: 0.036sec.
# optimization at t = 66 finished, lapse: 0.038sec.
# optimization at t = 67 finished, lapse: 0.038sec.
# optimization at t = 68 finished, lapse: 0.036sec.
# optimization at t = 69 finished, lapse: 0.036sec.
# optimization at t = 70 finished, lapse: 0.038sec.
# optimization at t = 71 finished, lapse: 0.036sec.
# optimization at t = 72 finished, lapse: 0.041sec.
# optimization at t = 73 finished, lapse: 0.038sec.
# optimization at t = 74 finished, lapse: 0.037sec.
# optimization at t = 75 finished, lapse: 0.037sec.
# optimization at t = 76 finished, lapse: 0.037sec.
# optimization at t = 77 finished, lapse: 0.036sec.
# optimization at t = 78 finished, lapse: 0.036sec.
# optimization at t = 79 finished, lapse: 0.037sec.
# optimization at t = 80 finished, lapse: 0.037sec.
# optimization at t = 81 finished, lapse: 0.036sec.
# optimization at t = 82 finished, lapse: 0.036sec.
# optimization at t = 83 finished, lapse: 0.036sec.
# optimization at t = 84 finished, lapse: 0.037sec.
# optimization at t = 85 finished, lapse: 0.037sec.
# optimization at t = 86 finished, lapse: 0.036sec.
# optimization at t = 87 finished, lapse: 0.036sec.
# optimization at t = 88 finished, lapse: 0.036sec.
# optimization at t = 89 finished, lapse: 0.036sec.
# optimization at t = 90 finished, lapse: 0.040sec.
# optimization at t = 91 finished, lapse: 0.035sec.
# optimization at t = 92 finished, lapse: 0.035sec.
# optimization at t = 93 finished, lapse: 0.034sec.
# optimization at t = 94 finished, lapse: 0.035sec.
# optimization at t = 95 finished, lapse: 0.035sec.
# optimization at t = 96 finished, lapse: 0.036sec.
# optimization at t = 97 finished, lapse: 0.036sec.
# optimization at t = 98 finished, lapse: 0.035sec.
# optimization at t = 99 finished, lapse: 0.035sec.
# optimization at t = 100 finished, lapse: 0.035sec.
# optimization at t = 101 finished, lapse: 0.035sec.
# optimization at t = 102 finished, lapse: 0.035sec.
# optimization at t = 103 finished, lapse: 0.036sec.
# optimization at t = 104 finished, lapse: 0.035sec.
# optimization at t = 105 finished, lapse: 0.035sec.
# optimization at t = 106 finished, lapse: 0.038sec.
# optimization at t = 107 finished, lapse: 0.035sec.
# optimization at t = 108 finished, lapse: 0.038sec.
# optimization at t = 109 finished, lapse: 0.037sec.
# optimization at t = 110 finished, lapse: 0.036sec.
# optimization at t = 111 finished, lapse: 0.036sec.
# optimization at t = 112 finished, lapse: 0.037sec.
# optimization at t = 113 finished, lapse: 0.036sec.
# optimization at t = 114 finished, lapse: 0.037sec.
# optimization at t = 115 finished, lapse: 0.037sec.
# optimization at t = 116 finished, lapse: 0.037sec.
# optimization at t = 117 finished, lapse: 0.037sec.
# optimization at t = 118 finished, lapse: 0.037sec.
# optimization at t = 119 finished, lapse: 0.037sec.
# optimization at t = 120 finished, lapse: 0.038sec.
# optimization at t = 121 finished, lapse: 0.152sec.
# optimization at t = 122 finished, lapse: 0.149sec.
# optimization at t = 123 finished, lapse: 0.128sec.
# optimization at t = 124 finished, lapse: 0.110sec.
# optimization at t = 125 finished, lapse: 0.104sec.
# optimization at t = 126 finished, lapse: 0.097sec.
# optimization at t = 127 finished, lapse: 0.093sec.
# optimization at t = 128 finished, lapse: 0.096sec.
# optimization at t = 129 finished, lapse: 0.104sec.
# optimization at t = 130 finished, lapse: 0.099sec.
# optimization at t = 131 finished, lapse: 0.099sec.
# optimization at t = 132 finished, lapse: 0.099sec.
# optimization at t = 133 finished, lapse: 0.098sec.
# optimization at t = 134 finished, lapse: 0.100sec.
# optimization at t = 135 finished, lapse: 0.096sec.
# optimization at t = 136 finished, lapse: 0.097sec.
# optimization at t = 137 finished, lapse: 0.098sec.
# optimization at t = 138 finished, lapse: 0.099sec.
# optimization at t = 139 finished, lapse: 0.099sec.
# optimization at t = 140 finished, lapse: 0.098sec.
# optimization at t = 141 finished, lapse: 0.099sec.
# optimization at t = 142 finished, lapse: 0.103sec.
# optimization at t = 143 finished, lapse: 0.098sec.
# optimization at t = 144 finished, lapse: 0.098sec.
# optimization at t = 145 finished, lapse: 0.100sec.
# optimization at t = 146 finished, lapse: 0.098sec.
# optimization at t = 147 finished, lapse: 0.108sec.
# optimization at t = 148 finished, lapse: 0.124sec.
# optimization at t = 149 finished, lapse: 0.101sec.
# optimization at t = 150 finished, lapse: 0.100sec.
# optimization at t = 151 finished, lapse: 0.098sec.
# optimization at t = 152 finished, lapse: 0.100sec.
# optimization at t = 153 finished, lapse: 0.099sec.
# optimization at t = 154 finished, lapse: 0.098sec.
# optimization at t = 155 finished, lapse: 0.101sec.
# optimization at t = 156 finished, lapse: 0.100sec.
# optimization at t = 157 finished, lapse: 0.098sec.
# optimization at t = 158 finished, lapse: 0.101sec.
# optimization at t = 159 finished, lapse: 0.099sec.
# optimization at t = 160 finished, lapse: 0.098sec.
# optimization at t = 161 finished, lapse: 0.099sec.
# optimization at t = 162 finished, lapse: 0.099sec.
# optimization at t = 163 finished, lapse: 0.099sec.
# optimization at t = 164 finished, lapse: 0.101sec.
# optimization at t = 165 finished, lapse: 0.099sec.
# optimization at t = 166 finished, lapse: 0.101sec.
# optimization at t = 167 finished, lapse: 0.101sec.
# optimization at t = 168 finished, lapse: 0.100sec.
# optimization at t = 169 finished, lapse: 0.099sec.
# optimization at t = 170 finished, lapse: 0.108sec.
# optimization at t = 171 finished, lapse: 0.142sec.
# optimization at t = 172 finished, lapse: 0.123sec.
# optimization at t = 173 finished, lapse: 0.129sec.
# optimization at t = 174 finished, lapse: 0.147sec.
# optimization at t = 175 finished, lapse: 0.145sec.
# optimization at t = 176 finished, lapse: 0.154sec.
# optimization at t = 177 finished, lapse: 0.156sec.
# optimization at t = 178 finished, lapse: 0.131sec.
# optimization at t = 179 finished, lapse: 0.099sec.
# optimization at t = 180 finished, lapse: 0.096sec.

# %%
plt.plot(R, color='grey')
plt.plot(model.predict_R(Ae, bmle))
plt.fill_between(np.arange(np.shape(conf_band)[0]),
                 conf_band[:,0], conf_band[:,1], alpha=0.3)

# %%
conf_band, theta_min, theta_max = \
model.confidence_I(Ae, mmle, bmle, np.linalg.inv(Ihat_dth)[1:,1:], chi_pa,
                    verbose=True)
# Out:
# optimization at t = 1 finished, lapse: 0.358sec.
# optimization at t = 2 finished, lapse: 0.089sec.
# optimization at t = 3 finished, lapse: 0.109sec.
# optimization at t = 4 finished, lapse: 0.144sec.
# optimization at t = 5 finished, lapse: 0.155sec.
# optimization at t = 6 finished, lapse: 0.126sec.
# optimization at t = 7 finished, lapse: 0.077sec.
# optimization at t = 8 finished, lapse: 0.087sec.
# optimization at t = 9 finished, lapse: 0.098sec.
# optimization at t = 10 finished, lapse: 0.245sec.
# optimization at t = 11 finished, lapse: 0.106sec.
# optimization at t = 12 finished, lapse: 0.124sec.
# optimization at t = 13 finished, lapse: 0.147sec.
# optimization at t = 14 finished, lapse: 0.151sec.
# optimization at t = 15 finished, lapse: 0.169sec.
# optimization at t = 16 finished, lapse: 0.226sec.
# optimization at t = 17 finished, lapse: 0.205sec.
# optimization at t = 18 finished, lapse: 0.146sec.
# optimization at t = 19 finished, lapse: 0.209sec.
# optimization at t = 20 finished, lapse: 0.260sec.
# optimization at t = 21 finished, lapse: 0.339sec.
# optimization at t = 22 finished, lapse: 0.261sec.
# optimization at t = 23 finished, lapse: 0.219sec.
# optimization at t = 24 finished, lapse: 0.203sec.
# optimization at t = 25 finished, lapse: 0.224sec.
# optimization at t = 26 finished, lapse: 0.223sec.
# optimization at t = 27 finished, lapse: 0.228sec.
# optimization at t = 28 finished, lapse: 0.262sec.
# optimization at t = 29 finished, lapse: 0.196sec.
# optimization at t = 30 finished, lapse: 0.184sec.
# optimization at t = 31 finished, lapse: 0.201sec.
# optimization at t = 32 finished, lapse: 0.408sec.
# optimization at t = 33 finished, lapse: 0.205sec.
# optimization at t = 34 finished, lapse: 0.274sec.
# optimization at t = 35 finished, lapse: 0.306sec.
# optimization at t = 36 finished, lapse: 0.319sec.
# optimization at t = 37 finished, lapse: 0.422sec.
# optimization at t = 38 finished, lapse: 1.435sec.
# optimization at t = 39 finished, lapse: 0.273sec.
# optimization at t = 40 finished, lapse: 0.407sec.
# optimization at t = 41 finished, lapse: 0.390sec.
# optimization at t = 42 finished, lapse: 0.359sec.
# optimization at t = 43 finished, lapse: 0.391sec.
# optimization at t = 44 finished, lapse: 0.369sec.
# optimization at t = 45 finished, lapse: 0.378sec.
# optimization at t = 46 finished, lapse: 0.423sec.
# optimization at t = 47 finished, lapse: 0.286sec.
# optimization at t = 48 finished, lapse: 0.318sec.
# optimization at t = 49 finished, lapse: 0.332sec.
# optimization at t = 50 finished, lapse: 0.342sec.
# optimization at t = 51 finished, lapse: 0.369sec.
# optimization at t = 52 finished, lapse: 0.327sec.
# optimization at t = 53 finished, lapse: 0.286sec.
# optimization at t = 54 finished, lapse: 0.747sec.
# optimization at t = 55 finished, lapse: 0.352sec.
# optimization at t = 56 finished, lapse: 0.605sec.
# optimization at t = 57 finished, lapse: 0.530sec.
# optimization at t = 58 finished, lapse: 0.774sec.
# optimization at t = 59 finished, lapse: 0.291sec.
# optimization at t = 60 finished, lapse: 1.400sec.
# optimization at t = 61 finished, lapse: 0.598sec.
# optimization at t = 62 finished, lapse: 0.394sec.
# optimization at t = 63 finished, lapse: 1.576sec.
# optimization at t = 64 finished, lapse: 0.451sec.
# optimization at t = 65 finished, lapse: 1.630sec.
# optimization at t = 66 finished, lapse: 1.610sec.
# optimization at t = 67 finished, lapse: 1.900sec.
# optimization at t = 68 finished, lapse: 1.576sec.
# optimization at t = 69 finished, lapse: 1.691sec.
# optimization at t = 70 finished, lapse: 0.520sec.
# optimization at t = 71 finished, lapse: 0.802sec.
# optimization at t = 72 finished, lapse: 1.008sec.
# optimization at t = 73 finished, lapse: 1.034sec.
# optimization at t = 74 finished, lapse: 0.741sec.
# optimization at t = 75 finished, lapse: 0.677sec.
# optimization at t = 76 finished, lapse: 0.576sec.
# optimization at t = 77 finished, lapse: 0.479sec.
# optimization at t = 78 finished, lapse: 0.597sec.
# optimization at t = 79 finished, lapse: 0.692sec.
# optimization at t = 80 finished, lapse: 0.678sec.
# optimization at t = 81 finished, lapse: 0.725sec.
# optimization at t = 82 finished, lapse: 0.764sec.
# optimization at t = 83 finished, lapse: 0.426sec.
# optimization at t = 84 finished, lapse: 0.616sec.
# optimization at t = 85 finished, lapse: 0.872sec.
# optimization at t = 86 finished, lapse: 0.820sec.
# optimization at t = 87 finished, lapse: 1.052sec.
# optimization at t = 88 finished, lapse: 1.136sec.
# optimization at t = 89 finished, lapse: 0.523sec.
# optimization at t = 90 finished, lapse: 0.703sec.
# optimization at t = 91 finished, lapse: 1.045sec.
# optimization at t = 92 finished, lapse: 0.797sec.
# optimization at t = 93 finished, lapse: 0.662sec.
# optimization at t = 94 finished, lapse: 0.783sec.
# optimization at t = 95 finished, lapse: 0.967sec.
# optimization at t = 96 finished, lapse: 0.667sec.
# optimization at t = 97 finished, lapse: 0.965sec.
# optimization at t = 98 finished, lapse: 0.829sec.
# optimization at t = 99 finished, lapse: 0.793sec.
# optimization at t = 100 finished, lapse: 0.886sec.
# optimization at t = 101 finished, lapse: 1.021sec.
# optimization at t = 102 finished, lapse: 0.855sec.
# optimization at t = 103 finished, lapse: 0.743sec.
# optimization at t = 104 finished, lapse: 2.694sec.
# optimization at t = 105 finished, lapse: 4.763sec.
# optimization at t = 106 finished, lapse: 2.465sec.
# optimization at t = 107 finished, lapse: 2.824sec.
# optimization at t = 108 finished, lapse: 2.290sec.
# optimization at t = 109 finished, lapse: 1.792sec.
# optimization at t = 110 finished, lapse: 1.972sec.
# optimization at t = 111 finished, lapse: 3.309sec.
# optimization at t = 112 finished, lapse: 1.656sec.
# optimization at t = 113 finished, lapse: 1.903sec.
# optimization at t = 114 finished, lapse: 4.784sec.
# optimization at t = 115 finished, lapse: 3.020sec.
# optimization at t = 116 finished, lapse: 2.876sec.
# optimization at t = 117 finished, lapse: 4.061sec.
# optimization at t = 118 finished, lapse: 2.645sec.
# optimization at t = 119 finished, lapse: 2.946sec.
# optimization at t = 120 finished, lapse: 3.142sec.
# optimization at t = 121 finished, lapse: 2.776sec.
# optimization at t = 122 finished, lapse: 2.913sec.
# optimization at t = 123 finished, lapse: 2.815sec.
# optimization at t = 124 finished, lapse: 3.576sec.
# optimization at t = 125 finished, lapse: 1.324sec.
# optimization at t = 126 finished, lapse: 1.958sec.
# optimization at t = 127 finished, lapse: 2.566sec.
# optimization at t = 128 finished, lapse: 3.370sec.
# optimization at t = 129 finished, lapse: 4.090sec.
# optimization at t = 130 finished, lapse: 2.268sec.
# optimization at t = 131 finished, lapse: 3.248sec.
# optimization at t = 132 finished, lapse: 3.185sec.
# optimization at t = 133 finished, lapse: 3.342sec.
# optimization at t = 134 finished, lapse: 4.140sec.
# optimization at t = 135 finished, lapse: 3.769sec.
# optimization at t = 136 finished, lapse: 3.334sec.
# optimization at t = 137 finished, lapse: 3.318sec.
# optimization at t = 138 finished, lapse: 1.740sec.
# optimization at t = 139 finished, lapse: 3.368sec.
# optimization at t = 140 finished, lapse: 1.852sec.
# optimization at t = 141 finished, lapse: 1.822sec.
# optimization at t = 142 finished, lapse: 3.413sec.
# optimization at t = 143 finished, lapse: 3.272sec.
# optimization at t = 144 finished, lapse: 2.122sec.
# optimization at t = 145 finished, lapse: 2.394sec.
# optimization at t = 146 finished, lapse: 4.501sec.
# optimization at t = 147 finished, lapse: 2.392sec.
# optimization at t = 148 finished, lapse: 1.787sec.
# optimization at t = 149 finished, lapse: 3.837sec.
# optimization at t = 150 finished, lapse: 3.546sec.
# optimization at t = 151 finished, lapse: 10.323sec.
# optimization at t = 152 finished, lapse: 5.267sec.
# optimization at t = 153 finished, lapse: 2.935sec.
# optimization at t = 154 finished, lapse: 6.063sec.
# optimization at t = 155 finished, lapse: 5.806sec.
# optimization at t = 156 finished, lapse: 7.007sec.
# optimization at t = 157 finished, lapse: 5.669sec.
# optimization at t = 158 finished, lapse: 22.897sec.
# optimization at t = 159 finished, lapse: 6.101sec.
# optimization at t = 160 finished, lapse: 7.780sec.
# optimization at t = 161 finished, lapse: 3.537sec.
# optimization at t = 162 finished, lapse: 4.761sec.
# optimization at t = 163 finished, lapse: 8.283sec.
# optimization at t = 164 finished, lapse: 7.414sec.
# optimization at t = 165 finished, lapse: 4.123sec.
# optimization at t = 166 finished, lapse: 4.861sec.
# optimization at t = 167 finished, lapse: 4.225sec.
# optimization at t = 168 finished, lapse: 7.762sec.
# optimization at t = 169 finished, lapse: 7.377sec.
# optimization at t = 170 finished, lapse: 5.355sec.
# optimization at t = 171 finished, lapse: 9.934sec.
# optimization at t = 172 finished, lapse: 4.254sec.
# optimization at t = 173 finished, lapse: 4.944sec.
# optimization at t = 174 finished, lapse: 6.019sec.
# optimization at t = 175 finished, lapse: 4.966sec.
# optimization at t = 176 finished, lapse: 6.594sec.
# optimization at t = 177 finished, lapse: 6.258sec.
# optimization at t = 178 finished, lapse: 4.303sec.
# optimization at t = 179 finished, lapse: 5.848sec.
# optimization at t = 180 finished, lapse: 2.940sec.

# %%
plt.bar(np.arange(T), I, color='grey', alpha=0.5)
plt.plot(model.predict_I(Ae, mmle, bmle))
plt.fill_between(np.arange(np.shape(conf_band)[0]),
                 conf_band[:,0], conf_band[:,1], alpha=0.3)

# %%
conf_band, theta_min, theta_max = \
model.confidence_EY(Ae, mmle, bmle, np.linalg.inv(Ihat_dth)[1:,1:], chi_pa,
                    verbose=True)
# Out:
# optimization at t = 1 finished, lapse: 1.366sec.
# optimization at t = 2 finished, lapse: 1.735sec.
# optimization at t = 3 finished, lapse: 1.506sec.
# optimization at t = 4 finished, lapse: 1.880sec.
# optimization at t = 5 finished, lapse: 1.609sec.
# optimization at t = 6 finished, lapse: 0.939sec.
# optimization at t = 7 finished, lapse: 1.984sec.
# optimization at t = 8 finished, lapse: 1.242sec.
# optimization at t = 9 finished, lapse: 1.242sec.
# optimization at t = 10 finished, lapse: 0.464sec.
# optimization at t = 11 finished, lapse: 0.348sec.
# optimization at t = 12 finished, lapse: 0.786sec.
# optimization at t = 13 finished, lapse: 0.462sec.
# optimization at t = 14 finished, lapse: 0.228sec.
# optimization at t = 15 finished, lapse: 0.412sec.
# optimization at t = 16 finished, lapse: 0.423sec.
# optimization at t = 17 finished, lapse: 0.185sec.
# optimization at t = 18 finished, lapse: 0.173sec.
# optimization at t = 19 finished, lapse: 0.160sec.
# optimization at t = 20 finished, lapse: 0.147sec.
# optimization at t = 21 finished, lapse: 0.168sec.
# optimization at t = 22 finished, lapse: 0.159sec.
# optimization at t = 23 finished, lapse: 0.109sec.
# optimization at t = 24 finished, lapse: 0.111sec.
# optimization at t = 25 finished, lapse: 0.129sec.
# optimization at t = 26 finished, lapse: 0.105sec.
# optimization at t = 27 finished, lapse: 0.100sec.
# optimization at t = 28 finished, lapse: 0.099sec.
# optimization at t = 29 finished, lapse: 0.082sec.
# optimization at t = 30 finished, lapse: 0.092sec.
# optimization at t = 31 finished, lapse: 0.079sec.
# optimization at t = 32 finished, lapse: 0.067sec.
# optimization at t = 33 finished, lapse: 0.075sec.
# optimization at t = 34 finished, lapse: 0.748sec.
# optimization at t = 35 finished, lapse: 0.076sec.
# optimization at t = 36 finished, lapse: 0.075sec.
# optimization at t = 37 finished, lapse: 0.179sec.
# optimization at t = 38 finished, lapse: 0.140sec.
# optimization at t = 39 finished, lapse: 0.174sec.
# optimization at t = 40 finished, lapse: 0.154sec.
# optimization at t = 41 finished, lapse: 0.196sec.
# optimization at t = 42 finished, lapse: 0.135sec.
# optimization at t = 43 finished, lapse: 0.226sec.
# optimization at t = 44 finished, lapse: 0.225sec.
# optimization at t = 45 finished, lapse: 0.238sec.
# optimization at t = 46 finished, lapse: 0.217sec.
# optimization at t = 47 finished, lapse: 0.198sec.
# optimization at t = 48 finished, lapse: 0.186sec.
# optimization at t = 49 finished, lapse: 0.304sec.
# optimization at t = 50 finished, lapse: 0.173sec.
# optimization at t = 51 finished, lapse: 0.275sec.
# optimization at t = 52 finished, lapse: 0.230sec.
# optimization at t = 53 finished, lapse: 0.243sec.
# optimization at t = 54 finished, lapse: 0.208sec.
# optimization at t = 55 finished, lapse: 0.268sec.
# optimization at t = 56 finished, lapse: 0.235sec.
# optimization at t = 57 finished, lapse: 0.223sec.
# optimization at t = 58 finished, lapse: 0.252sec.
# optimization at t = 59 finished, lapse: 0.264sec.
# optimization at t = 60 finished, lapse: 0.209sec.
# optimization at t = 61 finished, lapse: 0.264sec.
# optimization at t = 62 finished, lapse: 0.188sec.
# optimization at t = 63 finished, lapse: 0.197sec.
# optimization at t = 64 finished, lapse: 0.205sec.
# optimization at t = 65 finished, lapse: 0.377sec.
# optimization at t = 66 finished, lapse: 0.435sec.
# optimization at t = 67 finished, lapse: 0.431sec.
# optimization at t = 68 finished, lapse: 0.480sec.
# optimization at t = 69 finished, lapse: 0.396sec.
# optimization at t = 70 finished, lapse: 0.246sec.
# optimization at t = 71 finished, lapse: 0.281sec.
# optimization at t = 72 finished, lapse: 0.316sec.
# optimization at t = 73 finished, lapse: 0.553sec.
# optimization at t = 74 finished, lapse: 0.333sec.
# optimization at t = 75 finished, lapse: 0.483sec.
# optimization at t = 76 finished, lapse: 0.393sec.
# optimization at t = 77 finished, lapse: 0.378sec.
# optimization at t = 78 finished, lapse: 0.503sec.
# optimization at t = 79 finished, lapse: 0.457sec.
# optimization at t = 80 finished, lapse: 0.332sec.
# optimization at t = 81 finished, lapse: 0.418sec.
# optimization at t = 82 finished, lapse: 0.470sec.
# optimization at t = 83 finished, lapse: 0.421sec.
# optimization at t = 84 finished, lapse: 0.336sec.
# optimization at t = 85 finished, lapse: 0.522sec.
# optimization at t = 86 finished, lapse: 0.523sec.
# optimization at t = 87 finished, lapse: 0.462sec.
# optimization at t = 88 finished, lapse: 0.321sec.
# optimization at t = 89 finished, lapse: 0.169sec.
# optimization at t = 90 finished, lapse: 0.412sec.
# optimization at t = 91 finished, lapse: 0.379sec.
# optimization at t = 92 finished, lapse: 0.449sec.
# optimization at t = 93 finished, lapse: 0.496sec.
# optimization at t = 94 finished, lapse: 0.418sec.
# optimization at t = 95 finished, lapse: 0.470sec.
# optimization at t = 96 finished, lapse: 0.583sec.
# optimization at t = 97 finished, lapse: 0.454sec.
# optimization at t = 98 finished, lapse: 1.139sec.
# optimization at t = 99 finished, lapse: 0.690sec.
# optimization at t = 100 finished, lapse: 0.451sec.
# optimization at t = 101 finished, lapse: 0.623sec.
# optimization at t = 102 finished, lapse: 0.464sec.
# optimization at t = 103 finished, lapse: 0.481sec.
# optimization at t = 104 finished, lapse: 1.271sec.
# optimization at t = 105 finished, lapse: 1.935sec.
# optimization at t = 106 finished, lapse: 1.423sec.
# optimization at t = 107 finished, lapse: 1.032sec.
# optimization at t = 108 finished, lapse: 0.841sec.
# optimization at t = 109 finished, lapse: 1.354sec.
# optimization at t = 110 finished, lapse: 2.655sec.
# optimization at t = 111 finished, lapse: 0.511sec.
# optimization at t = 112 finished, lapse: 0.653sec.
# optimization at t = 113 finished, lapse: 0.665sec.
# optimization at t = 114 finished, lapse: 1.221sec.
# optimization at t = 115 finished, lapse: 0.719sec.
# optimization at t = 116 finished, lapse: 1.212sec.
# optimization at t = 117 finished, lapse: 1.071sec.
# optimization at t = 118 finished, lapse: 1.851sec.
# optimization at t = 119 finished, lapse: 1.182sec.
# optimization at t = 120 finished, lapse: 0.781sec.
# optimization at t = 121 finished, lapse: 0.636sec.
# optimization at t = 122 finished, lapse: 1.360sec.
# optimization at t = 123 finished, lapse: 0.799sec.
# optimization at t = 124 finished, lapse: 0.603sec.
# optimization at t = 125 finished, lapse: 0.840sec.
# optimization at t = 126 finished, lapse: 0.783sec.
# optimization at t = 127 finished, lapse: 1.849sec.
# optimization at t = 128 finished, lapse: 1.638sec.
# optimization at t = 129 finished, lapse: 1.674sec.
# optimization at t = 130 finished, lapse: 2.179sec.
# optimization at t = 131 finished, lapse: 0.310sec.
# optimization at t = 132 finished, lapse: 0.389sec.
# optimization at t = 133 finished, lapse: 0.360sec.
# optimization at t = 134 finished, lapse: 0.315sec.
# optimization at t = 135 finished, lapse: 1.316sec.
# optimization at t = 136 finished, lapse: 1.500sec.
# optimization at t = 137 finished, lapse: 0.581sec.
# optimization at t = 138 finished, lapse: 0.356sec.
# optimization at t = 139 finished, lapse: 0.312sec.
# optimization at t = 140 finished, lapse: 0.306sec.
# optimization at t = 141 finished, lapse: 0.296sec.
# optimization at t = 142 finished, lapse: 1.211sec.
# optimization at t = 143 finished, lapse: 0.486sec.
# optimization at t = 144 finished, lapse: 0.341sec.
# optimization at t = 145 finished, lapse: 0.332sec.
# optimization at t = 146 finished, lapse: 0.390sec.
# optimization at t = 147 finished, lapse: 0.409sec.
# optimization at t = 148 finished, lapse: 0.387sec.
# optimization at t = 149 finished, lapse: 0.383sec.
# optimization at t = 150 finished, lapse: 0.387sec.
# optimization at t = 151 finished, lapse: 0.413sec.
# optimization at t = 152 finished, lapse: 0.508sec.
# optimization at t = 153 finished, lapse: 0.382sec.
# optimization at t = 154 finished, lapse: 0.400sec.
# optimization at t = 155 finished, lapse: 0.444sec.
# optimization at t = 156 finished, lapse: 1.007sec.
# optimization at t = 157 finished, lapse: 0.430sec.
# optimization at t = 158 finished, lapse: 0.393sec.
# optimization at t = 159 finished, lapse: 0.456sec.
# optimization at t = 160 finished, lapse: 0.926sec.
# optimization at t = 161 finished, lapse: 0.465sec.
# optimization at t = 162 finished, lapse: 0.789sec.
# optimization at t = 163 finished, lapse: 1.071sec.
# optimization at t = 164 finished, lapse: 0.549sec.
# optimization at t = 165 finished, lapse: 0.598sec.
# optimization at t = 166 finished, lapse: 0.826sec.
# optimization at t = 167 finished, lapse: 0.498sec.
# optimization at t = 168 finished, lapse: 0.723sec.
# optimization at t = 169 finished, lapse: 0.537sec.
# optimization at t = 170 finished, lapse: 0.973sec.
# optimization at t = 171 finished, lapse: 0.788sec.
# optimization at t = 172 finished, lapse: 1.444sec.
# optimization at t = 173 finished, lapse: 2.015sec.
# optimization at t = 174 finished, lapse: 1.546sec.
# optimization at t = 175 finished, lapse: 1.047sec.
# optimization at t = 176 finished, lapse: 0.466sec.
# optimization at t = 177 finished, lapse: 0.835sec.
# optimization at t = 178 finished, lapse: 1.000sec.
# optimization at t = 179 finished, lapse: 0.455sec.
# optimization at t = 180 finished, lapse: 1.778sec.

# %%
plt.bar(np.arange(T), Y, color='grey', alpha=0.5)
plt.plot(model.predict_EY(Ae, mmle, bmle))
plt.fill_between(np.arange(np.shape(conf_band)[0]),
                 conf_band[:,0], conf_band[:,1], alpha=0.3)
plt.ylim(0,2000)
# Out:
# (0.0, 2000.0)

# %% [markdown]
# ## A = 0

# %%
Tf = 60
Af = np.zeros([Tf, d])

# %%
Af[:,0] = np.full(Tf, 1)
Af[:,1] = np.full(Tf, 0)

# %%
Ae = np.concatenate([A, Af], 0)

# %%
conf_band, beta_min, beta_max = \
model.confidence_R(Ae, bmle, np.linalg.inv(Ihat_dth)[-2:,-2:], chi_pa,
                   verbose=True)
# Out:
# optimization at t = 1 finished, lapse: 0.113sec.
# optimization at t = 2 finished, lapse: 0.117sec.
# optimization at t = 3 finished, lapse: 0.178sec.
# optimization at t = 4 finished, lapse: 0.070sec.
# optimization at t = 5 finished, lapse: 0.179sec.
# optimization at t = 6 finished, lapse: 0.070sec.
# optimization at t = 7 finished, lapse: 0.181sec.
# optimization at t = 8 finished, lapse: 0.070sec.
# optimization at t = 9 finished, lapse: 0.182sec.
# optimization at t = 10 finished, lapse: 0.070sec.
# optimization at t = 11 finished, lapse: 0.180sec.
# optimization at t = 12 finished, lapse: 0.071sec.
# optimization at t = 13 finished, lapse: 0.178sec.
# optimization at t = 14 finished, lapse: 0.070sec.
# optimization at t = 15 finished, lapse: 0.179sec.
# optimization at t = 16 finished, lapse: 0.071sec.
# optimization at t = 17 finished, lapse: 0.180sec.
# optimization at t = 18 finished, lapse: 0.070sec.
# optimization at t = 19 finished, lapse: 0.179sec.
# optimization at t = 20 finished, lapse: 0.071sec.
# optimization at t = 21 finished, lapse: 0.180sec.
# optimization at t = 22 finished, lapse: 0.071sec.
# optimization at t = 23 finished, lapse: 0.180sec.
# optimization at t = 24 finished, lapse: 0.069sec.
# optimization at t = 25 finished, lapse: 0.180sec.
# optimization at t = 26 finished, lapse: 0.068sec.
# optimization at t = 27 finished, lapse: 0.180sec.
# optimization at t = 28 finished, lapse: 0.071sec.
# optimization at t = 29 finished, lapse: 0.179sec.
# optimization at t = 30 finished, lapse: 0.070sec.
# optimization at t = 31 finished, lapse: 0.182sec.
# optimization at t = 32 finished, lapse: 0.088sec.
# optimization at t = 33 finished, lapse: 0.053sec.
# optimization at t = 34 finished, lapse: 0.053sec.
# optimization at t = 35 finished, lapse: 0.055sec.
# optimization at t = 36 finished, lapse: 0.053sec.
# optimization at t = 37 finished, lapse: 0.053sec.
# optimization at t = 38 finished, lapse: 0.053sec.
# optimization at t = 39 finished, lapse: 0.056sec.
# optimization at t = 40 finished, lapse: 0.053sec.
# optimization at t = 41 finished, lapse: 0.053sec.
# optimization at t = 42 finished, lapse: 0.053sec.
# optimization at t = 43 finished, lapse: 0.054sec.
# optimization at t = 44 finished, lapse: 0.053sec.
# optimization at t = 45 finished, lapse: 0.053sec.
# optimization at t = 46 finished, lapse: 0.053sec.
# optimization at t = 47 finished, lapse: 0.056sec.
# optimization at t = 48 finished, lapse: 0.053sec.
# optimization at t = 49 finished, lapse: 0.053sec.
# optimization at t = 50 finished, lapse: 0.053sec.
# optimization at t = 51 finished, lapse: 0.055sec.
# optimization at t = 52 finished, lapse: 0.053sec.
# optimization at t = 53 finished, lapse: 0.053sec.
# optimization at t = 54 finished, lapse: 0.053sec.
# optimization at t = 55 finished, lapse: 0.053sec.
# optimization at t = 56 finished, lapse: 0.054sec.
# optimization at t = 57 finished, lapse: 0.053sec.
# optimization at t = 58 finished, lapse: 0.053sec.
# optimization at t = 59 finished, lapse: 0.056sec.
# optimization at t = 60 finished, lapse: 0.053sec.
# optimization at t = 61 finished, lapse: 0.053sec.
# optimization at t = 62 finished, lapse: 0.052sec.
# optimization at t = 63 finished, lapse: 0.054sec.
# optimization at t = 64 finished, lapse: 0.053sec.
# optimization at t = 65 finished, lapse: 0.053sec.
# optimization at t = 66 finished, lapse: 0.053sec.
# optimization at t = 67 finished, lapse: 0.054sec.
# optimization at t = 68 finished, lapse: 0.053sec.
# optimization at t = 69 finished, lapse: 0.053sec.
# optimization at t = 70 finished, lapse: 0.052sec.
# optimization at t = 71 finished, lapse: 0.055sec.
# optimization at t = 72 finished, lapse: 0.054sec.
# optimization at t = 73 finished, lapse: 0.053sec.
# optimization at t = 74 finished, lapse: 0.053sec.
# optimization at t = 75 finished, lapse: 0.055sec.
# optimization at t = 76 finished, lapse: 0.054sec.
# optimization at t = 77 finished, lapse: 0.053sec.
# optimization at t = 78 finished, lapse: 0.053sec.
# optimization at t = 79 finished, lapse: 0.054sec.
# optimization at t = 80 finished, lapse: 0.053sec.
# optimization at t = 81 finished, lapse: 0.053sec.
# optimization at t = 82 finished, lapse: 0.053sec.
# optimization at t = 83 finished, lapse: 0.056sec.
# optimization at t = 84 finished, lapse: 0.054sec.
# optimization at t = 85 finished, lapse: 0.053sec.
# optimization at t = 86 finished, lapse: 0.053sec.
# optimization at t = 87 finished, lapse: 0.054sec.
# optimization at t = 88 finished, lapse: 0.053sec.
# optimization at t = 89 finished, lapse: 0.053sec.
# optimization at t = 90 finished, lapse: 0.053sec.
# optimization at t = 91 finished, lapse: 0.055sec.
# optimization at t = 92 finished, lapse: 0.053sec.
# optimization at t = 93 finished, lapse: 0.053sec.
# optimization at t = 94 finished, lapse: 0.053sec.
# optimization at t = 95 finished, lapse: 0.056sec.
# optimization at t = 96 finished, lapse: 0.053sec.
# optimization at t = 97 finished, lapse: 0.053sec.
# optimization at t = 98 finished, lapse: 0.053sec.
# optimization at t = 99 finished, lapse: 0.054sec.
# optimization at t = 100 finished, lapse: 0.053sec.
# optimization at t = 101 finished, lapse: 0.053sec.
# optimization at t = 102 finished, lapse: 0.052sec.
# optimization at t = 103 finished, lapse: 0.055sec.
# optimization at t = 104 finished, lapse: 0.054sec.
# optimization at t = 105 finished, lapse: 0.053sec.
# optimization at t = 106 finished, lapse: 0.053sec.
# optimization at t = 107 finished, lapse: 0.054sec.
# optimization at t = 108 finished, lapse: 0.054sec.
# optimization at t = 109 finished, lapse: 0.053sec.
# optimization at t = 110 finished, lapse: 0.053sec.
# optimization at t = 111 finished, lapse: 0.055sec.
# optimization at t = 112 finished, lapse: 0.053sec.
# optimization at t = 113 finished, lapse: 0.053sec.
# optimization at t = 114 finished, lapse: 0.052sec.
# optimization at t = 115 finished, lapse: 0.055sec.
# optimization at t = 116 finished, lapse: 0.054sec.
# optimization at t = 117 finished, lapse: 0.053sec.
# optimization at t = 118 finished, lapse: 0.053sec.
# optimization at t = 119 finished, lapse: 0.054sec.
# optimization at t = 120 finished, lapse: 0.053sec.
# optimization at t = 121 finished, lapse: 0.095sec.
# optimization at t = 122 finished, lapse: 0.180sec.
# optimization at t = 123 finished, lapse: 0.071sec.
# optimization at t = 124 finished, lapse: 0.181sec.
# optimization at t = 125 finished, lapse: 0.070sec.
# optimization at t = 126 finished, lapse: 0.179sec.
# optimization at t = 127 finished, lapse: 0.070sec.
# optimization at t = 128 finished, lapse: 0.181sec.
# optimization at t = 129 finished, lapse: 0.071sec.
# optimization at t = 130 finished, lapse: 0.178sec.
# optimization at t = 131 finished, lapse: 0.071sec.
# optimization at t = 132 finished, lapse: 0.180sec.
# optimization at t = 133 finished, lapse: 0.070sec.
# optimization at t = 134 finished, lapse: 0.179sec.
# optimization at t = 135 finished, lapse: 0.071sec.
# optimization at t = 136 finished, lapse: 0.178sec.
# optimization at t = 137 finished, lapse: 0.070sec.
# optimization at t = 138 finished, lapse: 0.179sec.
# optimization at t = 139 finished, lapse: 0.070sec.
# optimization at t = 140 finished, lapse: 0.180sec.
# optimization at t = 141 finished, lapse: 0.072sec.
# optimization at t = 142 finished, lapse: 0.179sec.
# optimization at t = 143 finished, lapse: 0.070sec.
# optimization at t = 144 finished, lapse: 0.180sec.
# optimization at t = 145 finished, lapse: 0.070sec.
# optimization at t = 146 finished, lapse: 0.184sec.
# optimization at t = 147 finished, lapse: 0.070sec.
# optimization at t = 148 finished, lapse: 0.179sec.
# optimization at t = 149 finished, lapse: 0.071sec.
# optimization at t = 150 finished, lapse: 0.181sec.
# optimization at t = 151 finished, lapse: 0.072sec.
# optimization at t = 152 finished, lapse: 0.179sec.
# optimization at t = 153 finished, lapse: 0.071sec.
# optimization at t = 154 finished, lapse: 0.180sec.
# optimization at t = 155 finished, lapse: 0.071sec.
# optimization at t = 156 finished, lapse: 0.179sec.
# optimization at t = 157 finished, lapse: 0.070sec.
# optimization at t = 158 finished, lapse: 0.179sec.
# optimization at t = 159 finished, lapse: 0.071sec.
# optimization at t = 160 finished, lapse: 0.179sec.
# optimization at t = 161 finished, lapse: 0.070sec.
# optimization at t = 162 finished, lapse: 0.184sec.
# optimization at t = 163 finished, lapse: 0.070sec.
# optimization at t = 164 finished, lapse: 0.181sec.
# optimization at t = 165 finished, lapse: 0.071sec.
# optimization at t = 166 finished, lapse: 0.183sec.
# optimization at t = 167 finished, lapse: 0.080sec.
# optimization at t = 168 finished, lapse: 0.180sec.
# optimization at t = 169 finished, lapse: 0.073sec.
# optimization at t = 170 finished, lapse: 0.181sec.
# optimization at t = 171 finished, lapse: 0.070sec.
# optimization at t = 172 finished, lapse: 0.177sec.
# optimization at t = 173 finished, lapse: 0.070sec.
# optimization at t = 174 finished, lapse: 0.179sec.
# optimization at t = 175 finished, lapse: 0.070sec.
# optimization at t = 176 finished, lapse: 0.178sec.
# optimization at t = 177 finished, lapse: 0.070sec.
# optimization at t = 178 finished, lapse: 0.180sec.
# optimization at t = 179 finished, lapse: 0.071sec.
# optimization at t = 180 finished, lapse: 0.179sec.

# %%
plt.plot(R, color='grey')
plt.plot(model.predict_R(Ae, bmle))
plt.fill_between(np.arange(np.shape(conf_band)[0]),
                 conf_band[:,0], conf_band[:,1], alpha=0.3)

# %%
conf_band, theta_min, theta_max = \
model.confidence_I(Ae, mmle, bmle, np.linalg.inv(Ihat_dth)[1:,1:], chi_pa,
                    verbose=True)
# Out:
# optimization at t = 1 finished, lapse: 0.114sec.
# optimization at t = 2 finished, lapse: 0.551sec.
# optimization at t = 3 finished, lapse: 0.104sec.
# optimization at t = 4 finished, lapse: 0.216sec.
# optimization at t = 5 finished, lapse: 0.413sec.
# optimization at t = 6 finished, lapse: 0.168sec.
# optimization at t = 7 finished, lapse: 0.156sec.
# optimization at t = 8 finished, lapse: 0.130sec.
# optimization at t = 9 finished, lapse: 0.079sec.
# optimization at t = 10 finished, lapse: 0.085sec.
# optimization at t = 11 finished, lapse: 0.071sec.
# optimization at t = 12 finished, lapse: 0.084sec.
# optimization at t = 13 finished, lapse: 0.132sec.
# optimization at t = 14 finished, lapse: 0.173sec.
# optimization at t = 15 finished, lapse: 0.205sec.
# optimization at t = 16 finished, lapse: 0.179sec.
# optimization at t = 17 finished, lapse: 0.171sec.
# optimization at t = 18 finished, lapse: 0.207sec.
# optimization at t = 19 finished, lapse: 0.217sec.
# optimization at t = 20 finished, lapse: 0.208sec.
# optimization at t = 21 finished, lapse: 0.244sec.
# optimization at t = 22 finished, lapse: 0.196sec.
# optimization at t = 23 finished, lapse: 0.221sec.
# optimization at t = 24 finished, lapse: 0.160sec.
# optimization at t = 25 finished, lapse: 0.211sec.
# optimization at t = 26 finished, lapse: 0.208sec.
# optimization at t = 27 finished, lapse: 0.258sec.
# optimization at t = 28 finished, lapse: 0.213sec.
# optimization at t = 29 finished, lapse: 0.271sec.
# optimization at t = 30 finished, lapse: 0.241sec.
# optimization at t = 31 finished, lapse: 0.195sec.
# optimization at t = 32 finished, lapse: 0.633sec.
# optimization at t = 33 finished, lapse: 0.192sec.
# optimization at t = 34 finished, lapse: 0.304sec.
# optimization at t = 35 finished, lapse: 0.285sec.
# optimization at t = 36 finished, lapse: 1.092sec.
# optimization at t = 37 finished, lapse: 0.459sec.
# optimization at t = 38 finished, lapse: 0.356sec.
# optimization at t = 39 finished, lapse: 0.371sec.
# optimization at t = 40 finished, lapse: 0.374sec.
# optimization at t = 41 finished, lapse: 0.337sec.
# optimization at t = 42 finished, lapse: 0.316sec.
# optimization at t = 43 finished, lapse: 0.393sec.
# optimization at t = 44 finished, lapse: 0.363sec.
# optimization at t = 45 finished, lapse: 0.374sec.
# optimization at t = 46 finished, lapse: 0.254sec.
# optimization at t = 47 finished, lapse: 0.276sec.
# optimization at t = 48 finished, lapse: 0.280sec.
# optimization at t = 49 finished, lapse: 0.256sec.
# optimization at t = 50 finished, lapse: 0.295sec.
# optimization at t = 51 finished, lapse: 0.478sec.
# optimization at t = 52 finished, lapse: 0.399sec.
# optimization at t = 53 finished, lapse: 0.424sec.
# optimization at t = 54 finished, lapse: 0.280sec.
# optimization at t = 55 finished, lapse: 0.450sec.
# optimization at t = 56 finished, lapse: 1.126sec.
# optimization at t = 57 finished, lapse: 0.740sec.
# optimization at t = 58 finished, lapse: 0.574sec.
# optimization at t = 59 finished, lapse: 0.434sec.
# optimization at t = 60 finished, lapse: 0.641sec.
# optimization at t = 61 finished, lapse: 1.705sec.
# optimization at t = 62 finished, lapse: 1.203sec.
# optimization at t = 63 finished, lapse: 1.229sec.
# optimization at t = 64 finished, lapse: 1.141sec.
# optimization at t = 65 finished, lapse: 1.671sec.
# optimization at t = 66 finished, lapse: 1.945sec.
# optimization at t = 67 finished, lapse: 1.749sec.
# optimization at t = 68 finished, lapse: 2.023sec.
# optimization at t = 69 finished, lapse: 1.900sec.
# optimization at t = 70 finished, lapse: 0.827sec.
# optimization at t = 71 finished, lapse: 0.720sec.
# optimization at t = 72 finished, lapse: 0.470sec.
# optimization at t = 73 finished, lapse: 0.656sec.
# optimization at t = 74 finished, lapse: 0.474sec.
# optimization at t = 75 finished, lapse: 0.761sec.
# optimization at t = 76 finished, lapse: 0.897sec.
# optimization at t = 77 finished, lapse: 0.707sec.
# optimization at t = 78 finished, lapse: 0.814sec.
# optimization at t = 79 finished, lapse: 0.701sec.
# optimization at t = 80 finished, lapse: 0.591sec.
# optimization at t = 81 finished, lapse: 0.737sec.
# optimization at t = 82 finished, lapse: 0.964sec.
# optimization at t = 83 finished, lapse: 0.927sec.
# optimization at t = 84 finished, lapse: 0.814sec.
# optimization at t = 85 finished, lapse: 0.778sec.
# optimization at t = 86 finished, lapse: 0.710sec.
# optimization at t = 87 finished, lapse: 0.487sec.
# optimization at t = 88 finished, lapse: 0.586sec.
# optimization at t = 89 finished, lapse: 0.550sec.
# optimization at t = 90 finished, lapse: 0.583sec.
# optimization at t = 91 finished, lapse: 0.637sec.
# optimization at t = 92 finished, lapse: 0.601sec.
# optimization at t = 93 finished, lapse: 0.395sec.
# optimization at t = 94 finished, lapse: 0.483sec.
# optimization at t = 95 finished, lapse: 0.684sec.
# optimization at t = 96 finished, lapse: 0.877sec.
# optimization at t = 97 finished, lapse: 0.822sec.
# optimization at t = 98 finished, lapse: 0.655sec.
# optimization at t = 99 finished, lapse: 0.694sec.
# optimization at t = 100 finished, lapse: 0.860sec.
# optimization at t = 101 finished, lapse: 1.073sec.
# optimization at t = 102 finished, lapse: 0.824sec.
# optimization at t = 103 finished, lapse: 0.591sec.
# optimization at t = 104 finished, lapse: 0.738sec.
# optimization at t = 105 finished, lapse: 0.903sec.
# optimization at t = 106 finished, lapse: 1.897sec.
# optimization at t = 107 finished, lapse: 1.747sec.
# optimization at t = 108 finished, lapse: 0.758sec.
# optimization at t = 109 finished, lapse: 0.820sec.
# optimization at t = 110 finished, lapse: 0.898sec.
# optimization at t = 111 finished, lapse: 1.275sec.
# optimization at t = 112 finished, lapse: 1.022sec.
# optimization at t = 113 finished, lapse: 1.066sec.
# optimization at t = 114 finished, lapse: 0.817sec.
# optimization at t = 115 finished, lapse: 0.856sec.
# optimization at t = 116 finished, lapse: 1.277sec.
# optimization at t = 117 finished, lapse: 0.811sec.
# optimization at t = 118 finished, lapse: 0.973sec.
# optimization at t = 119 finished, lapse: 0.834sec.
# optimization at t = 120 finished, lapse: 1.144sec.
# optimization at t = 121 finished, lapse: 1.388sec.
# optimization at t = 122 finished, lapse: 1.631sec.
# optimization at t = 123 finished, lapse: 1.456sec.
# optimization at t = 124 finished, lapse: 1.391sec.
# optimization at t = 125 finished, lapse: 1.260sec.
# optimization at t = 126 finished, lapse: 1.105sec.
# optimization at t = 127 finished, lapse: 1.177sec.
# optimization at t = 128 finished, lapse: 1.333sec.
# optimization at t = 129 finished, lapse: 1.425sec.
# optimization at t = 130 finished, lapse: 1.850sec.
# optimization at t = 131 finished, lapse: 1.508sec.
# optimization at t = 132 finished, lapse: 1.664sec.
# optimization at t = 133 finished, lapse: 1.200sec.
# optimization at t = 134 finished, lapse: 1.411sec.
# optimization at t = 135 finished, lapse: 0.831sec.
# optimization at t = 136 finished, lapse: 1.308sec.
# optimization at t = 137 finished, lapse: 1.323sec.
# optimization at t = 138 finished, lapse: 1.113sec.
# optimization at t = 139 finished, lapse: 1.469sec.
# optimization at t = 140 finished, lapse: 1.546sec.
# optimization at t = 141 finished, lapse: 1.490sec.
# optimization at t = 142 finished, lapse: 1.421sec.
# optimization at t = 143 finished, lapse: 1.227sec.
# optimization at t = 144 finished, lapse: 1.151sec.
# optimization at t = 145 finished, lapse: 1.440sec.
# optimization at t = 146 finished, lapse: 0.757sec.
# optimization at t = 147 finished, lapse: 2.423sec.
# optimization at t = 148 finished, lapse: 1.035sec.
# optimization at t = 149 finished, lapse: 6.865sec.
# optimization at t = 150 finished, lapse: 1.949sec.
# optimization at t = 151 finished, lapse: 2.397sec.
# optimization at t = 152 finished, lapse: 2.325sec.
# optimization at t = 153 finished, lapse: 1.635sec.
# optimization at t = 154 finished, lapse: 1.507sec.
# optimization at t = 155 finished, lapse: 2.335sec.
# optimization at t = 156 finished, lapse: 2.063sec.
# optimization at t = 157 finished, lapse: 1.754sec.
# optimization at t = 158 finished, lapse: 1.915sec.
# optimization at t = 159 finished, lapse: 1.820sec.
# optimization at t = 160 finished, lapse: 1.199sec.
# optimization at t = 161 finished, lapse: 2.919sec.
# optimization at t = 162 finished, lapse: 0.924sec.
# optimization at t = 163 finished, lapse: 1.157sec.
# optimization at t = 164 finished, lapse: 9.383sec.
# optimization at t = 165 finished, lapse: 3.771sec.
# optimization at t = 166 finished, lapse: 2.293sec.
# optimization at t = 167 finished, lapse: 2.737sec.
# optimization at t = 168 finished, lapse: 3.038sec.
# optimization at t = 169 finished, lapse: 2.109sec.
# optimization at t = 170 finished, lapse: 2.587sec.
# optimization at t = 171 finished, lapse: 1.700sec.
# optimization at t = 172 finished, lapse: 3.158sec.
# optimization at t = 173 finished, lapse: 2.043sec.
# optimization at t = 174 finished, lapse: 2.000sec.
# optimization at t = 175 finished, lapse: 3.585sec.
# optimization at t = 176 finished, lapse: 1.622sec.
# optimization at t = 177 finished, lapse: 1.780sec.
# optimization at t = 178 finished, lapse: 3.232sec.
# optimization at t = 179 finished, lapse: 1.792sec.
# optimization at t = 180 finished, lapse: 2.821sec.

# %%
plt.bar(np.arange(T), I, color='grey', alpha=0.5)
plt.plot(model.predict_I(Ae, mmle, bmle))
plt.fill_between(np.arange(np.shape(conf_band)[0]),
                 conf_band[:,0], conf_band[:,1], alpha=0.3)

# %%
conf_band, theta_min, theta_max = \
model.confidence_EY(Ae, mmle, bmle, np.linalg.inv(Ihat_dth)[1:,1:], chi_pa,
                    verbose=True)
# Out:
# optimization at t = 1 finished, lapse: 2.594sec.
# optimization at t = 2 finished, lapse: 1.579sec.
# optimization at t = 3 finished, lapse: 1.749sec.
# optimization at t = 4 finished, lapse: 1.889sec.
# optimization at t = 5 finished, lapse: 1.610sec.
# optimization at t = 6 finished, lapse: 2.484sec.
# optimization at t = 7 finished, lapse: 0.659sec.
# optimization at t = 8 finished, lapse: 0.694sec.
# optimization at t = 9 finished, lapse: 0.952sec.
# optimization at t = 10 finished, lapse: 1.726sec.
# optimization at t = 11 finished, lapse: 0.895sec.
# optimization at t = 12 finished, lapse: 0.867sec.
# optimization at t = 13 finished, lapse: 0.670sec.
# optimization at t = 14 finished, lapse: 0.687sec.
# optimization at t = 15 finished, lapse: 0.395sec.
# optimization at t = 16 finished, lapse: 0.275sec.
# optimization at t = 17 finished, lapse: 0.335sec.
# optimization at t = 18 finished, lapse: 0.283sec.
# optimization at t = 19 finished, lapse: 0.268sec.
# optimization at t = 20 finished, lapse: 0.104sec.
# optimization at t = 21 finished, lapse: 0.203sec.
# optimization at t = 22 finished, lapse: 0.188sec.
# optimization at t = 23 finished, lapse: 0.150sec.
# optimization at t = 24 finished, lapse: 0.112sec.
# optimization at t = 25 finished, lapse: 0.077sec.
# optimization at t = 26 finished, lapse: 0.093sec.
# optimization at t = 27 finished, lapse: 0.095sec.
# optimization at t = 28 finished, lapse: 0.096sec.
# optimization at t = 29 finished, lapse: 0.089sec.
# optimization at t = 30 finished, lapse: 0.087sec.
# optimization at t = 31 finished, lapse: 0.068sec.
# optimization at t = 32 finished, lapse: 0.072sec.
# optimization at t = 33 finished, lapse: 0.071sec.
# optimization at t = 34 finished, lapse: 0.071sec.
# optimization at t = 35 finished, lapse: 0.134sec.
# optimization at t = 36 finished, lapse: 0.063sec.
# optimization at t = 37 finished, lapse: 0.165sec.
# optimization at t = 38 finished, lapse: 0.199sec.
# optimization at t = 39 finished, lapse: 0.179sec.
# optimization at t = 40 finished, lapse: 0.072sec.
# optimization at t = 41 finished, lapse: 0.257sec.
# optimization at t = 42 finished, lapse: 0.178sec.
# optimization at t = 43 finished, lapse: 0.219sec.
# optimization at t = 44 finished, lapse: 0.177sec.
# optimization at t = 45 finished, lapse: 0.215sec.
# optimization at t = 46 finished, lapse: 0.223sec.
# optimization at t = 47 finished, lapse: 0.218sec.
# optimization at t = 48 finished, lapse: 0.151sec.
# optimization at t = 49 finished, lapse: 0.216sec.
# optimization at t = 50 finished, lapse: 0.151sec.
# optimization at t = 51 finished, lapse: 0.211sec.
# optimization at t = 52 finished, lapse: 0.160sec.
# optimization at t = 53 finished, lapse: 0.210sec.
# optimization at t = 54 finished, lapse: 0.236sec.
# optimization at t = 55 finished, lapse: 0.178sec.
# optimization at t = 56 finished, lapse: 0.194sec.
# optimization at t = 57 finished, lapse: 0.214sec.
# optimization at t = 58 finished, lapse: 0.204sec.
# optimization at t = 59 finished, lapse: 0.295sec.
# optimization at t = 60 finished, lapse: 0.097sec.
# optimization at t = 61 finished, lapse: 0.214sec.
# optimization at t = 62 finished, lapse: 0.152sec.
# optimization at t = 63 finished, lapse: 0.232sec.
# optimization at t = 64 finished, lapse: 0.200sec.
# optimization at t = 65 finished, lapse: 0.408sec.
# optimization at t = 66 finished, lapse: 0.430sec.
# optimization at t = 67 finished, lapse: 0.348sec.
# optimization at t = 68 finished, lapse: 0.379sec.
# optimization at t = 69 finished, lapse: 0.296sec.
# optimization at t = 70 finished, lapse: 0.463sec.
# optimization at t = 71 finished, lapse: 0.298sec.
# optimization at t = 72 finished, lapse: 0.425sec.
# optimization at t = 73 finished, lapse: 0.207sec.
# optimization at t = 74 finished, lapse: 0.299sec.
# optimization at t = 75 finished, lapse: 0.416sec.
# optimization at t = 76 finished, lapse: 0.229sec.
# optimization at t = 77 finished, lapse: 0.423sec.
# optimization at t = 78 finished, lapse: 0.359sec.
# optimization at t = 79 finished, lapse: 0.467sec.
# optimization at t = 80 finished, lapse: 0.459sec.
# optimization at t = 81 finished, lapse: 0.272sec.
# optimization at t = 82 finished, lapse: 0.368sec.
# optimization at t = 83 finished, lapse: 0.349sec.
# optimization at t = 84 finished, lapse: 0.259sec.
# optimization at t = 85 finished, lapse: 0.313sec.
# optimization at t = 86 finished, lapse: 0.397sec.
# optimization at t = 87 finished, lapse: 0.241sec.
# optimization at t = 88 finished, lapse: 0.433sec.
# optimization at t = 89 finished, lapse: 0.263sec.
# optimization at t = 90 finished, lapse: 0.287sec.
# optimization at t = 91 finished, lapse: 0.436sec.
# optimization at t = 92 finished, lapse: 0.351sec.
# optimization at t = 93 finished, lapse: 0.368sec.
# optimization at t = 94 finished, lapse: 0.350sec.
# optimization at t = 95 finished, lapse: 0.203sec.
# optimization at t = 96 finished, lapse: 0.155sec.
# optimization at t = 97 finished, lapse: 0.424sec.
# optimization at t = 98 finished, lapse: 0.470sec.
# optimization at t = 99 finished, lapse: 0.323sec.
# optimization at t = 100 finished, lapse: 0.419sec.
# optimization at t = 101 finished, lapse: 0.365sec.
# optimization at t = 102 finished, lapse: 0.434sec.
# optimization at t = 103 finished, lapse: 0.455sec.
# optimization at t = 104 finished, lapse: 0.816sec.
# optimization at t = 105 finished, lapse: 0.462sec.
# optimization at t = 106 finished, lapse: 1.101sec.
# optimization at t = 107 finished, lapse: 0.308sec.
# optimization at t = 108 finished, lapse: 0.570sec.
# optimization at t = 109 finished, lapse: 0.934sec.
# optimization at t = 110 finished, lapse: 0.658sec.
# optimization at t = 111 finished, lapse: 1.022sec.
# optimization at t = 112 finished, lapse: 0.453sec.
# optimization at t = 113 finished, lapse: 0.926sec.
# optimization at t = 114 finished, lapse: 1.458sec.
# optimization at t = 115 finished, lapse: 0.378sec.
# optimization at t = 116 finished, lapse: 0.377sec.
# optimization at t = 117 finished, lapse: 0.818sec.
# optimization at t = 118 finished, lapse: 0.551sec.
# optimization at t = 119 finished, lapse: 0.660sec.
# optimization at t = 120 finished, lapse: 0.730sec.
# optimization at t = 121 finished, lapse: 0.768sec.
# optimization at t = 122 finished, lapse: 0.300sec.
# optimization at t = 123 finished, lapse: 0.588sec.
# optimization at t = 124 finished, lapse: 0.311sec.
# optimization at t = 125 finished, lapse: 1.192sec.
# optimization at t = 126 finished, lapse: 0.966sec.
# optimization at t = 127 finished, lapse: 0.767sec.
# optimization at t = 128 finished, lapse: 0.414sec.
# optimization at t = 129 finished, lapse: 0.268sec.
# optimization at t = 130 finished, lapse: 0.899sec.
# optimization at t = 131 finished, lapse: 0.558sec.
# optimization at t = 132 finished, lapse: 0.744sec.
# optimization at t = 133 finished, lapse: 0.330sec.
# optimization at t = 134 finished, lapse: 0.439sec.
# optimization at t = 135 finished, lapse: 0.304sec.
# optimization at t = 136 finished, lapse: 0.275sec.
# optimization at t = 137 finished, lapse: 0.259sec.
# optimization at t = 138 finished, lapse: 0.358sec.
# optimization at t = 139 finished, lapse: 0.313sec.
# optimization at t = 140 finished, lapse: 0.784sec.
# optimization at t = 141 finished, lapse: 0.300sec.
# optimization at t = 142 finished, lapse: 0.722sec.
# optimization at t = 143 finished, lapse: 0.813sec.
# optimization at t = 144 finished, lapse: 0.529sec.
# optimization at t = 145 finished, lapse: 0.922sec.
# optimization at t = 146 finished, lapse: 0.885sec.
# optimization at t = 147 finished, lapse: 0.591sec.
# optimization at t = 148 finished, lapse: 1.269sec.
# optimization at t = 149 finished, lapse: 0.845sec.
# optimization at t = 150 finished, lapse: 0.921sec.
# optimization at t = 151 finished, lapse: 1.640sec.
# optimization at t = 152 finished, lapse: 1.079sec.
# optimization at t = 153 finished, lapse: 1.280sec.
# optimization at t = 154 finished, lapse: 1.070sec.
# optimization at t = 155 finished, lapse: 1.446sec.
# optimization at t = 156 finished, lapse: 1.707sec.
# optimization at t = 157 finished, lapse: 1.393sec.
# optimization at t = 158 finished, lapse: 1.622sec.
# optimization at t = 159 finished, lapse: 0.687sec.
# optimization at t = 160 finished, lapse: 1.399sec.
# optimization at t = 161 finished, lapse: 1.438sec.
# optimization at t = 162 finished, lapse: 1.419sec.
# optimization at t = 163 finished, lapse: 1.319sec.
# optimization at t = 164 finished, lapse: 2.141sec.
# optimization at t = 165 finished, lapse: 0.909sec.
# optimization at t = 166 finished, lapse: 1.753sec.
# optimization at t = 167 finished, lapse: 1.945sec.
# optimization at t = 168 finished, lapse: 1.264sec.
# optimization at t = 169 finished, lapse: 1.283sec.
# optimization at t = 170 finished, lapse: 1.552sec.
# optimization at t = 171 finished, lapse: 1.639sec.
# optimization at t = 172 finished, lapse: 1.823sec.
# optimization at t = 173 finished, lapse: 0.831sec.
# optimization at t = 174 finished, lapse: 1.732sec.
# optimization at t = 175 finished, lapse: 5.270sec.
# optimization at t = 176 finished, lapse: 1.864sec.
# optimization at t = 177 finished, lapse: 2.169sec.
# optimization at t = 178 finished, lapse: 1.813sec.
# optimization at t = 179 finished, lapse: 1.686sec.
# optimization at t = 180 finished, lapse: 1.986sec.

# %%
plt.bar(np.arange(T), Y, color='grey', alpha=0.5)
plt.plot(model.predict_EY(Ae, mmle, bmle))
plt.fill_between(np.arange(np.shape(conf_band)[0]),
                 conf_band[:,0], conf_band[:,1], alpha=0.3)
plt.ylim(0,2000)
# Out:
# (0.0, 2000.0)

# %% [markdown]
# # 7. Model checking

# %% [markdown]
# ## model diagnostics

# %%
p_stdrd = np.zeros(T)
t_stdrd = np.zeros(T)

# %%
for t in np.arange(T):
    EYmle = model.predict_EY(A, mmle, bmle)
    
    p_stdrd[t] = stats.nbinom.cdf(Y[t], nmle, nmle/(nmle+EYmle[t]))
    t_stdrd[t] = (Y[t] - EYmle[t]) / np.sqrt(EYmle[t] * (nmle + EYmle[t]) / nmle)

# %%
plt.figure(figsize=(4,3))
plt.scatter(np.arange(T), t_stdrd, color='blue')
plt.axhline(y=0, linewidth=1, color='black')
plt.axhline(y=stats.t.ppf(0.025/(T-d), df=T-d), linewidth=1, color='red', linestyle='--')
plt.axhline(y=-stats.t.ppf(0.025/(T-d), df=T-d), linewidth=1, color='red', linestyle='--')
plt.xlabel('time $t$')
plt.ylabel(r'standardized residuals')
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(4,3))
plt.boxplot([t_stdrd[A[:,-1]==0], t_stdrd[A[:,-1]==1]], labels=[0,1])
plt.axhline(y=0, linewidth=1, color='black')
plt.axhline(y=stats.t.ppf(0.025/(T-d), df=T-d), linewidth=1, color='red', linestyle='--')
plt.axhline(y=-stats.t.ppf(0.025/(T-d), df=T-d), linewidth=1, color='red', linestyle='--')
plt.xlabel('intervention')
plt.ylabel(r'standardized residuals')
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(4,3))
plt.scatter(EYmle, t_stdrd, color='blue', s=5)
plt.axhline(y=0, linewidth=1, color='black')
plt.axhline(y=stats.t.ppf(0.025/(T-d), df=T-d), linewidth=1, color='red', linestyle='--')
plt.axhline(y=-stats.t.ppf(0.025/(T-d), df=T-d), linewidth=1, color='red', linestyle='--')
plt.xlabel('fitted values')
plt.ylabel(r'standardized residuals')
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(4,3))
stats.probplot(t_stdrd, dist="norm", plot=plt, fit=False)
plt.gca().get_lines()[0].set_markersize(3)
plt.plot([-2.5, 3.5], [-2.5, 3.5], color='red', linestyle='--')
plt.title('')
plt.ylabel(r'Ordered standardized residuals')
plt.show()

# %%
plt.figure(figsize=(4,3))
plt.scatter(np.arange(T), p_stdrd, color='blue')
plt.axhline(y=0.025/(T-d), linewidth=1, color='red', linestyle='--')
plt.axhline(y=1-0.025/(T-d), linewidth=1, color='red', linestyle='--')
plt.xlabel('time $t$')
plt.ylabel(r'standardized residuals')
# Out:
# Text(0, 0.5, 'standardized residuals')

# %%
plt.figure(figsize=(4,3))
plt.boxplot([p_stdrd[A[:,-1]==0], p_stdrd[A[:,-1]==1]], labels=[0,1])
plt.axhline(y=0.025/(T-d), linewidth=1, color='red', linestyle='--')
plt.axhline(y=1-0.025/(T-d), linewidth=1, color='red', linestyle='--')
plt.xlabel('intervention')
plt.ylabel(r'p-residuals')
# Out:
# Text(0, 0.5, 'p-residuals')

# %%
plt.figure(figsize=(4,3))
plt.scatter(EYmle, p_stdrd, color='blue')
plt.axhline(y=0.025/(T-d), linewidth=1, color='red', linestyle='--')
plt.axhline(y=1-0.025/(T-d), linewidth=1, color='red', linestyle='--')
plt.xlabel('fitted values')
plt.ylabel(r'p-residuals')
# Out:
# Text(0, 0.5, 'p-residuals')

# %%
plt.figure(figsize=(4,3))
stats.probplot(p_stdrd, dist="uniform", plot=plt, fit=False)
plt.plot([0, 1], [0, 1], color='red', linestyle='--')
plt.title('')
plt.ylabel(r'Ordered p-residuals')
plt.show()

# %% [markdown]
# ## case diagnostics

# %%
tmts = np.zeros((T, d+2))

# %%
for t in np.arange(T):
    start_iter = time.time()
    
    Ymt = Y.copy().astype(float)
    Ymt[t] = np.nan
    
    nmt, mmt, bmt, _ =\
    model.fit(A, Ymt, n_iter=500, step_size=1,
              minit = mmle, binit = bmle,
              history=False, verbose=False)
    
    tmts[t] = np.array((nmt, mmt, *bmt))
    
    print("Leave-one-out estimation at t = %d finished, lapse: %.3fsec."
          %(t+1, time.time()-start_iter))
# Out:
# Leave-one-out estimation at t = 1 finished, lapse: 16.540sec.
# Leave-one-out estimation at t = 2 finished, lapse: 13.957sec.
# Leave-one-out estimation at t = 3 finished, lapse: 14.521sec.
# Leave-one-out estimation at t = 4 finished, lapse: 13.930sec.
# Leave-one-out estimation at t = 5 finished, lapse: 15.328sec.
# Leave-one-out estimation at t = 6 finished, lapse: 14.610sec.
# Leave-one-out estimation at t = 7 finished, lapse: 14.462sec.
# Leave-one-out estimation at t = 8 finished, lapse: 14.678sec.
# Leave-one-out estimation at t = 9 finished, lapse: 13.899sec.
# Leave-one-out estimation at t = 10 finished, lapse: 13.143sec.
# Leave-one-out estimation at t = 11 finished, lapse: 13.612sec.
# Leave-one-out estimation at t = 12 finished, lapse: 13.978sec.
# Leave-one-out estimation at t = 13 finished, lapse: 13.295sec.
# Leave-one-out estimation at t = 14 finished, lapse: 12.300sec.
# Leave-one-out estimation at t = 15 finished, lapse: 12.817sec.
# Leave-one-out estimation at t = 16 finished, lapse: 13.644sec.
# Leave-one-out estimation at t = 17 finished, lapse: 12.977sec.
# Leave-one-out estimation at t = 18 finished, lapse: 13.170sec.
# Leave-one-out estimation at t = 19 finished, lapse: 13.328sec.
# Leave-one-out estimation at t = 20 finished, lapse: 13.679sec.
# Leave-one-out estimation at t = 21 finished, lapse: 13.384sec.
# Leave-one-out estimation at t = 22 finished, lapse: 13.031sec.
# Leave-one-out estimation at t = 23 finished, lapse: 13.192sec.
# Leave-one-out estimation at t = 24 finished, lapse: 12.747sec.
# Leave-one-out estimation at t = 25 finished, lapse: 13.095sec.
# Leave-one-out estimation at t = 26 finished, lapse: 13.334sec.
# Leave-one-out estimation at t = 27 finished, lapse: 16.684sec.
# Leave-one-out estimation at t = 28 finished, lapse: 13.840sec.
# Leave-one-out estimation at t = 29 finished, lapse: 15.283sec.
# Leave-one-out estimation at t = 30 finished, lapse: 15.201sec.
# Leave-one-out estimation at t = 31 finished, lapse: 13.575sec.
# Leave-one-out estimation at t = 32 finished, lapse: 13.498sec.
# Leave-one-out estimation at t = 33 finished, lapse: 14.270sec.
# Leave-one-out estimation at t = 34 finished, lapse: 15.564sec.
# Leave-one-out estimation at t = 35 finished, lapse: 13.907sec.
# Leave-one-out estimation at t = 36 finished, lapse: 15.194sec.
# Leave-one-out estimation at t = 37 finished, lapse: 14.851sec.
# Leave-one-out estimation at t = 38 finished, lapse: 15.393sec.
# Leave-one-out estimation at t = 39 finished, lapse: 14.675sec.
# Leave-one-out estimation at t = 40 finished, lapse: 14.899sec.
# Leave-one-out estimation at t = 41 finished, lapse: 15.929sec.
# Leave-one-out estimation at t = 42 finished, lapse: 14.852sec.
# Leave-one-out estimation at t = 43 finished, lapse: 14.015sec.
# Leave-one-out estimation at t = 44 finished, lapse: 14.215sec.
# Leave-one-out estimation at t = 45 finished, lapse: 14.807sec.
# Leave-one-out estimation at t = 46 finished, lapse: 14.160sec.
# Leave-one-out estimation at t = 47 finished, lapse: 14.835sec.
# Leave-one-out estimation at t = 48 finished, lapse: 14.764sec.
# Leave-one-out estimation at t = 49 finished, lapse: 15.820sec.
# Leave-one-out estimation at t = 50 finished, lapse: 13.836sec.
# Leave-one-out estimation at t = 51 finished, lapse: 13.982sec.
# Leave-one-out estimation at t = 52 finished, lapse: 13.297sec.
# Leave-one-out estimation at t = 53 finished, lapse: 13.652sec.
# Leave-one-out estimation at t = 54 finished, lapse: 14.504sec.
# Leave-one-out estimation at t = 55 finished, lapse: 7.429sec.
# Leave-one-out estimation at t = 56 finished, lapse: 7.336sec.
# Leave-one-out estimation at t = 57 finished, lapse: 7.518sec.
# Leave-one-out estimation at t = 58 finished, lapse: 7.257sec.
# Leave-one-out estimation at t = 59 finished, lapse: 7.770sec.
# Leave-one-out estimation at t = 60 finished, lapse: 7.101sec.
# Leave-one-out estimation at t = 61 finished, lapse: 6.842sec.
# Leave-one-out estimation at t = 62 finished, lapse: 7.423sec.
# Leave-one-out estimation at t = 63 finished, lapse: 6.932sec.
# Leave-one-out estimation at t = 64 finished, lapse: 6.869sec.
# Leave-one-out estimation at t = 65 finished, lapse: 6.840sec.
# Leave-one-out estimation at t = 66 finished, lapse: 6.987sec.
# Leave-one-out estimation at t = 67 finished, lapse: 6.836sec.
# Leave-one-out estimation at t = 68 finished, lapse: 7.228sec.
# Leave-one-out estimation at t = 69 finished, lapse: 7.153sec.
# Leave-one-out estimation at t = 70 finished, lapse: 6.844sec.
# Leave-one-out estimation at t = 71 finished, lapse: 7.097sec.
# Leave-one-out estimation at t = 72 finished, lapse: 6.861sec.
# Leave-one-out estimation at t = 73 finished, lapse: 7.819sec.
# Leave-one-out estimation at t = 74 finished, lapse: 6.978sec.
# Leave-one-out estimation at t = 75 finished, lapse: 7.056sec.
# Leave-one-out estimation at t = 76 finished, lapse: 6.929sec.
# Leave-one-out estimation at t = 77 finished, lapse: 7.069sec.
# Leave-one-out estimation at t = 78 finished, lapse: 6.952sec.
# Leave-one-out estimation at t = 79 finished, lapse: 7.281sec.
# Leave-one-out estimation at t = 80 finished, lapse: 6.896sec.
# Leave-one-out estimation at t = 81 finished, lapse: 6.884sec.
# Leave-one-out estimation at t = 82 finished, lapse: 6.921sec.
# Leave-one-out estimation at t = 83 finished, lapse: 6.969sec.
# Leave-one-out estimation at t = 84 finished, lapse: 7.083sec.
# Leave-one-out estimation at t = 85 finished, lapse: 7.031sec.
# Leave-one-out estimation at t = 86 finished, lapse: 6.968sec.
# Leave-one-out estimation at t = 87 finished, lapse: 6.976sec.
# Leave-one-out estimation at t = 88 finished, lapse: 6.934sec.
# Leave-one-out estimation at t = 89 finished, lapse: 7.000sec.
# Leave-one-out estimation at t = 90 finished, lapse: 6.947sec.
# Leave-one-out estimation at t = 91 finished, lapse: 6.862sec.
# Leave-one-out estimation at t = 92 finished, lapse: 6.782sec.
# Leave-one-out estimation at t = 93 finished, lapse: 7.009sec.
# Leave-one-out estimation at t = 94 finished, lapse: 7.126sec.
# Leave-one-out estimation at t = 95 finished, lapse: 6.911sec.
# Leave-one-out estimation at t = 96 finished, lapse: 6.923sec.
# Leave-one-out estimation at t = 97 finished, lapse: 6.884sec.
# Leave-one-out estimation at t = 98 finished, lapse: 6.924sec.
# Leave-one-out estimation at t = 99 finished, lapse: 7.038sec.
# Leave-one-out estimation at t = 100 finished, lapse: 6.906sec.
# Leave-one-out estimation at t = 101 finished, lapse: 6.938sec.
# Leave-one-out estimation at t = 102 finished, lapse: 7.078sec.
# Leave-one-out estimation at t = 103 finished, lapse: 6.897sec.
# Leave-one-out estimation at t = 104 finished, lapse: 7.115sec.
# Leave-one-out estimation at t = 105 finished, lapse: 6.951sec.
# Leave-one-out estimation at t = 106 finished, lapse: 7.208sec.
# Leave-one-out estimation at t = 107 finished, lapse: 7.034sec.
# Leave-one-out estimation at t = 108 finished, lapse: 6.911sec.
# Leave-one-out estimation at t = 109 finished, lapse: 7.050sec.
# Leave-one-out estimation at t = 110 finished, lapse: 7.136sec.
# Leave-one-out estimation at t = 111 finished, lapse: 6.875sec.
# Leave-one-out estimation at t = 112 finished, lapse: 6.999sec.
# Leave-one-out estimation at t = 113 finished, lapse: 6.861sec.
# Leave-one-out estimation at t = 114 finished, lapse: 6.841sec.
# Leave-one-out estimation at t = 115 finished, lapse: 6.838sec.
# Leave-one-out estimation at t = 116 finished, lapse: 6.933sec.
# Leave-one-out estimation at t = 117 finished, lapse: 6.809sec.
# Leave-one-out estimation at t = 118 finished, lapse: 7.077sec.
# Leave-one-out estimation at t = 119 finished, lapse: 7.271sec.
# Leave-one-out estimation at t = 120 finished, lapse: 7.246sec.

# %%
# np.savez("result_freqepid_nbinom_randinf.npz",
#          nmle = nmle, mmle = mmle, bmle =  bmle, EYmle = EYmle,
#          tmts = tmts)

# %%
locals().update(
    np.load("result_freqepid_nbinom_randinf.npz")
)

# %%
leverage = np.zeros(T)
cook_dist = np.zeros(T)
p_stdnt = np.zeros(T)
t_stdnt = np.zeros(T)

# %%
MSE = np.sum((Y - EYmle)**2) / (T - (d+1))

# %%
for t in np.arange(T):
    nmt = tmts[t,0]
    mmt = tmts[t,1]
    bmt = tmts[t,2:]
    EYmt = model.predict_EY(A, mmt, bmt)
    
    leverage[t] = (bmt[-1] - bmle[-1]) / np.sqrt(la.inv(Ihat_sdw)[-1,-1])
    cook_dist[t] = np.sum((EYmt - EYmle)**2) / (d+1) / MSE
    p_stdnt[t] = stats.nbinom.cdf(Y[t], nmt, nmt/(nmt+EYmt[t]))
    t_stdnt[t] = (Y[t] - EYmt[t]) / np.sqrt(EYmt[t] * (nmt + EYmt[t]) / nmt)

# %%
plt.figure(figsize=(4,3))
plt.scatter(np.arange(T), leverage, color='blue', s=3)
plt.axhline(y=0, color='black', linewidth=1)
plt.xlabel('time $t$')
plt.ylabel(r"influence measure")
# Out:
# Text(0, 0.5, 'influence measure')

# %%
plt.figure(figsize=(4,3))
plt.bar(np.arange(T), cook_dist, color='blue')
plt.xlabel('time $t$'); plt.ylabel("Cook's distance")
# Out:
# Text(0, 0.5, "Cook's distance")

# %%
plt.figure(figsize=(4,3))
plt.scatter(np.arange(T), t_stdrd, color='blue', alpha=0.5, s=5, label='standardized')
plt.scatter(np.arange(T)+0.5, t_stdnt, color='orange', alpha=0.5, s=5, label='studentized')
plt.axhline(y=0, linewidth=1, color='black')
plt.axhline(y=stats.t.ppf(0.025/(T-d), df=T-d), linewidth=1, color='red', linestyle='--')
plt.axhline(y=-stats.t.ppf(0.025/(T-d), df=T-d), linewidth=1, color='red', linestyle='--')
plt.xlabel('time $t$') 
plt.ylabel(r'residuals')
plt.legend(); plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(4,3))
plt.scatter(np.arange(T), p_stdnt, color='blue')
plt.axhline(y=0.025/(T-d), linewidth=1, color='red', linestyle='--')
plt.axhline(y=1-0.025/(T-d), linewidth=1, color='red', linestyle='--')
plt.xlabel('time $t$')
plt.ylabel(r'studentized p-residuals')
# Out:
# Text(0, 0.5, 'studentized p-residuals')
