# %%
import os, importlib, sys, time

# %%
import numpy as np
import pandas as pd
import pyarrow
import matplotlib.pyplot as plt

# %%
import scipy.linalg as la
import scipy.stats as stats

# %%
import covidcast
from datetime import date

# %%
# %load_ext jupyternotify

# %%
data = pd.read_feather('data/CovidCastStateAdj_2.feather').iloc[:,:-1]

# %%
data
# Out:
#      geo_value time_value    deaths  completely_home_prop  \
# 0           al 2020-01-22  0.000000              0.183999
# 1           al 2020-01-23  0.000000              0.171479
# 2           al 2020-01-24  0.000000              0.169182
# 3           al 2020-01-25  0.000000              0.172661
# 4           al 2020-01-26  0.000000              0.193669
# ...        ...        ...       ...                   ...
# 9066        wv 2020-07-28  0.672611              0.273833
# 9067        wv 2020-07-29  1.642459              0.270546
# 9068        wv 2020-07-30  1.000000              0.266332
# 9069        wv 2020-07-31  4.000000              0.246038
# 9070        wv 2020-08-01  2.354288              0.267746
#
#       median_home_dwell_time  full_time_work_prop  part_time_work_prop
# 0                 655.805922             0.086965             0.151171
# 1                 636.370230             0.103856             0.161668
# 2                 596.711830             0.104405             0.174012
# 3                 687.538565             0.083919             0.149298
# 4                 699.710495             0.087651             0.152943
# ...                      ...                  ...                  ...
# 9066              646.344539             0.039517             0.062896
# 9067              637.137487             0.042846             0.068807
# 9068              606.638365             0.051520             0.079922
# 9069              599.132159             0.041380             0.067567
# 9070              639.938795             0.041526             0.064499
#
# [9071 rows x 7 columns]

# %%
iv=[5]

# %%
Y_raw = np.array(data[data.geo_value == 'ny'].deaths)
A_raw = np.array(data[data.geo_value == 'ny'].iloc[:,iv])

# %%
Y_raw.shape, A_raw.shape
# Out:
# ((193,), (193, 1))

# %%
plt.plot(Y_raw)

# %%
plt.plot(A_raw/np.max(A_raw, 0), label=iv)
plt.legend()

# %% [markdown]
# # 2. EDA

# %%
POI = np.sum(np.cumsum(Y_raw) < 10)
Y_data = np.maximum(np.round(Y_raw[POI:]), 0).astype(int)

# %%
T = Y_data.shape[0]
T0 = 20
alpha = 1
K = 6.5

# %%
plt.plot(Y_data)

# %%
GPi = np.load('data/GPi.npz')

# %%
# g
g = np.zeros(T+T0)
g[:GPi['g'].shape[0]] = GPi['g']
plt.plot(g)

# %%
# pi
pi = np.zeros(T+T0)
pi[:GPi['pi'].shape[0]] = GPi['pi']
plt.plot(pi)

# %%
# A
d = len(iv)+1
A = np.zeros([T+T0, d])

# %%
A[:,0] = np.full(T+T0, 1)
A[:,1:] = A_raw[POI-T0:,:]/np.max(A_raw[:,:], 0)

# %%
plt.plot(A)
# Out:
# [<matplotlib.lines.Line2D at 0x168b2a6b0>,
#  <matplotlib.lines.Line2D at 0x168b2a710>]

# %% [markdown]
# # 3. fit by EM algorithm

# %%
def fit(obs, minit_0, sinit_eps, binit,
        n_iter=3000, history=False, verbose=False, step_size=0.1):
    
    mhat_0=minit_0
    shat_eps = sinit_eps
    bhat=binit
    ss=np.inf
    
    # mhat = np.concatenate([[mhat_0], np.zeros(T+T0-1)])
    
    if history:
        mhs_0 = np.zeros(n_iter)
        shs_eps = np.zeros(n_iter)
        bhs = np.zeros([n_iter, d])
        
    Rhat = np.zeros(T+T0)
    d1Rh = np.zeros([d, T+T0])
    d2Rh = np.zeros([d, d, T+T0])
    
    for t in np.arange(T+T0):
        o = np.exp(- bhat @ A[t])
        p = 1 / (1 + o)
        q = o / (1 + o)

        Rhat[t] = K * p
        d1Rh[:,t] = K * p * q * A[t]
        d2Rh[:,:,t] = K * p * q * (q - p) * (A[t,:,None] * A[t])

    Pi = alpha * np.concatenate([[0],pi])[np.maximum(0, T0 + np.arange(T)[:,None] - np.arange(T+T0))]
    G = Rhat[:,None] * np.concatenate([[0],g])[np.maximum(0, np.arange(T+T0)[:,None] - np.arange(T+T0))]
    inv_ImG = la.inv(np.eye(T+T0)-G)
    Pi_inv_ImG = Pi @ inv_ImG
    
    EY = mhat_0 * Pi_inv_ImG[:,0]
    shat_eps = np.sqrt(np.sum((obs-EY)**2)/T)
    
    if verbose:
        print("Before EM, shat_eps: %f"%shat_eps)
    
    for i in np.arange(n_iter):
        start_iter = time.time()

        # iteration for mu
        mhat_0 = (obs @ Pi_inv_ImG[:,0]) / np.sum((Pi_inv_ImG[:,0])**2)
        # mhat = np.concatenate([[mhat_0], np.zeros(T+T0-1)])
        
        # iteration for beta
        d1G = d1Rh[:,:,None] * np.concatenate([[0],g])[
                np.maximum(0, np.arange(T+T0)[:,None] - np.arange(T+T0))]
        d2G = d2Rh[...,None] * np.concatenate([[0],g])[
                np.maximum(0, np.arange(T+T0)[:,None] - np.arange(T+T0))]
        
        EY = mhat_0 * Pi_inv_ImG[:,0]
        d1EY = mhat_0 * (Pi_inv_ImG @ (d1G @ inv_ImG[:,:1]))[...,0]
        d2EY = mhat_0 * (Pi_inv_ImG @ (
            d1G[:,None] @ inv_ImG @ d1G @ inv_ImG[:,:1]
            + d1G @ inv_ImG @ d1G[:,None] @ inv_ImG[:,:1]
            + d2G @ inv_ImG[:,:1]))[...,0]
        
        d1f = - (2/(T+T0)/shat_eps**2) * d1EY @ (obs - EY)
        d2f = (2/(T+T0)/shat_eps**2) * (d1EY @ d1EY.T - d2EY @ (obs-EY))
        
        u, v = la.eig(d2f)
        db = np.real(((v/np.maximum(u,np.max(u)/100)) @ v.T) @ d1f)
        ss = np.min([ss, step_size/np.sqrt(np.sum(db**2))])
        bhat = bhat - ss * db
        
        for t in np.arange(T+T0):
            o = np.exp(- bhat @ A[t])
            p = 1 / (1 + o)
            q = o / (1 + o)

            Rhat[t] = K * p
            d1Rh[:,t] = K * p * q * A[t]
            d2Rh[:,:,t] = K * p * q * (q - p) * (A[t,:,None] * A[t])

        Pi = alpha * np.concatenate([[0],pi])[np.maximum(0, T0 + np.arange(T)[:,None] - np.arange(T+T0))]
        G = Rhat[:,None] * np.concatenate([[0],g])[np.maximum(0, np.arange(T+T0)[:,None] - np.arange(T+T0))]
        inv_ImG = la.inv(np.eye(T+T0)-G)
        Pi_inv_ImG = Pi @ inv_ImG
    
        EY = mhat_0 * Pi_inv_ImG[:,0]
        shat_eps = np.sqrt(np.sum((obs-EY)**2)/T)
    
        if history:
            mhs_0[i] = mhat_0
            shs_eps[i] = shat_eps
            bhs[i] = bhat
        
        if verbose:
            print("%d-th iteration finished, shat_eps: %f, lapse: %.3fsec."
                  %(i+1, shat_eps, time.time()-start_iter))
            
    if history:
        return mhs_0, shs_eps, bhs
    else:
        return mhat_0, shat_eps, bhat

# %%
mmle_0 = 17.4
smle_eps = 138.5
bmle = np.array([0.207, 1.872])

# %%
# %%notify
# mhs_0, shs_eps, bhs =\
#     fit(Y_data, mmle_0, smle_eps, bmle,
#         history=True, verbose=True, n_iter=2000, step_size=0.05)
# Out:
# Before EM, shat_eps: 322682529963548800.000000
# 1-th iteration finished, shat_eps: 373.607871, lapse: 0.028sec.
# 2-th iteration finished, shat_eps: 373.607811, lapse: 0.024sec.
# 3-th iteration finished, shat_eps: 373.607748, lapse: 0.010sec.
# 4-th iteration finished, shat_eps: 373.607684, lapse: 0.005sec.
# 5-th iteration finished, shat_eps: 373.607618, lapse: 0.020sec.
# 6-th iteration finished, shat_eps: 373.607551, lapse: 0.007sec.
# 7-th iteration finished, shat_eps: 373.607481, lapse: 0.009sec.
# 8-th iteration finished, shat_eps: 373.607409, lapse: 0.015sec.
# 9-th iteration finished, shat_eps: 373.607334, lapse: 0.008sec.
# 10-th iteration finished, shat_eps: 373.607258, lapse: 0.006sec.
# 11-th iteration finished, shat_eps: 373.607179, lapse: 0.021sec.
# 12-th iteration finished, shat_eps: 373.607097, lapse: 0.007sec.
# 13-th iteration finished, shat_eps: 373.607013, lapse: 0.023sec.
# 14-th iteration finished, shat_eps: 373.606926, lapse: 0.034sec.
# 15-th iteration finished, shat_eps: 373.606835, lapse: 0.013sec.
# 16-th iteration finished, shat_eps: 373.606742, lapse: 0.026sec.
# 17-th iteration finished, shat_eps: 373.606645, lapse: 0.025sec.
# 18-th iteration finished, shat_eps: 373.606545, lapse: 0.010sec.
# 19-th iteration finished, shat_eps: 373.606441, lapse: 0.009sec.
# 20-th iteration finished, shat_eps: 373.606333, lapse: 0.020sec.
# 21-th iteration finished, shat_eps: 373.606221, lapse: 0.009sec.
# 22-th iteration finished, shat_eps: 373.606104, lapse: 0.006sec.
# 23-th iteration finished, shat_eps: 373.605983, lapse: 0.065sec.
# 24-th iteration finished, shat_eps: 373.605856, lapse: 0.035sec.
# 25-th iteration finished, shat_eps: 373.605724, lapse: 0.026sec.
# 26-th iteration finished, shat_eps: 373.605586, lapse: 0.022sec.
# 27-th iteration finished, shat_eps: 373.605442, lapse: 0.009sec.
# 28-th iteration finished, shat_eps: 373.605292, lapse: 0.005sec.
# 29-th iteration finished, shat_eps: 373.605134, lapse: 0.013sec.
# 30-th iteration finished, shat_eps: 373.604968, lapse: 0.014sec.
# 31-th iteration finished, shat_eps: 373.604794, lapse: 0.006sec.
# 32-th iteration finished, shat_eps: 373.604611, lapse: 0.003sec.
# 33-th iteration finished, shat_eps: 373.604418, lapse: 0.030sec.
# 34-th iteration finished, shat_eps: 373.604214, lapse: 0.023sec.
# 35-th iteration finished, shat_eps: 373.603999, lapse: 0.026sec.
# 36-th iteration finished, shat_eps: 373.603771, lapse: 0.016sec.
# 37-th iteration finished, shat_eps: 373.603529, lapse: 0.022sec.
# 38-th iteration finished, shat_eps: 373.603271, lapse: 0.015sec.
# 39-th iteration finished, shat_eps: 373.602996, lapse: 0.013sec.
# 40-th iteration finished, shat_eps: 373.602702, lapse: 0.005sec.
# 41-th iteration finished, shat_eps: 373.602388, lapse: 0.004sec.
# 42-th iteration finished, shat_eps: 373.602049, lapse: 0.009sec.
# 43-th iteration finished, shat_eps: 373.601684, lapse: 0.026sec.
# 44-th iteration finished, shat_eps: 373.601288, lapse: 0.005sec.
# 45-th iteration finished, shat_eps: 373.600858, lapse: 0.004sec.
# 46-th iteration finished, shat_eps: 373.600388, lapse: 0.016sec.
# 47-th iteration finished, shat_eps: 373.599873, lapse: 0.004sec.
# 48-th iteration finished, shat_eps: 373.599305, lapse: 0.008sec.
# 49-th iteration finished, shat_eps: 373.598675, lapse: 0.007sec.
# 50-th iteration finished, shat_eps: 373.597432, lapse: 0.019sec.
# 51-th iteration finished, shat_eps: 373.596030, lapse: 0.007sec.
# 52-th iteration finished, shat_eps: 373.594466, lapse: 0.007sec.
# 53-th iteration finished, shat_eps: 373.592722, lapse: 0.012sec.
# 54-th iteration finished, shat_eps: 373.590775, lapse: 0.011sec.
# 55-th iteration finished, shat_eps: 373.588600, lapse: 0.004sec.
# 56-th iteration finished, shat_eps: 373.586168, lapse: 0.005sec.
# 57-th iteration finished, shat_eps: 373.583445, lapse: 0.017sec.
# 58-th iteration finished, shat_eps: 373.580393, lapse: 0.005sec.
# 59-th iteration finished, shat_eps: 373.576961, lapse: 0.008sec.
# 60-th iteration finished, shat_eps: 373.573092, lapse: 0.022sec.
# 61-th iteration finished, shat_eps: 373.568707, lapse: 0.012sec.
# 62-th iteration finished, shat_eps: 373.563712, lapse: 0.013sec.
# 63-th iteration finished, shat_eps: 373.557981, lapse: 0.015sec.
# 64-th iteration finished, shat_eps: 373.551359, lapse: 0.007sec.
# 65-th iteration finished, shat_eps: 373.543643, lapse: 0.014sec.
# 66-th iteration finished, shat_eps: 373.534576, lapse: 0.004sec.
# 67-th iteration finished, shat_eps: 373.523826, lapse: 0.008sec.
# 68-th iteration finished, shat_eps: 373.510970, lapse: 0.008sec.
# 69-th iteration finished, shat_eps: 373.495458, lapse: 0.020sec.
# 70-th iteration finished, shat_eps: 373.476577, lapse: 0.006sec.
# 71-th iteration finished, shat_eps: 373.453404, lapse: 0.005sec.
# 72-th iteration finished, shat_eps: 373.424727, lapse: 0.065sec.
# 73-th iteration finished, shat_eps: 373.388962, lapse: 0.026sec.
# 74-th iteration finished, shat_eps: 373.344022, lapse: 0.005sec.
# 75-th iteration finished, shat_eps: 373.287159, lapse: 0.008sec.
# 76-th iteration finished, shat_eps: 373.214739, lapse: 0.019sec.
# 77-th iteration finished, shat_eps: 373.121957, lapse: 0.008sec.
# 78-th iteration finished, shat_eps: 373.002452, lapse: 0.006sec.
# 79-th iteration finished, shat_eps: 372.847815, lapse: 0.026sec.
# 80-th iteration finished, shat_eps: 372.646947, lapse: 0.006sec.
# 81-th iteration finished, shat_eps: 372.385236, lapse: 0.017sec.
# 82-th iteration finished, shat_eps: 372.043543, lapse: 0.006sec.
# 83-th iteration finished, shat_eps: 371.596942, lapse: 0.010sec.
# 84-th iteration finished, shat_eps: 371.013242, lapse: 0.022sec.
# 85-th iteration finished, shat_eps: 370.251295, lapse: 0.006sec.
# 86-th iteration finished, shat_eps: 369.259205, lapse: 0.007sec.
# 87-th iteration finished, shat_eps: 367.972616, lapse: 0.019sec.
# 88-th iteration finished, shat_eps: 366.313389, lapse: 0.009sec.
# 89-th iteration finished, shat_eps: 364.189179, lapse: 0.015sec.
# 90-th iteration finished, shat_eps: 361.494528, lapse: 0.005sec.
# 91-th iteration finished, shat_eps: 358.114279, lapse: 0.005sec.
# 92-th iteration finished, shat_eps: 353.930012, lapse: 0.009sec.
# 93-th iteration finished, shat_eps: 348.829935, lapse: 0.026sec.
# 94-th iteration finished, shat_eps: 342.721936, lapse: 0.006sec.
# 95-th iteration finished, shat_eps: 335.548449, lapse: 0.015sec.
# 96-th iteration finished, shat_eps: 327.300598, lapse: 0.006sec.
# 97-th iteration finished, shat_eps: 318.028273, lapse: 0.008sec.
# 98-th iteration finished, shat_eps: 307.842899, lapse: 0.022sec.
# 99-th iteration finished, shat_eps: 296.911112, lapse: 0.006sec.
# 100-th iteration finished, shat_eps: 285.439888, lapse: 0.004sec.
# 101-th iteration finished, shat_eps: 273.656153, lapse: 0.020sec.
# 102-th iteration finished, shat_eps: 261.785267, lapse: 0.008sec.
# 103-th iteration finished, shat_eps: 250.032644, lapse: 0.004sec.
# 104-th iteration finished, shat_eps: 238.571250, lapse: 0.004sec.
# 105-th iteration finished, shat_eps: 227.535752, lapse: 0.013sec.
# 106-th iteration finished, shat_eps: 217.022429, lapse: 0.006sec.
# 107-th iteration finished, shat_eps: 207.093092, lapse: 0.005sec.
# 108-th iteration finished, shat_eps: 197.781126, lapse: 0.006sec.
# 109-th iteration finished, shat_eps: 189.098130, lapse: 0.027sec.
# 110-th iteration finished, shat_eps: 181.040111, lapse: 0.030sec.
# 111-th iteration finished, shat_eps: 173.592734, lapse: 0.011sec.
# 112-th iteration finished, shat_eps: 166.735418, lapse: 0.016sec.
# 113-th iteration finished, shat_eps: 160.444339, lapse: 0.016sec.
# 114-th iteration finished, shat_eps: 154.694482, lapse: 0.022sec.
# 115-th iteration finished, shat_eps: 149.460929, lapse: 0.007sec.
# 116-th iteration finished, shat_eps: 144.742513, lapse: 0.021sec.
# 117-th iteration finished, shat_eps: 140.536899, lapse: 0.008sec.
# 118-th iteration finished, shat_eps: 136.832257, lapse: 0.004sec.
# 119-th iteration finished, shat_eps: 133.607314, lapse: 0.004sec.
# 120-th iteration finished, shat_eps: 130.832452, lapse: 0.006sec.
# 121-th iteration finished, shat_eps: 128.471391, lapse: 0.021sec.
# 122-th iteration finished, shat_eps: 126.483269, lapse: 0.007sec.
# 123-th iteration finished, shat_eps: 124.824873, lapse: 0.005sec.
# 124-th iteration finished, shat_eps: 123.452764, lapse: 0.018sec.
# 125-th iteration finished, shat_eps: 122.325073, lapse: 0.008sec.
# 126-th iteration finished, shat_eps: 121.402872, lapse: 0.008sec.
# 127-th iteration finished, shat_eps: 120.651050, lapse: 0.019sec.
# 128-th iteration finished, shat_eps: 120.038763, lapse: 0.005sec.
# 129-th iteration finished, shat_eps: 119.539515, lapse: 0.029sec.
# 130-th iteration finished, shat_eps: 119.130979, lapse: 0.008sec.
# 131-th iteration finished, shat_eps: 118.794644, lapse: 0.021sec.
# 132-th iteration finished, shat_eps: 118.515378, lapse: 0.016sec.
# 133-th iteration finished, shat_eps: 118.280953, lapse: 0.015sec.
# 134-th iteration finished, shat_eps: 118.081592, lapse: 0.012sec.
# 135-th iteration finished, shat_eps: 117.909539, lapse: 0.006sec.
# 136-th iteration finished, shat_eps: 117.758688, lapse: 0.016sec.
# 137-th iteration finished, shat_eps: 117.624261, lapse: 0.004sec.
# 138-th iteration finished, shat_eps: 117.502540, lapse: 0.005sec.
# 139-th iteration finished, shat_eps: 117.390642, lapse: 0.006sec.
# 140-th iteration finished, shat_eps: 117.286342, lapse: 0.023sec.
# 141-th iteration finished, shat_eps: 117.187928, lapse: 0.006sec.
# 142-th iteration finished, shat_eps: 117.094085, lapse: 0.007sec.
# 143-th iteration finished, shat_eps: 117.003808, lapse: 0.021sec.
# 144-th iteration finished, shat_eps: 116.916326, lapse: 0.006sec.
# 145-th iteration finished, shat_eps: 116.831055, lapse: 0.007sec.
# 146-th iteration finished, shat_eps: 116.747545, lapse: 0.007sec.
# 147-th iteration finished, shat_eps: 116.665458, lapse: 0.013sec.
# 148-th iteration finished, shat_eps: 116.584534, lapse: 0.011sec.
# 149-th iteration finished, shat_eps: 116.504578, lapse: 0.009sec.
# 150-th iteration finished, shat_eps: 116.425439, lapse: 0.006sec.
# 151-th iteration finished, shat_eps: 116.347003, lapse: 0.008sec.
# 152-th iteration finished, shat_eps: 116.269186, lapse: 0.005sec.
# 153-th iteration finished, shat_eps: 116.191920, lapse: 0.021sec.
# 154-th iteration finished, shat_eps: 116.115157, lapse: 0.004sec.
# 155-th iteration finished, shat_eps: 116.038857, lapse: 0.007sec.
# 156-th iteration finished, shat_eps: 115.962991, lapse: 0.016sec.
# 157-th iteration finished, shat_eps: 115.887536, lapse: 0.005sec.
# 158-th iteration finished, shat_eps: 115.812476, lapse: 0.007sec.
# 159-th iteration finished, shat_eps: 115.737795, lapse: 0.005sec.
# 160-th iteration finished, shat_eps: 115.663483, lapse: 0.018sec.
# 161-th iteration finished, shat_eps: 115.589532, lapse: 0.006sec.
# 162-th iteration finished, shat_eps: 115.515934, lapse: 0.006sec.
# 163-th iteration finished, shat_eps: 115.442683, lapse: 0.013sec.
# 164-th iteration finished, shat_eps: 115.369775, lapse: 0.005sec.
# 165-th iteration finished, shat_eps: 115.297204, lapse: 0.007sec.
# 166-th iteration finished, shat_eps: 115.224967, lapse: 0.005sec.
# 167-th iteration finished, shat_eps: 115.153061, lapse: 0.004sec.
# 168-th iteration finished, shat_eps: 115.081482, lapse: 0.027sec.
# 169-th iteration finished, shat_eps: 115.010228, lapse: 0.019sec.
# 170-th iteration finished, shat_eps: 114.939295, lapse: 0.031sec.
# 171-th iteration finished, shat_eps: 114.868681, lapse: 0.013sec.
# 172-th iteration finished, shat_eps: 114.798384, lapse: 0.005sec.
# 173-th iteration finished, shat_eps: 114.728400, lapse: 0.030sec.
# 174-th iteration finished, shat_eps: 114.658728, lapse: 0.023sec.
# 175-th iteration finished, shat_eps: 114.589364, lapse: 0.012sec.
# 176-th iteration finished, shat_eps: 114.520307, lapse: 0.023sec.
# 177-th iteration finished, shat_eps: 114.451555, lapse: 0.031sec.
# 178-th iteration finished, shat_eps: 114.383104, lapse: 0.018sec.
# 179-th iteration finished, shat_eps: 114.314953, lapse: 0.033sec.
# 180-th iteration finished, shat_eps: 114.247099, lapse: 0.028sec.
# 181-th iteration finished, shat_eps: 114.179540, lapse: 0.005sec.
# 182-th iteration finished, shat_eps: 114.112274, lapse: 0.017sec.
# 183-th iteration finished, shat_eps: 114.045299, lapse: 0.009sec.
# 184-th iteration finished, shat_eps: 113.978612, lapse: 0.004sec.
# 185-th iteration finished, shat_eps: 113.912211, lapse: 0.004sec.
# 186-th iteration finished, shat_eps: 113.846094, lapse: 0.020sec.
# 187-th iteration finished, shat_eps: 113.780260, lapse: 0.006sec.
# 188-th iteration finished, shat_eps: 113.714705, lapse: 0.006sec.
# 189-th iteration finished, shat_eps: 113.649428, lapse: 0.027sec.
# 190-th iteration finished, shat_eps: 113.584426, lapse: 0.008sec.
# 191-th iteration finished, shat_eps: 113.519698, lapse: 0.017sec.
# 192-th iteration finished, shat_eps: 113.455242, lapse: 0.013sec.
# 193-th iteration finished, shat_eps: 113.391055, lapse: 0.015sec.
# 194-th iteration finished, shat_eps: 113.327136, lapse: 0.005sec.
# 195-th iteration finished, shat_eps: 113.263483, lapse: 0.009sec.
# 196-th iteration finished, shat_eps: 113.200093, lapse: 0.020sec.
# 197-th iteration finished, shat_eps: 113.136965, lapse: 0.015sec.
# 198-th iteration finished, shat_eps: 113.074096, lapse: 0.003sec.
# 199-th iteration finished, shat_eps: 113.011485, lapse: 0.023sec.
# 200-th iteration finished, shat_eps: 112.949131, lapse: 0.011sec.
# 201-th iteration finished, shat_eps: 112.887030, lapse: 0.018sec.
# 202-th iteration finished, shat_eps: 112.825182, lapse: 0.011sec.
# 203-th iteration finished, shat_eps: 112.763584, lapse: 0.021sec.
# 204-th iteration finished, shat_eps: 112.702235, lapse: 0.008sec.
# 205-th iteration finished, shat_eps: 112.641133, lapse: 0.007sec.
# 206-th iteration finished, shat_eps: 112.580275, lapse: 0.016sec.
# 207-th iteration finished, shat_eps: 112.519661, lapse: 0.009sec.
# 208-th iteration finished, shat_eps: 112.459289, lapse: 0.009sec.
# 209-th iteration finished, shat_eps: 112.399156, lapse: 0.004sec.
# 210-th iteration finished, shat_eps: 112.339262, lapse: 0.015sec.
# 211-th iteration finished, shat_eps: 112.279604, lapse: 0.010sec.
# 212-th iteration finished, shat_eps: 112.220181, lapse: 0.004sec.
# 213-th iteration finished, shat_eps: 112.160991, lapse: 0.005sec.
# 214-th iteration finished, shat_eps: 112.102032, lapse: 0.028sec.
# 215-th iteration finished, shat_eps: 112.043303, lapse: 0.030sec.
# 216-th iteration finished, shat_eps: 111.984803, lapse: 0.004sec.
# 217-th iteration finished, shat_eps: 111.926529, lapse: 0.021sec.
# 218-th iteration finished, shat_eps: 111.868481, lapse: 0.008sec.
# 219-th iteration finished, shat_eps: 111.810656, lapse: 0.006sec.
# 220-th iteration finished, shat_eps: 111.753052, lapse: 0.022sec.
# 221-th iteration finished, shat_eps: 111.695670, lapse: 0.010sec.
# 222-th iteration finished, shat_eps: 111.638506, lapse: 0.014sec.
# 223-th iteration finished, shat_eps: 111.581560, lapse: 0.015sec.
# 224-th iteration finished, shat_eps: 111.524830, lapse: 0.009sec.
# 225-th iteration finished, shat_eps: 111.468314, lapse: 0.017sec.
# 226-th iteration finished, shat_eps: 111.412012, lapse: 0.042sec.
# 227-th iteration finished, shat_eps: 111.355921, lapse: 0.020sec.
# 228-th iteration finished, shat_eps: 111.300040, lapse: 0.029sec.
# 229-th iteration finished, shat_eps: 111.244368, lapse: 0.012sec.
# 230-th iteration finished, shat_eps: 111.188903, lapse: 0.007sec.
# 231-th iteration finished, shat_eps: 111.133645, lapse: 0.011sec.
# 232-th iteration finished, shat_eps: 111.078591, lapse: 0.010sec.
# 233-th iteration finished, shat_eps: 111.023740, lapse: 0.004sec.
# 234-th iteration finished, shat_eps: 110.969091, lapse: 0.004sec.
# 235-th iteration finished, shat_eps: 110.914643, lapse: 0.004sec.
# 236-th iteration finished, shat_eps: 110.860394, lapse: 0.019sec.
# 237-th iteration finished, shat_eps: 110.806343, lapse: 0.007sec.
# 238-th iteration finished, shat_eps: 110.752488, lapse: 0.006sec.
# 239-th iteration finished, shat_eps: 110.698829, lapse: 0.021sec.
# 240-th iteration finished, shat_eps: 110.645364, lapse: 0.005sec.
# 241-th iteration finished, shat_eps: 110.592092, lapse: 0.007sec.
# 242-th iteration finished, shat_eps: 110.539011, lapse: 0.016sec.
# 243-th iteration finished, shat_eps: 110.486121, lapse: 0.012sec.
# 244-th iteration finished, shat_eps: 110.433419, lapse: 0.005sec.
# 245-th iteration finished, shat_eps: 110.380906, lapse: 0.022sec.
# 246-th iteration finished, shat_eps: 110.328579, lapse: 0.007sec.
# 247-th iteration finished, shat_eps: 110.276438, lapse: 0.019sec.
# 248-th iteration finished, shat_eps: 110.224481, lapse: 0.010sec.
# 249-th iteration finished, shat_eps: 110.172707, lapse: 0.011sec.
# 250-th iteration finished, shat_eps: 110.121115, lapse: 0.015sec.
# 251-th iteration finished, shat_eps: 110.069703, lapse: 0.009sec.
# 252-th iteration finished, shat_eps: 110.018472, lapse: 0.005sec.
# 253-th iteration finished, shat_eps: 109.967419, lapse: 0.003sec.
# 254-th iteration finished, shat_eps: 109.916543, lapse: 0.022sec.
# 255-th iteration finished, shat_eps: 109.865844, lapse: 0.006sec.
# 256-th iteration finished, shat_eps: 109.815320, lapse: 0.005sec.
# 257-th iteration finished, shat_eps: 109.764970, lapse: 0.017sec.
# 258-th iteration finished, shat_eps: 109.714792, lapse: 0.008sec.
# 259-th iteration finished, shat_eps: 109.664787, lapse: 0.006sec.
# 260-th iteration finished, shat_eps: 109.614953, lapse: 0.006sec.
# 261-th iteration finished, shat_eps: 109.565288, lapse: 0.022sec.
# 262-th iteration finished, shat_eps: 109.515793, lapse: 0.004sec.
# 263-th iteration finished, shat_eps: 109.466465, lapse: 0.004sec.
# 264-th iteration finished, shat_eps: 109.417303, lapse: 0.015sec.
# 265-th iteration finished, shat_eps: 109.368308, lapse: 0.006sec.
# 266-th iteration finished, shat_eps: 109.319477, lapse: 0.005sec.
# 267-th iteration finished, shat_eps: 109.270809, lapse: 0.006sec.
# 268-th iteration finished, shat_eps: 109.222305, lapse: 0.019sec.
# 269-th iteration finished, shat_eps: 109.173962, lapse: 0.010sec.
# 270-th iteration finished, shat_eps: 109.125780, lapse: 0.026sec.
# 271-th iteration finished, shat_eps: 109.077757, lapse: 0.010sec.
# 272-th iteration finished, shat_eps: 109.029894, lapse: 0.020sec.
# 273-th iteration finished, shat_eps: 108.982188, lapse: 0.008sec.
# 274-th iteration finished, shat_eps: 108.934639, lapse: 0.007sec.
# 275-th iteration finished, shat_eps: 108.887246, lapse: 0.046sec.
# 276-th iteration finished, shat_eps: 108.840008, lapse: 0.019sec.
# 277-th iteration finished, shat_eps: 108.792924, lapse: 0.019sec.
# 278-th iteration finished, shat_eps: 108.745994, lapse: 0.006sec.
# 279-th iteration finished, shat_eps: 108.699215, lapse: 0.008sec.
# 280-th iteration finished, shat_eps: 108.652589, lapse: 0.007sec.
# 281-th iteration finished, shat_eps: 108.606112, lapse: 0.019sec.
# 282-th iteration finished, shat_eps: 108.559785, lapse: 0.006sec.
# 283-th iteration finished, shat_eps: 108.513608, lapse: 0.019sec.
# 284-th iteration finished, shat_eps: 108.467578, lapse: 0.010sec.
# 285-th iteration finished, shat_eps: 108.421694, lapse: 0.008sec.
# 286-th iteration finished, shat_eps: 108.375958, lapse: 0.026sec.
# 287-th iteration finished, shat_eps: 108.330366, lapse: 0.007sec.
# 288-th iteration finished, shat_eps: 108.284919, lapse: 0.016sec.
# 289-th iteration finished, shat_eps: 108.239616, lapse: 0.004sec.
# 290-th iteration finished, shat_eps: 108.194455, lapse: 0.005sec.
# 291-th iteration finished, shat_eps: 108.149437, lapse: 0.004sec.
# 292-th iteration finished, shat_eps: 108.104560, lapse: 0.005sec.
# 293-th iteration finished, shat_eps: 108.059823, lapse: 0.017sec.
# 294-th iteration finished, shat_eps: 108.015226, lapse: 0.009sec.
# 295-th iteration finished, shat_eps: 107.970767, lapse: 0.004sec.
# 296-th iteration finished, shat_eps: 107.926447, lapse: 0.003sec.
# 297-th iteration finished, shat_eps: 107.882264, lapse: 0.017sec.
# 298-th iteration finished, shat_eps: 107.838217, lapse: 0.005sec.
# 299-th iteration finished, shat_eps: 107.794306, lapse: 0.007sec.
# 300-th iteration finished, shat_eps: 107.750530, lapse: 0.020sec.
# 301-th iteration finished, shat_eps: 107.706889, lapse: 0.006sec.
# 302-th iteration finished, shat_eps: 107.663380, lapse: 0.004sec.
# 303-th iteration finished, shat_eps: 107.620005, lapse: 0.006sec.
# 304-th iteration finished, shat_eps: 107.576761, lapse: 0.021sec.
# 305-th iteration finished, shat_eps: 107.533649, lapse: 0.032sec.
# 306-th iteration finished, shat_eps: 107.490667, lapse: 0.010sec.
# 307-th iteration finished, shat_eps: 107.447815, lapse: 0.005sec.
# 308-th iteration finished, shat_eps: 107.405092, lapse: 0.019sec.
# 309-th iteration finished, shat_eps: 107.362497, lapse: 0.004sec.
# 310-th iteration finished, shat_eps: 107.320030, lapse: 0.008sec.
# 311-th iteration finished, shat_eps: 107.277690, lapse: 0.016sec.
# 312-th iteration finished, shat_eps: 107.235476, lapse: 0.011sec.
# 313-th iteration finished, shat_eps: 107.193388, lapse: 0.006sec.
# 314-th iteration finished, shat_eps: 107.151425, lapse: 0.017sec.
# 315-th iteration finished, shat_eps: 107.109586, lapse: 0.005sec.
# 316-th iteration finished, shat_eps: 107.067870, lapse: 0.005sec.
# 317-th iteration finished, shat_eps: 107.026278, lapse: 0.006sec.
# 318-th iteration finished, shat_eps: 106.984808, lapse: 0.022sec.
# 319-th iteration finished, shat_eps: 106.943459, lapse: 0.005sec.
# 320-th iteration finished, shat_eps: 106.902231, lapse: 0.006sec.
# 321-th iteration finished, shat_eps: 106.861124, lapse: 0.018sec.
# 322-th iteration finished, shat_eps: 106.820136, lapse: 0.007sec.
# 323-th iteration finished, shat_eps: 106.779267, lapse: 0.006sec.
# 324-th iteration finished, shat_eps: 106.738516, lapse: 0.018sec.
# 325-th iteration finished, shat_eps: 106.697883, lapse: 0.015sec.
# 326-th iteration finished, shat_eps: 106.657368, lapse: 0.036sec.
# 327-th iteration finished, shat_eps: 106.616969, lapse: 0.022sec.
# 328-th iteration finished, shat_eps: 106.576685, lapse: 0.008sec.
# 329-th iteration finished, shat_eps: 106.536517, lapse: 0.019sec.
# 330-th iteration finished, shat_eps: 106.496464, lapse: 0.015sec.
# 331-th iteration finished, shat_eps: 106.456525, lapse: 0.025sec.
# 332-th iteration finished, shat_eps: 106.416699, lapse: 0.014sec.
# 333-th iteration finished, shat_eps: 106.376986, lapse: 0.018sec.
# 334-th iteration finished, shat_eps: 106.337386, lapse: 0.005sec.
# 335-th iteration finished, shat_eps: 106.297897, lapse: 0.006sec.
# 336-th iteration finished, shat_eps: 106.258520, lapse: 0.003sec.
# 337-th iteration finished, shat_eps: 106.219252, lapse: 0.013sec.
# 338-th iteration finished, shat_eps: 106.180095, lapse: 0.004sec.
# 339-th iteration finished, shat_eps: 106.141048, lapse: 0.011sec.
# 340-th iteration finished, shat_eps: 106.102109, lapse: 0.010sec.
# 341-th iteration finished, shat_eps: 106.063279, lapse: 0.015sec.
# 342-th iteration finished, shat_eps: 106.024556, lapse: 0.012sec.
# 343-th iteration finished, shat_eps: 105.985941, lapse: 0.029sec.
# 344-th iteration finished, shat_eps: 105.947432, lapse: 0.017sec.
# 345-th iteration finished, shat_eps: 105.909030, lapse: 0.018sec.
# 346-th iteration finished, shat_eps: 105.870733, lapse: 0.017sec.
# 347-th iteration finished, shat_eps: 105.832541, lapse: 0.005sec.
# 348-th iteration finished, shat_eps: 105.794453, lapse: 0.007sec.
# 349-th iteration finished, shat_eps: 105.756470, lapse: 0.004sec.
# 350-th iteration finished, shat_eps: 105.718590, lapse: 0.013sec.
# 351-th iteration finished, shat_eps: 105.680813, lapse: 0.014sec.
# 352-th iteration finished, shat_eps: 105.643139, lapse: 0.007sec.
# 353-th iteration finished, shat_eps: 105.605567, lapse: 0.005sec.
# 354-th iteration finished, shat_eps: 105.568096, lapse: 0.027sec.
# 355-th iteration finished, shat_eps: 105.530726, lapse: 0.005sec.
# 356-th iteration finished, shat_eps: 105.493456, lapse: 0.023sec.
# 357-th iteration finished, shat_eps: 105.456286, lapse: 0.030sec.
# 358-th iteration finished, shat_eps: 105.419216, lapse: 0.027sec.
# 359-th iteration finished, shat_eps: 105.382245, lapse: 0.007sec.
# 360-th iteration finished, shat_eps: 105.345372, lapse: 0.010sec.
# 361-th iteration finished, shat_eps: 105.308598, lapse: 0.033sec.
# 362-th iteration finished, shat_eps: 105.271920, lapse: 0.023sec.
# 363-th iteration finished, shat_eps: 105.235340, lapse: 0.009sec.
# 364-th iteration finished, shat_eps: 105.198857, lapse: 0.034sec.
# 365-th iteration finished, shat_eps: 105.162469, lapse: 0.025sec.
# 366-th iteration finished, shat_eps: 105.126177, lapse: 0.013sec.
# 367-th iteration finished, shat_eps: 105.089981, lapse: 0.018sec.
# 368-th iteration finished, shat_eps: 105.053879, lapse: 0.004sec.
# 369-th iteration finished, shat_eps: 105.017871, lapse: 0.008sec.
# 370-th iteration finished, shat_eps: 104.981957, lapse: 0.018sec.
# 371-th iteration finished, shat_eps: 104.946136, lapse: 0.012sec.
# 372-th iteration finished, shat_eps: 104.910409, lapse: 0.005sec.
# 373-th iteration finished, shat_eps: 104.874773, lapse: 0.021sec.
# 374-th iteration finished, shat_eps: 104.839230, lapse: 0.009sec.
# 375-th iteration finished, shat_eps: 104.803779, lapse: 0.023sec.
# 376-th iteration finished, shat_eps: 104.768418, lapse: 0.010sec.
# 377-th iteration finished, shat_eps: 104.733149, lapse: 0.024sec.
# 378-th iteration finished, shat_eps: 104.697969, lapse: 0.009sec.
# 379-th iteration finished, shat_eps: 104.662879, lapse: 0.019sec.
# 380-th iteration finished, shat_eps: 104.627879, lapse: 0.006sec.
# 381-th iteration finished, shat_eps: 104.592968, lapse: 0.006sec.
# 382-th iteration finished, shat_eps: 104.558146, lapse: 0.028sec.
# 383-th iteration finished, shat_eps: 104.523411, lapse: 0.029sec.
# 384-th iteration finished, shat_eps: 104.488765, lapse: 0.029sec.
# 385-th iteration finished, shat_eps: 104.454205, lapse: 0.008sec.
# 386-th iteration finished, shat_eps: 104.419733, lapse: 0.011sec.
# 387-th iteration finished, shat_eps: 104.385347, lapse: 0.024sec.
# 388-th iteration finished, shat_eps: 104.351048, lapse: 0.009sec.
# 389-th iteration finished, shat_eps: 104.316834, lapse: 0.015sec.
# 390-th iteration finished, shat_eps: 104.282705, lapse: 0.005sec.
# 391-th iteration finished, shat_eps: 104.248662, lapse: 0.007sec.
# 392-th iteration finished, shat_eps: 104.214703, lapse: 0.005sec.
# 393-th iteration finished, shat_eps: 104.180828, lapse: 0.024sec.
# 394-th iteration finished, shat_eps: 104.147037, lapse: 0.007sec.
# 395-th iteration finished, shat_eps: 104.113330, lapse: 0.020sec.
# 396-th iteration finished, shat_eps: 104.079705, lapse: 0.015sec.
# 397-th iteration finished, shat_eps: 104.046163, lapse: 0.023sec.
# 398-th iteration finished, shat_eps: 104.012703, lapse: 0.027sec.
# 399-th iteration finished, shat_eps: 103.979326, lapse: 0.017sec.
# 400-th iteration finished, shat_eps: 103.946029, lapse: 0.011sec.
# 401-th iteration finished, shat_eps: 103.912814, lapse: 0.013sec.
# 402-th iteration finished, shat_eps: 103.879680, lapse: 0.007sec.
# 403-th iteration finished, shat_eps: 103.846626, lapse: 0.004sec.
# 404-th iteration finished, shat_eps: 103.813653, lapse: 0.017sec.
# 405-th iteration finished, shat_eps: 103.780759, lapse: 0.011sec.
# 406-th iteration finished, shat_eps: 103.747944, lapse: 0.006sec.
# 407-th iteration finished, shat_eps: 103.715208, lapse: 0.020sec.
# 408-th iteration finished, shat_eps: 103.682551, lapse: 0.012sec.
# 409-th iteration finished, shat_eps: 103.649972, lapse: 0.051sec.
# 410-th iteration finished, shat_eps: 103.617472, lapse: 0.014sec.
# 411-th iteration finished, shat_eps: 103.585048, lapse: 0.029sec.
# 412-th iteration finished, shat_eps: 103.552702, lapse: 0.026sec.
# 413-th iteration finished, shat_eps: 103.520433, lapse: 0.009sec.
# 414-th iteration finished, shat_eps: 103.488241, lapse: 0.004sec.
# 415-th iteration finished, shat_eps: 103.456125, lapse: 0.022sec.
# 416-th iteration finished, shat_eps: 103.424084, lapse: 0.008sec.
# 417-th iteration finished, shat_eps: 103.392120, lapse: 0.021sec.
# 418-th iteration finished, shat_eps: 103.360230, lapse: 0.010sec.
# 419-th iteration finished, shat_eps: 103.328415, lapse: 0.024sec.
# 420-th iteration finished, shat_eps: 103.296675, lapse: 0.005sec.
# 421-th iteration finished, shat_eps: 103.265010, lapse: 0.007sec.
# 422-th iteration finished, shat_eps: 103.233418, lapse: 0.014sec.
# 423-th iteration finished, shat_eps: 103.201900, lapse: 0.007sec.
# 424-th iteration finished, shat_eps: 103.170455, lapse: 0.011sec.
# 425-th iteration finished, shat_eps: 103.139083, lapse: 0.023sec.
# 426-th iteration finished, shat_eps: 103.107784, lapse: 0.005sec.
# 427-th iteration finished, shat_eps: 103.076557, lapse: 0.005sec.
# 428-th iteration finished, shat_eps: 103.045402, lapse: 0.025sec.
# 429-th iteration finished, shat_eps: 103.014319, lapse: 0.045sec.
# 430-th iteration finished, shat_eps: 102.983307, lapse: 0.024sec.
# 431-th iteration finished, shat_eps: 102.952366, lapse: 0.034sec.
# 432-th iteration finished, shat_eps: 102.921497, lapse: 0.032sec.
# 433-th iteration finished, shat_eps: 102.890697, lapse: 0.011sec.
# 434-th iteration finished, shat_eps: 102.859968, lapse: 0.024sec.
# 435-th iteration finished, shat_eps: 102.829309, lapse: 0.034sec.
# 436-th iteration finished, shat_eps: 102.798720, lapse: 0.030sec.
# 437-th iteration finished, shat_eps: 102.768199, lapse: 0.008sec.
# 438-th iteration finished, shat_eps: 102.737748, lapse: 0.026sec.
# 439-th iteration finished, shat_eps: 102.707366, lapse: 0.024sec.
# 440-th iteration finished, shat_eps: 102.677052, lapse: 0.011sec.
# 441-th iteration finished, shat_eps: 102.646806, lapse: 0.026sec.
# 442-th iteration finished, shat_eps: 102.616628, lapse: 0.009sec.
# 443-th iteration finished, shat_eps: 102.586518, lapse: 0.004sec.
# 444-th iteration finished, shat_eps: 102.556475, lapse: 0.024sec.
# 445-th iteration finished, shat_eps: 102.526499, lapse: 0.003sec.
# 446-th iteration finished, shat_eps: 102.496590, lapse: 0.017sec.
# 447-th iteration finished, shat_eps: 102.466747, lapse: 0.013sec.
# 448-th iteration finished, shat_eps: 102.436970, lapse: 0.010sec.
# 449-th iteration finished, shat_eps: 102.407260, lapse: 0.021sec.
# 450-th iteration finished, shat_eps: 102.377615, lapse: 0.010sec.
# 451-th iteration finished, shat_eps: 102.348035, lapse: 0.057sec.
# 452-th iteration finished, shat_eps: 102.318521, lapse: 0.043sec.
# 453-th iteration finished, shat_eps: 102.289071, lapse: 0.018sec.
# 454-th iteration finished, shat_eps: 102.259686, lapse: 0.005sec.
# 455-th iteration finished, shat_eps: 102.230366, lapse: 0.008sec.
# 456-th iteration finished, shat_eps: 102.201109, lapse: 0.006sec.
# 457-th iteration finished, shat_eps: 102.171916, lapse: 0.022sec.
# 458-th iteration finished, shat_eps: 102.142787, lapse: 0.007sec.
# 459-th iteration finished, shat_eps: 102.113721, lapse: 0.021sec.
# 460-th iteration finished, shat_eps: 102.084718, lapse: 0.011sec.
# 461-th iteration finished, shat_eps: 102.055777, lapse: 0.006sec.
# 462-th iteration finished, shat_eps: 102.026900, lapse: 0.022sec.
# 463-th iteration finished, shat_eps: 101.998084, lapse: 0.023sec.
# 464-th iteration finished, shat_eps: 101.969331, lapse: 0.018sec.
# 465-th iteration finished, shat_eps: 101.940639, lapse: 0.036sec.
# 466-th iteration finished, shat_eps: 101.912009, lapse: 0.020sec.
# 467-th iteration finished, shat_eps: 101.883440, lapse: 0.013sec.
# 468-th iteration finished, shat_eps: 101.854932, lapse: 0.022sec.
# 469-th iteration finished, shat_eps: 101.826485, lapse: 0.008sec.
# 470-th iteration finished, shat_eps: 101.798098, lapse: 0.025sec.
# 471-th iteration finished, shat_eps: 101.769772, lapse: 0.007sec.
# 472-th iteration finished, shat_eps: 101.741505, lapse: 0.022sec.
# 473-th iteration finished, shat_eps: 101.713299, lapse: 0.009sec.
# 474-th iteration finished, shat_eps: 101.685152, lapse: 0.026sec.
# 475-th iteration finished, shat_eps: 101.657064, lapse: 0.032sec.
# 476-th iteration finished, shat_eps: 101.629036, lapse: 0.015sec.
# 477-th iteration finished, shat_eps: 101.601066, lapse: 0.031sec.
# 478-th iteration finished, shat_eps: 101.573155, lapse: 0.029sec.
# 479-th iteration finished, shat_eps: 101.545303, lapse: 0.024sec.
# 480-th iteration finished, shat_eps: 101.517508, lapse: 0.013sec.
# 481-th iteration finished, shat_eps: 101.489772, lapse: 0.019sec.
# 482-th iteration finished, shat_eps: 101.462093, lapse: 0.008sec.
# 483-th iteration finished, shat_eps: 101.434472, lapse: 0.010sec.
# 484-th iteration finished, shat_eps: 101.406908, lapse: 0.023sec.
# 485-th iteration finished, shat_eps: 101.379401, lapse: 0.007sec.
# 486-th iteration finished, shat_eps: 101.351951, lapse: 0.017sec.
# 487-th iteration finished, shat_eps: 101.324558, lapse: 0.006sec.
# 488-th iteration finished, shat_eps: 101.297221, lapse: 0.016sec.
# 489-th iteration finished, shat_eps: 101.269940, lapse: 0.045sec.
# 490-th iteration finished, shat_eps: 101.242715, lapse: 0.010sec.
# 491-th iteration finished, shat_eps: 101.215546, lapse: 0.028sec.
# 492-th iteration finished, shat_eps: 101.188432, lapse: 0.005sec.
# 493-th iteration finished, shat_eps: 101.161374, lapse: 0.017sec.
# 494-th iteration finished, shat_eps: 101.134371, lapse: 0.006sec.
# 495-th iteration finished, shat_eps: 101.107422, lapse: 0.017sec.
# 496-th iteration finished, shat_eps: 101.080529, lapse: 0.011sec.
# 497-th iteration finished, shat_eps: 101.053690, lapse: 0.007sec.
# 498-th iteration finished, shat_eps: 101.026905, lapse: 0.008sec.
# 499-th iteration finished, shat_eps: 101.000174, lapse: 0.017sec.
# 500-th iteration finished, shat_eps: 100.973497, lapse: 0.006sec.
# 501-th iteration finished, shat_eps: 100.946874, lapse: 0.006sec.
# 502-th iteration finished, shat_eps: 100.920304, lapse: 0.014sec.
# 503-th iteration finished, shat_eps: 100.893787, lapse: 0.007sec.
# 504-th iteration finished, shat_eps: 100.867324, lapse: 0.009sec.
# 505-th iteration finished, shat_eps: 100.840913, lapse: 0.007sec.
# 506-th iteration finished, shat_eps: 100.814555, lapse: 0.026sec.
# 507-th iteration finished, shat_eps: 100.788249, lapse: 0.009sec.
# 508-th iteration finished, shat_eps: 100.761996, lapse: 0.033sec.
# 509-th iteration finished, shat_eps: 100.735795, lapse: 0.021sec.
# 510-th iteration finished, shat_eps: 100.709645, lapse: 0.028sec.
# 511-th iteration finished, shat_eps: 100.683547, lapse: 0.006sec.
# 512-th iteration finished, shat_eps: 100.657501, lapse: 0.007sec.
# 513-th iteration finished, shat_eps: 100.631506, lapse: 0.021sec.
# 514-th iteration finished, shat_eps: 100.605562, lapse: 0.008sec.
# 515-th iteration finished, shat_eps: 100.579669, lapse: 0.006sec.
# 516-th iteration finished, shat_eps: 100.553827, lapse: 0.016sec.
# 517-th iteration finished, shat_eps: 100.528036, lapse: 0.011sec.
# 518-th iteration finished, shat_eps: 100.502294, lapse: 0.010sec.
# 519-th iteration finished, shat_eps: 100.476603, lapse: 0.030sec.
# 520-th iteration finished, shat_eps: 100.450962, lapse: 0.014sec.
# 521-th iteration finished, shat_eps: 100.425370, lapse: 0.007sec.
# 522-th iteration finished, shat_eps: 100.399829, lapse: 0.034sec.
# 523-th iteration finished, shat_eps: 100.374336, lapse: 0.032sec.
# 524-th iteration finished, shat_eps: 100.348893, lapse: 0.011sec.
# 525-th iteration finished, shat_eps: 100.323499, lapse: 0.023sec.
# 526-th iteration finished, shat_eps: 100.298154, lapse: 0.010sec.
# 527-th iteration finished, shat_eps: 100.272858, lapse: 0.007sec.
# 528-th iteration finished, shat_eps: 100.247610, lapse: 0.017sec.
# 529-th iteration finished, shat_eps: 100.222410, lapse: 0.004sec.
# 530-th iteration finished, shat_eps: 100.197259, lapse: 0.005sec.
# 531-th iteration finished, shat_eps: 100.172156, lapse: 0.015sec.
# 532-th iteration finished, shat_eps: 100.147100, lapse: 0.007sec.
# 533-th iteration finished, shat_eps: 100.122093, lapse: 0.004sec.
# 534-th iteration finished, shat_eps: 100.097132, lapse: 0.009sec.
# 535-th iteration finished, shat_eps: 100.072219, lapse: 0.006sec.
# 536-th iteration finished, shat_eps: 100.047354, lapse: 0.021sec.
# 537-th iteration finished, shat_eps: 100.022535, lapse: 0.008sec.
# 538-th iteration finished, shat_eps: 99.997763, lapse: 0.020sec.
# 539-th iteration finished, shat_eps: 99.973038, lapse: 0.007sec.
# 540-th iteration finished, shat_eps: 99.948359, lapse: 0.035sec.
# 541-th iteration finished, shat_eps: 99.923726, lapse: 0.037sec.
# 542-th iteration finished, shat_eps: 99.899140, lapse: 0.020sec.
# 543-th iteration finished, shat_eps: 99.874600, lapse: 0.004sec.
# 544-th iteration finished, shat_eps: 99.850105, lapse: 0.009sec.
# 545-th iteration finished, shat_eps: 99.825657, lapse: 0.020sec.
# 546-th iteration finished, shat_eps: 99.801253, lapse: 0.007sec.
# 547-th iteration finished, shat_eps: 99.776895, lapse: 0.007sec.
# 548-th iteration finished, shat_eps: 99.752583, lapse: 0.015sec.
# 549-th iteration finished, shat_eps: 99.728315, lapse: 0.010sec.
# 550-th iteration finished, shat_eps: 99.704092, lapse: 0.006sec.
# 551-th iteration finished, shat_eps: 99.679914, lapse: 0.028sec.
# 552-th iteration finished, shat_eps: 99.655781, lapse: 0.008sec.
# 553-th iteration finished, shat_eps: 99.631692, lapse: 0.025sec.
# 554-th iteration finished, shat_eps: 99.607647, lapse: 0.017sec.
# 555-th iteration finished, shat_eps: 99.583646, lapse: 0.015sec.
# 556-th iteration finished, shat_eps: 99.559689, lapse: 0.005sec.
# 557-th iteration finished, shat_eps: 99.535776, lapse: 0.028sec.
# 558-th iteration finished, shat_eps: 99.511907, lapse: 0.009sec.
# 559-th iteration finished, shat_eps: 99.488081, lapse: 0.032sec.
# 560-th iteration finished, shat_eps: 99.464299, lapse: 0.022sec.
# 561-th iteration finished, shat_eps: 99.440559, lapse: 0.010sec.
# 562-th iteration finished, shat_eps: 99.416863, lapse: 0.008sec.
# 563-th iteration finished, shat_eps: 99.393210, lapse: 0.017sec.
# 564-th iteration finished, shat_eps: 99.369599, lapse: 0.016sec.
# 565-th iteration finished, shat_eps: 99.346031, lapse: 0.006sec.
# 566-th iteration finished, shat_eps: 99.322506, lapse: 0.012sec.
# 567-th iteration finished, shat_eps: 99.299023, lapse: 0.005sec.
# 568-th iteration finished, shat_eps: 99.275581, lapse: 0.021sec.
# 569-th iteration finished, shat_eps: 99.252182, lapse: 0.008sec.
# 570-th iteration finished, shat_eps: 99.228825, lapse: 0.019sec.
# 571-th iteration finished, shat_eps: 99.205510, lapse: 0.011sec.
# 572-th iteration finished, shat_eps: 99.182236, lapse: 0.008sec.
# 573-th iteration finished, shat_eps: 99.159004, lapse: 0.018sec.
# 574-th iteration finished, shat_eps: 99.135813, lapse: 0.005sec.
# 575-th iteration finished, shat_eps: 99.112663, lapse: 0.009sec.
# 576-th iteration finished, shat_eps: 99.089554, lapse: 0.017sec.
# 577-th iteration finished, shat_eps: 99.066487, lapse: 0.008sec.
# 578-th iteration finished, shat_eps: 99.043460, lapse: 0.006sec.
# 579-th iteration finished, shat_eps: 99.020473, lapse: 0.014sec.
# 580-th iteration finished, shat_eps: 98.997527, lapse: 0.019sec.
# 581-th iteration finished, shat_eps: 98.974622, lapse: 0.020sec.
# 582-th iteration finished, shat_eps: 98.951756, lapse: 0.009sec.
# 583-th iteration finished, shat_eps: 98.928931, lapse: 0.023sec.
# 584-th iteration finished, shat_eps: 98.906146, lapse: 0.008sec.
# 585-th iteration finished, shat_eps: 98.883400, lapse: 0.007sec.
# 586-th iteration finished, shat_eps: 98.860695, lapse: 0.015sec.
# 587-th iteration finished, shat_eps: 98.838028, lapse: 0.009sec.
# 588-th iteration finished, shat_eps: 98.815402, lapse: 0.009sec.
# 589-th iteration finished, shat_eps: 98.792814, lapse: 0.020sec.
# 590-th iteration finished, shat_eps: 98.770266, lapse: 0.007sec.
# 591-th iteration finished, shat_eps: 98.747757, lapse: 0.022sec.
# 592-th iteration finished, shat_eps: 98.725286, lapse: 0.007sec.
# 593-th iteration finished, shat_eps: 98.702855, lapse: 0.012sec.
# 594-th iteration finished, shat_eps: 98.680462, lapse: 0.012sec.
# 595-th iteration finished, shat_eps: 98.658107, lapse: 0.026sec.
# 596-th iteration finished, shat_eps: 98.635792, lapse: 0.019sec.
# 597-th iteration finished, shat_eps: 98.613514, lapse: 0.034sec.
# 598-th iteration finished, shat_eps: 98.591274, lapse: 0.021sec.
# 599-th iteration finished, shat_eps: 98.569073, lapse: 0.007sec.
# 600-th iteration finished, shat_eps: 98.546909, lapse: 0.010sec.
# 601-th iteration finished, shat_eps: 98.524784, lapse: 0.026sec.
# 602-th iteration finished, shat_eps: 98.502696, lapse: 0.006sec.
# 603-th iteration finished, shat_eps: 98.480645, lapse: 0.015sec.
# 604-th iteration finished, shat_eps: 98.458632, lapse: 0.005sec.
# 605-th iteration finished, shat_eps: 98.436656, lapse: 0.007sec.
# 606-th iteration finished, shat_eps: 98.414717, lapse: 0.005sec.
# 607-th iteration finished, shat_eps: 98.392816, lapse: 0.007sec.
# 608-th iteration finished, shat_eps: 98.370951, lapse: 0.018sec.
# 609-th iteration finished, shat_eps: 98.349123, lapse: 0.007sec.
# 610-th iteration finished, shat_eps: 98.327332, lapse: 0.013sec.
# 611-th iteration finished, shat_eps: 98.305578, lapse: 0.010sec.
# 612-th iteration finished, shat_eps: 98.283860, lapse: 0.004sec.
# 613-th iteration finished, shat_eps: 98.262178, lapse: 0.009sec.
# 614-th iteration finished, shat_eps: 98.240533, lapse: 0.023sec.
# 615-th iteration finished, shat_eps: 98.218923, lapse: 0.008sec.
# 616-th iteration finished, shat_eps: 98.197350, lapse: 0.025sec.
# 617-th iteration finished, shat_eps: 98.175813, lapse: 0.010sec.
# 618-th iteration finished, shat_eps: 98.154311, lapse: 0.023sec.
# 619-th iteration finished, shat_eps: 98.132845, lapse: 0.012sec.
# 620-th iteration finished, shat_eps: 98.111415, lapse: 0.033sec.
# 621-th iteration finished, shat_eps: 98.090020, lapse: 0.017sec.
# 622-th iteration finished, shat_eps: 98.068660, lapse: 0.020sec.
# 623-th iteration finished, shat_eps: 98.047336, lapse: 0.018sec.
# 624-th iteration finished, shat_eps: 98.026046, lapse: 0.007sec.
# 625-th iteration finished, shat_eps: 98.004792, lapse: 0.033sec.
# 626-th iteration finished, shat_eps: 97.983573, lapse: 0.006sec.
# 627-th iteration finished, shat_eps: 97.962388, lapse: 0.016sec.
# 628-th iteration finished, shat_eps: 97.941238, lapse: 0.012sec.
# 629-th iteration finished, shat_eps: 97.920123, lapse: 0.027sec.
# 630-th iteration finished, shat_eps: 97.899042, lapse: 0.006sec.
# 631-th iteration finished, shat_eps: 97.877996, lapse: 0.019sec.
# 632-th iteration finished, shat_eps: 97.856983, lapse: 0.011sec.
# 633-th iteration finished, shat_eps: 97.836005, lapse: 0.006sec.
# 634-th iteration finished, shat_eps: 97.815061, lapse: 0.035sec.
# 635-th iteration finished, shat_eps: 97.794151, lapse: 0.020sec.
# 636-th iteration finished, shat_eps: 97.773275, lapse: 0.008sec.
# 637-th iteration finished, shat_eps: 97.752432, lapse: 0.023sec.
# 638-th iteration finished, shat_eps: 97.731623, lapse: 0.044sec.
# 639-th iteration finished, shat_eps: 97.710847, lapse: 0.012sec.
# 640-th iteration finished, shat_eps: 97.690105, lapse: 0.020sec.
# 641-th iteration finished, shat_eps: 97.669397, lapse: 0.006sec.
# 642-th iteration finished, shat_eps: 97.648721, lapse: 0.018sec.
# 643-th iteration finished, shat_eps: 97.628079, lapse: 0.008sec.
# 644-th iteration finished, shat_eps: 97.607469, lapse: 0.012sec.
# 645-th iteration finished, shat_eps: 97.586893, lapse: 0.015sec.
# 646-th iteration finished, shat_eps: 97.566349, lapse: 0.008sec.
# 647-th iteration finished, shat_eps: 97.545838, lapse: 0.007sec.
# 648-th iteration finished, shat_eps: 97.525359, lapse: 0.013sec.
# 649-th iteration finished, shat_eps: 97.504913, lapse: 0.006sec.
# 650-th iteration finished, shat_eps: 97.484500, lapse: 0.004sec.
# 651-th iteration finished, shat_eps: 97.464119, lapse: 0.006sec.
# 652-th iteration finished, shat_eps: 97.443770, lapse: 0.003sec.
# 653-th iteration finished, shat_eps: 97.423453, lapse: 0.004sec.
# 654-th iteration finished, shat_eps: 97.403168, lapse: 0.015sec.
# 655-th iteration finished, shat_eps: 97.382915, lapse: 0.009sec.
# 656-th iteration finished, shat_eps: 97.362694, lapse: 0.008sec.
# 657-th iteration finished, shat_eps: 97.342505, lapse: 0.013sec.
# 658-th iteration finished, shat_eps: 97.322347, lapse: 0.007sec.
# 659-th iteration finished, shat_eps: 97.302221, lapse: 0.008sec.
# 660-th iteration finished, shat_eps: 97.282126, lapse: 0.014sec.
# 661-th iteration finished, shat_eps: 97.262062, lapse: 0.018sec.
# 662-th iteration finished, shat_eps: 97.242030, lapse: 0.020sec.
# 663-th iteration finished, shat_eps: 97.222029, lapse: 0.008sec.
# 664-th iteration finished, shat_eps: 97.202059, lapse: 0.005sec.
# 665-th iteration finished, shat_eps: 97.182121, lapse: 0.008sec.
# 666-th iteration finished, shat_eps: 97.162212, lapse: 0.012sec.
# 667-th iteration finished, shat_eps: 97.142335, lapse: 0.004sec.
# 668-th iteration finished, shat_eps: 97.122489, lapse: 0.004sec.
# 669-th iteration finished, shat_eps: 97.102673, lapse: 0.005sec.
# 670-th iteration finished, shat_eps: 97.082888, lapse: 0.009sec.
# 671-th iteration finished, shat_eps: 97.063133, lapse: 0.019sec.
# 672-th iteration finished, shat_eps: 97.043408, lapse: 0.006sec.
# 673-th iteration finished, shat_eps: 97.023714, lapse: 0.019sec.
# 674-th iteration finished, shat_eps: 97.004050, lapse: 0.011sec.
# 675-th iteration finished, shat_eps: 96.984416, lapse: 0.007sec.
# 676-th iteration finished, shat_eps: 96.964812, lapse: 0.019sec.
# 677-th iteration finished, shat_eps: 96.945237, lapse: 0.005sec.
# 678-th iteration finished, shat_eps: 96.925693, lapse: 0.004sec.
# 679-th iteration finished, shat_eps: 96.906179, lapse: 0.020sec.
# 680-th iteration finished, shat_eps: 96.886694, lapse: 0.008sec.
# 681-th iteration finished, shat_eps: 96.867238, lapse: 0.007sec.
# 682-th iteration finished, shat_eps: 96.847812, lapse: 0.015sec.
# 683-th iteration finished, shat_eps: 96.828416, lapse: 0.016sec.
# 684-th iteration finished, shat_eps: 96.809049, lapse: 0.007sec.
# 685-th iteration finished, shat_eps: 96.789711, lapse: 0.017sec.
# 686-th iteration finished, shat_eps: 96.770402, lapse: 0.005sec.
# 687-th iteration finished, shat_eps: 96.751122, lapse: 0.009sec.
# 688-th iteration finished, shat_eps: 96.731871, lapse: 0.005sec.
# 689-th iteration finished, shat_eps: 96.712649, lapse: 0.017sec.
# 690-th iteration finished, shat_eps: 96.693456, lapse: 0.003sec.
# 691-th iteration finished, shat_eps: 96.674292, lapse: 0.006sec.
# 692-th iteration finished, shat_eps: 96.655156, lapse: 0.021sec.
# 693-th iteration finished, shat_eps: 96.636049, lapse: 0.008sec.
# 694-th iteration finished, shat_eps: 96.616970, lapse: 0.008sec.
# 695-th iteration finished, shat_eps: 96.597920, lapse: 0.019sec.
# 696-th iteration finished, shat_eps: 96.578898, lapse: 0.007sec.
# 697-th iteration finished, shat_eps: 96.559904, lapse: 0.008sec.
# 698-th iteration finished, shat_eps: 96.540939, lapse: 0.011sec.
# 699-th iteration finished, shat_eps: 96.522001, lapse: 0.008sec.
# 700-th iteration finished, shat_eps: 96.503092, lapse: 0.005sec.
# 701-th iteration finished, shat_eps: 96.484210, lapse: 0.005sec.
# 702-th iteration finished, shat_eps: 96.465356, lapse: 0.006sec.
# 703-th iteration finished, shat_eps: 96.446530, lapse: 0.030sec.
# 704-th iteration finished, shat_eps: 96.427732, lapse: 0.036sec.
# 705-th iteration finished, shat_eps: 96.408961, lapse: 0.024sec.
# 706-th iteration finished, shat_eps: 96.390218, lapse: 0.026sec.
# 707-th iteration finished, shat_eps: 96.371502, lapse: 0.008sec.
# 708-th iteration finished, shat_eps: 96.352814, lapse: 0.007sec.
# 709-th iteration finished, shat_eps: 96.334153, lapse: 0.013sec.
# 710-th iteration finished, shat_eps: 96.315519, lapse: 0.004sec.
# 711-th iteration finished, shat_eps: 96.296912, lapse: 0.011sec.
# 712-th iteration finished, shat_eps: 96.278333, lapse: 0.007sec.
# 713-th iteration finished, shat_eps: 96.259780, lapse: 0.003sec.
# 714-th iteration finished, shat_eps: 96.241254, lapse: 0.021sec.
# 715-th iteration finished, shat_eps: 96.222756, lapse: 0.006sec.
# 716-th iteration finished, shat_eps: 96.204283, lapse: 0.021sec.
# 717-th iteration finished, shat_eps: 96.185838, lapse: 0.008sec.
# 718-th iteration finished, shat_eps: 96.167419, lapse: 0.007sec.
# 719-th iteration finished, shat_eps: 96.149027, lapse: 0.015sec.
# 720-th iteration finished, shat_eps: 96.130661, lapse: 0.018sec.
# 721-th iteration finished, shat_eps: 96.112322, lapse: 0.019sec.
# 722-th iteration finished, shat_eps: 96.094009, lapse: 0.012sec.
# 723-th iteration finished, shat_eps: 96.075722, lapse: 0.020sec.
# 724-th iteration finished, shat_eps: 96.057462, lapse: 0.007sec.
# 725-th iteration finished, shat_eps: 96.039227, lapse: 0.006sec.
# 726-th iteration finished, shat_eps: 96.021019, lapse: 0.006sec.
# 727-th iteration finished, shat_eps: 96.002836, lapse: 0.017sec.
# 728-th iteration finished, shat_eps: 95.984680, lapse: 0.006sec.
# 729-th iteration finished, shat_eps: 95.966549, lapse: 0.008sec.
# 730-th iteration finished, shat_eps: 95.948444, lapse: 0.020sec.
# 731-th iteration finished, shat_eps: 95.930365, lapse: 0.007sec.
# ...
# 1759-th iteration finished, shat_eps: 84.668269, lapse: 0.034sec.
# 1760-th iteration finished, shat_eps: 84.661415, lapse: 0.016sec.
# 1761-th iteration finished, shat_eps: 84.654565, lapse: 0.024sec.
# 1762-th iteration finished, shat_eps: 84.647721, lapse: 0.007sec.
# 1763-th iteration finished, shat_eps: 84.640881, lapse: 0.018sec.
# 1764-th iteration finished, shat_eps: 84.634047, lapse: 0.018sec.
# 1765-th iteration finished, shat_eps: 84.627217, lapse: 0.017sec.
# 1766-th iteration finished, shat_eps: 84.620393, lapse: 0.005sec.
# 1767-th iteration finished, shat_eps: 84.613573, lapse: 0.005sec.
# 1768-th iteration finished, shat_eps: 84.606759, lapse: 0.011sec.
# 1769-th iteration finished, shat_eps: 84.599949, lapse: 0.011sec.
# 1770-th iteration finished, shat_eps: 84.593145, lapse: 0.009sec.
# 1771-th iteration finished, shat_eps: 84.586345, lapse: 0.004sec.
# 1772-th iteration finished, shat_eps: 84.579551, lapse: 0.003sec.
# 1773-th iteration finished, shat_eps: 84.572761, lapse: 0.018sec.
# 1774-th iteration finished, shat_eps: 84.565977, lapse: 0.005sec.
# 1775-th iteration finished, shat_eps: 84.559197, lapse: 0.010sec.
# 1776-th iteration finished, shat_eps: 84.552423, lapse: 0.005sec.
# 1777-th iteration finished, shat_eps: 84.545653, lapse: 0.019sec.
# 1778-th iteration finished, shat_eps: 84.538889, lapse: 0.004sec.
# 1779-th iteration finished, shat_eps: 84.532129, lapse: 0.024sec.
# 1780-th iteration finished, shat_eps: 84.525374, lapse: 0.008sec.
# 1781-th iteration finished, shat_eps: 84.518624, lapse: 0.007sec.
# 1782-th iteration finished, shat_eps: 84.511880, lapse: 0.022sec.
# 1783-th iteration finished, shat_eps: 84.505140, lapse: 0.009sec.
# 1784-th iteration finished, shat_eps: 84.498405, lapse: 0.004sec.
# 1785-th iteration finished, shat_eps: 84.491675, lapse: 0.013sec.
# 1786-th iteration finished, shat_eps: 84.484950, lapse: 0.004sec.
# 1787-th iteration finished, shat_eps: 84.478229, lapse: 0.006sec.
# 1788-th iteration finished, shat_eps: 84.471514, lapse: 0.010sec.
# 1789-th iteration finished, shat_eps: 84.464804, lapse: 0.013sec.
# 1790-th iteration finished, shat_eps: 84.458098, lapse: 0.013sec.
# 1791-th iteration finished, shat_eps: 84.451398, lapse: 0.006sec.
# 1792-th iteration finished, shat_eps: 84.444702, lapse: 0.004sec.
# 1793-th iteration finished, shat_eps: 84.438012, lapse: 0.019sec.
# 1794-th iteration finished, shat_eps: 84.431326, lapse: 0.006sec.
# 1795-th iteration finished, shat_eps: 84.424645, lapse: 0.008sec.
# 1796-th iteration finished, shat_eps: 84.417969, lapse: 0.016sec.
# 1797-th iteration finished, shat_eps: 84.411298, lapse: 0.006sec.
# 1798-th iteration finished, shat_eps: 84.404631, lapse: 0.004sec.
# 1799-th iteration finished, shat_eps: 84.397970, lapse: 0.008sec.
# 1800-th iteration finished, shat_eps: 84.391313, lapse: 0.015sec.
# 1801-th iteration finished, shat_eps: 84.384662, lapse: 0.007sec.
# 1802-th iteration finished, shat_eps: 84.378015, lapse: 0.004sec.
# 1803-th iteration finished, shat_eps: 84.371373, lapse: 0.019sec.
# 1804-th iteration finished, shat_eps: 84.364736, lapse: 0.014sec.
# 1805-th iteration finished, shat_eps: 84.358104, lapse: 0.004sec.
# 1806-th iteration finished, shat_eps: 84.351476, lapse: 0.007sec.
# 1807-th iteration finished, shat_eps: 84.344854, lapse: 0.028sec.
# 1808-th iteration finished, shat_eps: 84.338236, lapse: 0.023sec.
# 1809-th iteration finished, shat_eps: 84.331623, lapse: 0.007sec.
# 1810-th iteration finished, shat_eps: 84.325015, lapse: 0.004sec.
# 1811-th iteration finished, shat_eps: 84.318412, lapse: 0.020sec.
# 1812-th iteration finished, shat_eps: 84.311813, lapse: 0.012sec.
# 1813-th iteration finished, shat_eps: 84.305220, lapse: 0.006sec.
# 1814-th iteration finished, shat_eps: 84.298631, lapse: 0.017sec.
# 1815-th iteration finished, shat_eps: 84.292047, lapse: 0.005sec.
# 1816-th iteration finished, shat_eps: 84.285468, lapse: 0.008sec.
# 1817-th iteration finished, shat_eps: 84.278894, lapse: 0.018sec.
# 1818-th iteration finished, shat_eps: 84.272324, lapse: 0.005sec.
# 1819-th iteration finished, shat_eps: 84.265759, lapse: 0.003sec.
# 1820-th iteration finished, shat_eps: 84.259199, lapse: 0.011sec.
# 1821-th iteration finished, shat_eps: 84.252644, lapse: 0.013sec.
# 1822-th iteration finished, shat_eps: 84.246094, lapse: 0.039sec.
# 1823-th iteration finished, shat_eps: 84.239548, lapse: 0.009sec.
# 1824-th iteration finished, shat_eps: 84.233007, lapse: 0.018sec.
# 1825-th iteration finished, shat_eps: 84.226471, lapse: 0.007sec.
# 1826-th iteration finished, shat_eps: 84.219940, lapse: 0.006sec.
# 1827-th iteration finished, shat_eps: 84.213413, lapse: 0.004sec.
# 1828-th iteration finished, shat_eps: 84.206892, lapse: 0.018sec.
# 1829-th iteration finished, shat_eps: 84.200375, lapse: 0.007sec.
# 1830-th iteration finished, shat_eps: 84.193862, lapse: 0.007sec.
# 1831-th iteration finished, shat_eps: 84.187355, lapse: 0.014sec.
# 1832-th iteration finished, shat_eps: 84.180852, lapse: 0.006sec.
# 1833-th iteration finished, shat_eps: 84.174354, lapse: 0.004sec.
# 1834-th iteration finished, shat_eps: 84.167861, lapse: 0.005sec.
# 1835-th iteration finished, shat_eps: 84.161372, lapse: 0.007sec.
# 1836-th iteration finished, shat_eps: 84.154888, lapse: 0.016sec.
# 1837-th iteration finished, shat_eps: 84.148409, lapse: 0.005sec.
# 1838-th iteration finished, shat_eps: 84.141935, lapse: 0.006sec.
# 1839-th iteration finished, shat_eps: 84.135465, lapse: 0.005sec.
# 1840-th iteration finished, shat_eps: 84.129000, lapse: 0.020sec.
# 1841-th iteration finished, shat_eps: 84.122540, lapse: 0.010sec.
# 1842-th iteration finished, shat_eps: 84.116084, lapse: 0.023sec.
# 1843-th iteration finished, shat_eps: 84.109633, lapse: 0.017sec.
# 1844-th iteration finished, shat_eps: 84.103187, lapse: 0.020sec.
# 1845-th iteration finished, shat_eps: 84.096746, lapse: 0.022sec.
# 1846-th iteration finished, shat_eps: 84.090309, lapse: 0.016sec.
# 1847-th iteration finished, shat_eps: 84.083877, lapse: 0.022sec.
# 1848-th iteration finished, shat_eps: 84.077449, lapse: 0.008sec.
# 1849-th iteration finished, shat_eps: 84.071027, lapse: 0.006sec.
# 1850-th iteration finished, shat_eps: 84.064609, lapse: 0.023sec.
# 1851-th iteration finished, shat_eps: 84.058195, lapse: 0.003sec.
# 1852-th iteration finished, shat_eps: 84.051786, lapse: 0.038sec.
# 1853-th iteration finished, shat_eps: 84.045382, lapse: 0.008sec.
# 1854-th iteration finished, shat_eps: 84.038983, lapse: 0.018sec.
# 1855-th iteration finished, shat_eps: 84.032588, lapse: 0.034sec.
# 1856-th iteration finished, shat_eps: 84.026198, lapse: 0.009sec.
# 1857-th iteration finished, shat_eps: 84.019813, lapse: 0.023sec.
# 1858-th iteration finished, shat_eps: 84.013432, lapse: 0.007sec.
# 1859-th iteration finished, shat_eps: 84.007056, lapse: 0.017sec.
# 1860-th iteration finished, shat_eps: 84.000684, lapse: 0.012sec.
# 1861-th iteration finished, shat_eps: 83.994317, lapse: 0.006sec.
# 1862-th iteration finished, shat_eps: 83.987955, lapse: 0.006sec.
# 1863-th iteration finished, shat_eps: 83.981598, lapse: 0.012sec.
# 1864-th iteration finished, shat_eps: 83.975245, lapse: 0.007sec.
# 1865-th iteration finished, shat_eps: 83.968896, lapse: 0.008sec.
# 1866-th iteration finished, shat_eps: 83.962552, lapse: 0.004sec.
# 1867-th iteration finished, shat_eps: 83.956213, lapse: 0.016sec.
# 1868-th iteration finished, shat_eps: 83.949879, lapse: 0.006sec.
# 1869-th iteration finished, shat_eps: 83.943549, lapse: 0.006sec.
# 1870-th iteration finished, shat_eps: 83.937224, lapse: 0.006sec.
# 1871-th iteration finished, shat_eps: 83.930903, lapse: 0.023sec.
# 1872-th iteration finished, shat_eps: 83.924587, lapse: 0.008sec.
# 1873-th iteration finished, shat_eps: 83.918275, lapse: 0.014sec.
# 1874-th iteration finished, shat_eps: 83.911968, lapse: 0.006sec.
# 1875-th iteration finished, shat_eps: 83.905666, lapse: 0.003sec.
# 1876-th iteration finished, shat_eps: 83.899368, lapse: 0.033sec.
# 1877-th iteration finished, shat_eps: 83.893075, lapse: 0.011sec.
# 1878-th iteration finished, shat_eps: 83.886786, lapse: 0.016sec.
# 1879-th iteration finished, shat_eps: 83.880502, lapse: 0.010sec.
# 1880-th iteration finished, shat_eps: 83.874223, lapse: 0.012sec.
# 1881-th iteration finished, shat_eps: 83.867948, lapse: 0.019sec.
# 1882-th iteration finished, shat_eps: 83.861677, lapse: 0.008sec.
# 1883-th iteration finished, shat_eps: 83.855411, lapse: 0.014sec.
# 1884-th iteration finished, shat_eps: 83.849150, lapse: 0.007sec.
# 1885-th iteration finished, shat_eps: 83.842893, lapse: 0.009sec.
# 1886-th iteration finished, shat_eps: 83.836641, lapse: 0.005sec.
# 1887-th iteration finished, shat_eps: 83.830393, lapse: 0.003sec.
# 1888-th iteration finished, shat_eps: 83.824150, lapse: 0.023sec.
# 1889-th iteration finished, shat_eps: 83.817912, lapse: 0.027sec.
# 1890-th iteration finished, shat_eps: 83.811678, lapse: 0.009sec.
# 1891-th iteration finished, shat_eps: 83.805448, lapse: 0.008sec.
# 1892-th iteration finished, shat_eps: 83.799223, lapse: 0.017sec.
# 1893-th iteration finished, shat_eps: 83.793003, lapse: 0.010sec.
# 1894-th iteration finished, shat_eps: 83.786787, lapse: 0.016sec.
# 1895-th iteration finished, shat_eps: 83.780575, lapse: 0.008sec.
# 1896-th iteration finished, shat_eps: 83.774368, lapse: 0.015sec.
# 1897-th iteration finished, shat_eps: 83.768166, lapse: 0.022sec.
# 1898-th iteration finished, shat_eps: 83.761968, lapse: 0.020sec.
# 1899-th iteration finished, shat_eps: 83.755775, lapse: 0.006sec.
# 1900-th iteration finished, shat_eps: 83.749586, lapse: 0.007sec.
# 1901-th iteration finished, shat_eps: 83.743401, lapse: 0.005sec.
# 1902-th iteration finished, shat_eps: 83.737221, lapse: 0.003sec.
# 1903-th iteration finished, shat_eps: 83.731046, lapse: 0.018sec.
# 1904-th iteration finished, shat_eps: 83.724875, lapse: 0.012sec.
# 1905-th iteration finished, shat_eps: 83.718708, lapse: 0.007sec.
# 1906-th iteration finished, shat_eps: 83.712546, lapse: 0.022sec.
# 1907-th iteration finished, shat_eps: 83.706389, lapse: 0.007sec.
# 1908-th iteration finished, shat_eps: 83.700235, lapse: 0.017sec.
# 1909-th iteration finished, shat_eps: 83.694087, lapse: 0.010sec.
# 1910-th iteration finished, shat_eps: 83.687943, lapse: 0.020sec.
# 1911-th iteration finished, shat_eps: 83.681803, lapse: 0.017sec.
# 1912-th iteration finished, shat_eps: 83.675668, lapse: 0.026sec.
# 1913-th iteration finished, shat_eps: 83.669537, lapse: 0.006sec.
# 1914-th iteration finished, shat_eps: 83.663410, lapse: 0.022sec.
# 1915-th iteration finished, shat_eps: 83.657288, lapse: 0.011sec.
# 1916-th iteration finished, shat_eps: 83.651171, lapse: 0.018sec.
# 1917-th iteration finished, shat_eps: 83.645058, lapse: 0.006sec.
# 1918-th iteration finished, shat_eps: 83.638949, lapse: 0.003sec.
# 1919-th iteration finished, shat_eps: 83.632845, lapse: 0.011sec.
# 1920-th iteration finished, shat_eps: 83.626745, lapse: 0.018sec.
# 1921-th iteration finished, shat_eps: 83.620650, lapse: 0.004sec.
# 1922-th iteration finished, shat_eps: 83.614559, lapse: 0.012sec.
# 1923-th iteration finished, shat_eps: 83.608473, lapse: 0.025sec.
# 1924-th iteration finished, shat_eps: 83.602391, lapse: 0.007sec.
# 1925-th iteration finished, shat_eps: 83.596313, lapse: 0.011sec.
# 1926-th iteration finished, shat_eps: 83.590240, lapse: 0.005sec.
# 1927-th iteration finished, shat_eps: 83.584171, lapse: 0.004sec.
# 1928-th iteration finished, shat_eps: 83.578106, lapse: 0.004sec.
# 1929-th iteration finished, shat_eps: 83.572046, lapse: 0.007sec.
# 1930-th iteration finished, shat_eps: 83.565991, lapse: 0.019sec.
# 1931-th iteration finished, shat_eps: 83.559939, lapse: 0.030sec.
# 1932-th iteration finished, shat_eps: 83.553892, lapse: 0.011sec.
# 1933-th iteration finished, shat_eps: 83.547850, lapse: 0.007sec.
# 1934-th iteration finished, shat_eps: 83.541812, lapse: 0.022sec.
# 1935-th iteration finished, shat_eps: 83.535778, lapse: 0.029sec.
# 1936-th iteration finished, shat_eps: 83.529749, lapse: 0.010sec.
# 1937-th iteration finished, shat_eps: 83.523724, lapse: 0.015sec.
# 1938-th iteration finished, shat_eps: 83.517703, lapse: 0.006sec.
# 1939-th iteration finished, shat_eps: 83.511687, lapse: 0.008sec.
# 1940-th iteration finished, shat_eps: 83.505675, lapse: 0.004sec.
# 1941-th iteration finished, shat_eps: 83.499667, lapse: 0.006sec.
# 1942-th iteration finished, shat_eps: 83.493664, lapse: 0.018sec.
# 1943-th iteration finished, shat_eps: 83.487665, lapse: 0.004sec.
# 1944-th iteration finished, shat_eps: 83.481671, lapse: 0.011sec.
# 1945-th iteration finished, shat_eps: 83.475681, lapse: 0.020sec.
# 1946-th iteration finished, shat_eps: 83.469695, lapse: 0.014sec.
# 1947-th iteration finished, shat_eps: 83.463713, lapse: 0.027sec.
# 1948-th iteration finished, shat_eps: 83.457736, lapse: 0.005sec.
# 1949-th iteration finished, shat_eps: 83.451763, lapse: 0.018sec.
# 1950-th iteration finished, shat_eps: 83.445795, lapse: 0.004sec.
# 1951-th iteration finished, shat_eps: 83.439831, lapse: 0.022sec.
# 1952-th iteration finished, shat_eps: 83.433871, lapse: 0.010sec.
# 1953-th iteration finished, shat_eps: 83.427915, lapse: 0.005sec.
# 1954-th iteration finished, shat_eps: 83.421964, lapse: 0.004sec.
# 1955-th iteration finished, shat_eps: 83.416017, lapse: 0.018sec.
# 1956-th iteration finished, shat_eps: 83.410075, lapse: 0.008sec.
# 1957-th iteration finished, shat_eps: 83.404136, lapse: 0.009sec.
# 1958-th iteration finished, shat_eps: 83.398202, lapse: 0.014sec.
# 1959-th iteration finished, shat_eps: 83.392273, lapse: 0.006sec.
# 1960-th iteration finished, shat_eps: 83.386347, lapse: 0.004sec.
# 1961-th iteration finished, shat_eps: 83.380426, lapse: 0.009sec.
# 1962-th iteration finished, shat_eps: 83.374510, lapse: 0.021sec.
# 1963-th iteration finished, shat_eps: 83.368597, lapse: 0.009sec.
# 1964-th iteration finished, shat_eps: 83.362689, lapse: 0.004sec.
# 1965-th iteration finished, shat_eps: 83.356785, lapse: 0.021sec.
# 1966-th iteration finished, shat_eps: 83.350885, lapse: 0.016sec.
# 1967-th iteration finished, shat_eps: 83.344990, lapse: 0.014sec.
# 1968-th iteration finished, shat_eps: 83.339099, lapse: 0.006sec.
# 1969-th iteration finished, shat_eps: 83.333212, lapse: 0.013sec.
# 1970-th iteration finished, shat_eps: 83.327329, lapse: 0.022sec.
# 1971-th iteration finished, shat_eps: 83.321451, lapse: 0.006sec.
# 1972-th iteration finished, shat_eps: 83.315577, lapse: 0.007sec.
# 1973-th iteration finished, shat_eps: 83.309707, lapse: 0.014sec.
# 1974-th iteration finished, shat_eps: 83.303842, lapse: 0.006sec.
# 1975-th iteration finished, shat_eps: 83.297980, lapse: 0.006sec.
# 1976-th iteration finished, shat_eps: 83.292123, lapse: 0.019sec.
# 1977-th iteration finished, shat_eps: 83.286271, lapse: 0.039sec.
# 1978-th iteration finished, shat_eps: 83.280422, lapse: 0.022sec.
# 1979-th iteration finished, shat_eps: 83.274578, lapse: 0.022sec.
# 1980-th iteration finished, shat_eps: 83.268738, lapse: 0.054sec.
# 1981-th iteration finished, shat_eps: 83.262902, lapse: 0.011sec.
# 1982-th iteration finished, shat_eps: 83.257070, lapse: 0.018sec.
# 1983-th iteration finished, shat_eps: 83.251243, lapse: 0.013sec.
# 1984-th iteration finished, shat_eps: 83.245420, lapse: 0.007sec.
# 1985-th iteration finished, shat_eps: 83.239601, lapse: 0.034sec.
# 1986-th iteration finished, shat_eps: 83.233786, lapse: 0.012sec.
# 1987-th iteration finished, shat_eps: 83.227975, lapse: 0.006sec.
# 1988-th iteration finished, shat_eps: 83.222169, lapse: 0.006sec.
# 1989-th iteration finished, shat_eps: 83.216367, lapse: 0.004sec.
# 1990-th iteration finished, shat_eps: 83.210569, lapse: 0.015sec.
# 1991-th iteration finished, shat_eps: 83.204775, lapse: 0.012sec.
# 1992-th iteration finished, shat_eps: 83.198986, lapse: 0.011sec.
# 1993-th iteration finished, shat_eps: 83.193200, lapse: 0.018sec.
# 1994-th iteration finished, shat_eps: 83.187419, lapse: 0.030sec.
# 1995-th iteration finished, shat_eps: 83.181642, lapse: 0.007sec.
# 1996-th iteration finished, shat_eps: 83.175870, lapse: 0.006sec.
# 1997-th iteration finished, shat_eps: 83.170101, lapse: 0.021sec.
# 1998-th iteration finished, shat_eps: 83.164337, lapse: 0.007sec.
# 1999-th iteration finished, shat_eps: 83.158576, lapse: 0.004sec.
# 2000-th iteration finished, shat_eps: 83.152820, lapse: 0.006sec.

# %%
mmle_0 = mhs_0[-1]
smle_eps = shs_eps[-1]
bmle = bhs[-1]

# %%
mmle_0, smle_eps, bmle
# Out:
# (31.332443074684353, 83.15282046545586, array([-5.78551628, 10.45236909]))

# %% [markdown]
# ## plots

# %%
plt.plot(shs_eps, label=r"$\hat{r}^{(i)}$")
plt.xlabel("iteration (i)"); plt.legend()

# %%
plt.plot(mhs_0, label=r"$\hat{\mu}^{(i)}$")
plt.xlabel("iteration (i)"); plt.legend()

# %%
plt.plot(bhs, label=r"$\hat{\beta}^{(i)}$")
plt.xlabel("iteration (i)"); plt.legend()

# %% [markdown]
# # 4. Wald's Confidence Region

# %%
Rmle = np.zeros(T+T0)
d1Rm = np.zeros([d, T+T0])
d2Rm = np.zeros([d, d, T+T0])

# %%
for t in np.arange(T+T0):
    o = np.exp(- bmle @ A[t])
    p = 1 / (1 + o)
    q = o / (1 + o)

    Rmle[t] = K * p
    d1Rm[:,t] = K * p * q * A[t]
    d2Rm[:,:,t] = K * p * q * (q - p) * (A[t,:,None] * A[t])

# %%
plt.plot(Rmle)

# %%
Pi = alpha * np.concatenate([[0],pi])[np.maximum(0, T0 + np.arange(T)[:,None] - np.arange(T+T0))]
G = Rmle[:,None] * np.concatenate([[0],g])[np.maximum(0, np.arange(T+T0)[:,None] - np.arange(T+T0))]

# %%
d1G = d1Rm[:,:,None] * np.concatenate([[0],g])[
        np.maximum(0, np.arange(T+T0)[:,None] - np.arange(T+T0))]
d2G = d2Rm[...,None] * np.concatenate([[0],g])[
        np.maximum(0, np.arange(T+T0)[:,None] - np.arange(T+T0))]

# %%
inv_ImG = la.inv(np.eye(T+T0)-G)

# %%
Pi_inv_ImG = Pi @ inv_ImG

# %%
EY = mmle_0 * Pi_inv_ImG[:,0]

# %%
plt.plot(EY+2*smle_eps)
plt.plot(EY)
plt.plot(EY-2*smle_eps)
plt.plot(Y_data)

# %%
d1EY = mmle_0 * (Pi_inv_ImG @ (d1G @ inv_ImG[:,:1]))[...,0]

# %%
d2EY = mmle_0 * (Pi_inv_ImG @ (
    d1G[:,None] @ inv_ImG @ d1G @ inv_ImG[:,:1]
    + d1G @ inv_ImG @ d1G[:,None] @ inv_ImG[:,:1]
    + d2G @ inv_ImG[:,:1]))[...,0]

# %%
Ed2l_ds2 = - 2 * T / smle_eps**2
Ed2l_dsdm = 0
Ed2l_dsdb = np.zeros(d)
Ed2l_dm2 = - np.sum(Pi_inv_ImG[:,0]**2) / smle_eps**2
Ed2l_dmdb = - np.sum(Pi_inv_ImG[:,0] * d1EY, 1) / smle_eps**2
Ed2l_db2 = - d1EY @ d1EY.T / smle_eps**2

# %%
Ed2l_dms2 = np.array(
    [[Ed2l_dm2, Ed2l_dsdm],
     [Ed2l_dsdm, Ed2l_ds2]]
)
Ed2l_dmsdb = np.stack([Ed2l_dmdb, Ed2l_dsdb])

# %%
Ihat_dth = - np.block(
    [[Ed2l_dms2, Ed2l_dmsdb],
     [Ed2l_dmsdb.T, Ed2l_db2]])

# %%
Ihat_dth
# Out:
# array([[ 3.62193499e+01, -0.00000000e+00,  4.92890325e+02,
#          2.06478054e+02],
#        [-0.00000000e+00,  4.82200895e-02, -0.00000000e+00,
#         -0.00000000e+00],
#        [ 4.92890325e+02, -0.00000000e+00,  8.40832122e+03,
#          3.43859877e+03],
#        [ 2.06478054e+02, -0.00000000e+00,  3.43859877e+03,
#          1.40970866e+03]])

# %%
la.inv(Ihat_dth)[2:,2:]
# Out:
# array([[ 0.69368316, -1.87490453],
#        [-1.87490453,  5.0718385 ]])

# %%
from matplotlib.patches import Ellipse
import matplotlib.transforms as transforms

def confidence_ellipse(mean, cov, ax, n_std=2.0, facecolor='none', **kwargs):
    """
    Create a plot of the covariance confidence ellipse of *x* and *y*.

    Parameters
    ----------
    x, y : array-like, shape (n, )
        Input data.

    ax : matplotlib.axes.Axes
        The axes object to draw the ellipse into.

    n_std : float
        The number of standard deviations to determine the ellipse's radiuses.

    **kwargs
        Forwarded to `~matplotlib.patches.Ellipse`

    Returns
    -------
    matplotlib.patches.Ellipse
    """

    pearson = cov[0, 1]/np.sqrt(cov[0, 0] * cov[1, 1])
    # Using a special case to obtain the eigenvalues of this
    # two-dimensional dataset.
    ell_radius_x = np.sqrt(1 + pearson)
    ell_radius_y = np.sqrt(1 - pearson)
    ellipse = Ellipse((0, 0), width=ell_radius_x * 2, height=ell_radius_y * 2,
                      facecolor=facecolor, **kwargs)

    # Calculating the standard deviation of x from
    # the squareroot of the variance and multiplying
    # with the given number of standard deviations.
    scale_x = np.sqrt(cov[0, 0]) * n_std
    mean_x = mean[0]

    # calculating the standard deviation of y ...
    scale_y = np.sqrt(cov[1, 1]) * n_std
    mean_y = mean[1]

    transf = transforms.Affine2D() \
        .rotate_deg(45) \
        .scale(scale_x, scale_y) \
        .translate(mean_x, mean_y)

    ellipse.set_transform(transf + ax.transData)
    return ax.add_patch(ellipse)

# %%
plt.figure(figsize=(5,5))
p = plt.scatter(*bmle)
confidence_ellipse(bmle, np.linalg.pinv(Ihat_dth)[2:,2:], 
                   plt.gca(), n_std=2.7, facecolor=p.get_facecolor(), alpha=0.3)

# %%
def EY_t(beta, mu_0, A):
    assert A.shape[0] > T0
    
    T = A.shape[0]-T0
    R = np.zeros(T+T0)
    for t in np.arange(T+T0):
        o = np.exp(- beta @ A[t])
        p = 1 / (1 + o)
        R[t] = K * p 
        
    # g
    g = np.zeros(T+T0)
    g[:np.minimum(T+T0,len(GPi['g']))] \
    = GPi['g'][:np.minimum(T+T0,len(GPi['g']))]
    
    # pi
    pi = np.zeros(T+T0)
    pi[:np.minimum(T+T0,len(GPi['pi']))] \
    = GPi['pi'][:np.minimum(T+T0,len(GPi['pi']))]
        
    Pi = alpha * np.concatenate([[0],pi])[np.maximum(0, T0 + np.arange(T)[:,None] - np.arange(T+T0))]
    G = R[:,None] * np.concatenate([[0],g])[np.maximum(0, np.arange(T+T0)[:,None] - np.arange(T+T0))]
    
    return mu_0 * np.linalg.inv(np.eye(T+T0)-G)[:,0] @ Pi.T

# %%
num_sim = 20
chi_sim = np.linspace(-2.4, 2.4, num_sim)

# %%
u, v = np.linalg.eig(np.linalg.pinv(Ihat_dth)[2:,2:])

# %%
u
# Out:
# array([5.17254372e-04, 5.76500441e+00])

# %%
beta_sim = bmle + v[:,1] * np.sqrt(u[1]) * chi_sim[:,None]
EY_sim = np.zeros([num_sim, T])

# %%
for i, b in enumerate(beta_sim):
    EY_sim[i] = EY_t(b, mmle_0, A)

# %%
plt.figure(figsize=(8,3))
plt.subplot(1,2,1)
plt.scatter(beta_sim[:,0],beta_sim[:,1], c=chi_sim, cmap='rainbow')
plt.xlabel(r'$\beta_0$'); plt.ylabel(r'$\beta_1$')

plt.subplot(1,2,2); 
plt.plot(Y_data, color='grey')
lines = plt.plot(EY_sim.T, alpha=0.3)
plt.xlabel('time (day)'); # plt.ylabel('expected deaths')
for i, l in enumerate(lines):
    l.set_color(plt.cm.rainbow(i/num_sim))
plt.show()

# %%
u, v = np.linalg.eig(np.linalg.pinv(Ihat_dth)[np.ix_([0,2,3],[0,2,3])])

# %%
u
# Out:
# array([8.07919141e+00, 1.00316830e-01, 1.01583101e-04])

# %%
v[:,0]
# Out:
# array([ 0.53853909,  0.29170959, -0.79049425])

# %%
beta_sim = bmle + v[1:,0] * np.sqrt(u[0]) * chi_sim[:,None]
m0_sim = mmle_0 + v[0,0] * np.sqrt(u[0]) * chi_sim[:,None]
EY_sim = np.zeros([num_sim, T])

# %%
for i, (m0, b) in enumerate(zip(m0_sim,beta_sim)):
    EY_sim[i] = EY_t(b, m0, A)

# %%
plt.figure(figsize=(8,3))
plt.subplot(1,2,1)
plt.scatter(beta_sim[:,0],beta_sim[:,1], c=chi_sim, cmap='rainbow')
plt.xlabel(r'$\beta_0$'); plt.ylabel(r'$\beta_1$')

plt.subplot(1,2,2); 
plt.plot(Y_data, color='grey')
lines = plt.plot(EY_sim.T, alpha=0.3)
plt.xlabel('time (day)'); # plt.ylabel('expected deaths')
for i, l in enumerate(lines):
    l.set_color(plt.cm.rainbow(i/num_sim))
plt.show()

# %% [markdown]
# # 5. Sandwich estimator

# %%
L_HAC = np.floor(4* (T/100)**(2/9))

# %%
w_HAC = np.maximum(1 - np.abs(np.arange(T)[:,None] - np.arange(T))/L_HAC, 0)

# %%
dlt_dm = Pi_inv_ImG[:,0] * (Y_data - EY) / smle_eps**2
dlt_dsp = - 1 / smle_eps + (Y_data - EY)**2 / smle_eps**3
dlt_db = d1EY * (Y_data - EY) / smle_eps**2

# %%
dlt_dth = np.concatenate([np.array([dlt_dm, dlt_dsp]), dlt_db], 0)

# %%
VEdl = dlt_dth @ w_HAC @ dlt_dth.T

# %%
VEdl
# Out:
# array([[2.79119703e+02, 2.45768363e+00, 3.16693702e+03, 1.36022665e+03],
#        [2.45768363e+00, 2.44091471e-01, 1.35726194e+01, 6.60216087e+00],
#        [3.16693702e+03, 1.35726194e+01, 4.09145138e+04, 1.73017873e+04],
#        [1.36022665e+03, 6.60216087e+00, 1.73017873e+04, 7.33013291e+03]])

# %%
Ihat_sdw = Ihat_dth @ la.inv(VEdl) @ Ihat_dth

# %%
Ihat_sdw
# Out:
# array([[ 7.00489960e+00, -2.44343914e-02,  1.31831026e+02,
#          5.31905898e+01],
#        [-2.44343914e-02,  1.28281391e-02,  9.40732288e-01,
#          3.31961714e-01],
#        [ 1.31831026e+02,  9.40732288e-01,  3.12963418e+03,
#          1.23925537e+03],
#        [ 5.31905898e+01,  3.31961714e-01,  1.23925537e+03,
#          4.91436759e+02]])

# %%
Ihat_dth
# Out:
# array([[ 3.62193499e+01, -0.00000000e+00,  4.92890325e+02,
#          2.06478054e+02],
#        [-0.00000000e+00,  4.82200895e-02, -0.00000000e+00,
#         -0.00000000e+00],
#        [ 4.92890325e+02, -0.00000000e+00,  8.40832122e+03,
#          3.43859877e+03],
#        [ 2.06478054e+02, -0.00000000e+00,  3.43859877e+03,
#          1.40970866e+03]])

# %%
la.inv(Ihat_sdw)[2:,2:]
# Out:
# array([[ 2.76445782, -7.53540289],
#        [-7.53540289, 20.5551521 ]])

# %%
num_sim = 20
chi_sim = np.linspace(-2.4, 2.4, num_sim)

# %%
u, v = np.linalg.eig(np.linalg.pinv(Ihat_sdw)[2:,2:])

# %%
u
# Out:
# array([1.78208401e-03, 2.33178278e+01])

# %%
beta_sim = bmle + v[:,1] * np.sqrt(u[1]) * chi_sim[:,None]
EY_sim = np.zeros([num_sim, T])

# %%
for i, b in enumerate(beta_sim):
    EY_sim[i] = EY_t(b, mmle_0, A)

# %%
plt.figure(figsize=(8,3))
plt.subplot(1,2,1)
plt.scatter(beta_sim[:,0],beta_sim[:,1], c=chi_sim, cmap='rainbow')
plt.xlabel(r'$\beta_0$'); plt.ylabel(r'$\beta_1$')

plt.subplot(1,2,2); 
plt.plot(Y_data, color='grey')
lines = plt.plot(EY_sim.T, alpha=0.3)
plt.xlabel('time (day)'); # plt.ylabel('expected deaths')
for i, l in enumerate(lines):
    l.set_color(plt.cm.rainbow(i/num_sim))
plt.show()

# %%
num_sim = 20
chi_sim = np.linspace(-2, 2, num_sim)

# %%
u, v = np.linalg.eig(np.linalg.pinv(Ihat_dth)[np.ix_([0,2,3],[0,2,3])])

# %%
u
# Out:
# array([8.07919141e+00, 1.00316830e-01, 1.01583101e-04])

# %%
beta_sim = bmle + v[1:,0] * np.sqrt(u[0]) * chi_sim[:,None]
m0_sim = mmle_0 + v[0,0] * np.sqrt(u[0]) * chi_sim[:,None]
EY_sim = np.zeros([num_sim, T])

# %%
for i, (m0, b) in enumerate(zip(m0_sim,beta_sim)):
    EY_sim[i] = EY_t(b, m0, A)

# %%
plt.figure(figsize=(8,3))
plt.subplot(1,2,1)
plt.scatter(beta_sim[:,0],beta_sim[:,1], c=chi_sim, cmap='rainbow')
plt.xlabel(r'$\beta_0$'); plt.ylabel(r'$\beta_1$')

plt.subplot(1,2,2); 
plt.plot(Y_data, color='grey')
lines = plt.plot(EY_sim.T, alpha=0.3)
plt.xlabel('time (day)'); # plt.ylabel('expected deaths')
for i, l in enumerate(lines):
    l.set_color(plt.cm.rainbow(i/num_sim))
plt.show()

# %% [markdown]
# # 6. Causal forecasting

# %%
Tf = 50
Af = np.zeros([Tf, d])

# %%
Af[:,0] = np.full(Tf, 1)
Af[:,1] = np.full(Tf, 0.5)

# %%
Te = T+Tf
Ae = np.concatenate([A, Af], 0)

# %%
# g
ge = np.zeros(Te+T0)
ge[:GPi['g'].shape[0]] = GPi['g']

# pi
pie = np.zeros(Te+T0)
pie[:GPi['pi'].shape[0]] = GPi['pi']

# %%
num_sim = 1000

# %%
bsim = np.random.multivariate_normal(bmle, la.inv(Ihat_dth)[2:,2:], num_sim)

# %%
Rmle = np.zeros(Te+T0)
Rsim = np.zeros([num_sim,Te+T0])

# %%
for t in np.arange(Te+T0):
    o = np.exp(- bmle @ Ae[t])
    p = 1 / (1 + o)
    Rmle[t] = K * p
    
    o = np.exp(- bsim @ Ae[t])
    p = 1 / (1 + o)
    Rsim[:,t] = K * p

# %%
Pie = alpha * np.concatenate([[0],pie])[np.maximum(0, T0 + np.arange(Te)[:,None] - np.arange(Te+T0))]
Ge = Rmle[:,None] * np.concatenate([[0],ge])[np.maximum(0, np.arange(Te+T0)[:,None] - np.arange(Te+T0))]
Gesim = Rsim[:,:,None] * np.concatenate([[0],ge])[np.maximum(0, np.arange(Te+T0)[:,None] - np.arange(Te+T0))]

# %%
EYf = mmle_0 * np.linalg.inv(np.eye(Te+T0)-Ge)[:,0] @ Pie.T
EYf_sim = mmle_0 * np.linalg.inv(np.eye(Te+T0)-Gesim)[:,:,0] @ Pie.T

# %%
plt.plot(EYf)
plt.fill_between(np.arange(Te), np.quantile(EYf_sim, 0.975, 0), np.quantile(EYf_sim, 0.025, 0),
                 alpha=0.3)
plt.plot(Y_data)

# %%
EY_sim
