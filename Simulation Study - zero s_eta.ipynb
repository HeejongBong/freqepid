# %%
import os, importlib, sys, time

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
import scipy.linalg as la
import scipy.stats as stats

# %% [markdown]
# # 1. parameters

# %%
T = 120
T0 = 20

# %%
GPi = np.load('EuropeCovid2_GPi.npz')

# %% [markdown]
# ## observation parameters

# %%
pi = np.zeros(T+T0)
pi[:GPi['pi'].shape[0]] = GPi['pi']
alpha = 1
s_eps = 138

# %% [markdown]
# $$Y_t = \alpha \sum_{s=1}^{t-1} I_s g_{t-s} + \epsilon_t$$
#
# $$\epsilon_t \sim N(0,\sigma_\epsilon^2)$$

# %% [markdown]
# ## latent parameters

# %%
g = np.zeros(T+T0)
g[:GPi['g'].shape[0]] = GPi['g']

# %%
d = 2
beta = [0.2, 1.8]
K = 6.5

# %% [markdown]
# $$I_0 = \mu + \eta_0$$
#
# $$I_t = R(\bar{A}_t, \beta) \sum_{s=1}^{t-1}I_s \pi_{t-s} + \eta_t, ~~ t \geq 1$$
#
# $$\eta_t \sim N(0,\sigma_\eta^2)$$
#
# $$R(\bar{A}_t, \beta) = \frac{K}{1+\exp(\beta \sum_{s=1}^{t-1}A_s h_{t-s})}$$

# %% [markdown]
# ## seed values

# %%
mu_0 = 18

# %% [markdown]
# # 2. simulation

# %%
R = np.zeros(T+T0)
I = np.zeros(T+T0)
A = np.zeros([T+T0, d])
Y = np.zeros(T)

# %% [markdown]
# ## initialization

# %%
A[0] = [1, 0]
R[0] = K / (1 + np.exp(beta @ A[0]))
I[0] = mu_0

# %% [markdown]
# ## iteration

# %%
for t in np.arange(1,T+T0):
    A[t] = [1, 1 * (t > 36)]
    R[t] = K / (1 + np.exp(beta @ A[t]))
    I[t] = R[t] * np.sum(np.flip(I[:t])*g[:t])

# %%
for t in np.arange(T):
    Y[t] = alpha * np.sum(np.flip(I[:t+T0])*pi[:t+T0]) + np.random.normal(0,s_eps)

# %% [markdown]
# ## result

# %%
plt.plot(A)
# Out:
# [<matplotlib.lines.Line2D at 0x1558ae5b0>,
#  <matplotlib.lines.Line2D at 0x1558ae610>]

# %%
plt.plot(R)

# %%
plt.plot(I[T0:])

# %%
plt.plot(Y)

# %% [markdown]
# # 3. fit by EM algorithm

# %%
def fit(obs, minit_0, sinit_eps, binit,
        n_iter=3000, history=False, verbose=False):
    
    mhat_0=minit_0
    shat_eps = sinit_eps
    bhat=binit
    
    mhat = np.concatenate([[mhat_0], np.zeros(T+T0-1)])
    
    if history:
        mhs_0 = np.zeros(n_iter)
        shs_eps = np.zeros(n_iter)
        bhs = np.zeros([n_iter, d])
        
    Rhat = np.zeros(T+T0)
    d1Rh = np.zeros([d, T+T0])
    d2Rh = np.zeros([d, d, T+T0])
    
    for t in np.arange(T+T0):
        o = np.exp(bhat @ A[t])
        p = 1 / (1 + o)
        q = o / (1 + o)

        Rhat[t] = K * p
        d1Rh[:,t] = - K * p * q * A[t]
        d2Rh[:,:,t] = K * p * q * (q - p) * (A[t,:,None] * A[t])

    Pi = alpha * np.concatenate([[0],pi])[np.maximum(0, T0 + np.arange(T)[:,None] - np.arange(T+T0))]
    G = Rhat[:,None] * np.concatenate([[0],g])[np.maximum(0, np.arange(T+T0)[:,None] - np.arange(T+T0))]
    inv_ImG = la.inv(np.eye(T+T0)-G)
    
    EY = (Pi @ (inv_ImG @ mhat[:,None]))[...,0]
    shat_eps = np.sqrt(np.sum((obs-EY)**2)/T)
    
    if verbose:
        print("Before EM, shat_eps: %f"%shat_eps)
    
    for i in np.arange(n_iter):
        start_iter = time.time()

        # iteration for mu
        mhat_0 = (obs @ Pi @ inv_ImG[:,0]) / np.sum((Pi @ inv_ImG[:,0])**2)
        mhat = np.concatenate([[mhat_0], np.zeros(T+T0-1)])
        
        # iteration for beta
        d1G = d1Rh[:,:,None] * np.concatenate([[0],g])[
                np.maximum(0, np.arange(T+T0)[:,None] - np.arange(T+T0))]
        d2G = d2Rh[...,None] * np.concatenate([[0],g])[
                np.maximum(0, np.arange(T+T0)[:,None] - np.arange(T+T0))]
        
        EY = (Pi @ (inv_ImG @ mhat[:,None]))[...,0]
        d1EY = (Pi @ (inv_ImG @ (d1G @ (inv_ImG @ mhat[:,None]))))[...,0]
        d2EY = (Pi @ (inv_ImG @ d1G[:,None] @ inv_ImG @ d1G @ inv_ImG
                      + inv_ImG @ d1G @ inv_ImG @ d1G[:,None] @ inv_ImG
                      + inv_ImG @ d2G @ inv_ImG) @ mhat[:,None])[...,0]
        
        d1f = - (2/(T+T0)/shat_eps**2) * d1EY @ (obs - EY)
        d2f = (2/(T+T0)/shat_eps**2) * (d1EY @ d1EY.T - d2EY @ (obs-EY))
        
        u, v = la.eig(d2f)
        db = np.real(((v/np.maximum(u,np.max(u)/100)) @ v.T) @ d1f)
        ss = np.min([1, 0.3/np.sqrt(np.sum(db**2))])
        bhat = bhat - ss * db
        
        for t in np.arange(T+T0):
            o = np.exp(bhat @ A[t])
            p = 1 / (1 + o)
            q = o / (1 + o)

            Rhat[t] = K * p
            d1Rh[:,t] = - K * p * q * A[t]
            d2Rh[:,:,t] = K * p * q * (q - p) * (A[t,:,None] * A[t])

        Pi = alpha * np.concatenate([[0],pi])[np.maximum(0, T0 + np.arange(T)[:,None] - np.arange(T+T0))]
        G = Rhat[:,None] * np.concatenate([[0],g])[np.maximum(0, np.arange(T+T0)[:,None] - np.arange(T+T0))]
        inv_ImG = la.inv(np.eye(T+T0)-G)
    
        EY = (Pi @ (inv_ImG @ mhat[:,None]))[...,0]
        shat_eps = np.sqrt(np.sum((obs-EY)**2)/T)
    
        if history:
            mhs_0[i] = mhat_0
            shs_eps[i] = shat_eps
            bhs[i] = bhat
        
        if verbose:
            print("%d-th iteration finished, shat_eps: %f, lapse: %.3fsec."
                  %(i+1, shat_eps, time.time()-start_iter))
            
    if history:
        return mhs_0, shs_eps, bhs
    else:
        return mhat_0, shat_eps, bhat

# %%
mhs_0, shs_eps, bhs =\
    fit(Y, mu_0, s_eps, beta, history=True, verbose=True, n_iter=3000)
# Out:
# Before EM, shat_eps: 130.553337
# 1-th iteration finished, shat_eps: 129.289374, lapse: 0.010sec.
# 2-th iteration finished, shat_eps: 129.280600, lapse: 0.009sec.
# 3-th iteration finished, shat_eps: 129.280592, lapse: 0.008sec.
# 4-th iteration finished, shat_eps: 129.280586, lapse: 0.008sec.
# 5-th iteration finished, shat_eps: 129.280581, lapse: 0.007sec.
# 6-th iteration finished, shat_eps: 129.280575, lapse: 0.011sec.
# 7-th iteration finished, shat_eps: 129.280569, lapse: 0.006sec.
# 8-th iteration finished, shat_eps: 129.280564, lapse: 0.005sec.
# 9-th iteration finished, shat_eps: 129.280558, lapse: 0.006sec.
# 10-th iteration finished, shat_eps: 129.280552, lapse: 0.006sec.
# 11-th iteration finished, shat_eps: 129.280547, lapse: 0.006sec.
# 12-th iteration finished, shat_eps: 129.280541, lapse: 0.005sec.
# 13-th iteration finished, shat_eps: 129.280535, lapse: 0.006sec.
# 14-th iteration finished, shat_eps: 129.280530, lapse: 0.007sec.
# 15-th iteration finished, shat_eps: 129.280524, lapse: 0.006sec.
# 16-th iteration finished, shat_eps: 129.280519, lapse: 0.006sec.
# 17-th iteration finished, shat_eps: 129.280513, lapse: 0.008sec.
# 18-th iteration finished, shat_eps: 129.280507, lapse: 0.008sec.
# 19-th iteration finished, shat_eps: 129.280502, lapse: 0.005sec.
# 20-th iteration finished, shat_eps: 129.280496, lapse: 0.007sec.
# 21-th iteration finished, shat_eps: 129.280491, lapse: 0.005sec.
# 22-th iteration finished, shat_eps: 129.280485, lapse: 0.005sec.
# 23-th iteration finished, shat_eps: 129.280479, lapse: 0.007sec.
# 24-th iteration finished, shat_eps: 129.280474, lapse: 0.006sec.
# 25-th iteration finished, shat_eps: 129.280468, lapse: 0.005sec.
# 26-th iteration finished, shat_eps: 129.280463, lapse: 0.006sec.
# 27-th iteration finished, shat_eps: 129.280457, lapse: 0.006sec.
# 28-th iteration finished, shat_eps: 129.280452, lapse: 0.010sec.
# 29-th iteration finished, shat_eps: 129.280446, lapse: 0.008sec.
# 30-th iteration finished, shat_eps: 129.280441, lapse: 0.007sec.
# 31-th iteration finished, shat_eps: 129.280435, lapse: 0.016sec.
# 32-th iteration finished, shat_eps: 129.280430, lapse: 0.008sec.
# 33-th iteration finished, shat_eps: 129.280424, lapse: 0.014sec.
# 34-th iteration finished, shat_eps: 129.280419, lapse: 0.012sec.
# 35-th iteration finished, shat_eps: 129.280414, lapse: 0.015sec.
# 36-th iteration finished, shat_eps: 129.280408, lapse: 0.014sec.
# 37-th iteration finished, shat_eps: 129.280403, lapse: 0.015sec.
# 38-th iteration finished, shat_eps: 129.280397, lapse: 0.007sec.
# 39-th iteration finished, shat_eps: 129.280392, lapse: 0.005sec.
# 40-th iteration finished, shat_eps: 129.280387, lapse: 0.012sec.
# 41-th iteration finished, shat_eps: 129.280381, lapse: 0.007sec.
# 42-th iteration finished, shat_eps: 129.280376, lapse: 0.006sec.
# 43-th iteration finished, shat_eps: 129.280370, lapse: 0.008sec.
# 44-th iteration finished, shat_eps: 129.280365, lapse: 0.008sec.
# 45-th iteration finished, shat_eps: 129.280360, lapse: 0.006sec.
# 46-th iteration finished, shat_eps: 129.280354, lapse: 0.005sec.
# 47-th iteration finished, shat_eps: 129.280349, lapse: 0.005sec.
# 48-th iteration finished, shat_eps: 129.280344, lapse: 0.006sec.
# 49-th iteration finished, shat_eps: 129.280338, lapse: 0.005sec.
# 50-th iteration finished, shat_eps: 129.280333, lapse: 0.006sec.
# 51-th iteration finished, shat_eps: 129.280328, lapse: 0.007sec.
# 52-th iteration finished, shat_eps: 129.280322, lapse: 0.007sec.
# 53-th iteration finished, shat_eps: 129.280317, lapse: 0.007sec.
# 54-th iteration finished, shat_eps: 129.280312, lapse: 0.006sec.
# 55-th iteration finished, shat_eps: 129.280307, lapse: 0.017sec.
# 56-th iteration finished, shat_eps: 129.280301, lapse: 0.005sec.
# 57-th iteration finished, shat_eps: 129.280296, lapse: 0.009sec.
# 58-th iteration finished, shat_eps: 129.280291, lapse: 0.007sec.
# 59-th iteration finished, shat_eps: 129.280286, lapse: 0.006sec.
# 60-th iteration finished, shat_eps: 129.280280, lapse: 0.012sec.
# 61-th iteration finished, shat_eps: 129.280275, lapse: 0.006sec.
# 62-th iteration finished, shat_eps: 129.280270, lapse: 0.008sec.
# 63-th iteration finished, shat_eps: 129.280265, lapse: 0.007sec.
# 64-th iteration finished, shat_eps: 129.280260, lapse: 0.010sec.
# 65-th iteration finished, shat_eps: 129.280254, lapse: 0.005sec.
# 66-th iteration finished, shat_eps: 129.280249, lapse: 0.010sec.
# 67-th iteration finished, shat_eps: 129.280244, lapse: 0.005sec.
# 68-th iteration finished, shat_eps: 129.280239, lapse: 0.007sec.
# 69-th iteration finished, shat_eps: 129.280234, lapse: 0.005sec.
# 70-th iteration finished, shat_eps: 129.280229, lapse: 0.008sec.
# 71-th iteration finished, shat_eps: 129.280224, lapse: 0.009sec.
# 72-th iteration finished, shat_eps: 129.280218, lapse: 0.005sec.
# 73-th iteration finished, shat_eps: 129.280213, lapse: 0.007sec.
# 74-th iteration finished, shat_eps: 129.280208, lapse: 0.006sec.
# 75-th iteration finished, shat_eps: 129.280203, lapse: 0.005sec.
# 76-th iteration finished, shat_eps: 129.280198, lapse: 0.006sec.
# 77-th iteration finished, shat_eps: 129.280193, lapse: 0.010sec.
# 78-th iteration finished, shat_eps: 129.280188, lapse: 0.006sec.
# 79-th iteration finished, shat_eps: 129.280183, lapse: 0.005sec.
# 80-th iteration finished, shat_eps: 129.280178, lapse: 0.007sec.
# 81-th iteration finished, shat_eps: 129.280173, lapse: 0.010sec.
# 82-th iteration finished, shat_eps: 129.280168, lapse: 0.008sec.
# 83-th iteration finished, shat_eps: 129.280163, lapse: 0.017sec.
# 84-th iteration finished, shat_eps: 129.280158, lapse: 0.007sec.
# 85-th iteration finished, shat_eps: 129.280153, lapse: 0.006sec.
# 86-th iteration finished, shat_eps: 129.280148, lapse: 0.015sec.
# 87-th iteration finished, shat_eps: 129.280143, lapse: 0.005sec.
# 88-th iteration finished, shat_eps: 129.280138, lapse: 0.006sec.
# 89-th iteration finished, shat_eps: 129.280133, lapse: 0.007sec.
# 90-th iteration finished, shat_eps: 129.280128, lapse: 0.005sec.
# 91-th iteration finished, shat_eps: 129.280123, lapse: 0.009sec.
# 92-th iteration finished, shat_eps: 129.280118, lapse: 0.006sec.
# 93-th iteration finished, shat_eps: 129.280113, lapse: 0.008sec.
# 94-th iteration finished, shat_eps: 129.280108, lapse: 0.006sec.
# 95-th iteration finished, shat_eps: 129.280103, lapse: 0.005sec.
# 96-th iteration finished, shat_eps: 129.280098, lapse: 0.010sec.
# 97-th iteration finished, shat_eps: 129.280093, lapse: 0.005sec.
# 98-th iteration finished, shat_eps: 129.280088, lapse: 0.007sec.
# 99-th iteration finished, shat_eps: 129.280083, lapse: 0.006sec.
# 100-th iteration finished, shat_eps: 129.280078, lapse: 0.005sec.
# 101-th iteration finished, shat_eps: 129.280074, lapse: 0.006sec.
# 102-th iteration finished, shat_eps: 129.280069, lapse: 0.006sec.
# 103-th iteration finished, shat_eps: 129.280064, lapse: 0.005sec.
# 104-th iteration finished, shat_eps: 129.280059, lapse: 0.005sec.
# 105-th iteration finished, shat_eps: 129.280054, lapse: 0.007sec.
# 106-th iteration finished, shat_eps: 129.280049, lapse: 0.006sec.
# 107-th iteration finished, shat_eps: 129.280044, lapse: 0.007sec.
# 108-th iteration finished, shat_eps: 129.280040, lapse: 0.009sec.
# 109-th iteration finished, shat_eps: 129.280035, lapse: 0.015sec.
# 110-th iteration finished, shat_eps: 129.280030, lapse: 0.016sec.
# 111-th iteration finished, shat_eps: 129.280025, lapse: 0.034sec.
# 112-th iteration finished, shat_eps: 129.280020, lapse: 0.024sec.
# 113-th iteration finished, shat_eps: 129.280016, lapse: 0.015sec.
# 114-th iteration finished, shat_eps: 129.280011, lapse: 0.014sec.
# 115-th iteration finished, shat_eps: 129.280006, lapse: 0.013sec.
# 116-th iteration finished, shat_eps: 129.280001, lapse: 0.008sec.
# 117-th iteration finished, shat_eps: 129.279996, lapse: 0.016sec.
# 118-th iteration finished, shat_eps: 129.279992, lapse: 0.014sec.
# 119-th iteration finished, shat_eps: 129.279987, lapse: 0.012sec.
# 120-th iteration finished, shat_eps: 129.279982, lapse: 0.015sec.
# 121-th iteration finished, shat_eps: 129.279978, lapse: 0.033sec.
# 122-th iteration finished, shat_eps: 129.279973, lapse: 0.023sec.
# 123-th iteration finished, shat_eps: 129.279968, lapse: 0.018sec.
# 124-th iteration finished, shat_eps: 129.279963, lapse: 0.008sec.
# 125-th iteration finished, shat_eps: 129.279959, lapse: 0.014sec.
# 126-th iteration finished, shat_eps: 129.279954, lapse: 0.011sec.
# 127-th iteration finished, shat_eps: 129.279949, lapse: 0.009sec.
# 128-th iteration finished, shat_eps: 129.279945, lapse: 0.005sec.
# 129-th iteration finished, shat_eps: 129.279940, lapse: 0.011sec.
# 130-th iteration finished, shat_eps: 129.279935, lapse: 0.005sec.
# 131-th iteration finished, shat_eps: 129.279931, lapse: 0.008sec.
# 132-th iteration finished, shat_eps: 129.279926, lapse: 0.007sec.
# 133-th iteration finished, shat_eps: 129.279921, lapse: 0.009sec.
# 134-th iteration finished, shat_eps: 129.279917, lapse: 0.017sec.
# 135-th iteration finished, shat_eps: 129.279912, lapse: 0.008sec.
# 136-th iteration finished, shat_eps: 129.279908, lapse: 0.028sec.
# 137-th iteration finished, shat_eps: 129.279903, lapse: 0.010sec.
# 138-th iteration finished, shat_eps: 129.279898, lapse: 0.017sec.
# 139-th iteration finished, shat_eps: 129.279894, lapse: 0.013sec.
# 140-th iteration finished, shat_eps: 129.279889, lapse: 0.014sec.
# 141-th iteration finished, shat_eps: 129.279885, lapse: 0.022sec.
# 142-th iteration finished, shat_eps: 129.279880, lapse: 0.010sec.
# 143-th iteration finished, shat_eps: 129.279875, lapse: 0.008sec.
# 144-th iteration finished, shat_eps: 129.279871, lapse: 0.017sec.
# 145-th iteration finished, shat_eps: 129.279866, lapse: 0.009sec.
# 146-th iteration finished, shat_eps: 129.279862, lapse: 0.005sec.
# 147-th iteration finished, shat_eps: 129.279857, lapse: 0.009sec.
# 148-th iteration finished, shat_eps: 129.279853, lapse: 0.006sec.
# 149-th iteration finished, shat_eps: 129.279848, lapse: 0.006sec.
# 150-th iteration finished, shat_eps: 129.279844, lapse: 0.007sec.
# 151-th iteration finished, shat_eps: 129.279839, lapse: 0.005sec.
# 152-th iteration finished, shat_eps: 129.279835, lapse: 0.004sec.
# 153-th iteration finished, shat_eps: 129.279830, lapse: 0.010sec.
# 154-th iteration finished, shat_eps: 129.279826, lapse: 0.007sec.
# 155-th iteration finished, shat_eps: 129.279821, lapse: 0.008sec.
# 156-th iteration finished, shat_eps: 129.279817, lapse: 0.009sec.
# 157-th iteration finished, shat_eps: 129.279812, lapse: 0.010sec.
# 158-th iteration finished, shat_eps: 129.279808, lapse: 0.011sec.
# 159-th iteration finished, shat_eps: 129.279803, lapse: 0.006sec.
# 160-th iteration finished, shat_eps: 129.279799, lapse: 0.007sec.
# 161-th iteration finished, shat_eps: 129.279795, lapse: 0.007sec.
# 162-th iteration finished, shat_eps: 129.279790, lapse: 0.007sec.
# 163-th iteration finished, shat_eps: 129.279786, lapse: 0.006sec.
# 164-th iteration finished, shat_eps: 129.279781, lapse: 0.005sec.
# 165-th iteration finished, shat_eps: 129.279777, lapse: 0.008sec.
# 166-th iteration finished, shat_eps: 129.279773, lapse: 0.018sec.
# 167-th iteration finished, shat_eps: 129.279768, lapse: 0.010sec.
# 168-th iteration finished, shat_eps: 129.279764, lapse: 0.009sec.
# 169-th iteration finished, shat_eps: 129.279759, lapse: 0.008sec.
# 170-th iteration finished, shat_eps: 129.279755, lapse: 0.016sec.
# 171-th iteration finished, shat_eps: 129.279751, lapse: 0.008sec.
# 172-th iteration finished, shat_eps: 129.279746, lapse: 0.011sec.
# 173-th iteration finished, shat_eps: 129.279742, lapse: 0.011sec.
# 174-th iteration finished, shat_eps: 129.279738, lapse: 0.008sec.
# 175-th iteration finished, shat_eps: 129.279733, lapse: 0.010sec.
# 176-th iteration finished, shat_eps: 129.279729, lapse: 0.013sec.
# 177-th iteration finished, shat_eps: 129.279725, lapse: 0.008sec.
# 178-th iteration finished, shat_eps: 129.279720, lapse: 0.010sec.
# 179-th iteration finished, shat_eps: 129.279716, lapse: 0.014sec.
# 180-th iteration finished, shat_eps: 129.279712, lapse: 0.013sec.
# 181-th iteration finished, shat_eps: 129.279708, lapse: 0.014sec.
# 182-th iteration finished, shat_eps: 129.279703, lapse: 0.009sec.
# 183-th iteration finished, shat_eps: 129.279699, lapse: 0.008sec.
# 184-th iteration finished, shat_eps: 129.279695, lapse: 0.008sec.
# 185-th iteration finished, shat_eps: 129.279690, lapse: 0.021sec.
# 186-th iteration finished, shat_eps: 129.279686, lapse: 0.008sec.
# 187-th iteration finished, shat_eps: 129.279682, lapse: 0.008sec.
# 188-th iteration finished, shat_eps: 129.279678, lapse: 0.012sec.
# 189-th iteration finished, shat_eps: 129.279674, lapse: 0.007sec.
# 190-th iteration finished, shat_eps: 129.279669, lapse: 0.012sec.
# 191-th iteration finished, shat_eps: 129.279665, lapse: 0.012sec.
# 192-th iteration finished, shat_eps: 129.279661, lapse: 0.011sec.
# 193-th iteration finished, shat_eps: 129.279657, lapse: 0.011sec.
# 194-th iteration finished, shat_eps: 129.279652, lapse: 0.008sec.
# 195-th iteration finished, shat_eps: 129.279648, lapse: 0.014sec.
# 196-th iteration finished, shat_eps: 129.279644, lapse: 0.009sec.
# 197-th iteration finished, shat_eps: 129.279640, lapse: 0.013sec.
# 198-th iteration finished, shat_eps: 129.279636, lapse: 0.008sec.
# 199-th iteration finished, shat_eps: 129.279632, lapse: 0.010sec.
# 200-th iteration finished, shat_eps: 129.279627, lapse: 0.012sec.
# 201-th iteration finished, shat_eps: 129.279623, lapse: 0.009sec.
# 202-th iteration finished, shat_eps: 129.279619, lapse: 0.014sec.
# 203-th iteration finished, shat_eps: 129.279615, lapse: 0.008sec.
# 204-th iteration finished, shat_eps: 129.279611, lapse: 0.009sec.
# 205-th iteration finished, shat_eps: 129.279607, lapse: 0.014sec.
# 206-th iteration finished, shat_eps: 129.279603, lapse: 0.017sec.
# 207-th iteration finished, shat_eps: 129.279599, lapse: 0.029sec.
# 208-th iteration finished, shat_eps: 129.279594, lapse: 0.013sec.
# 209-th iteration finished, shat_eps: 129.279590, lapse: 0.012sec.
# 210-th iteration finished, shat_eps: 129.279586, lapse: 0.010sec.
# 211-th iteration finished, shat_eps: 129.279582, lapse: 0.010sec.
# 212-th iteration finished, shat_eps: 129.279578, lapse: 0.028sec.
# 213-th iteration finished, shat_eps: 129.279574, lapse: 0.008sec.
# 214-th iteration finished, shat_eps: 129.279570, lapse: 0.035sec.
# 215-th iteration finished, shat_eps: 129.279566, lapse: 0.023sec.
# 216-th iteration finished, shat_eps: 129.279562, lapse: 0.008sec.
# 217-th iteration finished, shat_eps: 129.279558, lapse: 0.008sec.
# 218-th iteration finished, shat_eps: 129.279554, lapse: 0.021sec.
# 219-th iteration finished, shat_eps: 129.279550, lapse: 0.018sec.
# 220-th iteration finished, shat_eps: 129.279546, lapse: 0.023sec.
# 221-th iteration finished, shat_eps: 129.279542, lapse: 0.027sec.
# 222-th iteration finished, shat_eps: 129.279538, lapse: 0.015sec.
# 223-th iteration finished, shat_eps: 129.279534, lapse: 0.021sec.
# 224-th iteration finished, shat_eps: 129.279530, lapse: 0.010sec.
# 225-th iteration finished, shat_eps: 129.279526, lapse: 0.017sec.
# 226-th iteration finished, shat_eps: 129.279522, lapse: 0.006sec.
# 227-th iteration finished, shat_eps: 129.279518, lapse: 0.008sec.
# 228-th iteration finished, shat_eps: 129.279514, lapse: 0.006sec.
# 229-th iteration finished, shat_eps: 129.279510, lapse: 0.005sec.
# 230-th iteration finished, shat_eps: 129.279506, lapse: 0.009sec.
# 231-th iteration finished, shat_eps: 129.279502, lapse: 0.008sec.
# 232-th iteration finished, shat_eps: 129.279498, lapse: 0.005sec.
# 233-th iteration finished, shat_eps: 129.279494, lapse: 0.013sec.
# 234-th iteration finished, shat_eps: 129.279490, lapse: 0.012sec.
# 235-th iteration finished, shat_eps: 129.279486, lapse: 0.026sec.
# 236-th iteration finished, shat_eps: 129.279482, lapse: 0.017sec.
# 237-th iteration finished, shat_eps: 129.279478, lapse: 0.009sec.
# 238-th iteration finished, shat_eps: 129.279474, lapse: 0.014sec.
# 239-th iteration finished, shat_eps: 129.279471, lapse: 0.027sec.
# 240-th iteration finished, shat_eps: 129.279467, lapse: 0.011sec.
# 241-th iteration finished, shat_eps: 129.279463, lapse: 0.013sec.
# 242-th iteration finished, shat_eps: 129.279459, lapse: 0.016sec.
# 243-th iteration finished, shat_eps: 129.279455, lapse: 0.011sec.
# 244-th iteration finished, shat_eps: 129.279451, lapse: 0.009sec.
# 245-th iteration finished, shat_eps: 129.279447, lapse: 0.009sec.
# 246-th iteration finished, shat_eps: 129.279443, lapse: 0.011sec.
# 247-th iteration finished, shat_eps: 129.279440, lapse: 0.016sec.
# 248-th iteration finished, shat_eps: 129.279436, lapse: 0.011sec.
# 249-th iteration finished, shat_eps: 129.279432, lapse: 0.011sec.
# 250-th iteration finished, shat_eps: 129.279428, lapse: 0.007sec.
# 251-th iteration finished, shat_eps: 129.279424, lapse: 0.010sec.
# 252-th iteration finished, shat_eps: 129.279420, lapse: 0.006sec.
# 253-th iteration finished, shat_eps: 129.279417, lapse: 0.011sec.
# 254-th iteration finished, shat_eps: 129.279413, lapse: 0.007sec.
# 255-th iteration finished, shat_eps: 129.279409, lapse: 0.009sec.
# 256-th iteration finished, shat_eps: 129.279405, lapse: 0.008sec.
# 257-th iteration finished, shat_eps: 129.279401, lapse: 0.014sec.
# 258-th iteration finished, shat_eps: 129.279398, lapse: 0.008sec.
# 259-th iteration finished, shat_eps: 129.279394, lapse: 0.014sec.
# 260-th iteration finished, shat_eps: 129.279390, lapse: 0.010sec.
# 261-th iteration finished, shat_eps: 129.279386, lapse: 0.013sec.
# 262-th iteration finished, shat_eps: 129.279383, lapse: 0.007sec.
# 263-th iteration finished, shat_eps: 129.279379, lapse: 0.010sec.
# 264-th iteration finished, shat_eps: 129.279375, lapse: 0.011sec.
# 265-th iteration finished, shat_eps: 129.279371, lapse: 0.014sec.
# 266-th iteration finished, shat_eps: 129.279368, lapse: 0.014sec.
# 267-th iteration finished, shat_eps: 129.279364, lapse: 0.009sec.
# 268-th iteration finished, shat_eps: 129.279360, lapse: 0.011sec.
# 269-th iteration finished, shat_eps: 129.279356, lapse: 0.014sec.
# 270-th iteration finished, shat_eps: 129.279353, lapse: 0.006sec.
# 271-th iteration finished, shat_eps: 129.279349, lapse: 0.014sec.
# 272-th iteration finished, shat_eps: 129.279345, lapse: 0.013sec.
# 273-th iteration finished, shat_eps: 129.279342, lapse: 0.009sec.
# 274-th iteration finished, shat_eps: 129.279338, lapse: 0.010sec.
# 275-th iteration finished, shat_eps: 129.279334, lapse: 0.009sec.
# 276-th iteration finished, shat_eps: 129.279331, lapse: 0.007sec.
# 277-th iteration finished, shat_eps: 129.279327, lapse: 0.005sec.
# 278-th iteration finished, shat_eps: 129.279323, lapse: 0.005sec.
# 279-th iteration finished, shat_eps: 129.279320, lapse: 0.005sec.
# 280-th iteration finished, shat_eps: 129.279316, lapse: 0.014sec.
# 281-th iteration finished, shat_eps: 129.279312, lapse: 0.005sec.
# 282-th iteration finished, shat_eps: 129.279309, lapse: 0.005sec.
# 283-th iteration finished, shat_eps: 129.279305, lapse: 0.007sec.
# 284-th iteration finished, shat_eps: 129.279301, lapse: 0.007sec.
# 285-th iteration finished, shat_eps: 129.279298, lapse: 0.008sec.
# 286-th iteration finished, shat_eps: 129.279294, lapse: 0.011sec.
# 287-th iteration finished, shat_eps: 129.279291, lapse: 0.005sec.
# 288-th iteration finished, shat_eps: 129.279287, lapse: 0.012sec.
# 289-th iteration finished, shat_eps: 129.279283, lapse: 0.010sec.
# 290-th iteration finished, shat_eps: 129.279280, lapse: 0.008sec.
# 291-th iteration finished, shat_eps: 129.279276, lapse: 0.019sec.
# 292-th iteration finished, shat_eps: 129.279273, lapse: 0.025sec.
# 293-th iteration finished, shat_eps: 129.279269, lapse: 0.016sec.
# 294-th iteration finished, shat_eps: 129.279266, lapse: 0.011sec.
# 295-th iteration finished, shat_eps: 129.279262, lapse: 0.015sec.
# 296-th iteration finished, shat_eps: 129.279258, lapse: 0.008sec.
# 297-th iteration finished, shat_eps: 129.279255, lapse: 0.006sec.
# 298-th iteration finished, shat_eps: 129.279251, lapse: 0.013sec.
# 299-th iteration finished, shat_eps: 129.279248, lapse: 0.014sec.
# 300-th iteration finished, shat_eps: 129.279244, lapse: 0.013sec.
# 301-th iteration finished, shat_eps: 129.279241, lapse: 0.008sec.
# 302-th iteration finished, shat_eps: 129.279237, lapse: 0.006sec.
# 303-th iteration finished, shat_eps: 129.279234, lapse: 0.007sec.
# 304-th iteration finished, shat_eps: 129.279230, lapse: 0.006sec.
# 305-th iteration finished, shat_eps: 129.279227, lapse: 0.008sec.
# 306-th iteration finished, shat_eps: 129.279223, lapse: 0.005sec.
# 307-th iteration finished, shat_eps: 129.279220, lapse: 0.006sec.
# 308-th iteration finished, shat_eps: 129.279216, lapse: 0.009sec.
# 309-th iteration finished, shat_eps: 129.279213, lapse: 0.005sec.
# 310-th iteration finished, shat_eps: 129.279209, lapse: 0.005sec.
# 311-th iteration finished, shat_eps: 129.279206, lapse: 0.009sec.
# 312-th iteration finished, shat_eps: 129.279202, lapse: 0.005sec.
# 313-th iteration finished, shat_eps: 129.279199, lapse: 0.007sec.
# 314-th iteration finished, shat_eps: 129.279195, lapse: 0.009sec.
# 315-th iteration finished, shat_eps: 129.279192, lapse: 0.005sec.
# 316-th iteration finished, shat_eps: 129.279188, lapse: 0.006sec.
# 317-th iteration finished, shat_eps: 129.279185, lapse: 0.007sec.
# 318-th iteration finished, shat_eps: 129.279182, lapse: 0.008sec.
# 319-th iteration finished, shat_eps: 129.279178, lapse: 0.023sec.
# 320-th iteration finished, shat_eps: 129.279175, lapse: 0.014sec.
# 321-th iteration finished, shat_eps: 129.279171, lapse: 0.006sec.
# 322-th iteration finished, shat_eps: 129.279168, lapse: 0.016sec.
# 323-th iteration finished, shat_eps: 129.279165, lapse: 0.010sec.
# 324-th iteration finished, shat_eps: 129.279161, lapse: 0.014sec.
# 325-th iteration finished, shat_eps: 129.279158, lapse: 0.009sec.
# 326-th iteration finished, shat_eps: 129.279154, lapse: 0.011sec.
# 327-th iteration finished, shat_eps: 129.279151, lapse: 0.007sec.
# 328-th iteration finished, shat_eps: 129.279148, lapse: 0.014sec.
# 329-th iteration finished, shat_eps: 129.279144, lapse: 0.007sec.
# 330-th iteration finished, shat_eps: 129.279141, lapse: 0.007sec.
# 331-th iteration finished, shat_eps: 129.279138, lapse: 0.008sec.
# 332-th iteration finished, shat_eps: 129.279134, lapse: 0.012sec.
# 333-th iteration finished, shat_eps: 129.279131, lapse: 0.013sec.
# 334-th iteration finished, shat_eps: 129.279127, lapse: 0.005sec.
# 335-th iteration finished, shat_eps: 129.279124, lapse: 0.012sec.
# 336-th iteration finished, shat_eps: 129.279121, lapse: 0.007sec.
# 337-th iteration finished, shat_eps: 129.279117, lapse: 0.006sec.
# 338-th iteration finished, shat_eps: 129.279114, lapse: 0.006sec.
# 339-th iteration finished, shat_eps: 129.279111, lapse: 0.014sec.
# 340-th iteration finished, shat_eps: 129.279108, lapse: 0.008sec.
# 341-th iteration finished, shat_eps: 129.279104, lapse: 0.046sec.
# 342-th iteration finished, shat_eps: 129.279101, lapse: 0.009sec.
# 343-th iteration finished, shat_eps: 129.279098, lapse: 0.012sec.
# 344-th iteration finished, shat_eps: 129.279094, lapse: 0.007sec.
# 345-th iteration finished, shat_eps: 129.279091, lapse: 0.006sec.
# 346-th iteration finished, shat_eps: 129.279088, lapse: 0.007sec.
# 347-th iteration finished, shat_eps: 129.279085, lapse: 0.006sec.
# 348-th iteration finished, shat_eps: 129.279081, lapse: 0.008sec.
# 349-th iteration finished, shat_eps: 129.279078, lapse: 0.009sec.
# 350-th iteration finished, shat_eps: 129.279075, lapse: 0.006sec.
# 351-th iteration finished, shat_eps: 129.279071, lapse: 0.005sec.
# 352-th iteration finished, shat_eps: 129.279068, lapse: 0.005sec.
# 353-th iteration finished, shat_eps: 129.279065, lapse: 0.008sec.
# 354-th iteration finished, shat_eps: 129.279062, lapse: 0.005sec.
# 355-th iteration finished, shat_eps: 129.279059, lapse: 0.012sec.
# 356-th iteration finished, shat_eps: 129.279055, lapse: 0.011sec.
# 357-th iteration finished, shat_eps: 129.279052, lapse: 0.016sec.
# 358-th iteration finished, shat_eps: 129.279049, lapse: 0.025sec.
# 359-th iteration finished, shat_eps: 129.279046, lapse: 0.032sec.
# 360-th iteration finished, shat_eps: 129.279042, lapse: 0.016sec.
# 361-th iteration finished, shat_eps: 129.279039, lapse: 0.012sec.
# 362-th iteration finished, shat_eps: 129.279036, lapse: 0.013sec.
# 363-th iteration finished, shat_eps: 129.279033, lapse: 0.015sec.
# 364-th iteration finished, shat_eps: 129.279030, lapse: 0.008sec.
# 365-th iteration finished, shat_eps: 129.279027, lapse: 0.010sec.
# 366-th iteration finished, shat_eps: 129.279023, lapse: 0.013sec.
# 367-th iteration finished, shat_eps: 129.279020, lapse: 0.005sec.
# 368-th iteration finished, shat_eps: 129.279017, lapse: 0.010sec.
# 369-th iteration finished, shat_eps: 129.279014, lapse: 0.011sec.
# 370-th iteration finished, shat_eps: 129.279011, lapse: 0.007sec.
# 371-th iteration finished, shat_eps: 129.279008, lapse: 0.006sec.
# 372-th iteration finished, shat_eps: 129.279004, lapse: 0.005sec.
# 373-th iteration finished, shat_eps: 129.279001, lapse: 0.005sec.
# 374-th iteration finished, shat_eps: 129.278998, lapse: 0.008sec.
# 375-th iteration finished, shat_eps: 129.278995, lapse: 0.005sec.
# 376-th iteration finished, shat_eps: 129.278992, lapse: 0.005sec.
# 377-th iteration finished, shat_eps: 129.278989, lapse: 0.011sec.
# 378-th iteration finished, shat_eps: 129.278986, lapse: 0.005sec.
# 379-th iteration finished, shat_eps: 129.278983, lapse: 0.008sec.
# 380-th iteration finished, shat_eps: 129.278979, lapse: 0.012sec.
# 381-th iteration finished, shat_eps: 129.278976, lapse: 0.007sec.
# 382-th iteration finished, shat_eps: 129.278973, lapse: 0.007sec.
# 383-th iteration finished, shat_eps: 129.278970, lapse: 0.005sec.
# 384-th iteration finished, shat_eps: 129.278967, lapse: 0.005sec.
# 385-th iteration finished, shat_eps: 129.278964, lapse: 0.015sec.
# 386-th iteration finished, shat_eps: 129.278961, lapse: 0.014sec.
# 387-th iteration finished, shat_eps: 129.278958, lapse: 0.015sec.
# 388-th iteration finished, shat_eps: 129.278955, lapse: 0.007sec.
# 389-th iteration finished, shat_eps: 129.278952, lapse: 0.010sec.
# 390-th iteration finished, shat_eps: 129.278949, lapse: 0.010sec.
# 391-th iteration finished, shat_eps: 129.278946, lapse: 0.013sec.
# 392-th iteration finished, shat_eps: 129.278943, lapse: 0.011sec.
# 393-th iteration finished, shat_eps: 129.278940, lapse: 0.008sec.
# 394-th iteration finished, shat_eps: 129.278937, lapse: 0.009sec.
# 395-th iteration finished, shat_eps: 129.278934, lapse: 0.009sec.
# 396-th iteration finished, shat_eps: 129.278930, lapse: 0.009sec.
# 397-th iteration finished, shat_eps: 129.278927, lapse: 0.010sec.
# 398-th iteration finished, shat_eps: 129.278924, lapse: 0.006sec.
# 399-th iteration finished, shat_eps: 129.278921, lapse: 0.012sec.
# 400-th iteration finished, shat_eps: 129.278918, lapse: 0.007sec.
# 401-th iteration finished, shat_eps: 129.278915, lapse: 0.010sec.
# 402-th iteration finished, shat_eps: 129.278912, lapse: 0.017sec.
# 403-th iteration finished, shat_eps: 129.278909, lapse: 0.018sec.
# 404-th iteration finished, shat_eps: 129.278906, lapse: 0.005sec.
# 405-th iteration finished, shat_eps: 129.278903, lapse: 0.012sec.
# 406-th iteration finished, shat_eps: 129.278901, lapse: 0.004sec.
# 407-th iteration finished, shat_eps: 129.278898, lapse: 0.010sec.
# 408-th iteration finished, shat_eps: 129.278895, lapse: 0.005sec.
# 409-th iteration finished, shat_eps: 129.278892, lapse: 0.005sec.
# 410-th iteration finished, shat_eps: 129.278889, lapse: 0.005sec.
# 411-th iteration finished, shat_eps: 129.278886, lapse: 0.005sec.
# 412-th iteration finished, shat_eps: 129.278883, lapse: 0.008sec.
# 413-th iteration finished, shat_eps: 129.278880, lapse: 0.007sec.
# 414-th iteration finished, shat_eps: 129.278877, lapse: 0.005sec.
# 415-th iteration finished, shat_eps: 129.278874, lapse: 0.013sec.
# 416-th iteration finished, shat_eps: 129.278871, lapse: 0.006sec.
# 417-th iteration finished, shat_eps: 129.278868, lapse: 0.005sec.
# 418-th iteration finished, shat_eps: 129.278865, lapse: 0.014sec.
# 419-th iteration finished, shat_eps: 129.278862, lapse: 0.008sec.
# 420-th iteration finished, shat_eps: 129.278859, lapse: 0.018sec.
# 421-th iteration finished, shat_eps: 129.278856, lapse: 0.012sec.
# 422-th iteration finished, shat_eps: 129.278854, lapse: 0.014sec.
# 423-th iteration finished, shat_eps: 129.278851, lapse: 0.015sec.
# 424-th iteration finished, shat_eps: 129.278848, lapse: 0.021sec.
# 425-th iteration finished, shat_eps: 129.278845, lapse: 0.016sec.
# 426-th iteration finished, shat_eps: 129.278842, lapse: 0.017sec.
# 427-th iteration finished, shat_eps: 129.278839, lapse: 0.011sec.
# 428-th iteration finished, shat_eps: 129.278836, lapse: 0.010sec.
# 429-th iteration finished, shat_eps: 129.278833, lapse: 0.010sec.
# 430-th iteration finished, shat_eps: 129.278831, lapse: 0.007sec.
# 431-th iteration finished, shat_eps: 129.278828, lapse: 0.007sec.
# 432-th iteration finished, shat_eps: 129.278825, lapse: 0.005sec.
# 433-th iteration finished, shat_eps: 129.278822, lapse: 0.005sec.
# 434-th iteration finished, shat_eps: 129.278819, lapse: 0.004sec.
# 435-th iteration finished, shat_eps: 129.278816, lapse: 0.006sec.
# 436-th iteration finished, shat_eps: 129.278813, lapse: 0.005sec.
# 437-th iteration finished, shat_eps: 129.278811, lapse: 0.008sec.
# 438-th iteration finished, shat_eps: 129.278808, lapse: 0.006sec.
# 439-th iteration finished, shat_eps: 129.278805, lapse: 0.005sec.
# 440-th iteration finished, shat_eps: 129.278802, lapse: 0.008sec.
# 441-th iteration finished, shat_eps: 129.278799, lapse: 0.011sec.
# 442-th iteration finished, shat_eps: 129.278797, lapse: 0.005sec.
# 443-th iteration finished, shat_eps: 129.278794, lapse: 0.010sec.
# 444-th iteration finished, shat_eps: 129.278791, lapse: 0.009sec.
# 445-th iteration finished, shat_eps: 129.278788, lapse: 0.007sec.
# 446-th iteration finished, shat_eps: 129.278785, lapse: 0.006sec.
# 447-th iteration finished, shat_eps: 129.278783, lapse: 0.013sec.
# 448-th iteration finished, shat_eps: 129.278780, lapse: 0.005sec.
# 449-th iteration finished, shat_eps: 129.278777, lapse: 0.023sec.
# 450-th iteration finished, shat_eps: 129.278774, lapse: 0.014sec.
# 451-th iteration finished, shat_eps: 129.278772, lapse: 0.016sec.
# 452-th iteration finished, shat_eps: 129.278769, lapse: 0.010sec.
# 453-th iteration finished, shat_eps: 129.278766, lapse: 0.005sec.
# 454-th iteration finished, shat_eps: 129.278763, lapse: 0.013sec.
# 455-th iteration finished, shat_eps: 129.278761, lapse: 0.014sec.
# 456-th iteration finished, shat_eps: 129.278758, lapse: 0.007sec.
# 457-th iteration finished, shat_eps: 129.278755, lapse: 0.011sec.
# 458-th iteration finished, shat_eps: 129.278752, lapse: 0.013sec.
# 459-th iteration finished, shat_eps: 129.278750, lapse: 0.008sec.
# 460-th iteration finished, shat_eps: 129.278747, lapse: 0.011sec.
# 461-th iteration finished, shat_eps: 129.278744, lapse: 0.008sec.
# 462-th iteration finished, shat_eps: 129.278741, lapse: 0.008sec.
# 463-th iteration finished, shat_eps: 129.278739, lapse: 0.005sec.
# 464-th iteration finished, shat_eps: 129.278736, lapse: 0.012sec.
# 465-th iteration finished, shat_eps: 129.278733, lapse: 0.008sec.
# 466-th iteration finished, shat_eps: 129.278731, lapse: 0.008sec.
# 467-th iteration finished, shat_eps: 129.278728, lapse: 0.009sec.
# 468-th iteration finished, shat_eps: 129.278725, lapse: 0.005sec.
# 469-th iteration finished, shat_eps: 129.278722, lapse: 0.005sec.
# 470-th iteration finished, shat_eps: 129.278720, lapse: 0.013sec.
# 471-th iteration finished, shat_eps: 129.278717, lapse: 0.015sec.
# 472-th iteration finished, shat_eps: 129.278714, lapse: 0.026sec.
# 473-th iteration finished, shat_eps: 129.278712, lapse: 0.014sec.
# 474-th iteration finished, shat_eps: 129.278709, lapse: 0.016sec.
# 475-th iteration finished, shat_eps: 129.278706, lapse: 0.005sec.
# 476-th iteration finished, shat_eps: 129.278704, lapse: 0.010sec.
# 477-th iteration finished, shat_eps: 129.278701, lapse: 0.015sec.
# 478-th iteration finished, shat_eps: 129.278699, lapse: 0.010sec.
# 479-th iteration finished, shat_eps: 129.278696, lapse: 0.014sec.
# 480-th iteration finished, shat_eps: 129.278693, lapse: 0.013sec.
# 481-th iteration finished, shat_eps: 129.278691, lapse: 0.006sec.
# 482-th iteration finished, shat_eps: 129.278688, lapse: 0.008sec.
# 483-th iteration finished, shat_eps: 129.278685, lapse: 0.013sec.
# 484-th iteration finished, shat_eps: 129.278683, lapse: 0.015sec.
# 485-th iteration finished, shat_eps: 129.278680, lapse: 0.010sec.
# 486-th iteration finished, shat_eps: 129.278677, lapse: 0.010sec.
# 487-th iteration finished, shat_eps: 129.278675, lapse: 0.005sec.
# 488-th iteration finished, shat_eps: 129.278672, lapse: 0.005sec.
# 489-th iteration finished, shat_eps: 129.278670, lapse: 0.006sec.
# 490-th iteration finished, shat_eps: 129.278667, lapse: 0.008sec.
# 491-th iteration finished, shat_eps: 129.278664, lapse: 0.017sec.
# 492-th iteration finished, shat_eps: 129.278662, lapse: 0.020sec.
# 493-th iteration finished, shat_eps: 129.278659, lapse: 0.011sec.
# 494-th iteration finished, shat_eps: 129.278657, lapse: 0.008sec.
# 495-th iteration finished, shat_eps: 129.278654, lapse: 0.005sec.
# 496-th iteration finished, shat_eps: 129.278652, lapse: 0.006sec.
# 497-th iteration finished, shat_eps: 129.278649, lapse: 0.013sec.
# 498-th iteration finished, shat_eps: 129.278646, lapse: 0.008sec.
# 499-th iteration finished, shat_eps: 129.278644, lapse: 0.010sec.
# 500-th iteration finished, shat_eps: 129.278641, lapse: 0.008sec.
# 501-th iteration finished, shat_eps: 129.278639, lapse: 0.005sec.
# 502-th iteration finished, shat_eps: 129.278636, lapse: 0.016sec.
# 503-th iteration finished, shat_eps: 129.278634, lapse: 0.005sec.
# 504-th iteration finished, shat_eps: 129.278631, lapse: 0.021sec.
# 505-th iteration finished, shat_eps: 129.278629, lapse: 0.016sec.
# 506-th iteration finished, shat_eps: 129.278626, lapse: 0.016sec.
# 507-th iteration finished, shat_eps: 129.278624, lapse: 0.009sec.
# 508-th iteration finished, shat_eps: 129.278621, lapse: 0.011sec.
# 509-th iteration finished, shat_eps: 129.278619, lapse: 0.023sec.
# 510-th iteration finished, shat_eps: 129.278616, lapse: 0.013sec.
# 511-th iteration finished, shat_eps: 129.278613, lapse: 0.011sec.
# 512-th iteration finished, shat_eps: 129.278611, lapse: 0.014sec.
# 513-th iteration finished, shat_eps: 129.278608, lapse: 0.005sec.
# 514-th iteration finished, shat_eps: 129.278606, lapse: 0.007sec.
# 515-th iteration finished, shat_eps: 129.278603, lapse: 0.006sec.
# 516-th iteration finished, shat_eps: 129.278601, lapse: 0.012sec.
# 517-th iteration finished, shat_eps: 129.278599, lapse: 0.008sec.
# 518-th iteration finished, shat_eps: 129.278596, lapse: 0.008sec.
# 519-th iteration finished, shat_eps: 129.278594, lapse: 0.009sec.
# 520-th iteration finished, shat_eps: 129.278591, lapse: 0.012sec.
# 521-th iteration finished, shat_eps: 129.278589, lapse: 0.012sec.
# 522-th iteration finished, shat_eps: 129.278586, lapse: 0.010sec.
# 523-th iteration finished, shat_eps: 129.278584, lapse: 0.012sec.
# 524-th iteration finished, shat_eps: 129.278581, lapse: 0.008sec.
# 525-th iteration finished, shat_eps: 129.278579, lapse: 0.017sec.
# 526-th iteration finished, shat_eps: 129.278576, lapse: 0.008sec.
# 527-th iteration finished, shat_eps: 129.278574, lapse: 0.017sec.
# 528-th iteration finished, shat_eps: 129.278571, lapse: 0.010sec.
# 529-th iteration finished, shat_eps: 129.278569, lapse: 0.012sec.
# 530-th iteration finished, shat_eps: 129.278567, lapse: 0.018sec.
# 531-th iteration finished, shat_eps: 129.278564, lapse: 0.009sec.
# 532-th iteration finished, shat_eps: 129.278562, lapse: 0.013sec.
# 533-th iteration finished, shat_eps: 129.278559, lapse: 0.008sec.
# 534-th iteration finished, shat_eps: 129.278557, lapse: 0.007sec.
# 535-th iteration finished, shat_eps: 129.278554, lapse: 0.006sec.
# 536-th iteration finished, shat_eps: 129.278552, lapse: 0.007sec.
# 537-th iteration finished, shat_eps: 129.278550, lapse: 0.006sec.
# 538-th iteration finished, shat_eps: 129.278547, lapse: 0.007sec.
# 539-th iteration finished, shat_eps: 129.278545, lapse: 0.007sec.
# 540-th iteration finished, shat_eps: 129.278542, lapse: 0.006sec.
# 541-th iteration finished, shat_eps: 129.278540, lapse: 0.006sec.
# 542-th iteration finished, shat_eps: 129.278538, lapse: 0.006sec.
# 543-th iteration finished, shat_eps: 129.278535, lapse: 0.006sec.
# 544-th iteration finished, shat_eps: 129.278533, lapse: 0.008sec.
# 545-th iteration finished, shat_eps: 129.278530, lapse: 0.007sec.
# 546-th iteration finished, shat_eps: 129.278528, lapse: 0.008sec.
# 547-th iteration finished, shat_eps: 129.278526, lapse: 0.005sec.
# 548-th iteration finished, shat_eps: 129.278523, lapse: 0.005sec.
# 549-th iteration finished, shat_eps: 129.278521, lapse: 0.012sec.
# 550-th iteration finished, shat_eps: 129.278519, lapse: 0.008sec.
# 551-th iteration finished, shat_eps: 129.278516, lapse: 0.018sec.
# 552-th iteration finished, shat_eps: 129.278514, lapse: 0.009sec.
# 553-th iteration finished, shat_eps: 129.278512, lapse: 0.013sec.
# 554-th iteration finished, shat_eps: 129.278509, lapse: 0.025sec.
# 555-th iteration finished, shat_eps: 129.278507, lapse: 0.021sec.
# 556-th iteration finished, shat_eps: 129.278505, lapse: 0.009sec.
# 557-th iteration finished, shat_eps: 129.278502, lapse: 0.010sec.
# 558-th iteration finished, shat_eps: 129.278500, lapse: 0.010sec.
# 559-th iteration finished, shat_eps: 129.278498, lapse: 0.014sec.
# 560-th iteration finished, shat_eps: 129.278495, lapse: 0.010sec.
# 561-th iteration finished, shat_eps: 129.278493, lapse: 0.012sec.
# 562-th iteration finished, shat_eps: 129.278491, lapse: 0.019sec.
# 563-th iteration finished, shat_eps: 129.278488, lapse: 0.009sec.
# 564-th iteration finished, shat_eps: 129.278486, lapse: 0.009sec.
# 565-th iteration finished, shat_eps: 129.278484, lapse: 0.008sec.
# 566-th iteration finished, shat_eps: 129.278481, lapse: 0.007sec.
# 567-th iteration finished, shat_eps: 129.278479, lapse: 0.012sec.
# 568-th iteration finished, shat_eps: 129.278477, lapse: 0.007sec.
# 569-th iteration finished, shat_eps: 129.278475, lapse: 0.008sec.
# 570-th iteration finished, shat_eps: 129.278472, lapse: 0.008sec.
# 571-th iteration finished, shat_eps: 129.278470, lapse: 0.005sec.
# 572-th iteration finished, shat_eps: 129.278468, lapse: 0.022sec.
# 573-th iteration finished, shat_eps: 129.278465, lapse: 0.022sec.
# 574-th iteration finished, shat_eps: 129.278463, lapse: 0.013sec.
# 575-th iteration finished, shat_eps: 129.278461, lapse: 0.011sec.
# 576-th iteration finished, shat_eps: 129.278459, lapse: 0.012sec.
# 577-th iteration finished, shat_eps: 129.278456, lapse: 0.022sec.
# 578-th iteration finished, shat_eps: 129.278454, lapse: 0.015sec.
# 579-th iteration finished, shat_eps: 129.278452, lapse: 0.005sec.
# 580-th iteration finished, shat_eps: 129.278450, lapse: 0.014sec.
# 581-th iteration finished, shat_eps: 129.278447, lapse: 0.004sec.
# 582-th iteration finished, shat_eps: 129.278445, lapse: 0.014sec.
# 583-th iteration finished, shat_eps: 129.278443, lapse: 0.015sec.
# 584-th iteration finished, shat_eps: 129.278441, lapse: 0.013sec.
# 585-th iteration finished, shat_eps: 129.278438, lapse: 0.005sec.
# 586-th iteration finished, shat_eps: 129.278436, lapse: 0.010sec.
# 587-th iteration finished, shat_eps: 129.278434, lapse: 0.014sec.
# 588-th iteration finished, shat_eps: 129.278432, lapse: 0.007sec.
# 589-th iteration finished, shat_eps: 129.278430, lapse: 0.005sec.
# 590-th iteration finished, shat_eps: 129.278427, lapse: 0.010sec.
# 591-th iteration finished, shat_eps: 129.278425, lapse: 0.015sec.
# 592-th iteration finished, shat_eps: 129.278423, lapse: 0.007sec.
# 593-th iteration finished, shat_eps: 129.278421, lapse: 0.008sec.
# 594-th iteration finished, shat_eps: 129.278419, lapse: 0.006sec.
# 595-th iteration finished, shat_eps: 129.278416, lapse: 0.009sec.
# 596-th iteration finished, shat_eps: 129.278414, lapse: 0.007sec.
# 597-th iteration finished, shat_eps: 129.278412, lapse: 0.005sec.
# 598-th iteration finished, shat_eps: 129.278410, lapse: 0.015sec.
# 599-th iteration finished, shat_eps: 129.278408, lapse: 0.009sec.
# 600-th iteration finished, shat_eps: 129.278405, lapse: 0.012sec.
# 601-th iteration finished, shat_eps: 129.278403, lapse: 0.007sec.
# 602-th iteration finished, shat_eps: 129.278401, lapse: 0.008sec.
# 603-th iteration finished, shat_eps: 129.278399, lapse: 0.009sec.
# 604-th iteration finished, shat_eps: 129.278397, lapse: 0.017sec.
# 605-th iteration finished, shat_eps: 129.278395, lapse: 0.009sec.
# 606-th iteration finished, shat_eps: 129.278393, lapse: 0.008sec.
# 607-th iteration finished, shat_eps: 129.278390, lapse: 0.009sec.
# 608-th iteration finished, shat_eps: 129.278388, lapse: 0.010sec.
# 609-th iteration finished, shat_eps: 129.278386, lapse: 0.011sec.
# 610-th iteration finished, shat_eps: 129.278384, lapse: 0.013sec.
# 611-th iteration finished, shat_eps: 129.278382, lapse: 0.007sec.
# 612-th iteration finished, shat_eps: 129.278380, lapse: 0.012sec.
# 613-th iteration finished, shat_eps: 129.278378, lapse: 0.010sec.
# 614-th iteration finished, shat_eps: 129.278375, lapse: 0.008sec.
# 615-th iteration finished, shat_eps: 129.278373, lapse: 0.012sec.
# 616-th iteration finished, shat_eps: 129.278371, lapse: 0.006sec.
# 617-th iteration finished, shat_eps: 129.278369, lapse: 0.006sec.
# 618-th iteration finished, shat_eps: 129.278367, lapse: 0.007sec.
# 619-th iteration finished, shat_eps: 129.278365, lapse: 0.005sec.
# 620-th iteration finished, shat_eps: 129.278363, lapse: 0.005sec.
# 621-th iteration finished, shat_eps: 129.278361, lapse: 0.008sec.
# 622-th iteration finished, shat_eps: 129.278359, lapse: 0.007sec.
# 623-th iteration finished, shat_eps: 129.278356, lapse: 0.010sec.
# 624-th iteration finished, shat_eps: 129.278354, lapse: 0.005sec.
# 625-th iteration finished, shat_eps: 129.278352, lapse: 0.007sec.
# 626-th iteration finished, shat_eps: 129.278350, lapse: 0.008sec.
# 627-th iteration finished, shat_eps: 129.278348, lapse: 0.007sec.
# 628-th iteration finished, shat_eps: 129.278346, lapse: 0.007sec.
# 629-th iteration finished, shat_eps: 129.278344, lapse: 0.005sec.
# 630-th iteration finished, shat_eps: 129.278342, lapse: 0.009sec.
# 631-th iteration finished, shat_eps: 129.278340, lapse: 0.006sec.
# 632-th iteration finished, shat_eps: 129.278338, lapse: 0.007sec.
# 633-th iteration finished, shat_eps: 129.278336, lapse: 0.014sec.
# 634-th iteration finished, shat_eps: 129.278334, lapse: 0.011sec.
# 635-th iteration finished, shat_eps: 129.278332, lapse: 0.005sec.
# 636-th iteration finished, shat_eps: 129.278329, lapse: 0.011sec.
# 637-th iteration finished, shat_eps: 129.278327, lapse: 0.013sec.
# 638-th iteration finished, shat_eps: 129.278325, lapse: 0.014sec.
# 639-th iteration finished, shat_eps: 129.278323, lapse: 0.023sec.
# 640-th iteration finished, shat_eps: 129.278321, lapse: 0.009sec.
# 641-th iteration finished, shat_eps: 129.278319, lapse: 0.012sec.
# 642-th iteration finished, shat_eps: 129.278317, lapse: 0.011sec.
# 643-th iteration finished, shat_eps: 129.278315, lapse: 0.009sec.
# 644-th iteration finished, shat_eps: 129.278313, lapse: 0.007sec.
# 645-th iteration finished, shat_eps: 129.278311, lapse: 0.012sec.
# 646-th iteration finished, shat_eps: 129.278309, lapse: 0.007sec.
# 647-th iteration finished, shat_eps: 129.278307, lapse: 0.010sec.
# 648-th iteration finished, shat_eps: 129.278305, lapse: 0.012sec.
# 649-th iteration finished, shat_eps: 129.278303, lapse: 0.008sec.
# 650-th iteration finished, shat_eps: 129.278301, lapse: 0.005sec.
# 651-th iteration finished, shat_eps: 129.278299, lapse: 0.017sec.
# 652-th iteration finished, shat_eps: 129.278297, lapse: 0.005sec.
# 653-th iteration finished, shat_eps: 129.278295, lapse: 0.014sec.
# 654-th iteration finished, shat_eps: 129.278293, lapse: 0.006sec.
# 655-th iteration finished, shat_eps: 129.278291, lapse: 0.013sec.
# 656-th iteration finished, shat_eps: 129.278289, lapse: 0.014sec.
# 657-th iteration finished, shat_eps: 129.278287, lapse: 0.011sec.
# 658-th iteration finished, shat_eps: 129.278285, lapse: 0.009sec.
# 659-th iteration finished, shat_eps: 129.278283, lapse: 0.014sec.
# 660-th iteration finished, shat_eps: 129.278281, lapse: 0.015sec.
# 661-th iteration finished, shat_eps: 129.278279, lapse: 0.013sec.
# 662-th iteration finished, shat_eps: 129.278277, lapse: 0.022sec.
# 663-th iteration finished, shat_eps: 129.278275, lapse: 0.024sec.
# 664-th iteration finished, shat_eps: 129.278273, lapse: 0.019sec.
# 665-th iteration finished, shat_eps: 129.278271, lapse: 0.007sec.
# 666-th iteration finished, shat_eps: 129.278269, lapse: 0.010sec.
# 667-th iteration finished, shat_eps: 129.278267, lapse: 0.008sec.
# 668-th iteration finished, shat_eps: 129.278265, lapse: 0.011sec.
# 669-th iteration finished, shat_eps: 129.278264, lapse: 0.005sec.
# 670-th iteration finished, shat_eps: 129.278262, lapse: 0.012sec.
# 671-th iteration finished, shat_eps: 129.278260, lapse: 0.010sec.
# 672-th iteration finished, shat_eps: 129.278258, lapse: 0.010sec.
# 673-th iteration finished, shat_eps: 129.278256, lapse: 0.009sec.
# 674-th iteration finished, shat_eps: 129.278254, lapse: 0.009sec.
# 675-th iteration finished, shat_eps: 129.278252, lapse: 0.010sec.
# 676-th iteration finished, shat_eps: 129.278250, lapse: 0.007sec.
# 677-th iteration finished, shat_eps: 129.278248, lapse: 0.008sec.
# 678-th iteration finished, shat_eps: 129.278246, lapse: 0.016sec.
# 679-th iteration finished, shat_eps: 129.278244, lapse: 0.010sec.
# 680-th iteration finished, shat_eps: 129.278242, lapse: 0.008sec.
# 681-th iteration finished, shat_eps: 129.278240, lapse: 0.006sec.
# 682-th iteration finished, shat_eps: 129.278239, lapse: 0.007sec.
# 683-th iteration finished, shat_eps: 129.278237, lapse: 0.005sec.
# 684-th iteration finished, shat_eps: 129.278235, lapse: 0.005sec.
# 685-th iteration finished, shat_eps: 129.278233, lapse: 0.007sec.
# 686-th iteration finished, shat_eps: 129.278231, lapse: 0.005sec.
# 687-th iteration finished, shat_eps: 129.278229, lapse: 0.006sec.
# 688-th iteration finished, shat_eps: 129.278227, lapse: 0.015sec.
# 689-th iteration finished, shat_eps: 129.278225, lapse: 0.005sec.
# 690-th iteration finished, shat_eps: 129.278223, lapse: 0.006sec.
# 691-th iteration finished, shat_eps: 129.278221, lapse: 0.013sec.
# 692-th iteration finished, shat_eps: 129.278220, lapse: 0.009sec.
# 693-th iteration finished, shat_eps: 129.278218, lapse: 0.013sec.
# 694-th iteration finished, shat_eps: 129.278216, lapse: 0.007sec.
# 695-th iteration finished, shat_eps: 129.278214, lapse: 0.017sec.
# 696-th iteration finished, shat_eps: 129.278212, lapse: 0.011sec.
# 697-th iteration finished, shat_eps: 129.278210, lapse: 0.012sec.
# 698-th iteration finished, shat_eps: 129.278208, lapse: 0.009sec.
# 699-th iteration finished, shat_eps: 129.278207, lapse: 0.016sec.
# 700-th iteration finished, shat_eps: 129.278205, lapse: 0.011sec.
# 701-th iteration finished, shat_eps: 129.278203, lapse: 0.007sec.
# 702-th iteration finished, shat_eps: 129.278201, lapse: 0.014sec.
# 703-th iteration finished, shat_eps: 129.278199, lapse: 0.010sec.
# 704-th iteration finished, shat_eps: 129.278197, lapse: 0.010sec.
# 705-th iteration finished, shat_eps: 129.278196, lapse: 0.008sec.
# 706-th iteration finished, shat_eps: 129.278194, lapse: 0.005sec.
# 707-th iteration finished, shat_eps: 129.278192, lapse: 0.009sec.
# 708-th iteration finished, shat_eps: 129.278190, lapse: 0.007sec.
# 709-th iteration finished, shat_eps: 129.278188, lapse: 0.005sec.
# 710-th iteration finished, shat_eps: 129.278186, lapse: 0.009sec.
# 711-th iteration finished, shat_eps: 129.278185, lapse: 0.006sec.
# 712-th iteration finished, shat_eps: 129.278183, lapse: 0.006sec.
# 713-th iteration finished, shat_eps: 129.278181, lapse: 0.006sec.
# 714-th iteration finished, shat_eps: 129.278179, lapse: 0.005sec.
# 715-th iteration finished, shat_eps: 129.278177, lapse: 0.008sec.
# 716-th iteration finished, shat_eps: 129.278175, lapse: 0.007sec.
# 717-th iteration finished, shat_eps: 129.278174, lapse: 0.007sec.
# 718-th iteration finished, shat_eps: 129.278172, lapse: 0.013sec.
# 719-th iteration finished, shat_eps: 129.278170, lapse: 0.008sec.
# 720-th iteration finished, shat_eps: 129.278168, lapse: 0.007sec.
# 721-th iteration finished, shat_eps: 129.278167, lapse: 0.008sec.
# 722-th iteration finished, shat_eps: 129.278165, lapse: 0.007sec.
# 723-th iteration finished, shat_eps: 129.278163, lapse: 0.010sec.
# 724-th iteration finished, shat_eps: 129.278161, lapse: 0.013sec.
# 725-th iteration finished, shat_eps: 129.278159, lapse: 0.010sec.
# 726-th iteration finished, shat_eps: 129.278158, lapse: 0.015sec.
# 727-th iteration finished, shat_eps: 129.278156, lapse: 0.022sec.
# 728-th iteration finished, shat_eps: 129.278154, lapse: 0.024sec.
# ...
# 2763-th iteration finished, shat_eps: 129.277086, lapse: 0.014sec.
# 2764-th iteration finished, shat_eps: 129.277086, lapse: 0.008sec.
# 2765-th iteration finished, shat_eps: 129.277086, lapse: 0.008sec.
# 2766-th iteration finished, shat_eps: 129.277086, lapse: 0.009sec.
# 2767-th iteration finished, shat_eps: 129.277086, lapse: 0.009sec.
# 2768-th iteration finished, shat_eps: 129.277086, lapse: 0.007sec.
# 2769-th iteration finished, shat_eps: 129.277086, lapse: 0.008sec.
# 2770-th iteration finished, shat_eps: 129.277086, lapse: 0.005sec.
# 2771-th iteration finished, shat_eps: 129.277085, lapse: 0.011sec.
# 2772-th iteration finished, shat_eps: 129.277085, lapse: 0.010sec.
# 2773-th iteration finished, shat_eps: 129.277085, lapse: 0.006sec.
# 2774-th iteration finished, shat_eps: 129.277085, lapse: 0.005sec.
# 2775-th iteration finished, shat_eps: 129.277085, lapse: 0.007sec.
# 2776-th iteration finished, shat_eps: 129.277085, lapse: 0.007sec.
# 2777-th iteration finished, shat_eps: 129.277085, lapse: 0.004sec.
# 2778-th iteration finished, shat_eps: 129.277085, lapse: 0.007sec.
# 2779-th iteration finished, shat_eps: 129.277085, lapse: 0.007sec.
# 2780-th iteration finished, shat_eps: 129.277085, lapse: 0.007sec.
# 2781-th iteration finished, shat_eps: 129.277085, lapse: 0.008sec.
# 2782-th iteration finished, shat_eps: 129.277085, lapse: 0.005sec.
# 2783-th iteration finished, shat_eps: 129.277085, lapse: 0.007sec.
# 2784-th iteration finished, shat_eps: 129.277085, lapse: 0.007sec.
# 2785-th iteration finished, shat_eps: 129.277084, lapse: 0.006sec.
# 2786-th iteration finished, shat_eps: 129.277084, lapse: 0.007sec.
# 2787-th iteration finished, shat_eps: 129.277084, lapse: 0.007sec.
# 2788-th iteration finished, shat_eps: 129.277084, lapse: 0.009sec.
# 2789-th iteration finished, shat_eps: 129.277084, lapse: 0.010sec.
# 2790-th iteration finished, shat_eps: 129.277084, lapse: 0.005sec.
# 2791-th iteration finished, shat_eps: 129.277084, lapse: 0.007sec.
# 2792-th iteration finished, shat_eps: 129.277084, lapse: 0.008sec.
# 2793-th iteration finished, shat_eps: 129.277084, lapse: 0.007sec.
# 2794-th iteration finished, shat_eps: 129.277084, lapse: 0.021sec.
# 2795-th iteration finished, shat_eps: 129.277084, lapse: 0.015sec.
# 2796-th iteration finished, shat_eps: 129.277084, lapse: 0.009sec.
# 2797-th iteration finished, shat_eps: 129.277084, lapse: 0.013sec.
# 2798-th iteration finished, shat_eps: 129.277084, lapse: 0.014sec.
# 2799-th iteration finished, shat_eps: 129.277084, lapse: 0.011sec.
# 2800-th iteration finished, shat_eps: 129.277083, lapse: 0.014sec.
# 2801-th iteration finished, shat_eps: 129.277083, lapse: 0.010sec.
# 2802-th iteration finished, shat_eps: 129.277083, lapse: 0.013sec.
# 2803-th iteration finished, shat_eps: 129.277083, lapse: 0.017sec.
# 2804-th iteration finished, shat_eps: 129.277083, lapse: 0.011sec.
# 2805-th iteration finished, shat_eps: 129.277083, lapse: 0.009sec.
# 2806-th iteration finished, shat_eps: 129.277083, lapse: 0.010sec.
# 2807-th iteration finished, shat_eps: 129.277083, lapse: 0.008sec.
# 2808-th iteration finished, shat_eps: 129.277083, lapse: 0.005sec.
# 2809-th iteration finished, shat_eps: 129.277083, lapse: 0.007sec.
# 2810-th iteration finished, shat_eps: 129.277083, lapse: 0.011sec.
# 2811-th iteration finished, shat_eps: 129.277083, lapse: 0.026sec.
# 2812-th iteration finished, shat_eps: 129.277083, lapse: 0.016sec.
# 2813-th iteration finished, shat_eps: 129.277083, lapse: 0.015sec.
# 2814-th iteration finished, shat_eps: 129.277083, lapse: 0.015sec.
# 2815-th iteration finished, shat_eps: 129.277082, lapse: 0.009sec.
# 2816-th iteration finished, shat_eps: 129.277082, lapse: 0.010sec.
# 2817-th iteration finished, shat_eps: 129.277082, lapse: 0.006sec.
# 2818-th iteration finished, shat_eps: 129.277082, lapse: 0.014sec.
# 2819-th iteration finished, shat_eps: 129.277082, lapse: 0.014sec.
# 2820-th iteration finished, shat_eps: 129.277082, lapse: 0.013sec.
# 2821-th iteration finished, shat_eps: 129.277082, lapse: 0.008sec.
# 2822-th iteration finished, shat_eps: 129.277082, lapse: 0.014sec.
# 2823-th iteration finished, shat_eps: 129.277082, lapse: 0.006sec.
# 2824-th iteration finished, shat_eps: 129.277082, lapse: 0.005sec.
# 2825-th iteration finished, shat_eps: 129.277082, lapse: 0.009sec.
# 2826-th iteration finished, shat_eps: 129.277082, lapse: 0.007sec.
# 2827-th iteration finished, shat_eps: 129.277082, lapse: 0.005sec.
# 2828-th iteration finished, shat_eps: 129.277082, lapse: 0.006sec.
# 2829-th iteration finished, shat_eps: 129.277082, lapse: 0.008sec.
# 2830-th iteration finished, shat_eps: 129.277082, lapse: 0.005sec.
# 2831-th iteration finished, shat_eps: 129.277081, lapse: 0.011sec.
# 2832-th iteration finished, shat_eps: 129.277081, lapse: 0.007sec.
# 2833-th iteration finished, shat_eps: 129.277081, lapse: 0.010sec.
# 2834-th iteration finished, shat_eps: 129.277081, lapse: 0.024sec.
# 2835-th iteration finished, shat_eps: 129.277081, lapse: 0.019sec.
# 2836-th iteration finished, shat_eps: 129.277081, lapse: 0.016sec.
# 2837-th iteration finished, shat_eps: 129.277081, lapse: 0.015sec.
# 2838-th iteration finished, shat_eps: 129.277081, lapse: 0.032sec.
# 2839-th iteration finished, shat_eps: 129.277081, lapse: 0.019sec.
# 2840-th iteration finished, shat_eps: 129.277081, lapse: 0.011sec.
# 2841-th iteration finished, shat_eps: 129.277081, lapse: 0.021sec.
# 2842-th iteration finished, shat_eps: 129.277081, lapse: 0.015sec.
# 2843-th iteration finished, shat_eps: 129.277081, lapse: 0.009sec.
# 2844-th iteration finished, shat_eps: 129.277081, lapse: 0.015sec.
# 2845-th iteration finished, shat_eps: 129.277081, lapse: 0.015sec.
# 2846-th iteration finished, shat_eps: 129.277081, lapse: 0.026sec.
# 2847-th iteration finished, shat_eps: 129.277080, lapse: 0.012sec.
# 2848-th iteration finished, shat_eps: 129.277080, lapse: 0.021sec.
# 2849-th iteration finished, shat_eps: 129.277080, lapse: 0.008sec.
# 2850-th iteration finished, shat_eps: 129.277080, lapse: 0.021sec.
# 2851-th iteration finished, shat_eps: 129.277080, lapse: 0.010sec.
# 2852-th iteration finished, shat_eps: 129.277080, lapse: 0.015sec.
# 2853-th iteration finished, shat_eps: 129.277080, lapse: 0.015sec.
# 2854-th iteration finished, shat_eps: 129.277080, lapse: 0.015sec.
# 2855-th iteration finished, shat_eps: 129.277080, lapse: 0.012sec.
# 2856-th iteration finished, shat_eps: 129.277080, lapse: 0.008sec.
# 2857-th iteration finished, shat_eps: 129.277080, lapse: 0.010sec.
# 2858-th iteration finished, shat_eps: 129.277080, lapse: 0.008sec.
# 2859-th iteration finished, shat_eps: 129.277080, lapse: 0.013sec.
# 2860-th iteration finished, shat_eps: 129.277080, lapse: 0.005sec.
# 2861-th iteration finished, shat_eps: 129.277080, lapse: 0.015sec.
# 2862-th iteration finished, shat_eps: 129.277080, lapse: 0.020sec.
# 2863-th iteration finished, shat_eps: 129.277079, lapse: 0.020sec.
# 2864-th iteration finished, shat_eps: 129.277079, lapse: 0.023sec.
# 2865-th iteration finished, shat_eps: 129.277079, lapse: 0.009sec.
# 2866-th iteration finished, shat_eps: 129.277079, lapse: 0.012sec.
# 2867-th iteration finished, shat_eps: 129.277079, lapse: 0.009sec.
# 2868-th iteration finished, shat_eps: 129.277079, lapse: 0.013sec.
# 2869-th iteration finished, shat_eps: 129.277079, lapse: 0.005sec.
# 2870-th iteration finished, shat_eps: 129.277079, lapse: 0.009sec.
# 2871-th iteration finished, shat_eps: 129.277079, lapse: 0.008sec.
# 2872-th iteration finished, shat_eps: 129.277079, lapse: 0.005sec.
# 2873-th iteration finished, shat_eps: 129.277079, lapse: 0.005sec.
# 2874-th iteration finished, shat_eps: 129.277079, lapse: 0.008sec.
# 2875-th iteration finished, shat_eps: 129.277079, lapse: 0.009sec.
# 2876-th iteration finished, shat_eps: 129.277079, lapse: 0.007sec.
# 2877-th iteration finished, shat_eps: 129.277079, lapse: 0.009sec.
# 2878-th iteration finished, shat_eps: 129.277079, lapse: 0.005sec.
# 2879-th iteration finished, shat_eps: 129.277079, lapse: 0.007sec.
# 2880-th iteration finished, shat_eps: 129.277078, lapse: 0.006sec.
# 2881-th iteration finished, shat_eps: 129.277078, lapse: 0.005sec.
# 2882-th iteration finished, shat_eps: 129.277078, lapse: 0.004sec.
# 2883-th iteration finished, shat_eps: 129.277078, lapse: 0.009sec.
# 2884-th iteration finished, shat_eps: 129.277078, lapse: 0.012sec.
# 2885-th iteration finished, shat_eps: 129.277078, lapse: 0.022sec.
# 2886-th iteration finished, shat_eps: 129.277078, lapse: 0.009sec.
# 2887-th iteration finished, shat_eps: 129.277078, lapse: 0.014sec.
# 2888-th iteration finished, shat_eps: 129.277078, lapse: 0.013sec.
# 2889-th iteration finished, shat_eps: 129.277078, lapse: 0.014sec.
# 2890-th iteration finished, shat_eps: 129.277078, lapse: 0.008sec.
# 2891-th iteration finished, shat_eps: 129.277078, lapse: 0.011sec.
# 2892-th iteration finished, shat_eps: 129.277078, lapse: 0.008sec.
# 2893-th iteration finished, shat_eps: 129.277078, lapse: 0.020sec.
# 2894-th iteration finished, shat_eps: 129.277078, lapse: 0.012sec.
# 2895-th iteration finished, shat_eps: 129.277078, lapse: 0.012sec.
# 2896-th iteration finished, shat_eps: 129.277078, lapse: 0.011sec.
# 2897-th iteration finished, shat_eps: 129.277077, lapse: 0.009sec.
# 2898-th iteration finished, shat_eps: 129.277077, lapse: 0.018sec.
# 2899-th iteration finished, shat_eps: 129.277077, lapse: 0.008sec.
# 2900-th iteration finished, shat_eps: 129.277077, lapse: 0.011sec.
# 2901-th iteration finished, shat_eps: 129.277077, lapse: 0.018sec.
# 2902-th iteration finished, shat_eps: 129.277077, lapse: 0.013sec.
# 2903-th iteration finished, shat_eps: 129.277077, lapse: 0.009sec.
# 2904-th iteration finished, shat_eps: 129.277077, lapse: 0.008sec.
# 2905-th iteration finished, shat_eps: 129.277077, lapse: 0.006sec.
# 2906-th iteration finished, shat_eps: 129.277077, lapse: 0.005sec.
# 2907-th iteration finished, shat_eps: 129.277077, lapse: 0.004sec.
# 2908-th iteration finished, shat_eps: 129.277077, lapse: 0.014sec.
# 2909-th iteration finished, shat_eps: 129.277077, lapse: 0.006sec.
# 2910-th iteration finished, shat_eps: 129.277077, lapse: 0.015sec.
# 2911-th iteration finished, shat_eps: 129.277077, lapse: 0.005sec.
# 2912-th iteration finished, shat_eps: 129.277077, lapse: 0.004sec.
# 2913-th iteration finished, shat_eps: 129.277077, lapse: 0.004sec.
# 2914-th iteration finished, shat_eps: 129.277077, lapse: 0.004sec.
# 2915-th iteration finished, shat_eps: 129.277076, lapse: 0.006sec.
# 2916-th iteration finished, shat_eps: 129.277076, lapse: 0.004sec.
# 2917-th iteration finished, shat_eps: 129.277076, lapse: 0.007sec.
# 2918-th iteration finished, shat_eps: 129.277076, lapse: 0.005sec.
# 2919-th iteration finished, shat_eps: 129.277076, lapse: 0.006sec.
# 2920-th iteration finished, shat_eps: 129.277076, lapse: 0.006sec.
# 2921-th iteration finished, shat_eps: 129.277076, lapse: 0.006sec.
# 2922-th iteration finished, shat_eps: 129.277076, lapse: 0.005sec.
# 2923-th iteration finished, shat_eps: 129.277076, lapse: 0.006sec.
# 2924-th iteration finished, shat_eps: 129.277076, lapse: 0.005sec.
# 2925-th iteration finished, shat_eps: 129.277076, lapse: 0.006sec.
# 2926-th iteration finished, shat_eps: 129.277076, lapse: 0.006sec.
# 2927-th iteration finished, shat_eps: 129.277076, lapse: 0.004sec.
# 2928-th iteration finished, shat_eps: 129.277076, lapse: 0.004sec.
# 2929-th iteration finished, shat_eps: 129.277076, lapse: 0.007sec.
# 2930-th iteration finished, shat_eps: 129.277076, lapse: 0.007sec.
# 2931-th iteration finished, shat_eps: 129.277076, lapse: 0.010sec.
# 2932-th iteration finished, shat_eps: 129.277076, lapse: 0.024sec.
# 2933-th iteration finished, shat_eps: 129.277075, lapse: 0.006sec.
# 2934-th iteration finished, shat_eps: 129.277075, lapse: 0.008sec.
# 2935-th iteration finished, shat_eps: 129.277075, lapse: 0.012sec.
# 2936-th iteration finished, shat_eps: 129.277075, lapse: 0.007sec.
# 2937-th iteration finished, shat_eps: 129.277075, lapse: 0.005sec.
# 2938-th iteration finished, shat_eps: 129.277075, lapse: 0.006sec.
# 2939-th iteration finished, shat_eps: 129.277075, lapse: 0.005sec.
# 2940-th iteration finished, shat_eps: 129.277075, lapse: 0.006sec.
# 2941-th iteration finished, shat_eps: 129.277075, lapse: 0.005sec.
# 2942-th iteration finished, shat_eps: 129.277075, lapse: 0.013sec.
# 2943-th iteration finished, shat_eps: 129.277075, lapse: 0.012sec.
# 2944-th iteration finished, shat_eps: 129.277075, lapse: 0.012sec.
# 2945-th iteration finished, shat_eps: 129.277075, lapse: 0.010sec.
# 2946-th iteration finished, shat_eps: 129.277075, lapse: 0.029sec.
# 2947-th iteration finished, shat_eps: 129.277075, lapse: 0.069sec.
# 2948-th iteration finished, shat_eps: 129.277075, lapse: 0.028sec.
# 2949-th iteration finished, shat_eps: 129.277075, lapse: 0.025sec.
# 2950-th iteration finished, shat_eps: 129.277075, lapse: 0.013sec.
# 2951-th iteration finished, shat_eps: 129.277074, lapse: 0.016sec.
# 2952-th iteration finished, shat_eps: 129.277074, lapse: 0.014sec.
# 2953-th iteration finished, shat_eps: 129.277074, lapse: 0.009sec.
# 2954-th iteration finished, shat_eps: 129.277074, lapse: 0.012sec.
# 2955-th iteration finished, shat_eps: 129.277074, lapse: 0.009sec.
# 2956-th iteration finished, shat_eps: 129.277074, lapse: 0.008sec.
# 2957-th iteration finished, shat_eps: 129.277074, lapse: 0.008sec.
# 2958-th iteration finished, shat_eps: 129.277074, lapse: 0.007sec.
# 2959-th iteration finished, shat_eps: 129.277074, lapse: 0.014sec.
# 2960-th iteration finished, shat_eps: 129.277074, lapse: 0.009sec.
# 2961-th iteration finished, shat_eps: 129.277074, lapse: 0.010sec.
# 2962-th iteration finished, shat_eps: 129.277074, lapse: 0.011sec.
# 2963-th iteration finished, shat_eps: 129.277074, lapse: 0.008sec.
# 2964-th iteration finished, shat_eps: 129.277074, lapse: 0.024sec.
# 2965-th iteration finished, shat_eps: 129.277074, lapse: 0.022sec.
# 2966-th iteration finished, shat_eps: 129.277074, lapse: 0.009sec.
# 2967-th iteration finished, shat_eps: 129.277074, lapse: 0.013sec.
# 2968-th iteration finished, shat_eps: 129.277074, lapse: 0.008sec.
# 2969-th iteration finished, shat_eps: 129.277074, lapse: 0.008sec.
# 2970-th iteration finished, shat_eps: 129.277074, lapse: 0.008sec.
# 2971-th iteration finished, shat_eps: 129.277073, lapse: 0.007sec.
# 2972-th iteration finished, shat_eps: 129.277073, lapse: 0.007sec.
# 2973-th iteration finished, shat_eps: 129.277073, lapse: 0.007sec.
# 2974-th iteration finished, shat_eps: 129.277073, lapse: 0.005sec.
# 2975-th iteration finished, shat_eps: 129.277073, lapse: 0.006sec.
# 2976-th iteration finished, shat_eps: 129.277073, lapse: 0.007sec.
# 2977-th iteration finished, shat_eps: 129.277073, lapse: 0.006sec.
# 2978-th iteration finished, shat_eps: 129.277073, lapse: 0.005sec.
# 2979-th iteration finished, shat_eps: 129.277073, lapse: 0.006sec.
# 2980-th iteration finished, shat_eps: 129.277073, lapse: 0.008sec.
# 2981-th iteration finished, shat_eps: 129.277073, lapse: 0.005sec.
# 2982-th iteration finished, shat_eps: 129.277073, lapse: 0.006sec.
# 2983-th iteration finished, shat_eps: 129.277073, lapse: 0.009sec.
# 2984-th iteration finished, shat_eps: 129.277073, lapse: 0.008sec.
# 2985-th iteration finished, shat_eps: 129.277073, lapse: 0.005sec.
# 2986-th iteration finished, shat_eps: 129.277073, lapse: 0.008sec.
# 2987-th iteration finished, shat_eps: 129.277073, lapse: 0.012sec.
# 2988-th iteration finished, shat_eps: 129.277073, lapse: 0.007sec.
# 2989-th iteration finished, shat_eps: 129.277073, lapse: 0.008sec.
# 2990-th iteration finished, shat_eps: 129.277073, lapse: 0.006sec.
# 2991-th iteration finished, shat_eps: 129.277072, lapse: 0.017sec.
# 2992-th iteration finished, shat_eps: 129.277072, lapse: 0.005sec.
# 2993-th iteration finished, shat_eps: 129.277072, lapse: 0.009sec.
# 2994-th iteration finished, shat_eps: 129.277072, lapse: 0.008sec.
# 2995-th iteration finished, shat_eps: 129.277072, lapse: 0.009sec.
# 2996-th iteration finished, shat_eps: 129.277072, lapse: 0.005sec.
# 2997-th iteration finished, shat_eps: 129.277072, lapse: 0.008sec.
# 2998-th iteration finished, shat_eps: 129.277072, lapse: 0.005sec.
# 2999-th iteration finished, shat_eps: 129.277072, lapse: 0.007sec.
# 3000-th iteration finished, shat_eps: 129.277072, lapse: 0.009sec.

# %%
mmle_0 = mhs_0[-1]
smle_eps = shs_eps[-1]
bmle = bhs[-1]

# %% [markdown]
# ## plots

# %%
plt.plot(shs_eps, label=r"$\hat{\sigma}^{(i)}_\epsilon$")
# plt.plot(shs_eta, label=r"$\hat{\sigma}^{(i)}_\eta$")
plt.xlabel("iteration (i)"); plt.legend()

# %%
plt.plot(mhs_0, label=r"$\hat{\mu}^{(i)}$")
plt.xlabel("iteration (i)"); plt.legend()

# %%
plt.plot(bhs, label=r"$\hat{\beta}^{(i)}$")
plt.xlabel("iteration (i)"); plt.legend()

# %% [markdown]
# # 4. Simulation Study

# %%
num_sim = 200
num_iter = 100

# %%
msim_0 = np.zeros([num_sim])
ssim_eps = np.zeros([num_sim])
bsim = np.zeros([num_sim, d])

# %%
Ys_sim = np.zeros([num_sim, T])

# %% [markdown]
# ## simulation

# %%
for iter_sim in np.arange(num_sim):
    start_sim = time.time()
    
    Y_sim = np.zeros([T])
    for t in np.arange(T):
        Y_sim[t] = alpha * np.sum(np.flip(I[:t+T0])*pi[:t+T0]) + np.random.normal(0,s_eps)
        
    mhat_0, shat_eps, bhat =\
        fit(Y_sim, minit_0 = mu_0, sinit_eps = s_eps, binit = beta, 
            history=True, n_iter=num_iter) 
    
    msim_0[iter_sim] = mhat_0[-1]
    ssim_eps[iter_sim] = shat_eps[-1]
    bsim[iter_sim] = bhat[-1]
    
    Ys_sim[iter_sim] = Y_sim
    
    sys.__stdout__.write("%d-th simulation finished, %f sec.\n"
                         %(iter_sim+1, time.time()-start_sim))
    sys.__stdout__.flush()
# Out:
# 1-th simulation finished, 0.704007 sec.
# 2-th simulation finished, 0.781063 sec.
# 3-th simulation finished, 0.686796 sec.
# 4-th simulation finished, 0.718259 sec.
# 5-th simulation finished, 0.676578 sec.
# 6-th simulation finished, 0.671167 sec.
# 7-th simulation finished, 0.958957 sec.
# 8-th simulation finished, 0.853540 sec.
# 9-th simulation finished, 0.740751 sec.
# 10-th simulation finished, 0.783858 sec.
# 11-th simulation finished, 0.797412 sec.
# 12-th simulation finished, 0.749551 sec.
# 13-th simulation finished, 0.802218 sec.
# 14-th simulation finished, 0.694088 sec.
# 15-th simulation finished, 0.885470 sec.
# 16-th simulation finished, 0.976545 sec.
# 17-th simulation finished, 0.759932 sec.
# 18-th simulation finished, 0.754413 sec.
# 19-th simulation finished, 0.725931 sec.
# 20-th simulation finished, 0.722805 sec.
# 21-th simulation finished, 0.687796 sec.
# 22-th simulation finished, 0.722023 sec.
# 23-th simulation finished, 0.977264 sec.
# 24-th simulation finished, 0.770864 sec.
# 25-th simulation finished, 1.093410 sec.
# 26-th simulation finished, 0.792899 sec.
# 27-th simulation finished, 0.827622 sec.
# 28-th simulation finished, 0.766878 sec.
# 29-th simulation finished, 0.771120 sec.
# 30-th simulation finished, 0.917133 sec.
# 31-th simulation finished, 0.663856 sec.
# 32-th simulation finished, 1.046566 sec.
# 33-th simulation finished, 0.894794 sec.
# 34-th simulation finished, 0.784476 sec.
# 35-th simulation finished, 0.798198 sec.
# 36-th simulation finished, 0.766545 sec.
# 37-th simulation finished, 0.926959 sec.
# 38-th simulation finished, 0.820450 sec.
# 39-th simulation finished, 0.744890 sec.
# 40-th simulation finished, 0.798279 sec.
# 41-th simulation finished, 0.751148 sec.
# 42-th simulation finished, 0.659572 sec.
# 43-th simulation finished, 0.660358 sec.
# 44-th simulation finished, 0.799481 sec.
# 45-th simulation finished, 0.842205 sec.
# 46-th simulation finished, 0.985264 sec.
# 47-th simulation finished, 1.187323 sec.
# 48-th simulation finished, 0.878817 sec.
# 49-th simulation finished, 0.828943 sec.
# 50-th simulation finished, 0.751096 sec.
# 51-th simulation finished, 0.724078 sec.
# 52-th simulation finished, 0.699461 sec.
# 53-th simulation finished, 0.979892 sec.
# 54-th simulation finished, 1.020890 sec.
# 55-th simulation finished, 0.880172 sec.
# 56-th simulation finished, 0.908567 sec.
# 57-th simulation finished, 0.943622 sec.
# 58-th simulation finished, 0.870033 sec.
# 59-th simulation finished, 0.788597 sec.
# 60-th simulation finished, 0.658112 sec.
# 61-th simulation finished, 0.766351 sec.
# 62-th simulation finished, 0.699402 sec.
# 63-th simulation finished, 0.705451 sec.
# 64-th simulation finished, 0.688892 sec.
# 65-th simulation finished, 0.669803 sec.
# 66-th simulation finished, 0.730135 sec.
# 67-th simulation finished, 0.790349 sec.
# 68-th simulation finished, 0.670627 sec.
# 69-th simulation finished, 0.703756 sec.
# 70-th simulation finished, 0.657771 sec.
# 71-th simulation finished, 0.677487 sec.
# 72-th simulation finished, 0.764059 sec.
# 73-th simulation finished, 0.686526 sec.
# 74-th simulation finished, 0.671780 sec.
# 75-th simulation finished, 0.678380 sec.
# 76-th simulation finished, 0.682474 sec.
# 77-th simulation finished, 0.644039 sec.
# 78-th simulation finished, 0.645634 sec.
# 79-th simulation finished, 0.663989 sec.
# 80-th simulation finished, 0.677763 sec.
# 81-th simulation finished, 0.679419 sec.
# 82-th simulation finished, 0.648031 sec.
# 83-th simulation finished, 0.647294 sec.
# 84-th simulation finished, 0.717932 sec.
# 85-th simulation finished, 0.672355 sec.
# 86-th simulation finished, 0.634482 sec.
# 87-th simulation finished, 0.677860 sec.
# 88-th simulation finished, 0.649897 sec.
# 89-th simulation finished, 0.678123 sec.
# 90-th simulation finished, 0.720824 sec.
# 91-th simulation finished, 0.703912 sec.
# 92-th simulation finished, 0.650456 sec.
# 93-th simulation finished, 0.682072 sec.
# 94-th simulation finished, 0.647815 sec.
# 95-th simulation finished, 0.688978 sec.
# 96-th simulation finished, 0.657189 sec.
# 97-th simulation finished, 0.667861 sec.
# 98-th simulation finished, 0.705933 sec.
# 99-th simulation finished, 0.678877 sec.
# 100-th simulation finished, 0.714060 sec.
# 101-th simulation finished, 0.661608 sec.
# 102-th simulation finished, 0.696432 sec.
# 103-th simulation finished, 0.638301 sec.
# 104-th simulation finished, 0.663696 sec.
# 105-th simulation finished, 0.688596 sec.
# 106-th simulation finished, 0.734514 sec.
# 107-th simulation finished, 0.673655 sec.
# 108-th simulation finished, 0.695284 sec.
# 109-th simulation finished, 0.705675 sec.
# 110-th simulation finished, 0.683450 sec.
# 111-th simulation finished, 0.750262 sec.
# 112-th simulation finished, 0.648912 sec.
# 113-th simulation finished, 0.649426 sec.
# 114-th simulation finished, 0.638962 sec.
# 115-th simulation finished, 0.700495 sec.
# 116-th simulation finished, 0.677984 sec.
# 117-th simulation finished, 0.961382 sec.
# 118-th simulation finished, 0.750509 sec.
# 119-th simulation finished, 0.721004 sec.
# 120-th simulation finished, 0.797032 sec.
# 121-th simulation finished, 0.682438 sec.
# 122-th simulation finished, 0.726876 sec.
# 123-th simulation finished, 0.725116 sec.
# 124-th simulation finished, 0.831224 sec.
# 125-th simulation finished, 0.787981 sec.
# 126-th simulation finished, 0.874470 sec.
# 127-th simulation finished, 0.784722 sec.
# 128-th simulation finished, 0.789773 sec.
# 129-th simulation finished, 0.793668 sec.
# 130-th simulation finished, 0.770954 sec.
# 131-th simulation finished, 0.766327 sec.
# 132-th simulation finished, 0.793083 sec.
# 133-th simulation finished, 0.760632 sec.
# 134-th simulation finished, 0.788530 sec.
# 135-th simulation finished, 0.663074 sec.
# 136-th simulation finished, 0.644298 sec.
# 137-th simulation finished, 0.677949 sec.
# 138-th simulation finished, 0.786261 sec.
# 139-th simulation finished, 0.665939 sec.
# 140-th simulation finished, 0.664370 sec.
# 141-th simulation finished, 0.639841 sec.
# 142-th simulation finished, 0.706245 sec.
# 143-th simulation finished, 0.671986 sec.
# 144-th simulation finished, 0.644614 sec.
# 145-th simulation finished, 0.668332 sec.
# 146-th simulation finished, 0.664307 sec.
# 147-th simulation finished, 0.673171 sec.
# 148-th simulation finished, 0.666520 sec.
# 149-th simulation finished, 0.713034 sec.
# 150-th simulation finished, 0.618665 sec.
# 151-th simulation finished, 0.730884 sec.
# 152-th simulation finished, 0.763415 sec.
# 153-th simulation finished, 0.629334 sec.
# 154-th simulation finished, 0.658322 sec.
# 155-th simulation finished, 0.676071 sec.
# 156-th simulation finished, 0.609491 sec.
# 157-th simulation finished, 0.676227 sec.
# 158-th simulation finished, 0.656268 sec.
# 159-th simulation finished, 0.663326 sec.
# 160-th simulation finished, 0.709540 sec.
# 161-th simulation finished, 0.668233 sec.
# 162-th simulation finished, 0.654610 sec.
# 163-th simulation finished, 0.644107 sec.
# 164-th simulation finished, 0.677919 sec.
# 165-th simulation finished, 0.638167 sec.
# 166-th simulation finished, 0.705176 sec.
# 167-th simulation finished, 0.653404 sec.
# 168-th simulation finished, 0.684988 sec.
# 169-th simulation finished, 0.875829 sec.
# 170-th simulation finished, 0.642164 sec.
# 171-th simulation finished, 0.628137 sec.
# 172-th simulation finished, 0.648189 sec.
# 173-th simulation finished, 0.663201 sec.
# 174-th simulation finished, 0.714652 sec.
# 175-th simulation finished, 0.656239 sec.
# 176-th simulation finished, 0.712576 sec.
# 177-th simulation finished, 0.696012 sec.
# 178-th simulation finished, 0.667786 sec.
# 179-th simulation finished, 0.719925 sec.
# 180-th simulation finished, 0.646211 sec.
# 181-th simulation finished, 0.652394 sec.
# 182-th simulation finished, 0.654332 sec.
# 183-th simulation finished, 0.650328 sec.
# 184-th simulation finished, 0.655368 sec.
# 185-th simulation finished, 0.673160 sec.
# 186-th simulation finished, 0.680672 sec.
# 187-th simulation finished, 0.663127 sec.
# 188-th simulation finished, 0.709931 sec.
# 189-th simulation finished, 0.648248 sec.
# 190-th simulation finished, 0.670698 sec.
# 191-th simulation finished, 0.673809 sec.
# 192-th simulation finished, 0.639593 sec.
# 193-th simulation finished, 0.654425 sec.
# 194-th simulation finished, 0.647031 sec.
# 195-th simulation finished, 0.680521 sec.
# 196-th simulation finished, 0.730243 sec.
# 197-th simulation finished, 0.757517 sec.
# 198-th simulation finished, 0.649039 sec.
# 199-th simulation finished, 0.654984 sec.
# 200-th simulation finished, 0.679836 sec.

# %%
plt.plot(Y_sim.T)
plt.show()

# %% [markdown]
# ## plots

# %%
plt.hist(ssim_eps)
# Out:
# (array([ 1.,  8., 16., 32., 42., 48., 35., 14.,  3.,  1.]),
#  array([111.58344055, 116.68924422, 121.79504788, 126.90085155,
#         132.00665522, 137.11245889, 142.21826256, 147.32406623,
#         152.4298699 , 157.53567357, 162.64147724]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(msim_0)
# Out:
# (array([ 5.,  9., 28., 40., 42., 30., 30.,  9.,  3.,  4.]),
#  array([15.10942229, 15.75214343, 16.39486458, 17.03758572, 17.68030686,
#         18.323028  , 18.96574915, 19.60847029, 20.25119143, 20.89391257,
#         21.53663372]),
#  <BarContainer object of 10 artists>)

# %%
plt.scatter(bsim[:,0],bsim[:,1], s=2)
plt.axhline(y=beta[1], color='red')
plt.axvline(x=beta[0], color='red')

# %%
np.cov(bsim.T)
# Out:
# array([[ 0.00030027, -0.00040185],
#        [-0.00040185,  0.00076107]])
