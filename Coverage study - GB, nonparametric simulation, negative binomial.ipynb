# %%
import os, importlib, sys, time

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import scipy.linalg as la
import scipy.stats as stats

# %%
locals().update(np.load("result_nonparametric_negative_binomial.npz"))

# %% [markdown]
# # 1. Parameters

# %%
num_sim = 927
T = Ys_sim.shape[1]

# %%
T0 = 20
alpha = 1
K = 6.5

# %%
# g
plt.plot(g)

# %%
# pi
plt.plot(pi)

# %%
# A
d = A.shape[1]

# %%
plt.plot(A)
# Out:
# [<matplotlib.lines.Line2D at 0x17c3c78e0>,
#  <matplotlib.lines.Line2D at 0x17c3c79a0>]

# %% [markdown]
# # 3. coverage by Fisher Information Matrix

# %%
def NBLL(y, m, r):
    y = int(y)
    return (np.sum(np.log(1+(r-1)/(np.arange(y)+1))) 
            + r * np.log(r/(r+m)) 
            + y * np.log(m/(r+m)))

# %%
def dNBLLdr(y, m, r):
    y = int(y)
    return (np.sum(1/(np.arange(y)+r)) + np.log(r/(r+m)) + (m-y)/(r+m))

# %%
def d2NBLLdr2(y, m, r):
    y = int(y)
    return (-np.sum(1/(np.arange(y)+r)**2) + 1/r + 1/(r+m) - (m-y)/(r+m)**2)

# %% [markdown]
# # 4. Wald's Confidence Region coverage test

# %%
Ihs_dth = np.zeros([num_sim, 2+d, 2+d])
Ts_dth = np.zeros(num_sim)
ps_dth = np.zeros(num_sim)

# %%
for iter_sim in np.arange(num_sim):
    start_sim = time.time()
    
    rhat = rsim[iter_sim,-1]
    mhat_0 = msim_0[iter_sim,-1]
    bhat = bsim[iter_sim,-1,:]
    Y_data = Ys_sim[iter_sim]
    
    Rhat = np.zeros(T+T0)
    d1Rh = np.zeros([d, T+T0])
    d2Rh = np.zeros([d, d, T+T0])
    
    for t in np.arange(T+T0):
        o = np.exp(bhat @ A[t])
        p = 1 / (1 + o)
        q = o / (1 + o)

        Rhat[t] = K * p
        d1Rh[:,t] = - K * p * q * A[t]
        d2Rh[:,:,t] = K * p * q * (q - p) * (A[t,:,None] * A[t])
        
    Pi = alpha * np.concatenate([[0],pi])[np.maximum(0, T0 + np.arange(T)[:,None] - np.arange(T+T0))]
    G = Rhat[:,None] * np.concatenate([[0],g])[np.maximum(0, np.arange(T+T0)[:,None] - np.arange(T+T0))]
    d1G = d1Rh[:,:,None] * np.concatenate([[0],g])[
            np.maximum(0, np.arange(T+T0)[:,None] - np.arange(T+T0))]
    d2G = d2Rh[...,None] * np.concatenate([[0],g])[
            np.maximum(0, np.arange(T+T0)[:,None] - np.arange(T+T0))]
    
    inv_ImG = la.inv(np.eye(T+T0)-G)
    Pi_inv_ImG = Pi @ inv_ImG
    
    EY = mhat_0 * Pi_inv_ImG[:,0]
    d1EY = mhat_0 * (Pi_inv_ImG @ (d1G @ inv_ImG[:,:1]))[...,0]
    d2EY = mhat_0 * (Pi_inv_ImG @ (
        d1G[:,None] @ inv_ImG @ d1G @ inv_ImG[:,:1]
        + d1G @ inv_ImG @ d1G[:,None] @ inv_ImG[:,:1]
        + d2G @ inv_ImG[:,:1]))[...,0]

    dldEY = Y_data/EY - (rhat+Y_data)/(rhat+EY)
    d2ldEY2 = - Y_data/EY**2 + (rhat+Y_data)/(rhat+EY)**2
    d2ldrdEY = - 1/(rhat+EY) + (rhat+Y_data)/(rhat+EY)**2

    d2ldr2 = np.sum([d2NBLLdr2(y, m, rhat) for y, m in zip(Y_data, EY)])
    d2ldm2 = np.sum(d2ldEY2 * Pi_inv_ImG[:,0]**2)
    d2ldb2 = np.sum(d2ldEY2 * d1EY * d1EY[:,None,:], 2) \
           + np.sum(dldEY * d2EY, 2)

    d2ldrdm = np.sum(d2ldrdEY * Pi_inv_ImG[:,0])
    d2ldrdb = np.sum(d2ldrdEY * d1EY, 1)
    d2ldmdb = np.sum(d2ldEY2 * Pi_inv_ImG[:,0] * d1EY, 1) \
            + np.sum(dldEY * (Pi_inv_ImG @ (d1G @ inv_ImG[:,:1]))[...,0], 1)

    d2ldrm2 = np.array([[d2ldr2, d2ldrdm],
                        [d2ldrdm, d2ldm2]])
    d2ldrmdb = np.stack([d2ldrdb, 
                         d2ldmdb])

    Ihs_dth[iter_sim] = - np.block([[d2ldrm2, d2ldrmdb],
                                    [d2ldrmdb.T, d2ldb2]])
    Ts_dth[iter_sim] = (bhat[1]-bmle[1])/np.sqrt(la.inv(Ihs_dth[iter_sim])[-1,-1])
    ps_dth[iter_sim] = 2*(1-stats.norm.cdf(np.abs(Ts_dth[iter_sim])))
    
    sys.__stdout__.write("%d-th simulation finished, %f sec.\n"
                         %(iter_sim+1, time.time()-start_sim))
    sys.__stdout__.flush()
# Out:
# 1-th simulation finished, 0.015052 sec.
# 2-th simulation finished, 0.030363 sec.
# 3-th simulation finished, 0.006897 sec.
# 4-th simulation finished, 0.005022 sec.
# 5-th simulation finished, 0.004817 sec.
# 6-th simulation finished, 0.003355 sec.
# 7-th simulation finished, 0.006888 sec.
# 8-th simulation finished, 0.005891 sec.
# 9-th simulation finished, 0.005325 sec.
# 10-th simulation finished, 0.010365 sec.
# 11-th simulation finished, 0.006928 sec.
# 12-th simulation finished, 0.007422 sec.
# 13-th simulation finished, 0.006995 sec.
# 14-th simulation finished, 0.005769 sec.
# 15-th simulation finished, 0.005465 sec.
# 16-th simulation finished, 0.006831 sec.
# 17-th simulation finished, 0.003867 sec.
# 18-th simulation finished, 0.005840 sec.
# 19-th simulation finished, 0.007084 sec.
# 20-th simulation finished, 0.004331 sec.
# 21-th simulation finished, 0.005526 sec.
# 22-th simulation finished, 0.017149 sec.
# 23-th simulation finished, 0.013431 sec.
# 24-th simulation finished, 0.007478 sec.
# 25-th simulation finished, 0.008352 sec.
# 26-th simulation finished, 0.005702 sec.
# 27-th simulation finished, 0.013468 sec.
# 28-th simulation finished, 0.008839 sec.
# 29-th simulation finished, 0.072669 sec.
# 30-th simulation finished, 0.005995 sec.
# 31-th simulation finished, 0.005341 sec.
# 32-th simulation finished, 0.005445 sec.
# 33-th simulation finished, 0.005005 sec.
# 34-th simulation finished, 0.005399 sec.
# 35-th simulation finished, 0.005059 sec.
# 36-th simulation finished, 0.005586 sec.
# 37-th simulation finished, 0.007965 sec.
# 38-th simulation finished, 0.005529 sec.
# 39-th simulation finished, 0.005854 sec.
# 40-th simulation finished, 0.003507 sec.
# 41-th simulation finished, 0.009758 sec.
# 42-th simulation finished, 0.068660 sec.
# 43-th simulation finished, 0.004042 sec.
# 44-th simulation finished, 0.009337 sec.
# 45-th simulation finished, 0.014790 sec.
# 46-th simulation finished, 0.014835 sec.
# 47-th simulation finished, 0.014825 sec.
# 48-th simulation finished, 0.034139 sec.
# 49-th simulation finished, 0.006430 sec.
# 50-th simulation finished, 0.005914 sec.
# 51-th simulation finished, 0.005926 sec.
# 52-th simulation finished, 0.005998 sec.
# 53-th simulation finished, 0.006145 sec.
# 54-th simulation finished, 0.006018 sec.
# 55-th simulation finished, 0.011978 sec.
# 56-th simulation finished, 0.005651 sec.
# 57-th simulation finished, 0.003901 sec.
# 58-th simulation finished, 0.004864 sec.
# 59-th simulation finished, 0.003773 sec.
# 60-th simulation finished, 0.005994 sec.
# 61-th simulation finished, 0.004342 sec.
# 62-th simulation finished, 0.006711 sec.
# 63-th simulation finished, 0.005443 sec.
# 64-th simulation finished, 0.007460 sec.
# 65-th simulation finished, 0.005794 sec.
# 66-th simulation finished, 0.052615 sec.
# 67-th simulation finished, 0.007748 sec.
# 68-th simulation finished, 0.036728 sec.
# 69-th simulation finished, 0.034421 sec.
# 70-th simulation finished, 0.010591 sec.
# 71-th simulation finished, 0.007540 sec.
# 72-th simulation finished, 0.006156 sec.
# 73-th simulation finished, 0.005577 sec.
# 74-th simulation finished, 0.005736 sec.
# 75-th simulation finished, 0.013415 sec.
# 76-th simulation finished, 0.005416 sec.
# 77-th simulation finished, 0.007467 sec.
# 78-th simulation finished, 0.005866 sec.
# 79-th simulation finished, 0.005670 sec.
# 80-th simulation finished, 0.005670 sec.
# 81-th simulation finished, 0.006740 sec.
# 82-th simulation finished, 0.006678 sec.
# 83-th simulation finished, 0.007406 sec.
# 84-th simulation finished, 0.005506 sec.
# 85-th simulation finished, 0.005426 sec.
# 86-th simulation finished, 0.005414 sec.
# 87-th simulation finished, 0.038796 sec.
# 88-th simulation finished, 0.006917 sec.
# 89-th simulation finished, 0.005895 sec.
# 90-th simulation finished, 0.007506 sec.
# 91-th simulation finished, 0.010030 sec.
# 92-th simulation finished, 0.009201 sec.
# 93-th simulation finished, 0.030926 sec.
# 94-th simulation finished, 0.007721 sec.
# 95-th simulation finished, 0.014754 sec.
# 96-th simulation finished, 0.010656 sec.
# 97-th simulation finished, 0.006334 sec.
# 98-th simulation finished, 0.006739 sec.
# 99-th simulation finished, 0.009803 sec.
# 100-th simulation finished, 0.006016 sec.
# 101-th simulation finished, 0.005039 sec.
# 102-th simulation finished, 0.007292 sec.
# 103-th simulation finished, 0.007177 sec.
# 104-th simulation finished, 0.005749 sec.
# 105-th simulation finished, 0.005393 sec.
# 106-th simulation finished, 0.008112 sec.
# 107-th simulation finished, 0.011778 sec.
# 108-th simulation finished, 0.005880 sec.
# 109-th simulation finished, 0.011108 sec.
# 110-th simulation finished, 0.005551 sec.
# 111-th simulation finished, 0.021688 sec.
# 112-th simulation finished, 0.017937 sec.
# 113-th simulation finished, 0.011591 sec.
# 114-th simulation finished, 0.007376 sec.
# 115-th simulation finished, 0.008817 sec.
# 116-th simulation finished, 0.009518 sec.
# 117-th simulation finished, 0.006276 sec.
# 118-th simulation finished, 0.006494 sec.
# 119-th simulation finished, 0.006600 sec.
# 120-th simulation finished, 0.004455 sec.
# 121-th simulation finished, 0.006832 sec.
# 122-th simulation finished, 0.005605 sec.
# 123-th simulation finished, 0.005192 sec.
# 124-th simulation finished, 0.032287 sec.
# 125-th simulation finished, 0.009998 sec.
# 126-th simulation finished, 0.009742 sec.
# 127-th simulation finished, 0.006799 sec.
# 128-th simulation finished, 0.007475 sec.
# 129-th simulation finished, 0.016489 sec.
# 130-th simulation finished, 0.005930 sec.
# 131-th simulation finished, 0.006164 sec.
# 132-th simulation finished, 0.004296 sec.
# 133-th simulation finished, 0.007104 sec.
# 134-th simulation finished, 0.007156 sec.
# 135-th simulation finished, 0.007191 sec.
# 136-th simulation finished, 0.015154 sec.
# 137-th simulation finished, 0.005909 sec.
# 138-th simulation finished, 0.004961 sec.
# 139-th simulation finished, 0.006495 sec.
# 140-th simulation finished, 0.006558 sec.
# 141-th simulation finished, 0.007995 sec.
# 142-th simulation finished, 0.013278 sec.
# 143-th simulation finished, 0.013062 sec.
# 144-th simulation finished, 0.013929 sec.
# 145-th simulation finished, 0.011854 sec.
# 146-th simulation finished, 0.005680 sec.
# 147-th simulation finished, 0.006113 sec.
# 148-th simulation finished, 0.011559 sec.
# 149-th simulation finished, 0.015524 sec.
# 150-th simulation finished, 0.012761 sec.
# 151-th simulation finished, 0.015107 sec.
# 152-th simulation finished, 0.008375 sec.
# 153-th simulation finished, 0.005972 sec.
# 154-th simulation finished, 0.011379 sec.
# 155-th simulation finished, 0.003122 sec.
# 156-th simulation finished, 0.006165 sec.
# 157-th simulation finished, 0.006184 sec.
# 158-th simulation finished, 0.006665 sec.
# 159-th simulation finished, 0.012638 sec.
# 160-th simulation finished, 0.006893 sec.
# 161-th simulation finished, 0.007456 sec.
# 162-th simulation finished, 0.005745 sec.
# 163-th simulation finished, 0.009016 sec.
# 164-th simulation finished, 0.007660 sec.
# 165-th simulation finished, 0.005700 sec.
# 166-th simulation finished, 0.007432 sec.
# 167-th simulation finished, 0.005676 sec.
# 168-th simulation finished, 0.005867 sec.
# 169-th simulation finished, 0.008594 sec.
# 170-th simulation finished, 0.006672 sec.
# 171-th simulation finished, 0.005474 sec.
# 172-th simulation finished, 0.005481 sec.
# 173-th simulation finished, 0.007870 sec.
# 174-th simulation finished, 0.005640 sec.
# 175-th simulation finished, 0.004899 sec.
# 176-th simulation finished, 0.003012 sec.
# 177-th simulation finished, 0.006354 sec.
# 178-th simulation finished, 0.006444 sec.
# 179-th simulation finished, 0.005493 sec.
# 180-th simulation finished, 0.005573 sec.
# 181-th simulation finished, 0.007457 sec.
# 182-th simulation finished, 0.007967 sec.
# 183-th simulation finished, 0.015083 sec.
# 184-th simulation finished, 0.003519 sec.
# 185-th simulation finished, 0.014230 sec.
# 186-th simulation finished, 0.013616 sec.
# 187-th simulation finished, 0.007588 sec.
# 188-th simulation finished, 0.032402 sec.
# 189-th simulation finished, 0.008366 sec.
# 190-th simulation finished, 0.011309 sec.
# 191-th simulation finished, 0.003533 sec.
# 192-th simulation finished, 0.009540 sec.
# 193-th simulation finished, 0.009360 sec.
# 194-th simulation finished, 0.012403 sec.
# 195-th simulation finished, 0.006357 sec.
# 196-th simulation finished, 0.008298 sec.
# 197-th simulation finished, 0.007126 sec.
# 198-th simulation finished, 0.005784 sec.
# 199-th simulation finished, 0.006315 sec.
# 200-th simulation finished, 0.005919 sec.
# 201-th simulation finished, 0.006479 sec.
# 202-th simulation finished, 0.005561 sec.
# 203-th simulation finished, 0.014191 sec.
# 204-th simulation finished, 0.005768 sec.
# 205-th simulation finished, 0.004513 sec.
# 206-th simulation finished, 0.005881 sec.
# 207-th simulation finished, 0.005035 sec.
# 208-th simulation finished, 0.005894 sec.
# 209-th simulation finished, 0.006417 sec.
# 210-th simulation finished, 0.034522 sec.
# 211-th simulation finished, 0.006643 sec.
# 212-th simulation finished, 0.012527 sec.
# 213-th simulation finished, 0.010837 sec.
# 214-th simulation finished, 0.004741 sec.
# 215-th simulation finished, 0.003720 sec.
# 216-th simulation finished, 0.006749 sec.
# 217-th simulation finished, 0.011568 sec.
# 218-th simulation finished, 0.006025 sec.
# 219-th simulation finished, 0.005429 sec.
# 220-th simulation finished, 0.005339 sec.
# 221-th simulation finished, 0.006072 sec.
# 222-th simulation finished, 0.008276 sec.
# 223-th simulation finished, 0.004542 sec.
# 224-th simulation finished, 0.005611 sec.
# 225-th simulation finished, 0.005711 sec.
# 226-th simulation finished, 0.005742 sec.
# 227-th simulation finished, 0.004680 sec.
# 228-th simulation finished, 0.007527 sec.
# 229-th simulation finished, 0.014521 sec.
# 230-th simulation finished, 0.011354 sec.
# 231-th simulation finished, 0.039854 sec.
# 232-th simulation finished, 0.009050 sec.
# 233-th simulation finished, 0.005980 sec.
# 234-th simulation finished, 0.006147 sec.
# 235-th simulation finished, 0.027043 sec.
# 236-th simulation finished, 0.008630 sec.
# 237-th simulation finished, 0.007558 sec.
# 238-th simulation finished, 0.006417 sec.
# 239-th simulation finished, 0.006005 sec.
# 240-th simulation finished, 0.006732 sec.
# 241-th simulation finished, 0.025197 sec.
# 242-th simulation finished, 0.007406 sec.
# 243-th simulation finished, 0.008838 sec.
# 244-th simulation finished, 0.008768 sec.
# 245-th simulation finished, 0.014669 sec.
# 246-th simulation finished, 0.012593 sec.
# 247-th simulation finished, 0.008084 sec.
# 248-th simulation finished, 0.008197 sec.
# 249-th simulation finished, 0.005351 sec.
# 250-th simulation finished, 0.010582 sec.
# 251-th simulation finished, 0.008803 sec.
# 252-th simulation finished, 0.011264 sec.
# 253-th simulation finished, 0.006238 sec.
# 254-th simulation finished, 0.008668 sec.
# 255-th simulation finished, 0.015178 sec.
# 256-th simulation finished, 0.008336 sec.
# 257-th simulation finished, 0.011255 sec.
# 258-th simulation finished, 0.008287 sec.
# 259-th simulation finished, 0.006414 sec.
# 260-th simulation finished, 0.009637 sec.
# 261-th simulation finished, 0.012070 sec.
# 262-th simulation finished, 0.012358 sec.
# 263-th simulation finished, 0.003087 sec.
# 264-th simulation finished, 0.007424 sec.
# 265-th simulation finished, 0.004116 sec.
# 266-th simulation finished, 0.007829 sec.
# 267-th simulation finished, 0.005814 sec.
# 268-th simulation finished, 0.005206 sec.
# 269-th simulation finished, 0.005425 sec.
# 270-th simulation finished, 0.006572 sec.
# 271-th simulation finished, 0.006114 sec.
# 272-th simulation finished, 0.005537 sec.
# 273-th simulation finished, 0.005920 sec.
# 274-th simulation finished, 0.005646 sec.
# 275-th simulation finished, 0.006187 sec.
# 276-th simulation finished, 0.006477 sec.
# 277-th simulation finished, 0.005590 sec.
# 278-th simulation finished, 0.004611 sec.
# 279-th simulation finished, 0.007122 sec.
# 280-th simulation finished, 0.006312 sec.
# 281-th simulation finished, 0.004490 sec.
# 282-th simulation finished, 0.004841 sec.
# 283-th simulation finished, 0.005709 sec.
# 284-th simulation finished, 0.006720 sec.
# 285-th simulation finished, 0.005548 sec.
# 286-th simulation finished, 0.013698 sec.
# 287-th simulation finished, 0.008180 sec.
# 288-th simulation finished, 0.006808 sec.
# 289-th simulation finished, 0.009301 sec.
# 290-th simulation finished, 0.006199 sec.
# 291-th simulation finished, 0.007976 sec.
# 292-th simulation finished, 0.006002 sec.
# 293-th simulation finished, 0.006411 sec.
# 294-th simulation finished, 0.004513 sec.
# 295-th simulation finished, 0.003339 sec.
# 296-th simulation finished, 0.005458 sec.
# 297-th simulation finished, 0.005613 sec.
# 298-th simulation finished, 0.009058 sec.
# 299-th simulation finished, 0.004465 sec.
# 300-th simulation finished, 0.006207 sec.
# 301-th simulation finished, 0.009504 sec.
# 302-th simulation finished, 0.003543 sec.
# 303-th simulation finished, 0.006145 sec.
# 304-th simulation finished, 0.006101 sec.
# 305-th simulation finished, 0.025644 sec.
# 306-th simulation finished, 0.003618 sec.
# 307-th simulation finished, 0.005673 sec.
# 308-th simulation finished, 0.005631 sec.
# 309-th simulation finished, 0.005760 sec.
# 310-th simulation finished, 0.009383 sec.
# 311-th simulation finished, 0.008156 sec.
# 312-th simulation finished, 0.007363 sec.
# 313-th simulation finished, 0.010936 sec.
# 314-th simulation finished, 0.007425 sec.
# 315-th simulation finished, 0.050494 sec.
# 316-th simulation finished, 0.034277 sec.
# 317-th simulation finished, 0.039965 sec.
# 318-th simulation finished, 0.015952 sec.
# 319-th simulation finished, 0.022436 sec.
# 320-th simulation finished, 0.039579 sec.
# 321-th simulation finished, 0.024123 sec.
# 322-th simulation finished, 0.006161 sec.
# 323-th simulation finished, 0.034171 sec.
# 324-th simulation finished, 0.004045 sec.
# 325-th simulation finished, 0.006716 sec.
# 326-th simulation finished, 0.007276 sec.
# 327-th simulation finished, 0.005436 sec.
# 328-th simulation finished, 0.006744 sec.
# 329-th simulation finished, 0.003060 sec.
# 330-th simulation finished, 0.005974 sec.
# 331-th simulation finished, 0.006279 sec.
# 332-th simulation finished, 0.003988 sec.
# 333-th simulation finished, 0.003317 sec.
# 334-th simulation finished, 0.003000 sec.
# 335-th simulation finished, 0.005720 sec.
# 336-th simulation finished, 0.011397 sec.
# 337-th simulation finished, 0.006896 sec.
# 338-th simulation finished, 0.006011 sec.
# 339-th simulation finished, 0.006613 sec.
# 340-th simulation finished, 0.006005 sec.
# 341-th simulation finished, 0.005663 sec.
# 342-th simulation finished, 0.005128 sec.
# 343-th simulation finished, 0.005558 sec.
# 344-th simulation finished, 0.003348 sec.
# 345-th simulation finished, 0.003716 sec.
# 346-th simulation finished, 0.007001 sec.
# 347-th simulation finished, 0.005926 sec.
# 348-th simulation finished, 0.005778 sec.
# 349-th simulation finished, 0.006160 sec.
# 350-th simulation finished, 0.008608 sec.
# 351-th simulation finished, 0.017477 sec.
# 352-th simulation finished, 0.008115 sec.
# 353-th simulation finished, 0.019675 sec.
# 354-th simulation finished, 0.008517 sec.
# 355-th simulation finished, 0.006704 sec.
# 356-th simulation finished, 0.008903 sec.
# 357-th simulation finished, 0.010264 sec.
# 358-th simulation finished, 0.011236 sec.
# 359-th simulation finished, 0.008443 sec.
# 360-th simulation finished, 0.005300 sec.
# 361-th simulation finished, 0.006149 sec.
# 362-th simulation finished, 0.006223 sec.
# 363-th simulation finished, 0.006745 sec.
# 364-th simulation finished, 0.004693 sec.
# 365-th simulation finished, 0.006824 sec.
# 366-th simulation finished, 0.006083 sec.
# 367-th simulation finished, 0.006740 sec.
# 368-th simulation finished, 0.005409 sec.
# 369-th simulation finished, 0.007930 sec.
# 370-th simulation finished, 0.006667 sec.
# 371-th simulation finished, 0.006628 sec.
# 372-th simulation finished, 0.005654 sec.
# 373-th simulation finished, 0.005813 sec.
# 374-th simulation finished, 0.005260 sec.
# 375-th simulation finished, 0.006037 sec.
# 376-th simulation finished, 0.007074 sec.
# 377-th simulation finished, 0.006367 sec.
# 378-th simulation finished, 0.005404 sec.
# 379-th simulation finished, 0.013260 sec.
# 380-th simulation finished, 0.009374 sec.
# 381-th simulation finished, 0.005627 sec.
# 382-th simulation finished, 0.014075 sec.
# 383-th simulation finished, 0.007449 sec.
# 384-th simulation finished, 0.005904 sec.
# 385-th simulation finished, 0.007925 sec.
# 386-th simulation finished, 0.009687 sec.
# 387-th simulation finished, 0.009936 sec.
# 388-th simulation finished, 0.005592 sec.
# 389-th simulation finished, 0.011998 sec.
# 390-th simulation finished, 0.024364 sec.
# 391-th simulation finished, 0.010194 sec.
# 392-th simulation finished, 0.011578 sec.
# 393-th simulation finished, 0.010121 sec.
# 394-th simulation finished, 0.006327 sec.
# 395-th simulation finished, 0.007744 sec.
# 396-th simulation finished, 0.009077 sec.
# 397-th simulation finished, 0.004180 sec.
# 398-th simulation finished, 0.006765 sec.
# 399-th simulation finished, 0.004972 sec.
# 400-th simulation finished, 0.005910 sec.
# 401-th simulation finished, 0.007183 sec.
# 402-th simulation finished, 0.007572 sec.
# 403-th simulation finished, 0.012322 sec.
# 404-th simulation finished, 0.008005 sec.
# 405-th simulation finished, 0.005869 sec.
# 406-th simulation finished, 0.007252 sec.
# 407-th simulation finished, 0.007803 sec.
# 408-th simulation finished, 0.006765 sec.
# 409-th simulation finished, 0.006387 sec.
# 410-th simulation finished, 0.005438 sec.
# 411-th simulation finished, 0.005995 sec.
# 412-th simulation finished, 0.006861 sec.
# 413-th simulation finished, 0.005812 sec.
# 414-th simulation finished, 0.006808 sec.
# 415-th simulation finished, 0.005376 sec.
# 416-th simulation finished, 0.003143 sec.
# 417-th simulation finished, 0.005553 sec.
# 418-th simulation finished, 0.005690 sec.
# 419-th simulation finished, 0.005997 sec.
# 420-th simulation finished, 0.005487 sec.
# 421-th simulation finished, 0.006120 sec.
# 422-th simulation finished, 0.004618 sec.
# 423-th simulation finished, 0.005565 sec.
# 424-th simulation finished, 0.007211 sec.
# 425-th simulation finished, 0.007180 sec.
# 426-th simulation finished, 0.005734 sec.
# 427-th simulation finished, 0.006390 sec.
# 428-th simulation finished, 0.004554 sec.
# 429-th simulation finished, 0.004639 sec.
# 430-th simulation finished, 0.007408 sec.
# 431-th simulation finished, 0.006958 sec.
# 432-th simulation finished, 0.020712 sec.
# 433-th simulation finished, 0.015275 sec.
# 434-th simulation finished, 0.009061 sec.
# 435-th simulation finished, 0.007502 sec.
# 436-th simulation finished, 0.005952 sec.
# 437-th simulation finished, 0.006010 sec.
# 438-th simulation finished, 0.006196 sec.
# 439-th simulation finished, 0.005896 sec.
# 440-th simulation finished, 0.007053 sec.
# 441-th simulation finished, 0.014247 sec.
# 442-th simulation finished, 0.006129 sec.
# 443-th simulation finished, 0.006472 sec.
# 444-th simulation finished, 0.004498 sec.
# 445-th simulation finished, 0.005835 sec.
# 446-th simulation finished, 0.005886 sec.
# 447-th simulation finished, 0.005219 sec.
# 448-th simulation finished, 0.004398 sec.
# 449-th simulation finished, 0.003362 sec.
# 450-th simulation finished, 0.006711 sec.
# 451-th simulation finished, 0.004741 sec.
# 452-th simulation finished, 0.005572 sec.
# 453-th simulation finished, 0.010750 sec.
# 454-th simulation finished, 0.007095 sec.
# 455-th simulation finished, 0.006132 sec.
# 456-th simulation finished, 0.005914 sec.
# 457-th simulation finished, 0.005436 sec.
# 458-th simulation finished, 0.005653 sec.
# 459-th simulation finished, 0.005266 sec.
# 460-th simulation finished, 0.004516 sec.
# 461-th simulation finished, 0.005722 sec.
# 462-th simulation finished, 0.005122 sec.
# 463-th simulation finished, 0.004582 sec.
# 464-th simulation finished, 0.005912 sec.
# 465-th simulation finished, 0.005650 sec.
# 466-th simulation finished, 0.015997 sec.
# 467-th simulation finished, 0.008973 sec.
# 468-th simulation finished, 0.007596 sec.
# 469-th simulation finished, 0.008453 sec.
# 470-th simulation finished, 0.005465 sec.
# 471-th simulation finished, 0.012028 sec.
# 472-th simulation finished, 0.014133 sec.
# 473-th simulation finished, 0.009701 sec.
# 474-th simulation finished, 0.005671 sec.
# 475-th simulation finished, 0.013604 sec.
# 476-th simulation finished, 0.007831 sec.
# 477-th simulation finished, 0.005650 sec.
# 478-th simulation finished, 0.012791 sec.
# 479-th simulation finished, 0.016524 sec.
# 480-th simulation finished, 0.006411 sec.
# 481-th simulation finished, 0.009220 sec.
# 482-th simulation finished, 0.011674 sec.
# 483-th simulation finished, 0.010067 sec.
# 484-th simulation finished, 0.015521 sec.
# 485-th simulation finished, 0.012564 sec.
# 486-th simulation finished, 0.010332 sec.
# 487-th simulation finished, 0.020520 sec.
# 488-th simulation finished, 0.006692 sec.
# 489-th simulation finished, 0.012721 sec.
# 490-th simulation finished, 0.012605 sec.
# 491-th simulation finished, 0.005606 sec.
# 492-th simulation finished, 0.005575 sec.
# 493-th simulation finished, 0.007290 sec.
# 494-th simulation finished, 0.003126 sec.
# 495-th simulation finished, 0.003010 sec.
# 496-th simulation finished, 0.002878 sec.
# 497-th simulation finished, 0.003872 sec.
# 498-th simulation finished, 0.006729 sec.
# 499-th simulation finished, 0.005103 sec.
# 500-th simulation finished, 0.011142 sec.
# 501-th simulation finished, 0.005046 sec.
# 502-th simulation finished, 0.005548 sec.
# 503-th simulation finished, 0.006474 sec.
# 504-th simulation finished, 0.006424 sec.
# 505-th simulation finished, 0.005023 sec.
# 506-th simulation finished, 0.005706 sec.
# 507-th simulation finished, 0.006149 sec.
# 508-th simulation finished, 0.027297 sec.
# 509-th simulation finished, 0.010049 sec.
# 510-th simulation finished, 0.008833 sec.
# 511-th simulation finished, 0.006705 sec.
# 512-th simulation finished, 0.005690 sec.
# 513-th simulation finished, 0.019834 sec.
# 514-th simulation finished, 0.009980 sec.
# 515-th simulation finished, 0.007652 sec.
# 516-th simulation finished, 0.007355 sec.
# 517-th simulation finished, 0.011427 sec.
# 518-th simulation finished, 0.014837 sec.
# 519-th simulation finished, 0.008033 sec.
# 520-th simulation finished, 0.007665 sec.
# 521-th simulation finished, 0.008548 sec.
# 522-th simulation finished, 0.008022 sec.
# 523-th simulation finished, 0.008466 sec.
# 524-th simulation finished, 0.006067 sec.
# 525-th simulation finished, 0.006347 sec.
# 526-th simulation finished, 0.007113 sec.
# 527-th simulation finished, 0.003267 sec.
# 528-th simulation finished, 0.005700 sec.
# 529-th simulation finished, 0.005575 sec.
# 530-th simulation finished, 0.010808 sec.
# 531-th simulation finished, 0.005273 sec.
# 532-th simulation finished, 0.008573 sec.
# 533-th simulation finished, 0.006873 sec.
# 534-th simulation finished, 0.006390 sec.
# 535-th simulation finished, 0.007233 sec.
# 536-th simulation finished, 0.005951 sec.
# 537-th simulation finished, 0.006372 sec.
# 538-th simulation finished, 0.010236 sec.
# 539-th simulation finished, 0.007685 sec.
# 540-th simulation finished, 0.015122 sec.
# 541-th simulation finished, 0.016426 sec.
# 542-th simulation finished, 0.006424 sec.
# 543-th simulation finished, 0.006756 sec.
# 544-th simulation finished, 0.005843 sec.
# 545-th simulation finished, 0.009248 sec.
# 546-th simulation finished, 0.006201 sec.
# 547-th simulation finished, 0.007991 sec.
# 548-th simulation finished, 0.008310 sec.
# 549-th simulation finished, 0.005759 sec.
# 550-th simulation finished, 0.006403 sec.
# 551-th simulation finished, 0.006728 sec.
# 552-th simulation finished, 0.007480 sec.
# 553-th simulation finished, 0.009053 sec.
# 554-th simulation finished, 0.013344 sec.
# 555-th simulation finished, 0.033223 sec.
# 556-th simulation finished, 0.010244 sec.
# 557-th simulation finished, 0.008190 sec.
# 558-th simulation finished, 0.010582 sec.
# 559-th simulation finished, 0.005392 sec.
# 560-th simulation finished, 0.008798 sec.
# 561-th simulation finished, 0.013616 sec.
# 562-th simulation finished, 0.033209 sec.
# 563-th simulation finished, 0.014254 sec.
# 564-th simulation finished, 0.016656 sec.
# 565-th simulation finished, 0.003980 sec.
# 566-th simulation finished, 0.016379 sec.
# 567-th simulation finished, 0.005801 sec.
# 568-th simulation finished, 0.011712 sec.
# 569-th simulation finished, 0.006801 sec.
# 570-th simulation finished, 0.006516 sec.
# 571-th simulation finished, 0.005920 sec.
# 572-th simulation finished, 0.004784 sec.
# 573-th simulation finished, 0.005683 sec.
# 574-th simulation finished, 0.004936 sec.
# 575-th simulation finished, 0.006159 sec.
# 576-th simulation finished, 0.005162 sec.
# 577-th simulation finished, 0.005098 sec.
# 578-th simulation finished, 0.006015 sec.
# 579-th simulation finished, 0.006142 sec.
# 580-th simulation finished, 0.005531 sec.
# 581-th simulation finished, 0.018700 sec.
# 582-th simulation finished, 0.004119 sec.
# 583-th simulation finished, 0.004695 sec.
# 584-th simulation finished, 0.005644 sec.
# 585-th simulation finished, 0.007557 sec.
# 586-th simulation finished, 0.009851 sec.
# 587-th simulation finished, 0.008368 sec.
# 588-th simulation finished, 0.007668 sec.
# 589-th simulation finished, 0.004373 sec.
# 590-th simulation finished, 0.008998 sec.
# 591-th simulation finished, 0.006995 sec.
# 592-th simulation finished, 0.003047 sec.
# 593-th simulation finished, 0.008948 sec.
# 594-th simulation finished, 0.006789 sec.
# 595-th simulation finished, 0.007027 sec.
# 596-th simulation finished, 0.007694 sec.
# 597-th simulation finished, 0.010518 sec.
# 598-th simulation finished, 0.006098 sec.
# 599-th simulation finished, 0.013435 sec.
# 600-th simulation finished, 0.009106 sec.
# 601-th simulation finished, 0.010631 sec.
# 602-th simulation finished, 0.013838 sec.
# 603-th simulation finished, 0.006412 sec.
# 604-th simulation finished, 0.008518 sec.
# 605-th simulation finished, 0.007703 sec.
# 606-th simulation finished, 0.007939 sec.
# 607-th simulation finished, 0.009473 sec.
# 608-th simulation finished, 0.008870 sec.
# 609-th simulation finished, 0.003563 sec.
# 610-th simulation finished, 0.007330 sec.
# 611-th simulation finished, 0.011242 sec.
# 612-th simulation finished, 0.011430 sec.
# 613-th simulation finished, 0.009903 sec.
# 614-th simulation finished, 0.009590 sec.
# 615-th simulation finished, 0.008943 sec.
# 616-th simulation finished, 0.005574 sec.
# 617-th simulation finished, 0.011568 sec.
# 618-th simulation finished, 0.010741 sec.
# 619-th simulation finished, 0.011082 sec.
# 620-th simulation finished, 0.006280 sec.
# 621-th simulation finished, 0.007901 sec.
# 622-th simulation finished, 0.010471 sec.
# 623-th simulation finished, 0.009839 sec.
# 624-th simulation finished, 0.006724 sec.
# 625-th simulation finished, 0.009785 sec.
# 626-th simulation finished, 0.006538 sec.
# 627-th simulation finished, 0.006246 sec.
# 628-th simulation finished, 0.010334 sec.
# 629-th simulation finished, 0.010349 sec.
# 630-th simulation finished, 0.009684 sec.
# 631-th simulation finished, 0.008253 sec.
# 632-th simulation finished, 0.005461 sec.
# 633-th simulation finished, 0.006250 sec.
# 634-th simulation finished, 0.008227 sec.
# 635-th simulation finished, 0.011094 sec.
# 636-th simulation finished, 0.008356 sec.
# 637-th simulation finished, 0.008043 sec.
# 638-th simulation finished, 0.010278 sec.
# 639-th simulation finished, 0.007279 sec.
# 640-th simulation finished, 0.003456 sec.
# 641-th simulation finished, 0.010417 sec.
# 642-th simulation finished, 0.008649 sec.
# 643-th simulation finished, 0.006217 sec.
# 644-th simulation finished, 0.015877 sec.
# 645-th simulation finished, 0.005144 sec.
# 646-th simulation finished, 0.008641 sec.
# 647-th simulation finished, 0.006492 sec.
# 648-th simulation finished, 0.003035 sec.
# 649-th simulation finished, 0.007682 sec.
# 650-th simulation finished, 0.006940 sec.
# 651-th simulation finished, 0.006408 sec.
# 652-th simulation finished, 0.004591 sec.
# 653-th simulation finished, 0.004013 sec.
# 654-th simulation finished, 0.006593 sec.
# 655-th simulation finished, 0.004952 sec.
# 656-th simulation finished, 0.003844 sec.
# 657-th simulation finished, 0.005753 sec.
# 658-th simulation finished, 0.004961 sec.
# 659-th simulation finished, 0.002933 sec.
# 660-th simulation finished, 0.004484 sec.
# 661-th simulation finished, 0.005806 sec.
# 662-th simulation finished, 0.004465 sec.
# 663-th simulation finished, 0.005432 sec.
# 664-th simulation finished, 0.006561 sec.
# 665-th simulation finished, 0.007778 sec.
# 666-th simulation finished, 0.006259 sec.
# 667-th simulation finished, 0.007674 sec.
# 668-th simulation finished, 0.006404 sec.
# 669-th simulation finished, 0.005880 sec.
# 670-th simulation finished, 0.009733 sec.
# 671-th simulation finished, 0.010781 sec.
# 672-th simulation finished, 0.005698 sec.
# 673-th simulation finished, 0.005634 sec.
# 674-th simulation finished, 0.006640 sec.
# 675-th simulation finished, 0.008545 sec.
# 676-th simulation finished, 0.008600 sec.
# 677-th simulation finished, 0.003098 sec.
# 678-th simulation finished, 0.005879 sec.
# 679-th simulation finished, 0.006066 sec.
# 680-th simulation finished, 0.005314 sec.
# 681-th simulation finished, 0.005934 sec.
# 682-th simulation finished, 0.005763 sec.
# 683-th simulation finished, 0.006782 sec.
# 684-th simulation finished, 0.004252 sec.
# 685-th simulation finished, 0.004807 sec.
# 686-th simulation finished, 0.008181 sec.
# 687-th simulation finished, 0.006380 sec.
# 688-th simulation finished, 0.008551 sec.
# 689-th simulation finished, 0.011164 sec.
# 690-th simulation finished, 0.007621 sec.
# 691-th simulation finished, 0.009781 sec.
# 692-th simulation finished, 0.010941 sec.
# 693-th simulation finished, 0.006675 sec.
# 694-th simulation finished, 0.007084 sec.
# 695-th simulation finished, 0.015578 sec.
# 696-th simulation finished, 0.008069 sec.
# 697-th simulation finished, 0.014375 sec.
# 698-th simulation finished, 0.008230 sec.
# 699-th simulation finished, 0.007103 sec.
# 700-th simulation finished, 0.010665 sec.
# 701-th simulation finished, 0.013172 sec.
# 702-th simulation finished, 0.008097 sec.
# 703-th simulation finished, 0.008067 sec.
# 704-th simulation finished, 0.006846 sec.
# 705-th simulation finished, 0.005467 sec.
# 706-th simulation finished, 0.004163 sec.
# 707-th simulation finished, 0.006668 sec.
# 708-th simulation finished, 0.006797 sec.
# 709-th simulation finished, 0.003765 sec.
# 710-th simulation finished, 0.006184 sec.
# 711-th simulation finished, 0.008029 sec.
# 712-th simulation finished, 0.005690 sec.
# 713-th simulation finished, 0.007573 sec.
# 714-th simulation finished, 0.005812 sec.
# 715-th simulation finished, 0.005691 sec.
# 716-th simulation finished, 0.005859 sec.
# 717-th simulation finished, 0.007226 sec.
# 718-th simulation finished, 0.005549 sec.
# 719-th simulation finished, 0.004763 sec.
# 720-th simulation finished, 0.005539 sec.
# 721-th simulation finished, 0.006178 sec.
# 722-th simulation finished, 0.009359 sec.
# 723-th simulation finished, 0.006221 sec.
# 724-th simulation finished, 0.007014 sec.
# 725-th simulation finished, 0.008230 sec.
# 726-th simulation finished, 0.006356 sec.
# 727-th simulation finished, 0.008501 sec.
# 728-th simulation finished, 0.009677 sec.
# 729-th simulation finished, 0.012840 sec.
# 730-th simulation finished, 0.015704 sec.
# 731-th simulation finished, 0.014212 sec.
# 732-th simulation finished, 0.009174 sec.
# 733-th simulation finished, 0.004189 sec.
# 734-th simulation finished, 0.005901 sec.
# 735-th simulation finished, 0.011716 sec.
# 736-th simulation finished, 0.008088 sec.
# 737-th simulation finished, 0.012041 sec.
# 738-th simulation finished, 0.007301 sec.
# 739-th simulation finished, 0.006127 sec.
# 740-th simulation finished, 0.010416 sec.
# 741-th simulation finished, 0.008075 sec.
# 742-th simulation finished, 0.010216 sec.
# 743-th simulation finished, 0.009081 sec.
# 744-th simulation finished, 0.009648 sec.
# 745-th simulation finished, 0.017505 sec.
# 746-th simulation finished, 0.014546 sec.
# 747-th simulation finished, 0.006569 sec.
# 748-th simulation finished, 0.017599 sec.
# 749-th simulation finished, 0.011795 sec.
# 750-th simulation finished, 0.005899 sec.
# 751-th simulation finished, 0.007538 sec.
# 752-th simulation finished, 0.005716 sec.
# 753-th simulation finished, 0.009140 sec.
# 754-th simulation finished, 0.015070 sec.
# 755-th simulation finished, 0.008700 sec.
# 756-th simulation finished, 0.007808 sec.
# 757-th simulation finished, 0.008112 sec.
# 758-th simulation finished, 0.009074 sec.
# 759-th simulation finished, 0.007189 sec.
# 760-th simulation finished, 0.006502 sec.
# 761-th simulation finished, 0.008824 sec.
# 762-th simulation finished, 0.006396 sec.
# 763-th simulation finished, 0.006651 sec.
# 764-th simulation finished, 0.007468 sec.
# 765-th simulation finished, 0.005910 sec.
# 766-th simulation finished, 0.004784 sec.
# 767-th simulation finished, 0.007202 sec.
# 768-th simulation finished, 0.006733 sec.
# 769-th simulation finished, 0.005989 sec.
# 770-th simulation finished, 0.008139 sec.
# 771-th simulation finished, 0.006916 sec.
# 772-th simulation finished, 0.005959 sec.
# 773-th simulation finished, 0.006810 sec.
# 774-th simulation finished, 0.005850 sec.
# 775-th simulation finished, 0.007191 sec.
# 776-th simulation finished, 0.003218 sec.
# 777-th simulation finished, 0.007272 sec.
# 778-th simulation finished, 0.013585 sec.
# 779-th simulation finished, 0.003326 sec.
# 780-th simulation finished, 0.013426 sec.
# 781-th simulation finished, 0.011989 sec.
# 782-th simulation finished, 0.006301 sec.
# 783-th simulation finished, 0.009615 sec.
# 784-th simulation finished, 0.010131 sec.
# 785-th simulation finished, 0.006981 sec.
# 786-th simulation finished, 0.009721 sec.
# 787-th simulation finished, 0.010105 sec.
# 788-th simulation finished, 0.018619 sec.
# 789-th simulation finished, 0.005864 sec.
# 790-th simulation finished, 0.011894 sec.
# 791-th simulation finished, 0.010180 sec.
# 792-th simulation finished, 0.015367 sec.
# 793-th simulation finished, 0.017416 sec.
# 794-th simulation finished, 0.009057 sec.
# 795-th simulation finished, 0.011281 sec.
# 796-th simulation finished, 0.022348 sec.
# 797-th simulation finished, 0.009138 sec.
# 798-th simulation finished, 0.007583 sec.
# 799-th simulation finished, 0.010372 sec.
# 800-th simulation finished, 0.006287 sec.
# 801-th simulation finished, 0.009177 sec.
# 802-th simulation finished, 0.008045 sec.
# 803-th simulation finished, 0.008388 sec.
# 804-th simulation finished, 0.005906 sec.
# 805-th simulation finished, 0.012280 sec.
# 806-th simulation finished, 0.007420 sec.
# 807-th simulation finished, 0.011550 sec.
# 808-th simulation finished, 0.003288 sec.
# 809-th simulation finished, 0.009674 sec.
# 810-th simulation finished, 0.008996 sec.
# 811-th simulation finished, 0.006059 sec.
# 812-th simulation finished, 0.006619 sec.
# 813-th simulation finished, 0.008198 sec.
# 814-th simulation finished, 0.004820 sec.
# 815-th simulation finished, 0.007246 sec.
# 816-th simulation finished, 0.007713 sec.
# 817-th simulation finished, 0.007771 sec.
# 818-th simulation finished, 0.009612 sec.
# 819-th simulation finished, 0.006459 sec.
# 820-th simulation finished, 0.009003 sec.
# 821-th simulation finished, 0.007405 sec.
# 822-th simulation finished, 0.007605 sec.
# 823-th simulation finished, 0.007312 sec.
# 824-th simulation finished, 0.014169 sec.
# 825-th simulation finished, 0.007930 sec.
# 826-th simulation finished, 0.009129 sec.
# 827-th simulation finished, 0.005868 sec.
# 828-th simulation finished, 0.007720 sec.
# 829-th simulation finished, 0.005935 sec.
# 830-th simulation finished, 0.006984 sec.
# 831-th simulation finished, 0.005683 sec.
# 832-th simulation finished, 0.005905 sec.
# 833-th simulation finished, 0.008416 sec.
# 834-th simulation finished, 0.005737 sec.
# 835-th simulation finished, 0.007265 sec.
# 836-th simulation finished, 0.004678 sec.
# 837-th simulation finished, 0.005721 sec.
# 838-th simulation finished, 0.009293 sec.
# 839-th simulation finished, 0.009244 sec.
# 840-th simulation finished, 0.009039 sec.
# 841-th simulation finished, 0.013060 sec.
# 842-th simulation finished, 0.009904 sec.
# 843-th simulation finished, 0.006735 sec.
# 844-th simulation finished, 0.006785 sec.
# 845-th simulation finished, 0.005387 sec.
# 846-th simulation finished, 0.005213 sec.
# 847-th simulation finished, 0.009877 sec.
# 848-th simulation finished, 0.008674 sec.
# 849-th simulation finished, 0.006722 sec.
# 850-th simulation finished, 0.009498 sec.
# 851-th simulation finished, 0.012866 sec.
# 852-th simulation finished, 0.012918 sec.
# 853-th simulation finished, 0.005848 sec.
# 854-th simulation finished, 0.003239 sec.
# 855-th simulation finished, 0.010214 sec.
# 856-th simulation finished, 0.003490 sec.
# 857-th simulation finished, 0.005746 sec.
# 858-th simulation finished, 0.006657 sec.
# 859-th simulation finished, 0.005526 sec.
# 860-th simulation finished, 0.005857 sec.
# 861-th simulation finished, 0.007288 sec.
# 862-th simulation finished, 0.007658 sec.
# 863-th simulation finished, 0.003183 sec.
# 864-th simulation finished, 0.005442 sec.
# 865-th simulation finished, 0.007238 sec.
# 866-th simulation finished, 0.010094 sec.
# 867-th simulation finished, 0.005059 sec.
# 868-th simulation finished, 0.005476 sec.
# 869-th simulation finished, 0.011333 sec.
# 870-th simulation finished, 0.010161 sec.
# 871-th simulation finished, 0.008433 sec.
# 872-th simulation finished, 0.017382 sec.
# 873-th simulation finished, 0.013274 sec.
# 874-th simulation finished, 0.007810 sec.
# 875-th simulation finished, 0.010712 sec.
# 876-th simulation finished, 0.010145 sec.
# 877-th simulation finished, 0.006940 sec.
# 878-th simulation finished, 0.010180 sec.
# 879-th simulation finished, 0.003559 sec.
# 880-th simulation finished, 0.012421 sec.
# 881-th simulation finished, 0.007189 sec.
# 882-th simulation finished, 0.011839 sec.
# 883-th simulation finished, 0.006005 sec.
# 884-th simulation finished, 0.005508 sec.
# 885-th simulation finished, 0.005063 sec.
# 886-th simulation finished, 0.006269 sec.
# 887-th simulation finished, 0.007779 sec.
# 888-th simulation finished, 0.007015 sec.
# 889-th simulation finished, 0.005138 sec.
# 890-th simulation finished, 0.005500 sec.
# 891-th simulation finished, 0.003190 sec.
# 892-th simulation finished, 0.004377 sec.
# 893-th simulation finished, 0.005197 sec.
# 894-th simulation finished, 0.006454 sec.
# 895-th simulation finished, 0.006037 sec.
# 896-th simulation finished, 0.005416 sec.
# 897-th simulation finished, 0.005965 sec.
# 898-th simulation finished, 0.005331 sec.
# 899-th simulation finished, 0.005905 sec.
# 900-th simulation finished, 0.006133 sec.
# 901-th simulation finished, 0.005745 sec.
# 902-th simulation finished, 0.008294 sec.
# 903-th simulation finished, 0.004849 sec.
# 904-th simulation finished, 0.005966 sec.
# 905-th simulation finished, 0.005942 sec.
# 906-th simulation finished, 0.006637 sec.
# 907-th simulation finished, 0.005987 sec.
# 908-th simulation finished, 0.005427 sec.
# 909-th simulation finished, 0.013866 sec.
# 910-th simulation finished, 0.006823 sec.
# 911-th simulation finished, 0.007179 sec.
# 912-th simulation finished, 0.009520 sec.
# 913-th simulation finished, 0.003193 sec.
# 914-th simulation finished, 0.008442 sec.
# 915-th simulation finished, 0.007458 sec.
# 916-th simulation finished, 0.010881 sec.
# 917-th simulation finished, 0.007483 sec.
# 918-th simulation finished, 0.007745 sec.
# 919-th simulation finished, 0.014655 sec.
# 920-th simulation finished, 0.006647 sec.
# 921-th simulation finished, 0.004469 sec.
# 922-th simulation finished, 0.006797 sec.
# 923-th simulation finished, 0.007902 sec.
# 924-th simulation finished, 0.008075 sec.
# 925-th simulation finished, 0.006009 sec.
# 926-th simulation finished, 0.005735 sec.
# 927-th simulation finished, 0.005605 sec.

# %%
plt.hist(Ts_dth)
# Out:
# (array([ 21.,  43., 164., 201., 230., 147.,  88.,  22.,   6.,   5.]),
#  array([-1.96337109, -1.49967189, -1.03597269, -0.57227349, -0.10857429,
#          0.35512491,  0.81882411,  1.28252331,  1.74622252,  2.20992172,
#          2.67362092]),
#  <BarContainer object of 10 artists>)

# %%
stats.probplot(ps_dth, dist = 'uniform', plot=plt, fit=False)
plt.plot([0, 1], [0, 1], c='black')
plt.show()

# %%
np.mean(np.abs(Ts_dth) < stats.norm.ppf(0.975))
# Out:
# 0.9902912621359223

# %% [markdown]
# # 6. Sandwich estimator coverage test

# %%
L_HAC = np.floor(4* (T/100)**(2/9))

# %%
w_HAC = np.maximum(1 - np.abs(np.arange(T)[:,None] - np.arange(T))/L_HAC, 0)

# %%
Ihs_sdw = np.zeros([num_sim, 2+d, 2+d])
Ts_sdw = np.zeros(num_sim)
ps_sdw = np.zeros(num_sim)

# %%
for iter_sim in np.arange(num_sim):
    start_sim = time.time()
    
    rhat = rsim[iter_sim,-1]
    mhat_0 = msim_0[iter_sim,-1]
    bhat = bsim[iter_sim,-1,:]
    Y_data = Ys_sim[iter_sim]
    
    Rhat = np.zeros(T+T0)
    d1Rh = np.zeros([d, T+T0])
    d2Rh = np.zeros([d, d, T+T0])
    
    for t in np.arange(T+T0):
        o = np.exp(bhat @ A[t])
        p = 1 / (1 + o)
        q = o / (1 + o)

        Rhat[t] = K * p
        d1Rh[:,t] = - K * p * q * A[t]
        d2Rh[:,:,t] = K * p * q * (q - p) * (A[t,:,None] * A[t])
        
    Pi = alpha * np.concatenate([[0],pi])[np.maximum(0, T0 + np.arange(T)[:,None] - np.arange(T+T0))]
    G = Rhat[:,None] * np.concatenate([[0],g])[np.maximum(0, np.arange(T+T0)[:,None] - np.arange(T+T0))]
    d1G = d1Rh[:,:,None] * np.concatenate([[0],g])[
            np.maximum(0, np.arange(T+T0)[:,None] - np.arange(T+T0))]
    d2G = d2Rh[...,None] * np.concatenate([[0],g])[
            np.maximum(0, np.arange(T+T0)[:,None] - np.arange(T+T0))]
    
    inv_ImG = la.inv(np.eye(T+T0)-G)
    Pi_inv_ImG = Pi @ inv_ImG
    
    EY = mhat_0 * Pi_inv_ImG[:,0]
    d1EY = mhat_0 * (Pi_inv_ImG @ (d1G @ inv_ImG[:,:1]))[...,0]
    d2EY = mhat_0 * (Pi_inv_ImG @ (
        d1G[:,None] @ inv_ImG @ d1G @ inv_ImG[:,:1]
        + d1G @ inv_ImG @ d1G[:,None] @ inv_ImG[:,:1]
        + d2G @ inv_ImG[:,:1]))[...,0]
    
    dltdr = np.array([dNBLLdr(y, m, rmle) for y, m in zip(Y_data, EY)])
    dltdm = dldEY * Pi_inv_ImG[:,0]
    dltdb = dldEY * d1EY
    
    dltdth = np.concatenate([np.array([dltdr, dltdm]), dltdb], 0)
    VEdl = dltdth @ w_HAC @ dltdth.T

    Ihs_sdw[iter_sim] = Ihs_dth[iter_sim] @ la.inv(VEdl) @ Ihs_dth[iter_sim]
    Ts_sdw[iter_sim] = (bhat[1]-bmle[1])/np.sqrt(la.inv(Ihs_sdw[iter_sim])[-1,-1])
    ps_sdw[iter_sim] = 2*(1-stats.norm.cdf(np.abs(Ts_sdw[iter_sim])))
    
    sys.__stdout__.write("%d-th simulation finished, %f sec.\n"
                         %(iter_sim+1, time.time()-start_sim))
    sys.__stdout__.flush()
# Out:
# 1-th simulation finished, 0.010901 sec.
# 2-th simulation finished, 0.006352 sec.
# 3-th simulation finished, 0.007366 sec.
# 4-th simulation finished, 0.006117 sec.
# 5-th simulation finished, 0.005620 sec.
# 6-th simulation finished, 0.005013 sec.
# 7-th simulation finished, 0.008204 sec.
# 8-th simulation finished, 0.006564 sec.
# 9-th simulation finished, 0.004946 sec.
# 10-th simulation finished, 0.006555 sec.
# 11-th simulation finished, 0.016100 sec.
# 12-th simulation finished, 0.006691 sec.
# 13-th simulation finished, 0.005778 sec.
# 14-th simulation finished, 0.012827 sec.
# 15-th simulation finished, 0.008100 sec.
# 16-th simulation finished, 0.010995 sec.
# 17-th simulation finished, 0.006874 sec.
# 18-th simulation finished, 0.006653 sec.
# 19-th simulation finished, 0.008253 sec.
# 20-th simulation finished, 0.005830 sec.
# 21-th simulation finished, 0.009394 sec.
# 22-th simulation finished, 0.008513 sec.
# 23-th simulation finished, 0.008887 sec.
# 24-th simulation finished, 0.004630 sec.
# 25-th simulation finished, 0.005907 sec.
# 26-th simulation finished, 0.005834 sec.
# 27-th simulation finished, 0.005631 sec.
# 28-th simulation finished, 0.006402 sec.
# 29-th simulation finished, 0.006180 sec.
# 30-th simulation finished, 0.015448 sec.
# 31-th simulation finished, 0.010834 sec.
# 32-th simulation finished, 0.005924 sec.
# 33-th simulation finished, 0.005557 sec.
# 34-th simulation finished, 0.006726 sec.
# 35-th simulation finished, 0.004849 sec.
# 36-th simulation finished, 0.007042 sec.
# 37-th simulation finished, 0.006174 sec.
# 38-th simulation finished, 0.006479 sec.
# 39-th simulation finished, 0.005657 sec.
# 40-th simulation finished, 0.004210 sec.
# 41-th simulation finished, 0.005845 sec.
# 42-th simulation finished, 0.004401 sec.
# 43-th simulation finished, 0.010548 sec.
# 44-th simulation finished, 0.008668 sec.
# 45-th simulation finished, 0.011269 sec.
# 46-th simulation finished, 0.007335 sec.
# 47-th simulation finished, 0.005507 sec.
# 48-th simulation finished, 0.012342 sec.
# 49-th simulation finished, 0.009267 sec.
# 50-th simulation finished, 0.007321 sec.
# 51-th simulation finished, 0.004880 sec.
# 52-th simulation finished, 0.010828 sec.
# 53-th simulation finished, 0.008660 sec.
# 54-th simulation finished, 0.008518 sec.
# 55-th simulation finished, 0.003280 sec.
# 56-th simulation finished, 0.015045 sec.
# 57-th simulation finished, 0.004931 sec.
# 58-th simulation finished, 0.014715 sec.
# 59-th simulation finished, 0.013764 sec.
# 60-th simulation finished, 0.005896 sec.
# 61-th simulation finished, 0.008673 sec.
# 62-th simulation finished, 0.008813 sec.
# 63-th simulation finished, 0.007058 sec.
# 64-th simulation finished, 0.005407 sec.
# 65-th simulation finished, 0.012690 sec.
# 66-th simulation finished, 0.006144 sec.
# 67-th simulation finished, 0.009987 sec.
# 68-th simulation finished, 0.005852 sec.
# 69-th simulation finished, 0.009366 sec.
# 70-th simulation finished, 0.008580 sec.
# 71-th simulation finished, 0.008704 sec.
# 72-th simulation finished, 0.006304 sec.
# 73-th simulation finished, 0.008740 sec.
# 74-th simulation finished, 0.007133 sec.
# 75-th simulation finished, 0.008413 sec.
# 76-th simulation finished, 0.008818 sec.
# 77-th simulation finished, 0.005588 sec.
# 78-th simulation finished, 0.009112 sec.
# 79-th simulation finished, 0.018084 sec.
# 80-th simulation finished, 0.010769 sec.
# 81-th simulation finished, 0.009450 sec.
# 82-th simulation finished, 0.012130 sec.
# 83-th simulation finished, 0.007597 sec.
# 84-th simulation finished, 0.009306 sec.
# 85-th simulation finished, 0.004417 sec.
# 86-th simulation finished, 0.009703 sec.
# 87-th simulation finished, 0.004794 sec.
# 88-th simulation finished, 0.007179 sec.
# 89-th simulation finished, 0.005931 sec.
# 90-th simulation finished, 0.005799 sec.
# 91-th simulation finished, 0.005707 sec.
# 92-th simulation finished, 0.006168 sec.
# 93-th simulation finished, 0.006513 sec.
# 94-th simulation finished, 0.005886 sec.
# 95-th simulation finished, 0.005768 sec.
# 96-th simulation finished, 0.006785 sec.
# 97-th simulation finished, 0.004696 sec.
# 98-th simulation finished, 0.005323 sec.
# 99-th simulation finished, 0.007655 sec.
# 100-th simulation finished, 0.006038 sec.
# 101-th simulation finished, 0.005524 sec.
# 102-th simulation finished, 0.005924 sec.
# 103-th simulation finished, 0.003099 sec.
# 104-th simulation finished, 0.003804 sec.
# 105-th simulation finished, 0.005615 sec.
# 106-th simulation finished, 0.004673 sec.
# 107-th simulation finished, 0.007027 sec.
# 108-th simulation finished, 0.016949 sec.
# 109-th simulation finished, 0.004596 sec.
# 110-th simulation finished, 0.008901 sec.
# 111-th simulation finished, 0.022925 sec.
# 112-th simulation finished, 0.012528 sec.
# 113-th simulation finished, 0.018230 sec.
# 114-th simulation finished, 0.012364 sec.
# 115-th simulation finished, 0.013415 sec.
# 116-th simulation finished, 0.055724 sec.
# 117-th simulation finished, 0.013814 sec.
# 118-th simulation finished, 0.040289 sec.
# 119-th simulation finished, 0.009967 sec.
# 120-th simulation finished, 0.009238 sec.
# 121-th simulation finished, 0.012563 sec.
# 122-th simulation finished, 0.011189 sec.
# 123-th simulation finished, 0.006917 sec.
# 124-th simulation finished, 0.010438 sec.
# 125-th simulation finished, 0.008511 sec.
# 126-th simulation finished, 0.007443 sec.
# 127-th simulation finished, 0.011005 sec.
# 128-th simulation finished, 0.010840 sec.
# 129-th simulation finished, 0.013975 sec.
# 130-th simulation finished, 0.016508 sec.
# 131-th simulation finished, 0.007750 sec.
# 132-th simulation finished, 0.007539 sec.
# 133-th simulation finished, 0.011581 sec.
# 134-th simulation finished, 0.010413 sec.
# 135-th simulation finished, 0.013374 sec.
# 136-th simulation finished, 0.009254 sec.
# 137-th simulation finished, 0.007628 sec.
# 138-th simulation finished, 0.010639 sec.
# 139-th simulation finished, 0.016012 sec.
# 140-th simulation finished, 0.021614 sec.
# 141-th simulation finished, 0.007894 sec.
# 142-th simulation finished, 0.006441 sec.
# 143-th simulation finished, 0.005609 sec.
# 144-th simulation finished, 0.006748 sec.
# 145-th simulation finished, 0.004583 sec.
# 146-th simulation finished, 0.005655 sec.
# 147-th simulation finished, 0.007074 sec.
# 148-th simulation finished, 0.006699 sec.
# 149-th simulation finished, 0.006969 sec.
# 150-th simulation finished, 0.005544 sec.
# 151-th simulation finished, 0.006524 sec.
# 152-th simulation finished, 0.005560 sec.
# 153-th simulation finished, 0.004928 sec.
# 154-th simulation finished, 0.005783 sec.
# 155-th simulation finished, 0.007518 sec.
# 156-th simulation finished, 0.008158 sec.
# 157-th simulation finished, 0.005940 sec.
# 158-th simulation finished, 0.008018 sec.
# 159-th simulation finished, 0.005546 sec.
# 160-th simulation finished, 0.005363 sec.
# 161-th simulation finished, 0.003185 sec.
# 162-th simulation finished, 0.005722 sec.
# 163-th simulation finished, 0.005792 sec.
# 164-th simulation finished, 0.005485 sec.
# 165-th simulation finished, 0.006203 sec.
# 166-th simulation finished, 0.009238 sec.
# 167-th simulation finished, 0.006186 sec.
# 168-th simulation finished, 0.010593 sec.
# 169-th simulation finished, 0.006040 sec.
# 170-th simulation finished, 0.010617 sec.
# 171-th simulation finished, 0.005997 sec.
# 172-th simulation finished, 0.010898 sec.
# 173-th simulation finished, 0.006844 sec.
# 174-th simulation finished, 0.009137 sec.
# 175-th simulation finished, 0.006918 sec.
# 176-th simulation finished, 0.014787 sec.
# 177-th simulation finished, 0.003190 sec.
# 178-th simulation finished, 0.009246 sec.
# 179-th simulation finished, 0.007637 sec.
# 180-th simulation finished, 0.005842 sec.
# 181-th simulation finished, 0.007626 sec.
# 182-th simulation finished, 0.008220 sec.
# 183-th simulation finished, 0.005904 sec.
# 184-th simulation finished, 0.004496 sec.
# 185-th simulation finished, 0.009559 sec.
# 186-th simulation finished, 0.004453 sec.
# 187-th simulation finished, 0.015830 sec.
# 188-th simulation finished, 0.003126 sec.
# 189-th simulation finished, 0.007244 sec.
# 190-th simulation finished, 0.006746 sec.
# 191-th simulation finished, 0.005411 sec.
# 192-th simulation finished, 0.006783 sec.
# 193-th simulation finished, 0.010075 sec.
# 194-th simulation finished, 0.008371 sec.
# 195-th simulation finished, 0.006279 sec.
# 196-th simulation finished, 0.008601 sec.
# 197-th simulation finished, 0.007003 sec.
# 198-th simulation finished, 0.007400 sec.
# 199-th simulation finished, 0.006514 sec.
# 200-th simulation finished, 0.007206 sec.
# 201-th simulation finished, 0.005645 sec.
# 202-th simulation finished, 0.006071 sec.
# 203-th simulation finished, 0.005785 sec.
# 204-th simulation finished, 0.005510 sec.
# 205-th simulation finished, 0.031603 sec.
# 206-th simulation finished, 0.008274 sec.
# 207-th simulation finished, 0.005087 sec.
# 208-th simulation finished, 0.005392 sec.
# 209-th simulation finished, 0.007661 sec.
# 210-th simulation finished, 0.006340 sec.
# 211-th simulation finished, 0.006419 sec.
# 212-th simulation finished, 0.005127 sec.
# 213-th simulation finished, 0.005279 sec.
# 214-th simulation finished, 0.006001 sec.
# 215-th simulation finished, 0.005582 sec.
# 216-th simulation finished, 0.006082 sec.
# 217-th simulation finished, 0.005869 sec.
# 218-th simulation finished, 0.007169 sec.
# 219-th simulation finished, 0.006738 sec.
# 220-th simulation finished, 0.004516 sec.
# 221-th simulation finished, 0.004299 sec.
# 222-th simulation finished, 0.003018 sec.
# 223-th simulation finished, 0.005985 sec.
# 224-th simulation finished, 0.006255 sec.
# 225-th simulation finished, 0.005842 sec.
# 226-th simulation finished, 0.009956 sec.
# 227-th simulation finished, 0.005457 sec.
# 228-th simulation finished, 0.005632 sec.
# 229-th simulation finished, 0.006885 sec.
# 230-th simulation finished, 0.005945 sec.
# 231-th simulation finished, 0.005561 sec.
# 232-th simulation finished, 0.006853 sec.
# 233-th simulation finished, 0.005803 sec.
# 234-th simulation finished, 0.007508 sec.
# 235-th simulation finished, 0.005426 sec.
# 236-th simulation finished, 0.006543 sec.
# 237-th simulation finished, 0.005939 sec.
# 238-th simulation finished, 0.005964 sec.
# 239-th simulation finished, 0.012330 sec.
# 240-th simulation finished, 0.006174 sec.
# 241-th simulation finished, 0.010093 sec.
# 242-th simulation finished, 0.005812 sec.
# 243-th simulation finished, 0.005492 sec.
# 244-th simulation finished, 0.008946 sec.
# 245-th simulation finished, 0.005259 sec.
# 246-th simulation finished, 0.007512 sec.
# 247-th simulation finished, 0.007301 sec.
# 248-th simulation finished, 0.009030 sec.
# 249-th simulation finished, 0.006269 sec.
# 250-th simulation finished, 0.005796 sec.
# 251-th simulation finished, 0.004832 sec.
# 252-th simulation finished, 0.005901 sec.
# 253-th simulation finished, 0.007299 sec.
# 254-th simulation finished, 0.007318 sec.
# 255-th simulation finished, 0.008471 sec.
# 256-th simulation finished, 0.006870 sec.
# 257-th simulation finished, 0.008704 sec.
# 258-th simulation finished, 0.006867 sec.
# 259-th simulation finished, 0.006210 sec.
# 260-th simulation finished, 0.007300 sec.
# 261-th simulation finished, 0.007317 sec.
# 262-th simulation finished, 0.007315 sec.
# 263-th simulation finished, 0.007140 sec.
# 264-th simulation finished, 0.007169 sec.
# 265-th simulation finished, 0.005890 sec.
# 266-th simulation finished, 0.007291 sec.
# 267-th simulation finished, 0.014011 sec.
# 268-th simulation finished, 0.006524 sec.
# 269-th simulation finished, 0.005415 sec.
# 270-th simulation finished, 0.006289 sec.
# 271-th simulation finished, 0.005907 sec.
# 272-th simulation finished, 0.007277 sec.
# 273-th simulation finished, 0.006865 sec.
# 274-th simulation finished, 0.007772 sec.
# 275-th simulation finished, 0.005999 sec.
# 276-th simulation finished, 0.006876 sec.
# 277-th simulation finished, 0.008066 sec.
# 278-th simulation finished, 0.005999 sec.
# 279-th simulation finished, 0.005735 sec.
# 280-th simulation finished, 0.005789 sec.
# 281-th simulation finished, 0.006667 sec.
# 282-th simulation finished, 0.006093 sec.
# 283-th simulation finished, 0.009276 sec.
# 284-th simulation finished, 0.006395 sec.
# 285-th simulation finished, 0.005734 sec.
# 286-th simulation finished, 0.006347 sec.
# 287-th simulation finished, 0.010288 sec.
# 288-th simulation finished, 0.003546 sec.
# 289-th simulation finished, 0.008903 sec.
# 290-th simulation finished, 0.006593 sec.
# 291-th simulation finished, 0.005836 sec.
# 292-th simulation finished, 0.004993 sec.
# 293-th simulation finished, 0.005379 sec.
# 294-th simulation finished, 0.006861 sec.
# 295-th simulation finished, 0.005611 sec.
# 296-th simulation finished, 0.004058 sec.
# 297-th simulation finished, 0.009603 sec.
# 298-th simulation finished, 0.004013 sec.
# 299-th simulation finished, 0.011909 sec.
# 300-th simulation finished, 0.006148 sec.
# 301-th simulation finished, 0.004506 sec.
# 302-th simulation finished, 0.006164 sec.
# 303-th simulation finished, 0.014005 sec.
# 304-th simulation finished, 0.005694 sec.
# 305-th simulation finished, 0.004368 sec.
# 306-th simulation finished, 0.003046 sec.
# 307-th simulation finished, 0.006538 sec.
# 308-th simulation finished, 0.004107 sec.
# 309-th simulation finished, 0.005560 sec.
# 310-th simulation finished, 0.007154 sec.
# 311-th simulation finished, 0.007362 sec.
# 312-th simulation finished, 0.013479 sec.
# 313-th simulation finished, 0.011650 sec.
# 314-th simulation finished, 0.006769 sec.
# 315-th simulation finished, 0.012294 sec.
# 316-th simulation finished, 0.016154 sec.
# 317-th simulation finished, 0.009988 sec.
# 318-th simulation finished, 0.010703 sec.
# 319-th simulation finished, 0.005758 sec.
# 320-th simulation finished, 0.011658 sec.
# 321-th simulation finished, 0.005876 sec.
# 322-th simulation finished, 0.006064 sec.
# 323-th simulation finished, 0.005546 sec.
# 324-th simulation finished, 0.018026 sec.
# 325-th simulation finished, 0.008115 sec.
# 326-th simulation finished, 0.005954 sec.
# 327-th simulation finished, 0.005964 sec.
# 328-th simulation finished, 0.005635 sec.
# 329-th simulation finished, 0.005941 sec.
# 330-th simulation finished, 0.015437 sec.
# 331-th simulation finished, 0.004837 sec.
# 332-th simulation finished, 0.006133 sec.
# 333-th simulation finished, 0.006245 sec.
# 334-th simulation finished, 0.005936 sec.
# 335-th simulation finished, 0.005385 sec.
# 336-th simulation finished, 0.007458 sec.
# 337-th simulation finished, 0.010046 sec.
# 338-th simulation finished, 0.006438 sec.
# 339-th simulation finished, 0.007047 sec.
# 340-th simulation finished, 0.005923 sec.
# 341-th simulation finished, 0.005626 sec.
# 342-th simulation finished, 0.008851 sec.
# 343-th simulation finished, 0.004617 sec.
# 344-th simulation finished, 0.009040 sec.
# 345-th simulation finished, 0.005852 sec.
# 346-th simulation finished, 0.005042 sec.
# 347-th simulation finished, 0.005549 sec.
# 348-th simulation finished, 0.005600 sec.
# 349-th simulation finished, 0.005918 sec.
# 350-th simulation finished, 0.004308 sec.
# 351-th simulation finished, 0.006997 sec.
# 352-th simulation finished, 0.008589 sec.
# 353-th simulation finished, 0.004818 sec.
# 354-th simulation finished, 0.006514 sec.
# 355-th simulation finished, 0.008452 sec.
# 356-th simulation finished, 0.015610 sec.
# 357-th simulation finished, 0.003350 sec.
# 358-th simulation finished, 0.005850 sec.
# 359-th simulation finished, 0.005597 sec.
# 360-th simulation finished, 0.005586 sec.
# 361-th simulation finished, 0.006528 sec.
# 362-th simulation finished, 0.009144 sec.
# 363-th simulation finished, 0.006028 sec.
# 364-th simulation finished, 0.006060 sec.
# 365-th simulation finished, 0.003466 sec.
# 366-th simulation finished, 0.002972 sec.
# 367-th simulation finished, 0.006964 sec.
# 368-th simulation finished, 0.003700 sec.
# 369-th simulation finished, 0.005569 sec.
# 370-th simulation finished, 0.005663 sec.
# 371-th simulation finished, 0.005934 sec.
# 372-th simulation finished, 0.005689 sec.
# 373-th simulation finished, 0.007373 sec.
# 374-th simulation finished, 0.006261 sec.
# 375-th simulation finished, 0.005580 sec.
# 376-th simulation finished, 0.005234 sec.
# 377-th simulation finished, 0.005930 sec.
# 378-th simulation finished, 0.006816 sec.
# 379-th simulation finished, 0.008308 sec.
# 380-th simulation finished, 0.005863 sec.
# 381-th simulation finished, 0.005952 sec.
# 382-th simulation finished, 0.005623 sec.
# 383-th simulation finished, 0.012714 sec.
# 384-th simulation finished, 0.009871 sec.
# 385-th simulation finished, 0.012679 sec.
# 386-th simulation finished, 0.012550 sec.
# 387-th simulation finished, 0.021370 sec.
# 388-th simulation finished, 0.014967 sec.
# 389-th simulation finished, 0.039253 sec.
# 390-th simulation finished, 0.012187 sec.
# 391-th simulation finished, 0.030328 sec.
# 392-th simulation finished, 0.006248 sec.
# 393-th simulation finished, 0.006054 sec.
# 394-th simulation finished, 0.006370 sec.
# 395-th simulation finished, 0.010102 sec.
# 396-th simulation finished, 0.005769 sec.
# 397-th simulation finished, 0.005580 sec.
# 398-th simulation finished, 0.007953 sec.
# 399-th simulation finished, 0.005932 sec.
# 400-th simulation finished, 0.010389 sec.
# 401-th simulation finished, 0.005755 sec.
# 402-th simulation finished, 0.004908 sec.
# 403-th simulation finished, 0.006361 sec.
# 404-th simulation finished, 0.005854 sec.
# 405-th simulation finished, 0.004896 sec.
# 406-th simulation finished, 0.003138 sec.
# 407-th simulation finished, 0.013835 sec.
# 408-th simulation finished, 0.006534 sec.
# 409-th simulation finished, 0.012896 sec.
# 410-th simulation finished, 0.005636 sec.
# 411-th simulation finished, 0.004597 sec.
# 412-th simulation finished, 0.006808 sec.
# 413-th simulation finished, 0.017136 sec.
# 414-th simulation finished, 0.009148 sec.
# 415-th simulation finished, 0.007056 sec.
# 416-th simulation finished, 0.009721 sec.
# 417-th simulation finished, 0.009771 sec.
# 418-th simulation finished, 0.011272 sec.
# 419-th simulation finished, 0.012801 sec.
# 420-th simulation finished, 0.008379 sec.
# 421-th simulation finished, 0.007836 sec.
# 422-th simulation finished, 0.012977 sec.
# 423-th simulation finished, 0.009756 sec.
# 424-th simulation finished, 0.010137 sec.
# 425-th simulation finished, 0.014779 sec.
# 426-th simulation finished, 0.009361 sec.
# 427-th simulation finished, 0.013811 sec.
# 428-th simulation finished, 0.007881 sec.
# 429-th simulation finished, 0.005984 sec.
# 430-th simulation finished, 0.005249 sec.
# 431-th simulation finished, 0.008821 sec.
# 432-th simulation finished, 0.007300 sec.
# 433-th simulation finished, 0.007895 sec.
# 434-th simulation finished, 0.005830 sec.
# 435-th simulation finished, 0.006389 sec.
# 436-th simulation finished, 0.016657 sec.
# 437-th simulation finished, 0.005881 sec.
# 438-th simulation finished, 0.006694 sec.
# 439-th simulation finished, 0.005141 sec.
# 440-th simulation finished, 0.012891 sec.
# 441-th simulation finished, 0.054546 sec.
# 442-th simulation finished, 0.009133 sec.
# 443-th simulation finished, 0.026003 sec.
# 444-th simulation finished, 0.004531 sec.
# 445-th simulation finished, 0.034239 sec.
# 446-th simulation finished, 0.038324 sec.
# 447-th simulation finished, 0.036750 sec.
# 448-th simulation finished, 0.004050 sec.
# 449-th simulation finished, 0.006292 sec.
# 450-th simulation finished, 0.028581 sec.
# 451-th simulation finished, 0.010426 sec.
# 452-th simulation finished, 0.005329 sec.
# 453-th simulation finished, 0.008598 sec.
# 454-th simulation finished, 0.008099 sec.
# 455-th simulation finished, 0.010334 sec.
# 456-th simulation finished, 0.015147 sec.
# 457-th simulation finished, 0.007131 sec.
# 458-th simulation finished, 0.004803 sec.
# 459-th simulation finished, 0.009016 sec.
# 460-th simulation finished, 0.008754 sec.
# 461-th simulation finished, 0.025670 sec.
# 462-th simulation finished, 0.008120 sec.
# 463-th simulation finished, 0.007467 sec.
# 464-th simulation finished, 0.007184 sec.
# 465-th simulation finished, 0.010619 sec.
# 466-th simulation finished, 0.007458 sec.
# 467-th simulation finished, 0.008311 sec.
# 468-th simulation finished, 0.009820 sec.
# 469-th simulation finished, 0.007675 sec.
# 470-th simulation finished, 0.013952 sec.
# 471-th simulation finished, 0.007047 sec.
# 472-th simulation finished, 0.008647 sec.
# 473-th simulation finished, 0.007841 sec.
# 474-th simulation finished, 0.005687 sec.
# 475-th simulation finished, 0.009079 sec.
# 476-th simulation finished, 0.009065 sec.
# 477-th simulation finished, 0.009572 sec.
# 478-th simulation finished, 0.007166 sec.
# 479-th simulation finished, 0.007003 sec.
# 480-th simulation finished, 0.008850 sec.
# 481-th simulation finished, 0.008338 sec.
# 482-th simulation finished, 0.006545 sec.
# 483-th simulation finished, 0.013546 sec.
# 484-th simulation finished, 0.011036 sec.
# 485-th simulation finished, 0.006446 sec.
# 486-th simulation finished, 0.008461 sec.
# 487-th simulation finished, 0.009842 sec.
# 488-th simulation finished, 0.008896 sec.
# 489-th simulation finished, 0.005073 sec.
# 490-th simulation finished, 0.012340 sec.
# 491-th simulation finished, 0.008900 sec.
# 492-th simulation finished, 0.010465 sec.
# 493-th simulation finished, 0.011801 sec.
# 494-th simulation finished, 0.005854 sec.
# 495-th simulation finished, 0.017564 sec.
# 496-th simulation finished, 0.009699 sec.
# 497-th simulation finished, 0.004432 sec.
# 498-th simulation finished, 0.003367 sec.
# 499-th simulation finished, 0.014130 sec.
# 500-th simulation finished, 0.002941 sec.
# 501-th simulation finished, 0.003081 sec.
# 502-th simulation finished, 0.005269 sec.
# 503-th simulation finished, 0.010020 sec.
# 504-th simulation finished, 0.006158 sec.
# 505-th simulation finished, 0.006062 sec.
# 506-th simulation finished, 0.014060 sec.
# 507-th simulation finished, 0.007094 sec.
# 508-th simulation finished, 0.007655 sec.
# 509-th simulation finished, 0.018988 sec.
# 510-th simulation finished, 0.008315 sec.
# 511-th simulation finished, 0.007729 sec.
# 512-th simulation finished, 0.007861 sec.
# 513-th simulation finished, 0.009074 sec.
# 514-th simulation finished, 0.007779 sec.
# 515-th simulation finished, 0.011554 sec.
# 516-th simulation finished, 0.007610 sec.
# 517-th simulation finished, 0.013410 sec.
# 518-th simulation finished, 0.007274 sec.
# 519-th simulation finished, 0.010575 sec.
# 520-th simulation finished, 0.007423 sec.
# 521-th simulation finished, 0.008818 sec.
# 522-th simulation finished, 0.004870 sec.
# 523-th simulation finished, 0.003590 sec.
# 524-th simulation finished, 0.007398 sec.
# 525-th simulation finished, 0.010017 sec.
# 526-th simulation finished, 0.007583 sec.
# 527-th simulation finished, 0.004971 sec.
# 528-th simulation finished, 0.009032 sec.
# 529-th simulation finished, 0.004727 sec.
# 530-th simulation finished, 0.007463 sec.
# 531-th simulation finished, 0.007812 sec.
# 532-th simulation finished, 0.003100 sec.
# 533-th simulation finished, 0.004385 sec.
# 534-th simulation finished, 0.007041 sec.
# 535-th simulation finished, 0.010154 sec.
# 536-th simulation finished, 0.003076 sec.
# 537-th simulation finished, 0.009427 sec.
# 538-th simulation finished, 0.017909 sec.
# 539-th simulation finished, 0.005977 sec.
# 540-th simulation finished, 0.013739 sec.
# 541-th simulation finished, 0.011823 sec.
# 542-th simulation finished, 0.005932 sec.
# 543-th simulation finished, 0.005313 sec.
# 544-th simulation finished, 0.006017 sec.
# 545-th simulation finished, 0.004106 sec.
# 546-th simulation finished, 0.005109 sec.
# 547-th simulation finished, 0.010234 sec.
# 548-th simulation finished, 0.006474 sec.
# 549-th simulation finished, 0.008301 sec.
# 550-th simulation finished, 0.004689 sec.
# 551-th simulation finished, 0.007401 sec.
# 552-th simulation finished, 0.005225 sec.
# 553-th simulation finished, 0.006259 sec.
# 554-th simulation finished, 0.004918 sec.
# 555-th simulation finished, 0.006139 sec.
# 556-th simulation finished, 0.005945 sec.
# 557-th simulation finished, 0.006548 sec.
# 558-th simulation finished, 0.006291 sec.
# 559-th simulation finished, 0.006172 sec.
# 560-th simulation finished, 0.004049 sec.
# 561-th simulation finished, 0.003060 sec.
# 562-th simulation finished, 0.006129 sec.
# 563-th simulation finished, 0.006222 sec.
# 564-th simulation finished, 0.005744 sec.
# 565-th simulation finished, 0.005567 sec.
# 566-th simulation finished, 0.008128 sec.
# 567-th simulation finished, 0.019513 sec.
# 568-th simulation finished, 0.007986 sec.
# 569-th simulation finished, 0.004586 sec.
# 570-th simulation finished, 0.003816 sec.
# 571-th simulation finished, 0.005940 sec.
# 572-th simulation finished, 0.006752 sec.
# 573-th simulation finished, 0.005852 sec.
# 574-th simulation finished, 0.008227 sec.
# 575-th simulation finished, 0.004377 sec.
# 576-th simulation finished, 0.006948 sec.
# 577-th simulation finished, 0.007909 sec.
# 578-th simulation finished, 0.007084 sec.
# 579-th simulation finished, 0.007156 sec.
# 580-th simulation finished, 0.009219 sec.
# 581-th simulation finished, 0.009123 sec.
# 582-th simulation finished, 0.008189 sec.
# 583-th simulation finished, 0.007663 sec.
# 584-th simulation finished, 0.007740 sec.
# 585-th simulation finished, 0.008389 sec.
# 586-th simulation finished, 0.007440 sec.
# 587-th simulation finished, 0.007503 sec.
# 588-th simulation finished, 0.009041 sec.
# 589-th simulation finished, 0.010040 sec.
# 590-th simulation finished, 0.007433 sec.
# 591-th simulation finished, 0.008719 sec.
# 592-th simulation finished, 0.006027 sec.
# 593-th simulation finished, 0.006533 sec.
# 594-th simulation finished, 0.006133 sec.
# 595-th simulation finished, 0.006195 sec.
# 596-th simulation finished, 0.012269 sec.
# 597-th simulation finished, 0.004242 sec.
# 598-th simulation finished, 0.006450 sec.
# 599-th simulation finished, 0.005907 sec.
# 600-th simulation finished, 0.008484 sec.
# 601-th simulation finished, 0.007096 sec.
# 602-th simulation finished, 0.010247 sec.
# 603-th simulation finished, 0.004593 sec.
# 604-th simulation finished, 0.003033 sec.
# 605-th simulation finished, 0.006020 sec.
# 606-th simulation finished, 0.006300 sec.
# 607-th simulation finished, 0.003196 sec.
# 608-th simulation finished, 0.003503 sec.
# 609-th simulation finished, 0.006753 sec.
# 610-th simulation finished, 0.005462 sec.
# 611-th simulation finished, 0.007710 sec.
# 612-th simulation finished, 0.003163 sec.
# 613-th simulation finished, 0.006126 sec.
# 614-th simulation finished, 0.006365 sec.
# 615-th simulation finished, 0.009411 sec.
# 616-th simulation finished, 0.015243 sec.
# 617-th simulation finished, 0.011234 sec.
# 618-th simulation finished, 0.011294 sec.
# 619-th simulation finished, 0.011325 sec.
# 620-th simulation finished, 0.009730 sec.
# 621-th simulation finished, 0.011260 sec.
# 622-th simulation finished, 0.013190 sec.
# 623-th simulation finished, 0.010546 sec.
# 624-th simulation finished, 0.010720 sec.
# 625-th simulation finished, 0.011169 sec.
# 626-th simulation finished, 0.006977 sec.
# 627-th simulation finished, 0.007074 sec.
# 628-th simulation finished, 0.008737 sec.
# 629-th simulation finished, 0.007402 sec.
# 630-th simulation finished, 0.007325 sec.
# 631-th simulation finished, 0.008134 sec.
# 632-th simulation finished, 0.006286 sec.
# 633-th simulation finished, 0.006784 sec.
# 634-th simulation finished, 0.007125 sec.
# 635-th simulation finished, 0.007335 sec.
# 636-th simulation finished, 0.006493 sec.
# 637-th simulation finished, 0.007688 sec.
# 638-th simulation finished, 0.005633 sec.
# 639-th simulation finished, 0.006764 sec.
# 640-th simulation finished, 0.006760 sec.
# 641-th simulation finished, 0.005620 sec.
# 642-th simulation finished, 0.007237 sec.
# 643-th simulation finished, 0.004565 sec.
# 644-th simulation finished, 0.006477 sec.
# 645-th simulation finished, 0.005890 sec.
# 646-th simulation finished, 0.006060 sec.
# 647-th simulation finished, 0.005681 sec.
# 648-th simulation finished, 0.005716 sec.
# 649-th simulation finished, 0.007830 sec.
# 650-th simulation finished, 0.004275 sec.
# 651-th simulation finished, 0.003121 sec.
# 652-th simulation finished, 0.008158 sec.
# 653-th simulation finished, 0.006121 sec.
# 654-th simulation finished, 0.007922 sec.
# 655-th simulation finished, 0.012133 sec.
# 656-th simulation finished, 0.006135 sec.
# 657-th simulation finished, 0.007696 sec.
# 658-th simulation finished, 0.010124 sec.
# 659-th simulation finished, 0.009178 sec.
# 660-th simulation finished, 0.005814 sec.
# 661-th simulation finished, 0.014784 sec.
# 662-th simulation finished, 0.006426 sec.
# 663-th simulation finished, 0.009227 sec.
# 664-th simulation finished, 0.006146 sec.
# 665-th simulation finished, 0.008313 sec.
# 666-th simulation finished, 0.005907 sec.
# 667-th simulation finished, 0.010162 sec.
# 668-th simulation finished, 0.005692 sec.
# 669-th simulation finished, 0.008642 sec.
# 670-th simulation finished, 0.006029 sec.
# 671-th simulation finished, 0.007989 sec.
# 672-th simulation finished, 0.005952 sec.
# 673-th simulation finished, 0.007585 sec.
# 674-th simulation finished, 0.005695 sec.
# 675-th simulation finished, 0.003038 sec.
# 676-th simulation finished, 0.005222 sec.
# 677-th simulation finished, 0.009136 sec.
# 678-th simulation finished, 0.008397 sec.
# 679-th simulation finished, 0.008105 sec.
# 680-th simulation finished, 0.010630 sec.
# 681-th simulation finished, 0.006867 sec.
# 682-th simulation finished, 0.007367 sec.
# 683-th simulation finished, 0.008586 sec.
# 684-th simulation finished, 0.006106 sec.
# 685-th simulation finished, 0.010362 sec.
# 686-th simulation finished, 0.015610 sec.
# 687-th simulation finished, 0.005908 sec.
# 688-th simulation finished, 0.005846 sec.
# 689-th simulation finished, 0.012999 sec.
# 690-th simulation finished, 0.010388 sec.
# 691-th simulation finished, 0.006999 sec.
# 692-th simulation finished, 0.008025 sec.
# 693-th simulation finished, 0.006825 sec.
# 694-th simulation finished, 0.007597 sec.
# 695-th simulation finished, 0.008679 sec.
# 696-th simulation finished, 0.006750 sec.
# 697-th simulation finished, 0.006901 sec.
# 698-th simulation finished, 0.007135 sec.
# 699-th simulation finished, 0.005704 sec.
# 700-th simulation finished, 0.006297 sec.
# 701-th simulation finished, 0.006136 sec.
# 702-th simulation finished, 0.007111 sec.
# 703-th simulation finished, 0.007186 sec.
# 704-th simulation finished, 0.007579 sec.
# 705-th simulation finished, 0.006926 sec.
# 706-th simulation finished, 0.005958 sec.
# 707-th simulation finished, 0.024777 sec.
# 708-th simulation finished, 0.011315 sec.
# 709-th simulation finished, 0.007918 sec.
# 710-th simulation finished, 0.007610 sec.
# 711-th simulation finished, 0.005517 sec.
# 712-th simulation finished, 0.011190 sec.
# 713-th simulation finished, 0.015016 sec.
# 714-th simulation finished, 0.006141 sec.
# 715-th simulation finished, 0.004492 sec.
# 716-th simulation finished, 0.004233 sec.
# 717-th simulation finished, 0.005985 sec.
# 718-th simulation finished, 0.008154 sec.
# 719-th simulation finished, 0.006231 sec.
# 720-th simulation finished, 0.004571 sec.
# 721-th simulation finished, 0.009096 sec.
# 722-th simulation finished, 0.006241 sec.
# 723-th simulation finished, 0.006435 sec.
# 724-th simulation finished, 0.006160 sec.
# 725-th simulation finished, 0.005345 sec.
# 726-th simulation finished, 0.005203 sec.
# 727-th simulation finished, 0.007298 sec.
# 728-th simulation finished, 0.005057 sec.
# 729-th simulation finished, 0.002970 sec.
# 730-th simulation finished, 0.006217 sec.
# 731-th simulation finished, 0.005687 sec.
# 732-th simulation finished, 0.005962 sec.
# 733-th simulation finished, 0.005361 sec.
# 734-th simulation finished, 0.004720 sec.
# 735-th simulation finished, 0.006312 sec.
# 736-th simulation finished, 0.008941 sec.
# 737-th simulation finished, 0.005556 sec.
# 738-th simulation finished, 0.005425 sec.
# 739-th simulation finished, 0.005542 sec.
# 740-th simulation finished, 0.005550 sec.
# 741-th simulation finished, 0.010765 sec.
# 742-th simulation finished, 0.007311 sec.
# 743-th simulation finished, 0.008408 sec.
# 744-th simulation finished, 0.007597 sec.
# 745-th simulation finished, 0.008967 sec.
# 746-th simulation finished, 0.012051 sec.
# 747-th simulation finished, 0.006022 sec.
# 748-th simulation finished, 0.014724 sec.
# 749-th simulation finished, 0.005567 sec.
# 750-th simulation finished, 0.006799 sec.
# 751-th simulation finished, 0.006440 sec.
# 752-th simulation finished, 0.013276 sec.
# 753-th simulation finished, 0.010138 sec.
# 754-th simulation finished, 0.009763 sec.
# 755-th simulation finished, 0.013838 sec.
# 756-th simulation finished, 0.005663 sec.
# 757-th simulation finished, 0.005684 sec.
# 758-th simulation finished, 0.005699 sec.
# 759-th simulation finished, 0.005359 sec.
# 760-th simulation finished, 0.006696 sec.
# 761-th simulation finished, 0.003516 sec.
# 762-th simulation finished, 0.004295 sec.
# 763-th simulation finished, 0.010976 sec.
# 764-th simulation finished, 0.005628 sec.
# 765-th simulation finished, 0.005732 sec.
# 766-th simulation finished, 0.004601 sec.
# 767-th simulation finished, 0.008293 sec.
# 768-th simulation finished, 0.006773 sec.
# 769-th simulation finished, 0.008494 sec.
# 770-th simulation finished, 0.005840 sec.
# 771-th simulation finished, 0.005662 sec.
# 772-th simulation finished, 0.005722 sec.
# 773-th simulation finished, 0.005751 sec.
# 774-th simulation finished, 0.006461 sec.
# 775-th simulation finished, 0.004216 sec.
# 776-th simulation finished, 0.003426 sec.
# 777-th simulation finished, 0.005990 sec.
# 778-th simulation finished, 0.007555 sec.
# 779-th simulation finished, 0.005706 sec.
# 780-th simulation finished, 0.005859 sec.
# 781-th simulation finished, 0.005948 sec.
# 782-th simulation finished, 0.006717 sec.
# 783-th simulation finished, 0.005765 sec.
# 784-th simulation finished, 0.006825 sec.
# 785-th simulation finished, 0.007331 sec.
# 786-th simulation finished, 0.005558 sec.
# 787-th simulation finished, 0.005948 sec.
# 788-th simulation finished, 0.007451 sec.
# 789-th simulation finished, 0.006368 sec.
# 790-th simulation finished, 0.005410 sec.
# 791-th simulation finished, 0.006086 sec.
# 792-th simulation finished, 0.005278 sec.
# 793-th simulation finished, 0.005773 sec.
# 794-th simulation finished, 0.005781 sec.
# 795-th simulation finished, 0.005679 sec.
# 796-th simulation finished, 0.006855 sec.
# 797-th simulation finished, 0.009300 sec.
# 798-th simulation finished, 0.011881 sec.
# 799-th simulation finished, 0.014106 sec.
# 800-th simulation finished, 0.012538 sec.
# 801-th simulation finished, 0.007691 sec.
# 802-th simulation finished, 0.007045 sec.
# 803-th simulation finished, 0.010365 sec.
# 804-th simulation finished, 0.007186 sec.
# 805-th simulation finished, 0.011229 sec.
# 806-th simulation finished, 0.005488 sec.
# 807-th simulation finished, 0.009119 sec.
# 808-th simulation finished, 0.012754 sec.
# 809-th simulation finished, 0.005538 sec.
# 810-th simulation finished, 0.009750 sec.
# 811-th simulation finished, 0.016523 sec.
# 812-th simulation finished, 0.005440 sec.
# 813-th simulation finished, 0.013843 sec.
# 814-th simulation finished, 0.013638 sec.
# 815-th simulation finished, 0.009621 sec.
# 816-th simulation finished, 0.008915 sec.
# 817-th simulation finished, 0.019887 sec.
# 818-th simulation finished, 0.009457 sec.
# 819-th simulation finished, 0.009761 sec.
# 820-th simulation finished, 0.006798 sec.
# 821-th simulation finished, 0.007646 sec.
# 822-th simulation finished, 0.006429 sec.
# 823-th simulation finished, 0.006927 sec.
# 824-th simulation finished, 0.011128 sec.
# 825-th simulation finished, 0.006959 sec.
# 826-th simulation finished, 0.006383 sec.
# 827-th simulation finished, 0.010171 sec.
# 828-th simulation finished, 0.005566 sec.
# 829-th simulation finished, 0.004524 sec.
# 830-th simulation finished, 0.005850 sec.
# 831-th simulation finished, 0.005928 sec.
# 832-th simulation finished, 0.006031 sec.
# 833-th simulation finished, 0.009768 sec.
# 834-th simulation finished, 0.006377 sec.
# 835-th simulation finished, 0.004801 sec.
# 836-th simulation finished, 0.005616 sec.
# 837-th simulation finished, 0.008512 sec.
# 838-th simulation finished, 0.009921 sec.
# 839-th simulation finished, 0.011220 sec.
# 840-th simulation finished, 0.003306 sec.
# 841-th simulation finished, 0.006352 sec.
# 842-th simulation finished, 0.006236 sec.
# 843-th simulation finished, 0.005743 sec.
# 844-th simulation finished, 0.008204 sec.
# 845-th simulation finished, 0.016557 sec.
# 846-th simulation finished, 0.005847 sec.
# 847-th simulation finished, 0.008303 sec.
# 848-th simulation finished, 0.005551 sec.
# 849-th simulation finished, 0.004801 sec.
# 850-th simulation finished, 0.004191 sec.
# 851-th simulation finished, 0.005428 sec.
# 852-th simulation finished, 0.007253 sec.
# 853-th simulation finished, 0.007282 sec.
# 854-th simulation finished, 0.009842 sec.
# 855-th simulation finished, 0.011211 sec.
# 856-th simulation finished, 0.010699 sec.
# 857-th simulation finished, 0.007482 sec.
# 858-th simulation finished, 0.004601 sec.
# 859-th simulation finished, 0.006902 sec.
# 860-th simulation finished, 0.019517 sec.
# 861-th simulation finished, 0.005537 sec.
# 862-th simulation finished, 0.013696 sec.
# 863-th simulation finished, 0.007558 sec.
# 864-th simulation finished, 0.005881 sec.
# 865-th simulation finished, 0.004859 sec.
# 866-th simulation finished, 0.005660 sec.
# 867-th simulation finished, 0.006040 sec.
# 868-th simulation finished, 0.005644 sec.
# 869-th simulation finished, 0.005438 sec.
# 870-th simulation finished, 0.006302 sec.
# 871-th simulation finished, 0.007768 sec.
# 872-th simulation finished, 0.010902 sec.
# 873-th simulation finished, 0.008662 sec.
# 874-th simulation finished, 0.057600 sec.
# 875-th simulation finished, 0.003564 sec.
# 876-th simulation finished, 0.005805 sec.
# 877-th simulation finished, 0.021800 sec.
# 878-th simulation finished, 0.014876 sec.
# 879-th simulation finished, 0.005971 sec.
# 880-th simulation finished, 0.121842 sec.
# 881-th simulation finished, 0.008474 sec.
# 882-th simulation finished, 0.011670 sec.
# 883-th simulation finished, 0.013125 sec.
# 884-th simulation finished, 0.013250 sec.
# 885-th simulation finished, 0.008489 sec.
# 886-th simulation finished, 0.008384 sec.
# 887-th simulation finished, 0.007976 sec.
# 888-th simulation finished, 0.006938 sec.
# 889-th simulation finished, 0.010996 sec.
# 890-th simulation finished, 0.013574 sec.
# 891-th simulation finished, 0.005546 sec.
# 892-th simulation finished, 0.010938 sec.
# 893-th simulation finished, 0.013760 sec.
# 894-th simulation finished, 0.008391 sec.
# 895-th simulation finished, 0.011879 sec.
# 896-th simulation finished, 0.008151 sec.
# 897-th simulation finished, 0.008475 sec.
# 898-th simulation finished, 0.012560 sec.
# 899-th simulation finished, 0.006147 sec.
# 900-th simulation finished, 0.024093 sec.
# 901-th simulation finished, 0.014135 sec.
# 902-th simulation finished, 0.012400 sec.
# 903-th simulation finished, 0.011545 sec.
# 904-th simulation finished, 0.005564 sec.
# 905-th simulation finished, 0.005565 sec.
# 906-th simulation finished, 0.004886 sec.
# 907-th simulation finished, 0.003468 sec.
# 908-th simulation finished, 0.003034 sec.
# 909-th simulation finished, 0.003229 sec.
# 910-th simulation finished, 0.005596 sec.
# 911-th simulation finished, 0.006178 sec.
# 912-th simulation finished, 0.005646 sec.
# 913-th simulation finished, 0.004124 sec.
# 914-th simulation finished, 0.005544 sec.
# 915-th simulation finished, 0.003293 sec.
# 916-th simulation finished, 0.005875 sec.
# 917-th simulation finished, 0.005187 sec.
# 918-th simulation finished, 0.005612 sec.
# 919-th simulation finished, 0.005595 sec.
# 920-th simulation finished, 0.005703 sec.
# 921-th simulation finished, 0.004931 sec.
# 922-th simulation finished, 0.005170 sec.
# 923-th simulation finished, 0.005815 sec.
# 924-th simulation finished, 0.003491 sec.
# 925-th simulation finished, 0.003618 sec.
# 926-th simulation finished, 0.006485 sec.
# 927-th simulation finished, 0.003943 sec.

# %%
plt.hist(Ts_sdw)
# Out:
# (array([ 17.,  56., 260., 326., 175.,  67.,  12.,   7.,   4.,   3.]),
#  array([-3.75387234, -2.66757276, -1.58127317, -0.49497359,  0.591326  ,
#          1.67762558,  2.76392516,  3.85022475,  4.93652433,  6.02282391,
#          7.1091235 ]),
#  <BarContainer object of 10 artists>)

# %%
stats.probplot(ps_sdw, dist = 'uniform', plot=plt, fit=False)
plt.plot([0, 1], [0, 1], c='black')
plt.show()

# %%
np.mean(np.abs(Ts_sdw) < stats.norm.ppf(0.975))
# Out:
# 0.8791801510248112
