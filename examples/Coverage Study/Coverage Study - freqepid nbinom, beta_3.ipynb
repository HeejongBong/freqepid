# %%
import os, importlib, sys, time

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import scipy.linalg as la
import scipy.stats as stats
import scipy.optimize as opt

# %%
import freqepid

# %% [markdown]
# # 1. parameters

# %%
T = 60
T0 = 40

# %%
GPi = np.load('data/GPi.npz')

# %% [markdown]
# ## observation parameters

# %%
alpha = 0.01
r_Y = 10

# %% [markdown]
# $$Y_t = NegBinom( \frac{EY_t}{r_Y + EY_t}, r_Y )$$
#
# $$ EY_t = \alpha\sum_{s=1}^{t-1} I_s \pi_{t-s} $$

# %% [markdown]
# ## latent parameters

# %%
d = 2
beta = np.array([0.75, -2.95])

# %%
r_I = 100
K = 6.5

# %% [markdown]
# $$I_t = NegBinom( \frac{EI_t}{r_I + EI_t}, r_I )$$
#
# $$ EI_t = R(\bar{A}_t, \beta) \sum_{s=1}^{t-1} I_s g_{t-s} $$
#
# $$R(\bar{A}_t, \beta) = \frac{K}{1+\exp(- \beta^\top A_t)}$$

# %% [markdown]
# ## seed values

# %%
mu = np.log(100)

# %% [markdown]
# $$I_{[-T_0,0)} = \exp(\mu_0)$$

# %% [markdown]
# # 2. simulation

# %%
num_sim = 1000

# %% [markdown]
# ## load simulation

# %%
data = pd.read_feather('data/simulation_randinf_3.feather')

# %%
data
# Out:
#        sim  date         R          EI  infection         EY  death  \
# 0        0     0  4.414662  441.463115      480.0   0.956069      1
# 1        0     1  4.414662  472.207524      475.0   0.962545      0
# 2        0     2  4.414662  583.517000      588.0   0.968338      1
# 3        0     3  4.414662  762.157505      670.0   0.974015      1
# 4        0     4  4.414662  997.240682      955.0   0.981203      0
# ...    ...   ...       ...         ...        ...        ...    ...
# 59995  999    55  0.648378  686.970707      727.0  28.330299     27
# 59996  999    56  0.648378  653.139142      671.0  26.949973     22
# 59997  999    57  0.648378  620.762316      653.0  25.620683     22
# 59998  999    58  0.648378  589.514828      716.0  24.328280     22
# 59999  999    59  0.648378  560.923823      596.0  23.094372     22
#
#        intervention
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 59995             1
# 59996             1
# 59997             1
# 59998             1
# 59999             1
#
# [60000 rows x 8 columns]

# %% [markdown]
# # 3. Fit

# %%
model = freqepid.Model(GPi['g'], GPi['pi'], alpha, K, T0, "nbinom")

# %%
nsim = np.zeros(num_sim)
msim = np.zeros(num_sim)
bsim = np.zeros((num_sim,d))

# %%
for iter_sim in np.arange(num_sim):
    start_sim = time.time()
    
    data_i = data[data['sim']==iter_sim]
    A = np.stack([np.full(T, 1), data_i["intervention"].to_numpy()], -1)
    Y = data_i["death"].to_numpy()
    
    # fit
    nmle, mmle, bmle, ll =\
    model.fit(A, Y, n_iter=500, step_size=1,
              history=False, verbose=False)
    
    nsim[iter_sim] = nmle
    msim[iter_sim] = mmle
    bsim[iter_sim,:] = bmle
    
    sys.__stdout__.write("%d-th simulation finished, %f sec.\n"
                         %(iter_sim+1, time.time()-start_sim))
    sys.__stdout__.flush()
# Out:
# /Users/blueconet/mambaforge/envs/freqepid/lib/python3.10/site-packages/freqepid/model.py:140: FutureWarning: `rcond` parameter will change to the default of machine precision times ``max(M, N)`` where M and N are the input matrix dimensions.
# To use the future default and silence this warning we advise to pass `rcond=None`, to keep using the old, explicitly pass `rcond=-1`.
#   bhaty = np.linalg.lstsq(Xy, Yy)[0]
# 1-th simulation finished, 3.670403 sec.
# 2-th simulation finished, 3.626230 sec.
# 3-th simulation finished, 3.373973 sec.
# 4-th simulation finished, 3.498934 sec.
# 5-th simulation finished, 3.459901 sec.
# 6-th simulation finished, 3.505938 sec.
# 7-th simulation finished, 3.787037 sec.
# 8-th simulation finished, 3.604221 sec.
# 9-th simulation finished, 3.512252 sec.
# 10-th simulation finished, 3.501702 sec.
# 11-th simulation finished, 3.491172 sec.
# 12-th simulation finished, 3.268810 sec.
# 13-th simulation finished, 3.382079 sec.
# 14-th simulation finished, 3.990385 sec.
# 15-th simulation finished, 4.324591 sec.
# 16-th simulation finished, 3.479277 sec.
# 17-th simulation finished, 3.569700 sec.
# 18-th simulation finished, 3.592837 sec.
# 19-th simulation finished, 3.683398 sec.
# 20-th simulation finished, 3.182866 sec.
# 21-th simulation finished, 3.459124 sec.
# 22-th simulation finished, 3.399015 sec.
# 23-th simulation finished, 3.597824 sec.
# 24-th simulation finished, 3.711947 sec.
# 25-th simulation finished, 3.637277 sec.
# 26-th simulation finished, 3.459581 sec.
# 27-th simulation finished, 3.727926 sec.
# 28-th simulation finished, 3.674980 sec.
# 29-th simulation finished, 3.557893 sec.
# 30-th simulation finished, 3.373005 sec.
# 31-th simulation finished, 3.385492 sec.
# 32-th simulation finished, 3.197679 sec.
# 33-th simulation finished, 3.521657 sec.
# 34-th simulation finished, 3.379708 sec.
# 35-th simulation finished, 3.815289 sec.
# 36-th simulation finished, 3.396006 sec.
# 37-th simulation finished, 3.769561 sec.
# 38-th simulation finished, 3.687913 sec.
# 39-th simulation finished, 3.304683 sec.
# 40-th simulation finished, 3.381297 sec.
# 41-th simulation finished, 3.488695 sec.
# 42-th simulation finished, 3.463703 sec.
# 43-th simulation finished, 3.570794 sec.
# 44-th simulation finished, 3.652151 sec.
# 45-th simulation finished, 3.255326 sec.
# 46-th simulation finished, 3.144292 sec.
# 47-th simulation finished, 3.373584 sec.
# 48-th simulation finished, 3.462013 sec.
# 49-th simulation finished, 3.401221 sec.
# 50-th simulation finished, 3.488850 sec.
# 51-th simulation finished, 3.372555 sec.
# 52-th simulation finished, 3.427460 sec.
# 53-th simulation finished, 3.393103 sec.
# 54-th simulation finished, 3.783505 sec.
# 55-th simulation finished, 3.545498 sec.
# 56-th simulation finished, 3.392357 sec.
# 57-th simulation finished, 3.474342 sec.
# 58-th simulation finished, 3.495374 sec.
# 59-th simulation finished, 3.434183 sec.
# 60-th simulation finished, 3.588125 sec.
# 61-th simulation finished, 3.887213 sec.
# 62-th simulation finished, 4.160001 sec.
# 63-th simulation finished, 3.490190 sec.
# 64-th simulation finished, 3.233342 sec.
# 65-th simulation finished, 3.876298 sec.
# 66-th simulation finished, 3.549156 sec.
# 67-th simulation finished, 3.381164 sec.
# 68-th simulation finished, 3.447305 sec.
# 69-th simulation finished, 3.724412 sec.
# 70-th simulation finished, 3.536297 sec.
# 71-th simulation finished, 3.775551 sec.
# 72-th simulation finished, 3.414732 sec.
# 73-th simulation finished, 3.756290 sec.
# 74-th simulation finished, 3.453520 sec.
# 75-th simulation finished, 3.308820 sec.
# 76-th simulation finished, 3.490426 sec.
# 77-th simulation finished, 3.542725 sec.
# 78-th simulation finished, 3.462268 sec.
# 79-th simulation finished, 3.366484 sec.
# 80-th simulation finished, 3.396197 sec.
# 81-th simulation finished, 3.309366 sec.
# 82-th simulation finished, 3.842399 sec.
# 83-th simulation finished, 3.694342 sec.
# 84-th simulation finished, 3.182739 sec.
# 85-th simulation finished, 3.384052 sec.
# 86-th simulation finished, 3.356306 sec.
# 87-th simulation finished, 3.348712 sec.
# 88-th simulation finished, 3.500502 sec.
# 89-th simulation finished, 3.493260 sec.
# 90-th simulation finished, 3.879455 sec.
# 91-th simulation finished, 3.733880 sec.
# 92-th simulation finished, 3.648071 sec.
# 93-th simulation finished, 3.285053 sec.
# 94-th simulation finished, 3.224311 sec.
# 95-th simulation finished, 3.571243 sec.
# 96-th simulation finished, 3.453507 sec.
# 97-th simulation finished, 3.668058 sec.
# 98-th simulation finished, 3.519345 sec.
# 99-th simulation finished, 3.539604 sec.
# 100-th simulation finished, 3.448950 sec.
# 101-th simulation finished, 3.430981 sec.
# 102-th simulation finished, 3.486951 sec.
# 103-th simulation finished, 3.809458 sec.
# 104-th simulation finished, 3.339928 sec.
# 105-th simulation finished, 3.714857 sec.
# 106-th simulation finished, 3.415993 sec.
# 107-th simulation finished, 3.603032 sec.
# 108-th simulation finished, 3.436267 sec.
# 109-th simulation finished, 3.357645 sec.
# 110-th simulation finished, 3.471150 sec.
# 111-th simulation finished, 3.642398 sec.
# 112-th simulation finished, 3.735388 sec.
# 113-th simulation finished, 3.361567 sec.
# 114-th simulation finished, 3.439445 sec.
# 115-th simulation finished, 3.648715 sec.
# 116-th simulation finished, 3.374034 sec.
# 117-th simulation finished, 3.101799 sec.
# 118-th simulation finished, 3.479447 sec.
# 119-th simulation finished, 3.543153 sec.
# 120-th simulation finished, 3.659734 sec.
# 121-th simulation finished, 3.512972 sec.
# 122-th simulation finished, 3.507945 sec.
# 123-th simulation finished, 3.516401 sec.
# 124-th simulation finished, 3.714583 sec.
# 125-th simulation finished, 3.453553 sec.
# 126-th simulation finished, 3.654087 sec.
# 127-th simulation finished, 3.463259 sec.
# 128-th simulation finished, 3.390469 sec.
# 129-th simulation finished, 3.640587 sec.
# 130-th simulation finished, 3.695364 sec.
# 131-th simulation finished, 3.182229 sec.
# 132-th simulation finished, 3.409876 sec.
# 133-th simulation finished, 3.372622 sec.
# 134-th simulation finished, 3.471006 sec.
# 135-th simulation finished, 3.376611 sec.
# 136-th simulation finished, 3.425540 sec.
# 137-th simulation finished, 3.602526 sec.
# 138-th simulation finished, 3.324469 sec.
# 139-th simulation finished, 3.575425 sec.
# 140-th simulation finished, 3.622059 sec.
# 141-th simulation finished, 3.624637 sec.
# 142-th simulation finished, 3.649876 sec.
# 143-th simulation finished, 4.091852 sec.
# 144-th simulation finished, 3.290746 sec.
# 145-th simulation finished, 3.587086 sec.
# 146-th simulation finished, 3.475444 sec.
# 147-th simulation finished, 3.437931 sec.
# 148-th simulation finished, 3.482317 sec.
# 149-th simulation finished, 3.444275 sec.
# 150-th simulation finished, 3.369847 sec.
# 151-th simulation finished, 3.283262 sec.
# 152-th simulation finished, 3.584906 sec.
# 153-th simulation finished, 3.297940 sec.
# 154-th simulation finished, 3.246235 sec.
# 155-th simulation finished, 3.750174 sec.
# 156-th simulation finished, 3.252072 sec.
# 157-th simulation finished, 3.429902 sec.
# 158-th simulation finished, 3.543213 sec.
# 159-th simulation finished, 3.331147 sec.
# 160-th simulation finished, 3.524750 sec.
# 161-th simulation finished, 3.461568 sec.
# 162-th simulation finished, 3.514500 sec.
# 163-th simulation finished, 3.607499 sec.
# 164-th simulation finished, 3.972859 sec.
# 165-th simulation finished, 3.439661 sec.
# 166-th simulation finished, 3.928443 sec.
# 167-th simulation finished, 4.112879 sec.
# 168-th simulation finished, 3.403126 sec.
# 169-th simulation finished, 3.535179 sec.
# 170-th simulation finished, 4.074320 sec.
# 171-th simulation finished, 4.050058 sec.
# 172-th simulation finished, 3.480981 sec.
# 173-th simulation finished, 3.599591 sec.
# 174-th simulation finished, 3.342201 sec.
# 175-th simulation finished, 3.387532 sec.
# 176-th simulation finished, 3.334259 sec.
# 177-th simulation finished, 3.449273 sec.
# 178-th simulation finished, 3.362156 sec.
# 179-th simulation finished, 3.748705 sec.
# 180-th simulation finished, 3.274602 sec.
# 181-th simulation finished, 3.257611 sec.
# 182-th simulation finished, 3.211123 sec.
# 183-th simulation finished, 3.234923 sec.
# 184-th simulation finished, 3.396672 sec.
# 185-th simulation finished, 3.491509 sec.
# 186-th simulation finished, 3.420643 sec.
# 187-th simulation finished, 3.580142 sec.
# 188-th simulation finished, 3.493020 sec.
# 189-th simulation finished, 3.508341 sec.
# 190-th simulation finished, 3.371543 sec.
# 191-th simulation finished, 3.457089 sec.
# 192-th simulation finished, 3.398386 sec.
# 193-th simulation finished, 3.878815 sec.
# 194-th simulation finished, 3.481948 sec.
# 195-th simulation finished, 3.586871 sec.
# 196-th simulation finished, 3.403391 sec.
# 197-th simulation finished, 3.425969 sec.
# 198-th simulation finished, 3.610756 sec.
# 199-th simulation finished, 3.553466 sec.
# 200-th simulation finished, 3.534285 sec.
# 201-th simulation finished, 3.493871 sec.
# 202-th simulation finished, 3.509472 sec.
# 203-th simulation finished, 3.477075 sec.
# 204-th simulation finished, 3.397436 sec.
# 205-th simulation finished, 3.667896 sec.
# 206-th simulation finished, 3.332660 sec.
# 207-th simulation finished, 3.437609 sec.
# 208-th simulation finished, 3.130658 sec.
# 209-th simulation finished, 3.957481 sec.
# 210-th simulation finished, 3.382828 sec.
# 211-th simulation finished, 3.698038 sec.
# 212-th simulation finished, 3.222483 sec.
# 213-th simulation finished, 3.442986 sec.
# 214-th simulation finished, 3.184535 sec.
# 215-th simulation finished, 3.437384 sec.
# 216-th simulation finished, 3.337457 sec.
# 217-th simulation finished, 3.127741 sec.
# 218-th simulation finished, 3.254651 sec.
# 219-th simulation finished, 3.454319 sec.
# 220-th simulation finished, 3.832863 sec.
# 221-th simulation finished, 3.410488 sec.
# 222-th simulation finished, 3.739906 sec.
# 223-th simulation finished, 3.723997 sec.
# 224-th simulation finished, 3.496967 sec.
# 225-th simulation finished, 3.455330 sec.
# 226-th simulation finished, 3.728398 sec.
# 227-th simulation finished, 3.412724 sec.
# 228-th simulation finished, 3.220562 sec.
# 229-th simulation finished, 3.388184 sec.
# 230-th simulation finished, 3.433005 sec.
# 231-th simulation finished, 3.760465 sec.
# 232-th simulation finished, 3.444743 sec.
# 233-th simulation finished, 3.180305 sec.
# 234-th simulation finished, 3.515934 sec.
# 235-th simulation finished, 3.344997 sec.
# 236-th simulation finished, 3.350257 sec.
# 237-th simulation finished, 3.495176 sec.
# 238-th simulation finished, 3.479252 sec.
# 239-th simulation finished, 3.452336 sec.
# 240-th simulation finished, 3.437046 sec.
# 241-th simulation finished, 3.326538 sec.
# 242-th simulation finished, 4.040940 sec.
# 243-th simulation finished, 3.617029 sec.
# 244-th simulation finished, 3.931779 sec.
# 245-th simulation finished, 3.861866 sec.
# 246-th simulation finished, 3.443424 sec.
# 247-th simulation finished, 3.947674 sec.
# 248-th simulation finished, 3.463066 sec.
# 249-th simulation finished, 3.468596 sec.
# 250-th simulation finished, 3.302757 sec.
# 251-th simulation finished, 3.128214 sec.
# 252-th simulation finished, 3.230377 sec.
# 253-th simulation finished, 3.323087 sec.
# 254-th simulation finished, 3.468354 sec.
# 255-th simulation finished, 3.365969 sec.
# 256-th simulation finished, 3.934344 sec.
# 257-th simulation finished, 3.752150 sec.
# 258-th simulation finished, 3.592099 sec.
# 259-th simulation finished, 3.435499 sec.
# 260-th simulation finished, 3.374279 sec.
# 261-th simulation finished, 3.511807 sec.
# 262-th simulation finished, 3.706716 sec.
# 263-th simulation finished, 3.980981 sec.
# 264-th simulation finished, 3.684502 sec.
# 265-th simulation finished, 3.170500 sec.
# 266-th simulation finished, 3.324744 sec.
# 267-th simulation finished, 3.311756 sec.
# 268-th simulation finished, 3.392879 sec.
# 269-th simulation finished, 3.688558 sec.
# 270-th simulation finished, 3.471918 sec.
# 271-th simulation finished, 3.044625 sec.
# 272-th simulation finished, 3.329295 sec.
# 273-th simulation finished, 3.478816 sec.
# 274-th simulation finished, 3.386615 sec.
# 275-th simulation finished, 3.562819 sec.
# 276-th simulation finished, 3.547718 sec.
# 277-th simulation finished, 3.491223 sec.
# 278-th simulation finished, 3.259844 sec.
# 279-th simulation finished, 3.606003 sec.
# 280-th simulation finished, 3.665545 sec.
# 281-th simulation finished, 3.457139 sec.
# 282-th simulation finished, 3.426851 sec.
# 283-th simulation finished, 4.138048 sec.
# 284-th simulation finished, 3.457737 sec.
# 285-th simulation finished, 3.423118 sec.
# 286-th simulation finished, 3.458669 sec.
# 287-th simulation finished, 3.396063 sec.
# 288-th simulation finished, 3.269450 sec.
# 289-th simulation finished, 3.498818 sec.
# 290-th simulation finished, 3.464043 sec.
# 291-th simulation finished, 3.472960 sec.
# 292-th simulation finished, 3.152279 sec.
# 293-th simulation finished, 3.195604 sec.
# 294-th simulation finished, 3.610106 sec.
# 295-th simulation finished, 3.500448 sec.
# 296-th simulation finished, 3.478300 sec.
# 297-th simulation finished, 3.632784 sec.
# 298-th simulation finished, 3.299287 sec.
# 299-th simulation finished, 3.383657 sec.
# 300-th simulation finished, 3.404440 sec.
# 301-th simulation finished, 3.612738 sec.
# 302-th simulation finished, 3.445345 sec.
# 303-th simulation finished, 3.285890 sec.
# 304-th simulation finished, 3.376386 sec.
# 305-th simulation finished, 3.541804 sec.
# 306-th simulation finished, 3.173551 sec.
# 307-th simulation finished, 3.880657 sec.
# 308-th simulation finished, 3.423592 sec.
# 309-th simulation finished, 3.543249 sec.
# 310-th simulation finished, 3.393286 sec.
# 311-th simulation finished, 3.664505 sec.
# 312-th simulation finished, 3.510430 sec.
# 313-th simulation finished, 3.586121 sec.
# 314-th simulation finished, 3.694650 sec.
# 315-th simulation finished, 3.245434 sec.
# 316-th simulation finished, 3.719889 sec.
# 317-th simulation finished, 3.836264 sec.
# 318-th simulation finished, 3.439588 sec.
# 319-th simulation finished, 3.571515 sec.
# 320-th simulation finished, 3.562064 sec.
# 321-th simulation finished, 3.383654 sec.
# 322-th simulation finished, 3.320518 sec.
# 323-th simulation finished, 3.627347 sec.
# 324-th simulation finished, 3.480300 sec.
# 325-th simulation finished, 3.395216 sec.
# 326-th simulation finished, 4.439452 sec.
# 327-th simulation finished, 4.153385 sec.
# 328-th simulation finished, 3.574051 sec.
# 329-th simulation finished, 3.125718 sec.
# 330-th simulation finished, 3.633874 sec.
# 331-th simulation finished, 3.490448 sec.
# 332-th simulation finished, 3.571336 sec.
# 333-th simulation finished, 3.409783 sec.
# 334-th simulation finished, 3.641345 sec.
# 335-th simulation finished, 3.240639 sec.
# 336-th simulation finished, 3.418033 sec.
# 337-th simulation finished, 3.382364 sec.
# 338-th simulation finished, 3.554794 sec.
# 339-th simulation finished, 3.381004 sec.
# 340-th simulation finished, 3.566848 sec.
# 341-th simulation finished, 3.329553 sec.
# 342-th simulation finished, 3.357759 sec.
# 343-th simulation finished, 3.478518 sec.
# 344-th simulation finished, 3.361123 sec.
# 345-th simulation finished, 3.476899 sec.
# 346-th simulation finished, 3.369705 sec.
# 347-th simulation finished, 3.211539 sec.
# 348-th simulation finished, 3.473825 sec.
# 349-th simulation finished, 3.232616 sec.
# 350-th simulation finished, 3.398417 sec.
# 351-th simulation finished, 3.552252 sec.
# 352-th simulation finished, 3.557656 sec.
# 353-th simulation finished, 3.409249 sec.
# 354-th simulation finished, 3.452199 sec.
# 355-th simulation finished, 3.304313 sec.
# 356-th simulation finished, 3.467430 sec.
# 357-th simulation finished, 3.471197 sec.
# 358-th simulation finished, 3.929128 sec.
# 359-th simulation finished, 4.128185 sec.
# 360-th simulation finished, 3.761418 sec.
# 361-th simulation finished, 3.553904 sec.
# 362-th simulation finished, 3.104415 sec.
# 363-th simulation finished, 3.254092 sec.
# 364-th simulation finished, 3.483607 sec.
# 365-th simulation finished, 3.416056 sec.
# 366-th simulation finished, 3.237304 sec.
# 367-th simulation finished, 3.665820 sec.
# 368-th simulation finished, 3.493429 sec.
# 369-th simulation finished, 3.600894 sec.
# 370-th simulation finished, 3.331856 sec.
# 371-th simulation finished, 3.765089 sec.
# 372-th simulation finished, 3.563350 sec.
# 373-th simulation finished, 3.357220 sec.
# 374-th simulation finished, 3.381657 sec.
# 375-th simulation finished, 3.496255 sec.
# 376-th simulation finished, 3.543655 sec.
# 377-th simulation finished, 3.479830 sec.
# 378-th simulation finished, 3.611790 sec.
# 379-th simulation finished, 3.595696 sec.
# 380-th simulation finished, 3.545895 sec.
# 381-th simulation finished, 3.158992 sec.
# 382-th simulation finished, 3.196250 sec.
# 383-th simulation finished, 3.486572 sec.
# 384-th simulation finished, 4.010996 sec.
# 385-th simulation finished, 3.580071 sec.
# 386-th simulation finished, 3.384015 sec.
# 387-th simulation finished, 3.255972 sec.
# 388-th simulation finished, 3.751465 sec.
# 389-th simulation finished, 3.227065 sec.
# 390-th simulation finished, 3.473722 sec.
# 391-th simulation finished, 3.308025 sec.
# 392-th simulation finished, 3.491436 sec.
# 393-th simulation finished, 3.193245 sec.
# 394-th simulation finished, 3.349285 sec.
# 395-th simulation finished, 3.226229 sec.
# 396-th simulation finished, 3.407548 sec.
# 397-th simulation finished, 3.305044 sec.
# 398-th simulation finished, 3.380936 sec.
# 399-th simulation finished, 3.246534 sec.
# 400-th simulation finished, 3.471140 sec.
# 401-th simulation finished, 3.561502 sec.
# 402-th simulation finished, 3.252157 sec.
# 403-th simulation finished, 3.703674 sec.
# 404-th simulation finished, 3.327440 sec.
# 405-th simulation finished, 3.469507 sec.
# 406-th simulation finished, 3.509283 sec.
# 407-th simulation finished, 3.340868 sec.
# 408-th simulation finished, 3.230602 sec.
# 409-th simulation finished, 3.345206 sec.
# 410-th simulation finished, 3.378175 sec.
# 411-th simulation finished, 3.524541 sec.
# 412-th simulation finished, 3.653397 sec.
# 413-th simulation finished, 3.300928 sec.
# 414-th simulation finished, 3.427385 sec.
# 415-th simulation finished, 3.694513 sec.
# 416-th simulation finished, 3.379089 sec.
# 417-th simulation finished, 3.458874 sec.
# 418-th simulation finished, 3.670616 sec.
# 419-th simulation finished, 3.840072 sec.
# 420-th simulation finished, 3.325947 sec.
# 421-th simulation finished, 3.465586 sec.
# 422-th simulation finished, 3.712625 sec.
# 423-th simulation finished, 3.359219 sec.
# 424-th simulation finished, 3.480340 sec.
# 425-th simulation finished, 3.764012 sec.
# 426-th simulation finished, 3.315018 sec.
# 427-th simulation finished, 3.409007 sec.
# 428-th simulation finished, 3.255204 sec.
# 429-th simulation finished, 3.967273 sec.
# 430-th simulation finished, 3.203928 sec.
# 431-th simulation finished, 3.363573 sec.
# 432-th simulation finished, 3.433285 sec.
# 433-th simulation finished, 3.639455 sec.
# 434-th simulation finished, 3.368986 sec.
# 435-th simulation finished, 3.358967 sec.
# 436-th simulation finished, 3.495124 sec.
# 437-th simulation finished, 3.234106 sec.
# 438-th simulation finished, 3.822571 sec.
# 439-th simulation finished, 3.219708 sec.
# 440-th simulation finished, 3.446472 sec.
# 441-th simulation finished, 3.639825 sec.
# 442-th simulation finished, 3.134003 sec.
# 443-th simulation finished, 3.481823 sec.
# 444-th simulation finished, 3.650842 sec.
# 445-th simulation finished, 3.650657 sec.
# 446-th simulation finished, 3.307110 sec.
# 447-th simulation finished, 3.413940 sec.
# 448-th simulation finished, 3.348854 sec.
# 449-th simulation finished, 3.275333 sec.
# 450-th simulation finished, 3.538953 sec.
# 451-th simulation finished, 3.650481 sec.
# 452-th simulation finished, 3.770479 sec.
# 453-th simulation finished, 3.304782 sec.
# 454-th simulation finished, 3.266026 sec.
# 455-th simulation finished, 3.454567 sec.
# 456-th simulation finished, 3.290745 sec.
# 457-th simulation finished, 3.249404 sec.
# 458-th simulation finished, 3.405829 sec.
# 459-th simulation finished, 3.826798 sec.
# 460-th simulation finished, 3.407483 sec.
# 461-th simulation finished, 3.149951 sec.
# 462-th simulation finished, 3.286635 sec.
# 463-th simulation finished, 3.017646 sec.
# 464-th simulation finished, 3.116309 sec.
# 465-th simulation finished, 3.130801 sec.
# 466-th simulation finished, 3.171074 sec.
# 467-th simulation finished, 3.320773 sec.
# 468-th simulation finished, 3.081488 sec.
# 469-th simulation finished, 3.183028 sec.
# 470-th simulation finished, 3.000550 sec.
# 471-th simulation finished, 3.098041 sec.
# 472-th simulation finished, 3.250925 sec.
# 473-th simulation finished, 3.260349 sec.
# 474-th simulation finished, 3.045028 sec.
# 475-th simulation finished, 4.109187 sec.
# 476-th simulation finished, 3.758216 sec.
# 477-th simulation finished, 3.186390 sec.
# 478-th simulation finished, 3.297141 sec.
# 479-th simulation finished, 3.185070 sec.
# 480-th simulation finished, 3.145637 sec.
# 481-th simulation finished, 3.240228 sec.
# 482-th simulation finished, 3.069543 sec.
# 483-th simulation finished, 3.441170 sec.
# 484-th simulation finished, 3.211687 sec.
# 485-th simulation finished, 3.502031 sec.
# 486-th simulation finished, 3.479970 sec.
# 487-th simulation finished, 3.657479 sec.
# 488-th simulation finished, 3.704136 sec.
# 489-th simulation finished, 3.412666 sec.
# 490-th simulation finished, 3.581464 sec.
# 491-th simulation finished, 3.915452 sec.
# 492-th simulation finished, 3.606739 sec.
# 493-th simulation finished, 3.552163 sec.
# 494-th simulation finished, 3.595712 sec.
# 495-th simulation finished, 3.613533 sec.
# 496-th simulation finished, 3.629086 sec.
# 497-th simulation finished, 3.545330 sec.
# 498-th simulation finished, 3.464698 sec.
# 499-th simulation finished, 3.427952 sec.
# 500-th simulation finished, 4.384948 sec.
# 501-th simulation finished, 3.510034 sec.
# 502-th simulation finished, 4.025115 sec.
# 503-th simulation finished, 3.661586 sec.
# 504-th simulation finished, 3.407296 sec.
# 505-th simulation finished, 4.365345 sec.
# 506-th simulation finished, 3.584658 sec.
# 507-th simulation finished, 4.195625 sec.
# 508-th simulation finished, 4.278565 sec.
# 509-th simulation finished, 4.180272 sec.
# 510-th simulation finished, 3.825554 sec.
# 511-th simulation finished, 3.395887 sec.
# 512-th simulation finished, 3.306913 sec.
# 513-th simulation finished, 3.396563 sec.
# 514-th simulation finished, 4.034100 sec.
# 515-th simulation finished, 3.369245 sec.
# 516-th simulation finished, 3.864483 sec.
# 517-th simulation finished, 3.525413 sec.
# 518-th simulation finished, 3.416290 sec.
# 519-th simulation finished, 3.667175 sec.
# 520-th simulation finished, 3.604862 sec.
# 521-th simulation finished, 3.310300 sec.
# 522-th simulation finished, 3.445707 sec.
# 523-th simulation finished, 3.505351 sec.
# 524-th simulation finished, 3.432969 sec.
# 525-th simulation finished, 3.388865 sec.
# 526-th simulation finished, 3.320401 sec.
# 527-th simulation finished, 3.525250 sec.
# 528-th simulation finished, 3.678795 sec.
# 529-th simulation finished, 3.444115 sec.
# 530-th simulation finished, 3.761822 sec.
# 531-th simulation finished, 3.480087 sec.
# 532-th simulation finished, 3.473654 sec.
# 533-th simulation finished, 3.537336 sec.
# 534-th simulation finished, 3.371173 sec.
# 535-th simulation finished, 3.370570 sec.
# 536-th simulation finished, 3.467180 sec.
# 537-th simulation finished, 3.306701 sec.
# 538-th simulation finished, 3.213130 sec.
# 539-th simulation finished, 3.414283 sec.
# 540-th simulation finished, 3.433203 sec.
# 541-th simulation finished, 3.314626 sec.
# 542-th simulation finished, 3.576426 sec.
# 543-th simulation finished, 3.311224 sec.
# 544-th simulation finished, 3.301758 sec.
# 545-th simulation finished, 3.434010 sec.
# 546-th simulation finished, 3.478685 sec.
# 547-th simulation finished, 3.502846 sec.
# 548-th simulation finished, 3.462202 sec.
# 549-th simulation finished, 3.668008 sec.
# 550-th simulation finished, 3.485712 sec.
# 551-th simulation finished, 3.366694 sec.
# 552-th simulation finished, 3.557722 sec.
# 553-th simulation finished, 3.486961 sec.
# 554-th simulation finished, 3.312865 sec.
# 555-th simulation finished, 3.640469 sec.
# 556-th simulation finished, 3.347735 sec.
# 557-th simulation finished, 3.315069 sec.
# 558-th simulation finished, 3.507421 sec.
# 559-th simulation finished, 3.767696 sec.
# 560-th simulation finished, 3.558222 sec.
# 561-th simulation finished, 4.094334 sec.
# 562-th simulation finished, 3.403657 sec.
# 563-th simulation finished, 3.350429 sec.
# 564-th simulation finished, 3.371843 sec.
# 565-th simulation finished, 3.599847 sec.
# 566-th simulation finished, 3.142408 sec.
# 567-th simulation finished, 3.429537 sec.
# 568-th simulation finished, 3.366866 sec.
# 569-th simulation finished, 3.460594 sec.
# 570-th simulation finished, 3.429708 sec.
# 571-th simulation finished, 3.180505 sec.
# 572-th simulation finished, 3.806543 sec.
# 573-th simulation finished, 3.335480 sec.
# 574-th simulation finished, 3.408889 sec.
# 575-th simulation finished, 3.326709 sec.
# 576-th simulation finished, 3.359380 sec.
# 577-th simulation finished, 3.161414 sec.
# 578-th simulation finished, 3.256250 sec.
# 579-th simulation finished, 3.351161 sec.
# 580-th simulation finished, 3.413668 sec.
# 581-th simulation finished, 3.353682 sec.
# 582-th simulation finished, 3.372495 sec.
# 583-th simulation finished, 3.649023 sec.
# 584-th simulation finished, 3.152049 sec.
# 585-th simulation finished, 3.320308 sec.
# 586-th simulation finished, 3.258863 sec.
# 587-th simulation finished, 3.463996 sec.
# 588-th simulation finished, 3.402487 sec.
# 589-th simulation finished, 3.560722 sec.
# 590-th simulation finished, 3.815378 sec.
# 591-th simulation finished, 3.715986 sec.
# 592-th simulation finished, 3.587841 sec.
# 593-th simulation finished, 3.992890 sec.
# 594-th simulation finished, 3.116856 sec.
# 595-th simulation finished, 3.630224 sec.
# 596-th simulation finished, 3.187302 sec.
# 597-th simulation finished, 3.865790 sec.
# 598-th simulation finished, 3.608424 sec.
# 599-th simulation finished, 3.539221 sec.
# 600-th simulation finished, 3.793861 sec.
# 601-th simulation finished, 3.461930 sec.
# 602-th simulation finished, 3.094389 sec.
# 603-th simulation finished, 3.463442 sec.
# 604-th simulation finished, 3.222306 sec.
# 605-th simulation finished, 3.200376 sec.
# 606-th simulation finished, 3.533709 sec.
# 607-th simulation finished, 3.273310 sec.
# 608-th simulation finished, 3.007637 sec.
# 609-th simulation finished, 3.315797 sec.
# 610-th simulation finished, 3.357501 sec.
# 611-th simulation finished, 3.391882 sec.
# 612-th simulation finished, 3.338250 sec.
# 613-th simulation finished, 3.348798 sec.
# 614-th simulation finished, 3.167626 sec.
# 615-th simulation finished, 3.285765 sec.
# 616-th simulation finished, 3.171345 sec.
# 617-th simulation finished, 3.527806 sec.
# 618-th simulation finished, 3.350184 sec.
# 619-th simulation finished, 3.994565 sec.
# 620-th simulation finished, 3.262097 sec.
# 621-th simulation finished, 3.925512 sec.
# 622-th simulation finished, 3.349417 sec.
# 623-th simulation finished, 3.292691 sec.
# 624-th simulation finished, 3.366834 sec.
# 625-th simulation finished, 3.676244 sec.
# 626-th simulation finished, 3.296969 sec.
# 627-th simulation finished, 3.367652 sec.
# 628-th simulation finished, 3.334551 sec.
# 629-th simulation finished, 3.379240 sec.
# 630-th simulation finished, 3.297867 sec.
# 631-th simulation finished, 3.173433 sec.
# 632-th simulation finished, 3.294554 sec.
# 633-th simulation finished, 3.444518 sec.
# 634-th simulation finished, 3.887203 sec.
# 635-th simulation finished, 3.186320 sec.
# 636-th simulation finished, 3.868138 sec.
# 637-th simulation finished, 3.391395 sec.
# 638-th simulation finished, 3.351733 sec.
# 639-th simulation finished, 3.432223 sec.
# 640-th simulation finished, 3.310847 sec.
# 641-th simulation finished, 3.549926 sec.
# 642-th simulation finished, 2.970645 sec.
# 643-th simulation finished, 3.163031 sec.
# 644-th simulation finished, 3.451801 sec.
# 645-th simulation finished, 3.320140 sec.
# 646-th simulation finished, 3.212130 sec.
# 647-th simulation finished, 3.305217 sec.
# 648-th simulation finished, 3.423542 sec.
# 649-th simulation finished, 3.537728 sec.
# 650-th simulation finished, 3.474126 sec.
# 651-th simulation finished, 3.460016 sec.
# 652-th simulation finished, 3.923870 sec.
# 653-th simulation finished, 3.536385 sec.
# 654-th simulation finished, 3.164719 sec.
# 655-th simulation finished, 3.318295 sec.
# 656-th simulation finished, 3.561254 sec.
# 657-th simulation finished, 3.353654 sec.
# 658-th simulation finished, 3.243369 sec.
# 659-th simulation finished, 3.359265 sec.
# 660-th simulation finished, 3.319704 sec.
# 661-th simulation finished, 3.626772 sec.
# 662-th simulation finished, 3.578993 sec.
# 663-th simulation finished, 3.373105 sec.
# 664-th simulation finished, 3.449169 sec.
# 665-th simulation finished, 3.538626 sec.
# 666-th simulation finished, 3.731909 sec.
# 667-th simulation finished, 3.512207 sec.
# 668-th simulation finished, 3.348089 sec.
# 669-th simulation finished, 3.390829 sec.
# 670-th simulation finished, 3.230528 sec.
# 671-th simulation finished, 3.198426 sec.
# 672-th simulation finished, 3.359080 sec.
# 673-th simulation finished, 3.386716 sec.
# 674-th simulation finished, 3.412985 sec.
# 675-th simulation finished, 3.443998 sec.
# 676-th simulation finished, 3.354368 sec.
# 677-th simulation finished, 3.424709 sec.
# 678-th simulation finished, 3.376447 sec.
# 679-th simulation finished, 3.769429 sec.
# 680-th simulation finished, 3.382374 sec.
# 681-th simulation finished, 3.087357 sec.
# 682-th simulation finished, 3.620549 sec.
# 683-th simulation finished, 3.405376 sec.
# 684-th simulation finished, 3.394286 sec.
# 685-th simulation finished, 3.573913 sec.
# 686-th simulation finished, 3.393933 sec.
# 687-th simulation finished, 3.399310 sec.
# 688-th simulation finished, 3.347926 sec.
# 689-th simulation finished, 3.360535 sec.
# 690-th simulation finished, 3.307437 sec.
# 691-th simulation finished, 3.354186 sec.
# 692-th simulation finished, 3.400285 sec.
# 693-th simulation finished, 3.576714 sec.
# 694-th simulation finished, 3.401917 sec.
# 695-th simulation finished, 3.926904 sec.
# 696-th simulation finished, 3.959598 sec.
# 697-th simulation finished, 3.273830 sec.
# 698-th simulation finished, 3.236757 sec.
# 699-th simulation finished, 3.336908 sec.
# 700-th simulation finished, 3.541057 sec.
# 701-th simulation finished, 3.637239 sec.
# 702-th simulation finished, 3.463374 sec.
# 703-th simulation finished, 3.587104 sec.
# 704-th simulation finished, 3.237891 sec.
# 705-th simulation finished, 3.335835 sec.
# 706-th simulation finished, 4.154575 sec.
# 707-th simulation finished, 3.612344 sec.
# 708-th simulation finished, 3.549568 sec.
# 709-th simulation finished, 3.275711 sec.
# 710-th simulation finished, 3.794839 sec.
# 711-th simulation finished, 3.641645 sec.
# 712-th simulation finished, 3.585294 sec.
# 713-th simulation finished, 3.659105 sec.
# 714-th simulation finished, 3.574510 sec.
# 715-th simulation finished, 3.440867 sec.
# 716-th simulation finished, 3.375469 sec.
# 717-th simulation finished, 3.827843 sec.
# 718-th simulation finished, 3.301353 sec.
# 719-th simulation finished, 3.995295 sec.
# 720-th simulation finished, 3.406395 sec.
# 721-th simulation finished, 3.528513 sec.
# 722-th simulation finished, 3.384797 sec.
# 723-th simulation finished, 3.273647 sec.
# 724-th simulation finished, 3.299091 sec.
# 725-th simulation finished, 3.244289 sec.
# 726-th simulation finished, 3.403573 sec.
# 727-th simulation finished, 3.452858 sec.
# 728-th simulation finished, 3.444646 sec.
# 729-th simulation finished, 3.336479 sec.
# 730-th simulation finished, 3.306137 sec.
# 731-th simulation finished, 3.405349 sec.
# 732-th simulation finished, 3.680972 sec.
# 733-th simulation finished, 3.399717 sec.
# 734-th simulation finished, 3.431140 sec.
# 735-th simulation finished, 3.218823 sec.
# 736-th simulation finished, 3.503216 sec.
# 737-th simulation finished, 3.407647 sec.
# 738-th simulation finished, 3.451311 sec.
# 739-th simulation finished, 3.732352 sec.
# 740-th simulation finished, 3.352731 sec.
# 741-th simulation finished, 3.673246 sec.
# 742-th simulation finished, 3.373953 sec.
# 743-th simulation finished, 3.892580 sec.
# 744-th simulation finished, 3.358377 sec.
# 745-th simulation finished, 3.426822 sec.
# 746-th simulation finished, 3.300959 sec.
# 747-th simulation finished, 3.450828 sec.
# 748-th simulation finished, 3.145683 sec.
# 749-th simulation finished, 3.423438 sec.
# 750-th simulation finished, 3.580646 sec.
# 751-th simulation finished, 3.217012 sec.
# 752-th simulation finished, 3.712381 sec.
# 753-th simulation finished, 3.610795 sec.
# 754-th simulation finished, 3.583979 sec.
# 755-th simulation finished, 3.602423 sec.
# 756-th simulation finished, 3.338611 sec.
# 757-th simulation finished, 3.483129 sec.
# 758-th simulation finished, 3.368630 sec.
# 759-th simulation finished, 3.654372 sec.
# 760-th simulation finished, 3.327277 sec.
# 761-th simulation finished, 3.734226 sec.
# 762-th simulation finished, 3.655800 sec.
# 763-th simulation finished, 4.208798 sec.
# 764-th simulation finished, 4.161964 sec.
# 765-th simulation finished, 3.774816 sec.
# 766-th simulation finished, 3.603392 sec.
# 767-th simulation finished, 3.713644 sec.
# 768-th simulation finished, 3.877946 sec.
# 769-th simulation finished, 3.968952 sec.
# 770-th simulation finished, 4.817329 sec.
# 771-th simulation finished, 4.031801 sec.
# 772-th simulation finished, 4.227967 sec.
# 773-th simulation finished, 4.591102 sec.
# 774-th simulation finished, 4.132695 sec.
# 775-th simulation finished, 4.120642 sec.
# 776-th simulation finished, 4.110812 sec.
# 777-th simulation finished, 4.240400 sec.
# 778-th simulation finished, 4.215144 sec.
# 779-th simulation finished, 4.607530 sec.
# 780-th simulation finished, 4.437066 sec.
# 781-th simulation finished, 4.707177 sec.
# 782-th simulation finished, 4.704147 sec.
# 783-th simulation finished, 5.344843 sec.
# 784-th simulation finished, 4.555537 sec.
# 785-th simulation finished, 4.885834 sec.
# 786-th simulation finished, 4.538007 sec.
# 787-th simulation finished, 4.713706 sec.
# 788-th simulation finished, 4.503377 sec.
# 789-th simulation finished, 4.619119 sec.
# 790-th simulation finished, 4.375590 sec.
# 791-th simulation finished, 4.378013 sec.
# 792-th simulation finished, 4.711555 sec.
# 793-th simulation finished, 4.490011 sec.
# 794-th simulation finished, 4.959369 sec.
# 795-th simulation finished, 4.972185 sec.
# 796-th simulation finished, 5.440397 sec.
# 797-th simulation finished, 4.835677 sec.
# 798-th simulation finished, 4.265407 sec.
# 799-th simulation finished, 4.340591 sec.
# 800-th simulation finished, 5.051067 sec.
# 801-th simulation finished, 4.860147 sec.
# 802-th simulation finished, 4.222221 sec.
# 803-th simulation finished, 4.078972 sec.
# 804-th simulation finished, 4.452008 sec.
# 805-th simulation finished, 3.962231 sec.
# 806-th simulation finished, 4.539188 sec.
# 807-th simulation finished, 4.130806 sec.
# 808-th simulation finished, 4.347696 sec.
# 809-th simulation finished, 4.376611 sec.
# 810-th simulation finished, 4.061001 sec.
# 811-th simulation finished, 4.034273 sec.
# 812-th simulation finished, 4.197937 sec.
# 813-th simulation finished, 4.029522 sec.
# 814-th simulation finished, 4.417459 sec.
# 815-th simulation finished, 4.266949 sec.
# 816-th simulation finished, 4.174060 sec.
# 817-th simulation finished, 4.416354 sec.
# 818-th simulation finished, 4.205676 sec.
# 819-th simulation finished, 3.859565 sec.
# 820-th simulation finished, 4.171404 sec.
# 821-th simulation finished, 4.136524 sec.
# 822-th simulation finished, 4.138162 sec.
# 823-th simulation finished, 4.270778 sec.
# 824-th simulation finished, 4.382493 sec.
# 825-th simulation finished, 4.232126 sec.
# 826-th simulation finished, 4.087154 sec.
# 827-th simulation finished, 4.123230 sec.
# 828-th simulation finished, 4.273832 sec.
# 829-th simulation finished, 4.175221 sec.
# 830-th simulation finished, 4.347965 sec.
# 831-th simulation finished, 4.322750 sec.
# 832-th simulation finished, 4.306091 sec.
# 833-th simulation finished, 3.910244 sec.
# 834-th simulation finished, 4.128323 sec.
# 835-th simulation finished, 4.815919 sec.
# 836-th simulation finished, 4.171259 sec.
# 837-th simulation finished, 4.386655 sec.
# 838-th simulation finished, 5.011524 sec.
# 839-th simulation finished, 3.911408 sec.
# 840-th simulation finished, 4.235236 sec.
# 841-th simulation finished, 4.074639 sec.
# 842-th simulation finished, 4.534896 sec.
# 843-th simulation finished, 5.078889 sec.
# 844-th simulation finished, 4.689602 sec.
# 845-th simulation finished, 4.498219 sec.
# 846-th simulation finished, 4.558568 sec.
# 847-th simulation finished, 4.548718 sec.
# 848-th simulation finished, 4.269460 sec.
# 849-th simulation finished, 4.564816 sec.
# 850-th simulation finished, 4.347435 sec.
# 851-th simulation finished, 4.546135 sec.
# 852-th simulation finished, 4.257942 sec.
# 853-th simulation finished, 4.684424 sec.
# 854-th simulation finished, 4.573844 sec.
# 855-th simulation finished, 4.434009 sec.
# 856-th simulation finished, 4.441892 sec.
# 857-th simulation finished, 4.853081 sec.
# 858-th simulation finished, 3.712851 sec.
# 859-th simulation finished, 4.544118 sec.
# 860-th simulation finished, 4.558367 sec.
# 861-th simulation finished, 4.461334 sec.
# 862-th simulation finished, 4.468031 sec.
# 863-th simulation finished, 4.528990 sec.
# 864-th simulation finished, 4.217854 sec.
# 865-th simulation finished, 4.013278 sec.
# 866-th simulation finished, 4.260114 sec.
# 867-th simulation finished, 4.270769 sec.
# 868-th simulation finished, 4.262101 sec.
# 869-th simulation finished, 4.352144 sec.
# 870-th simulation finished, 4.355885 sec.
# 871-th simulation finished, 4.043191 sec.
# 872-th simulation finished, 4.755459 sec.
# 873-th simulation finished, 4.340887 sec.
# 874-th simulation finished, 4.556726 sec.
# 875-th simulation finished, 4.702309 sec.
# 876-th simulation finished, 4.473988 sec.
# 877-th simulation finished, 4.175695 sec.
# 878-th simulation finished, 4.120281 sec.
# 879-th simulation finished, 4.532337 sec.
# 880-th simulation finished, 4.449295 sec.
# 881-th simulation finished, 4.601593 sec.
# 882-th simulation finished, 4.910440 sec.
# 883-th simulation finished, 4.636658 sec.
# 884-th simulation finished, 5.178170 sec.
# 885-th simulation finished, 4.704570 sec.
# 886-th simulation finished, 4.377125 sec.
# 887-th simulation finished, 4.732724 sec.
# 888-th simulation finished, 4.273604 sec.
# 889-th simulation finished, 4.521654 sec.
# 890-th simulation finished, 4.189761 sec.
# 891-th simulation finished, 4.464231 sec.
# 892-th simulation finished, 4.228187 sec.
# 893-th simulation finished, 4.207821 sec.
# 894-th simulation finished, 4.413056 sec.
# 895-th simulation finished, 4.549070 sec.
# 896-th simulation finished, 4.509980 sec.
# 897-th simulation finished, 4.363178 sec.
# 898-th simulation finished, 4.586053 sec.
# 899-th simulation finished, 4.205237 sec.
# 900-th simulation finished, 4.377628 sec.
# 901-th simulation finished, 5.213196 sec.
# 902-th simulation finished, 4.426145 sec.
# 903-th simulation finished, 4.567664 sec.
# 904-th simulation finished, 4.576074 sec.
# 905-th simulation finished, 4.689523 sec.
# 906-th simulation finished, 4.885819 sec.
# 907-th simulation finished, 4.412883 sec.
# 908-th simulation finished, 4.625871 sec.
# 909-th simulation finished, 4.129477 sec.
# 910-th simulation finished, 5.008296 sec.
# 911-th simulation finished, 4.313583 sec.
# 912-th simulation finished, 4.736265 sec.
# 913-th simulation finished, 4.445113 sec.
# 914-th simulation finished, 4.981082 sec.
# 915-th simulation finished, 4.596273 sec.
# 916-th simulation finished, 4.598097 sec.
# 917-th simulation finished, 4.492415 sec.
# 918-th simulation finished, 4.991718 sec.
# 919-th simulation finished, 4.494317 sec.
# 920-th simulation finished, 4.666518 sec.
# 921-th simulation finished, 4.053460 sec.
# 922-th simulation finished, 4.606713 sec.
# 923-th simulation finished, 4.446953 sec.
# 924-th simulation finished, 4.352085 sec.
# 925-th simulation finished, 4.242590 sec.
# 926-th simulation finished, 4.452529 sec.
# 927-th simulation finished, 4.348514 sec.
# 928-th simulation finished, 4.395490 sec.
# 929-th simulation finished, 4.233739 sec.
# 930-th simulation finished, 5.046132 sec.
# 931-th simulation finished, 4.160256 sec.
# 932-th simulation finished, 4.704113 sec.
# 933-th simulation finished, 4.296737 sec.
# 934-th simulation finished, 4.686910 sec.
# 935-th simulation finished, 4.413293 sec.
# 936-th simulation finished, 4.495308 sec.
# 937-th simulation finished, 4.514866 sec.
# 938-th simulation finished, 4.421628 sec.
# 939-th simulation finished, 4.188870 sec.
# 940-th simulation finished, 4.684891 sec.
# 941-th simulation finished, 4.336946 sec.
# 942-th simulation finished, 4.739854 sec.
# 943-th simulation finished, 4.311077 sec.
# 944-th simulation finished, 4.371921 sec.
# 945-th simulation finished, 4.424717 sec.
# 946-th simulation finished, 4.494244 sec.
# 947-th simulation finished, 4.423612 sec.
# 948-th simulation finished, 4.411494 sec.
# 949-th simulation finished, 4.554487 sec.
# 950-th simulation finished, 4.613676 sec.
# 951-th simulation finished, 4.232398 sec.
# 952-th simulation finished, 4.668492 sec.
# 953-th simulation finished, 4.436633 sec.
# 954-th simulation finished, 5.081155 sec.
# 955-th simulation finished, 4.428509 sec.
# 956-th simulation finished, 4.163456 sec.
# 957-th simulation finished, 5.118548 sec.
# 958-th simulation finished, 4.630092 sec.
# 959-th simulation finished, 4.570795 sec.
# 960-th simulation finished, 4.467338 sec.
# 961-th simulation finished, 4.447284 sec.
# 962-th simulation finished, 4.426549 sec.
# 963-th simulation finished, 4.428367 sec.
# 964-th simulation finished, 4.378956 sec.
# 965-th simulation finished, 4.602335 sec.
# 966-th simulation finished, 4.447070 sec.
# 967-th simulation finished, 4.639844 sec.
# 968-th simulation finished, 4.369452 sec.
# 969-th simulation finished, 4.463276 sec.
# 970-th simulation finished, 4.282731 sec.
# 971-th simulation finished, 4.617654 sec.
# 972-th simulation finished, 4.344423 sec.
# 973-th simulation finished, 4.551453 sec.
# 974-th simulation finished, 4.222106 sec.
# 975-th simulation finished, 4.598484 sec.
# 976-th simulation finished, 4.408356 sec.
# 977-th simulation finished, 4.397315 sec.
# 978-th simulation finished, 4.351369 sec.
# 979-th simulation finished, 4.403999 sec.
# 980-th simulation finished, 4.626839 sec.
# 981-th simulation finished, 4.322892 sec.
# 982-th simulation finished, 4.404441 sec.
# 983-th simulation finished, 4.489445 sec.
# 984-th simulation finished, 4.561003 sec.
# 985-th simulation finished, 4.737207 sec.
# 986-th simulation finished, 4.352810 sec.
# 987-th simulation finished, 4.241082 sec.
# 988-th simulation finished, 5.392061 sec.
# 989-th simulation finished, 4.844522 sec.
# 990-th simulation finished, 4.619131 sec.
# 991-th simulation finished, 4.340704 sec.
# 992-th simulation finished, 4.406046 sec.
# 993-th simulation finished, 4.134834 sec.
# 994-th simulation finished, 4.449857 sec.
# 995-th simulation finished, 5.317865 sec.
# 996-th simulation finished, 4.548133 sec.
# 997-th simulation finished, 4.698073 sec.
# 998-th simulation finished, 4.510146 sec.
# 999-th simulation finished, 4.167244 sec.
# 1000-th simulation finished, 4.509541 sec.

# %%
np.savez('coverage_freqepid_nbinom_randinf_3.npz',
         nsim = nsim, msim = msim, bsim = bsim)

# %% [markdown]
# # 4. Wald's Confidence Region Coverage Test

# %%
# locals.update(np.load('coverage_freqepid_nbinom_randinf_3.npz'))

# %%
Ihs_dth = np.zeros([num_sim, 2+d, 2+d])
Ts_dth = np.zeros(num_sim)
ps_dth = np.zeros(num_sim)

# %%
Ihs_hac = np.zeros([num_sim, 2+d, 2+d])
Ts_hac = np.zeros(num_sim)
ps_hac = np.zeros(num_sim)

# %%
Ihs_sdw = np.zeros([num_sim, 2+d, 2+d])
Ts_sdw = np.zeros(num_sim)
ps_sdw = np.zeros(num_sim)

# %%
for iter_sim in np.arange(num_sim):
    start_sim = time.time()
    
    nmle = nsim[iter_sim]
    mmle = msim[iter_sim]
    bmle = bsim[iter_sim,:]
    
    data_i = data[data['sim']==iter_sim]
    A = np.stack([np.full(T, 1), data_i["intervention"].to_numpy()], -1)
    Y = data_i["death"].to_numpy()
    
    Ihat_dth, Ihat_hac, Ihat_sdw =\
    model.inference(A, Y, nmle, mmle, bmle)
    
    # Fisher information matrix
    Ihs_dth[iter_sim] = Ihat_dth
    Ts_dth[iter_sim] = (bmle[1]-beta[1])/np.sqrt(la.pinv(Ihs_dth[iter_sim])[-1,-1])
    ps_dth[iter_sim] = 2*(1-stats.norm.cdf(np.abs(Ts_dth[iter_sim])))
    
    # HAC estimator
    Ihs_hac[iter_sim] = Ihat_hac
    Ts_hac[iter_sim] = (bmle[1]-beta[1])/np.sqrt(la.pinv(Ihs_hac[iter_sim])[-1,-1])
    ps_hac[iter_sim] = 2*(1-stats.norm.cdf(np.abs(Ts_hac[iter_sim])))
    
    # Sandwich estimator
    Ihs_sdw[iter_sim] = Ihat_sdw
    Ts_sdw[iter_sim] = (bmle[1]-beta[1])/np.sqrt(la.pinv(Ihs_sdw[iter_sim])[-1,-1])
    ps_sdw[iter_sim] = 2*(1-stats.norm.cdf(np.abs(Ts_sdw[iter_sim])))
    
    sys.__stdout__.write("%d-th simulation finished, %f sec.\n"
                         %(iter_sim+1, time.time()-start_sim))
    sys.__stdout__.flush()
# Out:
# 1-th simulation finished, 0.006850 sec.
# 2-th simulation finished, 0.010318 sec.
# 3-th simulation finished, 0.001968 sec.
# 4-th simulation finished, 0.003217 sec.
# 5-th simulation finished, 0.001921 sec.
# 6-th simulation finished, 0.001722 sec.
# 7-th simulation finished, 0.001841 sec.
# 8-th simulation finished, 0.001959 sec.
# 9-th simulation finished, 0.001708 sec.
# 10-th simulation finished, 0.005919 sec.
# 11-th simulation finished, 0.001742 sec.
# 12-th simulation finished, 0.001698 sec.
# 13-th simulation finished, 0.001586 sec.
# 14-th simulation finished, 0.001547 sec.
# 15-th simulation finished, 0.001552 sec.
# 16-th simulation finished, 0.001519 sec.
# 17-th simulation finished, 0.001552 sec.
# 18-th simulation finished, 0.001522 sec.
# 19-th simulation finished, 0.004498 sec.
# 20-th simulation finished, 0.003227 sec.
# 21-th simulation finished, 0.003031 sec.
# 22-th simulation finished, 0.002794 sec.
# 23-th simulation finished, 0.001781 sec.
# 24-th simulation finished, 0.001757 sec.
# 25-th simulation finished, 0.001658 sec.
# 26-th simulation finished, 0.001566 sec.
# 27-th simulation finished, 0.001519 sec.
# 28-th simulation finished, 0.001539 sec.
# 29-th simulation finished, 0.003086 sec.
# 30-th simulation finished, 0.003125 sec.
# 31-th simulation finished, 0.002971 sec.
# 32-th simulation finished, 0.002159 sec.
# 33-th simulation finished, 0.004741 sec.
# 34-th simulation finished, 0.003401 sec.
# 35-th simulation finished, 0.002991 sec.
# 36-th simulation finished, 0.001701 sec.
# 37-th simulation finished, 0.001553 sec.
# 38-th simulation finished, 0.001517 sec.
# 39-th simulation finished, 0.001562 sec.
# 40-th simulation finished, 0.001638 sec.
# 41-th simulation finished, 0.001659 sec.
# 42-th simulation finished, 0.002484 sec.
# 43-th simulation finished, 0.010060 sec.
# 44-th simulation finished, 0.003003 sec.
# 45-th simulation finished, 0.001912 sec.
# 46-th simulation finished, 0.001693 sec.
# 47-th simulation finished, 0.001641 sec.
# 48-th simulation finished, 0.001670 sec.
# 49-th simulation finished, 0.001533 sec.
# 50-th simulation finished, 0.001532 sec.
# 51-th simulation finished, 0.001497 sec.
# 52-th simulation finished, 0.004262 sec.
# 53-th simulation finished, 0.003248 sec.
# 54-th simulation finished, 0.003681 sec.
# 55-th simulation finished, 0.002238 sec.
# 56-th simulation finished, 0.001672 sec.
# 57-th simulation finished, 0.001660 sec.
# 58-th simulation finished, 0.001630 sec.
# 59-th simulation finished, 0.001667 sec.
# 60-th simulation finished, 0.001631 sec.
# 61-th simulation finished, 0.001665 sec.
# 62-th simulation finished, 0.002396 sec.
# 63-th simulation finished, 0.016756 sec.
# 64-th simulation finished, 0.003584 sec.
# 65-th simulation finished, 0.003160 sec.
# 66-th simulation finished, 0.002359 sec.
# 67-th simulation finished, 0.001756 sec.
# 68-th simulation finished, 0.011139 sec.
# 69-th simulation finished, 0.003374 sec.
# 70-th simulation finished, 0.003659 sec.
# 71-th simulation finished, 0.003130 sec.
# 72-th simulation finished, 0.001696 sec.
# 73-th simulation finished, 0.001571 sec.
# 74-th simulation finished, 0.003422 sec.
# 75-th simulation finished, 0.003030 sec.
# 76-th simulation finished, 0.002614 sec.
# 77-th simulation finished, 0.002975 sec.
# 78-th simulation finished, 0.002833 sec.
# 79-th simulation finished, 0.002869 sec.
# 80-th simulation finished, 0.001703 sec.
# 81-th simulation finished, 0.001733 sec.
# 82-th simulation finished, 0.001731 sec.
# 83-th simulation finished, 0.011014 sec.
# 84-th simulation finished, 0.002237 sec.
# 85-th simulation finished, 0.001739 sec.
# 86-th simulation finished, 0.003385 sec.
# 87-th simulation finished, 0.002348 sec.
# 88-th simulation finished, 0.001748 sec.
# 89-th simulation finished, 0.007813 sec.
# 90-th simulation finished, 0.011204 sec.
# 91-th simulation finished, 0.003544 sec.
# 92-th simulation finished, 0.003047 sec.
# 93-th simulation finished, 0.002991 sec.
# 94-th simulation finished, 0.001740 sec.
# 95-th simulation finished, 0.011523 sec.
# 96-th simulation finished, 0.001783 sec.
# 97-th simulation finished, 0.003203 sec.
# 98-th simulation finished, 0.003951 sec.
# 99-th simulation finished, 0.002912 sec.
# 100-th simulation finished, 0.002982 sec.
# 101-th simulation finished, 0.001770 sec.
# 102-th simulation finished, 0.001567 sec.
# 103-th simulation finished, 0.001621 sec.
# 104-th simulation finished, 0.003003 sec.
# 105-th simulation finished, 0.002850 sec.
# 106-th simulation finished, 0.002945 sec.
# 107-th simulation finished, 0.001905 sec.
# 108-th simulation finished, 0.003473 sec.
# 109-th simulation finished, 0.002899 sec.
# 110-th simulation finished, 0.002454 sec.
# 111-th simulation finished, 0.001633 sec.
# 112-th simulation finished, 0.001678 sec.
# 113-th simulation finished, 0.006047 sec.
# 114-th simulation finished, 0.010311 sec.
# 115-th simulation finished, 0.001670 sec.
# 116-th simulation finished, 0.004812 sec.
# 117-th simulation finished, 0.003408 sec.
# 118-th simulation finished, 0.002962 sec.
# 119-th simulation finished, 0.001966 sec.
# 120-th simulation finished, 0.001747 sec.
# 121-th simulation finished, 0.003705 sec.
# 122-th simulation finished, 0.003144 sec.
# 123-th simulation finished, 0.002691 sec.
# 124-th simulation finished, 0.002306 sec.
# 125-th simulation finished, 0.001820 sec.
# 126-th simulation finished, 0.001721 sec.
# 127-th simulation finished, 0.001674 sec.
# 128-th simulation finished, 0.010288 sec.
# 129-th simulation finished, 0.001716 sec.
# 130-th simulation finished, 0.008786 sec.
# 131-th simulation finished, 0.002476 sec.
# 132-th simulation finished, 0.010438 sec.
# 133-th simulation finished, 0.001587 sec.
# 134-th simulation finished, 0.003352 sec.
# 135-th simulation finished, 0.005392 sec.
# 136-th simulation finished, 0.001928 sec.
# 137-th simulation finished, 0.002463 sec.
# 138-th simulation finished, 0.001900 sec.
# 139-th simulation finished, 0.001618 sec.
# 140-th simulation finished, 0.010740 sec.
# 141-th simulation finished, 0.003249 sec.
# 142-th simulation finished, 0.003191 sec.
# 143-th simulation finished, 0.003040 sec.
# 144-th simulation finished, 0.001749 sec.
# 145-th simulation finished, 0.001788 sec.
# 146-th simulation finished, 0.003268 sec.
# 147-th simulation finished, 0.003047 sec.
# 148-th simulation finished, 0.002876 sec.
# 149-th simulation finished, 0.002001 sec.
# 150-th simulation finished, 0.011436 sec.
# 151-th simulation finished, 0.001827 sec.
# 152-th simulation finished, 0.003474 sec.
# 153-th simulation finished, 0.001878 sec.
# 154-th simulation finished, 0.001740 sec.
# 155-th simulation finished, 0.003242 sec.
# 156-th simulation finished, 0.003699 sec.
# 157-th simulation finished, 0.002919 sec.
# 158-th simulation finished, 0.002788 sec.
# 159-th simulation finished, 0.003358 sec.
# 160-th simulation finished, 0.002131 sec.
# 161-th simulation finished, 0.002940 sec.
# 162-th simulation finished, 0.002824 sec.
# 163-th simulation finished, 0.003472 sec.
# 164-th simulation finished, 0.001819 sec.
# 165-th simulation finished, 0.001655 sec.
# 166-th simulation finished, 0.012598 sec.
# 167-th simulation finished, 0.012251 sec.
# 168-th simulation finished, 0.001544 sec.
# 169-th simulation finished, 0.003792 sec.
# 170-th simulation finished, 0.003148 sec.
# 171-th simulation finished, 0.002709 sec.
# 172-th simulation finished, 0.003752 sec.
# 173-th simulation finished, 0.003258 sec.
# 174-th simulation finished, 0.002882 sec.
# 175-th simulation finished, 0.002868 sec.
# 176-th simulation finished, 0.002276 sec.
# 177-th simulation finished, 0.001898 sec.
# 178-th simulation finished, 0.001737 sec.
# 179-th simulation finished, 0.001764 sec.
# 180-th simulation finished, 0.010196 sec.
# 181-th simulation finished, 0.001877 sec.
# 182-th simulation finished, 0.003649 sec.
# 183-th simulation finished, 0.002871 sec.
# 184-th simulation finished, 0.002557 sec.
# 185-th simulation finished, 0.012412 sec.
# 186-th simulation finished, 0.003186 sec.
# 187-th simulation finished, 0.003128 sec.
# 188-th simulation finished, 0.002970 sec.
# 189-th simulation finished, 0.002207 sec.
# 190-th simulation finished, 0.011481 sec.
# 191-th simulation finished, 0.001845 sec.
# 192-th simulation finished, 0.004310 sec.
# 193-th simulation finished, 0.003030 sec.
# 194-th simulation finished, 0.002200 sec.
# 195-th simulation finished, 0.002962 sec.
# 196-th simulation finished, 0.003251 sec.
# 197-th simulation finished, 0.003028 sec.
# 198-th simulation finished, 0.002122 sec.
# 199-th simulation finished, 0.001751 sec.
# 200-th simulation finished, 0.001774 sec.
# 201-th simulation finished, 0.003016 sec.
# 202-th simulation finished, 0.002931 sec.
# 203-th simulation finished, 0.002786 sec.
# 204-th simulation finished, 0.003400 sec.
# 205-th simulation finished, 0.002978 sec.
# 206-th simulation finished, 0.002775 sec.
# 207-th simulation finished, 0.002052 sec.
# 208-th simulation finished, 0.001814 sec.
# 209-th simulation finished, 0.002914 sec.
# 210-th simulation finished, 0.003117 sec.
# 211-th simulation finished, 0.001719 sec.
# 212-th simulation finished, 0.003096 sec.
# 213-th simulation finished, 0.001999 sec.
# 214-th simulation finished, 0.001598 sec.
# 215-th simulation finished, 0.001674 sec.
# 216-th simulation finished, 0.003602 sec.
# 217-th simulation finished, 0.002211 sec.
# 218-th simulation finished, 0.001682 sec.
# 219-th simulation finished, 0.001703 sec.
# 220-th simulation finished, 0.010755 sec.
# 221-th simulation finished, 0.001931 sec.
# 222-th simulation finished, 0.001666 sec.
# 223-th simulation finished, 0.003062 sec.
# 224-th simulation finished, 0.004586 sec.
# 225-th simulation finished, 0.002400 sec.
# 226-th simulation finished, 0.003021 sec.
# 227-th simulation finished, 0.003408 sec.
# 228-th simulation finished, 0.002937 sec.
# 229-th simulation finished, 0.002096 sec.
# 230-th simulation finished, 0.001770 sec.
# 231-th simulation finished, 0.012015 sec.
# 232-th simulation finished, 0.010605 sec.
# 233-th simulation finished, 0.011854 sec.
# 234-th simulation finished, 0.010532 sec.
# 235-th simulation finished, 0.012037 sec.
# 236-th simulation finished, 0.003114 sec.
# 237-th simulation finished, 0.002962 sec.
# 238-th simulation finished, 0.002835 sec.
# 239-th simulation finished, 0.001663 sec.
# 240-th simulation finished, 0.002034 sec.
# 241-th simulation finished, 0.003483 sec.
# 242-th simulation finished, 0.002884 sec.
# 243-th simulation finished, 0.001927 sec.
# 244-th simulation finished, 0.001835 sec.
# 245-th simulation finished, 0.003269 sec.
# 246-th simulation finished, 0.001891 sec.
# 247-th simulation finished, 0.003010 sec.
# 248-th simulation finished, 0.002084 sec.
# 249-th simulation finished, 0.001756 sec.
# 250-th simulation finished, 0.001837 sec.
# 251-th simulation finished, 0.001707 sec.
# 252-th simulation finished, 0.012743 sec.
# 253-th simulation finished, 0.003203 sec.
# 254-th simulation finished, 0.002941 sec.
# 255-th simulation finished, 0.002804 sec.
# 256-th simulation finished, 0.001855 sec.
# 257-th simulation finished, 0.001693 sec.
# 258-th simulation finished, 0.003143 sec.
# 259-th simulation finished, 0.002831 sec.
# 260-th simulation finished, 0.002896 sec.
# 261-th simulation finished, 0.002523 sec.
# 262-th simulation finished, 0.013027 sec.
# 263-th simulation finished, 0.001842 sec.
# 264-th simulation finished, 0.001761 sec.
# 265-th simulation finished, 0.003074 sec.
# 266-th simulation finished, 0.003653 sec.
# 267-th simulation finished, 0.002410 sec.
# 268-th simulation finished, 0.001649 sec.
# 269-th simulation finished, 0.003176 sec.
# 270-th simulation finished, 0.002906 sec.
# 271-th simulation finished, 0.002873 sec.
# 272-th simulation finished, 0.002105 sec.
# 273-th simulation finished, 0.001703 sec.
# 274-th simulation finished, 0.001688 sec.
# 275-th simulation finished, 0.001652 sec.
# 276-th simulation finished, 0.001644 sec.
# 277-th simulation finished, 0.001647 sec.
# 278-th simulation finished, 0.001645 sec.
# 279-th simulation finished, 0.011105 sec.
# 280-th simulation finished, 0.003168 sec.
# 281-th simulation finished, 0.002951 sec.
# 282-th simulation finished, 0.002713 sec.
# 283-th simulation finished, 0.001616 sec.
# 284-th simulation finished, 0.001592 sec.
# 285-th simulation finished, 0.001512 sec.
# 286-th simulation finished, 0.001545 sec.
# 287-th simulation finished, 0.001519 sec.
# 288-th simulation finished, 0.001551 sec.
# 289-th simulation finished, 0.002673 sec.
# 290-th simulation finished, 0.004522 sec.
# 291-th simulation finished, 0.002930 sec.
# 292-th simulation finished, 0.002574 sec.
# 293-th simulation finished, 0.001597 sec.
# 294-th simulation finished, 0.001512 sec.
# 295-th simulation finished, 0.001541 sec.
# 296-th simulation finished, 0.001500 sec.
# 297-th simulation finished, 0.001519 sec.
# 298-th simulation finished, 0.001684 sec.
# 299-th simulation finished, 0.004390 sec.
# 300-th simulation finished, 0.003868 sec.
# 301-th simulation finished, 0.001775 sec.
# 302-th simulation finished, 0.001657 sec.
# 303-th simulation finished, 0.001696 sec.
# 304-th simulation finished, 0.001640 sec.
# 305-th simulation finished, 0.001670 sec.
# 306-th simulation finished, 0.001641 sec.
# 307-th simulation finished, 0.002392 sec.
# 308-th simulation finished, 0.001960 sec.
# 309-th simulation finished, 0.001704 sec.
# 310-th simulation finished, 0.001647 sec.
# 311-th simulation finished, 0.001676 sec.
# 312-th simulation finished, 0.001634 sec.
# 313-th simulation finished, 0.001661 sec.
# 314-th simulation finished, 0.001623 sec.
# 315-th simulation finished, 0.003423 sec.
# 316-th simulation finished, 0.003427 sec.
# 317-th simulation finished, 0.003050 sec.
# 318-th simulation finished, 0.002763 sec.
# 319-th simulation finished, 0.001743 sec.
# 320-th simulation finished, 0.001638 sec.
# 321-th simulation finished, 0.001671 sec.
# 322-th simulation finished, 0.001654 sec.
# 323-th simulation finished, 0.003064 sec.
# 324-th simulation finished, 0.010351 sec.
# 325-th simulation finished, 0.001875 sec.
# 326-th simulation finished, 0.001646 sec.
# 327-th simulation finished, 0.010689 sec.
# 328-th simulation finished, 0.010282 sec.
# 329-th simulation finished, 0.001812 sec.
# 330-th simulation finished, 0.003372 sec.
# 331-th simulation finished, 0.003250 sec.
# 332-th simulation finished, 0.002670 sec.
# 333-th simulation finished, 0.003044 sec.
# 334-th simulation finished, 0.001877 sec.
# 335-th simulation finished, 0.001768 sec.
# 336-th simulation finished, 0.003626 sec.
# 337-th simulation finished, 0.003160 sec.
# 338-th simulation finished, 0.002847 sec.
# 339-th simulation finished, 0.001910 sec.
# 340-th simulation finished, 0.002992 sec.
# 341-th simulation finished, 0.002846 sec.
# 342-th simulation finished, 0.003172 sec.
# 343-th simulation finished, 0.002221 sec.
# 344-th simulation finished, 0.001674 sec.
# 345-th simulation finished, 0.013724 sec.
# 346-th simulation finished, 0.009845 sec.
# 347-th simulation finished, 0.001704 sec.
# 348-th simulation finished, 0.001638 sec.
# 349-th simulation finished, 0.001625 sec.
# 350-th simulation finished, 0.010196 sec.
# 351-th simulation finished, 0.001845 sec.
# 352-th simulation finished, 0.003262 sec.
# 353-th simulation finished, 0.003087 sec.
# 354-th simulation finished, 0.002855 sec.
# 355-th simulation finished, 0.002846 sec.
# 356-th simulation finished, 0.002340 sec.
# 357-th simulation finished, 0.001645 sec.
# 358-th simulation finished, 0.003662 sec.
# 359-th simulation finished, 0.003003 sec.
# 360-th simulation finished, 0.002986 sec.
# 361-th simulation finished, 0.001925 sec.
# 362-th simulation finished, 0.003335 sec.
# 363-th simulation finished, 0.003052 sec.
# 364-th simulation finished, 0.002677 sec.
# 365-th simulation finished, 0.001893 sec.
# 366-th simulation finished, 0.003071 sec.
# 367-th simulation finished, 0.002861 sec.
# 368-th simulation finished, 0.002917 sec.
# 369-th simulation finished, 0.003668 sec.
# 370-th simulation finished, 0.001804 sec.
# 371-th simulation finished, 0.001619 sec.
# 372-th simulation finished, 0.001549 sec.
# 373-th simulation finished, 0.001579 sec.
# 374-th simulation finished, 0.003207 sec.
# 375-th simulation finished, 0.003137 sec.
# 376-th simulation finished, 0.003077 sec.
# 377-th simulation finished, 0.001849 sec.
# 378-th simulation finished, 0.001731 sec.
# 379-th simulation finished, 0.009167 sec.
# 380-th simulation finished, 0.011350 sec.
# 381-th simulation finished, 0.005078 sec.
# 382-th simulation finished, 0.004030 sec.
# 383-th simulation finished, 0.002403 sec.
# 384-th simulation finished, 0.003096 sec.
# 385-th simulation finished, 0.003350 sec.
# 386-th simulation finished, 0.003102 sec.
# 387-th simulation finished, 0.001880 sec.
# 388-th simulation finished, 0.003694 sec.
# 389-th simulation finished, 0.003307 sec.
# 390-th simulation finished, 0.002913 sec.
# 391-th simulation finished, 0.002392 sec.
# 392-th simulation finished, 0.002127 sec.
# 393-th simulation finished, 0.001713 sec.
# 394-th simulation finished, 0.011221 sec.
# 395-th simulation finished, 0.009634 sec.
# 396-th simulation finished, 0.001736 sec.
# 397-th simulation finished, 0.001819 sec.
# 398-th simulation finished, 0.010521 sec.
# 399-th simulation finished, 0.003212 sec.
# 400-th simulation finished, 0.003012 sec.
# 401-th simulation finished, 0.002988 sec.
# 402-th simulation finished, 0.002034 sec.
# 403-th simulation finished, 0.003026 sec.
# 404-th simulation finished, 0.002813 sec.
# 405-th simulation finished, 0.002915 sec.
# 406-th simulation finished, 0.001614 sec.
# 407-th simulation finished, 0.002908 sec.
# 408-th simulation finished, 0.003252 sec.
# 409-th simulation finished, 0.001691 sec.
# 410-th simulation finished, 0.003070 sec.
# 411-th simulation finished, 0.002981 sec.
# 412-th simulation finished, 0.002871 sec.
# 413-th simulation finished, 0.001674 sec.
# 414-th simulation finished, 0.003055 sec.
# 415-th simulation finished, 0.003035 sec.
# 416-th simulation finished, 0.002809 sec.
# 417-th simulation finished, 0.002145 sec.
# 418-th simulation finished, 0.001765 sec.
# 419-th simulation finished, 0.001695 sec.
# 420-th simulation finished, 0.003100 sec.
# 421-th simulation finished, 0.002884 sec.
# 422-th simulation finished, 0.001744 sec.
# 423-th simulation finished, 0.003090 sec.
# 424-th simulation finished, 0.003224 sec.
# 425-th simulation finished, 0.002848 sec.
# 426-th simulation finished, 0.002038 sec.
# 427-th simulation finished, 0.001633 sec.
# 428-th simulation finished, 0.010693 sec.
# 429-th simulation finished, 0.002048 sec.
# 430-th simulation finished, 0.001666 sec.
# 431-th simulation finished, 0.001685 sec.
# 432-th simulation finished, 0.001627 sec.
# 433-th simulation finished, 0.001654 sec.
# 434-th simulation finished, 0.001634 sec.
# 435-th simulation finished, 0.001651 sec.
# 436-th simulation finished, 0.001670 sec.
# 437-th simulation finished, 0.001649 sec.
# 438-th simulation finished, 0.001612 sec.
# 439-th simulation finished, 0.001642 sec.
# 440-th simulation finished, 0.001611 sec.
# 441-th simulation finished, 0.001640 sec.
# 442-th simulation finished, 0.002101 sec.
# 443-th simulation finished, 0.001789 sec.
# 444-th simulation finished, 0.001727 sec.
# 445-th simulation finished, 0.001655 sec.
# 446-th simulation finished, 0.001666 sec.
# 447-th simulation finished, 0.004521 sec.
# 448-th simulation finished, 0.001737 sec.
# 449-th simulation finished, 0.001629 sec.
# 450-th simulation finished, 0.001656 sec.
# 451-th simulation finished, 0.001619 sec.
# 452-th simulation finished, 0.001642 sec.
# 453-th simulation finished, 0.001608 sec.
# 454-th simulation finished, 0.002320 sec.
# 455-th simulation finished, 0.001848 sec.
# 456-th simulation finished, 0.001676 sec.
# 457-th simulation finished, 0.001653 sec.
# 458-th simulation finished, 0.001665 sec.
# 459-th simulation finished, 0.001650 sec.
# 460-th simulation finished, 0.001645 sec.
# 461-th simulation finished, 0.001841 sec.
# 462-th simulation finished, 0.001643 sec.
# 463-th simulation finished, 0.001643 sec.
# 464-th simulation finished, 0.001637 sec.
# 465-th simulation finished, 0.003136 sec.
# 466-th simulation finished, 0.002925 sec.
# 467-th simulation finished, 0.001950 sec.
# 468-th simulation finished, 0.001613 sec.
# 469-th simulation finished, 0.001542 sec.
# 470-th simulation finished, 0.001512 sec.
# 471-th simulation finished, 0.001528 sec.
# 472-th simulation finished, 0.001501 sec.
# 473-th simulation finished, 0.001512 sec.
# 474-th simulation finished, 0.001629 sec.
# 475-th simulation finished, 0.001525 sec.
# 476-th simulation finished, 0.001515 sec.
# 477-th simulation finished, 0.001640 sec.
# 478-th simulation finished, 0.001631 sec.
# 479-th simulation finished, 0.001647 sec.
# 480-th simulation finished, 0.002146 sec.
# 481-th simulation finished, 0.001788 sec.
# 482-th simulation finished, 0.001755 sec.
# 483-th simulation finished, 0.001682 sec.
# 484-th simulation finished, 0.001645 sec.
# 485-th simulation finished, 0.001643 sec.
# 486-th simulation finished, 0.001644 sec.
# 487-th simulation finished, 0.001673 sec.
# 488-th simulation finished, 0.007073 sec.
# 489-th simulation finished, 0.001756 sec.
# 490-th simulation finished, 0.002203 sec.
# 491-th simulation finished, 0.001729 sec.
# 492-th simulation finished, 0.001733 sec.
# 493-th simulation finished, 0.001647 sec.
# 494-th simulation finished, 0.004547 sec.
# 495-th simulation finished, 0.002041 sec.
# 496-th simulation finished, 0.001790 sec.
# 497-th simulation finished, 0.010460 sec.
# 498-th simulation finished, 0.009179 sec.
# 499-th simulation finished, 0.001629 sec.
# 500-th simulation finished, 0.011197 sec.
# 501-th simulation finished, 0.003453 sec.
# 502-th simulation finished, 0.003021 sec.
# 503-th simulation finished, 0.002866 sec.
# 504-th simulation finished, 0.002054 sec.
# 505-th simulation finished, 0.001811 sec.
# 506-th simulation finished, 0.001838 sec.
# 507-th simulation finished, 0.003495 sec.
# 508-th simulation finished, 0.002645 sec.
# 509-th simulation finished, 0.002256 sec.
# 510-th simulation finished, 0.002133 sec.
# 511-th simulation finished, 0.001646 sec.
# 512-th simulation finished, 0.003580 sec.
# 513-th simulation finished, 0.002295 sec.
# 514-th simulation finished, 0.002388 sec.
# 515-th simulation finished, 0.001766 sec.
# 516-th simulation finished, 0.001698 sec.
# 517-th simulation finished, 0.002728 sec.
# 518-th simulation finished, 0.003725 sec.
# 519-th simulation finished, 0.003113 sec.
# 520-th simulation finished, 0.002910 sec.
# 521-th simulation finished, 0.002364 sec.
# 522-th simulation finished, 0.011993 sec.
# 523-th simulation finished, 0.001871 sec.
# 524-th simulation finished, 0.001793 sec.
# 525-th simulation finished, 0.001864 sec.
# 526-th simulation finished, 0.001923 sec.
# 527-th simulation finished, 0.003344 sec.
# 528-th simulation finished, 0.003035 sec.
# 529-th simulation finished, 0.003553 sec.
# 530-th simulation finished, 0.001760 sec.
# 531-th simulation finished, 0.007321 sec.
# 532-th simulation finished, 0.002270 sec.
# 533-th simulation finished, 0.001563 sec.
# 534-th simulation finished, 0.003150 sec.
# 535-th simulation finished, 0.002851 sec.
# 536-th simulation finished, 0.002876 sec.
# 537-th simulation finished, 0.001903 sec.
# 538-th simulation finished, 0.006520 sec.
# 539-th simulation finished, 0.002203 sec.
# 540-th simulation finished, 0.011447 sec.
# 541-th simulation finished, 0.009523 sec.
# 542-th simulation finished, 0.001856 sec.
# 543-th simulation finished, 0.003249 sec.
# 544-th simulation finished, 0.002956 sec.
# 545-th simulation finished, 0.002941 sec.
# 546-th simulation finished, 0.002970 sec.
# 547-th simulation finished, 0.003567 sec.
# 548-th simulation finished, 0.002973 sec.
# 549-th simulation finished, 0.002036 sec.
# 550-th simulation finished, 0.001708 sec.
# 551-th simulation finished, 0.001607 sec.
# 552-th simulation finished, 0.010490 sec.
# 553-th simulation finished, 0.010459 sec.
# 554-th simulation finished, 0.001560 sec.
# 555-th simulation finished, 0.010873 sec.
# 556-th simulation finished, 0.003766 sec.
# 557-th simulation finished, 0.003087 sec.
# 558-th simulation finished, 0.002868 sec.
# 559-th simulation finished, 0.002823 sec.
# 560-th simulation finished, 0.001725 sec.
# 561-th simulation finished, 0.003138 sec.
# 562-th simulation finished, 0.002394 sec.
# 563-th simulation finished, 0.003054 sec.
# 564-th simulation finished, 0.003404 sec.
# 565-th simulation finished, 0.002881 sec.
# 566-th simulation finished, 0.002816 sec.
# 567-th simulation finished, 0.002067 sec.
# 568-th simulation finished, 0.001698 sec.
# 569-th simulation finished, 0.001609 sec.
# 570-th simulation finished, 0.010592 sec.
# 571-th simulation finished, 0.002353 sec.
# 572-th simulation finished, 0.002125 sec.
# 573-th simulation finished, 0.001659 sec.
# 574-th simulation finished, 0.001561 sec.
# 575-th simulation finished, 0.001628 sec.
# 576-th simulation finished, 0.003244 sec.
# 577-th simulation finished, 0.002906 sec.
# 578-th simulation finished, 0.002929 sec.
# 579-th simulation finished, 0.001981 sec.
# 580-th simulation finished, 0.001718 sec.
# 581-th simulation finished, 0.001778 sec.
# 582-th simulation finished, 0.001736 sec.
# 583-th simulation finished, 0.001866 sec.
# 584-th simulation finished, 0.010245 sec.
# 585-th simulation finished, 0.001761 sec.
# 586-th simulation finished, 0.003465 sec.
# 587-th simulation finished, 0.003289 sec.
# 588-th simulation finished, 0.002521 sec.
# 589-th simulation finished, 0.002301 sec.
# 590-th simulation finished, 0.002926 sec.
# 591-th simulation finished, 0.002131 sec.
# 592-th simulation finished, 0.001747 sec.
# 593-th simulation finished, 0.001808 sec.
# 594-th simulation finished, 0.011084 sec.
# 595-th simulation finished, 0.004869 sec.
# 596-th simulation finished, 0.003844 sec.
# 597-th simulation finished, 0.001952 sec.
# 598-th simulation finished, 0.001704 sec.
# 599-th simulation finished, 0.002965 sec.
# 600-th simulation finished, 0.001633 sec.
# 601-th simulation finished, 0.002994 sec.
# 602-th simulation finished, 0.003545 sec.
# 603-th simulation finished, 0.002076 sec.
# 604-th simulation finished, 0.001867 sec.
# 605-th simulation finished, 0.010553 sec.
# 606-th simulation finished, 0.010112 sec.
# 607-th simulation finished, 0.001798 sec.
# 608-th simulation finished, 0.003155 sec.
# 609-th simulation finished, 0.004192 sec.
# 610-th simulation finished, 0.001636 sec.
# 611-th simulation finished, 0.002994 sec.
# 612-th simulation finished, 0.002806 sec.
# 613-th simulation finished, 0.003297 sec.
# 614-th simulation finished, 0.001822 sec.
# 615-th simulation finished, 0.001779 sec.
# 616-th simulation finished, 0.001722 sec.
# 617-th simulation finished, 0.011104 sec.
# 618-th simulation finished, 0.001764 sec.
# 619-th simulation finished, 0.005067 sec.
# 620-th simulation finished, 0.002901 sec.
# 621-th simulation finished, 0.002723 sec.
# 622-th simulation finished, 0.002961 sec.
# 623-th simulation finished, 0.002810 sec.
# 624-th simulation finished, 0.002870 sec.
# 625-th simulation finished, 0.002287 sec.
# 626-th simulation finished, 0.001732 sec.
# 627-th simulation finished, 0.010635 sec.
# 628-th simulation finished, 0.010934 sec.
# 629-th simulation finished, 0.001698 sec.
# 630-th simulation finished, 0.004687 sec.
# 631-th simulation finished, 0.001995 sec.
# 632-th simulation finished, 0.003102 sec.
# 633-th simulation finished, 0.002852 sec.
# 634-th simulation finished, 0.002944 sec.
# 635-th simulation finished, 0.001721 sec.
# 636-th simulation finished, 0.001720 sec.
# 637-th simulation finished, 0.001674 sec.
# 638-th simulation finished, 0.002495 sec.
# 639-th simulation finished, 0.003147 sec.
# 640-th simulation finished, 0.002849 sec.
# 641-th simulation finished, 0.001698 sec.
# 642-th simulation finished, 0.001590 sec.
# 643-th simulation finished, 0.001504 sec.
# 644-th simulation finished, 0.001569 sec.
# 645-th simulation finished, 0.001618 sec.
# 646-th simulation finished, 0.001646 sec.
# 647-th simulation finished, 0.003565 sec.
# 648-th simulation finished, 0.001703 sec.
# 649-th simulation finished, 0.001669 sec.
# 650-th simulation finished, 0.001631 sec.
# 651-th simulation finished, 0.001647 sec.
# 652-th simulation finished, 0.001632 sec.
# 653-th simulation finished, 0.001656 sec.
# 654-th simulation finished, 0.003231 sec.
# 655-th simulation finished, 0.002871 sec.
# 656-th simulation finished, 0.002792 sec.
# 657-th simulation finished, 0.002292 sec.
# 658-th simulation finished, 0.001512 sec.
# 659-th simulation finished, 0.001529 sec.
# 660-th simulation finished, 0.001483 sec.
# 661-th simulation finished, 0.001513 sec.
# 662-th simulation finished, 0.001483 sec.
# 663-th simulation finished, 0.004364 sec.
# 664-th simulation finished, 0.010273 sec.
# 665-th simulation finished, 0.003142 sec.
# 666-th simulation finished, 0.003113 sec.
# 667-th simulation finished, 0.005110 sec.
# 668-th simulation finished, 0.004379 sec.
# 669-th simulation finished, 0.002900 sec.
# 670-th simulation finished, 0.002926 sec.
# 671-th simulation finished, 0.002886 sec.
# 672-th simulation finished, 0.002838 sec.
# 673-th simulation finished, 0.005691 sec.
# 674-th simulation finished, 0.003206 sec.
# 675-th simulation finished, 0.003200 sec.
# 676-th simulation finished, 0.004869 sec.
# 677-th simulation finished, 0.001613 sec.
# 678-th simulation finished, 0.002000 sec.
# 679-th simulation finished, 0.001615 sec.
# 680-th simulation finished, 0.010785 sec.
# 681-th simulation finished, 0.002115 sec.
# 682-th simulation finished, 0.005439 sec.
# 683-th simulation finished, 0.010757 sec.
# 684-th simulation finished, 0.003291 sec.
# 685-th simulation finished, 0.005198 sec.
# 686-th simulation finished, 0.002890 sec.
# 687-th simulation finished, 0.001676 sec.
# 688-th simulation finished, 0.001638 sec.
# 689-th simulation finished, 0.001577 sec.
# 690-th simulation finished, 0.003163 sec.
# 691-th simulation finished, 0.001875 sec.
# 692-th simulation finished, 0.002965 sec.
# 693-th simulation finished, 0.003039 sec.
# 694-th simulation finished, 0.002641 sec.
# 695-th simulation finished, 0.001813 sec.
# 696-th simulation finished, 0.001839 sec.
# 697-th simulation finished, 0.001582 sec.
# 698-th simulation finished, 0.011788 sec.
# 699-th simulation finished, 0.003133 sec.
# 700-th simulation finished, 0.003108 sec.
# 701-th simulation finished, 0.003878 sec.
# 702-th simulation finished, 0.001687 sec.
# 703-th simulation finished, 0.003222 sec.
# 704-th simulation finished, 0.005479 sec.
# 705-th simulation finished, 0.002074 sec.
# 706-th simulation finished, 0.003036 sec.
# 707-th simulation finished, 0.002954 sec.
# 708-th simulation finished, 0.003369 sec.
# 709-th simulation finished, 0.001889 sec.
# 710-th simulation finished, 0.001708 sec.
# 711-th simulation finished, 0.002440 sec.
# 712-th simulation finished, 0.003066 sec.
# 713-th simulation finished, 0.001890 sec.
# 714-th simulation finished, 0.001812 sec.
# 715-th simulation finished, 0.003052 sec.
# 716-th simulation finished, 0.002994 sec.
# 717-th simulation finished, 0.003973 sec.
# 718-th simulation finished, 0.001809 sec.
# 719-th simulation finished, 0.003005 sec.
# 720-th simulation finished, 0.002992 sec.
# 721-th simulation finished, 0.002828 sec.
# 722-th simulation finished, 0.001792 sec.
# 723-th simulation finished, 0.008723 sec.
# 724-th simulation finished, 0.011756 sec.
# 725-th simulation finished, 0.003296 sec.
# 726-th simulation finished, 0.002913 sec.
# 727-th simulation finished, 0.004179 sec.
# 728-th simulation finished, 0.003649 sec.
# 729-th simulation finished, 0.003418 sec.
# 730-th simulation finished, 0.001955 sec.
# 731-th simulation finished, 0.001852 sec.
# 732-th simulation finished, 0.001756 sec.
# 733-th simulation finished, 0.003174 sec.
# 734-th simulation finished, 0.002873 sec.
# 735-th simulation finished, 0.002983 sec.
# 736-th simulation finished, 0.001766 sec.
# 737-th simulation finished, 0.010362 sec.
# 738-th simulation finished, 0.001690 sec.
# 739-th simulation finished, 0.010625 sec.
# 740-th simulation finished, 0.003157 sec.
# 741-th simulation finished, 0.003008 sec.
# 742-th simulation finished, 0.002806 sec.
# 743-th simulation finished, 0.002249 sec.
# 744-th simulation finished, 0.001841 sec.
# 745-th simulation finished, 0.003470 sec.
# 746-th simulation finished, 0.003112 sec.
# 747-th simulation finished, 0.001698 sec.
# 748-th simulation finished, 0.009760 sec.
# 749-th simulation finished, 0.011622 sec.
# 750-th simulation finished, 0.005403 sec.
# 751-th simulation finished, 0.003274 sec.
# 752-th simulation finished, 0.002075 sec.
# 753-th simulation finished, 0.001821 sec.
# 754-th simulation finished, 0.001743 sec.
# 755-th simulation finished, 0.003187 sec.
# 756-th simulation finished, 0.003677 sec.
# 757-th simulation finished, 0.003233 sec.
# 758-th simulation finished, 0.002019 sec.
# 759-th simulation finished, 0.002989 sec.
# 760-th simulation finished, 0.003257 sec.
# 761-th simulation finished, 0.002863 sec.
# 762-th simulation finished, 0.001729 sec.
# 763-th simulation finished, 0.003267 sec.
# 764-th simulation finished, 0.002991 sec.
# 765-th simulation finished, 0.002823 sec.
# 766-th simulation finished, 0.002168 sec.
# 767-th simulation finished, 0.011207 sec.
# 768-th simulation finished, 0.012211 sec.
# 769-th simulation finished, 0.003167 sec.
# 770-th simulation finished, 0.003036 sec.
# 771-th simulation finished, 0.002836 sec.
# 772-th simulation finished, 0.001674 sec.
# 773-th simulation finished, 0.011983 sec.
# 774-th simulation finished, 0.009406 sec.
# 775-th simulation finished, 0.001661 sec.
# 776-th simulation finished, 0.001616 sec.
# 777-th simulation finished, 0.003212 sec.
# 778-th simulation finished, 0.003199 sec.
# 779-th simulation finished, 0.003229 sec.
# 780-th simulation finished, 0.003703 sec.
# 781-th simulation finished, 0.003089 sec.
# 782-th simulation finished, 0.002996 sec.
# 783-th simulation finished, 0.002348 sec.
# 784-th simulation finished, 0.001753 sec.
# 785-th simulation finished, 0.001747 sec.
# 786-th simulation finished, 0.003156 sec.
# 787-th simulation finished, 0.002725 sec.
# 788-th simulation finished, 0.001880 sec.
# 789-th simulation finished, 0.003292 sec.
# 790-th simulation finished, 0.003042 sec.
# 791-th simulation finished, 0.003573 sec.
# 792-th simulation finished, 0.002260 sec.
# 793-th simulation finished, 0.003099 sec.
# 794-th simulation finished, 0.002886 sec.
# 795-th simulation finished, 0.002810 sec.
# 796-th simulation finished, 0.002275 sec.
# 797-th simulation finished, 0.001653 sec.
# 798-th simulation finished, 0.003100 sec.
# 799-th simulation finished, 0.003399 sec.
# 800-th simulation finished, 0.003002 sec.
# 801-th simulation finished, 0.001748 sec.
# 802-th simulation finished, 0.003053 sec.
# 803-th simulation finished, 0.002820 sec.
# 804-th simulation finished, 0.002825 sec.
# 805-th simulation finished, 0.002010 sec.
# 806-th simulation finished, 0.001851 sec.
# 807-th simulation finished, 0.001799 sec.
# 808-th simulation finished, 0.003033 sec.
# 809-th simulation finished, 0.003642 sec.
# 810-th simulation finished, 0.002823 sec.
# 811-th simulation finished, 0.001952 sec.
# 812-th simulation finished, 0.001928 sec.
# 813-th simulation finished, 0.011910 sec.
# 814-th simulation finished, 0.006397 sec.
# 815-th simulation finished, 0.002681 sec.
# 816-th simulation finished, 0.001710 sec.
# 817-th simulation finished, 0.001689 sec.
# 818-th simulation finished, 0.001636 sec.
# 819-th simulation finished, 0.001660 sec.
# 820-th simulation finished, 0.001651 sec.
# 821-th simulation finished, 0.001659 sec.
# 822-th simulation finished, 0.002326 sec.
# 823-th simulation finished, 0.002067 sec.
# 824-th simulation finished, 0.001668 sec.
# 825-th simulation finished, 0.001674 sec.
# 826-th simulation finished, 0.001630 sec.
# 827-th simulation finished, 0.001649 sec.
# 828-th simulation finished, 0.001640 sec.
# 829-th simulation finished, 0.001989 sec.
# 830-th simulation finished, 0.001758 sec.
# 831-th simulation finished, 0.001722 sec.
# 832-th simulation finished, 0.001660 sec.
# 833-th simulation finished, 0.001633 sec.
# 834-th simulation finished, 0.001659 sec.
# 835-th simulation finished, 0.001615 sec.
# 836-th simulation finished, 0.001650 sec.
# 837-th simulation finished, 0.001694 sec.
# 838-th simulation finished, 0.001759 sec.
# 839-th simulation finished, 0.001801 sec.
# 840-th simulation finished, 0.001680 sec.
# 841-th simulation finished, 0.002421 sec.
# 842-th simulation finished, 0.001608 sec.
# 843-th simulation finished, 0.001532 sec.
# 844-th simulation finished, 0.001570 sec.
# 845-th simulation finished, 0.001516 sec.
# 846-th simulation finished, 0.001526 sec.
# 847-th simulation finished, 0.001493 sec.
# 848-th simulation finished, 0.002362 sec.
# 849-th simulation finished, 0.003024 sec.
# 850-th simulation finished, 0.002934 sec.
# 851-th simulation finished, 0.002641 sec.
# 852-th simulation finished, 0.001733 sec.
# 853-th simulation finished, 0.001655 sec.
# 854-th simulation finished, 0.001655 sec.
# 855-th simulation finished, 0.001635 sec.
# 856-th simulation finished, 0.001640 sec.
# 857-th simulation finished, 0.001627 sec.
# 858-th simulation finished, 0.001647 sec.
# 859-th simulation finished, 0.001843 sec.
# 860-th simulation finished, 0.001697 sec.
# 861-th simulation finished, 0.001638 sec.
# 862-th simulation finished, 0.001677 sec.
# 863-th simulation finished, 0.001627 sec.
# 864-th simulation finished, 0.001651 sec.
# 865-th simulation finished, 0.002019 sec.
# 866-th simulation finished, 0.001720 sec.
# 867-th simulation finished, 0.001620 sec.
# 868-th simulation finished, 0.001659 sec.
# 869-th simulation finished, 0.001615 sec.
# 870-th simulation finished, 0.001645 sec.
# 871-th simulation finished, 0.001614 sec.
# 872-th simulation finished, 0.001649 sec.
# 873-th simulation finished, 0.002920 sec.
# 874-th simulation finished, 0.002969 sec.
# 875-th simulation finished, 0.002796 sec.
# 876-th simulation finished, 0.003715 sec.
# 877-th simulation finished, 0.001791 sec.
# 878-th simulation finished, 0.001771 sec.
# 879-th simulation finished, 0.001647 sec.
# 880-th simulation finished, 0.001666 sec.
# 881-th simulation finished, 0.001626 sec.
# 882-th simulation finished, 0.001653 sec.
# 883-th simulation finished, 0.001624 sec.
# 884-th simulation finished, 0.012197 sec.
# 885-th simulation finished, 0.001860 sec.
# 886-th simulation finished, 0.001735 sec.
# 887-th simulation finished, 0.010557 sec.
# 888-th simulation finished, 0.009979 sec.
# 889-th simulation finished, 0.002990 sec.
# 890-th simulation finished, 0.002991 sec.
# 891-th simulation finished, 0.001769 sec.
# 892-th simulation finished, 0.001646 sec.
# 893-th simulation finished, 0.003899 sec.
# 894-th simulation finished, 0.003110 sec.
# 895-th simulation finished, 0.002768 sec.
# 896-th simulation finished, 0.003672 sec.
# 897-th simulation finished, 0.002935 sec.
# 898-th simulation finished, 0.002920 sec.
# 899-th simulation finished, 0.001650 sec.
# 900-th simulation finished, 0.012912 sec.
# 901-th simulation finished, 0.003445 sec.
# 902-th simulation finished, 0.003006 sec.
# 903-th simulation finished, 0.002346 sec.
# 904-th simulation finished, 0.003588 sec.
# 905-th simulation finished, 0.003745 sec.
# 906-th simulation finished, 0.002963 sec.
# 907-th simulation finished, 0.001720 sec.
# 908-th simulation finished, 0.002904 sec.
# 909-th simulation finished, 0.002993 sec.
# 910-th simulation finished, 0.002916 sec.
# 911-th simulation finished, 0.002352 sec.
# 912-th simulation finished, 0.007934 sec.
# 913-th simulation finished, 0.001760 sec.
# 914-th simulation finished, 0.001800 sec.
# 915-th simulation finished, 0.006719 sec.
# 916-th simulation finished, 0.002806 sec.
# 917-th simulation finished, 0.003184 sec.
# 918-th simulation finished, 0.001766 sec.
# 919-th simulation finished, 0.001581 sec.
# 920-th simulation finished, 0.003041 sec.
# 921-th simulation finished, 0.001834 sec.
# 922-th simulation finished, 0.003336 sec.
# 923-th simulation finished, 0.003124 sec.
# 924-th simulation finished, 0.002959 sec.
# 925-th simulation finished, 0.001980 sec.
# 926-th simulation finished, 0.003078 sec.
# 927-th simulation finished, 0.002834 sec.
# 928-th simulation finished, 0.003304 sec.
# 929-th simulation finished, 0.001710 sec.
# 930-th simulation finished, 0.003807 sec.
# 931-th simulation finished, 0.003142 sec.
# 932-th simulation finished, 0.002897 sec.
# 933-th simulation finished, 0.001769 sec.
# 934-th simulation finished, 0.001688 sec.
# 935-th simulation finished, 0.001555 sec.
# 936-th simulation finished, 0.001750 sec.
# 937-th simulation finished, 0.008756 sec.
# 938-th simulation finished, 0.010478 sec.
# 939-th simulation finished, 0.001737 sec.
# 940-th simulation finished, 0.001786 sec.
# 941-th simulation finished, 0.010517 sec.
# 942-th simulation finished, 0.003255 sec.
# 943-th simulation finished, 0.003027 sec.
# 944-th simulation finished, 0.002759 sec.
# 945-th simulation finished, 0.001743 sec.
# 946-th simulation finished, 0.001789 sec.
# 947-th simulation finished, 0.003089 sec.
# 948-th simulation finished, 0.002827 sec.
# 949-th simulation finished, 0.003143 sec.
# 950-th simulation finished, 0.002926 sec.
# 951-th simulation finished, 0.002799 sec.
# 952-th simulation finished, 0.002012 sec.
# 953-th simulation finished, 0.001690 sec.
# 954-th simulation finished, 0.006978 sec.
# 955-th simulation finished, 0.010329 sec.
# 956-th simulation finished, 0.002089 sec.
# 957-th simulation finished, 0.010809 sec.
# 958-th simulation finished, 0.001786 sec.
# 959-th simulation finished, 0.003624 sec.
# 960-th simulation finished, 0.003188 sec.
# 961-th simulation finished, 0.003104 sec.
# 962-th simulation finished, 0.001728 sec.
# 963-th simulation finished, 0.001645 sec.
# 964-th simulation finished, 0.001605 sec.
# 965-th simulation finished, 0.010755 sec.
# 966-th simulation finished, 0.003130 sec.
# 967-th simulation finished, 0.002835 sec.
# 968-th simulation finished, 0.002782 sec.
# 969-th simulation finished, 0.001826 sec.
# 970-th simulation finished, 0.001697 sec.
# 971-th simulation finished, 0.010190 sec.
# 972-th simulation finished, 0.007964 sec.
# 973-th simulation finished, 0.001684 sec.
# 974-th simulation finished, 0.005250 sec.
# 975-th simulation finished, 0.001733 sec.
# 976-th simulation finished, 0.001762 sec.
# 977-th simulation finished, 0.001681 sec.
# 978-th simulation finished, 0.010896 sec.
# 979-th simulation finished, 0.003199 sec.
# 980-th simulation finished, 0.003040 sec.
# 981-th simulation finished, 0.001889 sec.
# 982-th simulation finished, 0.001783 sec.
# 983-th simulation finished, 0.003418 sec.
# 984-th simulation finished, 0.003139 sec.
# 985-th simulation finished, 0.002544 sec.
# 986-th simulation finished, 0.003082 sec.
# 987-th simulation finished, 0.002832 sec.
# 988-th simulation finished, 0.001909 sec.
# 989-th simulation finished, 0.001722 sec.
# 990-th simulation finished, 0.001709 sec.
# 991-th simulation finished, 0.003298 sec.
# 992-th simulation finished, 0.009905 sec.
# 993-th simulation finished, 0.002656 sec.
# 994-th simulation finished, 0.001636 sec.
# 995-th simulation finished, 0.003075 sec.
# 996-th simulation finished, 0.003080 sec.
# 997-th simulation finished, 0.002900 sec.
# 998-th simulation finished, 0.002996 sec.
# 999-th simulation finished, 0.002842 sec.
# 1000-th simulation finished, 0.002902 sec.

# %%
plt.hist(bsim[:,1])
plt.axvline(beta[1], color='red')

# %%
stats.probplot(bsim[:,1], dist = 'norm', plot=plt, fit=True)
# plt.plot([0, 1], [0, 1], color='black')
plt.show()

# %%
plt.hist(Ts_dth)
# Out:
# (array([ 75., 151., 249., 233., 156.,  86.,  34.,  12.,   3.,   1.]),
#  array([-1.9627979 , -1.3432855 , -0.72377309, -0.10426068,  0.51525173,
#          1.13476414,  1.75427654,  2.37378895,  2.99330136,  3.61281377,
#          4.23232618]),
#  <BarContainer object of 10 artists>)

# %%
stats.probplot(ps_dth, dist = 'uniform', plot=plt, fit=False)
plt.plot([0, 1], [0, 1], color='black')
plt.show()

# %%
np.mean(np.abs(ps_dth) > 0.05)
# Out:
# 0.961

# %%
stats.probplot(ps_sdw, dist = 'uniform', plot=plt, fit=False)
plt.plot([0, 1], [0, 1], color='black')
plt.show()

# %%
np.mean(np.abs(ps_sdw) > 0.05)
# Out:
# 0.938
